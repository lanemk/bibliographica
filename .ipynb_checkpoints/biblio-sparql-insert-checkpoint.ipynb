# %% [markdown]
# Copyright - Michael Lane. 2022. All Rights Reserved.

# %% [markdown]
# ### Using SPARQL to INSERT data into an RDF graph
#
# #### Bibliographica Ontology & Dataset
#
# The following queries insert data regarding a collection of books, authors, CDs, bootlegs, videos, solo artists, and bands.

# %% [markdown]
# #### First, what's running in the background, i.e., config, system status...

# %%
# %graph_notebook_version

# %%
# %graph_notebook_config

# %%
# %status

# %% [markdown]
# #### Load data: Bulk Loader (optional)

# %%
# %%load

# %% [markdown]
# #### Delete data, as needed (optional)

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# DELETE { GRAPH ?g { ?s ?p ?o } } WHERE { GRAPH ?g { ?s ?p ?o } }

# %% [markdown]
# ### Insert data: Bibliographica
#
# Use  the following SPARQL INSERT DATA template:

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
#
#
# }

# %% [markdown]
# #### Ontology

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# :viafURI  a           owl:DatatypeProperty ;
#         rdfs:comment  "This resource captures, or encodes a link to Library of Congress entities. It is presented as RDF file format URI (content-negotiable)." ;
#         rdfs:label    "viaf URI" ;
#         rdfs:range    xsd:anyURI .
#
# :infoFileURL  a       owl:DatatypeProperty ;
#         rdfs:comment  "URL where an info file can be accessed for a Live Music Release." ;
#         rdfs:label    "has info file URL" ;
#         rdfs:range    xsd:anyURI .
#
# :worldcatURI  a       owl:DatatypeProperty ;
#         rdfs:comment  "This resource captures, or encodes a link to Worldcat entities. It is presented as N3/Turtle format URI (content-negotiable)." ;
#         rdfs:label    "Worldcat URI" ;
#         rdfs:range    xsd:anyURI .
#
# :PerformanceQualityRating
#         a                owl:Class ;
#         rdfs:comment     "Evaluation of performance; 1 to 5 stars, 1 being lowest, 5 the highest." ;
#         rdfs:label       "Performance Quality Rating" ;
#         rdfs:subClassOf  schema:Rating .
#
# :audience  a        :RecordingType ;
#         rdfs:label  "Audience recording" .
#
# :AlphaClass  a           owl:Class ;
#         rdfs:label       "Alphabetical Class" ;
#         rdfs:subClassOf  schema:Intangible .
#
# :performanceRating  a  owl:DatatypeProperty ;
#         rdfs:comment  "The rating for the quality of the performance." ;
#         rdfs:domain   :PerformanceQualityRating ;
#         rdfs:label    "Performance rating" ;
#         rdfs:range    xsd:integer .
#
# :AlphaClassUV  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "U-V" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassVarious , :AlphaClassMP , :AlphaClassWZ , :AlphaClassAD , :AlphaClassQT , :AlphaClassEH , :AlphaClassIL , :AlphaClassNUM .
#
# :numberOfitems  a     owl:DatatypeProperty ;
#         rdfs:comment  "This property refers to the number of item copies are in the collection.." ;
#         rdfs:label    "Number of iterms" ;
#         rdfs:range    xsd:integer .
#
# :AlphaClassQT  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "Q-T" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassEH , :AlphaClassVarious , :AlphaClassIL , :AlphaClassUV , :AlphaClassMP , :AlphaClassNUM , :AlphaClassAD , :AlphaClassWZ .
#
# :ebook_format  a      owl:DatatypeProperty ;
#         rdfs:comment  "The type of digital format for an ebook." ;
#         rdfs:label    "has ebook format" .
#
# :AlphaClassIL  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "I-L" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassMP , :AlphaClassUV , :AlphaClassEH , :AlphaClassNUM , :AlphaClassWZ , :AlphaClassAD , :AlphaClassQT , :AlphaClassVarious .
#
# :soundboard  a      :RecordingType ;
#         rdfs:label  "Soundboard recording" .
#
# <http://www.connaissance.io/onto/biblio/bibliographica>
#         a                 owl:Ontology ;
#         rdfs:comment      "Created by M Lane" ;
#         dcterms:modified  "2020-10-24"^^xsd:date ;
#         owl:imports       dcterms: , <http://topbraid.org/schema/schema-single-range> , <http://topbraid.org/schema/> , <http://musicontology.com/specification/> , foaf: , <http://www.w3.org/2004/02/skos/core> ;
#         owl:versionInfo   "Version 2.1" .
#
# :AlphaClassAD  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "A-D" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassVarious , :AlphaClassMP , :AlphaClassIL , :AlphaClassNUM , :AlphaClassWZ , :AlphaClassQT , :AlphaClassUV , :AlphaClassEH .
#
# :binNumber  a         owl:DatatypeProperty ;
#         rdfs:comment  "This property refers to the bin container where the item is stored." ;
#         rdfs:label    "Bin number" ;
#         rdfs:range    xsd:integer .
#
# :AlphaClassVarious  a     rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying compilations by name." ;
#         rdfs:label        "Alphabetical Class Various" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassEH , :AlphaClassMP , :AlphaClassWZ , :AlphaClassAD , :AlphaClassIL , :AlphaClassNUM , :AlphaClassQT , :AlphaClassUV .
#
# :musicbrainzURI  a    owl:DatatypeProperty ;
#         rdfs:comment  "This resource captures, or encodes a link to MusicBrainz entities; can't determine if Collection Ontology possesses such a property, except that mo:musicbrainz won't accept a URI. In principle, this URI links a given entity in Bibliographica to the MusicBrainz graph. It is presented in N3/Turtle format (content-negotiable)." ;
#         rdfs:label    "Musicbrainz URI" ;
#         rdfs:range    xsd:anyURI .
#
# :RecordingType  a        owl:Class ;
#         rdfs:label       "Recording type" ;
#         rdfs:subClassOf  mo:ReleaseType .
#
# :AlphaClassWZ  a          owl:Class , rdfs:Datatype ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "W-Z" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassVarious , :AlphaClassQT , :AlphaClassUV , :AlphaClassAD , :AlphaClassEH , :AlphaClassIL , :AlphaClassMP , :AlphaClassNUM .
#
# :locationVenue  a     owl:AnnotationProperty ;
#         rdfs:comment  "The location of a music venue, theater, ampitheater, etc., though may revert to the city of the event if the venue is not specified. If neither is known, the labe should specify \"unknown.\"" ;
#         rdfs:label    "location" ;
#         rdfs:range    xsd:string .
#
# :fm     a             :RecordingType ;
#         rdfs:comment  "A recording derived from FM radio broadcast." ;
#         rdfs:label    "FM recording" .
#
# :SoundQualityRating  a   owl:Class ;
#         rdfs:comment     "Evaluation of sound quality (listening); 1 to 5 stars, 1 being lowest, 5 the highest." ;
#         rdfs:label       "Sound Quality Rating" ;
#         rdfs:subClassOf  schema:Rating .
#
# :LiveMusicRec  a         owl:Class ;
#         rdfs:label       "Live Bootleg" ;
#         rdfs:subClassOf  mo:Recording , mo:Performance .
#
# :dbpediaURI  a        owl:DatatypeProperty ;
#         rdfs:comment  "This resource captures, or encodes a link to DBpedia entities. It is presented as N3/Turtle format URI (content-negotiable)." ;
#         rdfs:label    "DBpedia URI" ;
#         rdfs:range    xsd:anyURI .
#
# :AlphaClassNUM  a         rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group, only the name begins with a number (i.e., 10,000 Maniacs or 4 Non Blondes)." ;
#         rdfs:label        "Numeric" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassWZ , :AlphaClassAD , :AlphaClassEH , :AlphaClassIL , :AlphaClassVarious , :AlphaClassUV , :AlphaClassMP , :AlphaClassQT .
#
# :soundtrack  a        :RecordingType ;
#         rdfs:comment  "Typically derived from a video recording sound track." ;
#         rdfs:label    "Soundtrack recording" .
#
# mo:MusicGroup  owl:equivalentClass  schema:MusicGroup .
#
# :AlphaClassMP  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "M-P" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassQT , :AlphaClassAD , :AlphaClassEH , :AlphaClassVarious , :AlphaClassUV , :AlphaClassIL , :AlphaClassNUM , :AlphaClassWZ .
#
# :AlphaClassEH  a          rdfs:Datatype , owl:Class ;
#         rdfs:comment      "Use for classifying creators by name as a group." ;
#         rdfs:label        "E-H" ;
#         rdfs:subClassOf   :AlphaClass ;
#         owl:disjointWith  :AlphaClassQT , :AlphaClassAD , :AlphaClassIL , :AlphaClassWZ , :AlphaClassMP , :AlphaClassNUM , :AlphaClassVarious , :AlphaClassUV .
#
# :soundQualityValue  a  owl:DatatypeProperty ;
#         rdfs:comment  "The rating for the sound quality of the content." ;
#         rdfs:domain   :SoundQualityRating ;
#         rdfs:label    "Sound quality rating" ;
#         rdfs:range    xsd:int .
#
# :byArtist  a                owl:ObjectProperty ;
#         rdfs:comment        "The artist that performed this album or recording." , "Extended schema:byArtist property to enable LiveMusicRecording domain." ;
#         rdfs:domain         [ a            owl:Class ;
#                               owl:unionOf  ( schema:MusicAlbum schema:MusicRecording )
#                             ] ;
#         rdfs:label          "by artist" ;
#         rdfs:range          [ a            owl:Class ;
#                               owl:unionOf  ( schema:MusicGroup mo:SoloMusicArtist )
#                             ] ;
#         rdfs:subPropertyOf  <http://purl.org/dc/elements/1.1/creator> .
#
# :digital_satellite  a  :RecordingType ;
#         rdfs:comment  "A recording derived from digital satellite broadcast." ;
#         rdfs:label    "Digital satellite recording" .
#
# :studio  a            :RecordingType ;
#         rdfs:comment  "Typically derived from a studio recording, but not necessarily a commercial release." ;
#         rdfs:label    "Studio recording" .
#
# }

# %% [markdown]
# #### Authors

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
#   <http://www.connaissance.io/onto/biblio/authors>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-20" ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#   dcterms:description "Authors, co-writers, editors of literature, serialized in RDF." ;
#   owl:imports <https://www.connaissance.io/onto/biblio/MusicGroup> ;
#   owl:imports <https://www.connaissance.io/onto/biblio/SoloMusicArtist> ;
#   owl:imports <https://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Made by M Lane" .
#
#
# authors:Olive_Ann_Burns  a                schema:Person ;
#         rdfs:label                 "Olive Ann Burns" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Olive_Ann_Burns.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91920255/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Olive Ann Burns" .
#
# authors:Hubert_Selby_Jr  a                schema:Person ;
#         rdfs:label                 "Hubert Selby Jr." ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hubert_Selby_Jr..ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73860124/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hubert Selby Jr." .
#
# authors:Miklos_Udvardy  a                 schema:Person ;
#         rdfs:label                 "Miklos Udvardy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Miklos_Udvardy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110129554/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Miklos Udvardy" .
#
# authors:Helen_Fielding  a                 schema:Person ;
#         rdfs:label                 "Helen Fielding" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Helen_Fielding.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/5075561/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Helen Fielding" .
#
# authors:Adriana_Trigiani  a               schema:Person ;
#         rdfs:label                 "Adriana Trigiani" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Adriana_Trigiani.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/33051445/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Adriana Trigiani" .
#
# authors:Leo_Tolstoy  a                    schema:Person ;
#         rdfs:label                 "Leo Tolstoy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Leo_Tolstoy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96987389/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "graf Leo Tolstoy" .
#
# authors:Jon_Krakauer  a                   schema:Person ;
#         rdfs:label                 "Jon Krakauer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jon_Krakauer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54285366/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jon Krakauer" .
#
# authors:Terry_Brooks  a                   schema:Person ;
#         rdfs:label                 "Terry Brooks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Terry_Brooks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73911214/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Terry Brooks" .
#
# authors:Robert_Brockway  a             schema:Person ;
#         rdfs:label              "Robert Brockway" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/42053730/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Robert Brockway" .
#
# authors:Richard_Powers  a                 schema:Person ;
#         rdfs:label                 "Richard Powers" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Powers.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113865419/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Powers" .
#
# authors:Arthur_Conan_Doyle  a             schema:Person ;
#         rdfs:label                 "Arthur Conan Doyle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arthur_Conan_Doyle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/65283845/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arthur Conan Doyle" .
#
# authors:Madonna  a                        schema:Person ;
#         rdfs:label                 "Madonna" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Madonna.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59270244/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Madonna" .
#
# authors:JJ_Henderson  a    schema:Person ;
#         rdfs:label  "J.J. Henderson" ;
#         foaf:name   "J.J. Henderson" .
#
# authors:Abraham_Verghese  a               schema:Person ;
#         rdfs:label                 "Abraham Verghese" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Abraham_Verghese.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93233765/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Abraham Verghese" .
#
# authors:Keith_Jack  a                  schema:Person ;
#         rdfs:label              "Keith Jack" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/32275531/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Keith Jack" .
#
# authors:DeLorme_Mapping_Company
#         a                       schema:Organization ;
#         rdfs:label              "DeLorme Mapping Company" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/266202041/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "DeLorme Mapping Company" .
#
# authors:Patrick_Humphries  a           schema:Person ;
#         rdfs:label              "Patrick Humphries" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/52355727/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Patrick Humphries" .
#
# authors:Gord_Rollo  a      schema:Person ;
#         rdfs:label  "Gord Rollo" ;
#         foaf:name   "Gord Rollo" .
#
# authors:Frederick_Copleston  a            schema:Person ;
#         rdfs:label                 "Frederick Copleston, S.J." ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frederick_Copleston.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108253278/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frederick Copleston, S.J." .
#
# authors:John_Burdett  a                   schema:Person ;
#         rdfs:label                 "John Burdett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Burdett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73961581/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Burdett" .
#
# authors:Bill_Morris  a                    schema:Person ;
#         rdfs:label                 "Bill Morris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Morris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113659463/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Morris" .
#
# authors:Ottmar_Liebert  a              schema:Person ;
#         rdfs:label              "Ottmar Liebert" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/237729511/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ottmar Liebert" .
#
# authors:Frank_Waters  a                   schema:Person ;
#         rdfs:label                 "Frank Waters" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frank_Waters.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85185478/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frank Waters" .
#
# authors:Noam_Chomsky  a                   schema:Person ;
#         rdfs:label                 "Noam Chomsky" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Noam_Chomsky.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/89803084/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Noam Chomsky" .
#
# authors:Stephen_Myhre  a               schema:Person ;
#         rdfs:label              "Stephen Myhre" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/5160302/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Stephen Myhre" .
#
# authors:Patricia_Schechter  a          schema:Person ;
#         rdfs:label              "Patricia Schechter" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/7267162/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Patricia Schechter" .
#
# authors:JG_Ballard  a                     schema:Person ;
#         rdfs:label                 "J. G. Ballard" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._G._Ballard.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9842556/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J. G. Ballard" .
#
# authors:David_Baldacci  a                 schema:Person ;
#         rdfs:label                 "David Baldacci" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Baldacci.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102339955/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Baldacci" .
#
# authors:Arthur_Winfield_Knight
#         a                       schema:Person ;
#         rdfs:label              "Arthur Winfield Knight" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/109831283/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Arthur Winfield Knight" .
#
# authors:Neal_Stephenson  a                schema:Person ;
#         rdfs:label                 "Neal Stephenson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Neal_Stephenson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7524021/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Neal Stephenson" .
#
# authors:Ayya_Khema  a                     schema:Person ;
#         rdfs:label                 "Ayya Khema" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ayya_Khema.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12447324/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ayya Khema" .
#
# authors:Alexander_McCall_Smith
#         a                          schema:Person ;
#         rdfs:label                 "Alexander McCall Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alexander_McCall_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/86227797/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alexander McCall Smith" .
#
# authors:George_Crile  a                   schema:Person ;
#         rdfs:label                 "George Crile" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_Crile_III.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71728324/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George Crile" .
#
# authors:Izaak_Walton  a                schema:Person ;
#         rdfs:label              "Izaak Walton" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/73863052/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Izaak Walton" .
#
# authors:John_Steinbeck  a                 schema:Person ;
#         rdfs:label                 "John Steinbeck" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Steinbeck.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96992551/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Steinbeck" .
#
# authors:Aesop  a                          schema:Person ;
#         rdfs:label                 "Aesop" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Aesop.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64013451/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Aesop" .
#
# authors:William_Gibson  a                 schema:Person ;
#         rdfs:label                 "William Gibson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Gibson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109517110/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Gibson" .
#
# authors:Ayaan_Hirsi_Ali  a                schema:Person ;
#         rdfs:label                 "Ayaan Hirsi Ali" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ayaan_Hirsi_Ali.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100329178/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ayaan Hirsi Ali" .
#
# authors:David_Downing  a                  schema:Person ;
#         rdfs:label                 "David Downing" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Downing.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/6900037/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Downing" .
#
# authors:Michael_Dibdin  a                 schema:Person ;
#         rdfs:label                 "Michael Dibdin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Dibdin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112722880/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Dibdin" .
#
# authors:Victor_Hugo  a                    schema:Person ;
#         rdfs:label                 "Victor Hugo" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Victor_Hugo.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9847974/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Victor Hugo" .
#
# authors:William_Carpenter  a              schema:Person ;
#         rdfs:label                 "William Carpenter" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Carpenter_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/278946902/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Carpenter" .
#
# authors:Wilhelm_Grimm  a                  schema:Person ;
#         rdfs:label                 "Wilhelm Grimm" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Wilhelm_Grimm.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14770699/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Wilhelm Grimm" .
#
# authors:Dr_Seuss  a                       schema:Person ;
#         rdfs:label                 "Dr. Seuss" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dr._Seuss.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/20959831/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dr. Seuss" .
#
# authors:John_Robbins  a                   schema:Person ;
#         rdfs:label                 "John Robbins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Robbins_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32691191/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Robbins" .
#
# authors:Tana_French  a                    schema:Person ;
#         rdfs:label                 "Tana French" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tana_French.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/149427877/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tana French" .
#
# authors:Denise_Chavez  a                  schema:Person ;
#         rdfs:label                 "Denise Chávez" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Denise_Chávez.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93811704/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Denise Chávez" .
#
# authors:Scott_Sigler  a                   schema:Person ;
#         rdfs:label                 "Scott Sigler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Scott_Sigler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/120765873/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Scott Sigler" .
#
# authors:Peter_Gadol  a                    schema:Person ;
#         rdfs:label                 "Peter Gadol" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Gadol.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93147476/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Gadol" .
#
# authors:Harper_Lee  a                     schema:Person ;
#         rdfs:label                 "Harper Lee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Harper_Lee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12431460/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Harper Lee" .
#
# authors:Thomas_Sanchez  a                 schema:Person ;
#         rdfs:label                 "Thomas Sanchez" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_Sanchez_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64011584/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Sanchez" .
#
# authors:Mary_Estella  a    schema:Person ;
#         rdfs:label  "Mary Estella" ;
#         foaf:name   "Mary Estella" .
#
# authors:Kent_Anderson  a                  schema:Person ;
#         rdfs:label                 "Kent Anderson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kent_Anderson_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/116848968/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kent Anderson" .
#
# authors:Steven_Johnson  a                 schema:Person ;
#         rdfs:label                 "Steven Johnson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Johnson_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42099221/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Johnson" .
#
# authors:Neil_Gaiman  a                    schema:Person ;
#         rdfs:label                 "Neil Gaiman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Neil_Gaiman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103859257/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Neil Gaiman" .
#
# authors:Sandra_Benitez  a                 schema:Person ;
#         rdfs:label                 "Sandra Benitez" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sandra_Benitez.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117628163/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sandra Benitez" .
#
# authors:Steven_Jenkins  a              schema:Person ;
#         rdfs:label              "Steven Jenkins" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/55824536/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Steven Jenkins" .
#
# authors:Rebecca_Wood  a                schema:Organization ;
#         rdfs:label              "Rebecca Theurer Wood" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/18585113/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Rebecca Theurer Wood" .
#
# authors:Collins_Publishing  a             schema:Organization ;
#         rdfs:label                 "Collins Publishing" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/HarperCollins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/129138489/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Collins Publishing" .
#
# authors:Tony_Birks  a                  schema:Person ;
#         rdfs:label              "Tony Birks" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/37036487/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Tony Birks" .
#
# authors:Mira_Grant  a                     schema:Person ;
#         rdfs:label                 "Mira Grant" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Seanan_McGuire.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97615503/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Seanan McGuire" ;
#         foaf:name                  "Mira Grant" .
#
# authors:Creative_Publishing  a         schema:Organization ;
#         rdfs:label              "Creative Publishing International" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/141786788/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Creative Publishing International" .
#
# authors:Anne_Rice  a                      schema:Person ;
#         rdfs:label                 "Anne Rice" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anne_Rice.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111989334/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anne Rice" .
#
# authors:Argie_Ligeros  a   schema:Person ;
#         rdfs:label  "Argie Ligeros" ;
#         foaf:name   "Argie Ligeros" .
#
# authors:John_Barth  a                     schema:Person ;
#         rdfs:label                 "John Barth" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Barth.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85932912/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Barth" .
#
# authors:Richard_Feynman  a                schema:Person ;
#         rdfs:label                 "Richard Feynman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Feynman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44298691/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard P. Feynman" .
#
# authors:Pattie_Vargas  a               schema:Person ;
#         bibliographica:viafURI  "https://viaf.org/viaf/93899257/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Pattie Vargas" .
#
# authors:Markus_Zusak  a                   schema:Person ;
#         rdfs:label                 "Markus Zusak" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Markus_Zusak.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50566653/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Markus Zusak" .
#
# authors:Alfred_Bester  a                  schema:Person ;
#         rdfs:label                 "Alfred Bester" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alfred_Bester..ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56605956/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alfred Bester" .
#
# authors:Gillian_Flynn  a                  schema:Person ;
#         rdfs:label                 "Gillian Flynn" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gillian_Flynn.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103168327/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gillian Flynn" .
#
# authors:Emily_Dodi  a                  schema:Person ;
#         rdfs:label              "Emily Dodi" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/16429550/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Emily Dodi" .
#
# authors:Edward_Rutherfurd  a              schema:Person ;
#         rdfs:label                 "Edward Rutherfurd" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edward_Rutherfurd.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60273426/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Francis Edward Wintle" ;
#         foaf:name                  "Edward Rutherfurd" .
#
# authors:Peter_Beilenson  a             schema:Person ;
#         rdfs:label              "Peter Beilenson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/75150766/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Peter Beilenson" .
#
# authors:Mark_Jacobs  a                    schema:Person ;
#         rdfs:label                 "Mark Jacobs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mark_Jacobs_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92288740/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mark Jacobs" .
#
# authors:Christian_Cantrell  a          schema:Person ;
#         rdfs:label              "Christian Cantrell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/46699029/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Christian Cantrell" .
#
# authors:Chinua_Achebe  a                  schema:Person ;
#         rdfs:label                 "Chinua Achebe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chinua_Achebe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/48164791/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chinua Achebe" .
#
# authors:Lawrence_Millman  a               schema:Person ;
#         rdfs:label                 "Lawrence Millman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lawrence_Millman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79357473/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lawrence Millman" .
#
# authors:Elizabeth_David  a                schema:Person ;
#         rdfs:label                 "Elizabeth David" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elizabeth_David.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112933568/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elizabeth David" .
#
# authors:Jonathan_Swift  a                 schema:Person ;
#         rdfs:label                 "Jonathan Swift" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jonathan_Swift.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14777110/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jonathan Swift" .
#
# authors:Kurt_Vonnegut  a                  schema:Person ;
#         rdfs:label                 "Kurt Vonnegut" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kurt_Vonnegut.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71398958/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kurt Vonnegut" .
#
# authors:Ernest_Callenbach  a              schema:Person ;
#         rdfs:label                 "Ernest Callenbach" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ernest_Callenbach.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39558998/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ernest Callenbach" .
#
# authors:Kenneth_Ring  a                   schema:Person ;
#         rdfs:label                 "Kenneth Ring" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kenneth_Ring.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49230744/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kenneth Ring" .
#
# authors:Carl_Hiaasen  a                   schema:Person ;
#         rdfs:label                 "Carl Hiaasen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carl_Hiaasen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2519004/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Carl Hiaasen" .
#
# authors:Chelsea_Handler  a                schema:Person ;
#         rdfs:label                 "Chelsea Handler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chelsea_Handler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12619513/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chelsea Handler" .
#
# authors:Jessica_Maxwell  a             schema:Person ;
#         rdfs:label              "Jessica Maxwell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/43577343/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jessica Maxwell" .
#
# authors:Robertson_Davies  a               schema:Person ;
#         rdfs:label                 "Robertson Davies" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robertson_Davies.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110344377/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robertson Davies" .
#
# authors:Robert_B_Parker  a                schema:Person ;
#         rdfs:label                 "Robert B. Parker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_B._Parker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101763416/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert B. Parker" .
#
# authors:Hans_Christian_Andersen
#         a                          schema:Person ;
#         rdfs:label                 "Hans Christian Andersen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hans_Christian_Andersen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4925902/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hans Christian Andersen" .
#
# authors:Jane_Austen  a                    schema:Person ;
#         rdfs:label                 "Jane Austen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jane_Austen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102333412/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jane Austen" .
#
# authors:Brad_Leithauser  a                schema:Person ;
#         rdfs:label                 "Brad Leithauser" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brad_Leithauser.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94522244/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brad Leithauser" .
#
# authors:Barbara_Ciletti  a             schema:Person ;
#         rdfs:label              "Barbara J. Ciletti" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/11894853/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Barbara J. Ciletti" .
#
# authors:Stephen_Dobyns  a                 schema:Person ;
#         rdfs:label                 "Stephen Dobyns" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Dobyns.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85546337/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Dobyns" .
#
# authors:Arthur_Jacobs  a                  schema:Person ;
#         rdfs:label                 "Arthur Jacobs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arthur_Jacobs.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109585390/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arthur Jacobs" .
#
# authors:John_Casey  a                     schema:Person ;
#         rdfs:label                 "John Casey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Casey_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32033282/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Casey" .
#
# authors:William_Vollmann  a               schema:Person ;
#         rdfs:label                 "William T. Vollmann" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_T._Vollmann.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/46804375/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William T. Vollmann" .
#
# authors:Anna_Thomas  a                    schema:Person ;
#         rdfs:label                 "Anna Thomas" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anna_Thomas.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79325000/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anna Thomas" .
#
# authors:Christopher_Paul  a            schema:Person ;
#         rdfs:label              "Christopher Paul" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/25219011/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Christopher Paul" .
#
# authors:Audrey_Niffenegger  a             schema:Person ;
#         rdfs:label                 "Audrey Niffenegger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Audrey_Niffenegger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85470258/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Audrey Niffenegger" .
#
# authors:TS_Eliot  a                       schema:Person ;
#         rdfs:label                 "T.S. Eliot" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/T._S._Eliot.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56609282/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "T.S. Eliot" .
#
# authors:Schuyler_Ingle  a              schema:Person ;
#         rdfs:label              "Schuyler Ingle" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/35994778/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Schuyler Ingle" .
#
# authors:Nick_Hornby  a                    schema:Person ;
#         rdfs:label                 "Nick Hornby" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nick_Hornby.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76432329/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nick Hornby" .
#
# authors:Miles_Krassen  a               schema:Person ;
#         rdfs:label              "Miles Krassen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/22309506/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Miles Krassen" .
#
# authors:Max_Allan_Collins  a              schema:Person ;
#         rdfs:label                 "Max Allan Collins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Max_Allan_Collins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41850849/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Max Allan Collins" .
#
# authors:James_Rollins  a                  schema:Person ;
#         rdfs:label                 "James Rollins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Rollins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99034801/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Rollins" .
#
# authors:Howard_Wallach  a              schema:Person ;
#         rdfs:label              "Howard R. Wallach" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/38969144/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Howard R. Wallach" .
#
# authors:John_Hanson_Mitchell
#         a                          schema:Person ;
#         rdfs:label                 "John Hanson Mitchell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Hanson_Mitchell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113703086/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Hanson Mitchell" .
#
# authors:Deepak_Chopra  a                  schema:Person ;
#         rdfs:label                 "Deepak Chopra" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Deepak_Chopra.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34491177/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Deepak Chopra" .
#
# authors:Bob_Dylan  a                      schema:Person , mo:SoloMusicArtist ;
#         rdfs:label                 "Bob Dylan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bob_Dylan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111894442/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bob Dylan" .
#
# authors:Tucker_Max  a                     schema:Person ;
#         rdfs:label                 "Tucker Max" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tucker_Max.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66225185/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tucker Max" .
#
# authors:Alicia_Bay_Laurel  a              schema:Person ;
#         rdfs:label                 "Alicia Bay Laurel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alicia_Bay_Laurel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112843633/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alicia Bay Laurel" .
#
# authors:Ralph_Steadman  a                 schema:Person ;
#         rdfs:label                 "Ralph Steadman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ralph_Steadman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103610475/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ralph Steadman" .
#
# authors:Tim_Dorsey  a                     schema:Person ;
#         rdfs:label                 "Tim Dorsey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_Dorsey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51856777/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim Dorsey" .
#
# authors:Jon_Hassler  a                    schema:Person ;
#         rdfs:label                 "Jon Hassler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jon_Hassler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7437022/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jon Hassler" .
#
# authors:Studs_Terkel  a                   schema:Person ;
#         rdfs:label                 "Studs Terkel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Studs_Terkel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36925056/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Studs Terkel" .
#
# authors:Gregory_Maguire  a                schema:Person ;
#         rdfs:label                 "Gregory Maguire" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gregory_Maguire.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/267230610/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gregory Maguire" .
#
# authors:Diane_Setterfield  a              schema:Person ;
#         rdfs:label                 "Diane Setterfield" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Diane_Setterfield.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/75019685/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Diane Setterfield" .
#
# authors:Kathryn_Stern  a               schema:Person ;
#         rdfs:label              "Kathryn Stern" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/73187902/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kathryn Stern" .
#
# authors:Sophie_Kinsella  a                schema:Person ;
#         rdfs:label                 "Sophie Kinsella" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sophie_Kinsella.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19665045/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sophie Kinsella" .
#
# authors:Gail_Anderson-Dargatz
#         a                          schema:Person ;
#         rdfs:label                 "Gail Anderson-Dargatz" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gail_Anderson-Dargatz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61710472/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gail Anderson-Dargatz" .
#
# authors:Phillip_Allen  a   schema:Person ;
#         rdfs:label  "Phillip Wayne Allen" ;
#         foaf:name   "Phillip Wayne Allen" .
#
# authors:JD_Salinger  a                    schema:Person ;
#         rdfs:label                 "J.D. Salinger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._D._Salinger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17092/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jerome David Salinger" .
#
# authors:Alan_Duff  a                      schema:Person ;
#         rdfs:label                 "Alan Duff" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alan_Duff.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113557653/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alan Duff" .
#
# authors:Beatrice_Trum_Hunter
#         a                          schema:Person ;
#         rdfs:label                 "Beatrice Trum Hunter" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Beatrice_Trum_Hunter.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/6223152/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Beatrice Trum Hunter" .
#
# authors:Edmund_Morris  a                  schema:Person ;
#         rdfs:label                 "Edmund Morris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edmund_Morris_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44289383/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edmund Morris" .
#
# authors:Chad_Hautmann  a               schema:Person ;
#         rdfs:label              "Chad Hautmann" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/9303632/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Chad Hautmann" .
#
# authors:Sara_Gruen  a                     schema:Person ;
#         rdfs:label                 "Sara Gruen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sara_Gruen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56867365/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sara Gruen" .
#
# authors:Sarah_Graves  a                   schema:Person ;
#         rdfs:label                 "Sarah Graves" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sarah_Graves.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/305276783/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sarah Graves" .
#
# authors:Max_Barry  a                      schema:Person ;
#         rdfs:label                 "Max Barry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Max_Barry.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79157507/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Max Barry" .
#
# authors:Dante_Alighieri  a                schema:Person ;
#         rdfs:label                 "Dante Alighieri" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dante_Alighieri.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97105654/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dante Alighieri" .
#
# authors:Upton_Sinclair  a                 schema:Person ;
#         rdfs:label                 "Upton Sinclair" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Upton_Sinclair.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32002923/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Upton Sinclair" .
#
# authors:Octavia_E_Butler  a               schema:Person ;
#         rdfs:label                 "Octavia E. Butler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Octavia_E._Butler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34453955/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Octavia E. Butler" .
#
# authors:Richard_Mayer  a                  schema:Person ;
#         rdfs:label                 "Richard E. Mayer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_E._Mayer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/5020937/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard E. Mayer" .
#
# authors:Wendy_Esko  a                  schema:Person ;
#         rdfs:label              "Wendy Esko" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/9992628/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Wendy Esko" .
#
# authors:Sheila_Lukins  a                  schema:Person ;
#         rdfs:label                 "Sheila Lukins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sheila_Lukins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79053153/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sheila Lukins" .
#
# authors:Jeff_Shapiro  a                schema:Person ;
#         rdfs:label              "Jeff Shapiro" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/56717951/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jeff Shapiro" .
#
# authors:Try_Foods_Intl  a  schema:Organization ;
#         rdfs:label  "Try-Foods International" ;
#         foaf:name   "Try-Foods International, Inc." .
#
# authors:F_Scott_Fitzgerald  a             schema:Person ;
#         rdfs:label                 "F. Scott Fitzgerald" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/F._Scott_Fitzgerald.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100254195/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "F. Scott Fitzgerald" .
#
# authors:M_Wylie_Blanchet  a               schema:Person ;
#         rdfs:label                 "Muriel Wylie Blanchet" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/M._Wylie_Blanchet.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76391491/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Muriel Wylie Blanchet" .
#
# authors:Lewis_Carroll  a                  schema:Person ;
#         rdfs:label                 "Lewis Carroll" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lewis_Carroll.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66462036/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lewis Carroll" .
#
# authors:Mark_Twain  a                     schema:Person ;
#         rdfs:label                 "Mark Twain" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mark_Twain.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50566653/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mark Twain" .
#
# authors:Dave_DeWitt  a                 schema:Person ;
#         rdfs:label              "Dave DeWitt" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/65287136/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Dave DeWitt" .
#
# authors:Joanne_Harris  a                  schema:Person ;
#         rdfs:label                 "Joanne Harris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joanne_Harris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51850630/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joanne Harris" .
#
# authors:Michael_Kernan  a                 schema:Person ;
#         rdfs:label                 "Michael Kernan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Kernan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42543887/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Kernan" .
#
# authors:Nicholas_Sparks  a                schema:Person ;
#         rdfs:label                 "Nicholas Sparks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nicholas_Sparks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117604749/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nicholas Sparks" .
#
# authors:Bill_Maher  a                     schema:Person ;
#         rdfs:label                 "Bill Maher" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bill_Maher.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95674622/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Maher" .
#
# authors:Terry_McMillan  a                 schema:Person ;
#         rdfs:label                 "Terry McMillan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Terry_McMillan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84546714/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Terry McMillan" .
#
# authors:Peter_Deadman  a                  schema:Person ;
#         rdfs:label                 "Peter Deadman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Deadman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79468141/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Deadman" .
#
# authors:James_M_Cain  a                   schema:Person ;
#         rdfs:label                 "James M. Cain" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_M._Cain.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/46758295/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James M. Cain" .
#
# authors:Anne_Tyler  a                     schema:Person ;
#         rdfs:label                 "Anne Tyler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anne_Tyler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39384885/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anne Tyler" .
#
# authors:David_Seals  a                    schema:Person ;
#         rdfs:label                 "David Seals" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Seals.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/1567974/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Seals" .
#
# authors:SD_Perry  a                       schema:Person ;
#         rdfs:label                 "S. D. Perry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/S._D._Perry.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100253100/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "S. D. Perry" .
#
# authors:Forrest_Carter  a                 schema:Person ;
#         rdfs:label                 "Forrest Carter" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Asa_Earl_Carter.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66464775/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Forrest Carter" .
#
# authors:David_McCullough  a               schema:Person ;
#         rdfs:label                 "David McCullough" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_McCullough.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/5000678/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David McCullough" .
#
# authors:Michio_Kushi  a                   schema:Person ;
#         rdfs:label                 "Michio Kushi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michio_Kushi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68931224/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michio Kushi" .
#
# authors:Larry_Niven  a                    schema:Person ;
#         rdfs:label                 "Larry Niven" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Larry_Niven.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36922585/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Larry Niven" .
#
# authors:Carl_Bode  a                   schema:Person ;
#         rdfs:label              "Carl Bode" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/91264195/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Carl Bode" .
#
# authors:Warren_Fahy  a                 schema:Person ;
#         rdfs:label              "Warren Fahy" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/101608882/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Warren Fahy" .
#
# authors:Charlotte_Bronte  a               schema:Person ;
#         rdfs:label                 "Charlotte Brontë" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Charlotte_Bront%C3%AB.ttl.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71388025/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charlotte Brontë" .
#
# authors:Sebastian_Junger  a               schema:Person ;
#         rdfs:label                 "Sebastian Junger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sebastian_Junger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17368316/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sebastian Junger" .
#
# authors:David_Haynes  a                   schema:Person ;
#         rdfs:label                 "David Haynes" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Haynes_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79463327/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Haynes" .
#
# authors:Swain_Wolfe  a                 schema:Person ;
#         rdfs:label              "Swain Wolfe" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/22852278/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Swain Wolfe" .
#
# authors:Bret_Easton_Ellis  a              schema:Person ;
#         rdfs:label                 "Bret Easton Ellis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bret_Easton_Ellis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49243962/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bret Easton Ellis" .
#
# authors:AA_Milne  a                       schema:Person ;
#         rdfs:label                 "A. A. Milne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/A._A._Milne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9850718/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alan Alexander Milne" .
#
# authors:Iain_Banks  a                     schema:Person ;
#         rdfs:label                 "Iain M. Banks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Iain_Banks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73864945/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Iain M. Banks" .
#
# authors:Thomas_King  a                    schema:Person ;
#         rdfs:label                 "Thomas King" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_King_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112721227/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas King" .
#
# authors:John_Green  a                     schema:Person ;
#         rdfs:label                 "John Green" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Green_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41229323/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Green" .
#
# authors:Nicholas_Mosley  a                schema:Person ;
#         rdfs:label                 "Nicholas Mosley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nicholas_Mosley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87196591/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nicholas Mosley" .
#
# authors:John_Lewis  a                     schema:Person ;
#         rdfs:label                 "John Lewis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Lewis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/164971276/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Lewis" .
#
# authors:Nelson_DeMille  a                 schema:Person ;
#         rdfs:label                 "Nelson DeMille" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nelson_DeMille.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/107015556/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nelson DeMille" .
#
# authors:Joe_Abercrombie  a                schema:Person ;
#         rdfs:label                 "Joe Abercrombie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joe_Abercrombie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85800591/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joe Abercrombie" .
#
# authors:Nikki_Goldbeck  a              schema:Person ;
#         rdfs:label              "Nikki Goldbeck" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/25849161/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Nikki Goldbeck" .
#
# authors:Stephen_Ambrose  a                schema:Person ;
#         rdfs:label                 "Stephen E. Ambrose" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_E._Ambrose.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109151847/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen E. Ambrose" .
#
# authors:Stanley_Karnow  a                 schema:Person ;
#         rdfs:label                 "Stanley Karnow" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stanley_Karnow.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/47288845/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stanley Karnow" .
#
# authors:Somerville_E  a                   schema:Person ;
#         rdfs:label                 "Somerville, E. Œ." ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edith_Somerville.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96053713/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Somerville, E. Œ." .
#
# authors:Elizabeth_Berg  a                 schema:Person ;
#         rdfs:label                 "Elizabeth Berg" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elizabeth_Berg_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85419722/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elizabeth Berg" .
#
# authors:Walt_Wheelock  a               schema:Person ;
#         rdfs:label              "Walt Wheelock" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/19531813/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Walt Wheelock" .
#
# authors:TH_White  a                       schema:Person ;
#         rdfs:label                 "T. H. White" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/T._H._White.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19685792/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "T. H. White" .
#
# authors:Jabari_Asim  a                    schema:Person ;
#         rdfs:label                 "Jabari Asim" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jabari_Asim.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/65566676/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jabari Asim" .
#
# authors:Earl_Shorris  a                   schema:Person ;
#         rdfs:label                 "Earl Shorris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Earl_Shorris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60282262/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Earl Shorris" .
#
# authors:Eckhart_Tolle  a                  schema:Person ;
#         rdfs:label                 "Eckhart Tolle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Eckhart_Tolle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87035036/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Eckhart Tolle" .
#
# authors:Black_Elk  a                      schema:Person ;
#         rdfs:label                 "Black Elk" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Black_Elk.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100267654/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Black Elk" .
#
# authors:Garth_Stein  a                    schema:Person ;
#         rdfs:label                 "Garth Stein" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Garth_Stein.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12636865/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Garth Stein" .
#
# authors:Gino_Sky  a                    schema:Person ;
#         rdfs:label              "Gino Sky" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/35746045/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Gino Sky" .
#
# authors:Edwin_Abbott  a                   schema:Person ;
#         rdfs:label                 "Edwin Abbott" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edwin_Abbott.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2505657/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edwin Abbott" .
#
# authors:Sue_Silverman  a               schema:Person ;
#         rdfs:label              "Sue William Silverman" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/68191561/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Sue William Silverman" .
#
# authors:Roddy_Doyle  a                    schema:Person ;
#         rdfs:label                 "Roddy Doyle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Roddy_Doyle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17301306/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Roddy Doyle" .
#
# authors:Garry_Trudeau  a                  schema:Person ;
#         rdfs:label                 "Garry Trudeau" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Garry_Trudeau.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37085738/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Garry Trudeau" .
#
# authors:Scott_Simon  a                    schema:Person ;
#         rdfs:label                 "Scott Simon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Scott_Simon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/8940309/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Scott Simon" .
#
# authors:Donald_Miller  a                  schema:Person ;
#         rdfs:label                 "Donald Miller" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Donald_Miller_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/38073734/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Donald Miller" .
#
# authors:Josquin_Des_Pres  a            schema:Person ;
#         rdfs:label              "Josquin Des Pres" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/23829271/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Josquin Des Pres" .
#
# authors:Charles_Bukowski  a               schema:Person ;
#         rdfs:label                 "Charles Bukowski" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Bukowski.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64002815/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Bukowski" .
#
# authors:Patricia_Haskell  a            schema:Person ;
#         rdfs:label              "Patrick Haskell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/304991391/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Patrick Haskell" .
#
# authors:Tim_Sandlin  a                    schema:Person ;
#         rdfs:label                 "Tim Sandlin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_Sandlin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/63029772/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim Sandlin" .
#
# authors:Sylvia_Plath  a                   schema:Person ;
#         rdfs:label                 "Sylvia Plath" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sylvia_Plath.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14775269/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sylvia Plath" .
#
# authors:Rolling_Stone  a                  schema:Organization ;
#         rdfs:label                 "Rolling Stone" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rolling_Stone.ttl"^^xsd:anyURI ;
#         foaf:name                  "Rolling Stone" .
#
# authors:Charlaine_Harris  a               schema:Person ;
#         rdfs:label                 "Charlaine Harris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charlaine_Harris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50289397/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charlaine Harris" .
#
# authors:Carl_Sagan  a                     schema:Person ;
#         rdfs:label                 "Carl Sagan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carl_Sagan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36997809/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Carl Sagan" .
#
# authors:James_Loewen  a                   schema:Person ;
#         rdfs:label                 "James Loewen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_W._Loewen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17349789/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Loewen" .
#
# authors:Mary_Roach  a                     schema:Person ;
#         rdfs:label                 "Mary Roach" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mary_Roach.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/10935075/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mary Roach" .
#
# authors:Ron_Paul  a                       schema:Person ;
#         rdfs:label                 "Ron Paul" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ron_Paul.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103120639/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ron Paul" .
#
# authors:Jorge_Amado  a                    schema:Person ;
#         rdfs:label                 "Jorge Amado" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jorge_Amado.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108732513/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jorge Amado" .
#
# authors:Junichiro_Tanizaki  a             schema:Person ;
#         rdfs:label                 "Jun'ichirō Tanizaki" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jun'ichir%C5%8D_Tanizaki.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95021658/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jun'ichirō Tanizaki" .
#
# authors:Barbara_Gordon_Gibson
#         a                       schema:Person ;
#         rdfs:label              "Barbara G. Gibson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/57924799/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Barbara G. Gibson" .
#
# authors:Irvin_Yalom  a                    schema:Person ;
#         rdfs:label                 "Irvin D. Yalom" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Irvin_D._Yalom.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109548796/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Irvin D. Yalom" .
#
# authors:Joe_Haldeman  a                   schema:Person ;
#         rdfs:label                 "Joe Haldeman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joe_Haldeman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59083671/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joe Haldeman" .
#
# authors:William_Golding  a                schema:Person ;
#         rdfs:label                 "William Golding" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Golding.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/89500102/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Golding" .
#
# authors:Clysta_Kinstler  a             schema:Person ;
#         rdfs:label              "Clysta Kinstler" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/38439187/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Clysta Kinstler" .
#
# authors:Michael_Crichton  a               schema:Person ;
#         rdfs:label                 "Michael Crichton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Crichton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/89578936/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Crichton" .
#
# authors:Francine_Prose  a                 schema:Person ;
#         rdfs:label                 "Francine Prose" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Francine_Prose.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112469802/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Francine Prose" .
#
# authors:WP_Kinsella  a                    schema:Person ;
#         rdfs:label                 "W. P. Kinsella" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/W._P._Kinsella.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/957296/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William P. Kinsella" .
#
# authors:Susan_Straight  a                 schema:Person ;
#         rdfs:label                 "Susan Straight" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Susan_Straight.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79369497/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Susan Straight" .
#
# authors:Dorothy_Dunnett  a                schema:Person ;
#         rdfs:label                 "Dorothy Dunnett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dorothy_Dunnett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/25413300/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dorothy Dunnett" .
#
# authors:Dave_Barry  a                     schema:Person ;
#         rdfs:label                 "Dave Barry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dave_Barry.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14929847/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dave Barry" .
#
# authors:Jennifer_Weiner  a                schema:Person ;
#         rdfs:label                 "Jennifer Weiner" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jennifer_Weiner.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24815905/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jennifer Weiner" .
#
# authors:Mikhail_Bulgakov  a               schema:Person ;
#         rdfs:label                 "Mikhail Bulgakov" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mikhail_Bulgakov.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99836700/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mikhail Bulgakov" .
#
# authors:Franz_Kafka  a                    schema:Person ;
#         rdfs:label                 "Franz Kafka" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Franz_Kafka.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56611857/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Franz Kafka" .
#
# authors:Carol_Brightman  a             schema:Person ;
#         rdfs:label              "Carol Brightman" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/64089192/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Carol Brightman" .
#
# authors:Vikram_Chandra  a                 schema:Person ;
#         rdfs:label                 "Vikram Chandra" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Vikram_Chandra_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/31973215/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Vikram Chandra" .
#
# authors:Alan_Weisman  a                   schema:Person ;
#         rdfs:label                 "Alan Weisman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alan_Weisman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79568185/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alan Weisman" .
#
# authors:Peter_Carey  a                    schema:Person ;
#         rdfs:label                 "Peter Carey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Carey_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110569724/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Carey" .
#
# authors:Patricia_Grace  a                 schema:Person ;
#         rdfs:label                 "Patricia Grace" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patricia_Grace.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111994998/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Patricia Grace" .
#
# authors:Vijay_Hassin  a                schema:Person ;
#         rdfs:label              "Vijay Hassin" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/28324484/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Vijay Hassin" .
#
# authors:Stephen_Hunt  a                   schema:Person ;
#         rdfs:label                 "Stephen Hunt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Hunt_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117601357/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Hunt" .
#
# authors:Dany_Laferriere  a                schema:Person ;
#         rdfs:label                 "Dany Laferrière" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dany_Laferri%C3%A8re.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87061403/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dany Laferrière" .
#
# authors:Ronny_Lee  a                      schema:Person ;
#         rdfs:label                 "Ronny Lee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ronny_Lee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/55669788/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ronny Lee" .
#
# authors:Katherine_Dunn  a                 schema:Person ;
#         rdfs:label                 "Katherine Dunn" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Katherine_Dunn.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/165285066/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Katherine Dunn" .
#
# authors:Molly_Gloss  a                    schema:Person ;
#         rdfs:label                 "Molly Gloss" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Molly_Gloss.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/58051379/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Molly Gloss" .
#
# authors:CS_Lewis  a                       schema:Person ;
#         rdfs:label                 "C.S. Lewis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/C._S._Lewis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22144877/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Clive Staples Lewis" .
#
# authors:Mark_Bego  a                      schema:Person ;
#         rdfs:label                 "Mark Bego" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mark_Bego.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12428230/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mark Bego" .
#
# authors:John_Updike  a                    schema:Person ;
#         rdfs:label                 "John Updike" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Updike.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/90712179/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Updike" .
#
# authors:JoAnn_Mapson  a                   schema:Person ;
#         rdfs:label                 "Jo-Ann Mapson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jo-Ann_Mapson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/74753783/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jo-Ann Mapson" .
#
# authors:Guillermo_del_Toro  a             schema:Person ;
#         rdfs:label                 "Guillermo del Toro" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Guillermo_del_Toro.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84318163/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Guillermo del Toro" .
#
# authors:William_Johnstone  a              schema:Person ;
#         rdfs:label                 "William W. Johnstone" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_W._Johnstone.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/231647883/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William W. Johnstone" .
#
# authors:Louise_Erdrich  a                 schema:Person ;
#         rdfs:label                 "Louise Erdrich" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Louise_Erdrich.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110425107/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Louise Erdrich" .
#
# authors:Scott_Smith  a                    schema:Person ;
#         rdfs:label                 "Scott Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Scott_Smith_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79110829/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Scott Smith" .
#
# authors:Michael_Baigent  a                schema:Person ;
#         rdfs:label                 "Michael Baigent" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Baigent.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44294884/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Baigent" .
#
# authors:Kevin_Desouza  a                  schema:Person ;
#         rdfs:label                 "Kevin Desouza" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kevin_Desouza.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102275130/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kevin Desouza" .
#
# authors:John_Kennedy_Toole  a             schema:Person ;
#         rdfs:label                 "John Kennedy Toole" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Kennedy_Toole.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71398405/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Kennedy Toole" .
#
# authors:Robert_J_Sawyer  a                schema:Person ;
#         rdfs:label                 "Robert J. Sawyer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_J._Sawyer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/116834060/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert J. Sawyer" .
#
# authors:Italo_Calvino  a                  schema:Person ;
#         rdfs:label                 "Italo Calvino" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Italo_Calvino.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/8520/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Italo Calvino" .
#
# authors:Miranda_July  a                   schema:Person ;
#         rdfs:label                 "Miranda July" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Miranda_July.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96584792/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Miranda July" .
#
# authors:John_W_Scott  a                schema:Person ;
#         rdfs:label              "John W. Scott" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/33145857162122920108/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "John W. Scott" .
#
# authors:Larry_Brown  a                    schema:Person ;
#         rdfs:label                 "Larry Brown" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Larry_Brown_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108691325/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Larry Brown" .
#
# authors:HA_VanderCook  a                  schema:Person ;
#         rdfs:label                 "H.A. VanderCook" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hale_A._VanderCook.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/13864041/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "H.A. VanderCook" .
#
# authors:Walt_Whitman  a                   schema:Person ;
#         rdfs:label                 "Walt Whitman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Walt_Whitman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2478331/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Walt Whitman" .
#
# authors:Pete_McCarthy  a                  schema:Person ;
#         rdfs:label                 "Pete McCarthy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Pete_McCarthy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/45215084/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Pete McCarthy" .
#
# authors:Gwen_Diehn  a                  schema:Person ;
#         rdfs:label              "Gwen Diehn" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/3930403/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Gwen Diehn" .
#
# authors:John_Shirley  a                   schema:Person ;
#         rdfs:label                 "John Shirley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Shirley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103141107/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Shirley" .
#
# authors:Robert_Dessaix  a                 schema:Person ;
#         rdfs:label                 "Robert Dessaix" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Dessaix.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7519816/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Adelle Davis" .
#
# authors:Joseph_Heller  a                  schema:Person ;
#         rdfs:label                 "Joseph Heller" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joseph_Heller.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36926967/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joseph Heller" .
#
# authors:Daniel_Mathews  a              schema:Person ;
#         rdfs:label              "Daniel Mathews" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/63091570/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Daniel Mathews" .
#
# authors:JRR_Tolkien  a                    schema:Person ;
#         rdfs:label                 "J. R. R. Tolkienn" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._R._R._Tolkien.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95218067/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J. R. R. Tolkien" .
#
# authors:Nathaniel_Hawthorne  a            schema:Person ;
#         rdfs:label                 "Nathaniel Hawthorne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nathaniel_Hawthorne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44435463/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nathaniel Hawthorne" .
#
# authors:Randy_Wayne_White  a              schema:Person ;
#         rdfs:label                 "Randy Wayne White" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Randy_Wayne_White.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102907844/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Randy Wayne White" .
#
# authors:Nicholas_Rinaldi  a               schema:Person ;
#         rdfs:label                 "Nicholas Rinaldi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nicholas_Rinaldi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52934685/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nicholas Rinaldi" .
#
# authors:Gary_Davis  a                  schema:Person ;
#         rdfs:label              "Gary Davis" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/223506770/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Gary Davis" .
#
# authors:China_Mieville  a                 schema:Person ;
#         rdfs:label                 "China Miéville" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/China_Mi%C3%A9ville.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100992516/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "China Miéville" .
#
# authors:John_Steakley  a                  schema:Person ;
#         rdfs:label                 "John Steakley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Steakley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29680155/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Steakley" .
#
# authors:Camilla_Lackberg  a               schema:Person ;
#         rdfs:label                 "Camilla Läckberg" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Camilla_L%C3%A4ckberg.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42169286/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Camilla Läckberg" .
#
# authors:Kathy_Griffin  a                  schema:Person ;
#         rdfs:label                 "Kathy Griffin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kathy_Griffin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100950362/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kathy Griffin" .
#
# authors:Markus_Heitz  a                   schema:Person ;
#         rdfs:label                 "Markus Heitz" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Markus_Heitz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59415373/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Markus Heitz" .
#
# authors:Norman_Waddell  a              schema:Person ;
#         rdfs:label              "Norman Waddell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/32121840/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Norman Waddell" .
#
# authors:David_Huber  a                    schema:Person ;
#         rdfs:label                 "David Miles Huber" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Miles_Huber.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64325693/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Miles Huber" .
#
# authors:Bruce_Chatwin  a                  schema:Person ;
#         rdfs:label                 "Bruce Chatwin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bruce_Chatwin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110567910/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bruce Chatwin" .
#
# authors:Gary_Snyder  a                    schema:Person ;
#         rdfs:label                 "Gary Snyder" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gary_Snyder.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68944804/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gary Snyder" .
#
# authors:Chris_Bohjalian  a                schema:Person ;
#         rdfs:label                 "Chris Bohjalian" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chris_Bohjalian.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/47594445/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chris Bohjalian" .
#
# authors:Rosario_Ferre  a                  schema:Person ;
#         rdfs:label                 "Rosario Ferré" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rosario_Ferr%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49265238/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rosario Ferré" .
#
# authors:Auguste_Escoffier  a              schema:Person ;
#         rdfs:label                 "Auguste Escoffier" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Auguste_Escoffier.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/62536916/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Auguste Escoffier" .
#
# authors:David_Axton  a                    schema:Person ;
#         rdfs:label                 "David Axton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dean_Koontz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110880758/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Dean Koontz" ;
#         foaf:name                  "David Axton" .
#
# authors:Aaron_Copeland  a                 schema:Person ;
#         rdfs:label                 "Aaron Copeland" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Aaron_Copeland.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51874819/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Aaron Copeland" .
#
# authors:Edgar_Allan_Poe  a                schema:Person ;
#         rdfs:label                 "Edgar Allan Poe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edgar_Allan_Poe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60351476/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edgar Allan Poe" .
#
# authors:Washington_Irving  a              schema:Person ;
#         rdfs:label                 "Washington Irving" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Washington_Irving.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/295999941/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Washington Irving" .
#
# authors:Rand_McNally  a                   schema:Organization ;
#         rdfs:label                 "Rand McNally" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rand_McNally.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/137487244/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rand McNally" .
#
# authors:Apple  a                       schema:Organization ;
#         rdfs:label              "Apple Computer, Inc" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/154701873/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Apple Computer, Inc" .
#
# authors:Betty_Smith  a                    schema:Person ;
#         rdfs:label                 "Betty Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Betty_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79125167/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Betty Smith" .
#
# authors:Jacqueline_Brooks  a           schema:Person ;
#         rdfs:label              "Jacqueline Grennon Brooks" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/91811852/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jacqueline Grennon Brooks" .
#
# authors:Miles_Davis  a                    schema:Person ;
#         rdfs:label                 "Miles Davis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Miles_Davis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97762193/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Miles Davis" .
#
# authors:AMA    a                          schema:Organization ;
#         rdfs:label                 "American Medical Association" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/American_Medical_Association.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/139178561/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "American Medical Association" .
#
# authors:Bruce_Shlain  a                schema:Person ;
#         rdfs:label              "Bruce Shlain" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/46847157/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Bruce Shlain" .
#
# authors:Warren_Murphy  a                  schema:Person ;
#         rdfs:label                 "Warren Murphy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Warren_Murphy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17227233/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Warren Murphy" .
#
# authors:Nick_Bantock  a                   schema:Person ;
#         rdfs:label                 "Nick Bantock" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nick_Bantock.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41886190/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nick Bantock" .
#
# authors:David_Mitchell  a                 schema:Person ;
#         rdfs:label                 "David Mitchell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Mitchell_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85328187/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Mitchell" .
#
# authors:Ted_Ringer  a      schema:Person ;
#         rdfs:label  "Ted Ringer" ;
#         foaf:name   "Ted Ringer" .
#
# authors:Ron_Jeremy  a                     schema:Person ;
#         rdfs:label                 "Ron Jeremy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ron_Jeremy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59277634/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ron Jeremy" .
#
# authors:Ruth_Rendell  a                   schema:Person ;
#         rdfs:label                 "Ruth Rendell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ruth_Rendell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/120719476/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ruth Rendell" .
#
# authors:Robert_Jordan  a                  schema:Person ;
#         rdfs:label                 "Robert Jordan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Jordan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79096089/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Jordan" .
#
# authors:Tatiana_de_Rosnay  a              schema:Person ;
#         rdfs:label                 "Tatiana de Rosnay" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tatiana_de_Rosnay.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71444033/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tatiana de Rosnay" .
#
# authors:Joseph_Sheban  a               schema:Person ;
#         rdfs:label              "Joseph Sheban" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/164687920/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Joseph Sheban" .
#
# authors:Pat_Frank  a                      schema:Person ;
#         rdfs:label                 "Pat Frank" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Pat_Frank.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/163817953/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Pat Frank" .
#
# authors:James_Grippando  a                schema:Person ;
#         rdfs:label                 "James Grippando" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Grippando.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/114862/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Grippando" .
#
# authors:Deborah_Harkness  a               schema:Person ;
#         rdfs:label                 "Deborah Harkness" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Deborah_Harkness.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117039140/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Deborah Harkness" .
#
# authors:Lewis_Porter  a                   schema:Person ;
#         rdfs:label                 "Lewis Porter" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lewis_Porter.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69048641/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lewis Porter" .
#
# authors:Woody_Mann  a                     schema:Person ;
#         rdfs:label                 "Woody Mann" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Woody_Mann.ttl"^^xsd:anyURI ;
#         foaf:name                  "Woody Mann" .
#
# authors:Kahlil_Gibran  a                  schema:Person ;
#         rdfs:label                 "Kahlil Gibrán" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kahlil_Gibran.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88896061/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kahlil Gibrán" .
#
# authors:Alice_Sebold  a                   schema:Person ;
#         rdfs:label                 "Alice Sebold" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alice_Sebold.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100246649/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alice Sebold" .
#
# authors:Philip_Roth  a                    schema:Person ;
#         rdfs:label                 "Philip Roth" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philip_Roth.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100235370/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philip Roth" .
#
# authors:Nic_Harcourt  a                   schema:Person ;
#         rdfs:label                 "Nic Harcourt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nic_Harcourt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/78181959/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nic Harcourt" .
#
# authors:Neal_Cassady  a                   schema:Person ;
#         rdfs:label                 "Neal Cassady" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Neal_Cassady.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9898072/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Neal Cassady" .
#
# authors:Jeff_Lindsay  a                   schema:Person ;
#         rdfs:label                 "Jeff Lindsay" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jeff_Lindsay_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/57713887/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jeff Lindsay" .
#
# authors:Jill_Ker_Conway  a                schema:Person ;
#         rdfs:label                 "Jill Ker Conway" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jill_Ker_Conway.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7374235/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jill Ker Conway" .
#
# authors:John_Lust  a                   schema:Person ;
#         rdfs:label              "John Lust" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/73929991/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "John Lust" .
#
# authors:David_Lamb  a                     schema:Person ;
#         rdfs:label                 "David Lamb" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Lamb_(journalist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108184894/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Lamb" .
#
# authors:Arturo_Perez_Reverte
#         a                          schema:Person ;
#         rdfs:label                 "Arturo Pérez-Reverte" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arturo_P%C3%A9rez-Reverte.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36965639/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arturo Pérez-Reverte" .
#
# authors:Anthony_Bourdain  a               schema:Person ;
#         rdfs:label                 "Anthony Bourdain" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anthony_Bourdain.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/74779959/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anthony Bourdain" .
#
# authors:Ernest_Hemingway  a               schema:Person ;
#         rdfs:label                 "Ernest Hemingway" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ernest_Hemingway.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97006051/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ernest Hemingway" .
#
# authors:Lisa_Bach  a                   schema:Person ;
#         rdfs:label              "Lisa Bach" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/51027140/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Lisa Bach" .
#
# authors:Stephen_Coonts  a                 schema:Person ;
#         rdfs:label                 "Stephen Coonts" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Coonts.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9870690/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Coonts" .
#
# authors:Helen_DeWitt  a                   schema:Person ;
#         rdfs:label                 "Helen DeWitt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Helen_DeWitt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79164261/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Helen DeWitt" .
#
# authors:AS_Byatt  a                       schema:Person ;
#         rdfs:label                 "A.S. Byatt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/A._S._Byatt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29521863/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Antonia Susan Byatt" .
#
# authors:Jane_S_Smith  a                schema:Person ;
#         rdfs:label              "Jane S. Smith" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/48092805/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jane S. Smith" .
#
# authors:Elie_Wiesel  a                    schema:Person ;
#         rdfs:label                 "Elie Wiesel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elie_Wiesel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108176447/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elie Wiesel" .
#
# authors:Larry_Wilmore  a                  schema:Person ;
#         rdfs:label                 "Larry Wilmore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Larry_Wilmore.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71132783/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Larry Wilmore" .
#
# authors:Bradford_Morrow  a                schema:Person ;
#         rdfs:label                 "Bradford Morrow" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bradford_Morrow.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59107135/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bradford Morrow" .
#
# authors:Rollo_May  a                      schema:Person ;
#         rdfs:label                 "Rollo May" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rollo_May.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108159288/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rollo May" .
#
# authors:Derek_Hansen  a                   schema:Person ;
#         rdfs:label                 "Derek Hansen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Derek_Hansen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/74557525/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Derek Hansen" .
#
# authors:Ray_Bradbury  a                   schema:Person ;
#         rdfs:label                 "Ray Bradbury" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ray_Bradbury.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12305881/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ray Bradbury" .
#
# authors:Meghan_McCain  a                  schema:Person ;
#         rdfs:label                 "Meghan McCain" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Meghan_McCain.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29353639/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Meghan McCain" .
#
# authors:Tim_Folger  a                     schema:Person ;
#         rdfs:label                 "Tim Folger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_Folger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/131146094150600330369/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim Folger" .
#
# authors:Laurie_Fabiano  a              schema:Person ;
#         rdfs:label              "Laurie Fabiano" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/121240322/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Laurie Fabiano" .
#
# authors:Austin_Sicard  a               schema:Person ;
#         rdfs:label              "Austin Sicard" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/279207152/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Austin Sicard" .
#
# authors:Thomas_Hardy  a                   schema:Person ;
#         rdfs:label                 "Thomas Hardy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_Hardy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54148778/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Hardy" .
#
# authors:Camille_Paglia  a                 schema:Person ;
#         rdfs:label                 "Camille Paglia" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Camille_Paglia.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27119934/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Camille Paglia" .
#
# authors:Rich_Carter  a     schema:Person ;
#         rdfs:label  "Rich Carter" ;
#         foaf:name   "Rich Carter" .
#
# authors:Mil_Millington  a                 schema:Person ;
#         rdfs:label                 "Mil Millington" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mil_Millington.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/3536494/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mil Millington" .
#
# authors:Lee_Child  a                      schema:Person ;
#         rdfs:label                 "Lee Child" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lee_Child.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100304282/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Jim Gorant" ;
#         foaf:name                  "Lee Child" .
#
# authors:Dominic_Behan  a                  schema:Person ;
#         rdfs:label                 "Dominic Behan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dominic_Behan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93872569/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dominic Behan" .
#
# authors:Doris_Kearns_Goodwin
#         a                          schema:Person ;
#         rdfs:label                 "Doris Kearns Goodwin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Doris_Kearns_Goodwin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93479825/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Doris Kearns Goodwin" .
#
# authors:Emma_Donoghue  a                  schema:Person ;
#         rdfs:label                 "Emma Donoghue" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Emma_Donoghue.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39539889/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Emma Donoghue" .
#
# authors:Margaret_Wittenberg  a         schema:Person ;
#         rdfs:label              "Margaret M. Wittenberg" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/26144321/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Margaret M. Wittenberg" .
#
# authors:Jaroslav_Pelikan  a               schema:Person ;
#         rdfs:label                 "Jaroslav Pelikan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jaroslav_Pelikan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66486209/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jaroslav Pelikan" .
#
# authors:John_Wyndham  a                   schema:Person ;
#         rdfs:label                 "John Wyndham" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Wyndham.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/21514326/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Wyndham" .
#
# authors:Ginny_Callan  a                schema:Person ;
#         rdfs:label              "Ginny Callan" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/65447239/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ginny Callan" .
#
# authors:Meg_Cabot  a                      schema:Person ;
#         rdfs:label                 "Meg Cabot" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Meg_Cabot.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61728296/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Meg Cabot" .
#
# authors:Elise_Juska  a                    schema:Person ;
#         rdfs:label                 "Elise Juska" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elise_Juska.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/23974635/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elise Juska" .
#
# authors:Roger_Zelazny  a                  schema:Person ;
#         rdfs:label                 "Roger Zelazny" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Roger_Zelazny.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49233219/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Roger Zelazny" .
#
# authors:W_Somerset_Maugham  a             schema:Person ;
#         rdfs:label                 "W. Somerset Maugham" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/W._Somerset_Maugham.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66470937/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "W. Somerset Maugham" .
#
# authors:Peter_Davies  a                schema:Person ;
#         rdfs:label              "Peter Davies" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/163261267/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Peter Davies" .
#
# authors:Andrea_Barrett  a                 schema:Person ;
#         rdfs:label                 "Andrea Barrett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Andrea_Barrett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79163089/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Andrea Barrett" .
#
# authors:Caleb_Carr  a                     schema:Person ;
#         rdfs:label                 "Caleb Carr" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Caleb_Carr.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113613186/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Caleb Carr" .
#
# authors:William_Glasser  a                schema:Person ;
#         rdfs:label                 "William Glasser" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Glasser.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2558195/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Glasser" .
#
# authors:Walter_Wager  a                schema:Person ;
#         rdfs:label              "Walter W. Wager" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/91880329/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Walter W. Wager" .
#
# authors:Justin_Cronin  a                  schema:Person ;
#         rdfs:label                 "Justin Cronin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Justin_Cronin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/305869306/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Justin Cronin" .
#
# authors:Clive_Barker  a                   schema:Person ;
#         rdfs:label                 "Clive Barker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Clive_Barker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111746890/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Clive Barker" .
#
# authors:Kenneth_Patchen  a                schema:Person ;
#         rdfs:label                 "Kenneth Patchen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kenneth_Patchen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9851596/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kenneth Patchen" .
#
# authors:Rudolfo_Anaya  a                  schema:Person ;
#         rdfs:label                 "Rudolfo Anaya" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rudolfo_Anaya.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110322020/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rudolfo Anaya" .
#
# authors:Alice_Walker  a                   schema:Person ;
#         rdfs:label                 "Alice Walker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alice_Walker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108495772/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alice Walker" .
#
# authors:Maeve_Binchy  a                   schema:Person ;
#         rdfs:label                 "Maeve Binchy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Maeve_Binchy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113069974/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Maeve Binchy" .
#
# authors:Brian_Moore  a                    schema:Person ;
#         rdfs:label                 "Brian Moore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brian_Moore_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36913224/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brian Moore" .
#
# authors:Sapphire  a                       schema:Person ;
#         rdfs:label                 "Sapphire" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sapphire_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7505505/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sapphire" .
#
# authors:Matthew_Reilly  a                 schema:Person ;
#         rdfs:label                 "Matthew Reilly" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Matthew_Reilly.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84058407/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Matthew Reilly" .
#
# authors:John_Clellon_Holmes  a            schema:Person ;
#         rdfs:label                 "John Clellon Holmes" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Clellon_Holmes.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112962936/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Clellon Holmes" .
#
# authors:David_Hoffmann  a              schema:Person ;
#         rdfs:label              "David Hoffmann" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/85687253/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "David Hoffmann" .
#
# authors:Misc   a           foaf:Agent ;
#         rdfs:label  "Miscellaneous" .
#
# authors:Bill_Bryson  a                    schema:Person ;
#         rdfs:label                 "Bill Bryson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bill_Bryson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59134159/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Bryson" .
#
# authors:David_Brin  a                     schema:Person ;
#         rdfs:label                 "David Brin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Brin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85314364/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Brin" .
#
# authors:Eric_Goodman  a                schema:Person ;
#         rdfs:label              "Eric Goodman" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/6202519/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Eric Goodman" .
#
# authors:T_Coraghessan_Boyle  a            schema:Person ;
#         rdfs:label                 "T Coraghessan Boyle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/T._C._Boyle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14796817/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "T Coraghessan Boyle" .
#
# authors:Steve_Martin  a                   schema:Person ;
#         rdfs:label                 "Steven Martin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steve_Martin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117464226/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Martin" .
#
# authors:Stephen_Hunter  a                 schema:Person ;
#         rdfs:label                 "Stephen Hunter" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Hunter.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41963736/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Hunter" .
#
# authors:Muriel_Barbery  a                 schema:Person ;
#         rdfs:label                 "Muriel Barbery" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Muriel_Barbery.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64172549/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Muriel Barbery" .
#
# authors:Michael_Moore  a                  schema:Person ;
#         rdfs:label                 "Michael Moore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Moore.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/115241226/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Moore" .
#
# authors:Dale_Carnegie  a                  schema:Person ;
#         rdfs:label                 "Dale Carnegie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dale_Carnegie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73851001/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dale Carnegie" .
#
# authors:Kim_Edwards  a                    schema:Person ;
#         rdfs:label                 "Kim Edwards" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kim_Edwards.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/57781322/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kim Edwards" .
#
# authors:Hank_Harrison  a               schema:Person ;
#         rdfs:label              "Hank Harrison" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/75039002/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Hank Harrison" .
#
# authors:Robert_Linssen  a                 schema:Person ;
#         rdfs:label                 "Robert Linssen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Linssen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/13998/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Linssen" .
#
# authors:James_McMillan  a              schema:Person ;
#         rdfs:label              "James H. McMillan" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/32329603/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "James H. McMillan" .
#
# authors:Helen_Campbell  a                 schema:Person ;
#         rdfs:label                 "Helen Campbell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Helen_Stuart_Campbell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/276916058/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Helen Campbell" .
#
# authors:Betty_Wason  a                    schema:Person ;
#         rdfs:label                 "Betty Wason" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Betty_Wason.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/72409901/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Betty Wason" .
#
# authors:Paulo_Coelho  a                   schema:Person ;
#         rdfs:label                 "Paulo Coelho" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paulo_Coelho.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52700/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paulo Coelho" .
#
# authors:Chuck_Klosterman  a               schema:Person ;
#         rdfs:label                 "Chuck Klosterman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chuck_Klosterman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/287806/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chuck Klosterman" .
#
# authors:Kazuko_Masui  a                schema:Person ;
#         rdfs:label              "Kazuko Masui" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/98494120/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kazuko Masui" .
#
# authors:Sylvan_Barnet  a                  schema:Person ;
#         rdfs:label                 "Sylvan Barnet" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sylvan_Barnet.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109902730/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sylvan Barnet" .
#
# authors:Gunter_Grass  a                   schema:Person ;
#         rdfs:label                 "Günter Grass" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/G%C3%BCnter_Grass.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102319859/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Günter Grass" .
#
# authors:Kate_Atkinson  a                  schema:Person ;
#         rdfs:label                 "Kate Atkinson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kate_Atkinson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59219639/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kate Atkinson" .
#
# authors:Shel_Silverstein  a               schema:Person ;
#         rdfs:label                 "Shel Silverstein" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Shel_Silverstein.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19880380/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Shel Silverstein" .
#
# authors:Jim_Harrison  a                   schema:Person ;
#         rdfs:label                 "Jim Harrison" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jim_Harrison.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73854596/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jim Harrison" .
#
# authors:Nel_King  a                    schema:Person ;
#         rdfs:label              "Nel King" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/67761281/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Nel King" .
#
# authors:Virginia_Woolf  a                 schema:Person ;
#         rdfs:label                 "Virginia Woolf" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Virginia_Woolf.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39385478/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Virginia Woolf" .
#
# authors:Ralph_Helfer  a                   schema:Person ;
#         rdfs:label                 "Ralph Helfer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ralph_Helfer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84642020/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ralph Helfer" .
#
# authors:Adam_Carolla  a                   schema:Person ;
#         rdfs:label                 "Adam Carolla" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Adam_Carolla.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/43611431/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Adam Carolla" .
#
# authors:Orson_Scott_Card  a               schema:Person ;
#         rdfs:label                 "Orson Scott Card" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Orson_Scott_Card.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/116838661/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Orson Scott Card" .
#
# authors:Glen_Cook  a                      schema:Person ;
#         rdfs:label                 "Glen Cook" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Glen_Cook.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64149024/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Glen Cook" .
#
# authors:Christopher_Parkening
#         a                          schema:Person ;
#         rdfs:label                 "Christopher Parkening" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Christopher_Parkening.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69120212/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Christopher Parkening" .
#
# authors:Stephenie_Meyer  a                schema:Person ;
#         rdfs:label                 "Stephanie Meyer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephenie_Meyer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102313919/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephanie Meyer" .
#
# authors:Janet_Evanovich  a                schema:Person ;
#         rdfs:label                 "Janet Evanovich" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Janet_Evanovich.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54180657/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Janet Evanovich" .
#
# authors:Lucy_Lidell  a                 schema:Person ;
#         rdfs:label              "Lucy Lidell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/15382531/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Lucy Lidell" .
#
# authors:Dennis_Lehane  a                  schema:Person ;
#         rdfs:label                 "Dennis Lehane" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dennis_Leary.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/10004693/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dennis Lehane" .
#
# authors:Mario_Puzo  a                     schema:Person ;
#         rdfs:label                 "Mario Puzo" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mario_Puzo.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/131948/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mario Puzo" .
#
# authors:James_Ellroy  a                   schema:Person ;
#         rdfs:label                 "James Ellroy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Ellroy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27090921/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Ellroy" .
#
# authors:Terence_McKenna  a                schema:Person ;
#         rdfs:label                 "Terence McKenna" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Terence_McKenna.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99983343/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Terence McKenna" .
#
# authors:Frederick_Forsyth  a              schema:Person ;
#         rdfs:label                 "Frederick Forsyth" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frederick_Forsyth.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108216096/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frederick Forsyth" .
#
# authors:Madeleine_Lengle  a               schema:Person ;
#         rdfs:label                 "Madeleine L'Engle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Madeleine_L'Engle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76391491/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Madeleine L'Engle" .
#
# authors:William_Styron  a                 schema:Person ;
#         rdfs:label                 "William Styron" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Styron.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71398096/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Styron" .
#
# authors:ATT    a           schema:Organization ;
#         rdfs:label  "AT&T" ;
#         foaf:name   "AT&T" .
#
# authors:James_Beard  a                    schema:Person ;
#         rdfs:label                 "James Beard" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Beard.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/115944621/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Beard" .
#
# authors:Wendy_Holden  a                   schema:Person ;
#         rdfs:label                 "Wendy Holden" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Wendy_Holden_(born_1965).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/163020838/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Wendy Holden" .
#
# authors:Carlton_Mellick  a                schema:Person ;
#         rdfs:label                 "Carlton Mellick III" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carlton_Mellick_III.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95149196606674792715/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Carlton Mellick III" .
#
# authors:Mary_Ann_Shaffer  a               schema:Person ;
#         rdfs:label                 "Mary Ann Shaffer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mary_Ann_Shaffer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79570919/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mary Ann Shaffer" .
#
# authors:Cracked  a                        schema:Organization ;
#         rdfs:label                 "Cracked.com" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Cracked.com.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/129245915/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Cracked.com" .
#
# authors:Donna_Andrews  a                  schema:Person ;
#         rdfs:label                 "Donna Andrews" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Donna_Andrews_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/118190995/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Donna Andrews" .
#
# authors:Carl_Forest  a                 schema:Person ;
#         rdfs:label              "Carl Forest" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/28784110/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Carl Forest" .
#
# authors:Jhumpa_Lahiri  a                  schema:Person ;
#         rdfs:label                 "Jhumpa Lahiri" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jhumpa_Lahiri.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100885199/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jhumpa Lahiri" .
#
# authors:Justin_Halpern  a                 schema:Person ;
#         rdfs:label                 "Justin Halpern" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Justin_Halpern.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/121236148/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Justin Halpern" .
#
# authors:Frank_Abagnale  a                 schema:Person ;
#         rdfs:label                 "Frank Abagnale" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Frank_Abagnale.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117984333/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frank Abagnale" .
#
# authors:Old_New_England  a  schema:Organization ;
#         rdfs:label  "Old New England" ;
#         foaf:name   "Old New England" .
#
# authors:Graeme_Base  a                    schema:Person ;
#         rdfs:label                 "Graeme Base" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Graeme_Base.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64188423/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Graeme Base" .
#
# authors:Aldo_Leopold  a                   schema:Person ;
#         rdfs:label                 "Aldo Leopold" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Aldo_Leopold.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69033111/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Aldo Leopold" .
#
# authors:Ron_Hansen  a                     schema:Person ;
#         rdfs:label                 "Ron Hansen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ron_Hansen_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/75895/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ron Hansen" .
#
# authors:Lois_Mai_Chan  a                  schema:Person ;
#         rdfs:label                 "Lois Mai Chan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lois_Mai_Chan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2488640/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lois Mai Chan" .
#
# authors:Clive_Cussler  a                  schema:Person ;
#         rdfs:label                 "Clive Cussler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Clive_Cussler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56608054/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Clive Cussler" .
#
# authors:AJ_Verdelle  a                    schema:Person ;
#         rdfs:label                 "A.J. Verdelle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/A._J._Verdelle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92332396/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "A.J. Verdelle" .
#
# authors:Tim_OBrien  a                     schema:Person ;
#         rdfs:label                 "Tim O'Brien" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_O'Brien_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85364833/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim O'Brien" .
#
# authors:Mickey_Hart  a                    schema:Person ;
#         rdfs:label                 "Mickey Hart" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mickey_Hart.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54947891/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mickey Hart" .
#
# authors:Michael_Palin  a                  schema:Person ;
#         rdfs:label                 "Michael Palin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Palin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44394038/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Palin" .
#
# authors:Wayne_Johnston  a              schema:Person ;
#         rdfs:label              "Wayne Johnston" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/120612960/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Wayne Johnston" .
#
# authors:Thich_Nhat_Hanh  a                schema:Person ;
#         rdfs:label                 "Thích. Nhất Hạnh" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Th%C3%ADch_Nh%E1%BA%A5t_H%E1%BA%A1nh.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87670142/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thích. Nhất Hạnh" .
#
# authors:Brian_Greene  a                   schema:Person ;
#         rdfs:label                 "Brian Greene" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brian_Greene.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97865728/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brian Greene" .
#
# authors:Judy_Fong_Bates  a                schema:Person ;
#         rdfs:label                 "Judy Fong Bates" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Judy_Fong_Bates.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42136645/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Judy Fong Bates" .
#
# authors:Dan_OBrien  a                     schema:Person ;
#         rdfs:label                 "Dan O'Brien" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_O'Brien_(playwright).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111809185/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan O'Brien" .
#
# authors:Douglas_Bauer  a               schema:Person ;
#         rdfs:label              "Douglas Bauer" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/38187142/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Douglas Bauer" .
#
# authors:Shirley_Jackson  a                schema:Person ;
#         rdfs:label                 "Shirley Jackson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Shirley_Jackson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91864979/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Shirley Jackson" .
#
# authors:Crab_Searl  a                  schema:Person ;
#         rdfs:label              "Crab Searl" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/104023755/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Crab Searl" .
#
# authors:Jostein_Gaarder  a                schema:Person ;
#         rdfs:label                 "Jostein Gaarder" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jostein_Gaarder.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54345762/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jostein Gaarder" .
#
# authors:Joel_Robuchon  a                  schema:Person ;
#         rdfs:label                 "Joël Robuchon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jo%C3%ABl_Robuchon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/106996736/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joël Robuchon" .
#
# authors:Evan_S_Connell  a                 schema:Person ;
#         rdfs:label                 "Evan S. Connell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Evan_S._Connell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97745717/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Evan S. Connell" .
#
# authors:Jen_Sincero  a                    schema:Person ;
#         rdfs:label                 "Jen Sincero" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jen_Sincero.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34130398/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jen Sincero" .
#
# authors:Judah_Friedlander  a              schema:Person ;
#         rdfs:label                 "Judah Friedlander" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Judah_Friedlander.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19149105995668490125/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Judah Friedlander" .
#
# authors:Peter_Matthiessen  a              schema:Person ;
#         rdfs:label                 "Peter Matthiessen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Matthiessen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14773612/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Matthiessen" .
#
# authors:Charles_Dickens  a                schema:Person ;
#         rdfs:label                 "Charles Dickens" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Dickens.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88666393/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Dickens" .
#
# authors:Stuart_Woods  a                   schema:Person ;
#         rdfs:label                 "Stuart Woods" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stuart_Woods.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108957653/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stuart Woods" .
#
# authors:Willis_Harman  a                  schema:Person ;
#         rdfs:label                 "Willis Harman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Willis_Harman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/5490335/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Willis Harman" .
#
# authors:Jim_Butcher  a                    schema:Person ;
#         rdfs:label                 "Jim Butcher" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jim_Carroll.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32309016/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jim Butcher" .
#
# authors:Margaret_Mitchell  a              schema:Person ;
#         rdfs:label                 "Margaret Mitchell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Margaret_Mitchell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27068921/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Margaret Mitchell" .
#
# authors:Barack_Obama  a                   schema:Person ;
#         rdfs:label                 "Barack Obama" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barack_Obama.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52010985/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barack Obama" .
#
# authors:Bill_Clinton  a                   schema:Person ;
#         rdfs:label                 "Bill Clinton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bill_Clinton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102338519/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Clinton" .
#
# authors:Kit_Knight  a                  schema:Person ;
#         rdfs:label              "Kit Knight" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/56631609/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kit Knight" .
#
# authors:Michael_Connelly  a               schema:Person ;
#         rdfs:label                 "Michael Connelly" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Connelly.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19745715/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Connelly" .
#
# authors:Jiawei_Han  a                     schema:Person ;
#         rdfs:label                 "Jiawei Han" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jiawei_Han.ttl"^^xsd:anyURI ;
#         foaf:name                  "Jiawei Han" .
#
# authors:Laura_Pedersen  a                 schema:Person ;
#         rdfs:label                 "Laura Pedersen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Laura_Pedersen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60711476/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Laura Pedersen" .
#
# authors:Barney_Hoskyns  a                 schema:Person ;
#         rdfs:label                 "Barney Hoskyns" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barney_Hoskyns.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/30179821/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barney Hoskyns" .
#
# authors:Alfalfas  a        schema:Organization ;
#         rdfs:label  "Alfalfa's" ;
#         foaf:name   "Alfalfa's" .
#
# authors:Kiana_Davenport  a                schema:Person ;
#         rdfs:label                 "Kiana Davenport" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kiana_Davenport.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42774413/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kiana Davenport" .
#
# authors:Jean_Smith  a                     schema:Person ;
#         rdfs:label                 "Jean Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jean_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102135050/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jean Smith" .
#
# authors:Angelo_Pellegrini  a              schema:Person ;
#         rdfs:label                 "Angelo Pellegrini" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Angelo_Pellegrini.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/70309309/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Angelo M. Pellegrini" .
#
# authors:Roald_Dahl  a                     schema:Person ;
#         rdfs:label                 "Roald Dahl" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Roald_Dahl.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108159131/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Roald Dahl" .
#
# authors:Marita_Conlon-McKenna
#         a                          schema:Person ;
#         rdfs:label                 "Marita Conlon-McKenna" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Marita_Conlon-McKenna.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22201303/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Marita Conlon-McKenna" .
#
# authors:Michael_Scott  a                  schema:Person ;
#         rdfs:label                 "Michael Scott" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Scott_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59255871/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Scott" .
#
# authors:Karen_Cox  a                   schema:Person ;
#         rdfs:label              "Karen C. Knox" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/160433829/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Karen C. Knox" .
#
# authors:Louisa_Rhine  a                   schema:Person ;
#         rdfs:label                 "Louisa E. Rhine" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Louisa_E._Rhine.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79316726/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Louisa E. Rhine" .
#
# authors:Craig_Johnson  a                  schema:Person ;
#         rdfs:label                 "Craig Johnson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Craig_Johnson_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88112170/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Craig Johnson" .
#
# authors:Tom_Watts  a                   schema:Person ;
#         rdfs:label              "Tom Watts" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/286599915/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Tom Watts" .
#
# authors:Michael_Talbot  a                 schema:Person ;
#         rdfs:label                 "Michael Talbot" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Talbot_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94728970/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Talbot" .
#
# authors:David_Gibbons  a               schema:Person ;
#         rdfs:label              "David Gibbons" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/58406631/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "David Gibbons" .
#
# authors:Chuck_Palahniuk  a                schema:Person ;
#         rdfs:label                 "Chuck Palahniuk" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chuck_Palahniuk.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85311088/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chuck Palahniuk" .
#
# authors:Frank_MacEowen  a              schema:Person ;
#         rdfs:label              "Frank MacEowen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/276513979/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Frank MacEowen" .
#
# authors:James_Frey  a                     schema:Person ;
#         rdfs:label                 "James Frey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Frey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85723317/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Frey" .
#
# authors:Jimella_Lucas  a               schema:Person ;
#         rdfs:label              "Jimella Lucas" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/30898730/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jimella Lucas" .
#
# authors:Leonardo_Maugeri  a               schema:Person ;
#         rdfs:label                 "Leonardo Maugeri" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Leonardo_Maugeri.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84412375/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Leonardo Maugeri" .
#
# authors:Scott_Lynch  a                    schema:Person ;
#         rdfs:label                 "Scott Lynch" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Scott_Lynch.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12618693/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Scott Lynch" .
#
# authors:Marianne_Fredriksson
#         a                          schema:Person ;
#         rdfs:label                 "Marianne Fredriksson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Marianne_Fredriksson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22207649/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Marianne Fredriksson" .
#
# authors:Steven_Erikson  a                 schema:Person ;
#         rdfs:label                 "Steven Erikson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Erikson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85327681/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Erikson" .
#
# authors:Terry_Farish  a                schema:Person ;
#         rdfs:label              "Terry Farish" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/92807646/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Terry Farish" .
#
# authors:Robert_Boswell  a                 schema:Person ;
#         rdfs:label                 "Robert Boswell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Boswell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49928619/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Boswell" .
#
# authors:Allan_Hunt_Badiner  a          schema:Person ;
#         rdfs:label              "Allan Hunt Badiner" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/11461986/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Allan Hunt Badiner" .
#
# authors:Sarah_Palin  a                    schema:Person ;
#         rdfs:label                 "Sarah Palin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sarah_Palin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7159878/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sarah Palin" .
#
# authors:Charlie_Huston  a                 schema:Person ;
#         rdfs:label                 "Charlie Huston" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charlie_Huston.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37228976/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charlie Huston" .
#
# authors:Jean_Vaysse  a                 schema:Person ;
#         rdfs:label              "Jean Vaysse" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/27187991/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jean Vaysse" .
#
# authors:Americas_Test_Kitchen
#         a                       schema:Person ;
#         rdfs:label              "America's Test Kitchen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/127070991/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "America's Test Kitchen" .
#
# authors:Oscar_Wilde  a                    schema:Person ;
#         rdfs:label                 "Oscar Wilde" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Oscar_Wilde.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34464414/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Oscar Wilde" .
#
# authors:Peter_Powers  a                schema:Person ;
#         rdfs:label              "Peter Powers" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/43459539/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Peter Powers" .
#
# authors:Gary_Meisner  a                schema:Person ;
#         rdfs:label              "Gary Meisner" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/55638838/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Gary Meisner" .
#
# authors:Terry_Pratchett  a                schema:Person ;
#         rdfs:label                 "Terry Pratchett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Terry_Pratchett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76382712/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Terry Pratchett" .
#
# authors:Douglas_Preston  a                schema:Person ;
#         rdfs:label                 "Douglas Preston" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Douglas_Preston.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/57543887/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Douglas Preston" .
#
# authors:Patrick_McManus  a                schema:Person ;
#         rdfs:label                 "Patrick McManus" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patrick_F._McManus.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52934600/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Patrick McManus" .
#
# authors:Harold_McGee  a                   schema:Person ;
#         rdfs:label                 "Harold McGee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Harold_McGee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71503302/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Harold McGee" .
#
# authors:Stephen_Hawking  a                schema:Person ;
#         rdfs:label                 "Stephen Hawking" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Hawking.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102304634/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Hawking" .
#
# authors:Lester_Bangs  a                   schema:Person ;
#         rdfs:label                 "Lester Bangs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lester_Bangs.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56722876/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lester Bangs" .
#
# authors:Arthur_C_Clarke  a                schema:Person ;
#         rdfs:label                 "Arthur C. Clarke" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arthur_C._Clarke.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27062571/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arthur C. Clarke" .
#
# authors:JA_Konrath  a                     schema:Person ;
#         rdfs:label                 "J. A. Konrath" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._A._Konrath.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/118678965/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Jack Kilborn" ;
#         foaf:name                  "J. A. Konrath" .
#
# authors:William_Bay  a                 schema:Person ;
#         rdfs:label              "William Bay" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/276823416/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "William Bay" .
#
# authors:OU_Levon  a                    schema:Person ;
#         rdfs:label              "O.U. Levon" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/93061705/rdf.xml"^^xsd:anyURI ;
#         owl:sameAs              :Ken_Kesey ;
#         foaf:name               "O.U. Levon" .
#
# authors:John_Watkinson  a              schema:Person ;
#         rdfs:label              "John Watkinson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/85371273/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "John Watkinson" .
#
# authors:Gloria_Naylor  a                  schema:Person ;
#         rdfs:label                 "Gloria Naylor" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gloria_Naylor.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59679442/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gloria Naylor" .
#
# authors:Steven_Rinella  a                 schema:Person ;
#         rdfs:label                 "Steven Rinella" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Rinella.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/38791038/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Rinella" .
#
# authors:Erich_Maria_Remarque
#         a                          schema:Person ;
#         rdfs:label                 "Erich Maria Remarque" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Erich_Maria_Remarque.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61551298/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Erich Maria Remarque" .
#
# authors:HG_Wells  a                       schema:Person ;
#         rdfs:label                 "H. G. Wells" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/H._G._Wells.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97006424/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "H. G. Wells" .
#
# authors:Barry_Galbraith  a                schema:Person ;
#         rdfs:label                 "Barry Galbraith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barry_Galbraith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64191738/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barry Galbraith" .
#
# authors:Cherie_Priest  a                  schema:Person ;
#         rdfs:label                 "Cherie Priest" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Cherie_Priest.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/65874776/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Cherie Priest" .
#
# authors:Saul_Bellow  a                    schema:Person ;
#         rdfs:label                 "Saul Bellow" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Saul_Bellow.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27060791/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Saul Bellow" .
#
# authors:Malcolm_X  a                      schema:Person ;
#         rdfs:label                 "Malcolm X" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Malcolm_X.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59092897/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Malcolm X" .
#
# authors:Wing_Tsit_Chan  a                 schema:Person ;
#         rdfs:label                 "Wing-Tsit Chan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Wing-tsit_Chan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109203044/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Wing-Tsit Chan" .
#
# authors:Lincoln_Child  a                  schema:Person ;
#         rdfs:label                 "Lincoln Child" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lincoln_Child.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76450949/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lincoln Child" .
#
# authors:Elliot_Perlman  a                 schema:Person ;
#         rdfs:label                 "Elliot Perlman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elliot_Perlman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42091070/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elliot Perlman" .
#
# authors:Paulette_Jiles  a                 schema:Person ;
#         rdfs:label                 "Paulette Jiles" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paulette_Jiles.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85467608/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paulette Jiles" .
#
# authors:Sarah_Bird  a                     schema:Person ;
#         rdfs:label                 "Sarah Bird" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sarah_Bird.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/166628963/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sarah Bird" .
#
# authors:Patricia_Henley  a             schema:Person ;
#         rdfs:label              "Patricia Henley" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/84511566/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Patricia Henley" .
#
# authors:Robert_Kiyosaki  a                schema:Person ;
#         rdfs:label                 "Robert Kiyosaki" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Kiyosaki.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/117195725/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Kiyosaki" .
#
# authors:Samuel_Beckett  a                 schema:Person ;
#         rdfs:label                 "Samuel Beckett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Samuel_Beckett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7386737/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Samuel Beckett" .
#
# authors:Victor_Sodsook  a              schema:Person ;
#         rdfs:label              "Victor Sodsook" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/6630699/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Victor Sodsook" .
#
# authors:Jack_London  a                    schema:Person ;
#         rdfs:label                 "Jack London" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jack_London.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/46764200/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jack London" .
#
# authors:Paul_Bosland  a                schema:Person ;
#         rdfs:label              "Paul W. Bosland" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/39550217/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Paul W. Bosland" .
#
# authors:Steven_Nightingale  a             schema:Person ;
#         rdfs:label                 "Steven Nightingale" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Nightingale.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/18934844/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Nightingale" .
#
# authors:Brandon_Sanderson  a              schema:Person ;
#         rdfs:label                 "Brandon Sanderson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brandon_Sanderson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50418535/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brandon Sanderson" .
#
# authors:Alexandre_Dumas  a                schema:Person ;
#         rdfs:label                 "Alexander McCall Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alexandre_Dumas.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51688902/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alexander McCall Smith" .
#
# authors:Walter_Miller  a                  schema:Person ;
#         rdfs:label                 "Walter Miller" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Walter_M._Miller_Jr..ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/105150576/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Walter Miller" .
#
# authors:Wally_Lamb  a                     schema:Person ;
#         rdfs:label                 "Wally Lamb" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Wally_Lamb.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/47628675/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Wally Lamb" .
#
# authors:Martin_Lee  a                     schema:Person ;
#         rdfs:label                 "Martin A. Lee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Martin_A._Lee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69016526/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Martin A. Lee" .
#
# authors:Lawrence_Lee  a                schema:Person ;
#         rdfs:label              "Lawrence Lee" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/111665261/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Lawrence Lee" .
#
# authors:Twelve_Time_Sys  a  schema:Organization ;
#         rdfs:label  "Twelve Time Systems" ;
#         foaf:name   "Twelve Time Systems" .
#
# authors:Hunter_S_Thompson  a              schema:Person ;
#         rdfs:label                 "Hunter S. Thompson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hunter_S._Thompson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109030443/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hunter S. Thompson" .
#
# authors:Barbara_Kingsolver  a             schema:Person ;
#         rdfs:label                 "Barbara Kingsolver" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barbara_Kingsolver.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79097759/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barbara Kingsolver" .
#
# authors:Peter_Adamson  a               schema:Person ;
#         rdfs:label              "Peter Adamson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/70144814341439043147/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Peter Adamson" .
#
# authors:Scott_Meyer  a     schema:Person ;
#         rdfs:label  "Scott Meyer" ;
#         foaf:name   "Scott Meyer" .
#
# authors:Kazuo_Ishiguro  a                 schema:Person ;
#         rdfs:label                 "Kazuo Ishiguro" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kazuo_Ishiguro.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108702574/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kazuo Ishiguro" .
#
# authors:Harry_Olson  a                    schema:Person ;
#         rdfs:label                 "Harry F. Olson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Harry_F._Olson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/5183972/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Harry F. Olson" .
#
# authors:Richard_Monaco  a              schema:Person ;
#         rdfs:label              "Richard Monaco" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/79266694/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Richard Monaco" .
#
# authors:Jean_Zallinger  a  schema:Person ;
#         rdfs:label  "Jean Zallinger" ;
#         foaf:name   "Jean Zallinger" .
#
# authors:Anne_Frank  a                     schema:Person ;
#         rdfs:label                 "Anne Frank" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anne_Frank.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27064673/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anne Frank" .
#
# authors:Robert_Kay  a                  schema:Person ;
#         rdfs:label              "Robert Kay" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/28683531/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Robert F. Kay" .
#
# authors:Cerridwen_Fallingstar
#         a                          schema:Person ;
#         rdfs:label                 "Cerridwen Fallingstar" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Cerridwen_Fallingstar.ttl"^^xsd:anyURI ;
#         foaf:name                  "Cerridwen Fallingstar" .
#
# authors:Randy_Pausch  a                   schema:Person ;
#         rdfs:label                 "Randy Pausch" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Randy_Pausch.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/67678397/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Randy Pausch" .
#
# authors:Batdorf_Bronson  a  schema:Organization ;
#         rdfs:label  "Batdorf Bronson" ;
#         foaf:name   "Batdorf Bronson" .
#
# authors:Don_DAmmassa  a                   schema:Person ;
#         rdfs:label                 "Don D'Ammassa" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Don_D'Ammassa.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7685710/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Don D'Ammassa" .
#
# authors:Jules_Verne  a                    schema:Person ;
#         rdfs:label                 "Jules Verne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jules_Verne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76323989/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jules Verne" .
#
# authors:Raymond_Chandler  a               schema:Person ;
#         rdfs:label                 "Raymond Chandler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Raymond_Chandler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39374901/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Raymond Chandler" .
#
# authors:Sunetra_Gupta  a                  schema:Person ;
#         rdfs:label                 "Sunetra Gupta" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sunetra_Gupta.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79157077/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sunetra Gupta" .
#
# authors:Mary_Donovan  a                schema:Person ;
#         rdfs:label              "Mary Deirdre Donovan" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/262492554/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Mary Deirdre Donovan" .
#
# authors:Lillian_B_Rubin  a             schema:Person ;
#         rdfs:label              "Lillian Breslow Rubin" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/41860973/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Lillian Breslow Rubin" .
#
# authors:Wilkie_Collins  a                 schema:Person ;
#         rdfs:label                 "Wilkie Collins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Wilkie_Collins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95173526/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Wilkie Collins" .
#
# authors:David_Arnason  a                  schema:Person ;
#         rdfs:label                 "David Arnason" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Arnason.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/115570529/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Arnason" .
#
# authors:John_Grogan  a                    schema:Person ;
#         rdfs:label                 "John Grogan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Grogan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12620571/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Grogan" .
#
# authors:Denis_Leary  a                    schema:Person ;
#         rdfs:label                 "Denis Leary" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Denis_Leary.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69129474/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Denis Leary" .
#
# authors:Ayn_Rand  a                       schema:Person ;
#         rdfs:label                 "Ayn Rand" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ayn_Rand.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/98139134/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ayn Rand" .
#
# authors:Ruth_Reichl  a                    schema:Person ;
#         rdfs:label                 "Ruth Reichl" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ruth_Reichl.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37796447/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ruth Reichl" .
#
# authors:Peter_Straub  a                   schema:Person ;
#         rdfs:label                 "Peter Straub" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Straub.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73860475/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Straub" .
#
# authors:Patricia_Cornwell  a              schema:Person ;
#         rdfs:label                 "Patricia Cornwell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patricia_Cornwell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36976332/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Patricia Cornwell" .
#
# authors:Martin_Cruz_Smith  a              schema:Person ;
#         rdfs:label                 "Martin Cruz Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Martin_Cruz_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95175916/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Martin Cruz Smith" .
#
# authors:Robert_Crais  a                   schema:Person ;
#         rdfs:label                 "Robert Crais" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Crais.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110237124/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Crais" .
#
# authors:Wisconsin_Milk_Marketing
#         a                       schema:Organization ;
#         rdfs:label              "Wisconsin Milk Marketing Board" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/139670152/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Wisconsin Milk Marketing Board" .
#
# authors:Thomas_Pynchon  a              schema:Person ;
#         rdfs:label              "Thomas Pynchon" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/88986700/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Thomas Pynchon" .
#
# authors:Sharon_Tyler_Herbst  a            schema:Person ;
#         rdfs:label                 "Sharon Tyler Herbst" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sharon_Tyler_Herbst.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/296145857943723021200/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sharon Tyler Herbst" .
#
# authors:Anne_Cameron  a                   schema:Person ;
#         rdfs:label                 "Anne Cameron" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anne_Cameron.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94714348/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anne Cameron" .
#
# authors:Salman_Rushdie  a                 schema:Person ;
#         rdfs:label                 "Salman Rushdie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Salman_Rushdie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29540187/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Salman Rushdie" .
#
# authors:DH_Lawrence  a                    schema:Person ;
#         rdfs:label                 "D. H. Lawrence" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/D._H._Lawrence.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95150359/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "D. H. Lawrence" .
#
# authors:Adam_Kadmon  a                 schema:Person ;
#         rdfs:label              "Adam Kadmon" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/79934587/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Adam Kadmon" .
#
# authors:Sharon_Pape  a                 schema:Person ;
#         rdfs:label              "Sharon Pape" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/100686926/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Sharon B. Pape" .
#
# authors:Donald_Peattie  a                 schema:Person ;
#         rdfs:label                 "Donald C. Peattie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Donald_C._Peattie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79210486/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Donald Culcross Peattie" .
#
# authors:Al_Di_Meola  a                    schema:Person ;
#         rdfs:label                 "Al Di Meola" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Al_Di_Meola.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85427757/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Al Di Meola" .
#
# authors:Sebastian_Faulks  a               schema:Person ;
#         rdfs:label                 "Sebastian Faulks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sebastian_Faulks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/106994448/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sebastian Faulks" .
#
# authors:William_Thackeray  a              schema:Person ;
#         rdfs:label                 "William Makepeace Thackeray" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Makepeace_Thackeray.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95208604/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Makepeace Thackeray" .
#
# authors:Nikolai_Gogol  a                  schema:Person ;
#         rdfs:label                 "Nikolai Vasilevich Gogol" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nikolai_Gogol.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54148306/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nikolai Vasilevich Gogol" .
#
# authors:William_Shakespeare  a            schema:Person ;
#         rdfs:label                 "William Shakespeare" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Shakespeare.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96994048/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Shakespeare" .
#
# authors:Jane_Coleman_Helmer  a         schema:Person ;
#         rdfs:label              "Jane Coleman Helmer" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/35740723/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jane Coleman Helmer" .
#
# authors:Vivienne_Marquis  a            schema:Person ;
#         rdfs:label              "Vivienne Marquis" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/40787917/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Vivienne Marquis" .
#
# authors:Tom_Rachman  a                    schema:Person ;
#         rdfs:label                 "Tom Rachman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tom_Rachman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96735104/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tom Rachman" .
#
# authors:Joanna_Rose  a                 schema:Person ;
#         rdfs:label              "Joanna Rose" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/14042673/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Joanna Rose" .
#
# authors:Richard_Dawkins  a                schema:Person ;
#         rdfs:label                 "Richard Dawkins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Dawkins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12307054/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Dawkins" .
#
# authors:Henning_Nelms  a                  schema:Person ;
#         rdfs:comment               "Pen name: Hake Talbot" ;
#         rdfs:label                 "Henning Nelms" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hake_Talbot.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/40619770/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Henning Nelms" .
#
# authors:Brad_Hansen  a                 schema:Person ;
#         rdfs:label              "Brad Hansen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/21405037/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Brad Hansen" .
#
# authors:Bram_Stoker  a                    schema:Person ;
#         rdfs:label                 "Bram Stoker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bram_Stoker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17229847/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bram Stoker" .
#
# authors:Elmore_Leonard  a                 schema:Person ;
#         rdfs:label                 "Elmore Leonard" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elmore_Leonard.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19680365/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elmore Leonard" .
#
# authors:Hugh_Williams  a               schema:Person ;
#         rdfs:label              "Hugh E. Williams" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/30453220/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Hugh E. Williams" .
#
# authors:Kiran_Desai  a                 schema:Person ;
#         rdfs:label              "Kiran Desai" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/34618623/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kiran Desai" .
#
# authors:Bob_Marley  a                     schema:Person ;
#         rdfs:label                 "Bob Marley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bob_Marley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14778710/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bob Marley" .
#
# authors:Edward_Rice  a                    schema:Person ;
#         rdfs:label                 "Edward Rice" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ed_Rice.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60273426/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edward Rice" .
#
# authors:Joseph_Campbell  a                schema:Person ;
#         rdfs:label                 "Joseph Campbell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joseph_Campbell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9844141/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joseph Campbell" .
#
# authors:Dermot_Bolger  a                  schema:Person ;
#         rdfs:label                 "Dermot Bolger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dermot_Bolger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9904049/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dermot Bolger" .
#
# authors:Andrew_Boyd  a                    schema:Person ;
#         rdfs:label                 "Andrew Boyd" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Andrew_Boyd_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42916451/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Andrew Boyd" .
#
# authors:Jim_Webb  a                       schema:Person ;
#         rdfs:label                 "Jim Webb" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jim_Webb.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/3717010/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jim Webb" .
#
# authors:Clarence_Major  a                 schema:Person ;
#         rdfs:label                 "Clarence Major" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Clarence_Major.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24604680/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Clarence Major" .
#
# authors:Jean_Auel  a                      schema:Person ;
#         rdfs:label                 "Jean M. Auel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jean_M._Auel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79487364/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jean M. Auel" .
#
# authors:Frederick_Douglass  a             schema:Person ;
#         rdfs:label                 "Frederick Douglass" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frederick_Douglass.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/10088/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frederick Douglass" .
#
# authors:Anton_Chekhov  a                  schema:Person ;
#         rdfs:label                 "Anton Chekhov" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anton_Chekhov.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95216565/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anton Pavlovich Chekhov" .
#
# authors:Charles_Larson  a              schema:Person ;
#         rdfs:label              "Charles Larson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/56738394/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Charles Larson" .
#
# authors:William_Trevor  a                 schema:Person ;
#         rdfs:label                 "William Trevor" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Trevor.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101362985/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William Trevor" .
#
# authors:Steve_Berry  a                    schema:Person ;
#         rdfs:label                 "Steve Berry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steve_Berry_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85545256/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steve Berry" .
#
# authors:HP_Lovecraft  a                   schema:Person ;
#         rdfs:label                 "H. P. Lovecraft" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/H._P._Lovecraft.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66470391/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "H. P. Lovecraft" .
#
# authors:Sarah_Silverman  a                schema:Person ;
#         rdfs:label                 "Sarah Silverman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sarah_Silverman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29258917/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sarah Silverman" .
#
# authors:Sara_Midda  a                  schema:Person ;
#         rdfs:label              "Sara Midda" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/302449407/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Sara Midda" .
#
# authors:Thomas_Ricks  a                   schema:Person ;
#         rdfs:label                 "Thomas Ricks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_E._Ricks_(journalist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/65756810/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Ricks" .
#
# authors:Alfredo_Vea  a                    schema:Person ;
#         rdfs:label                 "Alfredo Véa" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alfredo_V%C3%A9a_Jr..ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91422052/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alfredo Véa" .
#
# authors:Sune_Engelbrektson  a          schema:Person ;
#         rdfs:label              "Sune Engelbrektson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/306066397/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Sune Engelbrektson" .
#
# authors:Suzanne_Collins  a                schema:Person ;
#         rdfs:label                 "Suzanne Collins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Suzanne_Collins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/150638554/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Suzanne Collins" .
#
# authors:Connie_May_Fowler  a              schema:Person ;
#         rdfs:label                 "Connie May Fowler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Connie_May_Fowler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52360742/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Connie May Fowler" .
#
# authors:Ann_Dunnigan  a                   schema:Person ;
#         rdfs:label                 "Ann Dunnigan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ann_Dunnigan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/42584726/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ann Dunnigan" .
#
# authors:Deborah_Madison  a                schema:Person ;
#         rdfs:label                 "Deborah Madison" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Deborah_Madison.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/6372813/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Deborah Madison" .
#
# authors:Larry_Rockoff  a               schema:Person ;
#         rdfs:label              "Larry Rockoff" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/219213732/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Larry Rockoff" .
#
# authors:Christian_Lander  a               schema:Person ;
#         rdfs:label                 "Christian Lander" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stuff_White_People_Like.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76131227/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Christian Lander" .
#
# authors:Vincent_Kohler  a              schema:Person ;
#         rdfs:label              "Vincent Kohler" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/43641873/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Vincent Kohler" .
#
# authors:Merrill_Gilfillan  a              schema:Person ;
#         rdfs:label                 "Merrill Gilfillan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Merrill_Gilfillan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/28522484/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Merrill Gilfillan" .
#
# authors:JM_Coetzee  a                     schema:Person ;
#         rdfs:label                 "J. M. Coetzee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._M._Coetzee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101839018/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J. M. Coetzee" .
#
# authors:MerriamWebster  a                 schema:Organization ;
#         rdfs:label                 "Merriam-Webster, Inc." ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Merriam-Webster.ttl"^^xsd:anyURI ;
#         foaf:name                  "Merriam-Webster, Inc." .
#
# authors:Junot_Diaz  a                     schema:Person ;
#         rdfs:label                 "Junot Díaz" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Junot_Díaz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79142980/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Junot Díaz" .
#
# authors:Vernor_Vinge  a                   schema:Person ;
#         rdfs:label                 "Vernor Vinge" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Vernor_Vinge.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79037788/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Vernor Vinge" .
#
# authors:Jo_Nesbo  a                       schema:Person ;
#         rdfs:label                 "Jo Nesbø" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jo_Nesb%C3%B8.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44460209/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jo Nesbø" .
#
# authors:Ian_Kershaw  a                    schema:Person ;
#         rdfs:label                 "Ian Kershaw" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ian_Kershaw.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36930589/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ian Kershaw" .
#
# authors:Pavel_Kohout  a                   schema:Person ;
#         rdfs:label                 "Pavel Kohout" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Pavel_Kohout.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56612039/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Pavel Kohout" .
#
# authors:James_Gleick  a                   schema:Person ;
#         rdfs:label                 "James Gleick" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Gleick.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51721740/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Gleick" .
#
# authors:Elizabeth_Cunningham
#         a                          schema:Person ;
#         rdfs:label                 "Elizabeth Cunningham" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elizabeth_Cunningham.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94138577/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elizabeth Cunningham" .
#
# authors:Edward_Esko  a                    schema:Person ;
#         rdfs:label                 "Edward Esko" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edward_Esko.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59725320/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edward Esko" .
#
# authors:Truman_Capote  a                  schema:Person ;
#         rdfs:label                 "Truman Capote" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Truman_Capote.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51686739/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Truman Capote" .
#
# authors:Fred_Saberhagen  a                schema:Person ;
#         rdfs:label                 "Fred Saberhagen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Fred_Saberhagen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111612948/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Fred Saberhagen" .
#
# authors:David_James_Duncan  a             schema:Person ;
#         rdfs:label                 "David James Duncan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_James_Duncan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94759891/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David James Duncan" .
#
# authors:Rudyard_Kipling  a                schema:Person ;
#         rdfs:label                 "Rudyard Kipling" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rudyard_Kipling.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7524679/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rudyard Kipling" .
#
# authors:Richard_Kluger  a                 schema:Person ;
#         rdfs:label                 "Richard Kluger" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Kluger.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4959067/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Kluger" .
#
# authors:Anthony_Burgess  a                schema:Person ;
#         rdfs:label                 "Anthony Burgess" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anthony_Burgess.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71388189/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anthony Burgess" .
#
# authors:James_Patterson  a                schema:Person ;
#         rdfs:label                 "James Patterson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Patterson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22272314/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Patterson" .
#
# authors:T_Jeff_Williams  a             schema:Person ;
#         rdfs:label              "T. Jeff Williams" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/67753107/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "T. Jeff Williams" .
#
# authors:Samuel_Fromartz  a             schema:Person ;
#         rdfs:label              "Samuel Fromartz" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/53563060/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Samuel Fromartz" .
#
# authors:Alan_Watts  a                     schema:Person ;
#         rdfs:label                 "Alan Watts" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alan_Watts.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2478279/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alan Watts" .
#
# authors:Gordon_Parks  a                   schema:Person ;
#         rdfs:label                 "Gordon Parks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gordon_Parks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112248361/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gordon Parks" .
#
# authors:Sam_Harris  a                     schema:Person ;
#         rdfs:label                 "Sam Harris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sam_Harris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97888651/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sam Harris" .
#
# authors:Anthony_Doerr  a                  schema:Person ;
#         rdfs:label                 "Anthony Doerr" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anthony_Doerr.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79550093/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anthony Doerr" .
#
# authors:Tony_Glover  a                    schema:Person ;
#         rdfs:label                 "Tony Glover" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tony_Glover.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91558017/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tony Glover" .
#
# authors:R_Scott_Bakker  a                 schema:Person ;
#         rdfs:label                 "R. Scott Bakker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/R._Scott_Bakker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88102835/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "R. Scott Bakker" .
#
# authors:Dave_Cullen  a                    schema:Person ;
#         rdfs:label                 "Dave Cullen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dave_Cullen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71010788/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dave Cullen" .
#
# authors:George_Orwell  a                  schema:Person ;
#         rdfs:label                 "George Orwell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_Orwell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95155403/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George Orwell" .
#
# authors:Gene_Wolfe  a                     schema:Person ;
#         rdfs:label                 "Gene Wolfe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gene_Wolfe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92193245/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gene Wolfe" .
#
# authors:Nicole_Krauss  a                  schema:Person ;
#         rdfs:label                 "Nicole Krauss" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Nicole_Krauss.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99094300/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nicole Krauss" .
#
# authors:Lorraine_Anderson  a           schema:Person ;
#         rdfs:label              "Lorraine Anderson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/56844346/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Lorraine Anderson" .
#
# authors:William_Young  a                  schema:Person ;
#         rdfs:label                 "William P. Young" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_P._Young.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/78234437/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William P. Young" .
#
# authors:Richard_Nelson  a                 schema:Person ;
#         rdfs:label                 "Richard Nelson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Nelson_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91090206/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard K. Nelson" .
#
# authors:Jimmy_McDonough  a                schema:Person ;
#         rdfs:label                 "Jimmy McDonough" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jimmy_McDonough.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/78120958/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jimmy McDonough" .
#
# authors:Poppy_Brite  a                    schema:Person ;
#         rdfs:label                 "Poppy Z. Brite" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Poppy_Z._Brite.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85778403/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Poppy Z. Brite" .
#
# authors:Christopher_Moore  a              schema:Person ;
#         rdfs:label                 "Christopher Moore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Christopher_Moore_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85622613/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Christopher Moore" .
#
# authors:Richard_J_Evans  a                schema:Person ;
#         rdfs:label                 "Richard J. Evans" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_J._Evans.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12283480/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard J. Evans" .
#
# authors:Mary_Shelley  a                   schema:Person ;
#         rdfs:label                 "Mary Shelley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mary_Shelley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/6293/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mary Shelley" .
#
# authors:Jane_English  a                   schema:Person ;
#         rdfs:label                 "Jane English" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jane_English.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17801665/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jane English" .
#
# authors:Lois_Lowry  a                     schema:Person ;
#         rdfs:label                 "Lois Lowry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lois_Lowry.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66470410/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lois Lowry" .
#
# authors:Mark_Ely  a                    schema:Person ;
#         rdfs:label              "Mark Ely" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/6147149198302874940005/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Mark Ely" .
#
# authors:Jodi_Picoult  a                   schema:Person ;
#         rdfs:label                 "Jodi Picoult" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jodi_Picoult.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37821799/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jodi Picoult" .
#
# authors:Christian_Teubner  a           schema:Person ;
#         rdfs:label              "Christian Teubner" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/100954063/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Christian Teubner" .
#
# authors:Walter_Scott  a                   schema:Person ;
#         rdfs:label                 "Walter Scott" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Walter_Scott.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95207079/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Walter Scott" .
#
# authors:Brooks_Hansen  a                  schema:Person ;
#         rdfs:label                 "Brooks Hansen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brooks_Hansen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50079550/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brooks Hansen" .
#
# authors:Jim_Dodge  a                      schema:Person ;
#         rdfs:label                 "Jim Dodge" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jim_Dodge.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91586861/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jim Dodge" .
#
# authors:John_Neihardt  a                  schema:Person ;
#         rdfs:label                 "John G. Neihardt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Neihardt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59087102/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John G. Neihardt" .
#
# authors:Clifton_Fadiman  a                schema:Person ;
#         rdfs:label                 "Clifton Fadiman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Clifton_Fadiman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/762106/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Clifton Fadiman" .
#
# authors:Richard_Matheson  a               schema:Person ;
#         rdfs:label                 "Richard Matheson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Matheson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85394787/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Matheson" .
#
# authors:Jack_Hodgins  a                   schema:Person ;
#         rdfs:label                 "Jack Hodgins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jack_Hodgins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/114666696/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jack Hodgins" .
#
# authors:Betty_Sampson  a               schema:Person ;
#         rdfs:label              "Betty Sampson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/292149106279468492295/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Betty Sampson" .
#
# authors:Jean_Paul_Sartre  a               schema:Person ;
#         rdfs:label                 "Jean-Paul Sartre" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jean-Paul_Sartre.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76322562/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jean-Paul Sartre" .
#
# authors:Ellen_Ewald  a                 schema:Person ;
#         rdfs:label              "Ellen Buchman Ewald" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/116759379/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ellen Buchman Ewald" .
#
# authors:Ladies_Union_Circle  a  schema:Organization ;
#         rdfs:label  "Ladies' Union Circle" ;
#         foaf:name   "First Congregational Church (Nantucket, Mass.). Ladies' Union Circle" .
#
# authors:Yamaha  a                         schema:Organization ;
#         rdfs:label                 "Yamaha" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Yamaha_Corporation.ttl"^^xsd:anyURI ;
#         foaf:name                  "Yamaha" .
#
# authors:Marian_Keyes  a                   schema:Person ;
#         rdfs:label                 "Marian Keyes" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Marian_Keyes.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85314579/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Marian Keyes" .
#
# authors:Richard_Flanagan  a               schema:Person ;
#         rdfs:label                 "Richard Flanagan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Flanagan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99138677/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Flanagan" .
#
# authors:Barbara_Seels  a   schema:Person ;
#         rdfs:label  "Barbara Seels" ;
#         foaf:name   "Barbara Seels" .
#
# authors:Laura_Hillenbrand  a              schema:Person ;
#         rdfs:label                 "Laura Hillenbrand" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Laura_Hillenbrand.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56822917/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Laura Hillenbrand" .
#
# authors:Jonathan_Maberry  a               schema:Person ;
#         rdfs:label                 "Jonathan Maberry" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jonathan_Maberry.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103754358/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jonathan Maberry" .
#
# authors:Carlos_Zafon  a                   schema:Person ;
#         rdfs:label                 "Carlos Ruiz Zafón" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carlos_Ruiz_Zaf%C3%B3n.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95219127/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Carlos Ruiz Zafón" .
#
# authors:Elizabeth_Gilbert  a              schema:Person ;
#         rdfs:label                 "Elizabeth Gilbert" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Elizabeth_Gilbert.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7713013/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Elizabeth Gilbert" .
#
# authors:Harriet_Beecher_Stowe
#         a                          schema:Person ;
#         rdfs:label                 "Harriet Beecher Stowe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Harriet_Beecher_Stowe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32003151/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Harriet Beecher Stowe" .
#
# authors:Kathryn_Stockett  a               schema:Person ;
#         rdfs:label                 "Kathryn Stockett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kathryn_Stockett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68403808/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kathryn Stockett" .
#
# authors:Giafu_Feng  a                     schema:Person ;
#         rdfs:label                 "Gia-fu Feng" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gia-Fu_Feng.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69491160/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gia-fu Feng" .
#
# authors:George_Petrides  a             schema:Person ;
#         rdfs:label              "George Petrides" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/35980503/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "George Petrides" .
#
# authors:Kat_Richardson  a                 schema:Person ;
#         rdfs:label                 "Kat Richardson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kat_Richardson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73278148/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kat Richardson" .
#
# authors:Karen_Armstrong  a                schema:Person ;
#         rdfs:label                 "Karen Armstrong" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Karen_Armstrong.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97630837/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Karen Armstrong" .
#
# authors:Max_Brooks  a                     schema:Person ;
#         rdfs:label                 "Max Brooks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Max_Brooks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/40456445/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Max Brooks" .
#
# authors:Judy_Jewell  a                 schema:Person ;
#         rdfs:label              "Judy Jewell" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/48413628/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Judy Jewell" .
#
# authors:Lawrence_Norfolk  a               schema:Person ;
#         rdfs:label                 "Lawrence Norfolk" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lawrence_Norfolk.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113121215/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lawrence Norfolk" .
#
# authors:Voltaire  a                       schema:Person ;
#         rdfs:label                 "Voltaire" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Voltaire.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36925746/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Voltaire" .
#
# authors:Craig_DiLouie  a               schema:Person ;
#         rdfs:label              "Craig DiLouie" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/85190108/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Craig DiLouie" .
#
# authors:Walter_Mosley  a                  schema:Person ;
#         rdfs:label                 "Walter Mosley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Walter_Mosley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4979209/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Walter Mosley" .
#
# authors:Thomas_Paine  a                   schema:Person ;
#         rdfs:label                 "Thomas Paine" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_Paine.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4934659/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Paine" .
#
# authors:Patricia_Briggs  a                schema:Person ;
#         rdfs:label                 "Patricia Briggs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patricia_Briggs.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/70112022/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Patricia Briggs" .
#
# authors:Ardythe_Ashley  a              schema:Person ;
#         rdfs:label              "Ardythe Ashley" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/60735435/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ardythe Ashley" .
#
# authors:Ian_McEwan  a                     schema:Person ;
#         rdfs:label                 "Ian McEwan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ian_McEwan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109587997/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ian McEwan" .
#
# authors:Dan_Haerle  a                     schema:Person ;
#         rdfs:label                 "Dan Haerle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_Haerle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79605239/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan Haerle" .
#
# authors:Adelle_Davis  a                   schema:Person ;
#         rdfs:label                 "Adelle Davis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Adelle_Davis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112513588/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Adelle Davis" .
#
# authors:Michael_Lewis  a                  schema:Person ;
#         rdfs:label                 "Michael Lewis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Lewis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36966655/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Lewis" .
#
# authors:Robert_Olen_Butler  a             schema:Person ;
#         rdfs:label                 "Robert Olen Butler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Olen_Butler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/107542179/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Olen Butler" .
#
# authors:Albert_Einstein  a                schema:Person ;
#         rdfs:label                 "Albert Einstein" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Albert_Einstein.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/75121530/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Albert Einstein" .
#
# authors:Elsbeth_Woody  a               schema:Person ;
#         rdfs:label              "Elsbeth S. Woody" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/15352982/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Elsbeth S. Woody" .
#
# authors:Yann_Martel  a                    schema:Person ;
#         rdfs:label                 "Yann Martel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Yann_Martel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85372278/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Yann Martel" .
#
# authors:Ana_Castillo  a                   schema:Person ;
#         rdfs:label                 "Ana Castillo" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ana_Castillo.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/90599366/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ana Castillo" .
#
# authors:Michael_Cunningham  a             schema:Person ;
#         rdfs:label                 "Michael Cunningham" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Cunningham.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85321355/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Cunningham" .
#
# authors:Mark_Jacobson  a               schema:Person ;
#         rdfs:label              "Mark Jacobson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/92938772/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Mark Jacobson" .
#
# authors:Frederick_Franck  a               schema:Person ;
#         rdfs:label                 "Frederick Franck" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frederick_Franck.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111278883/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frederick Franck" .
#
# authors:Joseph_ONeill  a                  schema:Person ;
#         rdfs:label                 "Joseph O'Neill" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Joseph_O'Neill_(writer,_born_1964).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73443109/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joseph O'Neill" .
#
# authors:Edward_Abbey  a                   schema:Person ;
#         rdfs:label                 "Edward Abbey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edward_Abbey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85322062/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edward Abbey" .
#
# authors:Oasis_Project  a               schema:Organization ;
#         rdfs:label              "Oasis Project" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/132764033/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Oasis Project" .
#
# authors:Adam_Pepper  a     schema:Person ;
#         rdfs:label  "Adam Pepper" ;
#         foaf:name   "Adam Pepper" .
#
# authors:Peter_Hoeg  a                     schema:Person ;
#         rdfs:label                 "Peter Høeg" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_H%C3%B8eg.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/114758804/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Høeg" .
#
# authors:Patrick_OBrian  a                 schema:Person ;
#         rdfs:label                 "Patrick O'Brian" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patrick_O'Brian.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99981648/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Patrick O'Brian" .
#
# authors:David_Sedaris  a                  schema:Person ;
#         rdfs:label                 "David Sedaris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Sedaris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/8230168/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Sedaris" .
#
# authors:Salma_Samar_Damluji  a            schema:Person ;
#         rdfs:label                 "Salma Samar Damluji" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Salma_Samar_Damluji.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92515267/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Salma Samar Damluji" .
#
# authors:Joe_Hill  a                       schema:Person ;
#         rdfs:label                 "Joe Hill" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joe_Hill_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29856643/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joe Hill" .
#
# authors:Raymond_E_Feist  a                schema:Person ;
#         rdfs:label                 "Raymond E. Feist" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Raymond_E._Feist.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19708573/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Raymond E. Feist" .
#
# authors:Tom_Robbins  a                    schema:Person ;
#         rdfs:label                 "Tom Robbins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tom_Robbins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71491365/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tom Robbins" .
#
# authors:Gustave_Flaubert  a               schema:Person ;
#         rdfs:label                 "Gustave Flaubert" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gustave_Flaubert.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9846192/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gustave Flaubert" .
#
# authors:Naomi_Lazard  a                   schema:Person ;
#         rdfs:label                 "Naomi Lazard" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Naomi_Lazard.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7804711/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Naomi Lazard" .
#
# authors:Jane_Urquhart  a                  schema:Person ;
#         rdfs:label                 "Jane Urquhart" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jane_Urquhart.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84393856/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jane Urquhart" .
#
# authors:Anita_Shreve  a                   schema:Person ;
#         rdfs:label                 "Anita Shreve" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anita_Shreve.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32082253/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anita Shreve" .
#
# authors:Andy_McDermott  a                 schema:Person ;
#         rdfs:label                 "Andy McDermott" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Andy_McDermott.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/80474776/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Andy McDermott" .
#
# authors:James_Crumley  a                  schema:Person ;
#         rdfs:label                 "James Crumley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Crumley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85403130/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Crumley" .
#
# authors:Lemony_Snicket  a                 schema:Person ;
#         rdfs:label                 "Lemony Snicket" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lemony_Snicket.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44513180/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lemony Snicket" .
#
# authors:Max_McCalman  a                   schema:Person ;
#         rdfs:label                 "Max McCalman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Max_McCalman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/28872878/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Max McCalman" .
#
# authors:Willa_Cather  a                   schema:Person ;
#         rdfs:label                 "Willa Cather" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Willa_Cather.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2480701/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Willa Cather" .
#
# authors:Heather_Cheney  a  schema:Person ;
#         rdfs:label  "Heather Cheney" ;
#         foaf:name   "Heather Cheney" .
#
# authors:Phil_Lesh  a                      schema:Person ;
#         rdfs:label                 "Phil Lesh" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Phil_Lesh.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/78406355/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Phil Lesh" .
#
# authors:John_Grisham  a                   schema:Person ;
#         rdfs:label                 "John Grisham" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Grisham.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7449742/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Grisham" .
#
# authors:Floyd_Shuttleworth  a          schema:Person ;
#         rdfs:label              "Floyd Stephen Shuttleworth" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/44836611/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Floyd Stephen Shuttleworth" .
#
# authors:John_A_Lindquist  a               schema:Person ;
#         rdfs:label                 "John Ajvide Lindquist" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Ajvide_Lindqvist.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102262971/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Ajvide Lindquist" .
#
# authors:Robert_Solomon  a                 schema:Person ;
#         rdfs:label                 "Robert C. Solomon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_C._Solomon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108255013/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert C. Solomon" .
#
# authors:Rex_Pickett  a                    schema:Person ;
#         rdfs:label                 "Rex Pickett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rex_Pickett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85097972/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rex Pickett" .
#
# authors:Glenn_Day  a                   schema:Person ;
#         rdfs:label              "Glenn Day" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/112991023/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Glenn Day" .
#
# authors:DM_Dooling  a                  schema:Person ;
#         rdfs:label              "D. M. Dooling" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/93700890/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "D. M. Dooling" .
#
# authors:Mort_Rosenblum  a                 schema:Person ;
#         rdfs:label                 "Mort Rosenblum" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mort_Rosenblum.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73859456/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mort Rosenblum" .
#
# authors:Philip_K_Dick  a                  schema:Person ;
#         rdfs:label                 "Philip K. Dick" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philip_K._Dick.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27063583/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philip K. Dick" .
#
# authors:Andres_Segovia  a                 schema:Person ;
#         rdfs:label                 "Andres Segovia" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Andr%C3%A9s_Segovia.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54346467/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Andres Segovia" .
#
# authors:Van_Reid  a                    schema:Person ;
#         rdfs:label              "Van Reid" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/16535666/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Van Reid" .
#
# authors:Rita_Dove  a                      schema:Person ;
#         rdfs:label                 "Rita Dove" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rita_Dove.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39400140/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rita Dove" .
#
# authors:AC_Bhaktivedanta_Swami
#         a                          schema:Person ;
#         rdfs:label                 "A.C. Bhaktivedanta Swami Prabhupāda" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/A._C._Bhaktivedanta_Swami_Prabhupada.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/31993003/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "A.C. Bhaktivedanta Swami Prabhupāda" .
#
# authors:Jean_Hewitt  a                 schema:Person ;
#         rdfs:label              "Jean Hewitt" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/75142359/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jean Hewitt" .
#
# authors:Peter_Senge  a                    schema:Person ;
#         rdfs:label                 "Peter M. Senge" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Senge.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79377607/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter M. Senge" .
#
# authors:David_Guterson  a                 schema:Person ;
#         rdfs:label                 "David Guterson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Guterson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84055110/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Guterson" .
#
# authors:Maya_Angelou  a                   schema:Person ;
#         rdfs:label                 "Maya Angelou" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Maya_Angelou.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/7386077/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Maya Angelou" .
#
# authors:Jerry_Garcia  a                   schema:Person ;
#         rdfs:label                 "Jerry Garcia" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jerry_Garcia.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36777071/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jerry Garcia" .
#
# authors:Bruce_Campbell  a                 schema:Person ;
#         rdfs:label                 "Bruce Campbell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bruce_Campbell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51889044/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bruce Campbell" .
#
# authors:Dan_Millman  a                    schema:Person ;
#         rdfs:label                 "Dan Millman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_Millman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60874/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan Millman" .
#
# authors:Ted_Greene  a                     schema:Person ;
#         rdfs:label                 "Ted Greene" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ted_Greene.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103862530/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ted Greene" .
#
# authors:Rachel_Biheller_Bunin
#         a                       schema:Person ;
#         rdfs:label              "Rachel Biheller Bunin" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/46256461/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Rachel Biheller Bunin" .
#
# authors:Umberto_Eco  a                    schema:Person ;
#         rdfs:label                 "Umberto Eco" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Umberto_Eco.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108299403/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Umberto Eco" .
#
# authors:Becky_Ohlsen  a                schema:Person ;
#         rdfs:label              "Becky Ohlsen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/107633816/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Becky Ohlsen" .
#
# authors:Jonathan_Safran_Foer
#         a                          schema:Person ;
#         rdfs:label                 "Jonathan Safran Foer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jonathan_Safran_Foer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85500702/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jonathan Safran Foer" .
#
# authors:John_Joseph_Adams  a              schema:Person ;
#         rdfs:label                 "John Joseph Adams" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Joseph_Adams.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51511570/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Joseph Adams" .
#
# authors:Maryse_Conde  a                   schema:Person ;
#         rdfs:label                 "Maryse Condé" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Maryse_Cond%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/51687663/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Maryse Condé" .
#
# authors:Steve_Hall  a      schema:Person ;
#         rdfs:label  "Steve Hall" ;
#         foaf:name   "Steve Hall" .
#
# authors:Charles_Darwin  a                 schema:Person ;
#         rdfs:label                 "Charles Darwin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Darwin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27063124/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Darwin" .
#
# authors:Tom_Manoff  a                  schema:Person ;
#         rdfs:label              "Tom Manoff" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/8717374/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Tom Manoff" .
#
# authors:Steven_Wright  a                  schema:Person ;
#         rdfs:label                 "Steven Wright" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Wright.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/96948225/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Wright" .
#
# authors:Jared_Diamond  a                  schema:Person ;
#         rdfs:label                 "Jared Diamond" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jared_Diamond.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/90709225/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jared Diamond" .
#
# authors:Mark_Bridges  a                schema:Person ;
#         rdfs:label              "Mark Bridges" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/284104659/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Mark Bridges" .
#
# authors:Craig_Ferguson  a                 schema:Person ;
#         rdfs:label                 "Craig Ferguson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Craig_Ferguson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85085680/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Craig Ferguson" .
#
# authors:Arthur_Miller  a                  schema:Person ;
#         rdfs:label                 "Arthur Miller" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arthur_Miller.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44302716/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arthur Miller" .
#
# authors:Dan_Simmons  a                    schema:Person ;
#         rdfs:label                 "Dan Simmons" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_Simmons.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/107011235/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan Simmons" .
#
# authors:Charles_Mingus  a                 schema:Person ;
#         rdfs:label                 "Charles Mingus" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Mingus.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24604680/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Mingus" .
#
# authors:Charles_Baker  a                  schema:Person ;
#         rdfs:label                 "Charles H. Baker Jr." ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_H._Baker,_Jr..ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/1353418/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles H. Baker Jr." .
#
# authors:Mick_Goodrick  a                  schema:Person ;
#         rdfs:label                 "Mick Goodrick" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mick_Goodrick.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24789023/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mick Goodrick" .
#
# authors:James_Kelman  a                   schema:Person ;
#         rdfs:label                 "James Kelman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Kelman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111431072/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Kelman" .
#
# authors:Bill_Griffith  a                  schema:Person ;
#         rdfs:label                 "Bill Griffith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bill_Griffith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/118728837/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Griffith" .
#
# authors:Ann_Patchett  a                   schema:Person ;
#         rdfs:label                 "Ann Patchett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ann_Patchett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54362733/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ann Patchett" .
#
# authors:Sal_Salvador  a                   schema:Person ;
#         rdfs:label                 "Sal Salvador" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sal_Salvador.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92584411/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sal Salvador" .
#
# authors:David_Gans  a                     schema:Person ;
#         rdfs:label                 "David Gans" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Gans_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/72831631/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Gans" .
#
# authors:Zoe_Bran  a                    schema:Person ;
#         rdfs:label              "Zoë Brân" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/271668481/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Zoë Brân" .
#
# authors:Richard_Sterling  a               schema:Person ;
#         rdfs:label                 "Richard Sterling" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Sterling.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/18920262/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Sterling" .
#
# authors:Hermann_Hesse  a                  schema:Person ;
#         rdfs:label                 "Hermann Hesse" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hermann_Hesse.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41841418/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hermann Hesse" .
#
# authors:Mickey_Spillane  a                schema:Person ;
#         rdfs:label                 "Mickey Spillane" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mickey_Spillane.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12315338/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mickey Spillane" .
#
# authors:Dean_Koontz  a                    schema:Person ;
#         rdfs:label                 "Dean Koontz" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dean_Koontz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110880758/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dean Koontz" .
#
# authors:Robert_Frost  a                   schema:Person ;
#         rdfs:label                 "Robert Frost" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Frost.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32010055/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Frost" .
#
# authors:Louise_Rennison  a                schema:Person ;
#         rdfs:label                 "Louise Rennison" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Louise_Rennison.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44468078/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Louise Rennison" .
#
# authors:John_McPhee  a                    schema:Person ;
#         rdfs:label                 "John McPhee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_McPhee.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92169855/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John McPhee" .
#
# authors:John_Irving  a                    schema:Person ;
#         rdfs:label                 "John Irving" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Irving.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108238891/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Irving" .
#
# authors:Alafair_Burke  a                  schema:Person ;
#         rdfs:label                 "Alafair Burke" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alafair_Burke.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85530906/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alafair Burke" .
#
# authors:Fred_Darvill  a                schema:Person ;
#         rdfs:label              "Fred Darvill" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/20980989/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Fred T. Darvill, Jr." .
#
# authors:Erik_Larson  a                    schema:Person ;
#         rdfs:label                 "Erik Larson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Erik_Larson_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52556024/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Erik Larson" .
#
# authors:Mollie_Katzen  a                  schema:Person ;
#         rdfs:label                 "Mollie Katzen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mollie_Katzen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112616369/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mollie Katzen" .
#
# authors:Laurence_Boldt  a                 schema:Person ;
#         rdfs:label                 "Laurence G. Boldt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Laurence_Boldt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49098260/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Laurence G. Boldt" .
#
# authors:Blue_Ribbon  a     schema:Organization ;
#         rdfs:label  "Blue Ribbon Malt" ;
#         foaf:name   "Blue Ribbon Malt" .
#
# authors:Jana_Kolpen  a                 schema:Person ;
#         rdfs:label              "Jana Fayne Kolpen" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/69649257/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jana Fayne Kolpen" .
#
# authors:Muriel_Sweet  a                schema:Person ;
#         rdfs:label              "Muriel Sweet" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/112901383/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Muriel Sweet" .
#
# authors:Dave_Eggers  a                    schema:Person ;
#         rdfs:label                 "Dave Eggers" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dave_Eggers.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111612308/rdf.xml.xml"^^xsd:anyURI ;
#         foaf:name                  "Dave Eggers" .
#
# authors:Susan_Fox_Rogers  a            schema:Person ;
#         rdfs:label              "Susan Fox Rogers" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/13992580/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Susan Fox Rogers" .
#
# authors:Bentley_Little  a                 schema:Person ;
#         rdfs:label                 "Bentley Little" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bentley_Little.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102274498/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bentley Little" .
#
# authors:Lindsey_Davis  a                  schema:Person ;
#         rdfs:label                 "Lindsey Davis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lindsey_Davis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/8029680/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lindsey Davis" .
#
# authors:Robert_Pirsig  a                  schema:Person ;
#         rdfs:label                 "Robert M. Pirsig" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_M._Pirsig.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/78757182/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert M. Pirsig" .
#
# authors:Richard_Yates  a                  schema:Person ;
#         rdfs:label                 "Richard Yates" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Yates_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17323284/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Yates" .
#
# authors:Richard_Brautigan  a              schema:Person ;
#         rdfs:label                 "Richard Brautigan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Brautigan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/8169/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Brautigan" .
#
# authors:Tim_Cahill  a                     schema:Person ;
#         rdfs:label                 "Tim Cahill" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_Cahill_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79174785/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim Cahill" .
#
# authors:John_Brimhall  a                  schema:Person ;
#         rdfs:label                 "John Brimhall" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Brimhall.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4087931/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Brimhall" .
#
# authors:Jack_Kerouac  a                   schema:Person ;
#         rdfs:label                 "Jack Kerouac" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jack_Kerouac.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27066713/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jack Kerouac" .
#
# authors:John_Crowley  a                   schema:Person ;
#         rdfs:label                 "John Crowley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Crowley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85467356/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Crowley" .
#
# authors:Barry_Gifford  a                  schema:Person ;
#         rdfs:label                 "Barry Gifford" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barry_Gifford.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111118438/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barry Gifford" .
#
# authors:Norton_Juster  a                  schema:Person ;
#         rdfs:label                 "Norton Juster" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Norton_Juster.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39601304/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Norton Juster" .
#
# authors:Eliot_Asinof  a                   schema:Person ;
#         rdfs:label                 "Eliot Asinof" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Eliot_Asinof.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/1283166/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Eliot Asinof" .
#
# authors:Lois_Ann_Yamanaka  a              schema:Person ;
#         rdfs:label                 "Lois-Ann Yamanaka" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lois-Ann_Yamanaka.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/115656872/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lois-Ann Yamanaka" .
#
# authors:Richard_Adams  a                  schema:Person ;
#         rdfs:label                 "Richard Adams" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Adams.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71386171/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Adams" .
#
# authors:Norman_Rush  a                    schema:Person ;
#         rdfs:label                 "Norman Rush" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Norman_Rush.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93387650/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Norman Rush" .
#
# authors:Holly_George-Warren  a         schema:Person ;
#         rdfs:label              "Holly George-Warren" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/2616267/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Holly George-Warren" .
#
# authors:Diane_Seed  a                  schema:Person ;
#         rdfs:label              "Diane Seed" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/10739182/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Diane Seed" .
#
# authors:Haare_Williams  a  schema:Person ;
#         rdfs:label  "Haare Williams" ;
#         foaf:name   "Haare Williams" .
#
# authors:Tim_Ferriss  a                    schema:Person ;
#         rdfs:label                 "Tim Ferriss" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tim_Ferriss.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/162529942/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tim Ferriss" .
#
# authors:Maxine_Hong_Kingston
#         a                          schema:Person ;
#         rdfs:label                 "Maxine Hong Kingston" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Maxine_Hong_Kingston.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108862703/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Maxine Hong Kingston" .
#
# authors:Matt_Taibbi  a                    schema:Person ;
#         rdfs:label                 "Matt Taibbi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Matt_Taibbi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68257575/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Matt Taibbi" .
#
# authors:Keri_Hulme  a                     schema:Person ;
#         rdfs:label                 "Keri Hulme" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Keri_Hulme.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61567391/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Keri Hulme" .
#
# authors:Samuel_Chamberlain  a          schema:Person ;
#         rdfs:label              "Samuel Chamberlain" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/109405045/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Samuel Chamberlain" .
#
# authors:Hugh_Ambrose  a                   schema:Person ;
#         rdfs:label                 "Hugh Ambrose" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hugh_Ambrose.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101388387/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hugh Ambrose" .
#
# authors:Joshua_Piven  a                schema:Person ;
#         rdfs:label              "Joshua Piven" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/34635256/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Joshua Piven" .
#
# authors:David_Rains_Wallace  a            schema:Person ;
#         rdfs:label                 "David Rains Wallace" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Rains_Wallace.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112844734/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Rains Wallace" .
#
# authors:Robert_Louis_Stevenson
#         a                          schema:Person ;
#         rdfs:label                 "Robert Louis Stevenson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Louis_Stevenson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95207986/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Louis Stevenson" .
#
# authors:Stephen_Colbert  a                schema:Person ;
#         rdfs:label                 "Stephen Colbert" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Colbert.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/1829775/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Colbert" .
#
# authors:James_Lee_Burke  a                schema:Person ;
#         rdfs:label                 "James Lee Burke" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Lee_Burke.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110621918/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Lee Burke" .
#
# authors:Neil_Strauss  a                   schema:Person ;
#         rdfs:label                 "Neil Strauss" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Neil_Strauss.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34674382/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Neil Strauss" .
#
# authors:Quincy_Troupe  a                  schema:Person ;
#         rdfs:label                 "Quincy Troupe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Quincy_Troupe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100269725/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Quincy Troupe" .
#
# authors:Thomas_Harris  a                  schema:Person ;
#         rdfs:label                 "Thomas Harris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_Harris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110527100/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Harris" .
#
# authors:Niccolo_Tucci  a                  schema:Person ;
#         rdfs:label                 "Niccolò Tucci" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Niccol%C3%B2_Tucci.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61578001/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Niccolò Tucci" .
#
# authors:J_Tom_Burgess  a                  schema:Person ;
#         rdfs:label                 "J Tom Burgess" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joseph_Tom_Burgess.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54722911/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J Tom Burgess" .
#
# authors:Nikki_Sixx  a                     schema:Person ;
#         rdfs:label                 "Nikki Sixx" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nikki_Sixx.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91759236/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Nikki Sixx" .
#
# authors:Susan_Orlean  a                   schema:Person ;
#         rdfs:label                 "Susan Orlean" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Susan_Orlean.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/26077018/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Susan Orlean" .
#
# authors:Tananarive_Due  a                 schema:Person ;
#         rdfs:label                 "Tananarive Due" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tananarive_Due.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59266210/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tananarive Due" .
#
# authors:Jay_Z  a                          schema:Person ;
#         rdfs:label                 "Jay-Z" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jay-Z.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85637620/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jay-Z" .
#
# authors:Elisabeth_Hyde  a              schema:Person ;
#         rdfs:label              "Elisabeth Hyde" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/34752384/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Elisabeth Hyde" .
#
# authors:Robert_McLiam_Wilson
#         a                          schema:Person ;
#         rdfs:label                 "Robert McLiam Wilson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_McLiam_Wilson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54258546/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert McLiam Wilson" .
#
# authors:Kathleen_Tyau  a               schema:Person ;
#         rdfs:label              "Kathleen Tyau" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/92661176/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kathleen Tyau" .
#
# authors:Tom_Wolfe  a                      schema:Person ;
#         rdfs:label                 "Tom Wolfe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tom_Wolfe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/119067502/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tom Wolfe" .
#
# authors:JK_Rowling  a                     schema:Person ;
#         rdfs:label                 "J.K. Rowling" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._K._Rowling.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/116796842/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J.K. Rowling" .
#
# authors:Richard_Wright  a                 schema:Person ;
#         rdfs:label                 "Richard Wright" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Wright_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34464524/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Wright" .
#
# authors:Daniel_Quinn  a                   schema:Person ;
#         rdfs:label                 "Daniel Quinn" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Daniel_Quinn.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79122177/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Daniel Quinn" .
#
# authors:Peter_Roget  a                    schema:Person ;
#         rdfs:label                 "Peter Mark Roget" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Mark_Roget.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2594700/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Mark Roget" .
#
# authors:Charlie_Smith  a                  schema:Person ;
#         rdfs:label                 "Charlie Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Smith_(playwright).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/48164791/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charlie Smith" .
#
# authors:Aldous_Huxley  a                  schema:Person ;
#         rdfs:label                 "Aldous Huxley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Aldous_Huxley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71392434/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Aldous Huxley" .
#
# authors:Ariel_Dorfman  a                  schema:Person ;
#         rdfs:label                 "Ariel Dorfman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ariel_Dorfman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95177323/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ariel Dorfman" .
#
# authors:Dave_Miller  a                 schema:Person ;
#         rdfs:label              "Dave Miller" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/35830302/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Dave Miller" .
#
# authors:Avery_Publishing  a               schema:Organization ;
#         rdfs:label                 "Avery Publishing Group" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Avery_Publishing.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/134443168/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Avery Publishing Group" .
#
# authors:Dick_Francis  a                   schema:Person ;
#         rdfs:label                 "Dick Francis" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dick_Francis.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24601518/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dick Francis" .
#
# authors:Thomas_Wharton  a                 schema:Person ;
#         rdfs:label                 "Thomas Wharton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_Wharton_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19845769/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas Wharton" .
#
# authors:Annie_Hawes  a                 schema:Person ;
#         rdfs:label              "Annie Hawes" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/55047625/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Annie Hawes" .
#
# authors:Flannery_OConnor  a               schema:Person ;
#         rdfs:label                 "Flannery O'Connor" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Flannery_O'Connor.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17227472/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Flannery O'Connor" .
#
# authors:Mitch_Albom  a                    schema:Person ;
#         rdfs:label                 "Mitch Albom" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mitch_Albom.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97615503/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mitch Albom" .
#
# authors:APA_Press  a       schema:Organization ;
#         rdfs:label  "APA Press" ;
#         foaf:name   "APA Press" .
#
# authors:Michael_G_Moore  a                schema:Person ;
#         rdfs:label                 "Michael G. Moore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_G._Moore.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/38526213/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael G. Moore" .
#
# authors:Zoe_Weil  a                    schema:Person ;
#         rdfs:label              "Zoe Weil" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/7104831/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Zoe Weil" .
#
# authors:JL_Bourne  a                   schema:Person ;
#         rdfs:label              "J. L. Bourne" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/120524338/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "J. L. Bourne" .
#
# authors:Helene_Tursten  a                 schema:Person ;
#         rdfs:label                 "Helene Tursten" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Helene_Tursten.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85604955/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Helene Tursten" .
#
# authors:Parker_Palmer  a                  schema:Person ;
#         rdfs:label                 "Parker J. Palmer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Parker_Palmer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/75127263/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Parker J. Palmer" .
#
# authors:Gabriel_Marquez  a                schema:Person ;
#         rdfs:label                 "Gabriel García Márquez" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Gabriel_Garc%C3%ADa_M%C3%A1rquez.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54147956/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gabriel García Márquez" .
#
# authors:Kathryn_Thompson  a            schema:Person ;
#         rdfs:label              "Kathryn Thompson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/19157467902722321722/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kathryn Thompson" .
#
# authors:Mark_Bowden  a                    schema:Person ;
#         rdfs:label                 "Mark Bowden" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mark_Bowden.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88081766/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mark Bowden" .
#
# authors:Mike_Birbiglia  a                 schema:Person ;
#         rdfs:label                 "Mike Birbiglia" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mike_Birbiglia.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/121054250/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mike Birbiglia" .
#
# authors:Michael_Pollan  a                 schema:Person ;
#         rdfs:label                 "Michael Pollan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Pollan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79485320/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Pollan" .
#
# authors:John_Straley  a                   schema:Person ;
#         rdfs:label                 "John Straley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Straley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32131643/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Straley" .
#
# authors:Gary_Taubes  a                    schema:Person ;
#         rdfs:label                 "Gary Taubes" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gary_Taubes.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/50676378/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Gary Taubes" .
#
# authors:Paula_McLain  a                   schema:Person ;
#         rdfs:label                 "Paula McLain" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paula_McLain.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34098388/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paula McLain" .
#
# authors:Brett_Helquist  a                 schema:Person ;
#         rdfs:label                 "Brett Helquist" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brett_Helquist.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71606179/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brett Helquist" .
#
# authors:Laurell_K_Hamilton  a             schema:Person ;
#         rdfs:label                 "Laurell K. Hamilton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Laurell_K._Hamilton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39520379/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Laurell K. Hamilton" .
#
# authors:MIT_Outing_Club  a             schema:Organization ;
#         rdfs:label              "MIT Outing Club" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/155114530/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "MIT Outing Club" .
#
# authors:Michael_Chabon  a                 schema:Person ;
#         rdfs:label                 "Michael Chabon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Chabon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49255278/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Chabon" .
#
# authors:Okakura_Kakuzo  a                 schema:Person ;
#         rdfs:label                 "Okakura Kakuzō" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Okakura_Kakuz%C5%8D.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/99830297/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Okakura Kakuzō" .
#
# authors:Jeffrey_Eugenides  a              schema:Person ;
#         rdfs:label                 "Jeffrey Eugenides" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jeffrey_Eugenides.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37015518/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jeffrey Eugenides" .
#
# authors:Gilbert_Shelton  a                schema:Person ;
#         rdfs:label                 "Gilbert Shelton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Gilbert_Shelton.ttl"^^xsd:anyURI ;
#         foaf:name                  "Gilbert Shelton" .
#
# authors:Sonja_Maria_Dahl  a  schema:Person ;
#         rdfs:label  "Sonja Maria Dahl" ;
#         foaf:name   "Sonja Maria Dahl" .
#
# authors:Cathleen_Schine  a                schema:Person ;
#         rdfs:label                 "Cathleen Schine" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Cathleen_Schine.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73995580/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Cathleen Schine" .
#
# authors:Andrea_Dodi  a                 schema:Person ;
#         rdfs:label              "Andrea Dodi" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/28328862/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Andrea Dodi" .
#
# authors:JRH_Andrews  a                 schema:Person ;
#         rdfs:label              "J. R. H. Andrews" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/32033380/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "J. R. H. Andrews" .
#
# authors:Lisa_Grunwald  a                  schema:Person ;
#         rdfs:label                 "Lisa Grunwald" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lisa_Grunwald.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/93194297/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lisa Grunwald" .
#
# authors:Paul_Bowles  a                    schema:Person ;
#         rdfs:label                 "Paul Bowles" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paul_Bowles.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112464042/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paul Bowles" .
#
# authors:Julia_Alvarez  a                  schema:Person ;
#         rdfs:label                 "Julia Alvarez" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Julia_Alvarez.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79102742/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Julia Alvarez" .
#
# authors:Michael_J_Fox  a                  schema:Person ;
#         rdfs:label                 "Michael J. Fox" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_J._Fox.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85083574/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael J. Fox" .
#
# authors:Herman_Melville  a                schema:Person ;
#         rdfs:label                 "Herman Melville" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Herman_Melville.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27068555/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Herman Melville" .
#
# authors:Jan_Kerouac  a                    schema:Person ;
#         rdfs:label                 "Jan Kerouac" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jan_Kerouac.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94316561/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jan Kerouac" .
#
# authors:Portia_de_Rossi  a                schema:Person ;
#         rdfs:label                 "Portia de Rossi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Portia_de_Rossi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/163822159/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Portia de Rossi" .
#
# authors:James_Wesley_Rawles  a            schema:Person ;
#         rdfs:label                 "James Wesley Rawles" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Wesley_Rawles.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41172116/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Wesley Rawles" .
#
# authors:Robert_Ludlum  a                  schema:Person ;
#         rdfs:label                 "Robert Ludlum" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Ludlum.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109373898/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Ludlum" .
#
# authors:Richard_Spellenberg  a         schema:Person ;
#         rdfs:label              "Richard Spellenberg" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/66537526/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Richard Spellenberg" .
#
# authors:Krystyna_Pomorska  a           schema:Person ;
#         rdfs:label              "Krystyna Pomorska" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/37335012/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Krystyna Pomorska" .
#
# authors:Katherine_Neville  a              schema:Person ;
#         rdfs:label                 "Katherine Neville" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Katherine_Neville_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112187557/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Katherine Neville" .
#
# authors:Laurel_Robertson  a            schema:Person ;
#         rdfs:label              "Laurel Robertson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/92470035/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Laurel Robertson" .
#
# authors:Benjamin_Hoff  a                  schema:Person ;
#         rdfs:label                 "Benjamin Hoff" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Benjamin_Hoff.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19803933/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Benjamin Hoff" .
#
# authors:Stephen_King  a                   schema:Person ;
#         rdfs:label                 "Stephen King" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_King.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97113511/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen King" .
#
# authors:Brewster_Ghiselin  a              schema:Person ;
#         rdfs:label                 "Brewster Ghiselin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brewster_Ghiselin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97844400/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brewster Ghiselin" .
#
# authors:Dan_Eldon  a                      schema:Person ;
#         rdfs:label                 "Dan Eldon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_Eldon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/25453480/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan Eldon" .
#
# authors:Ralph_Waldo_Emerson  a            schema:Person ;
#         rdfs:label                 "Ralph Waldo Emerson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ralph_Waldo_Emerson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27079964/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ralph Waldo Emerson" .
#
# authors:Plato  a                          schema:Person ;
#         rdfs:label                 "Plato" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philippa_Gregory.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/303814984/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Plato" .
#
# authors:Michael_Ondaatje  a               schema:Person ;
#         rdfs:label                 "Michael Ondaatje" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Ondaatje.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111941870/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Ondaatje" .
#
# authors:Dave_Eddings  a                   schema:Person ;
#         rdfs:label                 "Dave Eddings" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dave_Eddings.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56593673/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dave Eddings" .
#
# authors:CH_Dalton  a                      schema:Person ;
#         rdfs:label                 "C.H. Dalton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sam_Means.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73305583/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Sam Means" ;
#         foaf:name                  "C.H. Dalton" .
#
# authors:Jason_Pargin  a                   schema:Person ;
#         rdfs:label                 "Jason Pargin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jason_Pargin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88378977/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "David Wong" ;
#         foaf:name                  "Jason Pargin" .
#
# authors:Lev_Grossman  a                   schema:Person ;
#         rdfs:label                 "Lev Grossman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Lev_Grossman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/15904503/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Lev Grossman" .
#
# authors:CG_Jung  a                        schema:Person ;
#         rdfs:label                 "C.G. Jung" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carl_Jung.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88819182/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Carl Jung" ;
#         foaf:name                  "C.G. Jung" .
#
# authors:Edith_Wharton  a                  schema:Person ;
#         rdfs:label                 "Edith Wharton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edith_Wharton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17230986/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edith Wharton" .
#
# authors:Bradley_Denton  a                 schema:Person ;
#         rdfs:label                 "Bradley Denton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bradley_Denton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/106955890/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bradley Denton" .
#
# authors:Stephen_Mitchell  a               schema:Person ;
#         rdfs:label                 "Stephen Mitchell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Mitchell_(translator).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22283107/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Mitchell" .
#
# authors:Dan_Homeres  a     schema:Person ;
#         rdfs:label  "Dan Homeres" ;
#         foaf:name   "Dan Homeres" .
#
# authors:Jeff_Sharlet  a                   schema:Person ;
#         rdfs:label                 "Jeff Sharlet" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jeff_Sharlet_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/48610858/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jeff Sharlet" .
#
# authors:Shunto_Aoyama  a               schema:Person ;
#         rdfs:label              "Shuntō Aoyama" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/66633701/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Shuntō Aoyama" .
#
# authors:Carl_Elliot  a                 schema:Person ;
#         rdfs:label              "Carl Elliot" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/75631435/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Carl Elliot" .
#
# authors:Jeannette_Walls  a                schema:Person ;
#         rdfs:label                 "Jeannette Walls" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jeannette_Walls.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/33089798/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jeannette Walls" .
#
# authors:Jonathan_Raban  a                 schema:Person ;
#         rdfs:label                 "Jonathan Raban" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jonathan_Raban.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66503699/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jonathan Raban" .
#
# authors:Margaret_Atwood  a                schema:Person ;
#         rdfs:label                 "Margaret Atwood" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Margaret_Atwood.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109322990/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Margaret Atwood" .
#
# authors:Christopher_Hitchens
#         a                          schema:Person ;
#         rdfs:label                 "Christopher Hitchens" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Christopher_Hitchens.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/98819926/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Christopher Hitchens" .
#
# authors:Bryan_Thomas  a                schema:Person ;
#         rdfs:label              "Bryan Thomas" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/276664257/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Bryan Thomas" .
#
# authors:James_McBride  a                  schema:Person ;
#         rdfs:label                 "James McBride" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_McBride_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/116053682/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James McBride" .
#
# authors:Elizabeth_Arthur  a            schema:Person ;
#         rdfs:label              "Elizabeth Arthur" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/34587746/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Elizabeth Arthur" .
#
# authors:Philip_Kerr  a                    schema:Person ;
#         rdfs:label                 "Philip Kerr" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philip_Kerr.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24671640/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philip Kerr" .
#
# authors:Peter_Mayle  a                    schema:Person ;
#         rdfs:label                 "Peter Mayle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Mayle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44302507/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Mayle" .
#
# authors:Keith_Richards  a                 schema:Person ;
#         rdfs:label                 "Keith Richards" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Keith_Richards.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59270715/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Keith Richards" .
#
# authors:Mary_Oliver  a                    schema:Person ;
#         rdfs:label                 "Mary Oliver" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mary_Oliver.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92313202/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mary Oliver" .
#
# authors:Eoin_Colfer  a                    schema:Person ;
#         rdfs:label                 "Eoin Colfer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Eoin_Colfer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/69145969/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Eoin Colfer" .
#
# authors:Nora_Roberts  a                   schema:Person ;
#         rdfs:label                 "Nora Roberts" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Nora_Roberts.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66448023/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "J.D. Robb" ;
#         foaf:name                  "Nora Roberts" .
#
# authors:Eric_Clapton  a                   schema:Person ;
#         rdfs:label                 "Eric Clapton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Eric_Clapton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/46945873/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Eric Clapton" .
#
# authors:Irma_Rombauer  a                  schema:Person ;
#         rdfs:label                 "Irma S. Rombauer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Irma_S._Rombauer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/35702310/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Irma S. Rombauer" .
#
# authors:David_Case  a                  schema:Person ;
#         rdfs:label              "David Owen Case" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/76541661/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "David Owen Case" .
#
# authors:Royal_Robbins  a                  schema:Person ;
#         rdfs:label                 "Royal Robbins" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Royal_Robbins.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79431312/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Royal Robbins" .
#
# authors:Thomas_Connolly  a             schema:Person ;
#         rdfs:label              "Thomas M. Connolly" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/55060755/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Thomas M. Connolly" .
#
# authors:Emmett_Grogan  a                  schema:Person ;
#         rdfs:label                 "Emmett Grogan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Emmett_Grogan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/6516238/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Emmett Grogan" .
#
# authors:Rotraud_Michael-Degner
#         a                       schema:Person ;
#         rdfs:label              "Rotraud Michael-Degner" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/505858/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Rotraud Michael-Degner‏" .
#
# authors:John_Wiessinger  a             schema:Person ;
#         rdfs:label              "John Wiessinger" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/40901161/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "John Wiessinger" .
#
# authors:Frederic_Sonnenschmidt
#         a                       schema:Person ;
#         rdfs:label              "Frederic H. Sonnenschmidt" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/24577465/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Frederic H. Sonnenschmidt" .
#
# authors:Charles_Frazier  a                schema:Person ;
#         rdfs:label                 "Charles Frazier" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Frazier.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84114568/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Frazier" .
#
# authors:Leigh_Riker  a                 schema:Person ;
#         rdfs:label              "Leigh Riker" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/58453584/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Leigh Riker" .
#
# authors:John_Saul  a                      schema:Person ;
#         rdfs:label                 "John Saul" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Saul.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100257906/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Saul" .
#
# authors:Robert_Leckie  a                  schema:Person ;
#         rdfs:label                 "Robert Leckie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Leckie_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/38162728/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Leckie" .
#
# authors:Christopher_Paolini  a            schema:Person ;
#         rdfs:label                 "Christopher Paolini" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Christopher_Paolini.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49468743/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Christopher Paolini" .
#
# authors:Charles_Scribner_Sons
#         a                          schema:Person ;
#         rdfs:label                 "Charles Scribner's Sons" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Charles_Scribner's_Sons.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/121555288/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Charles Scribner's Sons" .
#
# authors:Urban_Waite  a                 schema:Person ;
#         rdfs:label              "Urban Waite" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/26777817/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Urban Waite" .
#
# authors:Goldberry_Long  a              schema:Person ;
#         rdfs:label              "Goldberry Long" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/8235161211543640070008/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Goldberry Long" .
#
# authors:Mike_DOrso  a                     schema:Person ;
#         rdfs:label                 "Mike D'Orso" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mike_D'Orso.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84626415/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mike D'Orso" .
#
# authors:Ken_Follett  a                    schema:Person ;
#         rdfs:label                 "Ken Follett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ken_Follett.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64005683/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ken Follett" .
#
# authors:Brent_Weeks  a                    schema:Person ;
#         rdfs:label                 "Brent Weeks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brent_Weeks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/103339594/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brent Weeks" .
#
# authors:Douglas_Adams  a                  schema:Person ;
#         rdfs:label                 "Douglas Adams" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Douglas_Adams.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113230702/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Douglas Adams" .
#
# authors:Marjorie_Winn_Ford  a          schema:Person ;
#         rdfs:label              "Marjorie Winn Ford" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/31624085/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Marjorie Winn Ford" .
#
# authors:TA_Layton  a                   schema:Person ;
#         rdfs:label              "T.A. Layton" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/110250509/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "T.A. Layton" .
#
# authors:Madhur_Jaffrey  a                 schema:Person ;
#         rdfs:label                 "Madhur Jaffrey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Madhur_Jaffrey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/119620635/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Madhur Jaffrey" .
#
# authors:Albert_Camus  a                   schema:Person ;
#         rdfs:label                 "Albert Camus" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Albert_Camus.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/97000332/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Albert Camus" .
#
# authors:John_Dufresne  a                  schema:Person ;
#         rdfs:label                 "John Dufresne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Dufresne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/16387181/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Dufresne" .
#
# authors:Jane_McGonigal  a                 schema:Person ;
#         rdfs:label                 "Jane McGonigal" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jane_McGonigal.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/135109690/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jane McGonigal" .
#
# authors:James_Ensor  a                    schema:Person ;
#         rdfs:label                 "James Ensor" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Ensor.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/88625859/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Ensor" .
#
# authors:Dashka_Slater  a               schema:Person ;
#         rdfs:label              "Dashka Slater" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/9175113/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Dashka Slater" .
#
# authors:Hannah_Hinchman  a             schema:Person ;
#         rdfs:label              "Hannah Hinchman" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/60630811/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Hannah Hinchman" .
#
# authors:Hal_Leonard_Corp  a               schema:Person ;
#         rdfs:label                 "Hal Leonard Corporation" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hal_Leonard_LLC.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/168111519/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hal Leonard Corporation" .
#
# authors:Jim_DuFresne  a                schema:Person ;
#         rdfs:label              "Jim DuFresne" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/72004414/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jim DuFresne" .
#
# authors:SE_Hinton  a                      schema:Person ;
#         rdfs:label                 "S. E. Hinton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/S._E._Hinton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39583594/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "S. E. Hinton" .
#
# authors:April_Sinclair  a              schema:Person ;
#         rdfs:label              "April Sinclair" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/69650371/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "April Sinclair" .
#
# authors:Paul_Auster  a                    schema:Person ;
#         rdfs:label                 "Paul Auster" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paul_Auster.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110344312/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paul Auster" .
#
# authors:John_Lescroart  a                 schema:Person ;
#         rdfs:label                 "John Lescroart" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Lescroart.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64797966/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Lescroart" .
#
# authors:Agatha_Christie  a                schema:Person ;
#         rdfs:label                 "Agatha Christie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Agatha_Christie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71388952/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Agatha Christie" .
#
# authors:Manju_Singh  a                 schema:Person ;
#         rdfs:label              "Manju Shivraj Singh" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/13628160/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Manju Shivraj Singh" .
#
# authors:Amy_Tan  a                        schema:Person ;
#         rdfs:label                 "Amy Tan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Amy_Tan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110768273/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Amy Tan" .
#
# authors:James_Major  a                 schema:Person ;
#         rdfs:label              "James Major" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/4347379/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "James Major" .
#
# authors:Philip_Kapleau  a                 schema:Person ;
#         rdfs:label                 "Philip Kapleau" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philip_Kapleau.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79078238/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philip Kapleau" .
#
# authors:Alan_Davidson  a                  schema:Person ;
#         rdfs:label                 "Alan Davidson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alan_Davidson_(food_writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32006996/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alan Davidson" .
#
# authors:Time_Life_Books  a                schema:Person ;
#         rdfs:label                 "Time-Life Books" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Time_Life.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/210641501/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Time-Life Books" .
#
# authors:Peter_Benchley  a                 schema:Person ;
#         rdfs:label                 "Peter Benchley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Peter_Benchley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/111878649/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Peter Benchley" .
#
# authors:Carlos_Castaneda  a               schema:Person ;
#         rdfs:label                 "Carlos Castaneda" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Carlos_Castaneda.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100254667/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Carlos Castaneda" .
#
# authors:Toni_Morrison  a                  schema:Person ;
#         rdfs:label                 "Toni Morrison" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Toni_Morrison.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109406177/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Toni Morrison" .
#
# authors:Tina_McElroy_Ansa  a              schema:Person ;
#         rdfs:label                 "Tina McElroy Ansa" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tina_McElroy_Ansa.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52387993/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tina McElroy Ansa" .
#
# authors:Tony_Wheeler  a                   schema:Person ;
#         rdfs:label                 "Tony Wheeler" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tony_Wheeler.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95315509/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tony Wheeler" .
#
# authors:P_Statford  a      schema:Person ;
#         rdfs:label  "P. Statford" ;
#         foaf:name   "P. Statford" .
#
# authors:Susanna_Moore  a                  schema:Person ;
#         rdfs:label                 "Susanna Moore" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Susanna_Moore.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109902730/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Susanna Moore" .
#
# authors:Khaled_Hosseini  a                schema:Person ;
#         rdfs:label                 "Khaled Hosseini" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Khaled_Hosseini.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/98912036/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Khaled Hosseini" .
#
# authors:Cormac_McCarthy  a                schema:Person ;
#         rdfs:label                 "Cormac McCarthy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Cormac_McCarthy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29558386/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Cormac McCarthy" .
#
# authors:Frank_Herbert  a                  schema:Person ;
#         rdfs:label                 "Frank Herbert" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Frank_Herbert.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59083797/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frank Herbert" .
#
# authors:Wayne_Johnson  a               schema:Person ;
#         rdfs:label              "Wayne Johnson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/17276021/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Wayne Johnson" .
#
# authors:Bruno_Nettl  a                    schema:Person ;
#         rdfs:label                 "Bruno Nettl" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bruno_Nettl.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34488203/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bruno Nettl" .
#
# authors:Robert_A_Heinlein  a              schema:Person ;
#         rdfs:label                 "Robert A. Heinlein" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_A._Heinlein.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12309757/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert A. Heinlein" .
#
# authors:Paul_Reps  a                      schema:Person ;
#         rdfs:label                 "Paul Reps" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paul_Reps.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/34462122/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paul Reps" .
#
# authors:Hilary_Mantel  a                  schema:Person ;
#         rdfs:label                 "Hilary Mantel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hilary_Mantel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44415775/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hilary Mantel" .
#
# authors:Brian_Coffey  a                   schema:Person ;
#         rdfs:label                 "Brian Coffey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brian_Coffey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/22360530/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "Dean Koontz" ;
#         foaf:name                  "Brian Coffey" .
#
# authors:Daniel_Defoe  a                   schema:Person ;
#         rdfs:label                 "Daniel Defoe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Daniel_Defoe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/39375774/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Daniel Defoe" .
#
# authors:Jerry_Coker  a                    schema:Person ;
#         rdfs:label                 "Jerry Coker" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jerry_Coker.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/52426658/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jerry Coker" .
#
# authors:AJ_Jacobs  a                      schema:Person ;
#         rdfs:label                 "A.J. Jacobs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/A._J._Jacobs.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/15101819/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "A.J. Jacobs" .
#
# authors:Philip_Pratt  a                schema:Person ;
#         rdfs:label              "Philip J. Pratt" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/17404904/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Philip J. Pratt" .
#
# authors:David_Sibley  a                   schema:Person ;
#         rdfs:label                 "David Sibley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Allen_Sibley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27398912/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Sibley" .
#
# authors:ATI    a           schema:Organization ;
#         rdfs:label  "American Training International" ;
#         foaf:name   "American Training International" .
#
# authors:Bill_Watterson  a                 schema:Person ;
#         rdfs:label                 "Bill Watterson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bill_Watterson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73875998/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bill Watterson" .
#
# authors:George_W_Bush  a                  schema:Person ;
#         rdfs:label                 "George W. Bush" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_W._Bush.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/71559485/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George W. Bush" .
#
# authors:Homer  a                          schema:Person ;
#         rdfs:label                 "Homer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Homer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/224924963/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Homer" .
#
# authors:Theodore_Dreiser  a               schema:Person ;
#         rdfs:label                 "Theodore Dreiser" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Theodore_Dreiser.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4944366/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Theodore Dreiser" .
#
# authors:Marion_Rombauer_Becker
#         a                       schema:Person ;
#         rdfs:label              "Marion Rombauer Becker" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/91251106/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Marion Rombauer Becker" .
#
# authors:David_Smith_Ferri  a           schema:Person ;
#         rdfs:label              "David Smith-Ferri" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/68362669/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "David Smith-Ferri" .
#
# authors:David_Cross  a                    schema:Person ;
#         rdfs:label                 "David Cross" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Cross.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100247205/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Cross" .
#
# authors:Barry_Lopez  a                    schema:Person ;
#         rdfs:label                 "Barry Lopez" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Barry_Lopez.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/31207/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Barry Lopez" .
#
# authors:Eric_Schlosser  a                 schema:Person ;
#         rdfs:label                 "Eric Schlosser" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Eric_Schlosser.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56834947/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Eric Schlosser" .
#
# authors:Pearl_Luke  a                     schema:Person ;
#         rdfs:label                 "Pearl Luke" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Pearl_Luke.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/11076258/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Pearl Luke" .
#
# authors:Jeff_Smith  a                     schema:Person ;
#         rdfs:label                 "Jeff Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jeff_Smith_(chef).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/48620269/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jeff Smith" .
#
# authors:Robert_Gagne  a                   schema:Person ;
#         rdfs:label                 "Robert M. Gagné" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_M._Gagn%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59916732/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert M. Gagné" .
#
# authors:Bjorn_Kjellstrom  a               schema:Person ;
#         rdfs:label                 "Björn Kjellström" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bj%C3%B6rn_Kjellstr%C3%B6m.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/17193500/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Björn Kjellström" .
#
# authors:Jingxiong_Wu  a                schema:Person ;
#         rdfs:label              "Jingxiong Wu" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/50022349/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jingxiong Wu" .
#
# authors:George_Carlin  a                  schema:Person ;
#         rdfs:label                 "George Carlin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_Carlin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61755718/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George Carlin" .
#
# authors:PJ_ORourke  a                     schema:Person ;
#         rdfs:label                 "P.J. O'Rourke" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/P._J._O'Rourke.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/220813267/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "P.J. O'Rourke" .
#
# authors:Moosewood_Collective
#         a                       schema:Organization ;
#         rdfs:label              "Moosewood Collective" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/125587908/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Moosewood Collective" .
#
# authors:Relix_Magazine  a                 schema:Organization ;
#         rdfs:label                 "Relix Magazine" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Relix.ttl"^^xsd:anyURI ;
#         foaf:name                  "Relix Magazine" .
#
# authors:Troy_Soos  a                      schema:Person ;
#         rdfs:label                 "Troy Soos" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Troy_Soos.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4175916/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Troy Soos" .
#
# authors:Steven_Levitt  a                  schema:Person ;
#         rdfs:label                 "Steven Levitt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Steven_Levitt.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61833919/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Steven Levitt" .
#
# authors:Niccolo_Machiavelli  a            schema:Person ;
#         rdfs:label                 "Niccolò Machiavelli" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Niccol%C3%B2_Machiavelli.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95151646/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Niccolò Machiavelli" .
#
# authors:Toyoaki_Kawai  a               schema:Person ;
#         rdfs:label              "Toyoaki Kawai" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/110968907/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Toyoaki Kawai" .
#
# authors:Rick_Riordan  a                   schema:Person ;
#         rdfs:label                 "Rick Riordan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rick_Riordan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/60214017/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rick Riordan" .
#
# authors:William_S_Burroughs  a            schema:Person ;
#         rdfs:label                 "William S. Burroughs" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_S._Burroughs.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108916275/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William S. Burroughs" .
#
# authors:Philippa_Gregory  a               schema:Person ;
#         rdfs:label                 "Philippa Gregory" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philippa_Gregory.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19698456/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philippa Gregory" .
#
# authors:John_Stephenson  a             schema:Person ;
#         rdfs:label              "John Stephenson" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/158555642/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "John Stephenson" .
#
# authors:Gorham_Kindem  a               schema:Person ;
#         rdfs:label              "Gorham Kindem" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/79164430/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Gorham Kindem" .
#
# authors:Kathy_Eldon  a                 schema:Person ;
#         rdfs:label              "Kathy Eldon" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/236702507/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Kathy Eldon" .
#
# authors:Sun_Tzu  a                        schema:Person ;
#         rdfs:label                 "Sun Tzu" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sun_Tzu.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/200741950/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sun Tzu" .
#
# authors:Sue_Grafton  a                    schema:Person ;
#         rdfs:label                 "Sue Grafton" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Sue_Grafton.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/113386374/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Sue Grafton" .
#
# authors:Henning_Mankell  a                schema:Person ;
#         rdfs:label                 "Henning Mankell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Henning_Mankell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84944859/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Henning Mankell" .
#
# authors:Malcolm_Cowley  a                 schema:Person ;
#         rdfs:label                 "Malcolm Cowley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Malcolm_Cowley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/91308069/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Malcolm Cowley" .
#
# authors:Kenneth_Brower  a                 schema:Person ;
#         rdfs:label                 "Kenneth Brower" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kenneth_Brower.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/25272166/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kenneth Brower" .
#
# authors:Seamus_Heaney  a                  schema:Person ;
#         rdfs:label                 "Seamus Heaney" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Seamus_Heaney.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/109557338/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Seamus Heaney" .
#
# authors:Robert_McCammon  a                schema:Person ;
#         rdfs:label                 "Robert R. McCammon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_R._McCammon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79535858/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert R. McCammon" .
#
# authors:Ossian_Publications  a         schema:Organization ;
#         rdfs:label              "Ossian Publications" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/315674518/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ossian Publications" .
#
# authors:Mel_Bay  a                        schema:Person ;
#         rdfs:label                 "Mel Bay" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mel_Bay.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/64188423/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mel Bay" .
#
# authors:Louisa_May_Alcott  a              schema:Person ;
#         rdfs:label                 "Louisa May Alcott" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Louisa_May_Alcott.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29528997/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Louisa May Alcott" .
#
# authors:George_Pelecanos  a               schema:Person ;
#         rdfs:label                 "George Pelecanos" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_Pelecanos.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85313037/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George Pelecanos" .
#
# authors:Joe_Coomer  a                     schema:Person ;
#         rdfs:label                 "Joe Coomer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joe_Coomer_(author).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/18063386/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joe Coomer" .
#
# authors:Jonathan_Franzen  a               schema:Person ;
#         rdfs:label                 "Jonathan Franzen" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jonathan_Franzen.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84489381/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jonathan Franzen" .
#
# authors:L_Frank_Baum  a                   schema:Person ;
#         rdfs:label                 "L. Frank Baum" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/L._Frank_Baum.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/4926394/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "L. Frank Baum" .
#
# authors:Isaac_Asimov  a                   schema:Person ;
#         rdfs:label                 "Isaac Asimov" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Isaac_Asimov.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/24597135/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Isaac Asimov" .
#
# authors:EE_Cummings  a                    schema:Person ;
#         rdfs:label                 "E. E. Cummings" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/E._E._Cummings.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12306931/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "E. E. Cummings" .
#
# authors:Fyodor_Dostoevsky  a              schema:Person ;
#         rdfs:label                 "Fyodor Dostoevsky" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Fyodor_Dostoyevsky.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/104023256/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Fyodor Dostoevsky" .
#
# authors:Fitness_Swimmer  a  schema:Organization ;
#         rdfs:label  "Fitness Swimmer" ;
#         foaf:name   "Fitness Swimmer" .
#
# authors:Julee_Rosso  a                    schema:Person ;
#         rdfs:label                 "Julee Rosso" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Julee_Rosso.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/94898963/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Julee Rosso" .
#
# authors:Bob_Woodward  a                   schema:Person ;
#         rdfs:label                 "Bob Woodward" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Bob_Woodward.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/2478438/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Bob Woodward" .
#
# authors:Arundhati_Roy  a                  schema:Person ;
#         rdfs:label                 "Arundhati Roy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Arundhati_Roy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76457869/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Arundhati Roy" .
#
# authors:Andre_Dubus  a                    schema:Person ;
#         rdfs:label                 "Andre Dubus" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Andre_Dubus.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110787061/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Andre Dubus" .
#
# authors:Tom_Clancy  a                     schema:Person ;
#         rdfs:label                 "Tom Clancy" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tom_Clancy.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108842694/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tom Clancy" .
#
# authors:Mary_Monroe  a                    schema:Person ;
#         rdfs:label                 "Mary Monroe" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Mary_Monroe.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/45716717/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Mary Monroe" .
#
# authors:Henry_Miller  a                   schema:Person ;
#         rdfs:label                 "Henry Miller" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Henry_Miller.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59086729/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Henry Miller" .
#
# authors:Ozzy_Osbourne  a                  schema:Person ;
#         rdfs:label                 "Ozzy Osbourne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ozzy_Osbourne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84207881/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ozzy Osbourne" .
#
# authors:Otto_Werner  a                 schema:Person ;
#         rdfs:label              "Otto Werner" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/107594358/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Otto Werner" .
#
# authors:Edwidge_Danticat  a               schema:Person ;
#         rdfs:label                 "Edwidge Danticat" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edwidge_Danticat.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/32104515/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edwidge Danticat" .
#
# authors:Richard_Morgan  a                 schema:Person ;
#         rdfs:label                 "Richard Morgan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_K._Morgan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102483092/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Morgan" .
#
# authors:Chogyam_Trungpa  a                schema:Person ;
#         rdfs:label                 "Chögyam Trungpa" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ch%C3%B6gyam_Trungpa.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95161934/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chögyam Trungpa" .
#
# authors:Noah_Lukeman  a                   schema:Person ;
#         rdfs:label                 "Noah Lukeman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Noah_Lukeman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/28219607/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Noah Lukeman" .
#
# authors:James_Fenimore_Cooper
#         a                          schema:Person ;
#         rdfs:label                 "James Fenimore Cooper" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Fenimore_Cooper.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27062769/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Fenimore Cooper" .
#
# authors:Anita_Diamant  a                  schema:Person ;
#         rdfs:label                 "Anita Diamant" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Anita_Diamant.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/67392674/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Anita Diamant" .
#
# authors:J_Robert_Lennon  a                schema:Person ;
#         rdfs:label                 "J. Robert Lennon" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/J._Robert_Lennon.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79194062/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "J. Robert Lennon" .
#
# authors:Jose_Saramago  a                  schema:Person ;
#         rdfs:label                 "José Saramago" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Jos%C3%A9_Saramago.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/114473675/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "José Saramago" .
#
# authors:Brian_Lumley  a                   schema:Person ;
#         rdfs:label                 "Brian Lumley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Brian_Lumley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110619283/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Brian Lumley" .
#
# authors:David_Wallace  a                  schema:Person ;
#         rdfs:label                 "David Foster Wallace" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/David_Foster_Wallace.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68975157/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "David Foster Wallace" .
#
# authors:Kim_Harrison  a                   schema:Person ;
#         rdfs:label                 "Kim Harrison" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kim_Harrison.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/67626664/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kim Harrison" .
#
# authors:Dan_Brown  a                      schema:Person ;
#         rdfs:label                 "Dan Brown" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Dan_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102403515/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Dan Brown" .
#
# authors:Rob_Van_der_Plas  a            schema:Person ;
#         rdfs:label              "Rob Van der Plas" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/30274975/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Rob Van der Plas" .
#
# authors:Donald_Rumsfeld  a                schema:Person ;
#         rdfs:label                 "Donald Rumsfeld" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Donald_Rumsfeld.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/41974687/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Donald Rumsfeld" .
#
# authors:Jim_Carroll  a                    schema:Person ;
#         rdfs:label                 "Jim Carroll" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jim_Carroll.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/14783289/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jim Carroll" .
#
# authors:Esther_Grassian  a             schema:Person ;
#         rdfs:label              "Esther S. Grassian" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/1516256/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Esther S. Grassian" .
#
# authors:Rachel_Cusk  a                    schema:Person ;
#         rdfs:label                 "Rachel Cusk" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rachel_Cusk.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/318745/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rachel Cusk" .
#
# authors:Darby_Conley  a                   schema:Person ;
#         rdfs:label                 "Darby Conley" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Darby_Conley.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79481736/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Darby Conley" .
#
# authors:Kwadwo_Agymah_Kamau  a            schema:Person ;
#         rdfs:label                 "Kwadwo Agymah Kamau" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Agymah_Kamau.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/92719150/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kwadwo Agymah Kamau" .
#
# authors:Isabel_Allende  a                 schema:Person ;
#         rdfs:label                 "Isabel Allende" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Isabel_Allende.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61556825/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Isabel Allende" .
#
# authors:Johnny_Cash  a                    schema:Person ;
#         rdfs:label                 "Johnny Cash" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Johnny_Cash.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27251336/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Johnny Cash" .
#
# authors:Seth_Grahame_Smith  a             schema:Person ;
#         rdfs:label                 "Seth Grahame-Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Seth_Grahame-Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102429602/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Seth Grahame-Smith" .
#
# authors:Phil_Baguley  a                schema:Person ;
#         rdfs:label              "Phil Baguley" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/4148923/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Phil Baguley" .
#
# authors:Bryan_Smith  a                 schema:Person ;
#         rdfs:label              "Bryan Smith" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/300766071/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Bryan Smith" .
#
# authors:Robert_Michael_Pyle  a            schema:Person ;
#         rdfs:label                 "Robert Michael Pyle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robert_Michael_Pyle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19786367/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robert Michael Pyle" .
#
# authors:Olivia_Munn  a                    schema:Person ;
#         rdfs:label                 "Olivia Munn" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Olivia_Munn.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/264176120/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Olivia Munn" .
#
# authors:Ivan_Doig  a                      schema:Person ;
#         rdfs:label                 "Ivan Doig" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ivan_Doig.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79340625/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ivan Doig" .
#
# authors:Joseph_Conrad  a                  schema:Person ;
#         rdfs:label                 "Joseph Conrad" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Joseph_Conrad.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/73862853/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Joseph Conrad" .
#
# authors:David_Stanley  a               schema:Person ;
#         rdfs:label              "David Stanley" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/95326516/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "David Stanley" .
#
# authors:Richard_Bach  a                   schema:Person ;
#         rdfs:label                 "Richard Bach" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Bach.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/110244457/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Bach" .
#
# authors:PD_James  a                       schema:Person ;
#         rdfs:label                 "P. D. James" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/P._D._James.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101752435/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "P. D. James" .
#
# authors:William_Leavitt  a                schema:Person ;
#         rdfs:label                 "William G. Leavitt" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/William_Leavitt_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87434122/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "William G. Leavitt" .
#
# authors:Ruth_Winter  a                 schema:Person ;
#         rdfs:label              "Ruth Winter" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/36925906/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Ruth Winter" .
#
# authors:Irvine_Welsh  a                   schema:Person ;
#         rdfs:label                 "Irvine Welsh" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Irvine_Welsh.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/101956084/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Irvine Welsh" .
#
# authors:Malcolm_Gladwell  a               schema:Person ;
#         rdfs:label                 "Malcolm Gladwell" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Malcolm_Gladwell.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/25481798/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Malcolm Gladwell" .
#
# authors:Michio_Kaku  a                    schema:Person ;
#         rdfs:label                 "Michio Kaku" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michio_Kaku.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/87662844/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michio Kaku" .
#
# authors:Chris_Duff  a                     schema:Person ;
#         rdfs:label                 "Chris Duff" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Chris_Duff.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9175885/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Chris Duff" .
#
# authors:Friedrick_Nietzsche  a            schema:Person ;
#         rdfs:label                 "Friedrick Nietzsche" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Friedrich_Nietzsche.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/89798474/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Friedrick Nietzsche" .
#
# authors:Pablo_Neruda  a                   schema:Person ;
#         rdfs:label                 "Pablo Neruda" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Pablo_Neruda.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36976332/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Pablo Naruda" .
#
# authors:Matteo_Carcassi  a                schema:Person ;
#         rdfs:label                 "Matteo Carcassi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Matteo_Carcassi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/74116223/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Matteo Carcassi" .
#
# authors:Leslie_Esdaile_Banks
#         a                          schema:Person ;
#         rdfs:label                 "Leslie Esdaile Banks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Leslie_Esdaile_Banks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/170342143/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "L. A. Banks" ;
#         foaf:name                  "Leslie Esdaile Banks" .
#
# authors:Michael_Dorris  a                 schema:Person ;
#         rdfs:label                 "Michael Dorris" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Michael_Dorris.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/76330722/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Michael Dorris" .
#
# authors:Maxwell_Eden  a                schema:Person ;
#         rdfs:label              "Maxwell Eden" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/279280825/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Maxwell Eden" .
#
# authors:Tom_Perrotta  a                   schema:Person ;
#         rdfs:label                 "Tom Perrotta" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Tom_Perrotta.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/37124181/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Tom Perrotta" .
#
# authors:Henry_David_Thoreau  a            schema:Person ;
#         rdfs:label                 "Henry David Thoreau" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Henry_David_Thoreau.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/68936476/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Henry David Thoreau" .
#
# authors:Thomas_McGuane  a                 schema:Person ;
#         rdfs:label                 "Thomas McGuane" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Thomas_McGuane.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79030467/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Thomas McGuane" .
#
# authors:Vladimir_Nabokov  a               schema:Person ;
#         rdfs:label                 "Vladimir Nabokov" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Vladimir_Nabokov.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/27069388/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Vladimir Nabokov" .
#
# authors:James_Joyce  a                    schema:Person ;
#         rdfs:label                 "James Joyce" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/James_Joyce.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/44300643/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "James Joyce" .
#
# authors:Garrsion_Keillor  a               schema:Person ;
#         rdfs:label                 "Garrsion Keillor" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Garrison_Keillor.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79812213/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Garrsion Keillor" .
#
# authors:Patti_Smith  a                    schema:Person ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Patti_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/84037206/rdf.xml"^^xsd:anyURI ;
#         owl:sameAs                 SoloMusicArtist:Patti_Smith ;
#         foaf:name                  "Patti Smith" .
#
# authors:Kerstin_Ekman  a                  schema:Person ;
#         rdfs:label                 "Kerstin Ekman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Kerstin_Ekman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/114547100/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Kerstin Ekman" .
#
# authors:Francis_ONeill  a                 schema:Person ;
#         rdfs:label                 "Francis O'Neill" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Francis_O'Neill.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19988319/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Francis O'Neill" .
#
# authors:Frances_Moore_Lappe  a            schema:Person ;
#         rdfs:label                 "Frances Moore Lappé" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Frances_Moore_Lapp%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/67022690/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Frances Moore Lappé" .
#
# authors:Hugh_Laurie  a                    schema:Person ;
#         rdfs:label                 "Hugh Laurie" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Hugh_Laurie.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/79174873/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Hugh Laurie" .
#
# authors:Philip_Pullman  a                 schema:Person ;
#         rdfs:label                 "Philip Pullman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Philip_Pullman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/115199438/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Philip Pullman" .
#
# authors:Jessica_Bird  a                   schema:Person ;
#         rdfs:label                 "Jessica Bird" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jessica_Bird.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/158791569/rdf.xml"^^xsd:anyURI ;
#         skos:altLabel              "J.R. Ward" ;
#         foaf:name                  "Jessica Bird" .
#
# authors:Craig_Claiborne  a                schema:Person ;
#         rdfs:label                 "Craig Claiborne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Craig_Claiborne.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/49744429/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Craig Claiborne" .
#
# authors:Danny_Elfman  a                   schema:Person ;
#         rdfs:label                 "Danny Elfman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Danny_Elfman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12496007/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Danny Elfman" .
#
# authors:Joni_Rodgers  a                schema:Person ;
#         rdfs:label              "Joni Rodgers" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/8322430/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Joni Rodgers" .
#
# authors:Ken_Kesey  a                      schema:Person ;
#         rdfs:label                 "Ken Kesey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ken_Kesey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/108853111/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ken Kesey" .
#
# authors:Zora_Neale_Hurston  a             schema:Person ;
#         rdfs:label                 "Zora Neale Hurston" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Zora_Neale_Hurston.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/62824341/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Zora Neale Hurston" .
#
# authors:Per_Amann  a                   schema:Person ;
#         rdfs:label              "Per Amann" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/32574263/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Per Amann" .
#
# authors:John_Klemmer  a                   schema:Person ;
#         rdfs:label                 "John Klemmer" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Klemmer.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/59269987/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Klemmer" .
#
# authors:Alice_Hoffman  a                  schema:Person ;
#         rdfs:label                 "Alice Hoffman" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alice_Hoffman.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/85550312/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alice Hoffman" .
#
# authors:Henry_James  a                    schema:Person ;
#         rdfs:label                 "Henry James" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Henry_James.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/36920030/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Henry James" .
#
# authors:Jonathan_Cott  a               schema:Person ;
#         rdfs:label              "Jonathan Cott" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/39375477/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Jonathan Cott" .
#
# authors:Anne_Kent_Rush  a              schema:Person ;
#         rdfs:label              "Anne Kent Rush" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/113030470/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Anne Kent Rush" .
#
# authors:Aveline_Kushi  a                  schema:Person ;
#         rdfs:label                 "Aveline Kushi" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Aveline_Kushi.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66469498/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Aveline Kushi" .
#
# authors:John_Sandford  a                  schema:Person ;
#         rdfs:label                 "John Sandford" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Sandford_(novelist).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/112432108/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Sandford" .
#
# authors:Rigoberta_Menchu  a               schema:Person ;
#         rdfs:label                 "Rigoberta Menchú" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Rigoberta_Menchú.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/90599516/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Rigoberta Menchú" .
#
# authors:Stacy_Schiff  a                   schema:Person ;
#         rdfs:label                 "Stacy Schiff" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stacy_Schiff.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/12400885/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stacy Schiff" .
#
# authors:Robin_Hobb  a                     schema:Person ;
#         rdfs:label                 "Robin Hobb" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Robin_Hobb.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/120736798/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Robin Hobb" .
#
# authors:Karl_Marlantes  a                 schema:Person ;
#         rdfs:label                 "Karl Marlantes" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Karl_Marlantes.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/106896414/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Karl Marlantes" .
#
# authors:Richard_Castle  a                 schema:Person ;
#         rdfs:label                 "Richard Castle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Richard_Castle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/25791801/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Richard Castle" .
#
# authors:Stephen_Crane  a                  schema:Person ;
#         rdfs:label                 "Stephen Crane" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Crane.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/100175928/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Crane" .
#
# authors:ER_LaChapelle  a                  schema:Person ;
#         rdfs:label                 "E.R. LaChapelle" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edward_LaChapelle.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/29855352/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "E.R. LaChapelle" .
#
# authors:Paul_Jordan_Smith  a              schema:Person ;
#         rdfs:label                 "Paul Jordan-Smith" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Paul_Jordan-Smith.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/77086688/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Paul Jordan-Smith" .
#
# authors:Stephen_Covey  a                  schema:Person ;
#         rdfs:label                 "Stephen Covey" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stephen_Covey.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/19730461/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stephen Covey" .
#
# authors:Jennifer_Egan  a                  schema:Person ;
#         rdfs:label                 "Jennifer Egan" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jennifer_Egan.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/56717951/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jennifer Egan" .
#
# authors:Russell_Banks  a                  schema:Person ;
#         rdfs:label                 "Russell Banks" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Russell_Banks.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/66487364/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Russell Banks" .
#
# authors:Ntozake_Shange  a                 schema:Person ;
#         rdfs:label                 "Ntozake Shange" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Ntozake_Shange.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/9859533/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Ntozake Shange" .
#
# authors:Don_Miguel_Ruiz  a                schema:Person ;
#         rdfs:label                 "Don Miguel Ruiz" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Don_Miguel_Ruiz.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/61710035/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Don Miguel Ruiz" .
#
# authors:Franco_Ferrero  a              schema:Person ;
#         rdfs:label              "Franco Ferrero" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/33948444/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Franco Ferrero" .
#
# authors:Edward_Lee  a                     schema:Person ;
#         rdfs:label                 "Edward Lee" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Edward_Lee_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/57751958/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Edward Lee" .
#
# authors:Karen_Betteridge  a            schema:Person ;
#         rdfs:label              "Karen Betteridge" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/92216455/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Karen Betteridge" .
#
# authors:Greg_Garrett  a                   schema:Person ;
#         rdfs:label                 "Greg Garrett" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Greg_Garrett_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/209068417/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Greg Garrett" .
#
# authors:East_Coast_Books  a  schema:Organization ;
#         rdfs:label  "East Coast Books" ;
#         foaf:name   "East Coast Books" .
#
# authors:Stieg_Larsson  a                  schema:Person ;
#         rdfs:label                 "Stieg Larsson" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Stieg_Larsson.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/54441441/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Stieg Larsson" .
#
# authors:Jane_Rule  a                      schema:Person ;
#         rdfs:label                 "Jane Rule" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Jane_Rule.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/62399671/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Jane Rule" .
#
# authors:Betty_Edwards  a                  schema:Person ;
#         rdfs:label                 "Betty Edwards" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Betty_Edwards.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/102211145/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Betty Edwards" .
#
# authors:A_Vogel  a                        schema:Person ;
#         rdfs:label                 "Alfred Vogel" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Alfred_Vogel.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/95162826/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Alfred Vogel" .
#
# authors:Elson_Haas  a                  schema:Person ;
#         rdfs:label              "Elson Haas" ;
#         bibliographica:viafURI  "https://viaf.org/viaf/79335892/rdf.xml"^^xsd:anyURI ;
#         foaf:name               "Elson Haas" .
#
# authors:Terry_Goodkind  a                 schema:Person ;
#         rdfs:label                 "Terry Goodkind" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/Terry_Goodkind.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/67399498/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Terry Goodkind" .
#
# authors:John_Thorne  a                    schema:Person ;
#         rdfs:label                 "John Thorne" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/John_Thorne_(writer).ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/280664031/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "John Thorne" .
#
# authors:Home_Depot  a                     schema:Person ;
#         rdfs:label                 "Home Depot" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/The_Home_Depot.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/311582406/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "Home Depot" .
#
# authors:George_RR_Martin  a               schema:Person ;
#         rdfs:label                 "George R. R. Martin" ;
#         bibliographica:dbpediaURI  "https://dbpedia.org/data/George_R._R._Martin.ttl"^^xsd:anyURI ;
#         bibliographica:viafURI     "https://viaf.org/viaf/98636170/rdf.xml"^^xsd:anyURI ;
#         foaf:name                  "George R. R. Martin" .
#
# }

# %% [markdown]
# #### Books

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# <http://www.connaissance.io/onto/biblio/books>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-22" ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#   dcterms:description "Book items cataloged and serialized in RDF. Links items to WorldCat." ;
#   owl:imports <http://www.connaissance.io/onto/biblio/MusicGroup> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/SoloMusicArtist> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/authors> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Developed by M Lane" .
#
#
# books:Theme_From_The_Simpsons
#         a                             schema:Book ;
#         rdfs:label                    "Theme From The Simpsons" ;
#         dcterms:creator               authors:Danny_Elfman ;
#         dcterms:title                 "Theme From The Simpsons" ;
#         schema:author                 authors:Danny_Elfman ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/460555576.ttl"^^xsd:anyURI .
#
# books:Baby_No-Eyes  a                      schema:Book ;
#         rdfs:label                    "Baby No-Eyes" ;
#         dcterms:creator               authors:Patricia_Grace ;
#         dcterms:title                 "Baby No-Eyes" ;
#         schema:author                 authors:Patricia_Grace ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0824821610" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39677835.ttl"^^xsd:anyURI .
#
# books:Teachings_Learning_Online
#         a                             schema:Book ;
#         rdfs:label                    "Teaching & Learning Online" ;
#         dcterms:creator               authors:John_Stephenson ;
#         dcterms:title                 "Teaching & learning online : pedagogies for new technologies" ;
#         schema:author                 authors:John_Stephenson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0749435119" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/752300699.ttl"^^xsd:anyURI .
#
# books:Cooks_Country_2006  a                schema:Book ;
#         rdfs:label                    "Cook's Country, 2006" ;
#         dcterms:creator               authors:Americas_Test_Kitchen ;
#         dcterms:title                 "Cook's Country, 2006" ;
#         schema:author                 authors:Americas_Test_Kitchen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781933615134" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/129837242.ttl"^^xsd:anyURI .
#
# books:Tao_Te_Ching_3  a                    schema:Book ;
#         rdfs:comment                  "Translation of Lao Tsu's work." ;
#         rdfs:label                    "Tao Te Ching" ;
#         dcterms:creator               authors:Jane_English , authors:Giafu_Feng ;
#         dcterms:title                 "Tao Te Ching" ;
#         schema:author                 authors:Jane_English , authors:Giafu_Feng ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "039471833X" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/833200725.ttl"^^xsd:anyURI .
#
# books:Acid_Dreams  a                     schema:Book ;
#         rdfs:label                  "Acid Dreams" ;
#         dcterms:creator             authors:Martin_Lee , authors:Bruce_Shlain ;
#         dcterms:title               "Acid dreams : the CIA, LSD, and the sixties rebellion" ;
#         schema:author               authors:Martin_Lee , authors:Bruce_Shlain ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/12342491.ttl"^^xsd:anyURI .
#
# books:Modoc  a                             schema:Book ;
#         rdfs:label                    "Modoc" ;
#         dcterms:creator               authors:Ralph_Helfer ;
#         dcterms:title                 "Modoc: the true story of the greatest elephant that ever lived" ;
#         schema:author                 authors:Ralph_Helfer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060929510" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/908211929.ttl"^^xsd:anyURI .
#
# books:Sex_Art_Culture  a                   schema:Book ;
#         rdfs:label                    "Sex, art, and American culture essays" ;
#         dcterms:creator               authors:Camille_Paglia ;
#         dcterms:title                 "Sex, art, and American culture essays" ;
#         schema:author                 authors:Camille_Paglia ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679741011" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1050040955.ttl"^^xsd:anyURI .
#
# books:Game_of_Kings  a                     schema:Book ;
#         rdfs:label                    "The Game of Kings" ;
#         dcterms:creator               authors:Dorothy_Dunnett ;
#         dcterms:title                 "The Game of Kings" ;
#         schema:author                 authors:Dorothy_Dunnett ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/807550.ttl"^^xsd:anyURI .
#
# books:Natl_Audubon_Society_birds
#         a                             schema:Book ;
#         rdfs:label                    "National Audubon Society Field Guide to North American Birds - Western Region" ;
#         dcterms:creator               authors:Miklos_Udvardy ;
#         dcterms:title                 "National Audubon Society field guide to North American birds. Western region" ;
#         schema:author                 authors:Miklos_Udvardy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679428518" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/272565031.ttl"^^xsd:anyURI .
#
# books:Moon_Moon  a                         schema:Book ;
#         rdfs:label                    "Moon, Moon" ;
#         dcterms:creator               authors:Anne_Kent_Rush ;
#         dcterms:title                 "Moon, Moon" ;
#         schema:author                 authors:Anne_Kent_Rush ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394407679" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/898868485.ttl"^^xsd:anyURI .
#
# books:Burning_Ground  a                    schema:Book ;
#         rdfs:label                    "Burning Ground" ;
#         dcterms:creator               authors:Pearl_Luke ;
#         dcterms:title                 "Burning Ground" ;
#         schema:author                 authors:Pearl_Luke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452282675" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45962915.ttl"^^xsd:anyURI .
#
# books:Top_100_Pasta_Sauces
#         a                             schema:Book ;
#         rdfs:label                    "The Top 100 Pasta Sauces" ;
#         dcterms:creator               authors:Diane_Seed ;
#         dcterms:title                 "The Top 100 Pasta Sauces" ;
#         schema:author                 authors:Diane_Seed ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898152321" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/987937898.ttl"^^xsd:anyURI .
#
# books:Bone_carving  a                      schema:Book ;
#         rdfs:label                    "Bone carving : a skillbase of techniques and concepts" ;
#         dcterms:creator               authors:Stephen_Myhre ;
#         dcterms:title                 "Bone carving : a skillbase of techniques and concepts" ;
#         schema:author                 authors:Stephen_Myhre ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0790000393" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19734359.ttl"^^xsd:anyURI .
#
# books:Way_Lao_Tzu  a                       schema:Book ;
#         rdfs:label                    "The Way of Lao Tzu" ;
#         dcterms:creator               authors:Wing_Tsit_Chan ;
#         dcterms:title                 "The Way of Lao Tzu" ;
#         schema:author                 authors:Wing_Tsit_Chan ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/310723897.ttl"^^xsd:anyURI .
#
# books:Repair_to_Her_Grave  a               schema:Book ;
#         rdfs:label                    "Repair to Her Grave" ;
#         dcterms:creator               authors:Sarah_Graves ;
#         dcterms:title                 "Repair to Her Grave" ;
#         schema:author                 authors:Sarah_Graves ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553582259" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47731235.ttl"^^xsd:anyURI .
#
# books:The_southern_ark  a                  schema:Book ;
#         rdfs:label                    "The southern ark : zoological discovery in New Zealand, 1769-1900" ;
#         dcterms:creator               authors:JRH_Andrews ;
#         dcterms:title                 "The southern ark : zoological discovery in New Zealand, 1769-1900" ;
#         schema:author                 authors:JRH_Andrews ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0824811925" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/17806150.ttl"^^xsd:anyURI .
#
# books:Hullabaloo_Guava_Orchard
#         a                             schema:Book ;
#         rdfs:label                    "Hullabaloo in the Guava Orchard" ;
#         dcterms:creator               authors:Kiran_Desai ;
#         dcterms:title                 "Hullabaloo in the Guava Orchard" ;
#         schema:author                 authors:Kiran_Desai ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385493703" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/430350499.ttl"^^xsd:anyURI .
#
# books:The_Underpainter  a                  schema:Book ;
#         rdfs:label                    "The Underpainter" ;
#         dcterms:creator               authors:Jane_Urquhart ;
#         dcterms:title                 "The Underpainter" ;
#         schema:author                 authors:Jane_Urquhart ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140269738" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/470432633.ttl"^^xsd:anyURI .
#
# books:Courage_to_Teach  a                  schema:Book ;
#         rdfs:label                    "The Courage to Teach" ;
#         dcterms:creator               authors:Parker_Palmer ;
#         dcterms:title                 "The Courage to Teach : exploring the inner landscape of a teacher's life" ;
#         schema:author                 authors:Parker_Palmer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0787996866" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1141230024.ttl"^^xsd:anyURI .
#
# books:The_Seville_Communion
#         a                             schema:Book ;
#         rdfs:label                    "The Seville Communion" ;
#         dcterms:creator               authors:Arturo_Perez_Reverte ;
#         dcterms:title                 "The Seville Communion" ;
#         schema:author                 authors:Arturo_Perez_Reverte ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0156006391" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1102420812.ttl"^^xsd:anyURI .
#
# books:Age_of_Oil  a                        schema:Book ;
#         rdfs:label                    "The Age of Oil" ;
#         dcterms:creator               authors:Leonardo_Maugeri ;
#         dcterms:title                 "The Age of Oil : What They Don't Want You to Know About the World's Most Controversial Resource" ;
#         schema:author                 authors:Leonardo_Maugeri ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781599211183" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/635921667.ttl"^^xsd:anyURI .
#
# books:Ishmael  a                           schema:Book ;
#         rdfs:label                    "Ishmael" ;
#         dcterms:creator               authors:Daniel_Quinn ;
#         dcterms:title                 "Ishmael" ;
#         schema:author                 authors:Daniel_Quinn ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553561669" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32513532.ttl"^^xsd:anyURI .
#
# books:Modern_Yoga_Handbook
#         a                             schema:Book ;
#         rdfs:label                    "The Modern Yoga Handbook" ;
#         dcterms:creator               authors:Vijay_Hassin ;
#         dcterms:title                 "The Modern Yoga Handbook" ;
#         schema:author                 authors:Vijay_Hassin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385130015" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3748390.ttl"^^xsd:anyURI .
#
# books:All_Souls_Day  a                     schema:Book ;
#         rdfs:label                    "All Souls' Day : a novel" ;
#         dcterms:creator               authors:Bill_Morris ;
#         dcterms:title                 "All Souls' Day : a novel" ;
#         schema:author                 authors:Bill_Morris ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380791161" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35784600.ttl"^^xsd:anyURI .
#
# books:Coffee_Will_Make_You_Black
#         a                             schema:Book ;
#         rdfs:label                    "Coffee Will Make You Black" ;
#         dcterms:creator               authors:April_Sinclair ;
#         dcterms:title                 "Coffee Will Make You Black" ;
#         schema:author                 authors:April_Sinclair ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380724596" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/27937706.ttl"^^xsd:anyURI .
#
# books:Jolie_Blons_Bounce  a                schema:Book ;
#         rdfs:label                    "Jolie Blon's Bounce" ;
#         dcterms:creator               authors:James_Lee_Burke ;
#         dcterms:title                 "Jolie Blon's Bounce : a novel" ;
#         schema:author                 authors:James_Lee_Burke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743411447" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/53110192.ttl"^^xsd:anyURI .
#
# books:Trout_fishing_in_America
#         a                             schema:Book ;
#         rdfs:label                    "Trout fishing in America" ;
#         dcterms:creator               authors:Richard_Brautigan ;
#         dcterms:title                 "Trout fishing in America, the Pill versus the Springhill mine disasterk, and In watermelon sugar" ;
#         schema:author                 authors:Richard_Brautigan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0395500761" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/774280087.ttl"^^xsd:anyURI .
#
# books:The_good_house  a                  schema:Book ;
#         rdfs:label                  "The good house : a novel" ;
#         dcterms:creator             authors:Tananarive_Due ;
#         dcterms:title               "The good house : a novel" ;
#         schema:author               authors:Tananarive_Due ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/52889886.ttl"^^xsd:anyURI .
#
# books:That_was_then_this_is_now
#         a                             schema:Book ;
#         rdfs:label                    "That was then, this is now" ;
#         dcterms:creator               authors:SE_Hinton ;
#         dcterms:title                 "That was then, this is now" ;
#         schema:author                 authors:SE_Hinton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780670697984" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/143718.ttl"^^xsd:anyURI .
#
# books:Eureka_Street  a                     schema:Book ;
#         rdfs:label                    "Eureka Street" ;
#         dcterms:creator               authors:Robert_McLiam_Wilson ;
#         dcterms:title                 "Eureka Street : a novel of Ireland like no other" ;
#         schema:author                 authors:Robert_McLiam_Wilson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345427130" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/963043270.ttl"^^xsd:anyURI .
#
# books:Eva_Luna  a                          schema:Book ;
#         rdfs:label                    "Eva Luna" ;
#         dcterms:creator               authors:Isabel_Allende ;
#         dcterms:title                 "Eva Luna" ;
#         schema:author                 authors:Isabel_Allende ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553280589" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32091094.ttl"^^xsd:anyURI .
#
# books:Outdoor_Projects  a                  schema:Book ;
#         rdfs:label                    "Outdoor Projects 1-2-3" ;
#         dcterms:creator               authors:Home_Depot ;
#         dcterms:title                 "Home Depot Outdoor Projects 1-2-3" ;
#         schema:author                 authors:Home_Depot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0696206730" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1010977974.ttl"^^xsd:anyURI .
#
# books:Range_of_Motion  a                   schema:Book ;
#         rdfs:label                    "Range of Motion" ;
#         dcterms:creator               authors:Elizabeth_Berg ;
#         dcterms:title                 "Range of Motion" ;
#         schema:author                 authors:Elizabeth_Berg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "042516876X" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1021090663.ttl"^^xsd:anyURI .
#
# books:Herbal_Handbook  a                   schema:Book ;
#         rdfs:label                    "The Herbal Handbook" ;
#         dcterms:creator               authors:David_Hoffmann ;
#         dcterms:title                 "The herbal handbook : a user's guide to medical herbalism" ;
#         schema:author                 authors:David_Hoffmann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0892812753" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/245935628.ttl"^^xsd:anyURI .
#
# books:Intro_Lit  a                         schema:Book ;
#         rdfs:label                    "An Introduction to Literature" ;
#         dcterms:creator               authors:Sylvan_Barnet ;
#         dcterms:title                 "An introduction to literature : fiction, poetry, drama" ;
#         schema:author                 authors:Sylvan_Barnet ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316082279" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/939890273.ttl"^^xsd:anyURI .
#
# books:Closers  a                           schema:Book ;
#         rdfs:label                    "The Closers" ;
#         dcterms:creator               authors:Michael_Connelly ;
#         dcterms:title                 "The Closers" ;
#         schema:author                 authors:Michael_Connelly ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   " 1760875929" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1122586914.ttl"^^xsd:anyURI .
#
# books:Sultans_Qaboos  a                    schema:Book ;
#         rdfs:label                    "The Sultan Qaboos Grand Mosque" ;
#         dcterms:creator               authors:Salma_Samar_Damluji ;
#         dcterms:title                 "The Sultan Qaboos Grand Mosque" ;
#         schema:author                 authors:Salma_Samar_Damluji ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/913023300.ttl"^^xsd:anyURI .
#
# books:Once_Were_Warriors_2
#         a                             schema:Book ;
#         rdfs:label                    "Once Were Warriors" ;
#         dcterms:creator               authors:Alan_Duff ;
#         dcterms:title                 "Once Were Warriors" ;
#         schema:author                 authors:Alan_Duff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "090888446X" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/154261934.ttl"^^xsd:anyURI .
#
# books:Rolling_Stone_JG_1  a                schema:Book ;
#         rdfs:label                    "Rolling Stone: Jerry Garcia Issue 1" ;
#         dcterms:creator               authors:Rolling_Stone ;
#         dcterms:title                 "Rolling Stone: Jerry Garcia Issue 1" ;
#         schema:author                 authors:Rolling_Stone ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Beard_on_Bread  a                    schema:Book ;
#         rdfs:label                    "Beard on Bread" ;
#         dcterms:creator               authors:James_Beard ;
#         dcterms:title                 "Beard on Bread" ;
#         schema:author                 authors:James_Beard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394473450" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/907296901.ttl"^^xsd:anyURI .
#
# books:Guitar_Grimoire  a                   schema:Book ;
#         rdfs:label                    "The Guitar Grimoire" ;
#         dcterms:creator               authors:Adam_Kadmon ;
#         dcterms:title                 "The guitar grimoire : progressions & improvisation" ;
#         schema:author                 authors:Adam_Kadmon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825831970" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/833425479.ttl"^^xsd:anyURI .
#
# books:Awakened_Eye  a                      schema:Book ;
#         rdfs:label                    "The Awakened Eye" ;
#         dcterms:creator               authors:Frederick_Franck ;
#         dcterms:title                 "The awakened eye : a companion volume to The Zen of seeing : seeing, drawing as meditation" ;
#         schema:author                 authors:Frederick_Franck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394740211" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5007607.ttl"^^xsd:anyURI .
#
# books:Poisonwood_Bible_2  a                schema:Book ;
#         rdfs:label                    "Poisonwood Bible" ;
#         dcterms:creator               authors:Barbara_Kingsolver ;
#         dcterms:title                 "Poisonwood Bible" ;
#         schema:author                 authors:Barbara_Kingsolver ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060930535" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/825557679.ttl"^^xsd:anyURI .
#
# books:Higher_Creativity  a                 schema:Book ;
#         rdfs:label                    "Higher Creativity" ;
#         dcterms:creator               authors:Willis_Harman ;
#         dcterms:title                 "Higher Creativity" ;
#         schema:author                 authors:Willis_Harman ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/906820914.ttl"^^xsd:anyURI .
#
# books:Break_In  a                          schema:Book ;
#         rdfs:label                    "Break In" ;
#         dcterms:creator               authors:Dick_Francis ;
#         dcterms:title                 "Break In" ;
#         schema:author                 authors:Dick_Francis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0449207552" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12810376.ttl"^^xsd:anyURI .
#
# books:Cold_Sassy_Tree  a                   schema:Book ;
#         rdfs:label                    "Cold Sassy Tree" ;
#         dcterms:creator               authors:Olive_Ann_Burns ;
#         dcterms:title                 "Cold Sassy Tree" ;
#         schema:author                 authors:Olive_Ann_Burns ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440514428" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1023009342.ttl"^^xsd:anyURI .
#
# books:Hells_Angels_2  a                    schema:Book ;
#         rdfs:label                    "Hell's Angels : a strange and terrible saga" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "Hell's Angels : a strange and terrible saga" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345292383" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/377083.ttl"^^xsd:anyURI .
#
# books:Travels_with_Charley_2
#         a                             schema:Book ;
#         rdfs:label                    "Travels With Charley : in search of America" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "Travels With Charley : in search of America" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140053204" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1076344551.ttl"^^xsd:anyURI .
#
# books:Natl_Audubon_Society_wildflowers
#         a                             schema:Book ;
#         rdfs:label                    "The Audubon Society Field Guide to North American Wildflowers - Western Region" ;
#         dcterms:creator               authors:Richard_Spellenberg ;
#         dcterms:title                 "The Audubon Society field guide to North American wildflowers : western region" ;
#         schema:author                 authors:Richard_Spellenberg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394504313" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/659064350.ttl"^^xsd:anyURI .
#
# books:Havana_Bay  a                        schema:Book ;
#         rdfs:label                    "Havana Bay" ;
#         dcterms:creator               authors:Martin_Cruz_Smith ;
#         dcterms:title                 "Havana Bay : a novel" ;
#         schema:author                 authors:Martin_Cruz_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345390458" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1145761747.ttl"^^xsd:anyURI .
#
# books:Archipel_Vol_2  a         schema:Book ;
#         rdfs:label         "Archipel Vol. 2" ;
#         dcterms:title      "Archipel Vol. 2" ;
#         schema:bookFormat  schema:Paperback .
#
# books:Notes_from_a_bottle  a               schema:Book ;
#         rdfs:label                    "Notes from a bottle found on the beach at Carmel" ;
#         dcterms:creator               authors:Evan_S_Connell ;
#         dcterms:title                 "Notes from a bottle found on the beach at Carmel" ;
#         schema:author                 authors:Evan_S_Connell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0880014075" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/291703.ttl"^^xsd:anyURI .
#
# books:Tick_Tock  a                         schema:Book ;
#         rdfs:label                    "Tick Tock" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "Tick Tock" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781455506651" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1043704314.ttl"^^xsd:anyURI .
#
# books:Women_of_Brewster_Place
#         a                             schema:Book ;
#         rdfs:label                    "The Women of Brewster Place" ;
#         dcterms:creator               authors:Gloria_Naylor ;
#         dcterms:title                 "The Women of Brewster Place" ;
#         schema:author                 authors:Gloria_Naylor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451822021" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1140455121.ttl"^^xsd:anyURI .
#
# books:Fun_with_Harmonica  a                schema:Book ;
#         rdfs:label                    "Mel Bay's Fun with the Harmonica" ;
#         dcterms:creator               authors:William_Bay ;
#         dcterms:title                 "Mel Bay's fun with the harmonica : an instruction method for diatonic, chromatic, and blues styling" ;
#         schema:author                 authors:William_Bay ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0871664488" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/7539420.ttl"^^xsd:anyURI .
#
# books:Age_of_Reason  a                     schema:Book ;
#         rdfs:label                    "The Age of Reason" ;
#         dcterms:creator               authors:Jean_Paul_Sartre ;
#         dcterms:title                 "The Age of Reason" ;
#         schema:author                 authors:Jean_Paul_Sartre ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394718380" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1023741641.ttl"^^xsd:anyURI .
#
# books:Night_Letters  a                     schema:Book ;
#         rdfs:label                    "Night Letters" ;
#         dcterms:creator               authors:Robert_Dessaix ;
#         dcterms:title                 "Night Letters" ;
#         schema:author                 authors:Robert_Dessaix ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312199392" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40193784.ttl"^^xsd:anyURI .
#
# books:Fear_and_loathing_campaign_trail_2
#         a                             schema:Book ;
#         rdfs:label                    "Fear and loathing : on the campaign trail '72" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "Fear and loathing : on the campaign trail '72" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0445082488" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/7451719.ttl"^^xsd:anyURI .
#
# books:Living_on_the_Earth  a               schema:Book ;
#         rdfs:label                    "Living on the Earth" ;
#         dcterms:creator               authors:Alicia_Bay_Laurel ;
#         dcterms:title                 "Living on the Earth" ;
#         schema:author                 authors:Alicia_Bay_Laurel ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781586853433" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1004997897.ttl"^^xsd:anyURI .
#
# books:Sophies_World_2  a                   schema:Book ;
#         rdfs:label                    "Sophie's World" ;
#         dcterms:creator               authors:Jostein_Gaarder ;
#         dcterms:title                 "Sophie's world : a novel about the history of philosophy" ;
#         schema:author                 authors:Jostein_Gaarder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1897580479" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/976188175.ttl"^^xsd:anyURI .
#
# books:The_Woman_Who_Married_a_Bear
#         a                             schema:Book ;
#         rdfs:label                    "The Woman Who Married a Bear" ;
#         dcterms:creator               authors:John_Straley ;
#         dcterms:title                 "The Woman Who Married a Bear" ;
#         schema:author                 authors:John_Straley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451404211" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/495368482.ttl"^^xsd:anyURI .
#
# books:Two_in_the_Wild  a                   schema:Book ;
#         rdfs:label                    "Two in the Wild" ;
#         dcterms:creator               authors:Susan_Fox_Rogers ;
#         dcterms:title                 "Two in the Wild" ;
#         schema:author                 authors:Susan_Fox_Rogers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375702016" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41076179.ttl"^^xsd:anyURI .
#
# books:The_woman_who_walked_into_doors
#         a                             schema:Book ;
#         rdfs:label                    "The Woman Who Walked into Doors" ;
#         dcterms:creator               authors:Roddy_Doyle ;
#         dcterms:title                 "The Woman Who Walked into Doors" ;
#         schema:author                 authors:Roddy_Doyle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140255125" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/680286356.ttl"^^xsd:anyURI .
#
# books:Juniper_Tree_Burning
#         a                             schema:Book ;
#         rdfs:label                    "Juniper Tree Burning" ;
#         dcterms:creator               authors:Goldberry_Long ;
#         dcterms:title                 "Juniper Tree Burning : a novel" ;
#         schema:author                 authors:Goldberry_Long ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743222113" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/50270396.ttl"^^xsd:anyURI .
#
# books:Silver_Palate_Cookbook_2
#         a                           schema:Book ;
#         rdfs:label                  "The Silver Palate Good Times Cookbook" ;
#         dcterms:creator             authors:Sheila_Lukins , authors:Julee_Rosso ;
#         dcterms:title               "The Silver Palate good times cookbook" ;
#         schema:author               authors:Sheila_Lukins , authors:Julee_Rosso ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/11812146.ttl"^^xsd:anyURI .
#
# books:Tender_at_the_Bone  a                schema:Book ;
#         rdfs:label                    "Tender at the Bone" ;
#         dcterms:creator               authors:Ruth_Reichl ;
#         dcterms:title                 "Tender at the Bone" ;
#         schema:author                 authors:Ruth_Reichl ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0767903382" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/778977673.ttl"^^xsd:anyURI .
#
# books:Music_Kit_Rhythm_Reader
#         a                             schema:Book ;
#         rdfs:label                    "The Music Kit : Rhythm Reader" ;
#         dcterms:creator               authors:Tom_Manoff ;
#         dcterms:title                 "The Music Kit : Rhythm Reader" ;
#         schema:author                 authors:Tom_Manoff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0393952983" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/992422386.ttl"^^xsd:anyURI .
#
# books:Practice_of_the_Wild
#         a                             schema:Book ;
#         rdfs:label                    "The Practice of the Wild" ;
#         dcterms:creator               authors:Gary_Snyder ;
#         dcterms:title                 "The Practice of the Wild" ;
#         schema:author                 authors:Gary_Snyder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0865474532" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/963713461.ttl"^^xsd:anyURI .
#
# books:Hells_Angels  a                      schema:Book ;
#         rdfs:label                    "Hell's Angels : a strange and terrible saga" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "Hell's Angels : a strange and terrible saga" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345292383" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/377083.ttl"^^xsd:anyURI .
#
# books:Rocky_Mountain_Tree_Finder
#         a                             schema:Book ;
#         rdfs:label                    "Rocky Mountain Tree Finder" ;
#         dcterms:creator               authors:Tom_Watts ;
#         dcterms:title                 "Rocky Mountain Tree Finder: a pocket manual for identifying Rocky Mountain trees" ;
#         schema:author                 authors:Tom_Watts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0912550058" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3742915.ttl"^^xsd:anyURI .
#
# books:Queen_of_South  a                    schema:Book ;
#         rdfs:label                    "The Queen of the South" ;
#         dcterms:creator               authors:Arturo_Perez_Reverte ;
#         dcterms:title                 "The Queen of the South" ;
#         schema:author                 authors:Arturo_Perez_Reverte ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452286549" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1192555741.ttl"^^xsd:anyURI .
#
# books:Griffin_Sabine  a                    schema:Book ;
#         rdfs:label                    "Griffin & Sabine : an extraordinary correspondence" ;
#         dcterms:creator               authors:Nick_Bantock ;
#         dcterms:title                 "Griffin & Sabine : an extraordinary correspondence" ;
#         schema:author                 authors:Nick_Bantock ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877017883" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22891968.ttl"^^xsd:anyURI .
#
# books:Heading_Toward_Omega
#         a                             schema:Book ;
#         rdfs:label                    "Heading Toward Omega" ;
#         dcterms:creator               authors:Kenneth_Ring ;
#         dcterms:title                 "Heading toward omega : in search of the meaning of the near-death experience" ;
#         schema:author                 authors:Kenneth_Ring ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0688062687" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12929384.ttl"^^xsd:anyURI .
#
# books:Mile_Zero  a                         schema:Book ;
#         rdfs:label                    "Mile Zero" ;
#         dcterms:creator               authors:Thomas_Sanchez ;
#         dcterms:title                 "Mile Zero" ;
#         schema:author                 authors:Thomas_Sanchez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679732608" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/492364070.ttl"^^xsd:anyURI .
#
# books:Possession_a_romance
#         a                             schema:Book ;
#         rdfs:label                    "Possession : a romance" ;
#         dcterms:creator               authors:AS_Byatt ;
#         dcterms:title                 "Possession : a romance" ;
#         schema:author                 authors:AS_Byatt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780679735908" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23652129.ttl"^^xsd:anyURI .
#
# books:Higher_Taste  a                      schema:Book ;
#         rdfs:label                    "The Higher Taste" ;
#         dcterms:creator               authors:AC_Bhaktivedanta_Swami ;
#         dcterms:title                 "The Higher Taste : a guide to gourmet vegetarian cooking and a karma-free diet" ;
#         schema:author                 authors:AC_Bhaktivedanta_Swami ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0892131284" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/488275616.ttl"^^xsd:anyURI .
#
# books:Lucid_Intervals  a                 schema:Book ;
#         rdfs:label                  "Lucid Intervals" ;
#         dcterms:creator             authors:Stuart_Woods ;
#         dcterms:title               "Lucid Intervals" ;
#         schema:author               authors:Stuart_Woods ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/499178284.ttl"^^xsd:anyURI .
#
# books:Modern_Method_Guitar_v1
#         a                             schema:Book ;
#         rdfs:label                    "A Modern Method for Guitar. vol. 1" ;
#         dcterms:creator               authors:William_Leavitt ;
#         dcterms:title                 "A Modern Method for Guitar. vol. 1" ;
#         schema:author                 authors:William_Leavitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0876390130" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/837680299.ttl"^^xsd:anyURI .
#
# books:The_Good_Negress  a                  schema:Book ;
#         rdfs:label                    "The Good Negress" ;
#         dcterms:creator               authors:AJ_Verdelle ;
#         dcterms:title                 "The Good Negress" ;
#         schema:author                 authors:AJ_Verdelle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060976837" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/632643791.ttl"^^xsd:anyURI .
#
# books:Jabberwocky  a                       schema:Book ;
#         rdfs:label                    "Jabberwocky" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "Jabberwocky" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0810911507" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/44851689.ttl"^^xsd:anyURI .
#
# books:PSI_What_Is_It  a                    schema:Book ;
#         rdfs:label                    "PSI what is it?" ;
#         dcterms:creator               authors:Louisa_Rhine ;
#         dcterms:title                 "PSI what is it?" ;
#         schema:author                 authors:Louisa_Rhine ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0439136369" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1039070350.ttl"^^xsd:anyURI .
#
# books:Heart_of_Darkness_Secret_Sharer
#         a                             schema:Book ;
#         rdfs:label                    "Heart of Darkness and The Secret Sharer" ;
#         dcterms:creator               authors:Joseph_Conrad ;
#         dcterms:title                 "Heart of Darkness and The Secret Sharer" ;
#         schema:author                 authors:Joseph_Conrad ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553124269" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/65621303.ttl"^^xsd:anyURI .
#
# books:Bone_in_the_Throat  a                schema:Book ;
#         rdfs:label                    "Bone in the Throat" ;
#         dcterms:creator               authors:Anthony_Bourdain ;
#         dcterms:title                 "Bone in the Throat" ;
#         schema:author                 authors:Anthony_Bourdain ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1582341028" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31740216.ttl"^^xsd:anyURI .
#
# books:Unsuitable_Job_for_a_Woman
#         a                             schema:Book ;
#         rdfs:label                    "An Unsuitable Job for a Woman" ;
#         dcterms:creator               authors:PD_James ;
#         dcterms:title                 "An Unsuitable Job for a Woman" ;
#         schema:author                 authors:PD_James ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743219554" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1005489576.ttl"^^xsd:anyURI .
#
# books:Some_of_Dharma  a                    schema:Book ;
#         rdfs:label                    "Some of the Dharma" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Some of the Dharma" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140287078" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42951441.ttl"^^xsd:anyURI .
#
# books:Judgment_Calls  a                    schema:Book ;
#         rdfs:label                    "Judgment Calls" ;
#         dcterms:creator               authors:Alafair_Burke ;
#         dcterms:title                 "Judgment Calls" ;
#         schema:author                 authors:Alafair_Burke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312997205" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/55476003.ttl"^^xsd:anyURI .
#
# books:Getting_Over_Jack_Wagner
#         a                             schema:Book ;
#         rdfs:label                    "Getting Over Jack Wagner" ;
#         dcterms:creator               authors:Elise_Juska ;
#         dcterms:title                 "Getting Over Jack Wagner" ;
#         schema:author                 authors:Elise_Juska ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743464672" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/61423521.ttl"^^xsd:anyURI .
#
# books:Cheese_and_Cookery  a                schema:Book ;
#         rdfs:label                    "Cheese and Cheese Cookery" ;
#         dcterms:creator               authors:TA_Layton ;
#         dcterms:title                 "Cheese and Cheese Cookery" ;
#         schema:author                 authors:TA_Layton ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/658079487.ttl"^^xsd:anyURI .
#
# books:Turnip_Blues  a                      schema:Book ;
#         rdfs:label                    "Turnip Blues" ;
#         dcterms:creator               authors:Helen_Campbell ;
#         dcterms:title                 "Turnip Blues" ;
#         schema:author                 authors:Helen_Campbell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1883523230" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39849468.ttl"^^xsd:anyURI .
#
# books:Peppers_of_the_world
#         a                           schema:Book ;
#         rdfs:label                  "Peppers of the world : an identification guide" ;
#         dcterms:creator             authors:Paul_Bosland , authors:Dave_DeWitt ;
#         dcterms:title               "Peppers of the world : an identification guide" ;
#         schema:author               authors:Paul_Bosland , authors:Dave_DeWitt ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/34475704.ttl"^^xsd:anyURI .
#
# books:Julip  a                             schema:Book ;
#         rdfs:label                    "Julip" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Julip" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067189935X" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/213452422.ttl"^^xsd:anyURI .
#
# books:Recipe_for_Small_Planet
#         a                             schema:Book ;
#         rdfs:label                    "Recipes for a Small Planet" ;
#         dcterms:creator               authors:Ellen_Ewald ;
#         dcterms:title                 "Recipes for a small planet; the art and science of high protein vegetarian cookery" ;
#         schema:author                 authors:Ellen_Ewald ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345308719" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/699377.ttl"^^xsd:anyURI .
#
# books:Complete_Guide_Home_Carpentry
#         a                             schema:Book ;
#         rdfs:label                    "The Complete Guide to Home Carpentry" ;
#         dcterms:creator               authors:Creative_Publishing ;
#         dcterms:title                 "The Complete Guide to Home Carpentry : Carpentry Skills & Projects for Homeowners" ;
#         schema:author                 authors:Creative_Publishing ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43970873.ttl"^^xsd:anyURI .
#
# books:White_Death  a                       schema:Book ;
#         rdfs:label                    "White Death" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "White Death" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0399150641" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52514032.ttl"^^xsd:anyURI .
#
# books:Purity_of_Blood  a                   schema:Book ;
#         rdfs:label                    "Purity of Blood" ;
#         dcterms:creator               authors:Arturo_Perez_Reverte ;
#         dcterms:title                 "Purity of Blood" ;
#         schema:author                 authors:Arturo_Perez_Reverte ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452287987" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/76874786.ttl"^^xsd:anyURI .
#
# books:Florida_Roadkill  a                  schema:Book ;
#         rdfs:label                    "Florida Roadkill: a novel" ;
#         dcterms:creator               authors:Tim_Dorsey ;
#         dcterms:title                 "Florida Roadkill: a novel" ;
#         schema:author                 authors:Tim_Dorsey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380732335" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40311591.ttl"^^xsd:anyURI .
#
# books:Field_Guide_Trees_Shrubs
#         a                             schema:Book ;
#         rdfs:label                    "A Field Guide to Trees and Shrubs" ;
#         dcterms:creator               authors:George_Petrides ;
#         dcterms:title                 "A field guide to trees and shrubs : field marks of all trees, shrubs, and woody vines that grow wild in the northeastern and north-central United States and in southeastern and south-central Canada" ;
#         schema:author                 authors:George_Petrides ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0395175798" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/421844379.ttl"^^xsd:anyURI .
#
# books:Get_Fuzzy  a                         schema:Book ;
#         rdfs:label                    "The Get fuzzy experience : are you bucksperienced" ;
#         dcterms:creator               authors:Darby_Conley ;
#         dcterms:title                 "The Get Fuzzy Experience : are you bucksperienced" ;
#         schema:author                 authors:Darby_Conley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0740733001" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52035242.ttl"^^xsd:anyURI .
#
# books:Case_histories  a                    schema:Book ;
#         rdfs:label                    "Case histories" ;
#         dcterms:creator               authors:Kate_Atkinson ;
#         dcterms:title                 "Case histories" ;
#         schema:author                 authors:Kate_Atkinson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316010707" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/57216911.ttl"^^xsd:anyURI .
#
# books:Green_Grass_Running_Water
#         a                             schema:Book ;
#         rdfs:label                    "Green Grass, Running Water" ;
#         dcterms:creator               authors:Thomas_King ;
#         dcterms:title                 "Green Grass, Running Water" ;
#         schema:author                 authors:Thomas_King ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553373684" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/889998883.ttl"^^xsd:anyURI .
#
# books:The_Sheltering_Sky  a                schema:Book ;
#         rdfs:label                    "The Sheltering Sky" ;
#         dcterms:creator               authors:Paul_Bowles ;
#         dcterms:title                 "The Sheltering Sky" ;
#         schema:author                 authors:Paul_Bowles ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679729798" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/613602678.ttl"^^xsd:anyURI .
#
# books:The_three_pillars_of_Zen
#         a                             schema:Book ;
#         rdfs:label                    "The Three Pillars of Zen" ;
#         dcterms:creator               authors:Philip_Kapleau ;
#         dcterms:title                 "The three pillars of Zen: teaching, practice, and enlightenment" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Philip_Kapleau ;
#         schema:isbn                   "0807059757" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/973589279.ttl"^^xsd:anyURI .
#
# books:One_Hundred_Selected_Poems
#         a                             schema:Book ;
#         rdfs:label                    "100 Selected Poems" ;
#         dcterms:creator               authors:Dorothy_Dunnett ;
#         dcterms:title                 "100 Selected Poems" ;
#         schema:author                 authors:Dorothy_Dunnett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067977744X" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1107013340.ttl"^^xsd:anyURI .
#
# books:Rookery_Blues  a                     schema:Book ;
#         rdfs:label                    "Rookery Blues" ;
#         dcterms:creator               authors:Jon_Hassler ;
#         dcterms:title                 "Rookery Blues" ;
#         schema:author                 authors:Jon_Hassler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345406419" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35700571.ttl"^^xsd:anyURI .
#
# books:The_Horn  a                          schema:Book ;
#         rdfs:label                    "The Horn" ;
#         dcterms:creator               authors:John_Clellon_Holmes ;
#         dcterms:title                 "The Horn" ;
#         schema:author                 authors:John_Clellon_Holmes ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0938410512" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16804864.ttl"^^xsd:anyURI .
#
# books:The_friends_of_Freeland
#         a                           schema:Book ;
#         rdfs:label                  "The friends of Freeland : a novel" ;
#         dcterms:creator             authors:Brad_Leithauser ;
#         dcterms:title               "The friends of Freeland : a novel" ;
#         schema:author               authors:Brad_Leithauser ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/34658771.ttl"^^xsd:anyURI .
#
# books:The_Eternity_Code  a               schema:Book ;
#         rdfs:label                  "The Eternity Code" ;
#         dcterms:creator             authors:Eoin_Colfer ;
#         dcterms:title               "The Eternity Code" ;
#         schema:author               authors:Eoin_Colfer ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/861356676.ttl"^^xsd:anyURI .
#
# books:Dylan  a                             schema:Book ;
#         rdfs:label                    "Dylan" ;
#         dcterms:creator               authors:Jonathan_Cott ;
#         dcterms:title                 "Dylan" ;
#         schema:author                 authors:Jonathan_Cott ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0395191626" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/993492599.ttl"^^xsd:anyURI .
#
# books:Cold_Mountain  a                     schema:Book ;
#         rdfs:label                    "Cold Mountain" ;
#         dcterms:creator               authors:Charles_Frazier ;
#         dcterms:title                 "Cold Mountain" ;
#         schema:author                 authors:Charles_Frazier ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375700757" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/492287433.ttl"^^xsd:anyURI .
#
# books:The_Road_from_Coorain
#         a                           schema:Book ;
#         rdfs:label                  "The Road from Coorain" ;
#         dcterms:creator             authors:Jill_Ker_Conway ;
#         dcterms:title               "The Road from Coorain" ;
#         schema:author               authors:Jill_Ker_Conway ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/18415173.ttl"^^xsd:anyURI .
#
# books:Enemy_Women  a                       schema:Book ;
#         rdfs:label                    "Enemy Women" ;
#         dcterms:creator               authors:Paulette_Jiles ;
#         dcterms:title                 "Enemy Women" ;
#         schema:author                 authors:Paulette_Jiles ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060938099" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/748286964.ttl"^^xsd:anyURI .
#
# books:Monkey_Wrench_Gang  a                schema:Book ;
#         rdfs:label                    "The Monkey Wrench Gang" ;
#         dcterms:creator               authors:Edward_Abbey ;
#         dcterms:title                 "The Monkey Wrench Gang" ;
#         schema:author                 authors:Edward_Abbey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "038000741X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/895549785.ttl"^^xsd:anyURI .
#
# books:Discovery_of_Dragons
#         a                             schema:Book ;
#         rdfs:label                    "The Discovery of Dragons" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "The Discovery of Dragons" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0810932377" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/44851685.ttl"^^xsd:anyURI .
#
# books:Liquor  a                            schema:Book ;
#         rdfs:label                    "Liquor : a novel" ;
#         dcterms:creator               authors:Poppy_Brite ;
#         dcterms:title                 "Liquor : a novel" ;
#         schema:author                 authors:Poppy_Brite ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140088296" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/758802354.ttl"^^xsd:anyURI .
#
# books:Mexico_City_Blues  a                 schema:Book ;
#         rdfs:label                    "Mexico City Blues" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Mexico city blues : (242 choruses)" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394172876" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/631233507.ttl"^^xsd:anyURI .
#
# books:The_Austere_Academy  a             schema:Book ;
#         rdfs:label                  "The Austere Academy" ;
#         dcterms:creator             authors:Brett_Helquist ;
#         dcterms:title               "The Austere Academy" ;
#         schema:author               authors:Brett_Helquist ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/43952131.ttl"^^xsd:anyURI .
#
# books:Soups  a                             schema:Book ;
#         rdfs:label                    "Soups" ;
#         dcterms:creator               authors:Time_Life_Books ;
#         dcterms:title                 "Soups" ;
#         schema:author                 authors:Time_Life_Books ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0809428660" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9849950.ttl"^^xsd:anyURI .
#
# books:Diatonic_Major_Minor_Scales
#         a                             schema:Book ;
#         rdfs:label                    "Diatonic Major and Minor Scales" ;
#         dcterms:creator               authors:Andres_Segovia ;
#         dcterms:title                 "Diatonic Major and Minor Scales" ;
#         schema:author                 authors:Andres_Segovia ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1004934270.ttl"^^xsd:anyURI .
#
# books:Half_Asleep_in_Frog_Pajamas
#         a                             schema:Book ;
#         rdfs:label                    "Half Asleep in Frog Pajamas" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Half Asleep in Frog Pajamas" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553377876" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1104669526.ttl"^^xsd:anyURI .
#
# books:Mystery_Ride  a                      schema:Book ;
#         rdfs:label                    "Mystery Ride" ;
#         dcterms:creator               authors:Robert_Boswell ;
#         dcterms:title                 "Mystery Ride : a novel" ;
#         schema:author                 authors:Robert_Boswell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060975857" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28634529.ttl"^^xsd:anyURI .
#
# books:Sole_Survivor  a                     schema:Book ;
#         rdfs:label                    "Sole Survivor" ;
#         dcterms:creator               authors:Derek_Hansen ;
#         dcterms:title                 "Sole Survivor" ;
#         schema:author                 authors:Derek_Hansen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0812973305" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41163612.ttl"^^xsd:anyURI .
#
# books:Mind_Wide_Open  a                    schema:Book ;
#         rdfs:label                    "Mind Wide Open" ;
#         dcterms:creator               authors:Steven_Johnson ;
#         dcterms:title                 "Mind wide open : your brain and the neuroscience of everyday life" ;
#         schema:author                 authors:Steven_Johnson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743241665" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1044271483.ttl"^^xsd:anyURI .
#
# books:Atlas_Shrugged  a                    schema:Book ;
#         rdfs:label                    "Atlas Shrugged" ;
#         dcterms:creator               authors:Ayn_Rand ;
#         dcterms:title                 "Atlantis Found" ;
#         schema:author                 authors:Ayn_Rand ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/944146779.ttl"^^xsd:anyURI .
#
# books:Guitar_Chord_Encyclopedia
#         a                             schema:Book ;
#         rdfs:label                    "Guitar Chord Encyclopedia" ;
#         dcterms:creator               authors:Steve_Hall ;
#         dcterms:title                 "Guitar Chord Encyclopedia" ;
#         schema:author                 authors:Steve_Hall ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0882845292" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/66021017.ttl"^^xsd:anyURI .
#
# books:Celtic_Way_of_Seeing
#         a                             schema:Book ;
#         rdfs:label                    "The Celtic Way of Seeing" ;
#         dcterms:creator               authors:Frank_MacEowen ;
#         dcterms:title                 "The Celtic way of seeing: meditations on the Irish spirit wheel" ;
#         schema:author                 authors:Frank_MacEowen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1577315413" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/76820761.ttl"^^xsd:anyURI .
#
# books:Official_Book_of_DeadHeads
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead : the Official Book of the Dead Heads" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead : the Official Book of the Dead Heads" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0688015204" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/925014967.ttl"^^xsd:anyURI .
#
# books:Quality_School  a                    schema:Book ;
#         rdfs:label                    "The Quality School" ;
#         dcterms:creator               authors:William_Glasser ;
#         dcterms:title                 "The Quality School" ;
#         schema:author                 authors:William_Glasser ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060969555" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1072977671.ttl"^^xsd:anyURI .
#
# books:Potters_Companion  a                 schema:Book ;
#         rdfs:label                    "The Complete Potter's Companion" ;
#         dcterms:creator               authors:Tony_Birks ;
#         dcterms:title                 "The Complete Potter's Companion" ;
#         schema:author                 authors:Tony_Birks ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0821224956" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/875973119.ttl"^^xsd:anyURI .
#
# books:The_Alchemist  a                     schema:Book ;
#         rdfs:label                    "The Alchemist" ;
#         dcterms:creator               authors:Paulo_Coelho ;
#         dcterms:title                 "The Alchemist : a story about following your dream" ;
#         schema:author                 authors:Paulo_Coelho ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0062502174" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/429377194.ttl"^^xsd:anyURI .
#
# books:Jitterbug_Perfume  a                 schema:Book ;
#         rdfs:label                    "Jitterbug Perfume" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Jitterbug Perfume" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553251481" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/906465186.ttl"^^xsd:anyURI .
#
# books:Stars_Planets_and_Galaxies
#         a                             schema:Book ;
#         rdfs:label                    "Stars, Planets, and Galaxies" ;
#         dcterms:creator               authors:Sune_Engelbrektson ;
#         dcterms:title                 "Stars, Planets, and Galaxies" ;
#         schema:author                 authors:Sune_Engelbrektson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553264419" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/434838755.ttl"^^xsd:anyURI .
#
# books:Vegetarian_Epicure_II
#         a                             schema:Book ;
#         rdfs:label                    "The Vegetarian Epicure: Book Two" ;
#         dcterms:creator               authors:Anna_Thomas ;
#         dcterms:title                 "The Vegetarian Epicure: Book Two" ;
#         schema:author                 authors:Anna_Thomas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394734157" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/670537957.ttl"^^xsd:anyURI .
#
# books:Private_Games  a                     schema:Book ;
#         rdfs:label                    "Private Games" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "Private Games" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781455512973" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/768792793.ttl"^^xsd:anyURI .
#
# books:When_Nietzsche_Wept  a               schema:Book ;
#         rdfs:label                    "When Nietzsche Wept" ;
#         dcterms:creator               authors:Irvin_Yalom ;
#         dcterms:title                 "When Nietzsche Wept" ;
#         schema:author                 authors:Irvin_Yalom ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060975504" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/871746522.ttl"^^xsd:anyURI .
#
# books:Close_Your_Eyes  a                   schema:Book ;
#         rdfs:label                    "Close your Eyes and Think of Dublin" ;
#         dcterms:creator               authors:Kathryn_Thompson ;
#         dcterms:title                 "Close your eyes and think of Dublin : portrait of a girl" ;
#         schema:author                 authors:Kathryn_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0932511422" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/637027372.ttl"^^xsd:anyURI .
#
# books:American_Heritage_Dictionary
#         a                             schema:Book ;
#         rdfs:label                    "The American Heritage dictionary of the English language" ;
#         dcterms:creator               authors:Peter_Davies ;
#         dcterms:title                 "The American Heritage dictionary of the English language" ;
#         schema:author                 authors:Peter_Davies ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440503701" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/176051449.ttl"^^xsd:anyURI .
#
# books:Yellow_Raft_Blue_River
#         a                             schema:Book ;
#         rdfs:label                    "A Yellow Raft in Blue Water" ;
#         dcterms:creator               authors:Michael_Dorris ;
#         dcterms:title                 "A yellow raft in blue water" ;
#         schema:author                 authors:Michael_Dorris ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446387878" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/256099430.ttl"^^xsd:anyURI .
#
# books:Washington_Atlas_Gazetteer
#         a                             schema:Book ;
#         rdfs:label                    "Washington Atlas & Gazetteer" ;
#         dcterms:creator               authors:DeLorme_Mapping_Company ;
#         dcterms:title                 "Washington Atlas & Gazetteer" ;
#         schema:author                 authors:DeLorme_Mapping_Company ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0899332633" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42955265.ttl"^^xsd:anyURI .
#
# books:Wild_World_of_Bulk  a                schema:Book ;
#         rdfs:label                    "Wild World of Bulk" ;
#         dcterms:creator               authors:Alfalfas ;
#         dcterms:title                 "Wild World of Bulk ; Buying and Preparing Bulk Foods" ;
#         schema:author                 authors:Alfalfas ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 .
#
# books:Synchronicity  a                     schema:Book ;
#         rdfs:label                    "Synchronicity" ;
#         dcterms:creator               authors:CG_Jung ;
#         dcterms:title                 "Synchronicity" ;
#         schema:author                 authors:CG_Jung ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/611657875.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Comix_4
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Comix No. 4" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Comix No. 4" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Water_Witches  a                     schema:Book ;
#         rdfs:label                    "Water Witches" ;
#         dcterms:creator               authors:Chris_Bohjalian ;
#         dcterms:title                 "Water Witches" ;
#         schema:author                 authors:Chris_Bohjalian ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684826127" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/797125946.ttl"^^xsd:anyURI .
#
# books:La_Place_de_la_Concorde
#         a                             schema:Book ;
#         rdfs:label                    "La Place de la Concorde Suisse" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "La Place de la Concorde Suisse" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374182418" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924482221.ttl"^^xsd:anyURI .
#
# books:Color_Setup_Guide  a                 schema:Book ;
#         rdfs:label                    "Color Setup Guide" ;
#         dcterms:creator               authors:Apple ;
#         dcterms:title                 "Color Setup Guide" ;
#         schema:author                 authors:Apple ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 .
#
# books:Burnt_House_to_Paw_Paw
#         a                             schema:Book ;
#         rdfs:label                    "Burnt House to Paw Paw" ;
#         dcterms:creator               authors:Merrill_Gilfillan ;
#         dcterms:title                 "Burnt House to Paw Paw : Appalachian notes" ;
#         schema:author                 authors:Merrill_Gilfillan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1889097055" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35911879.ttl"^^xsd:anyURI .
#
# books:The_chess_garden  a                schema:Book ;
#         rdfs:label                  "The chess garden, or, The twilight letters of Gustav Uyterhoeven" ;
#         dcterms:creator             authors:Brooks_Hansen ;
#         dcterms:title               "The chess garden, or, The twilight letters of Gustav Uyterhoeven" ;
#         schema:author               authors:Brooks_Hansen ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/30110322.ttl"^^xsd:anyURI .
#
# books:Red_Earth_Pouring_Rain
#         a                             schema:Book ;
#         rdfs:label                    "Red Earth and Pouring Rain" ;
#         dcterms:creator               authors:Vikram_Chandra ;
#         dcterms:title                 "Red earth and pouring rain : a novel" ;
#         schema:author                 authors:Vikram_Chandra ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316132934" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/634225780.ttl"^^xsd:anyURI .
#
# books:Zippy_nation_of_pinheads
#         a                             schema:Book ;
#         rdfs:label                    "Zippy : nation of pinheads" ;
#         dcterms:creator               authors:Bill_Griffith ;
#         dcterms:title                 "Zippy : nation of pinheads" ;
#         schema:author                 authors:Bill_Griffith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0867193654" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28767387.ttl"^^xsd:anyURI .
#
# books:Drawing_on_Right_Side_of_Brain
#         a                             schema:Book ;
#         rdfs:label                    "Drawing on the Right Side of the Brain" ;
#         dcterms:creator               authors:Betty_Edwards ;
#         dcterms:title                 "Drawing on the Right Side of the Brain" ;
#         schema:author                 authors:Betty_Edwards ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0874770882" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/854851545.ttl"^^xsd:anyURI .
#
# books:Web_Database_Apps  a                 schema:Book ;
#         rdfs:label                    "Web Database Applications" ;
#         dcterms:creator               authors:Hugh_Williams ;
#         dcterms:title                 "Web Database Applications with PHP & MySQL" ;
#         schema:author                 authors:Hugh_Williams ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0596000413" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/493005759.ttl"^^xsd:anyURI .
#
# books:Book_of_Dreams  a                    schema:Book ;
#         rdfs:label                    "Book of Dreams" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Book of Dreams" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0872860272" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/928156792.ttl"^^xsd:anyURI .
#
# books:Icefields  a                         schema:Book ;
#         rdfs:label                    "Icefields" ;
#         dcterms:creator               authors:Thomas_Wharton ;
#         dcterms:title                 "Icefields" ;
#         schema:author                 authors:Thomas_Wharton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671002201" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/248956280.ttl"^^xsd:anyURI .
#
# books:McCarthys_Bar  a                     schema:Book ;
#         rdfs:label                    "McCarthy's Bar" ;
#         dcterms:creator               authors:Pete_McCarthy ;
#         dcterms:title                 "McCarthy's Bar : a journey of discovery in Ireland" ;
#         schema:author                 authors:Pete_McCarthy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312272103" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1090861382.ttl"^^xsd:anyURI .
#
# books:The_advancing_guitarist
#         a                             schema:Book ;
#         rdfs:label                    "The Advancing Guitarist" ;
#         dcterms:creator               authors:Mick_Goodrick ;
#         dcterms:title                 "The Advancing Guitarist" ;
#         schema:author                 authors:Mick_Goodrick ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780881885897" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/935760579.ttl"^^xsd:anyURI .
#
# books:Pottery_on_the_wheel
#         a                             schema:Book ;
#         rdfs:label                    "Pottery on the Wheel" ;
#         dcterms:creator               authors:Elsbeth_Woody ;
#         dcterms:title                 "Pottery on the Wheel" ;
#         schema:author                 authors:Elsbeth_Woody ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780374236564" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1364047.ttl"^^xsd:anyURI .
#
# books:Krik_Krak  a                         schema:Book ;
#         rdfs:label                    "Krik? Krak!" ;
#         dcterms:creator               authors:Edwidge_Danticat ;
#         dcterms:title                 "Krik? Krak!" ;
#         schema:author                 authors:Edwidge_Danticat ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067976657X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33359943.ttl"^^xsd:anyURI .
#
# books:The_Magdalen  a                      schema:Book ;
#         rdfs:label                    "The Magdalen" ;
#         dcterms:creator               authors:Marita_Conlon-McKenna ;
#         dcterms:title                 "The Magdalen" ;
#         schema:author                 authors:Marita_Conlon-McKenna ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0765305135" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/48221465.ttl"^^xsd:anyURI .
#
# books:Basket_Case  a                       schema:Book ;
#         rdfs:label                    "Basket Case" ;
#         dcterms:creator               authors:Carl_Hiaasen ;
#         dcterms:title                 "Basket Case" ;
#         schema:author                 authors:Carl_Hiaasen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "044661193X" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47255262.ttl"^^xsd:anyURI .
#
# books:Cyclops  a                           schema:Book ;
#         rdfs:label                    "Cyclops" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Cyclops" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781451621020" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12836017.ttl"^^xsd:anyURI .
#
# books:Art_of_Garde_Manger  a               schema:Book ;
#         rdfs:label                    "The Professional Chef's Art of Garde Manger" ;
#         dcterms:creator               authors:Frederic_Sonnenschmidt ;
#         dcterms:title                 "The Professional Chef's Art of Garde Manger" ;
#         schema:author                 authors:Frederic_Sonnenschmidt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0843622237" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/7814240.ttl"^^xsd:anyURI .
#
# books:Complete_Guide_to_House_Plants
#         a                             schema:Book ;
#         rdfs:label                    "Complete Guide to House Plants" ;
#         dcterms:creator               authors:Jane_Coleman_Helmer ;
#         dcterms:title                 "Complete Guide to House Plants" ;
#         schema:author                 authors:Jane_Coleman_Helmer ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3579291.ttl"^^xsd:anyURI .
#
# books:Vietnam_Now  a                       schema:Book ;
#         rdfs:label                    "Vietnam, Now" ;
#         dcterms:creator               authors:David_Lamb ;
#         dcterms:title                 "Vietnam, now : a reporter returns" ;
#         schema:author                 authors:David_Lamb ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1586481835" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52620020.ttl"^^xsd:anyURI .
#
# books:Inner_Chapters  a                    schema:Book ;
#         rdfs:comment                  "Translation of Chuang Tsu's work." ;
#         rdfs:label                    "Inner Chapters" ;
#         dcterms:creator               authors:Gia-fu_Feng , authors:Jane_English ;
#         dcterms:title                 "Tao Te Ching" ;
#         schema:author                 authors:Jane_English , authors:Gia-fu_Feng ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394719905" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5007607.ttl"^^xsd:anyURI .
#
# books:Greens_Cookbook  a                   schema:Book ;
#         rdfs:label                    "The Greens Cook Book" ;
#         dcterms:creator               authors:Deborah_Madison ;
#         dcterms:title                 "The Greens cook book : extraordinary vegetarian cuisine from the celebrated restaurant" ;
#         schema:author                 authors:Deborah_Madison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553051954" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/606020479.ttl"^^xsd:anyURI .
#
# books:Guitar_Fitness  a                    schema:Book ;
#         rdfs:label                    "Guitar Fitness" ;
#         dcterms:creator               authors:Josquin_Des_Pres ;
#         dcterms:title                 "Guitar Fitness : an exercising handbook" ;
#         schema:author                 authors:Josquin_Des_Pres ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0793516978" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31294819.ttl"^^xsd:anyURI .
#
# books:Whole_World_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "Whole World Cookbook" ;
#         dcterms:creator               authors:Avery_Publishing ;
#         dcterms:title                 "Whole world cookbook : international macrobiotic cuisine" ;
#         schema:author                 authors:Avery_Publishing ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0895292319" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/817662337.ttl"^^xsd:anyURI .
#
# books:If_I_die_in_a_combat_zone
#         a                             schema:Book ;
#         rdfs:label                    "If I die in a combat zone" ;
#         dcterms:creator               authors:Tim_OBrien ;
#         dcterms:title                 "If I die in a combat zone, box me up and ship me home" ;
#         schema:author                 authors:Tim_OBrien ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0767904435" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/896882642.ttl"^^xsd:anyURI .
#
# books:Banjo_Boy  a                         schema:Book ;
#         rdfs:label                    "Banjo Boy" ;
#         dcterms:creator               authors:Vincent_Kohler ;
#         dcterms:title                 "Banjo Boy" ;
#         schema:author                 authors:Vincent_Kohler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312114753" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30473488.ttl"^^xsd:anyURI .
#
# books:Inner_Reaches  a                     schema:Book ;
#         rdfs:label                    "The Inner Reaches of Outer Space" ;
#         dcterms:creator               authors:Joseph_Campbell ;
#         dcterms:title                 "The inner reaches of outer space : metaphor as myth and as religion" ;
#         schema:author                 authors:Joseph_Campbell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060969717" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32860604.ttl"^^xsd:anyURI .
#
# books:Saratoga_Haunting  a                 schema:Book ;
#         rdfs:label                    "Saratoga Haunting" ;
#         dcterms:creator               authors:Stephen_Dobyns ;
#         dcterms:title                 "Saratoga Haunting" ;
#         schema:author                 authors:Stephen_Dobyns ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140171622" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30842037.ttl"^^xsd:anyURI .
#
# books:Water_Music_a_novel  a             schema:Book ;
#         rdfs:label                  "Water Music: a novel" ;
#         dcterms:creator             authors:T_Coraghessan_Boyle ;
#         dcterms:title               "Water Music: a novel" ;
#         schema:author               authors:T_Coraghessan_Boyle ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/7733729.ttl"^^xsd:anyURI .
#
# books:The_Magicians_Wife  a                schema:Book ;
#         rdfs:label                    "The Magician's Wife" ;
#         dcterms:creator               authors:Brian_Moore ;
#         dcterms:title                 "The Magician's Wife" ;
#         schema:author                 authors:Brian_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452279593" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37392908.ttl"^^xsd:anyURI .
#
# books:In_Days_of_Awe  a                    schema:Book ;
#         rdfs:label                    "In Days of Awe" ;
#         dcterms:creator               authors:Eric_Goodman ;
#         dcterms:title                 "In Days of Awe" ;
#         schema:author                 authors:Eric_Goodman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671776738" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/238151132.ttl"^^xsd:anyURI .
#
# books:Best_of_the_Beatles  a               schema:Book ;
#         rdfs:label                    "The Best of the Beatles : 25 greatest hits" ;
#         dcterms:creator               authors:Beatles ;
#         dcterms:title                 "The Best of the Beatles : 25 greatest hits" ;
#         schema:author                 authors:Beatles ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0793537541" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31885156.ttl"^^xsd:anyURI .
#
# books:The_Dead_Book  a                     schema:Book ;
#         rdfs:label                    "The Dead Book" ;
#         dcterms:creator               authors:Hank_Harrison ;
#         dcterms:title                 "The Dead Book" ;
#         schema:author                 authors:Hank_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0918501075" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1039403788.ttl"^^xsd:anyURI .
#
# books:The_things_they_carried
#         a                             schema:Book ;
#         rdfs:label                    "The Things They Carried : a work of fiction" ;
#         dcterms:creator               authors:Tim_OBrien ;
#         dcterms:title                 "The Things They Carried : a work of fiction" ;
#         schema:author                 authors:Tim_OBrien ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "014014773X" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/449714032.ttl"^^xsd:anyURI .
#
# books:Boy_Meets_Girl  a                    schema:Book ;
#         rdfs:label                    "Boy Meets Girl" ;
#         dcterms:creator               authors:Meg_Cabot ;
#         dcterms:title                 "Boy Meets Girl" ;
#         schema:author                 authors:Meg_Cabot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060096195" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/871012100.ttl"^^xsd:anyURI .
#
# books:Carcassi_25_Studies  a               schema:Book ;
#         rdfs:label                    "Carcassi - 25 melodic and progressive studies for guitar" ;
#         dcterms:creator               authors:Matteo_Carcassi ;
#         dcterms:title                 "Carcassi - 25 melodic and progressive studies for guitar" ;
#         schema:author                 authors:Matteo_Carcassi ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41382742.ttl"^^xsd:anyURI .
#
# books:The_Funnies  a                     schema:Book ;
#         rdfs:label                  "The Funnies" ;
#         dcterms:creator             authors:J_Robert_Lennon ;
#         dcterms:title               "The Funnies" ;
#         schema:author               authors:J_Robert_Lennon ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/39765311.ttl"^^xsd:anyURI .
#
# books:Data_Mining  a                       schema:Book ;
#         rdfs:label                    "Data mining : concepts and techniques" ;
#         dcterms:creator               authors:Jiawei_Han ;
#         dcterms:title                 "Data mining : concepts and techniques" ;
#         schema:author                 authors:Jiawei_Han ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780123814791" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1080411368.ttl"^^xsd:anyURI .
#
# books:Food_Lovers_Companion
#         a                             schema:Book ;
#         rdfs:label                    "The New Food Lover's Companion" ;
#         dcterms:creator               authors:Sharon_Tyler_Herbst ;
#         dcterms:title                 "The New Food Lover's Companion" ;
#         schema:author                 authors:Sharon_Tyler_Herbst ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0812015207" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/968179390.ttl"^^xsd:anyURI .
#
# books:Ultimate_Scales_Modes
#         a                             schema:Book ;
#         rdfs:label                    "Ultimate Scales & Modes for Guitar" ;
#         dcterms:creator               authors:Sal_Salvador ;
#         dcterms:title                 "Ultimate Scales & Modes for Guitar" ;
#         schema:author                 authors:Sal_Salvador ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37644015.ttl"^^xsd:anyURI .
#
# books:Sisters_of_the_Earth
#         a                             schema:Book ;
#         rdfs:label                    "Sisters of the Earth" ;
#         dcterms:creator               authors:Lorraine_Anderson ;
#         dcterms:title                 "Sisters of the Earth : women's prose and poetry about nature" ;
#         schema:author                 authors:Lorraine_Anderson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679733825" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924995896.ttl"^^xsd:anyURI .
#
# books:Seven_spiritual_laws_of_success
#         a                           schema:Book ;
#         rdfs:label                  "The seven spiritual laws of success" ;
#         dcterms:creator             authors:Deepak_Chopra ;
#         dcterms:title               "The seven spiritual laws of success" ;
#         schema:author               authors:Deepak_Chopra ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/32182824.ttl"^^xsd:anyURI .
#
# books:Hemingways_Chair  a                  schema:Book ;
#         rdfs:label                    "Hemingway's Chair" ;
#         dcterms:creator               authors:Michael_Palin ;
#         dcterms:title                 "Hemingway's Chair" ;
#         schema:author                 authors:Michael_Palin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312205503" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41713736.ttl"^^xsd:anyURI .
#
# books:Guide_to_Chords_Scales_Arpeggios
#         a                             schema:Book ;
#         rdfs:label                    "Guide to Chords, Scales, & Arpeggios" ;
#         dcterms:creator               authors:Al_Di_Meola ;
#         dcterms:title                 "Guide to Chords, Scales, & Arpeggios" ;
#         schema:author                 authors:Al_Di_Meola ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/317714834.ttl"^^xsd:anyURI .
#
# books:Natures_Foods  a                     schema:Book ;
#         rdfs:label                    "Nature's Foods" ;
#         dcterms:creator               authors:Peter_Deadman , authors:Karen_Betteridge ;
#         dcterms:title                 "Nature's Foods" ;
#         schema:author                 authors:Karen_Betteridge , authors:Peter_Deadman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877283869" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/6702919.ttl"^^xsd:anyURI .
#
# books:Cordelia_Underwood  a                schema:Book ;
#         rdfs:label                    "Cordelia Underwood" ;
#         dcterms:creator               authors:Van_Reid ;
#         dcterms:title                 "Cordelia Underwood" ;
#         schema:author                 authors:Van_Reid ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140280103" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38324648.ttl"^^xsd:anyURI .
#
# books:Mike_Hammer_Collection
#         a                             schema:Book ;
#         rdfs:label                    "The Mike Hammer Collection" ;
#         dcterms:creator               authors:Mickey_Spillane ;
#         dcterms:title                 "The Mike Hammer Collection" ;
#         schema:author                 authors:Mickey_Spillane ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451203526" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/503175961.ttl"^^xsd:anyURI .
#
# books:Farmer  a                            schema:Book ;
#         rdfs:label                    "Farmer" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Farmer" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385282281" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/858818953.ttl"^^xsd:anyURI .
#
# books:The_Brothers_K  a                    schema:Book ;
#         rdfs:label                    "The Brothers K" ;
#         dcterms:creator               authors:David_James_Duncan ;
#         dcterms:title                 "The Brothers K" ;
#         schema:author                 authors:David_James_Duncan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "055337849X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/894501958.ttl"^^xsd:anyURI .
#
# books:Simple_Printmaking  a                schema:Book ;
#         rdfs:label                    "Simple Printmaking: a Beginner's Guide" ;
#         dcterms:creator               authors:Gwen_Diehn ;
#         dcterms:title                 "Simple printmaking : a beginner's guide to making relief prints with linoleum blocks, wood blocks, rubber stamps, found objects & more" ;
#         schema:author                 authors:Gwen_Diehn ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1579901581" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/44267776.ttl"^^xsd:anyURI .
#
# books:How_to_Find_Work_You_Love
#         a                             schema:Book ;
#         rdfs:label                    "How to Find the Work You Love" ;
#         dcterms:creator               authors:Laurence_Boldt ;
#         dcterms:title                 "How to Find the Work You Love" ;
#         schema:author                 authors:Laurence_Boldt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140195246" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33041869.ttl"^^xsd:anyURI .
#
# books:Rolling_Stone_JG_3  a                schema:Book ;
#         rdfs:label                    "Rolling Stone: Jerry Garcia Issue 3" ;
#         dcterms:creator               authors:Rolling_Stone ;
#         dcterms:title                 "Rolling Stone: Jerry Garcia Issue 3" ;
#         schema:author                 authors:Rolling_Stone ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:White_Jazz  a                        schema:Book ;
#         rdfs:label                    "White Jazz" ;
#         dcterms:creator               authors:James_Ellroy ;
#         dcterms:title                 "White Jazz : a novel" ;
#         schema:author                 authors:James_Ellroy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375727361" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/494098205.ttl"^^xsd:anyURI .
#
# books:Sugar_Cage  a                        schema:Book ;
#         rdfs:label                    "Sugar Cage" ;
#         dcterms:creator               authors:Connie_May_Fowler ;
#         dcterms:title                 "Sugar Cage" ;
#         schema:author                 authors:Connie_May_Fowler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671748092" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23765961.ttl"^^xsd:anyURI .
#
# books:So_Far_From_God  a                   schema:Book ;
#         rdfs:label                    "So Far From God" ;
#         dcterms:creator               authors:Ana_Castillo ;
#         dcterms:title                 "So Far From God" ;
#         schema:author                 authors:Ana_Castillo ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452272092" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/29470626.ttl"^^xsd:anyURI .
#
# books:Man_of_People  a                     schema:Book ;
#         rdfs:label                    "A Man of the People" ;
#         dcterms:creator               authors:Chinua_Achebe ;
#         dcterms:title                 "A Man of the People" ;
#         schema:author                 authors:Chinua_Achebe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385086164" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1052671814.ttl"^^xsd:anyURI .
#
# books:Gold_Bug_Variations  a               schema:Book ;
#         rdfs:label                    "The Gold Bug Variations" ;
#         dcterms:creator               authors:Richard_Powers ;
#         dcterms:title                 "The Gold Bug Variations" ;
#         schema:author                 authors:Richard_Powers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060975008" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/844016021.ttl"^^xsd:anyURI .
#
# books:All_the_Pretty_Horses
#         a                             schema:Book ;
#         rdfs:label                    "All the Pretty Horses" ;
#         dcterms:creator               authors:Cormac_McCarthy ;
#         dcterms:title                 "All the Pretty Horses" ;
#         schema:author                 authors:Cormac_McCarthy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679744398" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/858025466.ttl"^^xsd:anyURI .
#
# books:Pine_Barrens  a                      schema:Book ;
#         rdfs:label                    "The Pine Barrens" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "The Pine Barrens" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374514429" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/26487843.ttl"^^xsd:anyURI .
#
# books:Emotionally_Weird  a                 schema:Book ;
#         rdfs:label                    "Emotionally Weird" ;
#         dcterms:creator               authors:Kate_Atkinson ;
#         dcterms:title                 "Emotionally Weird" ;
#         schema:author                 authors:Kate_Atkinson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "031227999X" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/44120095.ttl"^^xsd:anyURI .
#
# books:Fingerbook_Workbook  a               schema:Book ;
#         rdfs:label                    "The fingerbook workbook: concepts in logical fingering" ;
#         dcterms:creator               authors:Barry_Galbraith ;
#         dcterms:title                 "The fingerbook workbook: concepts in logical fingering" ;
#         schema:author                 authors:Barry_Galbraith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781562240387" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1073711632.ttl"^^xsd:anyURI .
#
# books:Cousins  a                           schema:Book ;
#         rdfs:label                    "Cousins" ;
#         dcterms:creator               authors:Patricia_Grace ;
#         dcterms:title                 "Cousins" ;
#         schema:author                 authors:Patricia_Grace ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0824820746" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/474299813.ttl"^^xsd:anyURI .
#
# books:Flickering_Shadows  a              schema:Book ;
#         rdfs:label                  "Flickering Shadows" ;
#         dcterms:creator             authors:Kwadwo_Agymah_Kamau ;
#         dcterms:title               "Flickering Shadows" ;
#         schema:author               authors:Kwadwo_Agymah_Kamau ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/34604208.ttl"^^xsd:anyURI .
#
# books:A_Confederacy_of_Dunces
#         a                             schema:Book ;
#         rdfs:label                    "A Confederacy of Dunces" ;
#         dcterms:creator               authors:John_Kennedy_Toole ;
#         dcterms:title                 "A Confederacy of Dunces" ;
#         schema:author                 authors:John_Kennedy_Toole ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0807106577" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5336849.ttl"^^xsd:anyURI .
#
# books:Crazy_for_Trying  a                  schema:Book ;
#         rdfs:label                    "Crazy for Trying" ;
#         dcterms:creator               authors:Joni_Rodgers ;
#         dcterms:title                 "Crazy for Trying ; a novel" ;
#         schema:author                 authors:Joni_Rodgers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878448927" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45729773.ttl"^^xsd:anyURI .
#
# books:Silver_Palate_Cookbook
#         a                           schema:Book ;
#         rdfs:label                  "The Silver Palate Cookbook" ;
#         dcterms:creator             authors:Sheila_Lukins , authors:Julee_Rosso ;
#         dcterms:title               "The Silver Palate Cookbook" ;
#         schema:author               authors:Sheila_Lukins , authors:Julee_Rosso ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/8171905.ttl"^^xsd:anyURI .
#
# books:Big_Stone_Gap  a                   schema:Book ;
#         rdfs:label                  "Big Stone Gap : a novel" ;
#         dcterms:creator             authors:Adriana_Trigiani ;
#         dcterms:title               "Big Stone Gap : a novel" ;
#         schema:author               authors:Adriana_Trigiani ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/42072234.ttl"^^xsd:anyURI .
#
# books:Winter_of_Our_Discontent
#         a                             schema:Book ;
#         rdfs:label                    "The Winter of Our Discontent" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "The Winter of Our Discontent" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140062211" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/410042654.ttl"^^xsd:anyURI .
#
# books:The_Fall  a                          schema:Book ;
#         rdfs:label                    "The Fall" ;
#         dcterms:creator               authors:Albert_Camus ;
#         dcterms:title                 "The Fall" ;
#         schema:author                 authors:Albert_Camus ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/4293956.ttl"^^xsd:anyURI .
#
# books:Sea_of_Cortez  a                     schema:Book ;
#         rdfs:label                    "The Log From the Sea of Cortez" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "The Log From the Sea of Cortez" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "014004261X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/875986713.ttl"^^xsd:anyURI .
#
# books:Fools_Gold  a                        schema:Book ;
#         rdfs:label                    "Fool's Gold" ;
#         dcterms:creator               authors:Jane_S_Smith ;
#         dcterms:title                 "Fool's gold : a novel" ;
#         schema:author                 authors:Jane_S_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1581950357" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45556213.ttl"^^xsd:anyURI .
#
# books:Knots_ties_splices  a              schema:Book ;
#         rdfs:label                  "Knots, ties and splices" ;
#         dcterms:creator             authors:J_Tom_Burgess , authors:Crab_Searl ;
#         dcterms:title               "Knots, ties and splices : a handbook for seafarers, travellers and all who use cordage, with special notes " ;
#         schema:author               authors:J_Tom_Burgess ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Crab_Searl ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/877228297.ttl"^^xsd:anyURI .
#
# books:The_Mystery_Roast  a                 schema:Book ;
#         rdfs:label                    "The Mystery Roast" ;
#         dcterms:creator               authors:Peter_Gadol ;
#         dcterms:title                 "The Mystery Roast" ;
#         schema:author                 authors:Peter_Gadol ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312151764" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35159324.ttl"^^xsd:anyURI .
#
# books:Cataloging_Classification
#         a                             schema:Book ;
#         rdfs:label                    "Cataloging and Classification" ;
#         dcterms:creator               authors:Lois_Mai_Chan ;
#         dcterms:title                 "Cataloging and classification : an introduction" ;
#         schema:author                 authors:Lois_Mai_Chan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780810860001" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/804354590.ttl"^^xsd:anyURI .
#
# books:New_Dictionary_Music
#         a                             schema:Book ;
#         rdfs:label                    "A New Dictionary Music" ;
#         dcterms:creator               authors:Arthur_Jacobs ;
#         dcterms:title                 "A New Dictionary Music" ;
#         schema:author                 authors:Arthur_Jacobs ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1072411046.ttl"^^xsd:anyURI .
#
# books:The_Moon_Under_Her_Feet
#         a                             schema:Book ;
#         rdfs:label                    "The Moon Under Her Feet" ;
#         dcterms:creator               authors:Clysta_Kinstler ;
#         dcterms:title                 "The Moon Under Her Feet" ;
#         schema:author                 authors:Clysta_Kinstler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0062504975" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22493459.ttl"^^xsd:anyURI .
#
# books:The_Back_Country  a                  schema:Book ;
#         rdfs:label                    "The Back Country" ;
#         dcterms:creator               authors:Gary_Snyder ;
#         dcterms:title                 "The Back Country" ;
#         schema:author                 authors:Gary_Snyder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811201945" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/246269807.ttl"^^xsd:anyURI .
#
# books:The_Superhuman_Crew  a               schema:Book ;
#         rdfs:label                    "The Superhuman Crew" ;
#         dcterms:creator               authors:James_Ensor , authors:Bob_Dylan ;
#         dcterms:title                 "The Superhuman Crew" ;
#         schema:author                 authors:James_Ensor , authors:Bob_Dylan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0892365528" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59376779.ttl"^^xsd:anyURI .
#
# books:The_Road_Home  a                     schema:Book ;
#         rdfs:label                    "The Road Home" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "The Road Home" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0871137240" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42827031.ttl"^^xsd:anyURI .
#
# books:Maritime_NW_Garden_Guide
#         a                             schema:Book ;
#         rdfs:label                    "Maritime Northwest Garden Guide" ;
#         dcterms:creator               authors:Carl_Elliot ;
#         dcterms:title                 "The Maritime northwest garden guide : planning calendar for year-round organic gardening" ;
#         schema:author                 authors:Carl_Elliot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0931380189" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1052630183.ttl"^^xsd:anyURI .
#
# books:Changing_Seasons_Macrobiotic
#         a                             schema:Book ;
#         rdfs:label                    "The Changing Seasons Macrobiotic Cookbook" ;
#         dcterms:creator               authors:Aveline_Kushi , authors:Wendy_Esko ;
#         dcterms:title                 "The Changing Seasons Macrobiotic Cookbook" ;
#         schema:author                 authors:Wendy_Esko , authors:Aveline_Kushi ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0895292327" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/11290843.ttl"^^xsd:anyURI .
#
# books:Illusions  a                         schema:Book ;
#         rdfs:label                    "Illusions : the adventures of a reluctant Messiah" ;
#         dcterms:creator               authors:Richard_Bach ;
#         dcterms:title                 "Illusions : the adventures of a reluctant Messiah" ;
#         schema:author                 authors:Richard_Bach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440139791" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5176331.ttl"^^xsd:anyURI .
#
# books:Rum_Punch  a                         schema:Book ;
#         rdfs:label                    "Rum Punch" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Rum Punch" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060082194" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24671033.ttl"^^xsd:anyURI .
#
# books:A_Wrinkle_in_Time  a                 schema:Book ;
#         rdfs:label                    "A Wrinkle in Time" ;
#         dcterms:creator               authors:Madeleine_Lengle ;
#         dcterms:title                 "A Wrinkle in Time" ;
#         schema:author                 authors:Madeleine_Lengle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440498058" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22421788.ttl"^^xsd:anyURI .
#
# books:FullWoman_FleshyApple
#         a                             schema:Book ;
#         rdfs:label                    "Full Woman, Fleshy Apple, Hot Moon" ;
#         dcterms:creator               authors:Pablo_Neruda , authors:Stephen_Mitchell ;
#         dcterms:title                 "Full Woman, Fleshy Apple, Hot Moon: Selected Poems of Pablo Neruda" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0061733571" ;
#         schema:translator             authors:Stephen_Mitchell ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/973542925.ttl"^^xsd:anyURI .
#
# books:Educational_Research
#         a                             schema:Book ;
#         rdfs:label                    "Educational Research" ;
#         dcterms:creator               authors:James_McMillan ;
#         dcterms:title                 "Educational Research : fundamentals for the consumer" ;
#         schema:author                 authors:James_McMillan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0673384497" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23731851.ttl"^^xsd:anyURI .
#
# books:On_Celtic_Tides  a                   schema:Book ;
#         rdfs:label                    "On Celtic Tides" ;
#         dcterms:creator               authors:Chris_Duff ;
#         dcterms:title                 "On Celtic Tides" ;
#         schema:author                 authors:Chris_Duff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312263686" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/600186523.ttl"^^xsd:anyURI .
#
# books:The_Turquoise_Dragon
#         a                             schema:Book ;
#         rdfs:label                    "The Turquoise Dragon" ;
#         dcterms:creator               authors:David_Rains_Wallace ;
#         dcterms:title                 "The Turquoise Dragon : a mystery" ;
#         schema:author                 authors:David_Rains_Wallace ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0871567105" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16530436.ttl"^^xsd:anyURI .
#
# books:Deadbase_X  a                        schema:Book ;
#         rdfs:label                    "DeadBase X" ;
#         dcterms:creator               authors:John_W_Scott ;
#         dcterms:title                 "DeadBase X : the complete guide to Grateful Dead song lists" ;
#         schema:author                 authors:John_W_Scott ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1877657212" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39303081.ttl"^^xsd:anyURI .
#
# books:The_Lost_Coast  a                    schema:Book ;
#         rdfs:label                    "The Lost Coast" ;
#         dcterms:creator               authors:Steven_Nightingale ;
#         dcterms:title                 "The Lost Coast" ;
#         schema:author                 authors:Michael_Palin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312155727" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36521088.ttl"^^xsd:anyURI .
#
# books:Bangkok_8  a                         schema:Book ;
#         rdfs:label                    "Bangkok 8" ;
#         dcterms:creator               authors:John_Burdett ;
#         dcterms:title                 "Bangkok 8" ;
#         schema:author                 authors:John_Burdett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400032903" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1099286073.ttl"^^xsd:anyURI .
#
# books:On_Green_Dolphin_Street
#         a                             schema:Book ;
#         rdfs:label                    "On Green Dolphin Street" ;
#         dcterms:creator               authors:Sebastian_Faulks ;
#         dcterms:title                 "On Green Dolphin Street : a novel" ;
#         schema:author                 authors:Sebastian_Faulks ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375502254" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/320614579.ttl"^^xsd:anyURI .
#
# books:Spartan_Gold  a                      schema:Book ;
#         rdfs:label                    "Spartan Gold" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Spartan Gold" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425236291" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1065722481.ttl"^^xsd:anyURI .
#
# books:Tao_te_ching_2  a                    schema:Book ;
#         rdfs:label                    "Tao Te Ching" ;
#         dcterms:creator               authors:Jingxiong_Wu ;
#         dcterms:title                 "Tao Te Ching" ;
#         schema:author                 authors:Jingxiong_Wu ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877735425" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/671079723.ttl"^^xsd:anyURI .
#
# books:The_Miserable_Mill  a              schema:Book ;
#         rdfs:label                  "The Miserable Mill" ;
#         dcterms:creator             authors:Brett_Helquist ;
#         dcterms:title               "The Miserable Mill" ;
#         schema:author               authors:Brett_Helquist ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/42021532.ttl"^^xsd:anyURI .
#
# books:Artemis_Fowl  a                      schema:Book ;
#         rdfs:label                    "Artemis Fowl" ;
#         dcterms:creator               authors:Eoin_Colfer ;
#         dcterms:title                 "Artemis Fowl" ;
#         schema:author                 authors:Eoin_Colfer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0786814934" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  2 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52741261.ttl"^^xsd:anyURI .
#
# books:Hotel_Pastis  a                      schema:Book ;
#         rdfs:label                    "Hotel Pastis : a novel of Provence " ;
#         dcterms:creator               authors:Peter_Mayle ;
#         dcterms:title                 "Hotel Pastis : a novel of Provence " ;
#         schema:author                 authors:Peter_Mayle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679751114" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/820804101.ttl"^^xsd:anyURI .
#
# books:Red_Wolf_Red_Wolf  a                 schema:Book ;
#         rdfs:label                    "Red Wolf, Red Wolf" ;
#         dcterms:creator               authors:WP_Kinsella ;
#         dcterms:title                 "Red Wolf, Red Wolf" ;
#         schema:author                 authors:WP_Kinsella ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0870743147" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22458362.ttl"^^xsd:anyURI .
#
# books:In_the_Lake_of_the_Woods
#         a                             schema:Book ;
#         rdfs:label                    "In the Lake of the Woods" ;
#         dcterms:creator               authors:Tim_OBrien ;
#         dcterms:title                 "In the Lake of the Woods" ;
#         schema:author                 authors:Tim_OBrien ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140250948" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30895945.ttl"^^xsd:anyURI .
#
# books:Book_of_blues_guitar_licks
#         a                             schema:Book ;
#         rdfs:label                    "Mel Bay's Complete Book of Blues Guitar Licks & Phrases" ;
#         dcterms:creator               authors:Austin_Sicard ;
#         dcterms:title                 "Mel Bay's Complete Book of Blues Guitar Licks & Phrases" ;
#         schema:author                 authors:Austin_Sicard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1562222880" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32693013.ttl"^^xsd:anyURI .
#
# books:Sometimes_a_Great_Notion
#         a                             schema:Book ;
#         rdfs:label                    "Sometimes a Great Notion" ;
#         dcterms:creator               authors:Ken_Kesey ;
#         dcterms:title                 "Sometimes a Great Notion" ;
#         schema:author                 authors:Ken_Kesey ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/970506555.ttl"^^xsd:anyURI .
#
# books:Maya   a                             schema:Book ;
#         rdfs:label                    "Maya" ;
#         dcterms:creator               authors:Jostein_Gaarder ;
#         dcterms:title                 "Maya" ;
#         schema:author                 authors:Jostein_Gaarder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1861591837" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/49204890.ttl"^^xsd:anyURI .
#
# books:Dead_in_the_Water  a                 schema:Book ;
#         rdfs:label                    "Dead in the Water" ;
#         dcterms:creator               authors:Stuart_Woods ;
#         dcterms:title                 "Dead in the Water" ;
#         schema:author                 authors:Stuart_Woods ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780061711916" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/236329445.ttl"^^xsd:anyURI .
#
# books:The_Way_of_Zen  a                    schema:Book ;
#         rdfs:label                    "The Way of Zen" ;
#         dcterms:creator               authors:Alan_Watts ;
#         dcterms:title                 "The Way of Zen" ;
#         schema:author                 authors:Alan_Watts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394451198" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/228493.ttl"^^xsd:anyURI .
#
# books:Colony_Unrequited_Dreams
#         a                             schema:Book ;
#         rdfs:label                    "The Colony of Unrequited Dreams" ;
#         dcterms:creator               authors:Wayne_Johnston ;
#         dcterms:title                 "The Colony of Unrequited Dreams" ;
#         schema:author                 authors:Wayne_Johnston ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385495439" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1111713310.ttl"^^xsd:anyURI .
#
# books:Heart_of_the_Fire  a                 schema:Book ;
#         rdfs:label                    "Heart of the Fire" ;
#         dcterms:creator               authors:Cerridwen_Fallingstar ;
#         dcterms:title                 "The Heart of the Fire : a novel" ;
#         schema:author                 authors:Cerridwen_Fallingstar ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0962147001" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23810524.ttl"^^xsd:anyURI .
#
# books:Passage_to_Juneau  a                 schema:Book ;
#         rdfs:label                    "Passage to Juneau" ;
#         dcterms:creator               authors:Jonathan_Raban ;
#         dcterms:title                 "Passage to Juneau" ;
#         schema:author                 authors:Jonathan_Raban ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679776141" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1153178600.ttl"^^xsd:anyURI .
#
# books:Bluesman  a                          schema:Book ;
#         rdfs:label                    "Bluesman" ;
#         dcterms:creator               authors:Andre_Dubus ;
#         dcterms:title                 "Bluesman" ;
#         schema:author                 authors:Andre_Dubus ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0571198414" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/316142483.ttl"^^xsd:anyURI .
#
# books:The_Dead  a                          schema:Book ;
#         rdfs:label                    "The Dead" ;
#         dcterms:creator               authors:Hank_Harrison ;
#         dcterms:title                 "The Dead" ;
#         schema:author                 authors:Hank_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0890873003" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/463342010.ttl"^^xsd:anyURI .
#
# books:Time_Travelers_Wife  a               schema:Book ;
#         rdfs:label                    "The Time Traveler's Wife" ;
#         dcterms:creator               authors:Audrey_Niffenegger ;
#         dcterms:title                 "The Time Traveler's Wife" ;
#         schema:author                 authors:Audrey_Niffenegger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "015602943X" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/496183854.ttl"^^xsd:anyURI .
#
# books:Simply_Shrimp  a                     schema:Book ;
#         rdfs:label                    "Simply Shrimp" ;
#         dcterms:creator               authors:Glenn_Day ;
#         dcterms:title                 "Simply Shrimp" ;
#         schema:author                 authors:Glenn_Day ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0895944014" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20935108.ttl"^^xsd:anyURI .
#
# books:The_Orchid_Thief  a                  schema:Book ;
#         rdfs:label                    "The Orchid Thief" ;
#         dcterms:creator               authors:Susan_Orlean ;
#         dcterms:title                 "The Orchid Thief" ;
#         schema:author                 authors:Susan_Orlean ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "044900371X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/911609299.ttl"^^xsd:anyURI .
#
# books:Cascade_Olympic_Natural_History
#         a                             schema:Book ;
#         rdfs:label                    "Cascade-Olympic Natural History" ;
#         dcterms:creator               authors:Daniel_Mathews ;
#         dcterms:title                 "Cascade-Olympic Natural History" ;
#         schema:author                 authors:Daniel_Mathews ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0962078212" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/18416377.ttl"^^xsd:anyURI .
#
# books:Modern_Recording_Techniques
#         a                             schema:Book ;
#         rdfs:label                    "Modern Recording Techniques" ;
#         dcterms:creator               authors:David_Huber ;
#         dcterms:title                 "Modern Recording Techniques" ;
#         schema:author                 authors:David_Huber ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0240803086" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924953624.ttl"^^xsd:anyURI .
#
# books:Butterfly_Stories  a                 schema:Book ;
#         rdfs:label                    "Butterfly Stories" ;
#         dcterms:creator               authors:William_Vollmann ;
#         dcterms:title                 "Butterfly Stories" ;
#         schema:author                 authors:William_Vollmann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802134009" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1106929797.ttl"^^xsd:anyURI .
#
# books:Wild_meat_and_bully_burgers
#         a                             schema:Book ;
#         rdfs:label                    "Wild Meat and the Bully Burgers" ;
#         dcterms:creator               authors:Lois-Ann_Yamanaka ;
#         dcterms:title                 "Wild Meat and the Bully Burgers : [a novel]" ;
#         schema:author                 authors:Lois-Ann_Yamanaka ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374290202" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/636113793.ttl"^^xsd:anyURI .
#
# books:Jazz_Guitar_Masterpieces
#         a                             schema:Book ;
#         rdfs:label                    "Jazz Guitar Masterpieces" ;
#         dcterms:creator               authors:Rich_Carter ;
#         dcterms:title                 "Jazz Guitar Masterpieces" ;
#         schema:author                 authors:Rich_Carter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825697301" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/60365852.ttl"^^xsd:anyURI .
#
# books:Keep_the_Change  a                   schema:Book ;
#         rdfs:label                    "Keep the Change" ;
#         dcterms:creator               authors:Thomas_McGuane ;
#         dcterms:title                 "Keep the Change" ;
#         schema:author                 authors:Thomas_McGuane ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679730338" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19322955.ttl"^^xsd:anyURI .
#
# books:Expression_in_music  a               schema:Book ;
#         rdfs:label                    "Expression in Music" ;
#         dcterms:creator               authors:HA_VanderCook ;
#         dcterms:title                 "Expression in Music" ;
#         schema:author                 authors:HA_VanderCook ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1423489179" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/948479261.ttl"^^xsd:anyURI .
#
# books:Alice_in_Wonderland  a               schema:Book ;
#         rdfs:label                    "Alice in Wonderland and Through the looking glass" ;
#         dcterms:creator               authors:Lewis_Carroll ;
#         dcterms:title                 "Alice in Wonderland and Through the Looking Glass" ;
#         schema:author                 authors:Lewis_Carroll ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/8990946.ttl"^^xsd:anyURI .
#
# books:The_Education_of_Little_Tree
#         a                             schema:Book ;
#         rdfs:label                    "The Education of Little Tree" ;
#         dcterms:creator               authors:Forrest_Carter ;
#         dcterms:title                 "The Education of Little Tree" ;
#         schema:author                 authors:Forrest_Carter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0826308791" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22981484.ttl"^^xsd:anyURI .
#
# books:God_Bless_You_Mr_Rosewater
#         a                             schema:Book ;
#         rdfs:label                    "God bless you, Mr. Rosewater" ;
#         dcterms:creator               authors:Kurt_Vonnegut ;
#         dcterms:title                 "God bless you, Mr. Rosewater" ;
#         schema:author                 authors:Kurt_Vonnegut ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "044012929X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/850813719.ttl"^^xsd:anyURI .
#
# books:Galapagos  a                         schema:Book ;
#         rdfs:label                    "Galápagos" ;
#         dcterms:creator               authors:Kurt_Vonnegut ;
#         dcterms:title                 "Galápagos : a novel" ;
#         schema:author                 authors:Kurt_Vonnegut ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440127793" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/441835988.ttl"^^xsd:anyURI .
#
# books:The_House_on_the_Lagoon
#         a                             schema:Book ;
#         rdfs:label                    "The House on the Lagoon" ;
#         dcterms:creator               authors:Rosario_Ferre ;
#         dcterms:title                 "The House on the Lagoon" ;
#         schema:author                 authors:Rosario_Ferre ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452277078" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476914239.ttl"^^xsd:anyURI .
#
# books:In_the_Time_of_the_Butterflies
#         a                             schema:Book ;
#         rdfs:label                    "In the Time of the Butterflies" ;
#         dcterms:creator               authors:Julia_Alvarez ;
#         dcterms:title                 "In the Time of the Butterflies" ;
#         schema:author                 authors:Julia_Alvarez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452274427" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/422748699.ttl"^^xsd:anyURI .
#
# books:Axe_Handles  a                       schema:Book ;
#         rdfs:label                    "Axe Handles" ;
#         dcterms:creator               authors:Gary_Snyder ;
#         dcterms:title                 "Axe Handles: poems by Gary Snyder" ;
#         schema:author                 authors:Gary_Snyder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0865471207" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/867909327.ttl"^^xsd:anyURI .
#
# books:Authentic_Guitar_Classics
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead : Authentic Guitar Classics, Vol. 2" ;
#         dcterms:creator               authors:Jerry_Garcia ;
#         dcterms:title                 "Grateful Dead : Authentic Guitar Classics, Vol. 2" ;
#         schema:author                 authors:Jerry_Garcia ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1576232565" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46370661.ttl"^^xsd:anyURI .
#
# books:The_Jukebox_Queen_of_Malta
#         a                             schema:Book ;
#         rdfs:label                    "The Jukebox Queen of Malta" ;
#         dcterms:creator               authors:Nicholas_Rinaldi ;
#         dcterms:title                 "The Jukebox Queen of Malta" ;
#         schema:author                 authors:Nicholas_Rinaldi ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684867427" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/78064228.ttl"^^xsd:anyURI .
#
# books:Wintergreen_rambles_in_a_ravaged_land
#         a                             schema:Book ;
#         rdfs:label                    "Wintergreen: Rambles in a Ravaged Land" ;
#         dcterms:creator               authors:Robert_Michael_Pyle ;
#         dcterms:title                 "Wintergreen: rambles in a ravaged land" ;
#         schema:author                 authors:Robert_Michael_Pyle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684183218" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/14134756.ttl"^^xsd:anyURI .
#
# books:Legend_Best_of_Bob_Marley
#         a                             schema:Book ;
#         rdfs:label                    "Legend : the Best of Bob Marley and the Wailers" ;
#         dcterms:creator               authors:Bob_Marley ;
#         dcterms:title                 "Legend : the Best of Bob Marley and the Wailers" ;
#         schema:author                 authors:Bob_Marley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0793537002" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35106258.ttl"^^xsd:anyURI .
#
# books:Dexterity  a                         schema:Book ;
#         rdfs:label                    "Dexterity" ;
#         dcterms:creator               authors:Douglas_Bauer ;
#         dcterms:title                 "Dexterity : a novel" ;
#         schema:author                 authors:Douglas_Bauer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0805043020" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40180202.ttl"^^xsd:anyURI .
#
# books:The_Control_of_Nature
#         a                             schema:Book ;
#         rdfs:label                    "The Control of Nature" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "The Control of Nature" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374128901" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19264143.ttl"^^xsd:anyURI .
#
# books:Grandma_Lived_in_Gooligulch
#         a                             schema:Book ;
#         rdfs:label                    "My Grandma Lived in Gooligulch" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "My Grandma Lived in Gooligulch" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140509410" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/812934933.ttl"^^xsd:anyURI .
#
# books:Nouveau_Flamenco  a                  schema:Book ;
#         rdfs:label                    "Nouveau Flamenco" ;
#         dcterms:creator               authors:Ottmar_Liebert ;
#         dcterms:title                 "Nouveau Flamenco" ;
#         schema:author                 authors:Ottmar_Liebert ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781569221372" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38560113.ttl"^^xsd:anyURI .
#
# books:New_Natural_Foods_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "New York Times New Natural Foods Cookbook" ;
#         dcterms:creator               authors:Jean_Hewitt ;
#         dcterms:title                 "The New York Times New Natural Foods Cookbook" ;
#         schema:author                 authors:Jean_Hewitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "038062687X" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9661619.ttl"^^xsd:anyURI .
#
# books:Richard_Thompson_bio
#         a                             schema:Book ;
#         rdfs:label                    "Richard Thompson : the biography" ;
#         dcterms:creator               authors:Patrick_Humphries ;
#         dcterms:title                 "Richard Thompson : the biography" ;
#         schema:author                 authors:Patrick_Humphries ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0028647521" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36017030.ttl"^^xsd:anyURI .
#
# books:Microsoft_Project_2010
#         a                             schema:Book ;
#         rdfs:label                    "Microsoft Project 2010" ;
#         dcterms:creator               authors:Rachel_Biheller_Bunin ;
#         dcterms:title                 "Microsoft Project 2010 : Introductory" ;
#         schema:author                 authors:Rachel_Biheller_Bunin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780538746762" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/737492568.ttl"^^xsd:anyURI .
#
# books:Art_of_Cheese  a                     schema:Book ;
#         rdfs:label                    "The Art of Selecting and Serving Cheese" ;
#         dcterms:creator               authors:Try_Foods_Intl ;
#         dcterms:title                 "The Art of Selecting and Serving Cheese" ;
#         schema:author                 authors:Try_Foods_Intl ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1057356347.ttl"^^xsd:anyURI .
#
# books:Cross_Country  a                     schema:Book ;
#         rdfs:label                    "Cross Country" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "Cross Country" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0739492187" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/225870340.ttl"^^xsd:anyURI .
#
# books:The_Ersatz_Elevator  a             schema:Book ;
#         rdfs:label                  "The Ersatz Elevator" ;
#         dcterms:creator             authors:Brett_Helquist ;
#         dcterms:title               "The Ersatz Elevator" ;
#         schema:author               authors:Brett_Helquist ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/44777210.ttl"^^xsd:anyURI .
#
# books:Process_Quality_Mgmt
#         a                             schema:Book ;
#         rdfs:label                    "Process Quality Managment & Improvement Guidelines" ;
#         dcterms:creator               authors:ATT ;
#         dcterms:title                 "Process Quality Managment & Improvement Guidelines" ;
#         schema:author                 authors:ATT ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 .
#
# books:Making_Great_Cheese  a               schema:Book ;
#         rdfs:label                    "Making Great Cheese at Home" ;
#         dcterms:creator               authors:Barbara_Ciletti ;
#         dcterms:title                 "Making Great Cheese at Home : 30 simple recipes from cheddar the cheve" ;
#         schema:author                 authors:Barbara_Ciletti ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1579902677" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/428896149.ttl"^^xsd:anyURI .
#
# books:Living_at_the_Movies
#         a                             schema:Book ;
#         rdfs:label                    "Living at the Movies" ;
#         dcterms:creator               authors:Jim_Carroll ;
#         dcterms:title                 "Living at the Movies" ;
#         schema:author                 authors:Jim_Carroll ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140422900" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/925163197.ttl"^^xsd:anyURI .
#
# books:Lemprieres_Dictionary
#         a                             schema:Book ;
#         rdfs:label                    "Lemprière's Dictionary" ;
#         dcterms:creator               authors:Lawrence_Norfolk ;
#         dcterms:title                 "Lemprière's Dictionary" ;
#         schema:author                 authors:Lawrence_Norfolk ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0517581841" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/29152200.ttl"^^xsd:anyURI .
#
# books:A_trail_through_leaves
#         a                           schema:Book ;
#         rdfs:label                  "A trail through leaves" ;
#         dcterms:creator             authors:Hannah_Hinchman ;
#         dcterms:title               "A trail through leaves : the journal as a path to place" ;
#         schema:author               authors:Hannah_Hinchman ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/62782890.ttl"^^xsd:anyURI .
#
# books:The_Basic_Back_Book  a               schema:Book ;
#         rdfs:label                    "The Basic Back Book" ;
#         dcterms:creator               authors:Anne_Kent_Rush ;
#         dcterms:title                 "The Basic Back Book" ;
#         schema:author                 authors:Anne_Kent_Rush ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067140086X" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5101488.ttl"^^xsd:anyURI .
#
# books:Babel  a                             schema:Book ;
#         rdfs:label                    "Babel" ;
#         dcterms:creator               authors:Patti_Smith ;
#         dcterms:title                 "Babel" ;
#         schema:author                 authors:Patti_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "399121021" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3380074.ttl"^^xsd:anyURI .
#
# books:Blues_Harp  a                        schema:Book ;
#         rdfs:label                    "Blues Harp : an instruction method" ;
#         dcterms:creator               authors:Tony_Glover ;
#         dcterms:title                 "Blues harp : an instruction method for playing the blues harmonica" ;
#         schema:author                 authors:Tony_Glover ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825600189" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1078638.ttl"^^xsd:anyURI .
#
# books:Zen_flesh_Zen_bones  a               schema:Book ;
#         rdfs:label                    "Zen flesh, Zen bones" ;
#         dcterms:creator               authors:Paul_Reps ;
#         dcterms:title                 "Zen flesh, Zen bones" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Paul_Reps ;
#         schema:isbn                   "0385081308" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/312567.ttl"^^xsd:anyURI .
#
# books:In_the_Drink  a                      schema:Book ;
#         rdfs:label                    "In the Drink" ;
#         dcterms:creator               authors:Kate_Atkinson ;
#         dcterms:title                 "In the Drink" ;
#         schema:author                 authors:Kate_Atkinson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385720211" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45114282.ttl"^^xsd:anyURI .
#
# books:Common_Edible_Plants
#         a                             schema:Book ;
#         rdfs:label                    "Common Edible and Useful Plants of the West" ;
#         dcterms:creator               authors:Muriel_Sweet ;
#         dcterms:title                 "Common Edible and Useful Plants of the West" ;
#         schema:author                 authors:Muriel_Sweet ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0911010548" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23383660.ttl"^^xsd:anyURI .
#
# books:Galleys_of_Nantucket
#         a                             schema:Book ;
#         rdfs:label                    "From the Galleys of Nantucket" ;
#         dcterms:creator               authors:Ladies_Union_Circle ;
#         dcterms:title                 "From the Galleys of Nantucket" ;
#         schema:author                 authors:Ladies_Union_Circle ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/237192361.ttl"^^xsd:anyURI .
#
# books:John_Coltrane_life_and_music
#         a                           schema:Book ;
#         rdfs:label                  "John Coltrane : his life and music" ;
#         dcterms:creator             authors:Lewis_Porter ;
#         dcterms:title               "John Coltrane : his life and music" ;
#         schema:author               authors:Lewis_Porter ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/37693923.ttl"^^xsd:anyURI .
#
# books:Anna_Karenina_Book_1
#         a                             schema:Book ;
#         rdfs:label                    "Anna Karenina. Book 1" ;
#         dcterms:creator               authors:Leo_Tolstoy ;
#         dcterms:title                 "Anna Karenina. Book 1" ;
#         schema:author                 authors:Leo_Tolstoy ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/907464794.ttl"^^xsd:anyURI .
#
# books:Vincent_van_Gogh  a                  schema:Book ;
#         rdfs:label                    "Vincent van Gogh" ;
#         dcterms:creator               authors:Per_Amann ;
#         dcterms:title                 "Vincent van Gogh" ;
#         schema:author                 authors:Per_Amann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9783930653355" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37790325.ttl"^^xsd:anyURI .
#
# books:Slaughterhouse_Five  a               schema:Book ;
#         rdfs:label                    "Slaughterhouse Five" ;
#         dcterms:creator               authors:Kurt_Vonnegut ;
#         dcterms:title                 "Slaughterhouse-five, or, The children's crusade : a duty dance with death" ;
#         schema:author                 authors:Kurt_Vonnegut ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440180295" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/232125225.ttl"^^xsd:anyURI .
#
# books:Forty_Four_Scotland_St
#         a                             schema:Book ;
#         rdfs:label                    "44 Scotland Street" ;
#         dcterms:creator               authors:Alexander_McCall_Smith ;
#         dcterms:title                 "44 Scotland Street" ;
#         schema:author                 authors:Alexander_McCall_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400079446" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/58043219.ttl"^^xsd:anyURI .
#
# books:Week_on_the_Concord_and_Merrimack
#         a                             schema:Book ;
#         rdfs:label                    "A Week on the Concord and Merrimack Rivers" ;
#         dcterms:creator               authors:Henry_David_Thoreau ;
#         dcterms:title                 "A Week on the Concord and Merrimack Rivers" ;
#         schema:author                 authors:Henry_David_Thoreau ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0940450275" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/11785549.ttl"^^xsd:anyURI .
#
# books:Illywhacker  a                       schema:Book ;
#         rdfs:label                    "Illywhacker" ;
#         dcterms:creator               authors:Peter_Carey ;
#         dcterms:title                 "Illywhacker" ;
#         schema:author                 authors:Peter_Carey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679767908" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/904948711.ttl"^^xsd:anyURI .
#
# books:Guitar_Chord_Chart  a                schema:Book ;
#         rdfs:label                    "Guitar Chord Chart" ;
#         dcterms:creator               authors:Mel_Bay ;
#         dcterms:title                 "Guitar Chord Chart" ;
#         schema:author                 authors:Mel_Bay ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/10720780.ttl"^^xsd:anyURI .
#
# books:Murder_Wrigley_Field
#         a                             schema:Book ;
#         rdfs:label                    "Murder at Wrigley Field" ;
#         dcterms:creator               authors:Troy_Soos ;
#         dcterms:title                 "Murder at Wrigley Field" ;
#         schema:author                 authors:Troy_Soos ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1575661551" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36643846.ttl"^^xsd:anyURI .
#
# books:Book_of_Tea  a                       schema:Book ;
#         rdfs:label                    "The Book of Tea" ;
#         dcterms:creator               authors:Okakura_Kakuzo ;
#         dcterms:title                 "The Book of Tea" ;
#         schema:author                 authors:Okakura_Kakuzo ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1040121798" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1040121798.ttl"^^xsd:anyURI .
#
# books:Sweet_Chaos_Grateful_Dead
#         a                             schema:Book ;
#         rdfs:label                    "Sweet chaos : the Grateful Dead's American adventure" ;
#         dcterms:creator               authors:Carol_Brightman ;
#         dcterms:title                 "Sweet chaos : the Grateful Dead's American adventure" ;
#         schema:author                 authors:Carol_Brightman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "051759448X" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42413619.ttl"^^xsd:anyURI .
#
# books:Mating  a                            schema:Book ;
#         rdfs:label                    "Mating" ;
#         dcterms:creator               authors:Norman_Rush ;
#         dcterms:title                 "Mating" ;
#         schema:author                 authors:Norman_Rush ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067973709X" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/25747644.ttl"^^xsd:anyURI .
#
# books:The_Hesperides_Tree  a               schema:Book ;
#         rdfs:label                    "The Hesperides Tree" ;
#         dcterms:creator               authors:Nicholas_Mosley ;
#         dcterms:title                 "The Hesperides Tree" ;
#         schema:author                 authors:Nicholas_Mosley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1564782670" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45963231.ttl"^^xsd:anyURI .
#
# books:Daily_Exercises_Minor_Modes
#         a                             schema:Book ;
#         rdfs:label                    "Daily exercises : in the melodic and harmonic minor modes" ;
#         dcterms:creator               authors:Barry_Galbraith ;
#         dcterms:title                 "Daily exercises : in the melodic and harmonic minor modes" ;
#         schema:author                 authors:Barry_Galbraith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781562240394" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/953396013.ttl"^^xsd:anyURI .
#
# books:Been_in_Sorrows_Kitchen
#         a                             schema:Book ;
#         rdfs:label                    "I Been in Sorrow's Kitchen and Licked Out All the Pots" ;
#         dcterms:creator               authors:Susan_Straight ;
#         dcterms:title                 "I Been in Sorrow's Kitchen and Licked Out All the Pots" ;
#         schema:author                 authors:Susan_Straight ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385470126" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/27266495.ttl"^^xsd:anyURI .
#
# books:The_Lust_Lizard  a                   schema:Book ;
#         rdfs:label                    "The Lust Lizard of Melancholy Cove" ;
#         dcterms:creator               authors:Christopher_Moore ;
#         dcterms:title                 "The Lust Lizard of Melancholy Cove" ;
#         schema:author                 authors:Christopher_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380792745" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/62358849.ttl"^^xsd:anyURI .
#
# books:Sound_Reinforcement_Handbook
#         a                             schema:Book ;
#         rdfs:label                    "Sound Reinforcement Handbook" ;
#         dcterms:creator               authors:Gary_Davis ;
#         dcterms:title                 "The sound reinforcement handbook" ;
#         schema:author                 authors:Gary_Davis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0881889008" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/993110744.ttl"^^xsd:anyURI .
#
# books:Moving_Image  a                      schema:Book ;
#         rdfs:label                    "The Moving Image" ;
#         dcterms:creator               authors:Gorham_Kindem ;
#         dcterms:title                 "The moving image : production principles and practices" ;
#         schema:author                 authors:Gorham_Kindem ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0673155749" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/475596637.ttl"^^xsd:anyURI .
#
# books:Omelette_and_Glass_of_Wine
#         a                             schema:Book ;
#         rdfs:label                    "An Omelette and a Glass of Wine" ;
#         dcterms:creator               authors:Elizabeth_David ;
#         dcterms:title                 "An Omelette and a Glass of Wine" ;
#         schema:author                 authors:Elizabeth_David ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1558215719" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1036779322.ttl"^^xsd:anyURI .
#
# books:Breathing_Lessons  a                 schema:Book ;
#         rdfs:label                    "Breathing Lessons" ;
#         dcterms:creator               authors:Anne_Tyler ;
#         dcterms:title                 "Breathing Lessons" ;
#         schema:author                 authors:Anne_Tyler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "042516313X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/716133121.ttl"^^xsd:anyURI .
#
# books:Hot_Mahogany  a                      schema:Book ;
#         rdfs:label                    "Hot Mahogany" ;
#         dcterms:creator               authors:Stuart_Woods ;
#         dcterms:title                 "Hot Mahogany" ;
#         schema:author                 authors:Stuart_Woods ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780451226716" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/874568158.ttl"^^xsd:anyURI .
#
# books:Postcard_Killers  a                  schema:Book ;
#         rdfs:label                    "The Postcard Killers" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "The Postcard Killers : a novel" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781455506637" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/752069903.ttl"^^xsd:anyURI .
#
# books:Most_Good_Least_Harm
#         a                             schema:Book ;
#         rdfs:label                    "Most Good, Least Harm" ;
#         dcterms:creator               authors:Zoe_Weil ;
#         dcterms:title                 "Most Good, Least Harm" ;
#         schema:author                 authors:Zoe_Weil ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1582702063" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/209717223.ttl"^^xsd:anyURI .
#
# books:The_Barrytown_Trilogy
#         a                             schema:Book ;
#         rdfs:label                    "The Barrytown Trilogy" ;
#         dcterms:creator               authors:Roddy_Doyle ;
#         dcterms:title                 "The Barrytown Trilogy" ;
#         schema:author                 authors:Roddy_Doyle ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32311490.ttl"^^xsd:anyURI .
#
# books:Tess_of_the_Durbervilles
#         a                             schema:Book ;
#         rdfs:label                    "Tess of the d'Urbervilles" ;
#         dcterms:creator               authors:Thomas_Hardy ;
#         dcterms:title                 "Tess of the d'Urbervilles" ;
#         schema:author                 authors:Thomas_Hardy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140431357" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/769855992.ttl"^^xsd:anyURI .
#
# books:The_mommy_club  a                    schema:Book ;
#         rdfs:label                    "The Mommy Club" ;
#         dcterms:creator               authors:Sarah_Bird ;
#         dcterms:title                 "The Mommy Club : a novel" ;
#         schema:author                 authors:Sarah_Bird ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "044050449X" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/25728625.ttl"^^xsd:anyURI .
#
# books:Superior_Espresso  a                 schema:Book ;
#         rdfs:label                    "Guide to the Art of Preparing Superior Espresso" ;
#         dcterms:creator               authors:Batdorf_Bronson ;
#         dcterms:title                 "Guide to the Art of Preparing Superior Espresso" ;
#         schema:author                 authors:Batdorf_Bronson ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 .
#
# books:From_Rationalism_Existentialism
#         a                             schema:Book ;
#         rdfs:label                    "From Rationalism to Existentialism" ;
#         dcterms:creator               authors:Robert_Solomon ;
#         dcterms:title                 "From rationalism to existentialism : the existentialists and their nineteenth-century backgrounds" ;
#         schema:author                 authors:Robert_Solomon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0819146358" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/633446006.ttl"^^xsd:anyURI .
#
# books:Neil_Young_Rolling_stone_files
#         a                             schema:Book ;
#         rdfs:label                    "Neil Young, the Rolling Stone Files" ;
#         dcterms:creator               authors:Holly_George-Warren ;
#         dcterms:title                 "Neil Young, the Rolling Stone Files" ;
#         schema:author                 authors:Holly_George-Warren ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0786880430" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/243807016.ttl"^^xsd:anyURI .
#
# books:The_Bone_People  a                   schema:Book ;
#         rdfs:label                    "The Bone People : a Novel" ;
#         dcterms:creator               authors:Keri_Hulme ;
#         dcterms:title                 "The Bone People : a Novel" ;
#         schema:author                 authors:Keri_Hulme ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140089225" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12188626.ttl"^^xsd:anyURI .
#
# books:One_Flew_Over_the_Cuckoos_Nest
#         a                             schema:Book ;
#         rdfs:label                    "One Flew Over the Cuckoo's Nest" ;
#         dcterms:creator               authors:Ken_Kesey ;
#         dcterms:title                 "One Flew Over the Cuckoo's Nest" ;
#         schema:author                 authors:Ken_Kesey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0141181222 " ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/970506555.ttl"^^xsd:anyURI .
#
# books:Knowledge_Mgmt  a                    schema:Book ;
#         rdfs:label                    "Knowledge Management" ;
#         dcterms:creator               authors:Kevin_Desouza ;
#         dcterms:title                 "Knowledge Management: An Introduction" ;
#         schema:author                 authors:Kevin_Desouza ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781555707200" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1201641193.ttl"^^xsd:anyURI .
#
# books:Avalanche_Safety  a                  schema:Book ;
#         rdfs:label                    "Avalanche Safety" ;
#         dcterms:creator               authors:ER_LaChapelle ;
#         dcterms:title                 "Avalanche Safety" ;
#         schema:author                 authors:ER_LaChapelle ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/500458312.ttl"^^xsd:anyURI .
#
# books:Our_Lady_Forest  a                   schema:Book ;
#         rdfs:label                    "Our Lady of the Forest" ;
#         dcterms:creator               authors:David_Guterson ;
#         dcterms:title                 "Our Lady of the Forest" ;
#         schema:author                 authors:David_Guterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375726578" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1054961278.ttl"^^xsd:anyURI .
#
# books:Improvising_Jazz  a                  schema:Book ;
#         rdfs:label                    "Improvising Jazz" ;
#         dcterms:creator               authors:Jerry_Coker ;
#         dcterms:title                 "Improvising Jazz" ;
#         schema:author                 authors:Jerry_Coker ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/252481990.ttl"^^xsd:anyURI .
#
# books:Shark_dialogues  a                   schema:Book ;
#         rdfs:label                    "Shark Dialogues" ;
#         dcterms:creator               authors:Kiana_Davenport ;
#         dcterms:title                 "Shark Dialogues" ;
#         schema:author                 authors:Kiana_Davenport ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452274583" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28799372.ttl"^^xsd:anyURI .
#
# books:Angels_in_Black  a                   schema:Book ;
#         rdfs:label                    "Angels in Black" ;
#         dcterms:creator               authors:Max_Allan_Collins ;
#         dcterms:title                 "Angels in Black" ;
#         schema:author                 authors:Max_Allan_Collins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451205170" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/49012505.ttl"^^xsd:anyURI .
#
# books:Turtle_Island  a                     schema:Book ;
#         rdfs:label                    "Turtle Island" ;
#         dcterms:creator               authors:Gary_Snyder ;
#         dcterms:title                 "Turtle Island" ;
#         schema:author                 authors:Gary_Snyder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811205460" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/315782135.ttl"^^xsd:anyURI .
#
# books:Trails_of_the_Gila  a                schema:Book ;
#         rdfs:label                    "Trails of the Gila" ;
#         dcterms:creator               authors:Bryan_Thomas ;
#         dcterms:title                 "Trails of the Gila: a guide to the recreational trails of the Silver City area" ;
#         schema:author                 authors:Bryan_Thomas ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34284518.ttl"^^xsd:anyURI .
#
# books:Seven_Types_of_Ambiguity
#         a                           schema:Book ;
#         rdfs:label                  "Seven Types of Ambiguity" ;
#         dcterms:creator             authors:Elliot_Perlman ;
#         dcterms:title               "Seven Types of Ambiguity" ;
#         schema:author               authors:Elliot_Perlman ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/54752893.ttl"^^xsd:anyURI .
#
# books:Doors_of_Perception  a               schema:Book ;
#         rdfs:label                    "The Doors of Perception" ;
#         dcterms:creator               authors:Aldous_Huxley ;
#         dcterms:title                 "The Doors of Perception" ;
#         schema:author                 authors:Aldous_Huxley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060801719" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/954598973.ttl"^^xsd:anyURI .
#
# books:Prisoner_of_Azkaban  a               schema:Book ;
#         rdfs:label                    "The Prisoner of Azkaban" ;
#         dcterms:creator               authors:JK_Rowling ;
#         dcterms:title                 "The Prisoner of Azkaban" ;
#         schema:author                 authors:JK_Rowling ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0439136369" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/610301939.ttl"^^xsd:anyURI .
#
# books:Crossing_the_Mangrove
#         a                             schema:Book ;
#         rdfs:label                    "Crossing the Mangrove" ;
#         dcterms:creator               authors:Maryse_Conde ;
#         dcterms:title                 "Crossing the Mangrove" ;
#         schema:author                 authors:Maryse_Conde ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385476337" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020243571.ttl"^^xsd:anyURI .
#
# books:Blue_Gold  a                         schema:Book ;
#         rdfs:label                    "Blue Gold" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Blue Gold" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743506391" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/44865852.ttl"^^xsd:anyURI .
#
# books:Les_Miserables  a                    schema:Book ;
#         rdfs:label                    "Les Misérables" ;
#         dcterms:creator               authors:Victor_Hugo ;
#         dcterms:title                 "Les Misérables" ;
#         schema:author                 authors:Victor_Hugo ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0449300021" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1140268812.ttl"^^xsd:anyURI .
#
# books:Clockwork_Orange  a                  schema:Book ;
#         rdfs:label                    "A Clockwork Orange" ;
#         dcterms:creator               authors:Anthony_Burgess ;
#         dcterms:title                 "A Clockwork Orange" ;
#         schema:author                 authors:Anthony_Burgess ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345284119" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9950377.ttl"^^xsd:anyURI .
#
# books:The_Grapes_of_Ralph  a               schema:Book ;
#         rdfs:label                    "The Grapes of Ralph" ;
#         dcterms:creator               authors:Ralph_Steadman ;
#         dcterms:title                 "The Grapes of Ralph" ;
#         schema:author                 authors:Ralph_Steadman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780151002450" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34617961.ttl"^^xsd:anyURI .
#
# books:Mainlines_Blood_Feasts
#         a                             schema:Book ;
#         rdfs:label                    "Mainlines, Blood Feasts and Bad Taste" ;
#         dcterms:creator               authors:Lester_Bangs ;
#         dcterms:title                 "Mainlines, blood feasts and bad taste : a Lester Bangs reader" ;
#         schema:author                 authors:Lester_Bangs ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1852428236" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1153547073.ttl"^^xsd:anyURI .
#
# books:Doonesbury_Greatest_Hits
#         a                             schema:Book ;
#         rdfs:label                    "Doonesbury's Greatest Hits" ;
#         dcterms:creator               authors:Garry_Trudeau ;
#         dcterms:title                 "Doonesbury's Greatest Hits" ;
#         schema:author                 authors:Garry_Trudeau ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0030448565" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/780004367.ttl"^^xsd:anyURI .
#
# books:The_Prophet  a                       schema:Book ;
#         rdfs:label                    "The Prophet" ;
#         dcterms:creator               authors:Kahlil_Gibran ;
#         dcterms:title                 "The Prophet" ;
#         schema:author                 authors:Kahlil_Gibran ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0762470224" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1158629012.ttl"^^xsd:anyURI .
#
# books:Hunting_a_Detroit_Tiger
#         a                             schema:Book ;
#         rdfs:label                    "Hunting a Detroit Tiger" ;
#         dcterms:creator               authors:Troy_Soos ;
#         dcterms:title                 "Hunting a Detroit Tiger" ;
#         schema:author                 authors:Troy_Soos ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1575662914" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36570564.ttl"^^xsd:anyURI .
#
# books:A_Keeper_of_Sheep  a                 schema:Book ;
#         rdfs:label                    "A Keeper of Sheep" ;
#         dcterms:creator               authors:William_Carpenter ;
#         dcterms:title                 "A Keeper of Sheep" ;
#         schema:author                 authors:William_Carpenter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1571310002" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  18 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/29877779.ttl"^^xsd:anyURI .
#
# books:Holy_Fools  a                        schema:Book ;
#         rdfs:label                    "Holy Fools" ;
#         dcterms:creator               authors:Joanne_Harris ;
#         dcterms:title                 "Holy Fools" ;
#         schema:author                 authors:Joanne_Harris ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060559136" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/60423948.ttl"^^xsd:anyURI .
#
# books:Wood_Floors  a                       schema:Book ;
#         rdfs:label                    "Wood Floors 1-2-3" ;
#         dcterms:creator               authors:Home_Depot ;
#         dcterms:title                 "Wood Floors 1-2-3" ;
#         schema:author                 authors:Home_Depot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0696209101" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1027555792.ttl"^^xsd:anyURI .
#
# books:Cuba   a                             schema:Book ;
#         rdfs:label                    "Cuba" ;
#         dcterms:creator               authors:David_Stanley ;
#         dcterms:title                 "Cuba" ;
#         schema:author                 authors:David_Stanley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0864427506" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/636115473.ttl"^^xsd:anyURI .
#
# books:A_history_of_philosophy_3
#         a                             schema:Book ;
#         rdfs:label                    "A History of Philosophy, Volumes 7-9" ;
#         dcterms:creator               authors:Frederick_Copleston ;
#         dcterms:title                 "A History of Philosophy" ;
#         schema:author                 authors:Frederick_Copleston ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385230338" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1055441766.ttl"^^xsd:anyURI .
#
# books:Sun_and_Moon  a                      schema:Book ;
#         rdfs:label                    "The Sun and the Moon" ;
#         dcterms:creator               authors:Niccolo_Tucci ;
#         dcterms:title                 "The Sun and the Moon" ;
#         schema:author                 authors:Niccolo_Tucci ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1559211261" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30357938.ttl"^^xsd:anyURI .
#
# books:Jazz   a                             schema:Book ;
#         rdfs:label                    "Jazz" ;
#         dcterms:creator               authors:Toni_Morrison ;
#         dcterms:title                 "Jazz" ;
#         schema:author                 authors:Toni_Morrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452269652" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779380485.ttl"^^xsd:anyURI .
#
# books:The_Bourne_Identity  a               schema:Book ;
#         rdfs:label                    "The Bourne Identity" ;
#         dcterms:creator               authors:Robert_Ludlum ;
#         dcterms:title                 "The Bourne Identity" ;
#         schema:author                 authors:Robert_Ludlum ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553260111" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5675357.ttl"^^xsd:anyURI .
#
# books:The_Pilots_Wife  a                   schema:Book ;
#         rdfs:label                    "The Pilot's Wife" ;
#         dcterms:creator               authors:Anita_Shreve ;
#         dcterms:title                 "The Pilot's Wife" ;
#         schema:author                 authors:Anita_Shreve ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316601950" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38096984.ttl"^^xsd:anyURI .
#
# books:Renatos_Luck  a                      schema:Book ;
#         rdfs:label                    "Renato's Luck" ;
#         dcterms:creator               authors:Jeff_Shapiro ;
#         dcterms:title                 "Renato's Luck" ;
#         schema:author                 authors:Jeff_Shapiro ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060932198" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/762824742.ttl"^^xsd:anyURI .
#
# books:Flowers_Ferns_Fungi  a               schema:Book ;
#         rdfs:label                    "Flowers, Ferns, and Fungi" ;
#         dcterms:creator               authors:John_Wiessinger ;
#         dcterms:title                 "Flowers, ferns, and fungi-right before your eyes" ;
#         schema:author                 authors:John_Wiessinger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0894902679" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19514853.ttl"^^xsd:anyURI .
#
# books:Adventures_of_Huckleberry_Finn
#         a                             schema:Book ;
#         rdfs:label                    "The Adventures of Huckleberry Finn" ;
#         dcterms:creator               authors:Mark_Twain ;
#         dcterms:title                 "The Adventures of Huckleberry Finn" ;
#         schema:author                 authors:Mark_Twain ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553210793" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/919109663.ttl"^^xsd:anyURI .
#
# books:Journey_is_Destination
#         a                             schema:Book ;
#         rdfs:label                    "The Journey is the Destination : the journals of Dan Eldon" ;
#         dcterms:creator               authors:Dan_Eldon ;
#         dcterms:title                 "The journey is the destination : the journals of Dan Eldon" ;
#         schema:author                 authors:Dan_Eldon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811815862" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/925193110.ttl"^^xsd:anyURI .
#
# books:Little_Miss_Strange  a               schema:Book ;
#         rdfs:label                    "Little Miss Strange" ;
#         dcterms:creator               authors:Joanna_Rose ;
#         dcterms:title                 "Little Miss Strange" ;
#         schema:author                 authors:Joanna_Rose ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684847418" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38326153.ttl"^^xsd:anyURI .
#
# books:Be_Expert_Map_Compass
#         a                             schema:Book ;
#         rdfs:label                    "Be Expert with Map and Compass" ;
#         dcterms:creator               authors:Bjorn_Kjellstrom ;
#         dcterms:title                 "Be Expert with Map and Compass" ;
#         schema:author                 authors:Bjorn_Kjellstrom ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684164132" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/658234821.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Comix_1
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Comix No. 1" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Comix No. 1" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:The_kingdom_beyond_the_waves
#         a                             schema:Book ;
#         rdfs:label                    "The kingdom beyond the waves" ;
#         dcterms:creator               authors:Stephen_Hunt ;
#         dcterms:title                 "The kingdom beyond the waves" ;
#         schema:author                 authors:Stephen_Hunt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780765360236" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1035699571.ttl"^^xsd:anyURI .
#
# books:Sun_Dogs  a                          schema:Book ;
#         rdfs:label                    "Sun Dogs" ;
#         dcterms:creator               authors:Robert_Olen_Butler ;
#         dcterms:title                 "Sun Dogs : a novel" ;
#         schema:author                 authors:Robert_Olen_Butler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "080503143X" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/229206507.ttl"^^xsd:anyURI .
#
# books:The_sea_runners  a                 schema:Book ;
#         rdfs:label                  "The sea runners" ;
#         dcterms:creator             authors:Ivan_Doig ;
#         dcterms:title               "The sea runners" ;
#         schema:author               authors:Ivan_Doig ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/8430298.ttl"^^xsd:anyURI .
#
# books:The_Windeater  a                     schema:Book ;
#         rdfs:label                    "The Windeater" ;
#         dcterms:creator               authors:Keri_Hulme ;
#         dcterms:title                 "The Windeater" ;
#         schema:author                 authors:Keri_Hulme ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0864730195" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/154827482.ttl"^^xsd:anyURI .
#
# books:The_Last_Samurai  a                  schema:Book ;
#         rdfs:label                    "The Last Samurai" ;
#         dcterms:creator               authors:Helen_DeWitt ;
#         dcterms:title                 "The Last Samurai" ;
#         schema:author                 authors:Helen_DeWitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0786866683" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43391103.ttl"^^xsd:anyURI .
#
# books:Jazz_Tunes_for_Improvisation
#         a                             schema:Book ;
#         rdfs:label                    "Jazz Tunes for Improvisation, Vol. 1" ;
#         dcterms:creator               authors:Dan_Haerle ;
#         dcterms:title                 "Jazz Tunes for Improvisation, Vol. 1" ;
#         schema:author                 authors:Dan_Haerle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0769201261" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/68081458.ttl"^^xsd:anyURI .
#
# books:Atlas  a                             schema:Book ;
#         rdfs:label                    "The Atlas" ;
#         dcterms:creator               authors:William_Vollmann ;
#         dcterms:title                 "The Atlas" ;
#         schema:author                 authors:William_Vollmann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140254498 " ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/944146779.ttl"^^xsd:anyURI .
#
# books:A_Recipe_for_Bees  a               schema:Book ;
#         rdfs:label                  "A Recipe for Bees" ;
#         dcterms:creator             authors:Gail_Anderson-Dargatz ;
#         dcterms:title               "A Recipe for Bees" ;
#         schema:author               authors:Gail_Anderson-Dargatz ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/40979987.ttl"^^xsd:anyURI .
#
# books:Parable_of_the_Talents
#         a                             schema:Book ;
#         rdfs:label                    "Parable of the Talents" ;
#         dcterms:creator               authors:Octavia_E_Butler ;
#         dcterms:title                 "Parable of the Talents" ;
#         schema:author                 authors:Octavia_E_Butler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446675784" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/58463798.ttl"^^xsd:anyURI .
#
# books:Strapless  a                         schema:Book ;
#         rdfs:label                    "Strapless" ;
#         dcterms:creator               authors:Leigh_Riker ;
#         dcterms:title                 "Strapless" ;
#         schema:author                 authors:Leigh_Riker ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0373250185" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1027180126.ttl"^^xsd:anyURI .
#
# books:Toward_awakening  a                schema:Book ;
#         rdfs:label                  "Toward awakening : an approach to the teaching left by Gurdjieff" ;
#         dcterms:creator             authors:Jean_Vaysse ;
#         dcterms:title               "Toward awakening : an approach to the teaching left by Gurdjieff" ;
#         schema:author               authors:Jean_Vaysse ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/5794801.ttl"^^xsd:anyURI .
#
# books:An_Aroma_of_Coffee  a                schema:Book ;
#         rdfs:label                    "An Aroma of Coffee" ;
#         dcterms:creator               authors:Dany_Laferriere ;
#         dcterms:title                 "An Aroma of Coffee" ;
#         schema:author                 authors:Dany_Laferriere ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0889104395" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1101029452.ttl"^^xsd:anyURI .
#
# books:Natural_Foods_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "Natural Foods Cookbook" ;
#         dcterms:creator               authors:Mary_Estella ;
#         dcterms:title                 "Natural Foods Cookbook: Vegetarian dairy-free cuisine" ;
#         schema:author                 authors:Mary_Estella ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0870405837" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/244156595.ttl"^^xsd:anyURI .
#
# books:The_law_of_similars  a             schema:Book ;
#         rdfs:label                  "The Law of Similars" ;
#         dcterms:creator             authors:Chris_Bohjalian ;
#         dcterms:title               "The Law of Similars" ;
#         schema:author               authors:Chris_Bohjalian ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/38765082.ttl"^^xsd:anyURI .
#
# books:Implementing_Tech_Librqaries
#         a                             schema:Book ;
#         rdfs:label                    "Implementing Technology Solutions in Libraries" ;
#         dcterms:creator               authors:Karen_Cox ;
#         dcterms:title                 "Implementing Technology Solutions in Libraries : Techniques, Tools, and Tips from the Trenches" ;
#         schema:author                 authors:Karen_Cox ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781573874038" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/952745432.ttl"^^xsd:anyURI .
#
# books:Isle_of_Dogs  a                      schema:Book ;
#         rdfs:label                    "Isle of Dogs" ;
#         dcterms:creator               authors:Patricia_Cornwell ;
#         dcterms:title                 "Isle of Dogs" ;
#         schema:author                 authors:Patricia_Cornwell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316858595" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45875926.ttl"^^xsd:anyURI .
#
# books:The_Frugal_Gourmet_Cooks
#         a                             schema:Book ;
#         rdfs:label                    "The Frugal Gourmet Cooks Three Ancient Cuisines" ;
#         dcterms:creator               authors:Jeff_Smith ;
#         dcterms:title                 "The Frugal Gourmet Cooks Three Ancient Cuisines : China, Greece, Rome" ;
#         schema:author                 authors:Jeff_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380712172" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/83204475.ttl"^^xsd:anyURI .
#
# books:Joy_of_Cooking  a                    schema:Book ;
#         rdfs:label                    "Joy of Cooking" ;
#         dcterms:creator               authors:Irma_Rombauer ;
#         dcterms:title                 "Joy of Cooking" ;
#         schema:author                 authors:Irma_Rombauer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684818701" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37801353.ttl"^^xsd:anyURI .
#
# books:Still_Life  a                        schema:Book ;
#         rdfs:label                    "Still Life" ;
#         dcterms:creator               authors:AS_Byatt ;
#         dcterms:title                 "Still Life" ;
#         schema:author                 authors:AS_Byatt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0020178557" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12235397.ttl"^^xsd:anyURI .
#
# books:How_to_Build_Decks  a                schema:Book ;
#         rdfs:label                    "How to Plan and Build Decks" ;
#         dcterms:creator               authors:Barbara_Gordon_Gibson ;
#         dcterms:title                 "How to Plan and Build Decks" ;
#         schema:author                 authors:Barbara_Gordon_Gibson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0376010770" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/270801840.ttl"^^xsd:anyURI .
#
# books:Gone_Tomorrow  a                     schema:Book ;
#         rdfs:label                    "Gone Tomorrow" ;
#         dcterms:creator               authors:Lee_Child ;
#         dcterms:title                 "Gone Tomorrow" ;
#         schema:author                 authors:Lee_Child ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780440243687" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/891606222.ttl"^^xsd:anyURI .
#
# books:Beneath_the_Underdog
#         a                             schema:Book ;
#         rdfs:label                    "Beneath the Underdog" ;
#         dcterms:creator               authors:Nel_King ;
#         dcterms:title                 "Beneath the underdog: his world as composed by Mingus" ;
#         schema:author                 authors:Nel_King ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679737618" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/263187520.ttl"^^xsd:anyURI .
#
# books:Winnie_the_Pooh  a                   schema:Book ;
#         rdfs:label                    "Winnie the Pooh" ;
#         dcterms:creator               authors:AA_Milne ;
#         dcterms:title                 "Winnie the Pooh" ;
#         schema:author                 authors:AA_Milne ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/21112983.ttl"^^xsd:anyURI .
#
# books:The_Esquire_culinary_companion
#         a                           schema:Book ;
#         rdfs:label                  "The Esquire culinary companion" ;
#         dcterms:creator             authors:Charles_Baker ;
#         dcterms:title               "The Esquire culinary companion, being an exotic cookery book; or, Around Europe with knife, fork, and spoon" ;
#         schema:author               authors:Charles_Baker ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1118733.ttl"^^xsd:anyURI .
#
# books:Road_to_Coorain  a                   schema:Book ;
#         rdfs:label                    "The Road to Coorain" ;
#         dcterms:creator               authors:Jill_Ker_Conway ;
#         dcterms:title                 "The Road to Coorain" ;
#         schema:author                 authors:Jill_Ker_Conway ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679724362" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/733855194.ttl"^^xsd:anyURI .
#
# books:Kiteworks  a                         schema:Book ;
#         rdfs:label                    "Kiteworks" ;
#         dcterms:creator               authors:Maxwell_Eden ;
#         dcterms:title                 "Kiteworks : explorations in kite building & flying" ;
#         schema:author                 authors:Maxwell_Eden ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0806967137" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/477519337.ttl"^^xsd:anyURI .
#
# books:The_Cheeses_of_Italy
#         a                             schema:Book ;
#         rdfs:label                    "The Cheeses of Italy" ;
#         dcterms:creator               authors:Rotraud_Michael-Degner ;
#         dcterms:title                 "The Cheeses of Italy" ;
#         schema:author                 authors:Rotraud_Michael-Degner ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19491128.ttl"^^xsd:anyURI .
#
# books:Ringolevio  a                        schema:Book ;
#         rdfs:label                    "Ringolevio" ;
#         dcterms:creator               authors:Emmett_Grogan ;
#         dcterms:title                 "Ringolevio : a life played for keeps" ;
#         schema:author                 authors:Emmett_Grogan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0806511680" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/508677813.ttl"^^xsd:anyURI .
#
# books:Ecotopia_Emerging  a                 schema:Book ;
#         rdfs:label                    "Ecotopia Emerging" ;
#         dcterms:creator               authors:Ernest_Callenbach ;
#         dcterms:title                 "Ecotopia Emerging" ;
#         schema:author                 authors:Ernest_Callenbach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060930217" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/8625399.ttl"^^xsd:anyURI .
#
# books:Database_Systems  a                  schema:Book ;
#         rdfs:label                    "Database Systems" ;
#         dcterms:creator               authors:Thomas_Connolly ;
#         dcterms:title                 "Database Systems: a practical approach to design, implementation, and management" ;
#         schema:author                 authors:Thomas_Connolly ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780321523068" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/780977394.ttl"^^xsd:anyURI .
#
# books:Things_My_Girlfriend_Argued_About
#         a                             schema:Book ;
#         rdfs:label                    "Things My Girlfriend and I Have Argued About" ;
#         dcterms:creator               authors:Mil_Millington ;
#         dcterms:title                 "Things my girlfriend and I have argued about : a novel" ;
#         schema:author                 authors:Mil_Millington ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "081296666X" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/671722733.ttl"^^xsd:anyURI .
#
# books:Grasshopper_Trap  a                  schema:Book ;
#         rdfs:label                    "The Grasshopper Trap" ;
#         dcterms:creator               authors:Patrick_McManus ;
#         dcterms:title                 "The Grasshopper Trap" ;
#         schema:author                 authors:Patrick_McManus ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0805001115" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/858692462.ttl"^^xsd:anyURI .
#
# books:The_Deceiver  a                      schema:Book ;
#         rdfs:label                    "The Deceiver" ;
#         dcterms:creator               authors:Frederick_Forsyth ;
#         dcterms:title                 "The Deceiver" ;
#         schema:author                 authors:Frederick_Forsyth ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553297422" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23584313.ttl"^^xsd:anyURI .
#
# books:Sub_Rosa  a                          schema:Book ;
#         rdfs:label                    "Sub Rosa" ;
#         dcterms:creator               authors:Dan_Homeres ;
#         dcterms:title                 "Sub Rosa" ;
#         schema:author                 authors:Dan_Homeres ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781462698769" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/894351234.ttl"^^xsd:anyURI .
#
# books:I_Become_Part_of_It  a               schema:Book ;
#         rdfs:label                    "I Become Part of It" ;
#         dcterms:creator               authors:Paul_Jordan_Smith , authors:DM_Dooling ;
#         dcterms:title                 "I become part of it : sacred dimensions in native American life" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Paul_Jordan_Smith , authors:DM_Dooling ;
#         schema:isbn                   "0062502352" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24911184.ttl"^^xsd:anyURI .
#
# books:Food_Lovers_Companion_2
#         a                             schema:Book ;
#         rdfs:label                    "The New Food Lover's Companion" ;
#         dcterms:creator               authors:Sharon_Tyler_Herbst ;
#         dcterms:title                 "The New Food Lover's Companion" ;
#         schema:author                 authors:Sharon_Tyler_Herbst ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0764112589" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43894522.ttl"^^xsd:anyURI .
#
# books:Joni_Mitchell  a                     schema:Book ;
#         rdfs:label                    "Joni Mitchell" ;
#         dcterms:creator               authors:Mark_Bego ;
#         dcterms:title                 "Joni Mitchell" ;
#         schema:author                 authors:Mark_Bego ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1589791347" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59002778.ttl"^^xsd:anyURI .
#
# books:Remains_of_the_Day  a                schema:Book ;
#         rdfs:label                    "The Remains of the Day" ;
#         dcterms:creator               authors:Kazuo_Ishiguro ;
#         dcterms:title                 "The Remains of the Day" ;
#         schema:author                 authors:Kazuo_Ishiguro ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679731725" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20167919.ttl"^^xsd:anyURI .
#
# books:Sivananda_companion_yoga
#         a                             schema:Book ;
#         rdfs:label                    "The Sivananda Companion to Yoga" ;
#         dcterms:creator               authors:Lorraine_Anderson ;
#         dcterms:title                 "The Sivananda Companion to Yoga" ;
#         schema:author                 authors:Lorraine_Anderson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671470884" ;
#         bibliographica:binNumber      11 , 10 ;
#         bibliographica:numberOfitems  2 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/435300858.ttl"^^xsd:anyURI .
#
# books:Cooks_Country_2005  a                schema:Book ;
#         rdfs:label                    "Cook's Country, 2005" ;
#         dcterms:creator               authors:Americas_Test_Kitchen ;
#         dcterms:title                 "Cook's Country, 2005" ;
#         schema:author                 authors:Americas_Test_Kitchen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0936184949" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/70144009.ttl"^^xsd:anyURI .
#
# books:Beach_Road  a                        schema:Book ;
#         rdfs:label                    "Beach Road" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "Beach Road" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1600242510" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/67616899.ttl"^^xsd:anyURI .
#
# books:Zen_of_Seeing  a                     schema:Book ;
#         rdfs:label                    "The Zen of Seeing" ;
#         dcterms:creator               authors:Frederick_Franck ;
#         dcterms:title                 "The Zen of Seeing" ;
#         schema:author                 authors:Frederick_Franck ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/911804492.ttl"^^xsd:anyURI .
#
# books:Wisdom_of_Gibran  a                  schema:Book ;
#         rdfs:label                    "The Wisdom of Gibran" ;
#         dcterms:creator               authors:Kahlil_Gibran , authors:Joseph_Sheban ;
#         dcterms:title                 "The Wisdom of Gibran" ;
#         schema:author                 authors:Joseph_Sheban , authors:Kahlil_Gibran ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/900171274.ttl"^^xsd:anyURI .
#
# books:Get_Home_Free  a                     schema:Book ;
#         rdfs:label                    "Get Home Free" ;
#         dcterms:creator               authors:John_Clellon_Holmes ;
#         dcterms:title                 "Get Home Free" ;
#         schema:author                 authors:John_Clellon_Holmes ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0938410539" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16831964.ttl"^^xsd:anyURI .
#
# books:The_Magicians_Assistant
#         a                             schema:Book ;
#         rdfs:label                    "The Magician's Assistant" ;
#         dcterms:creator               authors:Ann_Patchett ;
#         dcterms:title                 "The Magician's Assistant" ;
#         schema:author                 authors:Ann_Patchett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0156006219" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36225079.ttl"^^xsd:anyURI .
#
# books:Battlefield_Without_Borders
#         a                             schema:Book ;
#         rdfs:label                    "Battlefield Without Borders" ;
#         dcterms:creator               authors:David_Smith_Ferri ;
#         dcterms:title                 "Battlefield without borders : Iraq poems" ;
#         schema:author                 authors:David_Smith_Ferri ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1884540805" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/237180836.ttl"^^xsd:anyURI .
#
# books:Basic_Wiring  a                      schema:Book ;
#         rdfs:label                    "Basic Wiring Techniques" ;
#         dcterms:creator               authors:T_Jeff_Williams ;
#         dcterms:title                 "Basic Wiring Techniques" ;
#         schema:author                 authors:T_Jeff_Williams ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "089721000X" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/678639167.ttl"^^xsd:anyURI .
#
# books:Comfort_me_with_apples
#         a                             schema:Book ;
#         rdfs:label                    "Comfort Me with Apples" ;
#         dcterms:creator               authors:Ruth_Reichl ;
#         dcterms:title                 "Comfort me with apples : more adventures at the table" ;
#         schema:author                 authors:Ruth_Reichl ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375758739" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45364140.ttl"^^xsd:anyURI .
#
# books:Sweet_Thursday  a                    schema:Book ;
#         rdfs:label                    "Sweet Thursday" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "Sweet Thursday" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140048898" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/439234680.ttl"^^xsd:anyURI .
#
# books:Fifty_Years_of_Russian_Prose_2
#         a                           schema:Book ;
#         rdfs:label                  "Fifty Years of Russian Prose v.2" ;
#         dcterms:creator             authors:Krystyna_Pomorska ;
#         dcterms:title               "Fifty Years of Russian Prose v.2" ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Krystyna_Pomorska ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/749549285.ttl"^^xsd:anyURI .
#
# books:The_girl_with_dragon_tattoo
#         rdfs:label                    "The Girl with the Dragon Tattoo" ;
#         dcterms:creator               authors:Stieg_Larsson ;
#         dcterms:title                 "The Girl with the Dragon Tattoo" ;
#         schema:author                 authors:Stieg_Larsson ;
#         schema:isbn                   "9780307473479" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/921574026.ttl"^^xsd:anyURI .
#
# books:New_Professional_Chef
#         a                             schema:Book ;
#         rdfs:label                    "The New Professional Chef" ;
#         dcterms:creator               authors:Mary_Donovan ;
#         dcterms:title                 "The New Professional Chef" ;
#         schema:author                 authors:Mary_Donovan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0442019610" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1051668798.ttl"^^xsd:anyURI .
#
# books:The_Rottweiler  a                    schema:Book ;
#         rdfs:label                    "The Rottweiler" ;
#         dcterms:creator               authors:Ruth_Rendell ;
#         dcterms:title                 "The Rottweiler" ;
#         schema:author                 authors:Ruth_Rendell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400095883" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/53939544.ttl"^^xsd:anyURI .
#
# books:The_Lorax  a                         schema:Book ;
#         rdfs:label                    "The Lorax" ;
#         dcterms:creator               authors:Dr_Seuss ;
#         dcterms:title                 "The Lorax" ;
#         schema:author                 authors:Dr_Seuss ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0007468741" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1063696710.ttl"^^xsd:anyURI .
#
# books:The_House_at_Pooh_Corner
#         a                             schema:Book ;
#         rdfs:label                    "The House at Pooh Corner" ;
#         dcterms:creator               authors:AA_Milne ;
#         dcterms:title                 "The House at Pooh Corner" ;
#         schema:author                 authors:AA_Milne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440437954" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/26613496.ttl"^^xsd:anyURI .
#
# books:The_Deuce  a                         schema:Book ;
#         rdfs:label                    "The Deuce : a novel" ;
#         dcterms:creator               authors:Robert_Olen_Butler ;
#         dcterms:title                 "The Deuce : a novel" ;
#         schema:author                 authors:Robert_Olen_Butler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0805031979" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1082308027.ttl"^^xsd:anyURI .
#
# books:Siddhartha  a                        schema:Book ;
#         rdfs:label                    "Siddhartha" ;
#         dcterms:creator               authors:Hermann_Hesse ;
#         dcterms:title                 "Siddhartha" ;
#         schema:author                 authors:Hermann_Hesse ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1529024048" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1126002453.ttl"^^xsd:anyURI .
#
# books:Dead_Souls  a                        schema:Book ;
#         rdfs:label                    "Dead Souls" ;
#         dcterms:creator               authors:Nikolai_Gogol ;
#         dcterms:title                 "Dead Souls" ;
#         schema:author                 authors:Nikolai_Gogol ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140441131" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/815618948.ttl"^^xsd:anyURI .
#
# books:Reading_Studies_Guitar
#         a                             schema:Book ;
#         rdfs:label                    "Reading Studies for Guitar" ;
#         dcterms:creator               authors:William_Leavitt ;
#         dcterms:title                 "Reading studies for guitar : positions one through seven and multi-position studies in all keys" ;
#         schema:author                 authors:William_Leavitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0634013351" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1027900862.ttl"^^xsd:anyURI .
#
# books:Satori_in_Paris  a                   schema:Book ;
#         rdfs:label                    "Satori in Paris" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Satori in Paris" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394174372" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/614268541.ttl"^^xsd:anyURI .
#
# books:Looking_for_a_Ship  a                schema:Book ;
#         rdfs:label                    "Looking for a Ship" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "Looking for a Ship" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374190771" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/21442775.ttl"^^xsd:anyURI .
#
# books:AMA_Guide  a                         schema:Book ;
#         rdfs:label                    "The American Medical Association guide to your family's symptoms" ;
#         dcterms:creator               authors:AMA ;
#         dcterms:title                 "The American Medical Association guide to your family's symptoms" ;
#         schema:author                 authors:AMA ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679741283" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1010990221.ttl"^^xsd:anyURI .
#
# books:Greasy_Lake  a                       schema:Book ;
#         rdfs:label                    "Greasy Lake & other stories" ;
#         dcterms:creator               authors:T_Coraghessan_Boyle ;
#         dcterms:title                 "Greasy Lake & other stories" ;
#         schema:author                 authors:T_Coraghessan_Boyle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140077812" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/633669021.ttl"^^xsd:anyURI .
#
# books:Sassafrass_Cypress_Indigo
#         a                             schema:Book ;
#         rdfs:label                    "Sassafrass, Cypress & Indigo" ;
#         dcterms:creator               authors:Ntozake_Shange ;
#         dcterms:title                 "Sassafrass, Cypress & Indigo : a novel" ;
#         schema:author                 authors:Ntozake_Shange ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312699719" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/632555176.ttl"^^xsd:anyURI .
#
# books:Tao_te_ching_4  a                    schema:Book ;
#         rdfs:label                    "Tao Te Ching" ;
#         dcterms:creator               authors:Jingxiong_Wu ;
#         dcterms:title                 "Tao Te Ching" ;
#         schema:author                 authors:Jingxiong_Wu ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877733880" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/778989878.ttl"^^xsd:anyURI .
#
# books:Learners_Guide_Principles_of_Instructional_Design
#         a                             schema:Book ;
#         rdfs:label                    "Learner's Guide to Accompany Principles of Instructional Design" ;
#         dcterms:creator               authors:Robert_Gagne , authors:Walter_Wager ;
#         dcterms:title                 "Learner's Guide to Accompany Principles of Instructional Design" ;
#         schema:author                 authors:Robert_Gagne , authors:Walter_Wager ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0030339820" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/757307558.ttl"^^xsd:anyURI .
#
# books:Pacific_Northwest  a                 schema:Book ;
#         rdfs:label                    "The Pacific Northwest" ;
#         dcterms:creator               authors:APA_PRess ;
#         dcterms:title                 "The Pacific Northwest" ;
#         schema:author                 authors:APA_PRess ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 .
#
# books:Publishing_DVD  a                    schema:Book ;
#         rdfs:label                    "Publishing in the Age of DVD" ;
#         dcterms:creator               authors:Sonic_Solutions ;
#         dcterms:title                 "Publishing in the Age of DVD" ;
#         schema:author                 authors:Sonic_Solutions ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 .
#
# books:Dead_Lagoon  a                       schema:Book ;
#         rdfs:label                    "Dead Lagoon" ;
#         dcterms:creator               authors:Michael_Dibdin ;
#         dcterms:title                 "Dead Lagoon : an Aurelio Zen mystery" ;
#         schema:author                 authors:Michael_Dibdin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679753117" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/827725422.ttl"^^xsd:anyURI .
#
# books:Rolling_Stone_Interviews
#         a                             schema:Book ;
#         rdfs:label                    "The Rolling Stone Interviews" ;
#         dcterms:creator               authors:Rolling_Stone ;
#         dcterms:title                 "The Rolling Stone Interviews" ;
#         schema:author                 authors:Rolling_Stone ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312689551" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/978168751.ttl"^^xsd:anyURI .
#
# books:Creative_Origami  a                  schema:Book ;
#         rdfs:label                    "Creative Origami" ;
#         dcterms:creator               authors:Toyoaki_Kawai ;
#         dcterms:title                 "Creative Origami" ;
#         schema:author                 authors:Toyoaki_Kawai ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "4586540354" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/450459795.ttl"^^xsd:anyURI .
#
# books:Bicycle_Repair_Book  a               schema:Book ;
#         rdfs:label                    "The Bicycle Repair Book" ;
#         dcterms:creator               authors:Rob_Van_der_Plas ;
#         dcterms:title                 "The bicycle repair book : the complete manual of bicycle care" ;
#         schema:author                 authors:Rob_Van_der_Plas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0933201117" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1098766690.ttl"^^xsd:anyURI .
#
# books:Mutuwhenua  a                        schema:Book ;
#         rdfs:label                    "Mutuwhenua" ;
#         dcterms:creator               authors:Helene_Tursten ;
#         dcterms:title                 "Mutuwhenua" ;
#         schema:author                 authors:Helene_Tursten ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140089454" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1045652537.ttl"^^xsd:anyURI .
#
# books:Another_Roadside_Attraction
#         a                             schema:Book ;
#         rdfs:label                    "Another Roadside Attraction" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Another Roadside Attraction" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1842431293" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1148843196.ttl"^^xsd:anyURI .
#
# books:Sundog  a                            schema:Book ;
#         rdfs:label                    "Sundog" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Sundog" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671741519" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/21487403.ttl"^^xsd:anyURI .
#
# books:Selected_Journals_of_Thoreau
#         a                             schema:Book ;
#         rdfs:label                    "Selected Journals of Henry David Thoreau" ;
#         dcterms:creator               authors:Carl_Bode ;
#         dcterms:title                 "Selected Journals of Henry David Thoreau" ;
#         schema:author                 authors:Carl_Bode ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1404769.ttl"^^xsd:anyURI .
#
# books:Art_of_Digital_Video
#         a                             schema:Book ;
#         rdfs:label                    "The Art of Digital Video" ;
#         dcterms:creator               authors:John_Watkinson ;
#         dcterms:title                 "The Art of Digital Video" ;
#         schema:author                 authors:John_Watkinson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0240515862" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/758054751.ttl"^^xsd:anyURI .
#
# books:The_Grateful_Dead_Movie
#         a                             schema:Book ;
#         rdfs:label                    "The Grateful Dead Movie" ;
#         dcterms:creator               authors:Jerry_Garcia ;
#         dcterms:title                 "The Grateful Dead Movie" ;
#         schema:author                 authors:Jerry_Garcia ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1569942390" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1001933131.ttl"^^xsd:anyURI .
#
# books:Villa_Incognito  a                   schema:Book ;
#         rdfs:label                    "Villa Incognito" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Villa Incognito" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553382195" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/838383095.ttl"^^xsd:anyURI .
#
# books:The_Island_Within  a                 schema:Book ;
#         rdfs:label                    "The Island Within" ;
#         dcterms:creator               authors:Richard_Nelson ;
#         dcterms:title                 "The Island Within" ;
#         schema:author                 authors:Richard_Nelson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067973239X" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59909446.ttl"^^xsd:anyURI .
#
# books:Best_American_Science_Writing
#         a                             schema:Book ;
#         rdfs:label                    "The best American science and nature writing, 2004" ;
#         dcterms:creator               authors:Tim_Folger ;
#         dcterms:title                 "The best American science and nature writing, 2004" ;
#         schema:author                 authors:Tim_Folger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0618246983" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/56676823.ttl"^^xsd:anyURI .
#
# books:Worst_Band_Universe  a               schema:Book ;
#         rdfs:label                    "The Worst Band in the Universe" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "The Worst Band in the Universe" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140565876" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/822072431.ttl"^^xsd:anyURI .
#
# books:Selected_poems  a                    schema:Book ;
#         rdfs:label                    "Selected poems, 1966-1987" ;
#         dcterms:creator               authors:Seamus_Heaney ;
#         dcterms:title                 "Selected poems, 1966-1987" ;
#         schema:author                 authors:Seamus_Heaney ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374522804" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/634989838.ttl"^^xsd:anyURI .
#
# books:Mandolin_Chord_Book  a               schema:Book ;
#         rdfs:label                    "Mandolin Chord Book" ;
#         dcterms:creator               authors:James_Major ;
#         dcterms:title                 "Mandolin Chord Book" ;
#         schema:author                 authors:James_Major ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825622964" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12916103.ttl"^^xsd:anyURI .
#
# books:Archipel_Vol_1  a         schema:Book ;
#         rdfs:label         "Archipel Vol. 1" ;
#         dcterms:title      "Archipel Vol. 1" ;
#         schema:bookFormat  schema:Paperback .
#
# books:Baileys_Cafe  a                      schema:Book ;
#         rdfs:label                    "Bailey's Café" ;
#         dcterms:creator               authors:Gloria_Naylor ;
#         dcterms:title                 "Bailey's Café" ;
#         schema:author                 authors:Gloria_Naylor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679748210" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/444969777.ttl"^^xsd:anyURI .
#
# books:Diet_for_a_New_America
#         a                             schema:Book ;
#         rdfs:label                    "Diet for a New America" ;
#         dcterms:creator               authors:John_Robbins ;
#         dcterms:title                 "Diet for a New America" ;
#         schema:author                 authors:John_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0913299545" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38425991.ttl"^^xsd:anyURI .
#
# books:Art_of_Making_Wine  a                schema:Book ;
#         rdfs:label                    "The Professional Chef's Art of Garde Manger" ;
#         dcterms:creator               authors:Frederic_Sonnenschmidt ;
#         dcterms:title                 "The Professional Chef's Art of Garde Manger" ;
#         schema:author                 authors:Frederic_Sonnenschmidt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0843622237" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/7814240.ttl"^^xsd:anyURI .
#
# books:Eleventh_Hour  a                     schema:Book ;
#         rdfs:label                    "The Eleventh hour" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "The Eleventh hour" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0810932652" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/907727528.ttl"^^xsd:anyURI .
#
# books:Christopher_Parkening_Guitar
#         a                             schema:Book ;
#         rdfs:label                    "Christopher Parkening Guitar Method" ;
#         dcterms:creator               authors:Christopher_Parkening ;
#         dcterms:title                 "The Christopher Parkening guitar method. Vol. 1 : the art and technique of the classical guitar" ;
#         schema:author                 authors:Christopher_Parkening ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "142343417X" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/539537495.ttl"^^xsd:anyURI .
#
# books:Ecotopia  a                          schema:Book ;
#         rdfs:label                    "Ecotopia" ;
#         dcterms:creator               authors:Ernest_Callenbach ;
#         dcterms:title                 "Ecotopia" ;
#         schema:author                 authors:Ernest_Callenbach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553348477" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1037415622.ttl"^^xsd:anyURI .
#
# books:Atomic_Lobster  a                    schema:Book ;
#         rdfs:label                    "Atomic Lobster" ;
#         dcterms:creator               authors:Tim_Dorsey ;
#         dcterms:title                 "Atomic Lobster" ;
#         schema:author                 authors:Tim_Dorsey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780060829704" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/493630106.ttl"^^xsd:anyURI .
#
# books:The_Sound_and_Fury  a                schema:Book ;
#         rdfs:label                    "The Sound and the Fury" ;
#         dcterms:creator               authors:Barney_Hoskyns ;
#         dcterms:title                 "The Sound and the Fury : a Rock's Backpages reader : 40 years of classic rock journalism" ;
#         schema:author                 authors:Barney_Hoskyns ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1582342822" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52731941.ttl"^^xsd:anyURI .
#
# books:Tracks_a_novel  a                    schema:Book ;
#         rdfs:label                    "Tracks : a novel" ;
#         dcterms:creator               authors:Louise_Erdrich ;
#         dcterms:title                 "Tracks : a novel" ;
#         schema:author                 authors:Louise_Erdrich ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060972459" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/17776478.ttl"^^xsd:anyURI .
#
# books:Jazz_Guitar_Single_Note
#         a                             schema:Book ;
#         rdfs:label                    "Jazz Guitar Single Note Soloing. Vol. 1" ;
#         dcterms:creator               authors:Ted_Greene ;
#         dcterms:title                 "Jazz guitar single note soloing. Vol. 1" ;
#         schema:author                 authors:Ted_Greene ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0769209726" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/813693717.ttl"^^xsd:anyURI .
#
# books:Dog_Falling  a                       schema:Book ;
#         rdfs:label                    "Dog Falling" ;
#         dcterms:creator               authors:Dan_Homeres ;
#         dcterms:title                 "Dog Falling" ;
#         schema:author                 authors:Dan_Homeres ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1608132722" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 .
#
# books:Bad_Heir_Day  a                      schema:Book ;
#         rdfs:label                    "Bad Heir Day" ;
#         dcterms:creator               authors:Wendy_Holden ;
#         dcterms:title                 "Bad Heir Day" ;
#         schema:author                 authors:Wendy_Holden ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452281784" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/797099814.ttl"^^xsd:anyURI .
#
# books:Sideways  a                          schema:Book ;
#         rdfs:label                    "Sideways" ;
#         dcterms:creator               authors:Rex_Pickett ;
#         dcterms:title                 "Sideways" ;
#         schema:author                 authors:Rex_Pickett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312342519" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/53951011.ttl"^^xsd:anyURI .
#
# books:Irish_Favorites  a                   schema:Book ;
#         rdfs:label                    "Irish Favorites" ;
#         dcterms:creator               authors:Hal_Leonard_Corp ;
#         dcterms:title                 "Irish Favorites" ;
#         schema:author                 authors:Hal_Leonard_Corp ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0793521769" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/503219730.ttl"^^xsd:anyURI .
#
# books:Borderliners  a                      schema:Book ;
#         rdfs:label                    "Borderliners" ;
#         dcterms:creator               authors:Peter_Hoeg ;
#         dcterms:title                 "Borderliners" ;
#         schema:author                 authors:Peter_Hoeg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385315082" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30437554.ttl"^^xsd:anyURI .
#
# books:Dont_think_twice  a                  schema:Book ;
#         rdfs:label                    "Don't think twice : a novel" ;
#         dcterms:creator               authors:Wayne_Johnson ;
#         dcterms:title                 "Don't think twice : a novel" ;
#         schema:author                 authors:Wayne_Johnson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0609604600" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40979986.ttl"^^xsd:anyURI .
#
# books:Arctic_Dreams  a                     schema:Book ;
#         rdfs:label                    "Arctic Dreams" ;
#         dcterms:creator               authors:Barry_Lopez ;
#         dcterms:title                 "Arctic Dreams: imagination and desire in a northern landscape " ;
#         schema:author                 authors:Barry_Lopez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553346644" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12665576.ttl"^^xsd:anyURI .
#
# books:The_Chase  a                         schema:Book ;
#         rdfs:label                    "The Chase" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "The Chase" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425224427" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1012397513.ttl"^^xsd:anyURI .
#
# books:Dictionary_of_Multimedia
#         a                             schema:Book ;
#         rdfs:label                    "The Dictionary of Multimedia" ;
#         dcterms:creator               authors:Brad_Hansen ;
#         dcterms:title                 "The dictionary of multimedia : terms & acronyms" ;
#         schema:author                 authors:Brad_Hansen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1887902147" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/955549428.ttl"^^xsd:anyURI .
#
# books:Femme_dAdventure  a                  schema:Book ;
#         rdfs:label                    "Femme d'adventure : travel tales" ;
#         dcterms:creator               authors:Jessica_Maxwell ;
#         dcterms:title                 "Femme d'adventure : travel tales from Inner Montana to Outer Mongolia" ;
#         schema:author                 authors:Jessica_Maxwell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878067982" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37331596.ttl"^^xsd:anyURI .
#
# books:RocknRoll_Comics_GD_2
#         a                             schema:Book ;
#         rdfs:label                    "Rock n Roll Comics Grateful Dead Issue 45" ;
#         dcterms:creator               authors:Heather_Cheney ;
#         dcterms:title                 "Rock n Roll Comics Grateful Dead Issue 45" ;
#         schema:author                 authors:Heather_Cheney ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Fitness_Swimming_Secrets
#         a                             schema:Book ;
#         rdfs:label                    "101 Fitness Swimming Secrets" ;
#         dcterms:creator               authors:Fitness_Swimmer ;
#         dcterms:title                 "101 Fitness Swimming Secrets" ;
#         schema:author                 authors:Fitness_Swimmer ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/55115223.ttl"^^xsd:anyURI .
#
# books:Harrington_Street  a               schema:Book ;
#         rdfs:label                  "Harrington Street" ;
#         dcterms:creator             authors:Jerry_Garcia ;
#         dcterms:title               "Harrington Street" ;
#         schema:author               authors:Jerry_Garcia ;
#         schema:bookFormat           schema:Paperback ;
#         schema:isbn                 "0385313535" ;
#         bibliographica:binNumber    1 ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/33631673.ttl"^^xsd:anyURI .
#
# books:Tishomingo_Blues  a                  schema:Book ;
#         rdfs:label                    "Tishomingo Blues" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Tishomingo Blues" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060083948" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/471551794.ttl"^^xsd:anyURI .
#
# books:Deadhead_Forever  a                  schema:Book ;
#         rdfs:label                    "Deadhead Forever : Property of Haze" ;
#         dcterms:creator               authors:Scott_Meyer ;
#         dcterms:title                 "Deadhead Forever : Property of Haze" ;
#         schema:author                 authors:Scott_Meyer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0762428368" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/231686069.ttl"^^xsd:anyURI .
#
# books:Night_Over_Water  a                  schema:Book ;
#         rdfs:label                    "Night Over Water" ;
#         dcterms:creator               authors:Ken_Follett ;
#         dcterms:title                 "Night Over Water" ;
#         schema:author                 authors:Ken_Follett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780451173133" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/883321554.ttl"^^xsd:anyURI .
#
# books:Project_Mgmt  a                      schema:Book ;
#         rdfs:label                    "Teach Yourself Project Management" ;
#         dcterms:creator               authors:Phil_Baguley ;
#         dcterms:title                 "Teach Yourself Project Management" ;
#         schema:author                 authors:Phil_Baguley ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/828199043.ttl"^^xsd:anyURI .
#
# books:Sympathy_for_the_Devil
#         a                             schema:Book ;
#         rdfs:label                    "Sympathy for the Devil" ;
#         dcterms:creator               authors:Kent_Anderson ;
#         dcterms:title                 "Sympathy for the Devil" ;
#         schema:author                 authors:Kent_Anderson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553580876" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1013834944.ttl"^^xsd:anyURI .
#
# books:Cross_Fire  a                        schema:Book ;
#         rdfs:label                    "Cross Fire" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "Cross Fire" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780446574716" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/797257798.ttl"^^xsd:anyURI .
#
# books:Sand_County_Almanac  a               schema:Book ;
#         rdfs:label                    "A Sand County Almanac" ;
#         dcterms:creator               authors:Aldo_Leopold ;
#         dcterms:title                 "A sand county almanac : with essays on conservation from Round River" ;
#         schema:author                 authors:Aldo_Leopold ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345253361195" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/254229667.ttl"^^xsd:anyURI .
#
# books:Caverns  a                           schema:Book ;
#         rdfs:label                    "Caverns" ;
#         dcterms:creator               authors:OU_Levon ;
#         dcterms:title                 "Caverns : a novel" ;
#         schema:author                 authors:OU_Levon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140122087" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20131987.ttl"^^xsd:anyURI .
#
# books:Religious_Thought  a                 schema:Book ;
#         rdfs:label                    "The World treasury of modern religious thought" ;
#         dcterms:creator               authors:Clifton_Fadiman , authors:Jaroslav_Pelikan ;
#         dcterms:title                 "The World treasury of modern religious thought" ;
#         schema:author                 authors:Clifton_Fadiman , authors:Jaroslav_Pelikan ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1036929223.ttl"^^xsd:anyURI .
#
# books:How_Stella_Got_Her_Groove_Back
#         a                             schema:Book ;
#         rdfs:label                    "How Stella Got Her Groove Back" ;
#         dcterms:creator               authors:Terry_McMillan ;
#         dcterms:title                 "How Stella Got Her Groove Back" ;
#         schema:author                 authors:Terry_McMillan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451192001" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/53974432.ttl"^^xsd:anyURI .
#
# books:The_Half_Life_Happiness
#         a                             schema:Book ;
#         rdfs:label                    "The Half-life of Happiness" ;
#         dcterms:creator               authors:John_Casey ;
#         dcterms:title                 "The Half-life of Happiness" ;
#         schema:author                 authors:John_Casey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375706089" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/491702096.ttl"^^xsd:anyURI .
#
# books:Wild_Life  a                         schema:Book ;
#         rdfs:label                    "Wild Life" ;
#         dcterms:creator               authors:Molly_Gloss ;
#         dcterms:title                 "Wild Life" ;
#         schema:author                 authors:Molly_Gloss ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0618131574" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/704899989.ttl"^^xsd:anyURI .
#
# books:Language_of_SQL  a                   schema:Book ;
#         rdfs:label                    "The Language of SQL" ;
#         dcterms:creator               authors:Larry_Rockoff ;
#         dcterms:title                 "The Language of SQL" ;
#         schema:author                 authors:Larry_Rockoff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781435457515" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/820396166.ttl"^^xsd:anyURI .
#
# books:Spice_Box_Cookbook  a                schema:Book ;
#         rdfs:label                    "The Spice Box : Vegetarian Indian Cookbook" ;
#         dcterms:creator               authors:Manju_Singh ;
#         dcterms:title                 "The Spice Box : Vegetarian Indian Cookbook" ;
#         schema:author                 authors:Manju_Singh ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0895940531" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/867938272.ttl"^^xsd:anyURI .
#
# books:Guide_to_SQL  a                      schema:Book ;
#         rdfs:label                    "A Guide to SQL" ;
#         dcterms:creator               authors:Philip_Pratt ;
#         dcterms:title                 "A Guide to SQL" ;
#         schema:author                 authors:Philip_Pratt ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/653070023.ttl"^^xsd:anyURI .
#
# books:Tramping_in_New_Zealand
#         a                             schema:Book ;
#         rdfs:label                    "Tramping in New Zealand" ;
#         dcterms:creator               authors:Jim_DuFresne ;
#         dcterms:title                 "Tramping in New Zealand" ;
#         schema:author                 authors:Jim_DuFresne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0908086334" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/70765553.ttl"^^xsd:anyURI .
#
# books:Worlds_of_Pain  a                    schema:Book ;
#         rdfs:label                    "Worlds of Pain : Life in the Working-Class Family" ;
#         dcterms:creator               authors:Lillian_B_Rubin ;
#         dcterms:title                 "Worlds of Pain : Life in the Working-Class Family" ;
#         schema:author                 authors:Lillian_B_Rubin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0465097243" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/974052595.ttl"^^xsd:anyURI .
#
# books:Step_by_Step_Organic_Vegetable
#         a                             schema:Book ;
#         rdfs:label                    "Step by Step to Organic Vegetable Growing" ;
#         dcterms:creator               authors:Vijay_Hassin ;
#         dcterms:title                 "Step by Step to Organic Vegetable Growing" ;
#         schema:author                 authors:Vijay_Hassin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0878570012" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/873290078.ttl"^^xsd:anyURI .
#
# books:Fast_Food_Nation  a                  schema:Book ;
#         rdfs:label                    "Fast Food Nation" ;
#         dcterms:creator               authors:Eric_Schlosser ;
#         dcterms:title                 "Fast food nation : the dark side of the all-American meal" ;
#         schema:author                 authors:Eric_Schlosser ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060938455" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1110140143.ttl"^^xsd:anyURI .
#
# books:The_Farming_of_Bones
#         a                             schema:Book ;
#         rdfs:label                    "The Farming of Bones" ;
#         dcterms:creator               authors:Edwidge_Danticat ;
#         dcterms:title                 "The Farming of Bones" ;
#         schema:author                 authors:Edwidge_Danticat ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140280499" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38731998.ttl"^^xsd:anyURI .
#
# books:Songs_of_Humpback_Whale
#         a                             schema:Book ;
#         rdfs:label                    "Songs of the Humpback Whale" ;
#         dcterms:creator               authors:Jodi_Picoult ;
#         dcterms:title                 "Songs of the humpback whale : a novel in five voices" ;
#         schema:author                 authors:Jodi_Picoult ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743431014" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/986707294.ttl"^^xsd:anyURI .
#
# books:Ropes_Knots_Slings  a                schema:Book ;
#         rdfs:label                    "Ropes, Knots & Slings for Climbers" ;
#         dcterms:creator               authors:Walt_Wheelock ;
#         dcterms:title                 "Ropes, Knots & Slings for Climbers" ;
#         schema:author                 authors:Walt_Wheelock ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/49402453.ttl"^^xsd:anyURI .
#
# books:Tortilla_Curtain  a                  schema:Book ;
#         rdfs:label                    "The Tortilla Curtain" ;
#         dcterms:creator               authors:T_Coraghessan_Boyle ;
#         dcterms:title                 "The Tortilla Curtain" ;
#         schema:author                 authors:T_Coraghessan_Boyle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "014023828X" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/466335054.ttl"^^xsd:anyURI .
#
# books:Another_Roadside_Attraction_2
#         a                             schema:Book ;
#         rdfs:label                    "Another Roadside Attraction" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Another Roadside Attraction" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345292456" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1148843196.ttl"^^xsd:anyURI .
#
# books:Moosewood_Cookbook  a                schema:Book ;
#         rdfs:label                    "The Moosewood Cookbook" ;
#         dcterms:creator               authors:Mollie_Katzen ;
#         dcterms:title                 "The Moosewood Cookbook : Recipes from Moosewood Restaurant" ;
#         schema:author                 authors:Mollie_Katzen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0913668680" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1036761462.ttl"^^xsd:anyURI .
#
# books:Second_Ring_of_Power
#         a                             schema:Book ;
#         rdfs:label                    "The Second Ring of Power" ;
#         dcterms:creator               authors:Carlos_Castaneda ;
#         dcterms:title                 "The Second Ring of Power" ;
#         schema:author                 authors:Carlos_Castaneda ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671229427" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924934301.ttl"^^xsd:anyURI .
#
# books:Tales_of_Power  a                    schema:Book ;
#         rdfs:label                    "Tales of Power" ;
#         dcterms:creator               authors:Carlos_Castaneda ;
#         dcterms:title                 "Tales of Power" ;
#         schema:author                 authors:Carlos_Castaneda ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140041443" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/760555328.ttl"^^xsd:anyURI .
#
# books:Pepper_Garden  a                     schema:Book ;
#         rdfs:label                    "The Pepper Garden" ;
#         dcterms:creator               authors:Dave_DeWitt ;
#         dcterms:title                 "The Pepper Garden" ;
#         schema:author                 authors:Dave_DeWitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898155541" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1036827685.ttl"^^xsd:anyURI .
#
# books:Sketch_me_if_you_can
#         a                             schema:Book ;
#         rdfs:label                    "Sketch me if you can" ;
#         dcterms:creator               authors:Sharon_Pape ;
#         dcterms:title                 "Sketch me if you can" ;
#         schema:author                 authors:Sharon_Pape ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425236048" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/650500867.ttl"^^xsd:anyURI .
#
# books:Another_Song_King  a                 schema:Book ;
#         rdfs:label                    "Another Song About the King" ;
#         dcterms:creator               authors:Kathryn_Stern ;
#         dcterms:title                 "Another Song About the King" ;
#         schema:author                 authors:Kathryn_Stern ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "034543319X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47257560.ttl"^^xsd:anyURI .
#
# books:The_first_third  a                   schema:Book ;
#         rdfs:label                    "The first third & other writings" ;
#         dcterms:creator               authors:Neal_Cassady ;
#         dcterms:title                 "The first third & other writings" ;
#         schema:author                 authors:Neal_Cassady ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0872860051" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1031784480.ttl"^^xsd:anyURI .
#
# books:Child_of_Her_People  a               schema:Book ;
#         rdfs:label                    "Child of Her People" ;
#         dcterms:creator               authors:Anne_Cameron ;
#         dcterms:title                 "Child of Her People" ;
#         schema:author                 authors:Anne_Cameron ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0933216289" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/17821459.ttl"^^xsd:anyURI .
#
# books:Life_of_Pi  a                        schema:Book ;
#         rdfs:label                    "Life of Pi" ;
#         dcterms:creator               authors:Yann_Martel ;
#         dcterms:title                 "Life of Pi" ;
#         schema:author                 authors:Yann_Martel ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "184195392X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/464698108.ttl"^^xsd:anyURI .
#
# books:Brimhall_Jazz_Standards
#         a                             schema:Book ;
#         rdfs:label                    "The Best of the Best of Brimhall Jazz Standards" ;
#         dcterms:creator               authors:John_Brimhall ;
#         dcterms:title                 "The Best of the Best of Brimhall Jazz Standards" ;
#         schema:author                 authors:John_Brimhall ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0769216722" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/786137080.ttl"^^xsd:anyURI .
#
# books:Fiji_a_travel_survival_kit
#         a                             schema:Book ;
#         rdfs:label                    "Fiji : a travel survival kit" ;
#         dcterms:creator               authors:Robert_Kay ;
#         dcterms:title                 "Fiji : a travel survival kit" ;
#         schema:author                 authors:Robert_Kay ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "086442177X" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33080026.ttl"^^xsd:anyURI .
#
# books:The_English_patient  a               schema:Book ;
#         rdfs:label                    "The English Patient" ;
#         dcterms:creator               authors:Michael_Ondaatje ;
#         dcterms:title                 "The English Patient : a novel" ;
#         schema:author                 authors:Michael_Ondaatje ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679745203" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/716735011.ttl"^^xsd:anyURI .
#
# books:Detox_Diet  a                        schema:Book ;
#         rdfs:label                    "The Detox Diet" ;
#         dcterms:creator               authors:Elson_Haas ;
#         dcterms:title                 "The Detox Diet" ;
#         schema:author                 authors:Elson_Haas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1587611899" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/54527833.ttl"^^xsd:anyURI .
#
# books:Gravitys_Rainbow  a                  schema:Book ;
#         rdfs:label                    "Gravity's Rainbow" ;
#         dcterms:creator               authors:Thomas_Pynchon ;
#         dcterms:title                 "Gravity's Rainbow" ;
#         schema:author                 authors:Thomas_Pynchon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553147617" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/592261.ttl"^^xsd:anyURI .
#
# books:Incredible_Chord_Finder
#         a                             schema:Book ;
#         rdfs:label                    "Incredible Chord Finder" ;
#         dcterms:creator               authors:Hal_Leonard_Corp ;
#         dcterms:title                 "Incredible Chord Finder : a complete guide to over 1116 guitar chords" ;
#         schema:author                 authors:Hal_Leonard_Corp ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0881881406" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/979255046.ttl"^^xsd:anyURI .
#
# books:Beginners_Luck  a                    schema:Book ;
#         rdfs:label                    "Beginner's Luck" ;
#         dcterms:creator               authors:Laura_Pedersen ;
#         dcterms:title                 "Beginner's Luck" ;
#         schema:author                 authors:Laura_Pedersen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345458303" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/51267386.ttl"^^xsd:anyURI .
#
# books:Music_Kit_Workbook  a                schema:Book ;
#         rdfs:label                    "The Music Kit : Workbook" ;
#         dcterms:creator               authors:Tom_Manoff ;
#         dcterms:title                 "The Music Kit : Workbook" ;
#         schema:author                 authors:Tom_Manoff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0393952983" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779063823.ttl"^^xsd:anyURI .
#
# books:Compleat_Angler  a                   schema:Book ;
#         rdfs:label                    "The Compleat Angler" ;
#         dcterms:creator               authors:Izaak_Walton ;
#         dcterms:title                 "The Compleat Angler" ;
#         schema:author                 authors:Izaak_Walton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1870630750" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/666901008.ttl"^^xsd:anyURI .
#
# books:The_young_in_one_anothers_arms
#         a                             schema:Book ;
#         rdfs:label                    "The Young in One Another's Arms" ;
#         dcterms:creator               authors:Jane_Rule ;
#         dcterms:title                 "The Young in One Another's Arms" ;
#         schema:author                 authors:Jane_Rule ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0930044533" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1171116932.ttl"^^xsd:anyURI .
#
# books:Miles_the_autobiography
#         a                             schema:Book ;
#         rdfs:label                    "Miles: the autobiography" ;
#         dcterms:creator               authors:Miles_Davis , authors:Quincy_Troupe ;
#         dcterms:title                 "Miles: the autobiography" ;
#         schema:author                 authors:Miles_Davis , authors:Quincy_Troupe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671725823" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20015144.ttl"^^xsd:anyURI .
#
# books:Freak_Brothers_4  a                  schema:Book ;
#         rdfs:label                    "Freak Brothers Issue 4" ;
#         dcterms:creator               authors:Gilbert_Shelton ;
#         dcterms:title                 "Freak Brothers Issue 4" ;
#         schema:author                 authors:Gilbert_Shelton ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Fay    a                             schema:Book ;
#         rdfs:label                    "Fay: a novel" ;
#         dcterms:creator               authors:Larry_Brown ;
#         dcterms:title                 "Fay: a novel" ;
#         schema:author                 authors:Larry_Brown ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743205383" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46518578.ttl"^^xsd:anyURI .
#
# books:Dreamer_of_pictures  a               schema:Book ;
#         rdfs:label                    "A dreamer of pictures : Neil Young, the man and his music" ;
#         dcterms:creator               authors:David_Downing ;
#         dcterms:title                 "A dreamer of pictures : Neil Young, the man and his music" ;
#         schema:author                 authors:David_Downing ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0306806118" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30913139.ttl"^^xsd:anyURI .
#
# books:Tree_of_Life  a                      schema:Book ;
#         rdfs:label                    "Tree of Life" ;
#         dcterms:creator               authors:Maryse_Conde ;
#         dcterms:title                 "Tree of Life" ;
#         schema:author                 authors:Maryse_Conde ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345384695" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/25507757.ttl"^^xsd:anyURI .
#
# books:The_Hunted  a                        schema:Book ;
#         rdfs:label                    "The Hunted" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "The Hunted" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780060084066" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/464594938.ttl"^^xsd:anyURI .
#
# books:Harry_Potter_Sorcerer_Stone
#         a                             schema:Book ;
#         rdfs:label                    "Harry Potter and the Sorcerer's Stone" ;
#         dcterms:creator               authors:JK_Rowling ;
#         dcterms:title                 "Harry Potter and the Sorcerer's Stone" ;
#         schema:author                 authors:JK_Rowling ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "059035342X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/994697419.ttl"^^xsd:anyURI .
#
# books:Fields_of_Fire  a                    schema:Book ;
#         rdfs:label                    "Fields of Fire" ;
#         dcterms:creator               authors:Jim_Webb ;
#         dcterms:title                 "Fields of Fire" ;
#         schema:author                 authors:Jim_Webb ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553583859" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1091588382.ttl"^^xsd:anyURI .
#
# books:Seventh_Heaven  a                    schema:Book ;
#         rdfs:label                    "Seventh Heaven" ;
#         dcterms:creator               authors:Patti_Smith ;
#         dcterms:title                 "Seventh Heaven" ;
#         schema:author                 authors:Patti_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0915890291" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/500372274.ttl"^^xsd:anyURI .
#
# books:Thinking_With_Pencil
#         a                             schema:Book ;
#         rdfs:label                    "Thinking With A Pencil" ;
#         dcterms:creator               authors:Henning_Nelms ;
#         dcterms:title                 "Thinking With A Pencil" ;
#         schema:author                 authors:Henning_Nelms ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898150523" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 .
#
# books:Parliament_of_Whores
#         a                             schema:Book ;
#         rdfs:label                    "Parliament of Whores" ;
#         dcterms:creator               authors:PJ_ORourke ;
#         dcterms:title                 "Parliament of Whores" ;
#         schema:author                 authors:PJ_ORourke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679417125" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/26201346.ttl"^^xsd:anyURI .
#
# books:Oneills_Music_Ireland
#         a                             schema:Book ;
#         rdfs:label                    "O'Neill's Music of Ireland" ;
#         dcterms:creator               authors:Miles_Krassen , authors:Francis_ONeill ;
#         dcterms:title                 "O'Neill's Music of Ireland" ;
#         schema:author                 authors:Miles_Krassen , authors:Francis_ONeill ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825601738" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/833169028.ttl"^^xsd:anyURI .
#
# books:Juliet_Naked  a                      schema:Book ;
#         rdfs:label                    "Juliet, Naked" ;
#         dcterms:creator               authors:Nick_Hornby ;
#         dcterms:title                 "Juliet, Naked" ;
#         schema:author                 authors:Nick_Hornby ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781594484773" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1059570310.ttl"^^xsd:anyURI .
#
# books:In_the_Country_Great_King
#         a                             schema:Book ;
#         rdfs:label                    "In the Country of the Great King" ;
#         dcterms:creator               authors:Ardythe_Ashley ;
#         dcterms:title                 "In the Country of the Great King" ;
#         schema:author                 authors:Ardythe_Ashley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345379934" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/27980135.ttl"^^xsd:anyURI .
#
# books:Bloodsucking_Fiends  a               schema:Book ;
#         rdfs:label                    "Bloodsucking Fiends" ;
#         dcterms:creator               authors:Christopher_Moore ;
#         dcterms:title                 "Bloodsucking fiends : a love story" ;
#         schema:author                 authors:Christopher_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0571198414" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/175285154.ttl"^^xsd:anyURI .
#
# books:Too_Many_Tears  a                    schema:Book ;
#         rdfs:label                    "Too Many Tears" ;
#         dcterms:creator               authors:Sonja_Maria_Dahl ;
#         dcterms:title                 "Too Many Tears" ;
#         schema:author                 authors:Sonja_Maria_Dahl ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46867512.ttl"^^xsd:anyURI .
#
# books:Flounder  a                          schema:Book ;
#         rdfs:label                    "The Flounder" ;
#         dcterms:creator               authors:Gunter_Grass ;
#         dcterms:title                 "The Flounder" ;
#         schema:author                 authors:Gunter_Grass ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0156319357" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39118958.ttl"^^xsd:anyURI .
#
# books:Courage_to_Create  a                 schema:Book ;
#         rdfs:label                    "The Courage to Create" ;
#         dcterms:creator               authors:Rollo_May ;
#         dcterms:title                 "The Courage to Create" ;
#         schema:author                 authors:Rollo_May ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0844668540" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/231586929.ttl"^^xsd:anyURI .
#
# books:The_Return_of_Goddess
#         a                             schema:Book ;
#         rdfs:label                    "The Return of the Goddess" ;
#         dcterms:creator               authors:Elizabeth_Cunningham ;
#         dcterms:title                 "The Return of the Goddess : a divine comedy" ;
#         schema:author                 authors:Elizabeth_Cunningham ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0882681575" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/228391661.ttl"^^xsd:anyURI .
#
# books:American_Primitive  a                schema:Book ;
#         rdfs:label                    "American Primitive : poems" ;
#         dcterms:creator               authors:Mary_Oliver ;
#         dcterms:title                 "American Primitive : poems" ;
#         schema:author                 authors:Mary_Oliver ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316650048" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/8930963.ttl"^^xsd:anyURI .
#
# books:The_Cold_Dish  a                     schema:Book ;
#         rdfs:label                    "The Cold Dish" ;
#         dcterms:creator               authors:Craig_Johnson ;
#         dcterms:title                 "The Cold Dish" ;
#         schema:author                 authors:Craig_Johnson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780143123170" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1001983160.ttl"^^xsd:anyURI .
#
# books:Jazz_Guitarist_v2  a                 schema:Book ;
#         rdfs:label                    "Jazz Guitarist, Volume 2" ;
#         dcterms:creator               authors:Ronny_Lee ;
#         dcterms:title                 "Jazz Guitarist, Volume 2" ;
#         schema:author                 authors:Ronny_Lee ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/939559211.ttl"^^xsd:anyURI .
#
# books:House_of_Sand_and_Fog
#         a                             schema:Book ;
#         rdfs:label                    "House of Sand and Fog" ;
#         dcterms:creator               authors:Andre_Dubus ;
#         dcterms:title                 "House of Sand and Fog" ;
#         schema:author                 authors:Andre_Dubus ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375708413" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/54498224.ttl"^^xsd:anyURI .
#
# books:Maximum_Bob  a                       schema:Book ;
#         rdfs:label                    "Maximum Bob" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Maximum Bob" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385323964" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/38993721.ttl"^^xsd:anyURI .
#
# books:The_N_Word  a                        schema:Book ;
#         rdfs:label                    "The N Word" ;
#         dcterms:creator               authors:Jabari_Asim ;
#         dcterms:title                 "The N Word : who can say it, who shouldn't, and why" ;
#         schema:author                 authors:Jabari_Asim ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780618197170" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/71222991.ttl"^^xsd:anyURI .
#
# books:Stories_of_Eva_Luna  a               schema:Book ;
#         rdfs:label                    "The Stories of Eva Luna" ;
#         dcterms:creator               authors:Isabel_Allende ;
#         dcterms:title                 "The Stories of Eva Luna" ;
#         schema:author                 authors:Isabel_Allende ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553550039" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/804373994.ttl"^^xsd:anyURI .
#
# books:Cheese_Primer  a                     schema:Book ;
#         rdfs:label                    "Cheese Primer" ;
#         dcterms:creator               authors:Steven_Jenkins ;
#         dcterms:title                 "Cheese Primer" ;
#         schema:author                 authors:Steven_Jenkins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0894807625" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/671737286.ttl"^^xsd:anyURI .
#
# books:Atlantis_Found  a                    schema:Book ;
#         rdfs:label                    "Atlantis Found" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Atlantis Found" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0425177173" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41967119.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Comix_3
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Comix No. 3" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Comix No. 3" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Jazz_Styles_of_John_Klemmer
#         a                             schema:Book ;
#         rdfs:label                    "The Jazz Styles of John Klemmer" ;
#         dcterms:creator               authors:John_Klemmer ;
#         dcterms:title                 "The Jazz Styles of John Klemmer" ;
#         schema:author                 authors:John_Klemmer ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/225844749.ttl"^^xsd:anyURI .
#
# books:Coyote_Silk  a                       schema:Book ;
#         rdfs:label                    "Coyote Silk" ;
#         dcterms:creator               authors:Gino_Sky ;
#         dcterms:title                 "Coyote Silk" ;
#         schema:author                 authors:Gino_Sky ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "093819092X" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16523093.ttl"^^xsd:anyURI .
#
# books:On_the_Road  a                       schema:Book ;
#         rdfs:label                    "On the Road" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "On the Road" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670874787" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36597852.ttl"^^xsd:anyURI .
#
# books:Relix_16_2  a                        schema:Book ;
#         rdfs:label                    "Relix Vol. 16 No. 2" ;
#         dcterms:creator               authors:Relix_Magazine ;
#         dcterms:title                 "Relix Vol. 16 No. 2" ;
#         schema:author                 authors:Relix_Magazine ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Winnie_the_Pooh_2  a                 schema:Book ;
#         rdfs:label                    "Winnie the Pooh (Dell ed.)" ;
#         dcterms:creator               authors:AA_Milne ;
#         dcterms:title                 "Winnie the Pooh" ;
#         schema:author                 authors:AA_Milne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440495903" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/4677728.ttl"^^xsd:anyURI .
#
# books:Budding_Prospects  a               schema:Book ;
#         rdfs:label                  "Budding Prospects" ;
#         dcterms:creator             authors:T_Coraghessan_Boyle ;
#         dcterms:title               "Budding Prospects" ;
#         schema:author               authors:T_Coraghessan_Boyle ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/10146303.ttl"^^xsd:anyURI .
#
# books:Te_of_Piglet  a                      schema:Book ;
#         rdfs:label                    "Te of Piglet" ;
#         dcterms:creator               authors:Benjamin_Hoff ;
#         dcterms:title                 "Te of Piglet" ;
#         schema:author                 authors:Benjamin_Hoff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140230165" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/438340159.ttl"^^xsd:anyURI .
#
# books:Love_n_Sleep  a                      schema:Book ;
#         rdfs:label                    "Love & Sleep" ;
#         dcterms:creator               authors:John_Crowley ;
#         dcterms:title                 "Love & Sleep" ;
#         schema:author                 authors:John_Crowley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553374680" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/29429204.ttl"^^xsd:anyURI .
#
# books:Cheese_Bible  a                      schema:Book ;
#         rdfs:label                    "The Cheese Bible" ;
#         dcterms:creator               authors:Christian_Teubner ;
#         dcterms:title                 "The Cheese Bible" ;
#         schema:author                 authors:Christian_Teubner ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670881295" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40168789.ttl"^^xsd:anyURI .
#
# books:Calculated_Risk  a                   schema:Book ;
#         rdfs:label                    "A Calculated Risk" ;
#         dcterms:creator               authors:Katherine_Neville ;
#         dcterms:title                 "A Calculated Risk" ;
#         schema:author                 authors:Katherine_Neville ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345386825" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/441198481.ttl"^^xsd:anyURI .
#
# books:Matterhorn  a                        schema:Book ;
#         rdfs:label                    "Matterhorn : a novel of the Vietnam War" ;
#         dcterms:creator               authors:Karl_Marlantes ;
#         dcterms:title                 "Matterhorn : a novel of the Vietnam War" ;
#         schema:author                 authors:Karl_Marlantes ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780802145314" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/669750166.ttl"^^xsd:anyURI .
#
# books:Our_Like_Will_Not_Be
#         a                             schema:Book ;
#         rdfs:label                    "Our Like Will Not Be There Again" ;
#         dcterms:creator               authors:Lawrence_Millman ;
#         dcterms:title                 "Our like will not be there again : notes from the west of Ireland" ;
#         schema:author                 authors:Lawrence_Millman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1886913528" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47716517.ttl"^^xsd:anyURI .
#
# books:Macrobiotic_Cooking  a               schema:Book ;
#         rdfs:label                    "Macrobiotic Cooking for Everyone" ;
#         dcterms:creator               authors:Edward_Esko , authors:Wendy_Esko ;
#         dcterms:title                 "Macrobiotic Cooking for Everyone" ;
#         schema:author                 authors:Edward_Esko , authors:Wendy_Esko ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0870404695" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/415351511.ttl"^^xsd:anyURI .
#
# books:Dont_Sleep_With_Drummer
#         a                             schema:Book ;
#         rdfs:label                    "Don't Sleep with Your Drummer" ;
#         dcterms:creator               authors:Jen_Sincero ;
#         dcterms:title                 "Don't Sleep with Your Drummer" ;
#         schema:author                 authors:Jen_Sincero ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743453913" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52785410.ttl"^^xsd:anyURI .
#
# books:French_Cheeses  a                    schema:Book ;
#         rdfs:label                    "French Cheeses" ;
#         dcterms:creator               authors:Kazuko_Masui ;
#         dcterms:title                 "French Cheeses" ;
#         schema:author                 authors:Kazuko_Masui ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0789410702" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/317866716.ttl"^^xsd:anyURI .
#
# books:MerriamWebsterDict  a                schema:Book ;
#         rdfs:label                    "Merriam-Webster's Pocket Dictionary" ;
#         dcterms:creator               authors:MerriamWebster ;
#         dcterms:title                 "Merriam-Webster's Pocket Dictionary" ;
#         schema:author                 authors:MerriamWebster ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877795002" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52981160.ttl"^^xsd:anyURI .
#
# books:Ripe_for_Picking  a                  schema:Book ;
#         rdfs:label                    "Ripe for the Picking" ;
#         dcterms:creator               authors:Annie_Hawes ;
#         dcterms:title                 "Ripe for the Picking" ;
#         schema:author                 authors:Annie_Hawes ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0141008903" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1028333006.ttl"^^xsd:anyURI .
#
# books:Miss_Smillas_feeling_for_snow
#         a                             schema:Book ;
#         rdfs:label                    "Miss Smilla's feeling for snow" ;
#         dcterms:creator               authors:Peter_Hoeg ;
#         dcterms:title                 "Miss Smilla's feeling for snow" ;
#         schema:author                 authors:Peter_Hoeg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0002713349" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/156470741.ttl"^^xsd:anyURI .
#
# books:God_Delusion  a                      schema:Book ;
#         rdfs:label                    "The God Delusion" ;
#         dcterms:creator               authors:Richard_Dawkins ;
#         dcterms:title                 "The God Delusion" ;
#         schema:author                 authors:Richard_Dawkins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0618680004" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/475140358.ttl"^^xsd:anyURI .
#
# books:The_Kingdom  a                       schema:Book ;
#         rdfs:label                    "The Kingdom : a Fargo Adventure" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "The Kingdom : a Fargo Adventure" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425248089" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1102141184.ttl"^^xsd:anyURI .
#
# books:Travels_with_Charley
#         a                             schema:Book ;
#         rdfs:label                    "Travels with Charley : in search of America" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "Travels with Charley : in search of America" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140053204" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/419514.ttl"^^xsd:anyURI .
#
# books:Sundays_at_Moosewood_Restaurant
#         a                           schema:Book ;
#         rdfs:label                  "Sundays at Moosewood Restaurant" ;
#         dcterms:creator             authors:Moosewood_Collective ;
#         dcterms:title               "Sundays at Moosewood Restaurant" ;
#         schema:author               authors:Moosewood_Collective ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/21563875.ttl"^^xsd:anyURI .
#
# books:Deadeye_Dick  a                      schema:Book ;
#         rdfs:label                    "Deadeye Dick" ;
#         dcterms:creator               authors:Kurt_Vonnegut ;
#         dcterms:title                 "Deadeye Dick : a novel" ;
#         schema:author                 authors:Kurt_Vonnegut ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440117658" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/314044679.ttl"^^xsd:anyURI .
#
# books:Valhalla_Rising  a                   schema:Book ;
#         rdfs:label                    "Valhalla Rising" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Valhalla Rising" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0425185710" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1028021852.ttl"^^xsd:anyURI .
#
# books:A_cat_man_and_two_women
#         a                             schema:Book ;
#         rdfs:label                    "A Cat, a Man, and Two Women : stories" ;
#         dcterms:creator               authors:Junichiro_Tanizaki ;
#         dcterms:title                 "A Cat, a Man, and Two Women : stories" ;
#         schema:author                 authors:Junichiro_Tanizaki ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "4770016050" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/926773648.ttl"^^xsd:anyURI .
#
# books:The_Journal_of_Albion_Moonlight
#         a                             schema:Book ;
#         rdfs:label                    "The Journal of Albion Moonlight" ;
#         dcterms:creator               authors:Kenneth_Patchen ;
#         dcterms:title                 "The Journal of Albion Moonlight" ;
#         schema:author                 authors:Kenneth_Patchen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811201449" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/917052513.ttl"^^xsd:anyURI .
#
# books:Sound_of_One_Hand_Clapping
#         a                             schema:Book ;
#         rdfs:label                    "The Sound of One Hand Clapping" ;
#         dcterms:creator               authors:Richard_Flanagan ;
#         dcterms:title                 "The Sound of One Hand Clapping" ;
#         schema:author                 authors:Richard_Flanagan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802137849" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/492941920.ttl"^^xsd:anyURI .
#
# books:The_Lincoln_Lawyer  a                schema:Book ;
#         rdfs:label                    "The Lincoln Lawyer : a novel" ;
#         dcterms:creator               authors:Michael_Connelly ;
#         dcterms:title                 "The Lincoln Lawyer : a novel" ;
#         schema:author                 authors:Michael_Connelly ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781455516346" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/60311867.ttl"^^xsd:anyURI .
#
# books:Going_after_Cacciato
#         a                             schema:Book ;
#         rdfs:label                    "Going After Cacciato : a novel" ;
#         dcterms:creator               authors:Tim_OBrien ;
#         dcterms:title                 "Going After Cacciato : a novel" ;
#         schema:author                 authors:Tim_OBrien ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385283490" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/471548545.ttl"^^xsd:anyURI .
#
# books:A_Wolverine_is_Eating_My_Leg
#         a                           schema:Book ;
#         rdfs:label                  "A Wolverine is Eating My Leg" ;
#         dcterms:creator             authors:Tim_Cahill ;
#         dcterms:title               "A Wolverine is Eating My Leg" ;
#         schema:author               authors:Tim_Cahill ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/18463134.ttl"^^xsd:anyURI .
#
# books:Dirty_bird_blues  a                  schema:Book ;
#         rdfs:label                    "Dirty bird blues : a novel" ;
#         dcterms:creator               authors:Clarence_Major ;
#         dcterms:title                 "Dirty bird blues : a novel" ;
#         schema:author                 authors:Clarence_Major ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0425159035" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34356908.ttl"^^xsd:anyURI .
#
# books:Cooks_Tour  a                        schema:Book ;
#         rdfs:label                    "A Cook's Tour: In Search of a Perfect Meal" ;
#         dcterms:creator               authors:Anthony_Bourdain ;
#         dcterms:title                 "A Cook's Tour: In Search of a Perfect Meal" ;
#         schema:author                 authors:Anthony_Bourdain ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1582341400" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/702200908.ttl"^^xsd:anyURI .
#
# books:Enduring_Cuba  a                     schema:Book ;
#         rdfs:label                    "Enduring Cuba" ;
#         dcterms:creator               authors:Zoe_Bran ;
#         dcterms:title                 "Enduring Cuba" ;
#         schema:author                 authors:Zoe_Bran ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1740590678" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/948165459.ttl"^^xsd:anyURI .
#
# books:Mumbo_Jumbo  a                       schema:Book ;
#         rdfs:label                    "Mumbo Jumbo" ;
#         dcterms:creator               authors:JJ_Henderson ;
#         dcterms:title                 "Mumbo Jumbo" ;
#         schema:author                 authors:JJ_Henderson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0689707304" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/974305617.ttl"^^xsd:anyURI .
#
# books:A_Little_Too_Much_is_Enough
#         a                             schema:Book ;
#         rdfs:label                    "A Little Too Much is Enough" ;
#         dcterms:creator               authors:Kathleen_Tyau ;
#         dcterms:title                 "A Little Too Much is Enough" ;
#         schema:author                 authors:Kathleen_Tyau ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0393315592" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32693013.ttl"^^xsd:anyURI .
#
# books:What_Am_I_Doing_Here
#         a                             schema:Book ;
#         rdfs:label                    "What Am I Doing Here" ;
#         dcterms:creator               authors:Bruce_Chatwin ;
#         dcterms:title                 "What Am I Doing Here" ;
#         schema:author                 authors:Bruce_Chatwin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140115773" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/889698709.ttl"^^xsd:anyURI .
#
# books:The_river_why  a                     schema:Book ;
#         rdfs:label                    "The River Why" ;
#         dcterms:creator               authors:David_James_Duncan ;
#         dcterms:title                 "The River Why" ;
#         schema:author                 authors:David_James_Duncan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553344862" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/10512023.ttl"^^xsd:anyURI .
#
# books:Song_of_Solomon  a                   schema:Book ;
#         rdfs:label                    "Song of Solomon" ;
#         dcterms:creator               authors:Toni_Morrison ;
#         dcterms:title                 "Song of Solomon" ;
#         schema:author                 authors:Toni_Morrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452260116" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/2798656.ttl"^^xsd:anyURI .
#
# books:Vintage_Pellegrini  a              schema:Book ;
#         rdfs:label                  "Vintage Pellegrini" ;
#         dcterms:creator             authors:Schuyler_Ingle , authors:Angelo_Pellegrini ;
#         dcterms:title               "Vintage Pellegrini : the collected wisdom of an American buongustaio : writings" ;
#         schema:author               authors:Angelo_Pellegrini ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Schuyler_Ingle ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/24065023.ttl"^^xsd:anyURI .
#
# books:American_Wholefoods_Cuisine
#         a                             schema:Book ;
#         rdfs:label                    "American Wholefoods Cuisine" ;
#         dcterms:creator               authors:Nikki_Goldbeck ;
#         dcterms:title                 "American wholefoods cuisine : 1300 meatless wholesome recipes from short order to gourmet" ;
#         schema:author                 authors:Nikki_Goldbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1886101116" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/824202446.ttl"^^xsd:anyURI .
#
# books:The_last_good_kiss_a_novel
#         a                             schema:Book ;
#         rdfs:label                    "The Last Good Kiss : a novel" ;
#         dcterms:creator               authors:James_Crumley ;
#         dcterms:title                 "The Last Good Kiss : a novel" ;
#         schema:author                 authors:James_Crumley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394759893" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3914232.ttl"^^xsd:anyURI .
#
# books:Polar_Shift  a                       schema:Book ;
#         rdfs:label                    "Polar Shift" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Polar Shift" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060930535" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1012397947.ttl"^^xsd:anyURI .
#
# books:The_Cooks_Own_Book  a                schema:Book ;
#         rdfs:label                    "The Cook's Own Book" ;
#         dcterms:creator               authors:Collins_Publishing ;
#         dcterms:title                 "The Cook's Own Book" ;
#         schema:author                 authors:Collins_Publishing ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679729798" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/613602678.ttl"^^xsd:anyURI .
#
# books:Te_Ao_marama  a                      schema:Book ;
#         rdfs:label                    "Te Ao Mārama : Contemporary Maori Writing" ;
#         dcterms:creator               authors:Haare_Williams ;
#         dcterms:title                 "Te Ao mārama : contemporary Maori writing. volume 3" ;
#         schema:author                 authors:Haare_Williams ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0790003163" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/968777962.ttl"^^xsd:anyURI .
#
# books:Ireland_Sings  a                     schema:Book ;
#         rdfs:label                    "Ireland Sings" ;
#         dcterms:creator               authors:Dominic_Behan ;
#         dcterms:title                 "Ireland Sings" ;
#         schema:author                 authors:Dominic_Behan ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/917052153.ttl"^^xsd:anyURI .
#
# books:Panama  a                            schema:Book ;
#         rdfs:label                    "Panama" ;
#         dcterms:creator               authors:Thomas_McGuane ;
#         dcterms:title                 "Panama" ;
#         schema:author                 authors:Thomas_McGuane ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679752919" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/4195144.ttl"^^xsd:anyURI .
#
# books:Haiku_Harvest  a                     schema:Book ;
#         rdfs:label                    "Haiku Harvest" ;
#         dcterms:creator               authors:Peter_Beilenson ;
#         dcterms:title                 "Haiku Harvest" ;
#         schema:author                 authors:Peter_Beilenson ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/895150436.ttl"^^xsd:anyURI .
#
# books:I_the_Jury_My_Gun_is_Quick
#         a                           schema:Book ;
#         rdfs:label                  "I, the Jury, My Gun is Quick, Vengeance is Mine" ;
#         dcterms:creator             authors:Mickey_Spillane ;
#         dcterms:title               "I, the Jury, My Gun is Quick, Vengeance is Mine" ;
#         schema:author               authors:Mickey_Spillane ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/655034321.ttl"^^xsd:anyURI .
#
# books:Rolling_Stone_JG_2  a                schema:Book ;
#         rdfs:label                    "Rolling Stone: Jerry Garcia Issue 2" ;
#         dcterms:creator               authors:Rolling_Stone ;
#         dcterms:title                 "Rolling Stone: Jerry Garcia Issue 2" ;
#         schema:author                 authors:Rolling_Stone ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Mariette_in_Ecstasy  a               schema:Book ;
#         rdfs:label                    "Mariette in Ecstasy" ;
#         dcterms:creator               authors:Ron_Hansen ;
#         dcterms:title                 "Mariette in Ecstasy" ;
#         schema:author                 authors:Ron_Hansen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060981180" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23733958.ttl"^^xsd:anyURI .
#
# books:One    a                             schema:Book ;
#         rdfs:label                    "One: a novel" ;
#         dcterms:creator               authors:Richard_Bach ;
#         dcterms:title                 "One: a novel" ;
#         schema:author                 authors:Richard_Bach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "044020562X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20672897.ttl"^^xsd:anyURI .
#
# books:The_Ice_Princess  a                  schema:Book ;
#         rdfs:label                    "The Ice Princess" ;
#         dcterms:creator               authors:Camilla_Lackberg ;
#         dcterms:title                 "The Ice Princess" ;
#         schema:author                 authors:Camilla_Lackberg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781451621747" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/954809606.ttl"^^xsd:anyURI .
#
# books:Worlds_End  a                        schema:Book ;
#         rdfs:label                    "World's End" ;
#         dcterms:creator               authors:T_Coraghessan_Boyle ;
#         dcterms:title                 "World's End : a novel" ;
#         schema:author                 authors:T_Coraghessan_Boyle ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140299939" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/958196981.ttl"^^xsd:anyURI .
#
# books:Walking_With_the_Wind
#         a                             schema:Book ;
#         rdfs:label                    "Walking with the Wind" ;
#         dcterms:creator               authors:Mike_DOrso , authors:John_Lewis ;
#         dcterms:title                 "Walking with the wind : a memoir of the movement" ;
#         schema:author                 authors:Mike_DOrso , authors:John_Lewis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0156007088" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/849221955.ttl"^^xsd:anyURI .
#
# books:Henderson_Rain_King  a               schema:Book ;
#         rdfs:label                    "Henderson, the Rain King" ;
#         dcterms:creator               authors:Saul_Bellow ;
#         dcterms:title                 "Henderson, the Rain King" ;
#         schema:author                 authors:Saul_Bellow ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140189424" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/263635216.ttl"^^xsd:anyURI .
#
# books:Shine_Hawk  a                        schema:Book ;
#         rdfs:label                    "Shine Hawk" ;
#         dcterms:creator               authors:Charlie_Smith ;
#         dcterms:title                 "Shine Hawk : a novel" ;
#         schema:author                 authors:Charlie_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671684981" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20996858.ttl"^^xsd:anyURI .
#
# books:Hammerhead_Ranch_Motel
#         a                             schema:Book ;
#         rdfs:label                    "Hammerhead Ranch Motel" ;
#         dcterms:creator               authors:Tim_Dorsey ;
#         dcterms:title                 "Hammerhead Ranch Motel" ;
#         schema:author                 authors:Tim_Dorsey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380732343" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/69331979.ttl"^^xsd:anyURI .
#
# books:Mama_Day  a                          schema:Book ;
#         rdfs:label                    "Mama Day" ;
#         dcterms:creator               authors:Gloria_Naylor ;
#         dcterms:title                 "Mama Day" ;
#         schema:author                 authors:Gloria_Naylor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679721819" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/302016615.ttl"^^xsd:anyURI .
#
# books:The_God_of_Small_Things
#         a                             schema:Book ;
#         rdfs:label                    "The God of Small Things" ;
#         dcterms:creator               authors:Arundhati_Roy ;
#         dcterms:title                 "The God of Small Things" ;
#         schema:author                 authors:Arundhati_Roy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060977493" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/993998622.ttl"^^xsd:anyURI .
#
# books:Detective_Inspector_Huss
#         a                             schema:Book ;
#         rdfs:label                    "Detective Inspector Huss" ;
#         dcterms:creator               authors:Helene_Tursten ;
#         dcterms:title                 "Detective Inspector Huss" ;
#         schema:author                 authors:Helene_Tursten ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1569473706" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/50645586.ttl"^^xsd:anyURI .
#
# books:The_Wishing_Box  a                   schema:Book ;
#         rdfs:label                    "The Wishing Box" ;
#         dcterms:creator               authors:Dashka_Slater ;
#         dcterms:title                 "The Wishing Box" ;
#         schema:author                 authors:Dashka_Slater ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811831302" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59534773.ttl"^^xsd:anyURI .
#
# books:Heat_Islands  a                      schema:Book ;
#         rdfs:label                    "The Heat Islands" ;
#         dcterms:creator               authors:Randy_Wayne_White ;
#         dcterms:title                 "The Heat Islands" ;
#         schema:author                 authors:Randy_Wayne_White ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312929773" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24698726.ttl"^^xsd:anyURI .
#
# books:Selected_Poems_ts  a                 schema:Book ;
#         rdfs:label                    "Selected Poems" ;
#         dcterms:creator               authors:TS_Eliot ;
#         dcterms:title                 "Selected Poems" ;
#         schema:author                 authors:TS_Eliot ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20548864.ttl"^^xsd:anyURI .
#
# books:I_love_myself_when_laughing
#         a                           schema:Book ;
#         rdfs:label                  "I love myself when I am laughing" ;
#         dcterms:creator             authors:Zora_Neale_Hurston , authors:Alice_Walker ;
#         dcterms:title               "I love myself when I am laughing : and then again when I am looking mean : a Zora Neale Hurston reader" ;
#         schema:author               authors:Zora_Neale_Hurston ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Alice_Walker ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/968533965.ttl"^^xsd:anyURI .
#
# books:Sea_Kayak_Navigation
#         a                           schema:Book ;
#         rdfs:label                  "Sea Kayak Navigation" ;
#         dcterms:creator             authors:Franco_Ferrero ;
#         dcterms:title               "Sea Kayak Navigation" ;
#         schema:author               authors:Franco_Ferrero ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/43540585.ttl"^^xsd:anyURI .
#
# books:The_Natural_Foods_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "The Natural Foods Cookbook" ;
#         dcterms:creator               authors:Beatrice_Trum_Hunter ;
#         dcterms:title                 "The Natural Foods Cookbook" ;
#         schema:author                 authors:Beatrice_Trum_Hunter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0515053422" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/6301593.ttl"^^xsd:anyURI .
#
# books:Vietnam_History  a                   schema:Book ;
#         rdfs:label                    "Vietnam : a history" ;
#         dcterms:creator               authors:Stanley_Karnow ;
#         dcterms:title                 "Vietnam : a history" ;
#         schema:author                 authors:Stanley_Karnow ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670746045" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1001499478.ttl"^^xsd:anyURI .
#
# books:The_Hand_I_Fan_With  a               schema:Book ;
#         rdfs:label                    "The Hand I Fan With" ;
#         dcterms:creator               authors:Tina_McElroy_Ansa ;
#         dcterms:title                 "The Hand I Fan With" ;
#         schema:author                 authors:Tina_McElroy_Ansa ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385476019" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34285168.ttl"^^xsd:anyURI .
#
# books:Aegypt  a                            schema:Book ;
#         rdfs:label                    "Aegypt" ;
#         dcterms:creator               authors:John_Crowley ;
#         dcterms:title                 "Aegypt" ;
#         schema:author                 authors:John_Crowley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553374303" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31760735.ttl"^^xsd:anyURI .
#
# books:Principles_Instructional_Design
#         a                             schema:Book ;
#         rdfs:label                    "Principles of Instructional Design" ;
#         dcterms:creator               authors:Robert_Gagne ;
#         dcterms:title                 "Principles of Instructional Design" ;
#         schema:author                 authors:Robert_Gagne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0030347572" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/473873958.ttl"^^xsd:anyURI .
#
# books:Mere_Christianity  a                 schema:Book ;
#         rdfs:label                    "Mere Christianity" ;
#         dcterms:creator               authors:CS_Lewis ;
#         dcterms:title                 "Mere Christianity" ;
#         schema:author                 authors:CS_Lewis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0020868308" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/941701078.ttl"^^xsd:anyURI .
#
# books:Vanity_of_Duluoz  a                  schema:Book ;
#         rdfs:label                    "Vanity of Duluoz" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Vanity of Duluoz" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0399503862" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924854674.ttl"^^xsd:anyURI .
#
# books:The_Hard_Way  a                      schema:Book ;
#         rdfs:label                    "The Hard Way" ;
#         dcterms:creator               authors:Lee_Child ;
#         dcterms:title                 "The Hard Way" ;
#         schema:author                 authors:Lee_Child ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440246008" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1104669634.ttl"^^xsd:anyURI .
#
# books:How_Late_It_Was  a                   schema:Book ;
#         rdfs:label                    "How Late It Was, How Late" ;
#         dcterms:creator               authors:James_Kelman ;
#         dcterms:title                 "How Late It Was, How Late" ;
#         schema:author                 authors:James_Kelman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385315600" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924500254.ttl"^^xsd:anyURI .
#
# books:Linden_Hills  a                      schema:Book ;
#         rdfs:label                    "Linden Hills" ;
#         dcterms:creator               authors:Gloria_Naylor ;
#         dcterms:title                 "Linden Hills" ;
#         schema:author                 authors:Gloria_Naylor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140088296" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476327782.ttl"^^xsd:anyURI .
#
# books:Get_Outta_Town  a                    schema:Book ;
#         rdfs:label                    "Get Outta Town" ;
#         dcterms:creator               authors:Ted_Ringer ;
#         dcterms:title                 "Get Outta Town : a Tale of the Grateful Dead, the IRS, and Coffee" ;
#         schema:author                 authors:Ted_Ringer ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1033660650.ttl"^^xsd:anyURI .
#
# books:White_Linoness  a                    schema:Book ;
#         rdfs:label                    "The White Lioness" ;
#         dcterms:creator               authors:Henning_Mankell ;
#         dcterms:title                 "The White Lioness" ;
#         schema:author                 authors:Henning_Mankell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781400031559" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1120399545.ttl"^^xsd:anyURI .
#
# books:Lets_Cook_It_Right  a              schema:Book ;
#         rdfs:label                  "Let's Cook It Right" ;
#         dcterms:creator             authors:Adelle_Davis ;
#         dcterms:title               "Let's Cook It Right" ;
#         schema:author               authors:Adelle_Davis ;
#         schema:bookFormat           schema:Paperback ;
#         schema:isbn                 "0046410333" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/938432387.ttl"^^xsd:anyURI .
#
# books:The_Country_Life  a                  schema:Book ;
#         rdfs:label                    "The Country Life" ;
#         dcterms:creator               authors:Rachel_Cusk ;
#         dcterms:title                 "The Country Life" ;
#         schema:author                 authors:Rachel_Cusk ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312198485" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39812370.ttl"^^xsd:anyURI .
#
# books:Bangkok_Tattoo  a                    schema:Book ;
#         rdfs:label                    "Bangkok Tattoo" ;
#         dcterms:creator               authors:John_Burdett ;
#         dcterms:title                 "Bangkok Tattoo" ;
#         schema:author                 authors:John_Burdett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400032911" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/70705035.ttl"^^xsd:anyURI .
#
# books:Road_Atlas  a                        schema:Book ;
#         rdfs:label                    "Road Atlas & Trip Planner" ;
#         dcterms:creator               authors:Rand_McNally ;
#         dcterms:title                 "Road Atlas & Trip Planner" ;
#         schema:author                 authors:Rand_McNally ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36858541.ttl"^^xsd:anyURI .
#
# books:Songbook  a                          schema:Book ;
#         rdfs:label                    "Songbook" ;
#         dcterms:creator               authors:Nick_Hornby ;
#         dcterms:title                 "Songbook" ;
#         schema:author                 authors:Nick_Hornby ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0971904774" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/964873786.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Made_Easy_for_Guitar
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead : Made Easy for Guitar" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead : Made Easy for Guitar" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30420761.ttl"^^xsd:anyURI .
#
# books:Zia_Summer  a                        schema:Book ;
#         rdfs:label                    "Zia Summer" ;
#         dcterms:creator               authors:Rudolfo_Anaya ;
#         dcterms:title                 "Zia Summer" ;
#         schema:author                 authors:Rudolfo_Anaya ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446518433" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31606922.ttl"^^xsd:anyURI .
#
# books:Eric_Clapton_Guitar  a               schema:Book ;
#         rdfs:label                    "Eric Clapton - Guitar" ;
#         dcterms:creator               authors:Eric_Clapton ;
#         dcterms:title                 "Eric Clapton - Guitar" ;
#         schema:author                 authors:Eric_Clapton ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 .
#
# books:Old_Possums_Book_of_Practical_Cats
#         a                             schema:Book ;
#         rdfs:label                    "Old Possum's Book of Practical Cats" ;
#         dcterms:creator               authors:TS_Eliot ;
#         dcterms:title                 "Old Possum's Book of Practical Cats" ;
#         schema:author                 authors:TS_Eliot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "015668568X" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/817814380.ttl"^^xsd:anyURI .
#
# books:Diet_for_a_Small_Planet_2
#         a                             schema:Book ;
#         rdfs:label                    "Diet for a Small Planet" ;
#         dcterms:creator               authors:Frances_Moore_Lappe ;
#         dcterms:title                 "Diet for a Small Planet" ;
#         schema:author                 authors:Frances_Moore_Lappe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345295242" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32693013.ttl"^^xsd:anyURI .
#
# books:The_journey_home  a                schema:Book ;
#         rdfs:label                  "The journey home : some words" ;
#         dcterms:creator             authors:Edward_Abbey ;
#         dcterms:title               "The journey home : some words in defense of the American West" ;
#         schema:author               authors:Edward_Abbey ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/2523569.ttl"^^xsd:anyURI .
#
# books:Starship_and_Canoe  a                schema:Book ;
#         rdfs:label                    "The Starship and the Canoe" ;
#         dcterms:creator               authors:Kenneth_Brower ;
#         dcterms:title                 "The Starship and the Canoe" ;
#         schema:author                 authors:Kenneth_Brower ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060910305" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9466934.ttl"^^xsd:anyURI .
#
# books:The_girl_who_played_with_fire
#         a                             schema:Book ;
#         rdfs:label                    "The Girl Who Played with Fire" ;
#         dcterms:creator               authors:Stieg_Larsson ;
#         dcterms:title                 "The Girl Who Played with Fire" ;
#         schema:author                 authors:Stieg_Larsson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780143170105" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/262433336.ttl"^^xsd:anyURI .
#
# books:The_Scarecrow  a                     schema:Book ;
#         rdfs:label                    "The Scarecrow : a novel" ;
#         dcterms:creator               authors:Michael_Connelly ;
#         dcterms:title                 "The Scarecrow : a novel" ;
#         schema:author                 authors:Michael_Connelly ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780446401203" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/298209030.ttl"^^xsd:anyURI .
#
# books:Journey_to_Ixtlan  a                 schema:Book ;
#         rdfs:label                    "Journey to Ixtlan" ;
#         dcterms:creator               authors:Carlos_Castaneda ;
#         dcterms:title                 "Journey to Ixtlan the lessons of Don Juan" ;
#         schema:author                 authors:Carlos_Castaneda ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671827685" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1075682359.ttl"^^xsd:anyURI .
#
# books:Western_Swing  a                     schema:Book ;
#         rdfs:label                    "Western Swing" ;
#         dcterms:creator               authors:Tim_Sandlin ;
#         dcterms:title                 "Western Swing" ;
#         schema:author                 authors:Tim_Sandlin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1573226319" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36188313.ttl"^^xsd:anyURI .
#
# books:Bad_Luck_and_Trouble
#         a                             schema:Book ;
#         rdfs:label                    "Bad Luck and Trouble" ;
#         dcterms:creator               authors:Lee_Child ;
#         dcterms:title                 "Bad Luck and Trouble" ;
#         schema:author                 authors:Lee_Child ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780440246015" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1054386655.ttl"^^xsd:anyURI .
#
# books:Cheese_Connaisseur  a                schema:Book ;
#         rdfs:label                    "Cheese : a connoisseur's guide to the world's best" ;
#         dcterms:creator               authors:Max_McCalman , authors:David_Gibbons ;
#         dcterms:title                 "Cheese : a connoisseur's guide to the world's best" ;
#         schema:author                 authors:David_Gibbons , authors:Max_McCalman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400050340" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/56329285.ttl"^^xsd:anyURI .
#
# books:Writings_Drawings_Dylan
#         a                             schema:Book ;
#         rdfs:label                    "Writings and Drawings" ;
#         dcterms:creator               authors:Bob_Dylan ;
#         dcterms:title                 "Writings and Drawings" ;
#         schema:author                 authors:Bob_Dylan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394482433" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/429390723.ttl"^^xsd:anyURI .
#
# books:Under_the_Fifth_Sun  a               schema:Book ;
#         rdfs:label                    "Under the Fifth Sun" ;
#         dcterms:creator               authors:Earl_Shorris ;
#         dcterms:title                 "Under the Fifth Sun" ;
#         schema:author                 authors:Earl_Shorris ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440093880" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1029850734.ttl"^^xsd:anyURI .
#
# books:The_World_As_I_See_It
#         a                             schema:Book ;
#         rdfs:label                    "The World As I See It" ;
#         dcterms:creator               authors:Albert_Einstein ;
#         dcterms:title                 "The World As I See It: Out of My Later Years" ;
#         schema:author                 authors:Albert_Einstein ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22340941.ttl"^^xsd:anyURI .
#
# books:The_Virgin_in_the_Garden
#         a                           schema:Book ;
#         rdfs:label                  "The Virgin in the Garden" ;
#         dcterms:creator             authors:AS_Byatt ;
#         dcterms:title               "The Virgin in the Garden" ;
#         schema:author               authors:AS_Byatt ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/24373791.ttl"^^xsd:anyURI .
#
# books:Tao_Te_Ching  a                      schema:Book ;
#         rdfs:comment                  "Translation of Lao Tsu's work." ;
#         rdfs:label                    "Tao Te Ching" ;
#         dcterms:creator               authors:Jane_English , authors:Giafu_Feng ;
#         dcterms:title                 "Tao Te Ching" ;
#         schema:author                 authors:Jane_English , authors:Giafu_Feng ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "039471833X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/833200725.ttl"^^xsd:anyURI .
#
# books:Fifty_Guitar_Solos  a                schema:Book ;
#         rdfs:label                    "50 classical guitar solos in tablature" ;
#         dcterms:creator               authors:Howard_Wallach ;
#         dcterms:title                 "50 classical guitar solos in tablature" ;
#         schema:author                 authors:Howard_Wallach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1569220808" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779024194.ttl"^^xsd:anyURI .
#
# books:Salamander  a                        schema:Book ;
#         rdfs:label                    "Salamander" ;
#         dcterms:creator               authors:Thomas_Wharton ;
#         dcterms:title                 "Salamander" ;
#         schema:author                 authors:Maryse_Conde ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743444159" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45414348.ttl"^^xsd:anyURI .
#
# books:Modern_Method_Guitar_v2
#         a                             schema:Book ;
#         rdfs:label                    "A Modern Method for Guitar. vol. 2" ;
#         dcterms:creator               authors:William_Leavitt ;
#         dcterms:title                 "A Modern Method for Guitar. vol. 2" ;
#         schema:author                 authors:William_Leavitt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0876390165" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/66566421.ttl"^^xsd:anyURI .
#
# books:Irons_in_the_Fire  a               schema:Book ;
#         rdfs:label                  "Irons in the Fire" ;
#         dcterms:creator             authors:John_McPhee ;
#         dcterms:title               "Irons in the Fire" ;
#         schema:author               authors:John_McPhee ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/35121749.ttl"^^xsd:anyURI .
#
# books:Singin_and_swingin  a                schema:Book ;
#         rdfs:label                    "Singin' and swingin' and gettin' merry like Christmas" ;
#         dcterms:creator               authors:Maya_Angelou ;
#         dcterms:title                 "Singin' and swingin' and gettin' merry like Christmas " ;
#         schema:author                 authors:Maya_Angelou ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0860686736" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/2213357.ttl"^^xsd:anyURI .
#
# books:Lunatics  a                          schema:Book ;
#         rdfs:label                    "Lunatics" ;
#         dcterms:creator               authors:Bradley_Denton ;
#         dcterms:title                 "Lunatics" ;
#         schema:author                 authors:Bradley_Denton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553378910" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/809384716.ttl"^^xsd:anyURI .
#
# books:Trinity_Fields  a                    schema:Book ;
#         rdfs:label                    "Trinity Fields" ;
#         dcterms:creator               authors:Bradford_Morrow ;
#         dcterms:title                 "Trinity Fields" ;
#         schema:author                 authors:Bradford_Morrow ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140240136" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34682426.ttl"^^xsd:anyURI .
#
# books:Blueprint_for_Disaster
#         a                             schema:Book ;
#         rdfs:label                    "Get Fuzzy : Blueprint for Disaster" ;
#         dcterms:creator               authors:Darby_Conley ;
#         dcterms:title                 "Get Fuzzy : Blueprint for Disaster" ;
#         schema:author                 authors:Darby_Conley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0740738089" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/856144818.ttl"^^xsd:anyURI .
#
# books:Equinox_life_love_and_birds_of_prey
#         a                             schema:Book ;
#         rdfs:label                    "Equinox: life, love, and birds of prey" ;
#         dcterms:creator               authors:Dan_OBrien ;
#         dcterms:title                 "Equinox: life, love, and birds of prey" ;
#         schema:author                 authors:Dan_OBrien ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1558214569" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/35397811.ttl"^^xsd:anyURI .
#
# books:The_Macken_Charm  a                  schema:Book ;
#         rdfs:label                    "The Macken Charm : a novel" ;
#         dcterms:creator               authors:Jack_Hodgins ;
#         dcterms:title                 "The Macken Charm : a novel" ;
#         schema:author                 authors:Jack_Hodgins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0771041853" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/878914595.ttl"^^xsd:anyURI .
#
# books:Wolf   a                             schema:Book ;
#         rdfs:label                    "Wolf" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Wolf" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684826127" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/786202456.ttl"^^xsd:anyURI .
#
# books:Escape_to_Beulah  a                schema:Book ;
#         rdfs:label                  "Escape to Beulah" ;
#         dcterms:creator             authors:Anne_Cameron ;
#         dcterms:title               "Escape to Beulah" ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Anne_Cameron ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/22505494.ttl"^^xsd:anyURI .
#
# books:Fearless_Jones  a                    schema:Book ;
#         rdfs:label                    "Fearless Jones" ;
#         dcterms:creator               authors:Walter_Mosley ;
#         dcterms:title                 "Fearless Jones : a novel" ;
#         schema:author                 authors:Walter_Mosley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446610127" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45393179.ttl"^^xsd:anyURI .
#
# books:In_Out_Garden  a                     schema:Book ;
#         rdfs:label                    "In and Out of the Garden" ;
#         dcterms:creator               authors:Sara_Midda ;
#         dcterms:title                 "In and Out of the Garden" ;
#         schema:author                 authors:Sara_Midda ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0894801937" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779980574.ttl"^^xsd:anyURI .
#
# books:Billies_Ghost  a                     schema:Book ;
#         rdfs:label                    "Billie's Ghost" ;
#         dcterms:creator               authors:Chad_Hautmann ;
#         dcterms:title                 "Billie's Ghost" ;
#         schema:author                 authors:Chad_Hautmann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452284813" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/56944480.ttl"^^xsd:anyURI .
#
# books:Sex_and_Sunsets  a                   schema:Book ;
#         rdfs:label                    "Sex and Sunsets" ;
#         dcterms:creator               authors:Tim_Sandlin ;
#         dcterms:title                 "Sex and Sunsets" ;
#         schema:author                 authors:Tim_Sandlin ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0449909247" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/14003275.ttl"^^xsd:anyURI .
#
# books:Creative_Process  a                  schema:Book ;
#         rdfs:label                    "The Creative Process" ;
#         dcterms:creator               authors:Brewster_Ghiselin ;
#         dcterms:title                 "The Creative Process" ;
#         schema:author                 authors:Brewster_Ghiselin ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/752951877.ttl"^^xsd:anyURI .
#
# books:Oregon  a                            schema:Book ;
#         rdfs:label                    "Oregon" ;
#         dcterms:creator               authors:Judy_Jewell ;
#         dcterms:title                 "Oregon" ;
#         schema:author                 authors:Judy_Jewell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878867881" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/873183171.ttl"^^xsd:anyURI .
#
# books:Good_Food  a                         schema:Book ;
#         rdfs:label                    "Good Food" ;
#         dcterms:creator               authors:Margaret_Wittenberg ;
#         dcterms:title                 "Good Food : the Complete Guide to Eating Well" ;
#         schema:author                 authors:Margaret_Wittenberg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0895947463" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31901397.ttl"^^xsd:anyURI .
#
# books:Cryptonomicon  a                     schema:Book ;
#         rdfs:label                    "Cryptonomicon" ;
#         dcterms:creator               authors:Neal_Stephenson ;
#         dcterms:title                 "Cryptonomicon" ;
#         schema:author                 authors:Neal_Stephenson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380788624" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/829769762.ttl"^^xsd:anyURI .
#
# books:The_Infinite_Plan  a                 schema:Book ;
#         rdfs:label                    "The Infinite Plan" ;
#         dcterms:creator               authors:Isabel_Allende ;
#         dcterms:title                 "The Infinite Plan : a novel" ;
#         schema:author                 authors:Isabel_Allende ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060924985" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1140463229.ttl"^^xsd:anyURI .
#
# books:You_Shall_Know_Velocity
#         a                             schema:Book ;
#         rdfs:label                    "You Shall Know our Velocity" ;
#         dcterms:creator               authors:Dave_Eggers ;
#         dcterms:title                 "You shall know our velocity : previously retitled as Sacrament" ;
#         schema:author                 authors:Dave_Eggers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1400033543" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/940711110.ttl"^^xsd:anyURI .
#
# books:Peace_is_every_step  a               schema:Book ;
#         rdfs:label                    "Peace is every step : the path of mindfulness in everyday life" ;
#         dcterms:creator               authors:Thich_Nhat_Hanh ;
#         dcterms:title                 "Peace is every step : the path of mindfulness in everyday life" ;
#         schema:author                 authors:Thich_Nhat_Hanh ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553071289" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22387883.ttl"^^xsd:anyURI .
#
# books:Chocolat_a_novel  a                schema:Book ;
#         rdfs:label                  "Chocolat : a novel" ;
#         dcterms:creator             authors:Joanne_Harris ;
#         dcterms:title               "Chocolat : a novel" ;
#         schema:author               authors:Joanne_Harris ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/39223572.ttl"^^xsd:anyURI .
#
# books:Ark_Restaurant_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "The Ark Restaurant Cookbook" ;
#         dcterms:creator               authors:Jimella_Lucas ;
#         dcterms:title                 "The Ark Restaurant Cookbook : Cuisine of the Pacific Northwest " ;
#         schema:author                 authors:Jimella_Lucas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140467319" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12163043.ttl"^^xsd:anyURI .
#
# books:Terror_of_Living  a                  schema:Book ;
#         rdfs:label                    "The Terror of Living" ;
#         dcterms:creator               authors:Urban_Waite ;
#         dcterms:title                 "The Terror of Living" ;
#         schema:author                 authors:Urban_Waite ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780316097888" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/707964821.ttl"^^xsd:anyURI .
#
# books:Pretty_Birds  a                      schema:Book ;
#         rdfs:label                    "Pretty Birds" ;
#         dcterms:creator               authors:Scott_Simon ;
#         dcterms:title                 "Pretty Birds" ;
#         schema:author                 authors:Scott_Simon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0812973305" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/70143924.ttl"^^xsd:anyURI .
#
# books:Be_Cool  a                           schema:Book ;
#         rdfs:label                    "Be Cool" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Be Cool" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060777060" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/57186411.ttl"^^xsd:anyURI .
#
# books:Once_Were_Warriors  a                schema:Book ;
#         rdfs:label                    "Once Were Warriors" ;
#         dcterms:creator               authors:Alan_Duff ;
#         dcterms:title                 "Once Were Warriors" ;
#         schema:author                 authors:Alan_Duff ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0824815939" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/469372382.ttl"^^xsd:anyURI .
#
# books:Yamaha_Song_Book  a                  schema:Book ;
#         rdfs:label                    "Yamaha Song Book" ;
#         dcterms:creator               authors:Yamaha ;
#         dcterms:title                 "Yamaha Song Book" ;
#         schema:author                 authors:Yamaha ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 .
#
# books:Wisconsin_Cheesecyclopedia
#         a                             schema:Book ;
#         rdfs:label                    "Wisconsin Cheesecyclopedia" ;
#         dcterms:creator               authors:Wisconsin_Milk_Marketing ;
#         dcterms:title                 "Wisconsin Cheesecyclopedia" ;
#         schema:author                 authors:Wisconsin_Milk_Marketing ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/952098239.ttl"^^xsd:anyURI .
#
# books:The_War_of_the_Saints
#         a                             schema:Book ;
#         rdfs:label                    "The War of the Saints" ;
#         dcterms:creator               authors:Jorge_Amado ;
#         dcterms:title                 "The War of the Saints" ;
#         schema:author                 authors:Jorge_Amado ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553374400" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1077851342.ttl"^^xsd:anyURI .
#
# books:The_Invisible_Circus
#         a                             schema:Book ;
#         rdfs:label                    "The Invisible Circus" ;
#         dcterms:creator               authors:Jennifer_Egan ;
#         dcterms:title                 "The Invisible Circus" ;
#         schema:author                 authors:Jennifer_Egan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312140908" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/972697773.ttl"^^xsd:anyURI .
#
# books:Holographic_Universe
#         a                             schema:Book ;
#         rdfs:label                    "The Holographic Universe" ;
#         dcterms:creator               authors:Michael_Talbot ;
#         dcterms:title                 "The Holographic Universe" ;
#         schema:author                 authors:Michael_Talbot ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060922583" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476785446.ttl"^^xsd:anyURI .
#
# books:The_Sorceress  a                     schema:Book ;
#         rdfs:label                    "The Sorceress" ;
#         dcterms:creator               authors:Michael_Scott ;
#         dcterms:title                 "The sorceress ; the secrets of the immortal Nicholas Flamel : Book three" ;
#         schema:author                 authors:Michael_Scott ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780385735308" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/860754338.ttl"^^xsd:anyURI .
#
# books:Catcher_in_the_Rye  a                schema:Book ;
#         rdfs:label                    "The Catcher in the Rye" ;
#         dcterms:creator               authors:JD_Salinger ;
#         dcterms:title                 "The Catcher in the Rye" ;
#         schema:author                 authors:JD_Salinger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "031654003X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1153562713.ttl"^^xsd:anyURI .
#
# books:Sailor_Song  a                       schema:Book ;
#         rdfs:label                    "Sailor Song" ;
#         dcterms:creator               authors:Ken_Kesey ;
#         dcterms:title                 "Sailor Song" ;
#         schema:author                 authors:Ken_Kesey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670835218" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28572564.ttl"^^xsd:anyURI .
#
# books:Purple_Cane_Road  a                  schema:Book ;
#         rdfs:label                    "Purple Cane Road" ;
#         dcterms:creator               authors:James_Lee_Burke ;
#         dcterms:title                 "Purple Cane Road" ;
#         schema:author                 authors:James_Lee_Burke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440224047" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47836299.ttl"^^xsd:anyURI .
#
# books:Serious_Pig  a                       schema:Book ;
#         rdfs:label                    "Serious Pig" ;
#         dcterms:creator               authors:John_Thorne ;
#         dcterms:title                 "Serious pig : an American cook in search of his roots" ;
#         schema:author                 authors:John_Thorne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0865475970" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46925809.ttl"^^xsd:anyURI .
#
# books:Modern_Chord_Progressions
#         a                             schema:Book ;
#         rdfs:label                    "Modern Chord Progressions" ;
#         dcterms:creator               authors:Ted_Greene ;
#         dcterms:title                 "Modern Chord Progressions" ;
#         schema:author                 authors:Ted_Greene ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898986982" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/642838585.ttl"^^xsd:anyURI .
#
# books:Karamazov_Brothers  a                schema:Book ;
#         rdfs:label                    "The Karamazov Brothers" ;
#         dcterms:creator               authors:Fyodor_Dostoevsky ;
#         dcterms:title                 "The Karamazov Brothers" ;
#         schema:author                 authors:Fyodor_Dostoevsky ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0192826646" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/999469087.ttl"^^xsd:anyURI .
#
# books:Encounters_with_the_Archdruid
#         a                             schema:Book ;
#         rdfs:label                    "Encounters with the Archdruid" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "Encounters with the Archdruid" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374148228" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/154248.ttl"^^xsd:anyURI .
#
# books:Irish_Pub_Songs  a                   schema:Book ;
#         rdfs:label                    "The Irish Pub Songbook" ;
#         dcterms:creator               authors:Ossian_Publications ;
#         dcterms:title                 "The Irish pub songbook : 36 of the very best Irish pubsongs : with complete words, music and guitar chords" ;
#         schema:author                 authors:Ossian_Publications ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/917052153.ttl"^^xsd:anyURI .
#
# books:Memories_of_Rain  a                  schema:Book ;
#         rdfs:label                    "Memories of Rain" ;
#         dcterms:creator               authors:Sunetra_Gupta ;
#         dcterms:title                 "Memories of Rain" ;
#         schema:author                 authors:Sunetra_Gupta ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "080213341X" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1075275025.ttl"^^xsd:anyURI .
#
# books:Mountaineering_Medicine
#         a                             schema:Book ;
#         rdfs:label                    "Mountaineering Medicine" ;
#         dcterms:creator               authors:Fred_Darvill ;
#         dcterms:title                 "Mountaineering Medicine: (a wilderness medical guide)" ;
#         schema:author                 authors:Fred_Darvill ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/15535896.ttl"^^xsd:anyURI .
#
# books:Basic_Rockcraft  a                   schema:Book ;
#         rdfs:label                    "Basic Rockcraft" ;
#         dcterms:creator               authors:Royal_Robbins ;
#         dcterms:title                 "Basic Rockcraft" ;
#         schema:author                 authors:Royal_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0910856346" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24339675.ttl"^^xsd:anyURI .
#
# books:ThreeSixtyFive_Zen  a                schema:Book ;
#         rdfs:label                    "365 Zen" ;
#         dcterms:creator               authors:Jean_Smith ;
#         dcterms:title                 "365 Zen" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Jean_Smith ;
#         schema:isbn                   "0062516027" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40255968.ttl"^^xsd:anyURI .
#
# books:The_Beat_Vision  a                   schema:Book ;
#         rdfs:label                    "The Beat Vision" ;
#         dcterms:creator               authors:Arthur_Winfield_Knight , authors:Kit_Knight ;
#         dcterms:title                 "The Beat Vision" ;
#         schema:author                 authors:Kit_Knight , authors:Arthur_Winfield_Knight ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0913729418" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/14187434.ttl"^^xsd:anyURI .
#
# books:Sonar3  a                            schema:Book ;
#         rdfs:label                    "Sonar 3" ;
#         dcterms:creator               authors:Twelve_Time_Sys ;
#         dcterms:title                 "Sonar 3" ;
#         schema:author                 authors:Twelve_Time_Sys ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 .
#
# books:Gods_Go_Begging  a                   schema:Book ;
#         rdfs:label                    "Gods Go Begging" ;
#         dcterms:creator               authors:Alfredo_Vea ;
#         dcterms:title                 "Gods Go Begging" ;
#         schema:author                 authors:Alfredo_Vea ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452281156" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1102248007.ttl"^^xsd:anyURI .
#
# books:Four_Agreements  a                   schema:Book ;
#         rdfs:label                    "The Four Agreements" ;
#         dcterms:creator               authors:Don_Miguel_Ruiz ;
#         dcterms:title                 "The four agreements : a practical guide to personal freedom" ;
#         schema:author                 authors:Don_Miguel_Ruiz ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878424319" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1083740655.ttl"^^xsd:anyURI .
#
# books:Blackwater  a                        schema:Book ;
#         rdfs:label                    "Blackwater" ;
#         dcterms:creator               authors:Kerstin_Ekman ;
#         dcterms:title                 "Blackwater" ;
#         schema:author                 authors:Kerstin_Ekman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312152477" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1028331853.ttl"^^xsd:anyURI .
#
# books:Cats_Cradle  a                       schema:Book ;
#         rdfs:label                    "Cat's Cradle" ;
#         dcterms:creator               authors:Kurt_Vonnegut ;
#         dcterms:title                 "Cat's Cradle" ;
#         schema:author                 authors:Kurt_Vonnegut ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440111498" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19000012.ttl"^^xsd:anyURI .
#
# books:The_electric_kool_aid_acid_test
#         a                             schema:Book ;
#         rdfs:label                    "The electric kool-aid acid test" ;
#         dcterms:creator               authors:Tom_Wolfe ;
#         dcterms:title                 "The electric kool-aid acid test" ;
#         schema:author                 authors:Tom_Wolfe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553126873" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42827164.ttl"^^xsd:anyURI .
#
# books:Shambhala  a                         schema:Book ;
#         rdfs:label                    "Shambhala" ;
#         dcterms:creator               authors:Chogyam_Trungpa ;
#         dcterms:title                 "Shambhala : the sacred path of the warrior" ;
#         schema:author                 authors:Chogyam_Trungpa ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "055326172X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/636492791.ttl"^^xsd:anyURI .
#
# books:Fear_and_loathing_campaign_trail
#         a                             schema:Book ;
#         rdfs:label                    "Fear and loathing : on the campaign trail '72" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "Fear and loathing : on the campaign trail '72" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446698229" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/692291194.ttl"^^xsd:anyURI .
#
# books:Raw_and_the_Cooked  a                schema:Book ;
#         rdfs:label                    "The Raw and the Cooked" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "The Raw and the Cooked" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802116981" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46952110.ttl"^^xsd:anyURI .
#
# books:Wild_meat_and_bully_burgers_2
#         a                             schema:Book ;
#         rdfs:label                    "Wild Meat and the Bully Burgers" ;
#         dcterms:creator               authors:Lois-Ann_Yamanaka ;
#         dcterms:title                 "Wild Meat and the Bully Burgers : [a novel]" ;
#         schema:author                 authors:Lois-Ann_Yamanaka ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374290202" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/636113793.ttl"^^xsd:anyURI .
#
# books:Voice_Crying_in_the_Wilderness
#         a                             schema:Book ;
#         rdfs:label                    "A Voice Crying in the Wilderness" ;
#         dcterms:creator               authors:Edward_Abbey ;
#         dcterms:title                 "A Voice Crying in the Wilderness" ;
#         schema:author                 authors:Edward_Abbey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312041470" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/22392647.ttl"^^xsd:anyURI .
#
# books:Playing_in_the_band  a               schema:Book ;
#         rdfs:label                    "Playing in the band : an oral and visual portrait of the Grateful Dead" ;
#         dcterms:creator               authors:David_Gans ;
#         dcterms:title                 "Playing in the band : an oral and visual portrait of the Grateful Dead" ;
#         schema:author                 authors:David_Gans ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312616309" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12198235.ttl"^^xsd:anyURI .
#
# books:The_Fire_Never_Dies  a               schema:Book ;
#         rdfs:label                    "The Fire Never Dies" ;
#         dcterms:creator               authors:Richard_Sterling ;
#         dcterms:title                 "The fire never dies : one man's raucous romp down the road of food, passion, and adventure" ;
#         schema:author                 authors:Richard_Sterling ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1885211708" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1035904344.ttl"^^xsd:anyURI .
#
# books:Midwives  a                          schema:Book ;
#         rdfs:label                    "Midwives" ;
#         dcterms:creator               authors:Chris_Bohjalian ;
#         dcterms:title                 "Midwives" ;
#         schema:author                 authors:Chris_Bohjalian ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679771468" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45342004.ttl"^^xsd:anyURI .
#
# books:Ireland_selected_stories
#         a                             schema:Book ;
#         rdfs:label                    "Ireland : selected stories" ;
#         dcterms:creator               authors:William_Trevor ;
#         dcterms:title                 "Ireland : selected stories" ;
#         schema:author                 authors:William_Trevor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140277595" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/607404449.ttl"^^xsd:anyURI .
#
# books:Gig_Bag_Scales  a                    schema:Book ;
#         rdfs:label                    "Gig Bag Book of Scales" ;
#         dcterms:creator               authors:Mark_Bridges ;
#         dcterms:title                 "The Gig Bag Book of Scales for All Guitarists" ;
#         schema:author                 authors:Mark_Bridges ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825615755" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39785467.ttl"^^xsd:anyURI .
#
# books:Man_on_Spikes  a                     schema:Book ;
#         rdfs:label                    "Man on Spikes" ;
#         dcterms:creator               authors:Eliot_Asinof ;
#         dcterms:title                 "Man on Spikes" ;
#         schema:author                 authors:Eliot_Asinof ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0809321904" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/37843781.ttl"^^xsd:anyURI .
#
# books:Childhood_Adolescence_Youth
#         a                             schema:Book ;
#         rdfs:label                    "Childhood Adolescence Youth" ;
#         dcterms:creator               authors:Leo_Tolstoy ;
#         dcterms:title                 "Childhood Adolescence Youth" ;
#         schema:author                 authors:Leo_Tolstoy ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/18616746.ttl"^^xsd:anyURI .
#
# books:New_Recipes_from_Moosewood_Restaurant
#         a                           schema:Book ;
#         rdfs:label                  "New Recipes from Moosewood Restaurant" ;
#         dcterms:creator             authors:Moosewood_Collective ;
#         dcterms:title               "New Recipes from Moosewood Restaurant" ;
#         schema:author               authors:Moosewood_Collective ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/16165443.ttl"^^xsd:anyURI .
#
# books:On_the_Bright_Side  a                schema:Book ;
#         rdfs:label                    "On the bright side, I'm now the girlfriend of a sex god" ;
#         dcterms:creator               authors:Louise_Rennison ;
#         dcterms:title                 "On the bright side, I'm now the girlfriend of a sex god" ;
#         schema:author                 authors:Louise_Rennison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0064472264" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1089624050.ttl"^^xsd:anyURI .
#
# books:Letranger  a                         schema:Book ;
#         rdfs:label                    "L'étranger" ;
#         dcterms:creator               authors:Albert_Camus ;
#         dcterms:title                 "L'étranger" ;
#         schema:author                 authors:Albert_Camus ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "2070360024" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476921778.ttl"^^xsd:anyURI .
#
# books:Hard_Evidence  a                     schema:Book ;
#         rdfs:label                    "Hard Evidence" ;
#         dcterms:creator               authors:John_Lescroart ;
#         dcterms:title                 "Hard Evidence" ;
#         schema:author                 authors:John_Lescroart ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0451206460" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/50022059.ttl"^^xsd:anyURI .
#
# books:Jacks_Book  a                        schema:Book ;
#         rdfs:label                    "Jack's Book : an Oral Biography of Jack Kerouac" ;
#         dcterms:creator               authors:Lawrence_Lee , authors:Barry_Gifford ;
#         dcterms:title                 "Jack's Book : an Oral Biography of Jack Kerouac" ;
#         schema:author                 authors:Lawrence_Lee , authors:Barry_Gifford ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140052690" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/5101937.ttl"^^xsd:anyURI .
#
# books:Reality_Is_Broken  a                 schema:Book ;
#         rdfs:label                    "Reality is Broken" ;
#         dcterms:creator               authors:Jane_McGonigal ;
#         dcterms:title                 "Reality is broken : why games make us better and how they can change the world" ;
#         schema:author                 authors:Jane_McGonigal ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781594202858" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/894571741.ttl"^^xsd:anyURI .
#
# books:Book_of_Macrobiotics
#         a                             schema:Book ;
#         rdfs:label                    "The Book of Macrobiotics" ;
#         dcterms:creator               authors:Michio_Kushi ;
#         dcterms:title                 "The Book of Macrobiotics" ;
#         schema:author                 authors:Michio_Kushi ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0870403818" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/873084571.ttl"^^xsd:anyURI .
#
# books:Almanac_for_Moderns  a               schema:Book ;
#         rdfs:label                    "An Almanac for Moderns" ;
#         dcterms:creator               authors:Donald_Peattie ;
#         dcterms:title                 "An Almanac for Moderns" ;
#         schema:author                 authors:Donald_Peattie ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0879233141" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/6554226.ttl"^^xsd:anyURI .
#
# books:Teachings_Don_Juan  a                schema:Book ;
#         rdfs:label                    "The Teachings of Don Juan" ;
#         dcterms:creator               authors:Carlos_Castaneda ;
#         dcterms:title                 "The teachings of Don Juan : a Yaqui way of knowledge" ;
#         schema:author                 authors:Carlos_Castaneda ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "671787489" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/924626383.ttl"^^xsd:anyURI .
#
# books:Crescent_Dawn  a                     schema:Book ;
#         rdfs:label                    "Crescent Dawn" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "Crescent Dawn" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425242391" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1005363806.ttl"^^xsd:anyURI .
#
# books:Deaf_Smith_Cookbook  a               schema:Book ;
#         rdfs:label                    "The Deaf Smith Country Cookbook" ;
#         dcterms:creator               authors:Marjorie_Winn_Ford ;
#         dcterms:title                 "The Deaf Smith Country Cookbook" ;
#         schema:author                 authors:Marjorie_Winn_Ford ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0020095007" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779049687.ttl"^^xsd:anyURI .
#
# books:Shakey  a                            schema:Book ;
#         rdfs:label                    "Shakey : Neil Young's biography" ;
#         dcterms:creator               authors:Jimmy_McDonough ;
#         dcterms:title                 "Shakey : Neil Young's biography" ;
#         schema:author                 authors:Jimmy_McDonough ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679427724" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/923857680.ttl"^^xsd:anyURI .
#
# books:Demon_Box  a                         schema:Book ;
#         rdfs:label                    "Demon Box" ;
#         dcterms:creator               authors:Ken_Kesey ;
#         dcterms:title                 "Demon Box" ;
#         schema:author                 authors:Ken_Kesey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140085300" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/13010828.ttl"^^xsd:anyURI .
#
# books:Nature_Guide_to_Healthy_Living
#         a                             schema:Book ;
#         rdfs:label                    "Nature - Your Guide to Healthy Living" ;
#         dcterms:creator               authors:A_Vogel ;
#         dcterms:title                 "Nature - Your Guide to Healthy Living" ;
#         schema:author                 authors:A_Vogel ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34380521.ttl"^^xsd:anyURI .
#
# books:The_origin_and_development_of_jazz
#         a                             schema:Book ;
#         rdfs:label                    "The Origin and Development of Jazz" ;
#         dcterms:creator               authors:Otto_Werner ;
#         dcterms:title                 "The Origin and Development of Jazz" ;
#         schema:author                 authors:Otto_Werner ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0840332327" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/239913944.ttl"^^xsd:anyURI .
#
# books:Hannas_Daughters  a                  schema:Book ;
#         rdfs:label                    "Hanna's Daughters" ;
#         dcterms:creator               authors:Marianne_Fredriksson ;
#         dcterms:title                 "Hanna's Daughters" ;
#         schema:author                 authors:Marianne_Fredriksson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345433491" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/794472086.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Comix_5
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Comix No. 5" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Comix No. 5" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Instructional_Technology
#         a                             schema:Book ;
#         rdfs:label                    "Instructional Technology" ;
#         dcterms:creator               authors:Barbara_Seels ;
#         dcterms:title                 "Instructional Technology : the definition and domains of the field." ;
#         schema:author                 authors:Barbara_Seels ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0892400722" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  2 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/856782733.ttl"^^xsd:anyURI .
#
# books:Her_Fork_Road  a                     schema:Book ;
#         rdfs:label                    "Her Fork in the Road" ;
#         dcterms:creator               authors:Lisa_Bach ;
#         dcterms:title                 "Her fork in the road : women celebrate food and travel" ;
#         schema:author                 authors:Lisa_Bach ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1885211716" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47667096.ttl"^^xsd:anyURI .
#
# books:Catcher_in_the_Rye_2
#         a                             schema:Book ;
#         rdfs:label                    "The Catcher in the Rye" ;
#         dcterms:creator               authors:JD_Salinger ;
#         dcterms:title                 "The Catcher in the Rye" ;
#         schema:author                 authors:JD_Salinger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "031654003X" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1153562713.ttl"^^xsd:anyURI .
#
# books:Down_the_River  a                    schema:Book ;
#         rdfs:label                    "Down the River" ;
#         dcterms:creator               authors:Edward_Abbey ;
#         dcterms:title                 "Down the River" ;
#         schema:author                 authors:Edward_Abbey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0525476768" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/437270249.ttl"^^xsd:anyURI .
#
# books:Relix_16_4  a                        schema:Book ;
#         rdfs:label                    "Relix Vol. 16 No. 4" ;
#         dcterms:creator               authors:Relix_Magazine ;
#         dcterms:title                 "Relix Vol. 16 No. 4" ;
#         schema:author                 authors:Relix_Magazine ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Oxford_Companion_Food
#         a                             schema:Book ;
#         rdfs:label                    "The Oxford Companion to Food" ;
#         dcterms:creator               authors:Alan_Davidson ;
#         dcterms:title                 "The Oxford Companion to Food" ;
#         schema:author                 authors:Alan_Davidson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0696206730" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/901890365.ttl"^^xsd:anyURI .
#
# books:V      a                             schema:Book ;
#         rdfs:label                    "V." ;
#         dcterms:creator               authors:Thomas_Pynchon ;
#         dcterms:title                 "V." ;
#         schema:author                 authors:Thomas_Pynchon ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060930217" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1201629551.ttl"^^xsd:anyURI .
#
# books:The_Neon_Bible  a                    schema:Book ;
#         rdfs:label                    "The Neon Bible" ;
#         dcterms:creator               authors:John_Kennedy_Toole ;
#         dcterms:title                 "The Neon Bible" ;
#         schema:author                 authors:John_Kennedy_Toole ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802132073" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/18411432.ttl"^^xsd:anyURI .
#
# books:Cloud_hidden  a                      schema:Book ;
#         rdfs:label                    "Cloud-hidden, whereabouts unknown" ;
#         dcterms:creator               authors:Alan_Watts ;
#         dcterms:title                 "Cloud-hidden, whereabouts unknown; a mountain journal" ;
#         schema:author                 authors:Alan_Watts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394719999" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/532215.ttl"^^xsd:anyURI .
#
# books:Curve_of_Time  a                   schema:Book ;
#         rdfs:label                  "The Curve of Time" ;
#         dcterms:creator             authors:M_Wylie_Blanchet ;
#         dcterms:title               "The curve of time : the classic memoir of a woman and her children who explored the coastal waters of the Pacific Northwest" ;
#         schema:author               authors:M_Wylie_Blanchet ;
#         schema:bookFormat           schema:Paperback ;
#         schema:isbn                 "1580050727" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/180082723.ttl"^^xsd:anyURI .
#
# books:Giving_Good_Weight  a                schema:Book ;
#         rdfs:label                    "Giving Good Weight" ;
#         dcterms:creator               authors:John_McPhee ;
#         dcterms:title                 "Giving Good Weight" ;
#         schema:author                 authors:John_McPhee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374516006" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/222792443.ttl"^^xsd:anyURI .
#
# books:Monkey_Wrench_Gang_2
#         a                             schema:Book ;
#         rdfs:label                    "The Monkey Wrench Gang" ;
#         dcterms:creator               authors:Edward_Abbey ;
#         dcterms:title                 "The Monkey Wrench Gang" ;
#         schema:author                 authors:Edward_Abbey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "038000741X" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/895549785.ttl"^^xsd:anyURI .
#
# books:Antarctic_navigation_a_novel
#         a                             schema:Book ;
#         rdfs:label                    "Antarctic navigation : a novel" ;
#         dcterms:creator               authors:Elizabeth_Arthur ;
#         dcterms:title                 "Antarctic navigation : a novel" ;
#         schema:author                 authors:Elizabeth_Arthur ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345402073" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28291634.ttl"^^xsd:anyURI .
#
# books:The_evolution_of_Jane
#         a                             schema:Book ;
#         rdfs:label                    "The Evolution of Jane" ;
#         dcterms:creator               authors:Cathleen_Schine ;
#         dcterms:title                 "The evolution of Jane" ;
#         schema:author                 authors:Cathleen_Schine ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452281202" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/39085423.ttl"^^xsd:anyURI .
#
# books:Desert_Solitaire  a                  schema:Book ;
#         rdfs:label                    "Desert Solitaire" ;
#         dcterms:creator               authors:Edward_Abbey ;
#         dcterms:title                 "Desert Solitaire" ;
#         schema:author                 authors:Edward_Abbey ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345278666" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/633963453.ttl"^^xsd:anyURI .
#
# books:Cheese_Cookery  a                    schema:Book ;
#         rdfs:label                    "Encyclopedia of Cheese Cookery: a Salute to Cheese" ;
#         dcterms:creator               authors:Betty_Wason ;
#         dcterms:title                 "Encyclopedia of Cheese Cookery: a Salute to Cheese" ;
#         schema:author                 authors:Betty_Wason ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0883652668" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/316870645.ttl"^^xsd:anyURI .
#
# books:The_Portable_Faulkner
#         a                             schema:Book ;
#         rdfs:label                    "The Portable Faulkner" ;
#         dcterms:creator               authors:Malcolm_Cowley ;
#         dcterms:title                 "The Portable Faulkner" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Malcolm_Cowley ;
#         schema:isbn                   "014243728X" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/283836.ttl"^^xsd:anyURI .
#
# books:WLT_a_radio_romance  a               schema:Book ;
#         rdfs:label                    "WLT, A Radio Romance" ;
#         dcterms:creator               authors:Garrsion_Keillor ;
#         dcterms:title                 "WLT, A Radio Romance" ;
#         schema:author                 authors:Garrsion_Keillor ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670842656" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23767162.ttl"^^xsd:anyURI .
#
# books:Returning_to_Earth  a                schema:Book ;
#         rdfs:label                    "Returning to Earth" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Returning to Earth" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802143318" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/795371669.ttl"^^xsd:anyURI .
#
# books:Dharma_Gaia  a                       schema:Book ;
#         rdfs:label                    "Dharma Gaia" ;
#         dcterms:creator               authors:Allan_Hunt_Badiner ;
#         dcterms:title                 "Dharma gaia : a harvest of essays in buddhism and ecology" ;
#         schema:author                 authors:Allan_Hunt_Badiner ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0938077309" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/963458729.ttl"^^xsd:anyURI .
#
# books:Sibley_Field_Guide_to_Birds
#         a                             schema:Book ;
#         rdfs:label                    "Sibley field Guide to Birds of Western North America" ;
#         dcterms:creator               authors:David_Sibley ;
#         dcterms:title                 "The Sibley field guide to birds of western North America" ;
#         schema:author                 authors:David_Sibley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679451218" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/52077800.ttl"^^xsd:anyURI .
#
# books:Ivory_Gate  a                        schema:Book ;
#         rdfs:label                    "Through the Ivory Gate" ;
#         dcterms:creator               authors:Rita_Dove ;
#         dcterms:title                 "Through the Ivory Gate" ;
#         schema:author                 authors:Rita_Dove ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679742409" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/495536582.ttl"^^xsd:anyURI .
#
# books:Midnight_at_the_Dragon_Cafe
#         a                             schema:Book ;
#         rdfs:label                    "Midnight at the Dragon Café" ;
#         dcterms:creator               authors:Judy_Fong_Bates ;
#         dcterms:title                 "Midnight at the Dragon Café" ;
#         schema:author                 authors:Judy_Fong_Bates ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781582431895" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/58955512.ttl"^^xsd:anyURI .
#
# books:Whiteness_of_Bones  a                schema:Book ;
#         rdfs:label                    "The Whiteness of Bones : a novel" ;
#         dcterms:creator               authors:Susanna_Moore ;
#         dcterms:title                 "The Whiteness of Bones : a novel" ;
#         schema:author                 authors:Susanna_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140130209" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/817662337.ttl"^^xsd:anyURI .
#
# books:Lovesick  a                          schema:Book ;
#         rdfs:label                    "Love Sick" ;
#         dcterms:creator               authors:Sue_Silverman ;
#         dcterms:title                 "Love sick : one woman's journey through sexual addiction" ;
#         schema:author                 authors:Sue_Silverman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780393333008" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/181139127.ttl"^^xsd:anyURI .
#
# books:Cat_Chaser  a                        schema:Book ;
#         rdfs:label                    "Cat Chaser" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Cat Chaser" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380646420" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/873134307.ttl"^^xsd:anyURI .
#
# books:Skinny_dip  a                        schema:Book ;
#         rdfs:label                    "Skinny Dip" ;
#         dcterms:creator               authors:Carl_Hiaasen ;
#         dcterms:title                 "Skinny Dip" ;
#         schema:author                 authors:Carl_Hiaasen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446695564" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/965568651.ttl"^^xsd:anyURI .
#
# books:Baby_of_the_Family  a                schema:Book ;
#         rdfs:label                    "Baby of the Family" ;
#         dcterms:creator               authors:Tina_McElroy_Ansa ;
#         dcterms:title                 "Baby of the Family" ;
#         schema:author                 authors:Tina_McElroy_Ansa ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0156101505" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1154542976.ttl"^^xsd:anyURI .
#
# books:Murder_of_Einstein  a                schema:Book ;
#         rdfs:label                    "Murder at Wrigley Field" ;
#         dcterms:creator               authors:Troy_Soos ;
#         dcterms:title                 "Murder at Wrigley Field" ;
#         schema:author                 authors:Troy_Soos ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553373668" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28846721.ttl"^^xsd:anyURI .
#
# books:Looking_for_Info  a                  schema:Book ;
#         rdfs:label                    "Looking for Information" ;
#         dcterms:creator               authors:David_Case ;
#         dcterms:title                 "Looking for information : a survey of research on information seeking, needs, and behavior" ;
#         schema:author                 authors:David_Case ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780123694300" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476199086.ttl"^^xsd:anyURI .
#
# books:Deans_December  a                    schema:Book ;
#         rdfs:label                    "The Dean's December" ;
#         dcterms:creator               authors:Saul_Bellow ;
#         dcterms:title                 "The Dean's December" ;
#         schema:author                 authors:Saul_Bellow ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067145806X" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/802995500.ttl"^^xsd:anyURI .
#
# books:I_Am_Snowing  a                      schema:Book ;
#         rdfs:label                    "I Am Snowing" ;
#         dcterms:creator               authors:Pavel_Kohout ;
#         dcterms:title                 "I Am Snowing : the confessions of a woman of Prague" ;
#         schema:author                 authors:Pavel_Kohout ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "015600187X" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1097592111.ttl"^^xsd:anyURI .
#
# books:Information_Literacy_Instruction
#         a                             schema:Book ;
#         rdfs:label                    "Information Literacy Instruction" ;
#         dcterms:creator               authors:Esther_Grassian ;
#         dcterms:title                 "Information literacy instruction : theory and practice" ;
#         schema:author                 authors:Esther_Grassian ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9781555706661" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1144562550.ttl"^^xsd:anyURI .
#
# books:River_Notes  a                       schema:Book ;
#         rdfs:label                    "River notes : the dance of herons" ;
#         dcterms:creator               authors:Barry_Lopez ;
#         dcterms:title                 "River notes : the dance of herons" ;
#         schema:author                 authors:Barry_Lopez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380525143" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1002886737.ttl"^^xsd:anyURI .
#
# books:A_history_of_philosophy_2
#         a                             schema:Book ;
#         rdfs:label                    "A History of Philosophy, Volumes 4-6" ;
#         dcterms:creator               authors:Frederick_Copleston ;
#         dcterms:title                 "A History of Philosophy" ;
#         schema:author                 authors:Frederick_Copleston ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "038523032X" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1014016461.ttl"^^xsd:anyURI .
#
# books:Searching_for_the_Sound
#         a                             schema:Book ;
#         rdfs:label                    "Searching for the Sound" ;
#         dcterms:creator               authors:Phil_Lesh ;
#         dcterms:title                 "Searching for the Sound" ;
#         schema:author                 authors:Phil_Lesh ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316009989" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/57393699.ttl"^^xsd:anyURI .
#
# books:Road_Dogs  a                         schema:Book ;
#         rdfs:label                    "Road Dogs" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Road Dogs" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780061985706" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1227647673.ttl"^^xsd:anyURI .
#
# books:Secrets_of_Pistoulet
#         a                             schema:Book ;
#         rdfs:label                    "The Secrets of Pistoulet : a Fable of Food, Magic, & Love" ;
#         dcterms:creator               authors:Jana_Kolpen ;
#         dcterms:title                 "The Secrets of Pistoulet : a Fable of Food, Magic, & Love" ;
#         schema:author                 authors:Jana_Kolpen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1556704437" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/990576262.ttl"^^xsd:anyURI .
#
# books:Brave_New_World  a                   schema:Book ;
#         rdfs:label                    "Brave New World" ;
#         dcterms:creator               authors:Aldous_Huxley ;
#         dcterms:title                 "Brave New World" ;
#         schema:author                 authors:Aldous_Huxley ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060830956" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1192992461.ttl"^^xsd:anyURI .
#
# books:Annual_Perennial_Groundcover
#         a                             schema:Book ;
#         rdfs:label                    "Home Depot Annual, Perennial, and Groundcover Guide" ;
#         dcterms:creator               authors:Home_Depot ;
#         dcterms:title                 "Home Depot Annual, Perennial, and Groundcover Guide" ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 .
#
# books:A_Life_in_Hand  a                    schema:Book ;
#         rdfs:label                    "A Life in Hand" ;
#         dcterms:creator               authors:Hannah_Hinchman ;
#         dcterms:title                 "A Life in Hand : creating the illuminated journal." ;
#         schema:author                 authors:Hannah_Hinchman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0879053712" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23383660.ttl"^^xsd:anyURI .
#
# books:Face_of_an_angel  a                  schema:Book ;
#         rdfs:label                    "Face of an Angel" ;
#         dcterms:creator               authors:Denise_Chavez ;
#         dcterms:title                 "Face of an Angel" ;
#         schema:author                 authors:Denise_Chavez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446671851" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32590616.ttl"^^xsd:anyURI .
#
# books:The_Last_Detective  a                schema:Book ;
#         rdfs:label                    "The Last Detective" ;
#         dcterms:creator               authors:Robert_Crais ;
#         dcterms:title                 "The Last Detective" ;
#         schema:author                 authors:Robert_Crais ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345451902" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/54830961.ttl"^^xsd:anyURI .
#
# books:Fifth_Discipline  a                  schema:Book ;
#         rdfs:label                    "The Fifth Discipline" ;
#         dcterms:creator               authors:George_Petrides ;
#         dcterms:title                 "The Fifth Discipline : the art and practice of the learning organization" ;
#         schema:author                 authors:George_Petrides ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385260954" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/263627570.ttl"^^xsd:anyURI .
#
# books:Spin_Mag  a                          schema:Book ;
#         rdfs:label                    "Spin Magazine" ;
#         dcterms:title                 "Spin Magazine" ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 .
#
# books:Candide  a                           schema:Book ;
#         rdfs:label                    "Candide" ;
#         dcterms:creator               authors:Voltaire ;
#         dcterms:title                 "Candide" ;
#         schema:author                 authors:Voltaire ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0486266893" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1178980021.ttl"^^xsd:anyURI .
#
# books:Non-Flowering_Plants
#         a                             schema:Book ;
#         rdfs:label                    "Non-Flowering Plants" ;
#         dcterms:creator               authors:Floyd_Shuttleworth ;
#         dcterms:title                 "Non-Flowering Plants" ;
#         schema:author                 authors:Floyd_Shuttleworth ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/503131711.ttl"^^xsd:anyURI .
#
# books:Not_Fade_Away  a                     schema:Book ;
#         rdfs:label                    "Not Fade Away" ;
#         dcterms:creator               authors:Jim_Dodge ;
#         dcterms:title                 "Not Fade Away" ;
#         schema:author                 authors:Jim_Dodge ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802135846" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/319775091.ttl"^^xsd:anyURI .
#
# books:Tales_of_the_Night  a                schema:Book ;
#         rdfs:label                    "Tales of the Night" ;
#         dcterms:creator               authors:Peter_Hoeg ;
#         dcterms:title                 "Tales of the Night" ;
#         schema:author                 authors:Peter_Hoeg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140279733" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1052962560.ttl"^^xsd:anyURI .
#
# books:Bitter_Grounds  a                    schema:Book ;
#         rdfs:label                    "Bitter Grounds" ;
#         dcterms:creator               authors:Sandra_Benitez ;
#         dcterms:title                 "Bitter Grounds" ;
#         schema:author                 authors:Sandra_Benitez ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312195419" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36074578.ttl"^^xsd:anyURI .
#
# books:Queens_Play  a                       schema:Book ;
#         rdfs:label                    "Queen's Play" ;
#         dcterms:creator               authors:Dorothy_Dunnett ;
#         dcterms:title                 "Queen's Play" ;
#         schema:author                 authors:Dorothy_Dunnett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067977744X" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1107013340.ttl"^^xsd:anyURI .
#
# books:The_New_York_Times_Cookbook
#         a                           schema:Book ;
#         rdfs:label                  "The New York Times Cookbook" ;
#         dcterms:creator             authors:Craig_Claiborne ;
#         dcterms:title               "The New York Times Cookbook" ;
#         schema:author               authors:Craig_Claiborne ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/429611629.ttl"^^xsd:anyURI .
#
# books:Parsival  a                          schema:Book ;
#         rdfs:label                    "Parsival, or a Knight's Tale" ;
#         dcterms:creator               authors:Richard_Monaco ;
#         dcterms:title                 "Parsival, or a Knight's Tale" ;
#         schema:author                 authors:Richard_Monaco ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067182225X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/4760083.ttl"^^xsd:anyURI .
#
# books:Zen_seeds  a                         schema:Book ;
#         rdfs:label                    "Zen seeds : reflections of a female priest" ;
#         dcterms:creator               authors:Shunto_Aoyama ;
#         dcterms:title                 "Zen seeds : reflections of a female priest" ;
#         schema:author                 authors:Shunto_Aoyama ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "4333014786" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24132008.ttl"^^xsd:anyURI .
#
# books:Snow_Falling_on_Cedars
#         a                             schema:Book ;
#         rdfs:label                    "Snow Falling on Cedars" ;
#         dcterms:creator               authors:David_Guterson ;
#         dcterms:title                 "Snow Falling on Cedars" ;
#         schema:author                 authors:David_Guterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "067976402X" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/761987250.ttl"^^xsd:anyURI .
#
# books:Olives  a                            schema:Book ;
#         rdfs:label                    "Olives" ;
#         dcterms:creator               authors:Mort_Rosenblum ;
#         dcterms:title                 "Olives" ;
#         schema:author                 authors:Mort_Rosenblum ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0865475032" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/41665188.ttl"^^xsd:anyURI .
#
# books:The_KGB_Bar_Nonfiction_Reader
#         a                           schema:Book ;
#         rdfs:label                  "The KGB Bar Nonfiction Reader" ;
#         dcterms:creator             authors:Mark_Jacobson ;
#         dcterms:title               "The KGB Bar Nonfiction Reader" ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Mark_Jacobson ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/56411820.ttl"^^xsd:anyURI .
#
# books:One_Virgin_Too_Many  a               schema:Book ;
#         rdfs:label                    "One Virgin Too Many" ;
#         dcterms:creator               authors:Lindsey_Davis ;
#         dcterms:title                 "One Virgin Too Many" ;
#         schema:author                 authors:Lindsey_Davis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446677698" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/47959610.ttl"^^xsd:anyURI .
#
# books:Chord_Chemistry  a                   schema:Book ;
#         rdfs:label                    "Chord Chemistry for Guitar" ;
#         dcterms:creator               authors:East_Coast_Books ;
#         dcterms:title                 "Chord Chemistry for Guitar" ;
#         schema:author                 authors:East_Coast_Books ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1585604909" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/948371949.ttl"^^xsd:anyURI .
#
# books:Portlable_Tolstoy  a                 schema:Book ;
#         rdfs:label                    "The Portable Tolstoy" ;
#         dcterms:creator               authors:Leo_Tolstoy ;
#         dcterms:title                 "The Portable Tolstoy" ;
#         schema:author                 authors:Leo_Tolstoy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140150919" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/865552003.ttl"^^xsd:anyURI .
#
# books:Murder_with_Puffins  a               schema:Book ;
#         rdfs:label                    "Murder with Puffins" ;
#         dcterms:creator               authors:Donna_Andrews ;
#         dcterms:title                 "Murder with Puffins" ;
#         schema:author                 authors:Donna_Andrews ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312978863" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1004883618.ttl"^^xsd:anyURI .
#
# books:Junky  a                             schema:Book ;
#         rdfs:label                    "Junky" ;
#         dcterms:creator               authors:William_S_Burroughs ;
#         dcterms:title                 "Junky" ;
#         schema:author                 authors:William_S_Burroughs ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140043519" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/2890662.ttl"^^xsd:anyURI .
#
# books:Little_Treasure_Poetry
#         a                             schema:Book ;
#         rdfs:label                    "A Little Treasure of Modern Poetry" ;
#         dcterms:creator               authors:Charles_Scribner_Sons ;
#         dcterms:title                 "A Little Treasure of Modern Poetry" ;
#         schema:author                 authors:Charles_Scribner_Sons ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 .
#
# books:Harry_Potter_Chamber_of_Secrets
#         a                             schema:Book ;
#         rdfs:label                    "Harry Potter and the Chamber of Secrets" ;
#         dcterms:creator               authors:JK_Rowling ;
#         dcterms:title                 "Harry Potter and the Chamber of Secrets" ;
#         schema:author                 authors:JK_Rowling ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0439064872" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40043650.ttl"^^xsd:anyURI .
#
# books:The_shell_collector  a               schema:Book ;
#         rdfs:label                    "The shell collector : stories" ;
#         dcterms:creator               authors:Anthony_Doerr ;
#         dcterms:title                 "The shell collector : stories" ;
#         schema:author                 authors:Anthony_Doerr ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0142002968" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20296326.ttl"^^xsd:anyURI .
#
# books:Legends_of_the_Fall  a               schema:Book ;
#         rdfs:label                    "Legends of the Fall" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Legends of the Fall" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385285965" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/918334537.ttl"^^xsd:anyURI .
#
# books:Moosewood_Desserts  a                schema:Book ;
#         rdfs:label                    "Moosewood Restaurant Book of Desserts" ;
#         dcterms:creator               authors:Moosewood_Collective ;
#         dcterms:title                 "Moosewood Restaurant Book of Desserts" ;
#         schema:author                 authors:Moosewood_Collective ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0517884933" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020245835.ttl"^^xsd:anyURI .
#
# books:Beachcombing_for_a_Shipwrecked_God
#         a                             schema:Book ;
#         rdfs:label                    "Beachcombing for a Shipwrecked God" ;
#         dcterms:creator               authors:Joe_Coomer ;
#         dcterms:title                 "Beachcombing for a Shipwrecked God" ;
#         schema:author                 authors:Joe_Coomer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "068482440X" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/472919327.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Anthology
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Anthology" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Anthology" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0897248589" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/679924548.ttl"^^xsd:anyURI .
#
# books:True_Thai  a                       schema:Book ;
#         rdfs:label                  "True Thai : the modern art of Thai cooking" ;
#         dcterms:creator             authors:Victor_Sodsook ;
#         dcterms:title               "True Thai : the modern art of Thai cooking" ;
#         schema:author               authors:Victor_Sodsook ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/31433995.ttl"^^xsd:anyURI .
#
# books:French_Cheese  a                     schema:Book ;
#         rdfs:label                    "French Cheese" ;
#         dcterms:creator               authors:Kazuko_Masui ;
#         dcterms:title                 "French Cheese" ;
#         schema:author                 authors:Kazuko_Masui ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0756614023" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/889698709.ttl"^^xsd:anyURI .
#
# books:The_Upper_Room  a                  schema:Book ;
#         rdfs:label                  "The Upper Room" ;
#         dcterms:creator             authors:Mary_Monroe ;
#         dcterms:title               "The Upper Room" ;
#         schema:author               authors:Mary_Monroe ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/47986200.ttl"^^xsd:anyURI .
#
# books:Nature_man_woman  a                  schema:Book ;
#         rdfs:label                    "Nature, man, and woman" ;
#         dcterms:creator               authors:Alan_Watts ;
#         dcterms:title                 "Nature, man, and woman" ;
#         schema:author                 authors:Alan_Watts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "394705920" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/758717.ttl"^^xsd:anyURI .
#
# books:Old_New_England_Cookbook
#         a                             schema:Book ;
#         rdfs:label                    "Old New England Cookbook" ;
#         dcterms:creator               authors:Old_New_England ;
#         dcterms:title                 "Old New England Cookbook" ;
#         schema:author                 authors:Old_New_England ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 .
#
# books:A_Sand_County_Almanac
#         a                             schema:Book ;
#         rdfs:label                    "A Sand County Almanac" ;
#         dcterms:creator               authors:Aldo_Leopold ;
#         dcterms:title                 "A Sand County Almanac" ;
#         schema:author                 authors:Aldo_Leopold ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "019505928X" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59974180.ttl"^^xsd:anyURI .
#
# books:Through_Painted_Deserts
#         a                             schema:Book ;
#         rdfs:label                    "Through Painted Deserts" ;
#         dcterms:creator               authors:Donald_Miller ;
#         dcterms:title                 "Through painted deserts : light, God, and beauty on the open road" ;
#         schema:author                 authors:Donald_Miller ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0785209824" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/58807183.ttl"^^xsd:anyURI .
#
# books:Instructional_Tech_Foundations
#         a                             schema:Book ;
#         rdfs:label                    "Instructional Technology : Foundations" ;
#         dcterms:creator               authors:Robert_Gagne ;
#         dcterms:title                 "Instructional Technology : Foundations" ;
#         schema:author                 authors:Robert_Gagne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898598788" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/697784346.ttl"^^xsd:anyURI .
#
# books:Early_Work  a                        schema:Book ;
#         rdfs:label                    "Early Work" ;
#         dcterms:creator               authors:Patti_Smith ;
#         dcterms:title                 "Early Work" ;
#         schema:author                 authors:Patti_Smith ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0393313018" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/918119945.ttl"^^xsd:anyURI .
#
# books:Fear_and_loathing_Las_Vegas
#         a                             schema:Book ;
#         rdfs:label                    "Fear and Loathing in Las Vegas" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "Fear and Loathing in Las Vegas: a savage journey to the heart of the American dream" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0446312444" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9211372.ttl"^^xsd:anyURI .
#
# books:Her_Native_Colors  a                 schema:Book ;
#         rdfs:label                    "Her Native Colors" ;
#         dcterms:creator               authors:Elisabeth_Hyde ;
#         dcterms:title                 "Her Native Colors" ;
#         schema:author                 authors:Elisabeth_Hyde ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "038529686X" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1035616489.ttl"^^xsd:anyURI .
#
# books:Still_Life_With_Woodpecker
#         a                             schema:Book ;
#         rdfs:label                    "Still Life With Woodpecker" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Still life with woodpecker : [a sort of a love story]" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553245694" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/630825504.ttl"^^xsd:anyURI .
#
# books:Physics_of_Caribou_Creek
#         a                             schema:Book ;
#         rdfs:label                    "The Physics of Caribou Creek" ;
#         dcterms:creator               authors:Carl_Forest ;
#         dcterms:title                 "The Physics of Caribou Creek" ;
#         schema:author                 authors:Carl_Forest ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878987011" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23177137.ttl"^^xsd:anyURI .
#
# books:Ordinances  a                        schema:Book ;
#         rdfs:label                    "Ordinances" ;
#         dcterms:creator               authors:Naomi_Lazard ;
#         dcterms:title                 "The Essential Teachings of Zen Master Hakuin" ;
#         schema:author                 authors:Naomi_Lazard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0882332570" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/729785974.ttl"^^xsd:anyURI .
#
# books:Close_Case  a                        schema:Book ;
#         rdfs:label                    "Close Case" ;
#         dcterms:creator               authors:Alafair_Burke ;
#         dcterms:title                 "Close Case" ;
#         schema:author                 authors:Alafair_Burke ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312940572" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/70170656.ttl"^^xsd:anyURI .
#
# books:Worst_Case_Scenario  a               schema:Book ;
#         rdfs:label                    "The Worst-case Scenario Survival Handbook" ;
#         dcterms:creator               authors:Joshua_Piven ;
#         dcterms:title                 "The worst-case scenario survival handbook : dating & sex" ;
#         schema:author                 authors:Joshua_Piven ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0811832414" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/48834019.ttl"^^xsd:anyURI .
#
# books:Consumers_Dictionary_Food
#         a                             schema:Book ;
#         rdfs:label                    "A consumer's dictionary of food additives" ;
#         dcterms:creator               authors:Ruth_Winter ;
#         dcterms:title                 "A consumer's dictionary of food additives" ;
#         schema:author                 authors:Ruth_Winter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0517572621" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/954472453.ttl"^^xsd:anyURI .
#
# books:Orchard_Beach  a                     schema:Book ;
#         rdfs:label                    "Orchard Beach" ;
#         dcterms:creator               authors:Stuart_Woods ;
#         dcterms:title                 "Orchard Beach" ;
#         schema:author                 authors:Stuart_Woods ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780061987304" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/456180917.ttl"^^xsd:anyURI .
#
# books:Catch_22  a                          schema:Book ;
#         rdfs:label                    "Catch 22" ;
#         dcterms:creator               authors:Joseph_Heller ;
#         dcterms:title                 "Catch 22" ;
#         schema:author                 authors:Joseph_Heller ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440511208" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1089509739.ttl"^^xsd:anyURI .
#
# books:Sprouting_Health  a                  schema:Book ;
#         rdfs:label                    "Sprouting for Health in the 90s" ;
#         dcterms:creator               authors:Phillip_Allen ;
#         dcterms:title                 "Sprouting for health in the 90s : build your immune system and detox your body" ;
#         schema:author                 authors:Phillip_Allen ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/397965461.ttl"^^xsd:anyURI .
#
# books:Pagan_Wall  a                        schema:Book ;
#         rdfs:label                    "The Pagan Wall" ;
#         dcterms:creator               authors:David_Arnason ;
#         dcterms:title                 "The Pagan Wall" ;
#         schema:author                 authors:David_Arnason ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0889223122" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1105180217.ttl"^^xsd:anyURI .
#
# books:On_Food_and_Cooking  a               schema:Book ;
#         rdfs:label                    "On Food and Cooking" ;
#         dcterms:creator               authors:Harold_McGee ;
#         dcterms:title                 "On Food and Cooking: the Science and Lore of the Kitchen" ;
#         schema:author                 authors:Harold_McGee ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0684800012" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1015943370.ttl"^^xsd:anyURI .
#
# books:Hummingbird_House  a               schema:Book ;
#         rdfs:label                  "Hummingbird House" ;
#         dcterms:creator             authors:Patricia_Henley ;
#         dcterms:title               "Hummingbird House" ;
#         schema:author               authors:Patricia_Henley ;
#         schema:bookFormat           schema:Paperback ;
#         schema:isbn                 "1878448986" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/985842074.ttl"^^xsd:anyURI .
#
# books:Notes_of_a_Dirty_Old_Man
#         a                             schema:Book ;
#         rdfs:label                    "Notes of a Dirty Old Man" ;
#         dcterms:creator               authors:Charles_Bukowski ;
#         dcterms:title                 "Notes of a Dirty Old Man" ;
#         schema:author                 authors:Charles_Bukowski ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0872860744" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/781238383.ttl"^^xsd:anyURI .
#
# books:Voices_in_Mirror  a                  schema:Book ;
#         rdfs:label                    "Voices in the Mirror" ;
#         dcterms:creator               authors:Gordon_Parks ;
#         dcterms:title                 "Voices in the Mirror : an autobiography" ;
#         schema:author                 authors:Gordon_Parks ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0767922123" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/839973475.ttl"^^xsd:anyURI .
#
# books:Split_Image  a                       schema:Book ;
#         rdfs:label                    "Split Image" ;
#         dcterms:creator               authors:Robert_B_Parker ;
#         dcterms:title                 "Split Image" ;
#         schema:author                 authors:Robert_B_Parker ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425239735" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/993110744.ttl"^^xsd:anyURI .
#
# books:ChroniclesOne  a                     schema:Book ;
#         rdfs:label                    "Chronicles, Volume One" ;
#         dcterms:creator               authors:Bob_Dylan ;
#         dcterms:title                 "Chronicles, Volume One" ;
#         schema:author                 authors:Bob_Dylan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743228154" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/741373728.ttl"^^xsd:anyURI .
#
# books:Making_Wild_Wine  a                  schema:Book ;
#         rdfs:label                    "Making Wild Wines and Meads" ;
#         dcterms:creator               authors:Pattie_Vargas ;
#         dcterms:title                 "Making Wild Wines and Meads" ;
#         schema:author                 authors:Pattie_Vargas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1580171826" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42835118.ttl"^^xsd:anyURI .
#
# books:Box_Unfortunate_Events
#         a                             schema:Book ;
#         rdfs:label                    "A Box of Unfortunate Events" ;
#         dcterms:creator               authors:Lemony_Snicket ;
#         dcterms:title                 "A box of unfortunate events : the situation worsens" ;
#         schema:author                 authors:Lemony_Snicket ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060095563" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/123114930.ttl"^^xsd:anyURI .
#
# books:Concise_Bob_Dylan  a                 schema:Book ;
#         rdfs:label                    "The Concise Bob Dylan" ;
#         dcterms:creator               authors:Bob_Dylan ;
#         dcterms:title                 "The Concise Bob Dylan" ;
#         schema:author                 authors:Bob_Dylan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0711957800" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40979987.ttl"^^xsd:anyURI .
#
# books:A_good_day_to_die  a                 schema:Book ;
#         rdfs:label                    "A Good day to Die" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "A Good day to Die : a novel" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385283431" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19856861.ttl"^^xsd:anyURI .
#
# books:Visions_of_Cody  a                   schema:Book ;
#         rdfs:label                    "Visions of Cody" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Visions of Cody" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0070342016" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/577961.ttl"^^xsd:anyURI .
#
# books:Pagan_Babies  a                      schema:Book ;
#         rdfs:label                    "Pagan Babies" ;
#         dcterms:creator               authors:Elmore_Leonard ;
#         dcterms:title                 "Pagan Babies" ;
#         schema:author                 authors:Elmore_Leonard ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060008776" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43851355.ttl"^^xsd:anyURI .
#
# books:Anton_Chekhov_selected_stories
#         a                             schema:Book ;
#         rdfs:label                    "Anton Chekhov selected stories" ;
#         dcterms:creator               authors:Ann_Dunnigan , authors:Anton_Chekhov ;
#         dcterms:title                 "Anton Chekhov selected stories" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:translator             authors:Ann_Dunnigan ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/15869268.ttl"^^xsd:anyURI .
#
# books:Finbars_Hotel  a                   schema:Book ;
#         rdfs:label                  "Finbar's Hotel" ;
#         dcterms:creator             authors:Dermot_Bolger ;
#         dcterms:title               "Finbar's Hotel" ;
#         schema:bookFormat           schema:Paperback ;
#         schema:editor               authors:Dermot_Bolger ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/39905962.ttl"^^xsd:anyURI .
#
# books:Stone_Junction  a                    schema:Book ;
#         rdfs:label                    "Stone Junction" ;
#         dcterms:creator               authors:Jim_Dodge ;
#         dcterms:title                 "Stone junction : an alchemical potboiler" ;
#         schema:author                 authors:Jim_Dodge ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802135854" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/19975978.ttl"^^xsd:anyURI .
#
# books:The_Enchanted_Broccoli_Forest
#         a                             schema:Book ;
#         rdfs:label                    "The Enchanted Broccoli Forest" ;
#         dcterms:creator               authors:Mollie_Katzen ;
#         dcterms:title                 "The Enchanted Broccoli Forest and Other Timeless Delicacies" ;
#         schema:author                 authors:Mollie_Katzen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0898150787" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/9576204.ttl"^^xsd:anyURI .
#
# books:An_Almanac_for_Moderns
#         a                           schema:Book ;
#         rdfs:label                  "An Almanac for Moderns" ;
#         dcterms:creator             authors:Donald_Peattie ;
#         dcterms:title               "An Almanac for Moderns " ;
#         schema:author               authors:Donald_Peattie ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1445415.ttl"^^xsd:anyURI .
#
# books:Oregon_Atlas_Gazetteer
#         a                             schema:Book ;
#         rdfs:label                    "Oregon Atlas & Gazetteer" ;
#         dcterms:creator               authors:DeLorme_Mapping_Company ;
#         dcterms:title                 "Oregon Atlas & Gazetteer" ;
#         schema:author                 authors:DeLorme_Mapping_Company ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0899332587" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/42952165.ttl"^^xsd:anyURI .
#
# books:Escoffier_Cook_Book  a               schema:Book ;
#         rdfs:label                    "The Escoffier Cook Book" ;
#         dcterms:creator               authors:Auguste_Escoffier ;
#         dcterms:title                 "The Escoffier Cook Book" ;
#         schema:author                 authors:Auguste_Escoffier ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0517506629" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/45090101.ttl"^^xsd:anyURI .
#
# books:Remembering_Power_of_Words
#         a                             schema:Book ;
#         rdfs:label                    "Remembering the Power of Words" ;
#         dcterms:creator               authors:Patricia_Schechter ;
#         dcterms:title                 "Remembering the power of words: the life of an Oregon activist, legislator, and community leader" ;
#         schema:author                 authors:Patricia_Schechter ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780870716041" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/800739511.ttl"^^xsd:anyURI .
#
# books:Last_Voyage_of_Somebody_Sailor
#         a                             schema:Book ;
#         rdfs:label                    "The Last Voyage of Somebody the Sailor" ;
#         dcterms:creator               authors:John_Barth ;
#         dcterms:title                 "The Last Voyage of Somebody the Sailor" ;
#         schema:author                 authors:John_Barth ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385422202" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/440573799.ttl"^^xsd:anyURI .
#
# books:A_Philosophical_Investigation
#         a                             schema:Book ;
#         rdfs:label                    "A Philosophical Investigation" ;
#         dcterms:creator               authors:Kathleen_Tyau ;
#         dcterms:title                 "A Philosophical Investigation" ;
#         schema:author                 authors:Kathleen_Tyau ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452271401" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28708816.ttl"^^xsd:anyURI .
#
# books:Things_Fall_Apart  a                 schema:Book ;
#         rdfs:label                    "Things Fall Apart" ;
#         dcterms:creator               authors:Chinua_Achebe ;
#         dcterms:title                 "Things Fall Apart" ;
#         schema:author                 authors:Chinua_Achebe ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1015005083.ttl"^^xsd:anyURI .
#
# books:Warlock  a                           schema:Book ;
#         rdfs:label                    "Warlock" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "Warlock: A Novel" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385291345" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/7577943.ttl"^^xsd:anyURI .
#
# books:Case_Constructivist_Classrooms
#         a                             schema:Book ;
#         rdfs:label                    "The Case for Constructivist Classrooms" ;
#         dcterms:creator               authors:Jacqueline_Brooks ;
#         dcterms:title                 "The Case for Constructivist Classrooms : in search of understanding" ;
#         schema:author                 authors:Jacqueline_Brooks ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0871202115" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/257054770.ttl"^^xsd:anyURI .
#
# books:The_woman_who_lives_in_the_earth
#         a                             schema:Book ;
#         rdfs:label                    "The Woman Who Lives in the Earth" ;
#         dcterms:creator               authors:Swain_Wolfe ;
#         dcterms:title                 "The Woman Who Lives in the Earth" ;
#         schema:author                 authors:Swain_Wolfe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0963478907" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/28567823.ttl"^^xsd:anyURI .
#
# books:Charley_Wilons_War  a                schema:Book ;
#         rdfs:label                    "Charlie Wilson's War" ;
#         dcterms:creator               authors:George_Crile ;
#         dcterms:title                 "Charlie Wilson's War" ;
#         schema:author                 authors:George_Crile ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802141242" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1030768561.ttl"^^xsd:anyURI .
#
# books:Decade_score  a                      schema:Book ;
#         rdfs:label                    "Decade" ;
#         dcterms:creator               authors:Neil_Young ;
#         dcterms:title                 "Decade" ;
#         schema:author                 authors:Neil_Young ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36033939.ttl"^^xsd:anyURI .
#
# books:Bite_Me  a                           schema:Book ;
#         rdfs:label                    "Bite Me" ;
#         dcterms:creator               authors:Christopher_Moore ;
#         dcterms:title                 "Bite Me" ;
#         schema:author                 authors:Christopher_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780061779732" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1107992371.ttl"^^xsd:anyURI .
#
# books:Being_nobody_going_nowhere
#         a                             schema:Book ;
#         rdfs:label                    "Being Nobody, Going Nowhere" ;
#         dcterms:creator               authors:Ayya_Khema ;
#         dcterms:title                 "Being Nobody, Going Nowhere" ;
#         schema:author                 authors:Ayya_Khema ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0861710525" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16079137.ttl"^^xsd:anyURI .
#
# books:Cucina_Leggera  a                  schema:Book ;
#         rdfs:label                  "Cucina Leggera" ;
#         dcterms:creator             authors:Emily_Dodi , authors:Andrea_Dodi ;
#         dcterms:title               "Cucina leggera : light & healthy recipes from northern Italy" ;
#         schema:author               authors:Emily_Dodi , authors:Andrea_Dodi ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/27147191.ttl"^^xsd:anyURI .
#
# books:Somebody_Elses_Mama  a               schema:Book ;
#         rdfs:label                    "Somebody Else's Mama : a novel" ;
#         dcterms:creator               authors:David_Haynes ;
#         dcterms:title                 "Somebody else's mama : a novel" ;
#         schema:author                 authors:David_Haynes ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1571310037" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/613321362.ttl"^^xsd:anyURI .
#
# books:Selected_Journals_of_Thoreau_2
#         a                             schema:Book ;
#         rdfs:label                    "Selected Journals of Henry David Thoreau" ;
#         dcterms:creator               authors:Carl_Bode ;
#         dcterms:title                 "Selected Journals of Henry David Thoreau" ;
#         schema:author                 authors:Carl_Bode ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1404769.ttl"^^xsd:anyURI .
#
# books:Baby_Driver  a                       schema:Book ;
#         rdfs:label                    "Baby Driver" ;
#         dcterms:creator               authors:Jan_Kerouac ;
#         dcterms:title                 "Baby Driver" ;
#         schema:author                 authors:Jan_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0030625386" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/8762624.ttl"^^xsd:anyURI .
#
# books:Tales_of_Ordinary_Madness
#         a                             schema:Book ;
#         rdfs:label                    "Tales of Ordinary Madness" ;
#         dcterms:creator               authors:Charles_Bukowski ;
#         dcterms:title                 "Tales of Ordinary Madness" ;
#         schema:author                 authors:Charles_Bukowski ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0872861554" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/800837351.ttl"^^xsd:anyURI .
#
# books:Daily_Afflictions  a                 schema:Book ;
#         rdfs:label                    "Daily Afflictions" ;
#         dcterms:creator               authors:Andrew_Boyd ;
#         dcterms:title                 "Daily afflictions : the agony of being connected to everything in the universe" ;
#         schema:author                 authors:Andrew_Boyd ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0393322815" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/46685676.ttl"^^xsd:anyURI .
#
# books:Bean_Trees  a                        schema:Book ;
#         rdfs:label                    "The Bean Trees" ;
#         dcterms:creator               authors:Barbara_Kingsolver ;
#         dcterms:title                 "The Bean Trees : a novel" ;
#         schema:author                 authors:Barbara_Kingsolver ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060915544" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/709411408.ttl"^^xsd:anyURI .
#
# books:Subterraneans  a                     schema:Book ;
#         rdfs:label                    "The Subterraneans" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "The Subterraneans" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802131867" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1004997702.ttl"^^xsd:anyURI .
#
# books:Fifty_Years_of_Russian_Prose
#         a                             schema:Book ;
#         rdfs:label                    "Fifty Years of Russian Prose" ;
#         dcterms:creator               authors:Krystyna_Pomorska ;
#         dcterms:title                 "Fifty Years of Russian Prose" ;
#         schema:bookFormat             schema:Paperback ;
#         schema:editor                 authors:Krystyna_Pomorska ;
#         schema:isbn                   "0262660199" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/310656026.ttl"^^xsd:anyURI .
#
# books:Poisonwood_Bible  a                  schema:Book ;
#         rdfs:label                    "Poisonwood Bible" ;
#         dcterms:creator               authors:Barbara_Kingsolver ;
#         dcterms:title                 "Poisonwood Bible" ;
#         schema:author                 authors:Barbara_Kingsolver ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060930535" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/825557679.ttl"^^xsd:anyURI .
#
# books:Book_of_Hopi  a                      schema:Book ;
#         rdfs:label                    "The Book of the Hopi" ;
#         dcterms:creator               authors:Frank_Waters ;
#         dcterms:title                 "The Book of the Hopi" ;
#         schema:author                 authors:Frank_Waters ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140045279" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/847055696.ttl"^^xsd:anyURI .
#
# books:Black_Elk_Speaks  a                  schema:Book ;
#         rdfs:label                    "Black Elk Speaks" ;
#         dcterms:creator               authors:John_Neihardt , authors:Black_Elk ;
#         dcterms:title                 "Black Elk Speaks" ;
#         schema:author                 authors:Black_Elk , authors:John_Neihardt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0743506391" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/608838231.ttl"^^xsd:anyURI .
#
# books:Basic_Writings_of_Nietzsche
#         a                             schema:Book ;
#         rdfs:label                    "Basic Writings of Nietzsche" ;
#         dcterms:creator               authors:Friedrick_Nietzsche ;
#         dcterms:title                 "Basic Writings of Nietzsche" ;
#         schema:author                 authors:Friedrick_Nietzsche ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394604067" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/809730238.ttl"^^xsd:anyURI .
#
# books:The_Powwow_Highway  a                schema:Book ;
#         rdfs:label                    "The Powwow Highway : a novel" ;
#         dcterms:creator               authors:David_Seals ;
#         dcterms:title                 "The Powwow Highway : a novel" ;
#         schema:author                 authors:David_Seals ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452263778" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/246305495.ttl"^^xsd:anyURI .
#
# books:Free_Bird  a                         schema:Book ;
#         rdfs:label                    "Free Bird" ;
#         dcterms:creator               authors:Greg_Garrett ;
#         dcterms:title                 "Free Bird" ;
#         schema:author                 authors:Greg_Garrett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0758201397" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/49200765.ttl"^^xsd:anyURI .
#
# books:En_Attendant_Godot  a                schema:Book ;
#         rdfs:label                    "En Attendant Godot" ;
#         dcterms:creator               authors:Samuel_Beckett ;
#         dcterms:title                 "En Attendant Godot" ;
#         schema:author                 authors:Samuel_Beckett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "2707301485" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/248338524.ttl"^^xsd:anyURI .
#
# books:Ceremonial_Time  a                   schema:Book ;
#         rdfs:label                    "Ceremonial Time" ;
#         dcterms:creator               authors:John_Hanson_Mitchell ;
#         dcterms:title                 "Ceremonial time : fifteen thousand years on one square mile" ;
#         schema:author                 authors:John_Hanson_Mitchell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0395591295" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1038158429.ttl"^^xsd:anyURI .
#
# books:New_Zealand  a                       schema:Book ;
#         rdfs:label                    "New Zealand : a travel survival kit" ;
#         dcterms:creator               authors:Tony_Wheeler ;
#         dcterms:title                 "New Zealand : a travel survival kit" ;
#         schema:author                 authors:Tony_Wheeler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0864422040" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/473419745.ttl"^^xsd:anyURI .
#
# books:Clementine_in_the_Kitchen
#         a                             schema:Book ;
#         rdfs:label                    "Clémentine in the Kitchen" ;
#         dcterms:creator               authors:Samuel_Chamberlain ;
#         dcterms:title                 "Clémentine in the Kitchen" ;
#         schema:author                 authors:Samuel_Chamberlain ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0375756647" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1201985761.ttl"^^xsd:anyURI .
#
# books:Rogets_Thesaurus  a                  schema:Book ;
#         rdfs:label                    "Roget's thesaurus of synonyms and antonyms" ;
#         dcterms:creator               authors:Peter_Roget ;
#         dcterms:title                 "Roget's thesaurus of synonyms and antonyms" ;
#         schema:author                 authors:Peter_Roget ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0938261088" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1200941933.ttl"^^xsd:anyURI .
#
# books:Chiefs  a                            schema:Book ;
#         rdfs:label                    "Chiefs" ;
#         dcterms:creator               authors:Stuart_Woods ;
#         dcterms:title                 "Chiefs" ;
#         schema:author                 authors:Stuart_Woods ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780451215802" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/6943084.ttl"^^xsd:anyURI .
#
# books:Living_at_the_End_of_Time
#         a                             schema:Book ;
#         rdfs:label                    "Living at the End of Time" ;
#         dcterms:creator               authors:John_Hanson_Mitchell ;
#         dcterms:title                 "Living at the End of Time" ;
#         schema:author                 authors:John_Hanson_Mitchell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0395445949" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20723110.ttl"^^xsd:anyURI .
#
# books:Blues_Fakebook  a                    schema:Book ;
#         rdfs:label                    "The Blues Fakebook" ;
#         dcterms:creator               authors:Woody_Mann ;
#         dcterms:title                 "The Blues Fakebook" ;
#         schema:author                 authors:Woody_Mann ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0825614171" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40979987.ttl"^^xsd:anyURI .
#
# books:Essential_Calvin_and_Hobbes
#         a                             schema:Book ;
#         rdfs:label                    "The Essential Calvin and Hobbes" ;
#         dcterms:creator               authors:Bill_Watterson ;
#         dcterms:title                 "The Essential Calvin and Hobbes" ;
#         schema:author                 authors:Bill_Watterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0836218051" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/441440805.ttl"^^xsd:anyURI .
#
# books:The_History_of_Danish_Dreams
#         a                             schema:Book ;
#         rdfs:label                    "The History of Danish Dreams" ;
#         dcterms:creator               authors:Peter_Hoeg ;
#         dcterms:title                 "The History of Danish Dreams" ;
#         schema:author                 authors:Peter_Hoeg ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374171386" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32544765.ttl"^^xsd:anyURI .
#
# books:Coastliners  a                       schema:Book ;
#         rdfs:label                    "Coastliners" ;
#         dcterms:creator               authors:Joanna_Rose ;
#         dcterms:title                 "Coastliners : a novel" ;
#         schema:author                 authors:Joanna_Rose ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060958014" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/937808905.ttl"^^xsd:anyURI .
#
# books:Sophies_World  a                     schema:Book ;
#         rdfs:label                    "Sophie's World" ;
#         dcterms:creator               authors:Jostein_Gaarder ;
#         dcterms:title                 "Sophie's world : a novel about the history of philosophy" ;
#         schema:author                 authors:Jostein_Gaarder ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780374530716" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/30474946.ttl"^^xsd:anyURI .
#
# books:Botany  a                            schema:Book ;
#         rdfs:label                    "Botany" ;
#         dcterms:creator               authors:Jean_Zallinger ;
#         dcterms:title                 "Botany" ;
#         schema:author                 authors:Jean_Zallinger ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1030409675.ttl"^^xsd:anyURI .
#
# books:Vegetarian_Epicure_I
#         a                             schema:Book ;
#         rdfs:label                    "The Vegetarian Epicure" ;
#         dcterms:creator               authors:Anna_Thomas ;
#         dcterms:title                 "The Vegetarian Epicure" ;
#         schema:author                 authors:Anna_Thomas ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394717848" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/936798168.ttl"^^xsd:anyURI .
#
# books:Horn_of_the_Moon_Cookbook
#         a                           schema:Book ;
#         rdfs:label                  "Horn of the Moon Cookbook" ;
#         dcterms:creator             authors:Ginny_Callan ;
#         dcterms:title               "Horn of the Moon Cookbook" ;
#         schema:author               authors:Ginny_Callan ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/14933446.ttl"^^xsd:anyURI .
#
# books:Regarding_Wave  a                    schema:Book ;
#         rdfs:label                    "Regarding Wave" ;
#         dcterms:creator               authors:Gary_Snyder ;
#         dcterms:title                 "Regarding Wave" ;
#         schema:author                 authors:Gary_Snyder ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/10220833.ttl"^^xsd:anyURI .
#
# books:Nine_Stories  a                      schema:Book ;
#         rdfs:label                    "Nine Stories" ;
#         dcterms:creator               authors:JD_Salinger ;
#         dcterms:title                 "Nine Stories" ;
#         schema:author                 authors:JD_Salinger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553263609" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/232747.ttl"^^xsd:anyURI .
#
# books:A_history_of_philosophy
#         a                             schema:Book ;
#         rdfs:label                    "A History of Philosophy, Volumes 1-3" ;
#         dcterms:creator               authors:Frederick_Copleston ;
#         dcterms:title                 "A History of Philosophy" ;
#         schema:author                 authors:Frederick_Copleston ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385230311" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/441941907.ttl"^^xsd:anyURI .
#
# books:Practical_Magic  a                   schema:Book ;
#         rdfs:label                    "Practical Magic" ;
#         dcterms:creator               authors:Alice_Hoffman ;
#         dcterms:title                 "Practical Magic" ;
#         schema:author                 authors:Alice_Hoffman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0425152499" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31814750.ttl"^^xsd:anyURI .
#
# books:The_Outsiders  a                     schema:Book ;
#         rdfs:label                    "The Outsiders" ;
#         dcterms:creator               authors:SE_Hinton ;
#         dcterms:title                 "The Outsiders" ;
#         schema:author                 authors:SE_Hinton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0425185710" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1119554769.ttl"^^xsd:anyURI .
#
# books:Instant_Guide_Keyboards
#         a                             schema:Book ;
#         rdfs:label                    "Instant Scale and Chord Guide for Keyboards" ;
#         dcterms:creator               authors:Gary_Meisner ;
#         dcterms:title                 "Instant Scale and Chord Guide for Keyboards" ;
#         schema:author                 authors:Gary_Meisner ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0793500087" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/25007572.ttl"^^xsd:anyURI .
#
# books:The_Flanders_Panel  a                schema:Book ;
#         rdfs:label                    "The Flanders Panel" ;
#         dcterms:creator               authors:Arturo_Perez_Reverte ;
#         dcterms:title                 "The Flanders Panel" ;
#         schema:author                 authors:Arturo_Perez_Reverte ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553377868" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33407942.ttl"^^xsd:anyURI .
#
# books:Anna_Karenina_Book_2
#         a                             schema:Book ;
#         rdfs:label                    "Anna Karenina. Book 2" ;
#         dcterms:creator               authors:Leo_Tolstoy ;
#         dcterms:title                 "Anna Karenina. Book 2" ;
#         schema:author                 authors:Leo_Tolstoy ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/934765377.ttl"^^xsd:anyURI .
#
# books:The_Color_of_Water  a                schema:Book ;
#         rdfs:label                    "The Color of Water" ;
#         dcterms:creator               authors:James_McBride ;
#         dcterms:title                 "The Color of Water" ;
#         schema:author                 authors:James_McBride ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1573225789" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33044768.ttl"^^xsd:anyURI .
#
# books:Music_Lust  a                        schema:Book ;
#         rdfs:label                    "Music Lust" ;
#         dcterms:creator               authors:Nic_Harcourt ;
#         dcterms:title                 "Music lust : recommended listening for every mood, moment, and reason" ;
#         schema:author                 authors:Nic_Harcourt ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1570614377" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/57675951.ttl"^^xsd:anyURI .
#
# books:The_beast_God_forgot_to_invent
#         a                             schema:Book ;
#         rdfs:label                    "The Beast God Forgot to Invent" ;
#         dcterms:creator               authors:Jim_Harrison ;
#         dcterms:title                 "The Beast God Forgot to Invent" ;
#         schema:author                 authors:Jim_Harrison ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802138365" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43811141.ttl"^^xsd:anyURI .
#
# books:What_bred_in_the_bone
#         a                             schema:Book ;
#         rdfs:label                    "What's Bred in the Bone" ;
#         dcterms:creator               authors:Robertson_Davies ;
#         dcterms:title                 "What's bred in the bone" ;
#         schema:author                 authors:Robertson_Davies ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140097112" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1170510544.ttl"^^xsd:anyURI .
#
# books:Touring_the_Islands  a               schema:Book ;
#         rdfs:label                    "Touring the Islands" ;
#         dcterms:creator               authors:Peter_Powers ;
#         dcterms:title                 "Touring the Islands : bicycling in the San Juan, Gulf, and Vancouver Islands" ;
#         schema:author                 authors:Peter_Powers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0944376010" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/33635467.ttl"^^xsd:anyURI .
#
# books:The_God_of_Small_Things_2
#         a                             schema:Book ;
#         rdfs:label                    "The God of Small Things" ;
#         dcterms:creator               authors:Arundhati_Roy ;
#         dcterms:title                 "The God of Small Things" ;
#         schema:author                 authors:Arundhati_Roy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060977493" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/993998622.ttl"^^xsd:anyURI .
#
# books:The_Intruders  a                     schema:Book ;
#         rdfs:label                    "The Intruders" ;
#         dcterms:creator               authors:Stephen_Coonts ;
#         dcterms:title                 "The Intruders" ;
#         schema:author                 authors:Stephen_Coonts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671870602" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/779355780.ttl"^^xsd:anyURI .
#
# books:Nine_Headed_Dragon_River
#         a                             schema:Book ;
#         rdfs:label                    "Nine Headed Dragon River" ;
#         dcterms:creator               authors:Peter_Matthiessen ;
#         dcterms:title                 "Nine Headed Dragon River" ;
#         schema:author                 authors:Peter_Matthiessen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877733252" ;
#         bibliographica:binNumber      19 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/24300237.ttl"^^xsd:anyURI .
#
# books:Walden  a                            schema:Book ;
#         rdfs:label                    "Walden" ;
#         dcterms:creator               authors:Henry_David_Thoreau ;
#         dcterms:title                 "Walden" ;
#         schema:author                 authors:Henry_David_Thoreau ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0879050934" ;
#         bibliographica:binNumber      3 , 9 ;
#         bibliographica:numberOfitems  2 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/966556.ttl"^^xsd:anyURI .
#
# books:Scavengers_Guide_to_Haute_Cuisine
#         a                             schema:Book ;
#         rdfs:label                    "The Scavenger's Guide to Haute Cuisine" ;
#         dcterms:creator               authors:Steven_Rinella ;
#         dcterms:title                 "The Scavenger's Guide to Haute Cuisine" ;
#         schema:author                 authors:Steven_Rinella ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1401352375" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/62741534.ttl"^^xsd:anyURI .
#
# books:Cheese_Book  a                       schema:Book ;
#         rdfs:label                    "The Cheese Book" ;
#         dcterms:creator               authors:Patricia_Haskell , authors:Vivienne_Marquis ;
#         dcterms:title                 "The Cheese Book" ;
#         schema:author                 authors:Patricia_Haskell , authors:Vivienne_Marquis ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671203061" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/708295306.ttl"^^xsd:anyURI .
#
# books:Laurels_Kitchen  a                   schema:Book ;
#         rdfs:label                    "Laurel's Kitchen" ;
#         dcterms:creator               authors:Laurel_Robertson ;
#         dcterms:title                 "Laurel's kitchen : a handbook for vegetarian cookery & nutrition" ;
#         schema:author                 authors:Laurel_Robertson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394724348" ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1005489996.ttl"^^xsd:anyURI .
#
# books:Stone_Cowboy  a                      schema:Book ;
#         rdfs:label                    "Stone Cowboy" ;
#         dcterms:creator               authors:Mark_Jacobs ;
#         dcterms:title                 "Stone Cowboy : a novel" ;
#         schema:author                 authors:Mark_Jacobs ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1569470987" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/36857237.ttl"^^xsd:anyURI .
#
# books:The_Sheriff_of_Nottingham
#         a                             schema:Book ;
#         rdfs:label                    "The Sheriff of Nottingham" ;
#         dcterms:creator               authors:Richard_Kluger ;
#         dcterms:title                 "The Sheriff of Nottingham" ;
#         schema:author                 authors:Richard_Kluger ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140177035" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23462954.ttl"^^xsd:anyURI .
#
# books:Test_Recipes  a                      schema:Book ;
#         rdfs:label                    "Test Recipes with Blue Ribbon Malt Extract" ;
#         dcterms:creator               authors:Blue_Ribbon ;
#         dcterms:title                 "Test Recipes with Blue Ribbon Malt Extract" ;
#         schema:author                 authors:Blue_Ribbon ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 .
#
# books:Relix_16_6  a                        schema:Book ;
#         rdfs:label                    "Relix Vol. 16 No. 6" ;
#         dcterms:creator               authors:Relix_Magazine ;
#         dcterms:title                 "Relix Vol. 16 No. 6" ;
#         schema:author                 authors:Relix_Magazine ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Monoosook_Valley  a                  schema:Book ;
#         rdfs:label                    "Monoosook Valley" ;
#         dcterms:creator               authors:Elisabeth_Hyde ;
#         dcterms:title                 "Monoosook Valley" ;
#         schema:author                 authors:Elisabeth_Hyde ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0385296851" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/18559112.ttl"^^xsd:anyURI .
#
# books:The_book_of_illusions
#         a                             schema:Book ;
#         rdfs:label                    "The book of illusions : a novel" ;
#         dcterms:creator               authors:Paul_Auster ;
#         dcterms:title                 "The book of illusions : a novel" ;
#         schema:author                 authors:Paul_Auster ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312421818" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/48892900.ttl"^^xsd:anyURI .
#
# books:Handbook_Home_Brewing
#         a                             schema:Book ;
#         rdfs:label                    "Hammerhead Ranch Motel" ;
#         dcterms:creator               authors:Dave_Miller ;
#         dcterms:title                 "The complete handbook of home brewing : equipment, ingredients, methods, 55 recipes" ;
#         schema:author                 authors:Dave_Miller ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0882665170" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/313784922.ttl"^^xsd:anyURI .
#
# books:Eaters_of_the_Dead  a                schema:Book ;
#         rdfs:label                    "Eaters of the Dead" ;
#         dcterms:creator               authors:Michael_Crichton ;
#         dcterms:title                 "Eaters of the Dead" ;
#         schema:author                 authors:Michael_Crichton ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345354613" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43676123.ttl"^^xsd:anyURI .
#
# books:Cannery_Row  a                       schema:Book ;
#         rdfs:label                    "Cannery Row" ;
#         dcterms:creator               authors:John_Steinbeck ;
#         dcterms:title                 "Cannery Row" ;
#         schema:author                 authors:John_Steinbeck ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553278231" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020198845.ttl"^^xsd:anyURI .
#
# books:Forgetting_Room  a                   schema:Book ;
#         rdfs:label                    "The Forgetting Room" ;
#         dcterms:creator               authors:Nick_Bantock ;
#         dcterms:title                 "The Forgetting Room" ;
#         schema:author                 authors:Nick_Bantock ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0002251760" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/60183520.ttl"^^xsd:anyURI .
#
# books:Crime_and_Punishment
#         a                             schema:Book ;
#         rdfs:label                    "Crime and Punishment" ;
#         dcterms:creator               authors:Fyodor_Dostoevsky ;
#         dcterms:title                 "Crime and Punishment" ;
#         schema:author                 authors:Fyodor_Dostoevsky ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0330258532" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/16433163.ttl"^^xsd:anyURI .
#
# books:Tuscan_Master  a                     schema:Book ;
#         rdfs:label                    "The Tuscan Master" ;
#         dcterms:creator               authors:Peter_Adamson ;
#         dcterms:title                 "The Tuscan Master" ;
#         schema:author                 authors:Peter_Adamson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0340695676" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/59511380.ttl"^^xsd:anyURI .
#
# books:Yoga_for_Athletes  a                 schema:Book ;
#         rdfs:label                    "Yoga for Athletes" ;
#         dcterms:creator               authors:Argie_Ligeros ;
#         dcterms:title                 "The Yoga for Athletes Fitness System" ;
#         schema:author                 authors:Argie_Ligeros ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0967685605" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/48165737.ttl"^^xsd:anyURI .
#
# books:Murder_on_Naked_Beach
#         a                             schema:Book ;
#         rdfs:label                    "Murder on Naked Beach" ;
#         dcterms:creator               authors:JJ_Henderson ;
#         dcterms:title                 "Murder on Naked Beach" ;
#         schema:author                 authors:JJ_Henderson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1593152876" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020195461.ttl"^^xsd:anyURI .
#
# books:Idiot  a                             schema:Book ;
#         rdfs:label                    "The Idiot" ;
#         dcterms:creator               authors:Fyodor_Dostoevsky ;
#         dcterms:title                 "The Idiot" ;
#         schema:author                 authors:Fyodor_Dostoevsky ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140440542" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/237117158.ttl"^^xsd:anyURI .
#
# books:Home_Landscape_Guide
#         a                             schema:Book ;
#         rdfs:label                    "Home Depot : plant guide for home landscaping" ;
#         dcterms:creator               authors:Home_Depot ;
#         dcterms:title                 "Home Depot : plant guide for home landscaping" ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      14 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/843766604.ttl"^^xsd:anyURI .
#
# books:The_Tidewater_tales  a             schema:Book ;
#         rdfs:label                  "The Tidewater tales : a novel" ;
#         dcterms:creator             authors:John_Barth ;
#         dcterms:title               "The Tidewater tales : a novel" ;
#         schema:author               authors:John_Barth ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/14691557.ttl"^^xsd:anyURI .
#
# books:Fundamentals_Rockclimbing
#         a                             schema:Book ;
#         rdfs:label                    "Fundamentals of Rock Climbing" ;
#         dcterms:creator               authors:MIT_Outing_Club ;
#         dcterms:title                 "Fundamentals of Rock Climbing" ;
#         schema:author                 authors:MIT_Outing_Club ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/4862070.ttl"^^xsd:anyURI .
#
# books:Planet_Drum  a                       schema:Book ;
#         rdfs:label                    "Planet Drum" ;
#         dcterms:creator               authors:Mickey_Hart ;
#         dcterms:title                 "Planet Drum" ;
#         schema:author                 authors:Mickey_Hart ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0062503979" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/27641725.ttl"^^xsd:anyURI .
#
# books:Multimedia_Learning  a               schema:Book ;
#         rdfs:label                    "Cambridge Handbook of Multimedia Learning" ;
#         dcterms:creator               authors:Richard_Mayer ;
#         dcterms:title                 "Cambridge Handbook of Multimedia Learning" ;
#         schema:author                 authors:Richard_Mayer ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0521547512" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/123232811.ttl"^^xsd:anyURI .
#
# books:Animalia  a                          schema:Book ;
#         rdfs:label                    "Animalia" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "Animalia" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670079138" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  2 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1016502154.ttl"^^xsd:anyURI .
#
# books:RocknRoll_Comics_GD  a               schema:Book ;
#         rdfs:label                    "Rock n Roll Comics Grateful Dead Issue 46" ;
#         dcterms:creator               authors:Heather_Cheney ;
#         dcterms:title                 "Rock n Roll Comics Grateful Dead Issue 46" ;
#         schema:author                 authors:Heather_Cheney ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:The_book_on_taboo  a                 schema:Book ;
#         rdfs:label                    "The book; on the taboo against knowing who you are" ;
#         dcterms:creator               authors:Alan_Watts ;
#         dcterms:title                 "The book; on the taboo against knowing who you are" ;
#         schema:author                 authors:Alan_Watts ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0394718534" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/546416.ttl"^^xsd:anyURI .
#
# books:Gig_Bag_Arpeggios  a                 schema:Book ;
#         rdfs:label                    "Gig Bag Book of Arpeggios" ;
#         dcterms:creator               authors:Mark_Bridges ;
#         dcterms:title                 "The Gig Bag Book of Arpeggios for All Guitarists" ;
#         schema:author                 authors:Mark_Bridges ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "082561659X" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/908128393.ttl"^^xsd:anyURI .
#
# books:Way_Peaceful_Warrior
#         a                             schema:Book ;
#         rdfs:label                    "Way of the Peaceful Warrior" ;
#         dcterms:creator               authors:Dan_Millman ;
#         dcterms:title                 "Way of the Peaceful Warrior" ;
#         schema:author                 authors:Dan_Millman ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/611657875.ttl"^^xsd:anyURI .
#
# books:Demian  a                            schema:Book ;
#         rdfs:label                    "Demian" ;
#         dcterms:creator               authors:Hermann_Hesse ;
#         dcterms:title                 "Demian" ;
#         schema:author                 authors:Hermann_Hesse ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/987251577.ttl"^^xsd:anyURI .
#
# books:Zen_Master_Hakuin  a                 schema:Book ;
#         rdfs:label                    "The Essential Teachings of Zen Master Hakuin" ;
#         dcterms:creator               authors:Norman_Waddell ;
#         dcterms:title                 "The Essential Teachings of Zen Master Hakuin" ;
#         schema:author                 authors:Norman_Waddell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0877739722" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020229138.ttl"^^xsd:anyURI .
#
# books:Tipping_Point  a                     schema:Book ;
#         rdfs:label                    "The Tipping Point" ;
#         dcterms:creator               authors:Malcolm_Gladwell ;
#         dcterms:title                 "The Tipping Point: how little things can make a big difference" ;
#         schema:author                 authors:Malcolm_Gladwell ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0316316962" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1010950132.ttl"^^xsd:anyURI .
#
# books:Watership_Down  a                    schema:Book ;
#         rdfs:label                    "Watership Down" ;
#         dcterms:creator               authors:Richard_Adams ;
#         dcterms:title                 "Watership Down" ;
#         schema:author                 authors:Richard_Adams ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380002930" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/730688.ttl"^^xsd:anyURI .
#
# books:Harry_Potter_Order_of_the_Phoenix
#         a                             schema:Book ;
#         rdfs:label                    "Harry Potter and the Order of the Phoenix" ;
#         dcterms:creator               authors:JK_Rowling ;
#         dcterms:title                 "Harry Potter and the Order of the Phoenix" ;
#         schema:author                 authors:JK_Rowling ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0439358078" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/51532204.ttl"^^xsd:anyURI .
#
# books:Breath_Eyes_Memory  a                schema:Book ;
#         rdfs:label                    "Breath, Eyes, Memory" ;
#         dcterms:creator               authors:Edwidge_Danticat ;
#         dcterms:title                 "Breath, Eyes, Memory" ;
#         schema:author                 authors:Edwidge_Danticat ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679756612" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1020220168.ttl"^^xsd:anyURI .
#
# books:Tristessa  a                         schema:Book ;
#         rdfs:label                    "Tristessa" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "Tristessa" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0070342059" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/3950940.ttl"^^xsd:anyURI .
#
# books:The_Irish_RM  a                      schema:Book ;
#         rdfs:label                    "The Irish R.M." ;
#         dcterms:creator               authors:Somerville_E ;
#         dcterms:title                 "The Irish R.M." ;
#         schema:author                 authors:Somerville_E ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140071768" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1087852076.ttl"^^xsd:anyURI .
#
# books:A_House_in_Earnest_2
#         a                             schema:Book ;
#         rdfs:label                    "A House in Earnest : a novel" ;
#         dcterms:creator               authors:Terry_Farish ;
#         dcterms:title                 "A House in Earnest : a novel" ;
#         schema:author                 authors:Terry_Farish ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1883642523" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43114269.ttl"^^xsd:anyURI .
#
# books:The_lost_diaries_of_Frans_Hals
#         a                             schema:Book ;
#         rdfs:label                    "The Lost Diaries of Frans Hals" ;
#         dcterms:creator               authors:Michael_Kernan ;
#         dcterms:title                 "The Lost Diaries of Frans Hals : a novel" ;
#         schema:author                 authors:Michael_Kernan ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0312131178" ;
#         bibliographica:binNumber      15 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/31936299.ttl"^^xsd:anyURI .
#
# books:Island  a                            schema:Book ;
#         rdfs:label                    "Island" ;
#         dcterms:creator               authors:Aldous_Huxley ;
#         dcterms:title                 "Island" ;
#         schema:author                 authors:Aldous_Huxley ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/251621899.ttl"^^xsd:anyURI .
#
# books:Tara_Road  a                         schema:Book ;
#         rdfs:label                    "Tara Road" ;
#         dcterms:creator               authors:Maeve_Binchy ;
#         dcterms:title                 "Tara Road" ;
#         schema:author                 authors:Maeve_Binchy ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440235596" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1005289444.ttl"^^xsd:anyURI .
#
# books:Organic_Inc  a                       schema:Book ;
#         rdfs:label                    "Organic, Inc." ;
#         dcterms:creator               authors:Samuel_Fromartz ;
#         dcterms:title                 "Organic, inc. : natural foods and how they grew" ;
#         schema:author                 authors:Samuel_Fromartz ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780156032421" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/607090487.ttl"^^xsd:anyURI .
#
# books:Hoot   a                             schema:Book ;
#         rdfs:label                    "Hoot" ;
#         dcterms:creator               authors:Carl_Hiaasen ;
#         dcterms:title                 "Hoot" ;
#         schema:author                 authors:Carl_Hiaasen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0440421705" ;
#         bibliographica:binNumber      8 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/634950494.ttl"^^xsd:anyURI .
#
# books:Skeleton_Coast  a                  schema:Book ;
#         rdfs:label                  "Skeleton Coast" ;
#         dcterms:creator             authors:Clive_Cussler ;
#         dcterms:title               "Skeleton Coast" ;
#         schema:author               authors:Clive_Cussler ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/70167720.ttl"^^xsd:anyURI .
#
# books:Study_of_ethnomusicology
#         a                             schema:Book ;
#         rdfs:label                    "The Study of Ethnomusicology" ;
#         dcterms:creator               authors:Bruno_Nettl ;
#         dcterms:title                 "The study of ethnomusicology : thirty-one issues and concepts" ;
#         schema:author                 authors:Bruno_Nettl ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780252072789" ;
#         bibliographica:binNumber      17 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/694967185.ttl"^^xsd:anyURI .
#
# books:Different_Dances  a                  schema:Book ;
#         rdfs:label                    "Different Dances" ;
#         dcterms:creator               authors:Shel_Silverstein ;
#         dcterms:title                 "Different Dances" ;
#         schema:author                 authors:Shel_Silverstein ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780060256593" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/473279925.ttl"^^xsd:anyURI .
#
# books:Connections_Tech_Training
#         a                             schema:Book ;
#         rdfs:label                    "Connections Technology Training" ;
#         dcterms:creator               authors:Oasis_Project ;
#         dcterms:title                 "Connections Technology Training" ;
#         schema:author                 authors:Oasis_Project ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 .
#
# books:Nanny_and_the_iceberg
#         a                             schema:Book ;
#         rdfs:label                    "The Nanny and the Iceberg" ;
#         dcterms:creator               authors:Ariel_Dorfman ;
#         dcterms:title                 "The Nanny and the Iceberg" ;
#         schema:author                 authors:Ariel_Dorfman ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0374218986" ;
#         bibliographica:binNumber      6 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1105180217.ttl"^^xsd:anyURI .
#
# books:Contemporary_Distance_Educ
#         a                             schema:Book ;
#         rdfs:label                    "Contemporary Issues in American Distance Education" ;
#         dcterms:creator               authors:Michael_G_Moore ;
#         dcterms:title                 "Contemporary Issues in American Distance Education" ;
#         schema:author                 authors:Michael_G_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "008040233X" ;
#         bibliographica:binNumber      13 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/260145553.ttl"^^xsd:anyURI .
#
# books:The_Race  a                          schema:Book ;
#         rdfs:label                    "The Race" ;
#         dcterms:creator               authors:Clive_Cussler ;
#         dcterms:title                 "The Race" ;
#         schema:author                 authors:Clive_Cussler ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780425250440" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/706017163.ttl"^^xsd:anyURI .
#
# books:Art_Culinaire  a                     schema:Book ;
#         rdfs:label                    "Art Culinaire, 62" ;
#         dcterms:title                 "Art Culinaire, 62" ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/434473571.ttl"^^xsd:anyURI .
#
# books:Death_of_Ivan_Lynch  a               schema:Book ;
#         rdfs:label                    "The Death of Ivan Lynch" ;
#         dcterms:creator               authors:Leo_Tolstoy ;
#         dcterms:title                 "The Death of Ivan Lynch and Other Stories" ;
#         schema:author                 authors:Leo_Tolstoy ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 .
#
# books:Fierce_Invalids  a                   schema:Book ;
#         rdfs:label                    "Fierce Invalids Home from Hot Climates" ;
#         dcterms:creator               authors:Tom_Robbins ;
#         dcterms:title                 "Fierce Invalids Home from Hot Climates" ;
#         schema:author                 authors:Tom_Robbins ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "055337933X" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1157176163.ttl"^^xsd:anyURI .
#
# books:Practical_Demonkeeping
#         a                             schema:Book ;
#         rdfs:label                    "Practical Demonkeeping" ;
#         dcterms:creator               authors:Christopher_Moore ;
#         dcterms:title                 "Practical Demonkeeping" ;
#         schema:author                 authors:Christopher_Moore ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0380730375" ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/40865053.ttl"^^xsd:anyURI .
#
# books:Grateful_Dead_Comix_2
#         a                             schema:Book ;
#         rdfs:label                    "Grateful Dead Comix No. 2" ;
#         dcterms:creator               authors:Grateful_Dead ;
#         dcterms:title                 "Grateful Dead Comix No. 2" ;
#         schema:author                 authors:Grateful_Dead ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  2 .
#
# books:Music_Physics_Enginnering
#         a                             schema:Book ;
#         rdfs:label                    "Music, Physics, and Engineering" ;
#         dcterms:creator               authors:Harry_Olson ;
#         dcterms:title                 "Music, Physics, and Engineering" ;
#         schema:author                 authors:Harry_Olson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0486217698" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1135442367.ttl"^^xsd:anyURI .
#
# books:Great_Shark_Hunt  a                  schema:Book ;
#         rdfs:label                    "The Great shark hunt : Strange tales from a strange time" ;
#         dcterms:creator               authors:Hunter_S_Thompson ;
#         dcterms:title                 "The Great shark hunt : Strange tales from a strange time" ;
#         schema:author                 authors:Hunter_S_Thompson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0445045965" ;
#         bibliographica:binNumber      9 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/492412781.ttl"^^xsd:anyURI .
#
# books:World_of_the_East  a               schema:Book ;
#         rdfs:label                  "World-of-the-East Vegetarian Cooking" ;
#         dcterms:creator             authors:Madhur_Jaffrey ;
#         dcterms:title               "World-of-the-East Vegetarian Cooking" ;
#         schema:author               authors:Madhur_Jaffrey ;
#         schema:bookFormat           schema:Paperback ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/7575597.ttl"^^xsd:anyURI .
#
# books:The_8th_Confession  a                schema:Book ;
#         rdfs:label                    "The 8th Confession" ;
#         dcterms:creator               authors:James_Patterson ;
#         dcterms:title                 "The 8th Confession" ;
#         schema:author                 authors:James_Patterson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1607518988" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/233798821.ttl"^^xsd:anyURI .
#
# books:Under_African_Skies  a               schema:Book ;
#         rdfs:label                    "Under African Skies : modern African stories" ;
#         dcterms:creator               authors:Charles_Larson ;
#         dcterms:title                 "Under African Skies : modern African stories" ;
#         schema:author                 authors:Charles_Larson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1841955957" ;
#         bibliographica:binNumber      10 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/474911200.ttl"^^xsd:anyURI .
#
# books:The_Forms_of_Water  a                schema:Book ;
#         rdfs:label                    "The Forms of Water" ;
#         dcterms:creator               authors:Andrea_Barrett ;
#         dcterms:title                 "The Forms of Water" ;
#         schema:author                 authors:Andrea_Barrett ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0671795228" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/27068491.ttl"^^xsd:anyURI .
#
# books:Rolling_Stone_1000th
#         a                             schema:Book ;
#         rdfs:label                    "Rolling Stone: 1000th Issue" ;
#         dcterms:creator               authors:Rolling_Stone ;
#         dcterms:title                 "Rolling Stone: 1000th Issue" ;
#         schema:author                 authors:Rolling_Stone ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1082456926.ttl"^^xsd:anyURI .
#
# books:Relix_16_1  a                        schema:Book ;
#         rdfs:label                    "Relix Vol. 16 No. 1" ;
#         dcterms:creator               authors:Relix_Magazine ;
#         dcterms:title                 "Relix Vol. 16 No. 1" ;
#         schema:author                 authors:Relix_Magazine ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 .
#
# books:Video_Demystified  a                 schema:Book ;
#         rdfs:label                    "Video demystified : a handbook for the digital engineer" ;
#         dcterms:creator               authors:Keith_Jack ;
#         dcterms:title                 "Video demystified : a handbook for the digital engineer" ;
#         schema:author                 authors:Keith_Jack ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1878707361" ;
#         bibliographica:binNumber      2 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/23383660.ttl"^^xsd:anyURI .
#
# books:Sign_of_Seahorse  a                  schema:Book ;
#         rdfs:label                    "The Sign of the Seahorse" ;
#         dcterms:creator               authors:Graeme_Base ;
#         dcterms:title                 "The Sign of the Seahorse" ;
#         schema:author                 authors:Graeme_Base ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0670840009" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/988933146.ttl"^^xsd:anyURI .
#
# books:What_Is_What  a                      schema:Book ;
#         rdfs:label                    "What Is the What" ;
#         dcterms:creator               authors:Dave_Eggers ;
#         dcterms:title                 "What Is the What" ;
#         schema:author                 authors:Dave_Eggers ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "9780307385901" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1141749822.ttl"^^xsd:anyURI .
#
# books:Desolation_Angels  a                 schema:Book ;
#         rdfs:label                    "The Island Within" ;
#         dcterms:creator               authors:Jack_Kerouac ;
#         dcterms:title                 "The Island Within" ;
#         schema:author                 authors:Jack_Kerouac ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/476109877.ttl"^^xsd:anyURI .
#
# books:Tripmaster_Monkey  a                 schema:Book ;
#         rdfs:label                    "Tripmaster Monkey" ;
#         dcterms:creator               authors:Maxine_Hong_Kingston ;
#         dcterms:title                 "Tripmaster Monkey" ;
#         schema:author                 authors:Maxine_Hong_Kingston ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0679727892" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/18521694.ttl"^^xsd:anyURI .
#
# books:Living_Zen  a                        schema:Book ;
#         rdfs:label                    "Living Zen" ;
#         dcterms:creator               authors:Robert_Linssen ;
#         dcterms:title                 "Living Zen" ;
#         schema:author                 authors:Robert_Linssen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0802131360" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/21261631.ttl"^^xsd:anyURI .
#
# books:The_Bourne_Supremacy
#         a                             schema:Book ;
#         rdfs:label                    "The Bourne Supremacy" ;
#         dcterms:creator               authors:Robert_Ludlum ;
#         dcterms:title                 "The Bourne Supremacy" ;
#         schema:author                 authors:Robert_Ludlum ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0553263226" ;
#         bibliographica:binNumber      7 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/12371273.ttl"^^xsd:anyURI .
#
# books:Portable_Graham_Greene
#         a                             schema:Book ;
#         rdfs:label                    "The Portable Graham Greene" ;
#         dcterms:creator               authors:P_Statford ;
#         dcterms:title                 "The Portable Graham Greene" ;
#         schema:author                 authors:P_Statford ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0140150757" ;
#         bibliographica:binNumber      5 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/966029603.ttl"^^xsd:anyURI .
#
# books:Whole_Foods_Employee_Guide
#         a                             schema:Book ;
#         rdfs:label                    "Whole Foods Guide for Employees" ;
#         dcterms:creator               authors:Rebecca_Wood ;
#         dcterms:title                 "Whole Foods Guide for Employees of Natural Food Stores" ;
#         schema:author                 authors:Rebecca_Wood ;
#         schema:bookFormat             schema:Paperback ;
#         bibliographica:binNumber      16 ;
#         bibliographica:numberOfitems  1 .
#
# books:A_House_in_Earnest  a                schema:Book ;
#         rdfs:label                    "A House in Earnest : a novel" ;
#         dcterms:creator               authors:Terry_Farish ;
#         dcterms:title                 "A House in Earnest : a novel" ;
#         schema:author                 authors:Terry_Farish ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1883642523" ;
#         bibliographica:binNumber      1 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/43114269.ttl"^^xsd:anyURI .
#
# books:Captain_Sir_Richard_Francis_Burton
#         a                             schema:Book ;
#         rdfs:label                    "Captain Sir Richard Francis Burton. A biography" ;
#         dcterms:creator               authors:Edward_Rice ;
#         dcterms:title                 "Captain Sir Richard Francis Burton. A biography" ;
#         schema:author                 authors:Edward_Rice ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "030681028X" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/20296326.ttl"^^xsd:anyURI .
#
# books:Herb_Book  a                         schema:Book ;
#         rdfs:label                    "The Herb Book" ;
#         dcterms:creator               authors:John_Lust ;
#         dcterms:title                 "The Herb Book" ;
#         schema:author                 authors:John_Lust ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "05531222428" ;
#         bibliographica:binNumber      11 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/717193103.ttl"^^xsd:anyURI .
#
# books:Shadow_Ranch  a                      schema:Book ;
#         rdfs:label                    "Shadow Ranch" ;
#         dcterms:creator               authors:JoAnn_Mapson ;
#         dcterms:title                 "Shadow Ranch : a novel" ;
#         schema:author                 authors:JoAnn_Mapson ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060928433" ;
#         bibliographica:binNumber      18 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/34026629.ttl"^^xsd:anyURI .
#
# books:Continental_Drift  a                 schema:Book ;
#         rdfs:label                    "Continental Drift" ;
#         dcterms:creator               authors:Russell_Banks ;
#         dcterms:title                 "Continental Drift" ;
#         schema:author                 authors:Russell_Banks ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0060153830" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/10998820.ttl"^^xsd:anyURI .
#
# books:Louisiana_Power_Light
#         a                             schema:Book ;
#         rdfs:label                    "Louisiana Power & Light" ;
#         dcterms:creator               authors:John_Dufresne ;
#         dcterms:title                 "Louisiana Power & Light" ;
#         schema:author                 authors:John_Dufresne ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0452275024" ;
#         bibliographica:binNumber      12 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/890376703.ttl"^^xsd:anyURI .
#
# books:Seattle_city_guide  a                schema:Book ;
#         rdfs:label                    "Seattle : city guide" ;
#         dcterms:creator               authors:Becky_Ohlsen ;
#         dcterms:title                 "Seattle : city guide" ;
#         schema:author                 authors:Becky_Ohlsen ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "1741041570" ;
#         bibliographica:binNumber      3 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/1028442575.ttl"^^xsd:anyURI .
#
# books:Diet_for_a_Small_Planet
#         a                             schema:Book ;
#         rdfs:label                    "Diet for a Small Planet" ;
#         dcterms:creator               authors:Frances_Moore_Lappe ;
#         dcterms:title                 "Diet for a Small Planet" ;
#         schema:author                 authors:Frances_Moore_Lappe ;
#         schema:bookFormat             schema:Paperback ;
#         schema:isbn                   "0345295242" ;
#         bibliographica:binNumber      4 ;
#         bibliographica:numberOfitems  1 ;
#         bibliographica:worldcatURI    "http://www.worldcat.org/oclc/32693013.ttl"^^xsd:anyURI .
#
# }

# %% [markdown]
# #### CDs

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# <http://www.connaissance.io/onto/biblio/CDs>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-20" ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#   dcterms:description "CD media collection, cataloged and serialized in RDF. Links items to Musicbrainz." ;
#   owl:imports <http://www.connaissance.io/onto/biblio/MusicGroup> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/SoloMusicArtist> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Developed by M Lane" .
#
#
# CDs:Man_And_A_Half  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Man And A Half: The Best of Wilson Pickett" ;
#         dcterms:creator                SoloMusicArtist:Wilson_Pickett ;
#         bibliographica:byArtist        SoloMusicArtist:Wilson_Pickett ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e0a0372f-e795-443d-a0a4-27c893b61b72"^^xsd:anyURI .
#
# CDs:Barricades_Brickwalls
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Barricades & Brickwalls" ;
#         dcterms:creator                SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:byArtist        SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4d4df1ad-482e-40d8-abee-85bbe425dceb"^^xsd:anyURI .
#
# CDs:Bongo_Fury  a                         mo:Record , mo:CD , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "Bongo Fury" ;
#         dcterms:creator                MusicGroup:Captain_Beefheart_Magic_Band , SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa , MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/abe5e4e8-2daf-36c7-826d-a5ce0dddceba"^^xsd:anyURI .
#
# CDs:Africa  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Africa" ;
#         dcterms:creator                SoloMusicArtist:Miriam_Makeba ;
#         bibliographica:byArtist        SoloMusicArtist:Miriam_Makeba ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/766fa133-c9bc-467c-b965-84ba69b4768c"^^xsd:anyURI .
#
# CDs:Highway_Cafe_Of_The_Damned
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Highway Cafe Of The Damned (1988)" ;
#         dcterms:creator                MusicGroup:Austin_Lounge_Lizards ;
#         bibliographica:byArtist        MusicGroup:Austin_Lounge_Lizards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/e6d56ffd-cd69-316d-8d76-43934fd27a6d"^^xsd:anyURI .
#
# CDs:Wandering_Home  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wandering Home" ;
#         dcterms:creator                SoloMusicArtist:Maura_OConnell ;
#         bibliographica:byArtist        SoloMusicArtist:Maura_OConnell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ce8ec74e-6228-42df-aa35-cb6fba7c352a"^^xsd:anyURI .
#
# CDs:Live_Love_Larf_Loaf  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live, Love, Larf, & Loaf" ;
#         dcterms:creator                MusicGroup:French_Frith_Kaiser_Thompson ;
#         bibliographica:byArtist        MusicGroup:French_Frith_Kaiser_Thompson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b03f8087-f951-4f0b-a0b1-8e1dd41d9427"^^xsd:anyURI .
#
# CDs:Wholly_Earth  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Wholly Earth" ;
#         dcterms:creator          SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:byArtist  SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:musicbrainzSoloMusicArtistURI
#                 "https://musicbrainz.org/release/689dad1c-0789-42d6-8346-b48f115e05fb"^^xsd:anyURI .
#
# CDs:Three_of_a_Perfect_Pair
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Three of a Perfect Pair" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d41e6dba-361f-41e6-bfa9-1c1e5f6c04f6"^^xsd:anyURI .
#
# CDs:Passengers  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Passengers" ;
#         dcterms:creator                MusicGroup:Gary_Burton_Quartet ;
#         bibliographica:byArtist        MusicGroup:Gary_Burton_Quartet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dcf0173c-9751-4300-b77a-8faf3c0ad900"^^xsd:anyURI .
#
# CDs:Both_Sides_Midnight  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Both Sides of Midnight" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/20a42bf8-9029-4a47-9246-4efc703cdc43"^^xsd:anyURI .
#
# CDs:Luxury_Liner  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Luxury Liner" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/640b080f-4e7c-4447-8169-8809bcfe32dc"^^xsd:anyURI .
#
# CDs:Minstrel_In_Gallery  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Minstrel in the Gallery" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99a89431-9b5d-4672-9e34-1d21384d43b3"^^xsd:anyURI .
#
# CDs:Young_Americans  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Young Americans" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ea63a602-1d7f-3c4b-ba68-bc79557000d1"^^xsd:anyURI .
#
# CDs:Talula  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Talula" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ee62f4c1-fe9a-433a-a580-639530c3498f"^^xsd:anyURI .
#
# CDs:Live_Too_Hot_Snakes  a                mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Too Hot For Snakes" ;
#         dcterms:creator                SoloMusicArtist:Mick_Taylor , SoloMusicArtist:Carla_Olson ;
#         bibliographica:byArtist        SoloMusicArtist:Mick_Taylor , SoloMusicArtist:Carla_Olson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2c517f65-97f0-4546-91ac-d47ae9e64714"^^xsd:anyURI .
#
# CDs:Revisited  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Revisited" ;
#         dcterms:creator          SoloMusicArtist:Robbie_Laws ;
#         bibliographica:byArtist  SoloMusicArtist:Robbie_Laws .
#
# CDs:Leo_Kottke_Live  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Leo Kottke Live" ;
#         dcterms:creator                SoloMusicArtist:Leo_Kottke ;
#         bibliographica:byArtist        SoloMusicArtist:Leo_Kottke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/76f61f92-5926-46bd-bce3-12cfb27ef24c"^^xsd:anyURI .
#
# CDs:Horombe  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Horombe" ;
#         dcterms:creator                MusicGroup:DGary_Jihe ;
#         bibliographica:byArtist        MusicGroup:DGary_Jihe ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/47f399c0-9765-47c7-b0d8-f0658b92de39"^^xsd:anyURI .
#
# CDs:Mingus_Live_in_Time  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Time" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b6a9783-d795-465b-8cb3-3392960f051e"^^xsd:anyURI .
#
# CDs:Aqualung  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Aqualung" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b8e3b5bd-497e-4c40-a4ca-c9371da05106"^^xsd:anyURI .
#
# CDs:Chiwoniso  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chiwoniso: Music of Zimbabwe" ;
#         dcterms:creator                SoloMusicArtist:Dumisani_Maraire ;
#         bibliographica:byArtist        SoloMusicArtist:Dumisani_Maraire ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83e2b3be-7334-428e-ae95-caba10f67121"^^xsd:anyURI .
#
# CDs:Bend_Without_Breaking
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Bend Without Breaking" ;
#         dcterms:creator          MusicGroup:Chris_Maggie ;
#         bibliographica:byArtist  MusicGroup:Chris_Maggie .
#
# CDs:You_Cant_Do_That_On_Stage_v6
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 6" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/441adb31-93d3-4e44-88ae-0f53f5fb4acb"^^xsd:anyURI .
#
# CDs:Dancing_in_Trance  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Dancing In The Trance" ;
#         dcterms:creator          MusicGroup:Endangered_Species ;
#         bibliographica:byArtist  MusicGroup:Endangered_Species .
#
# CDs:Friends  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Friends" ;
#         dcterms:creator                SoloMusicArtist:Larry_Carlton ;
#         bibliographica:byArtist        SoloMusicArtist:Larry_Carlton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34d413e6-678b-3c6d-8205-2f82cc4e1e6f"^^xsd:anyURI .
#
# CDs:Running_on_Empty  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Running on Empty" ;
#         dcterms:creator                SoloMusicArtist:Jackson_Browne ;
#         bibliographica:byArtist        SoloMusicArtist:Jackson_Browne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7870f7a8-1e70-3f41-8cdc-664440784786"^^xsd:anyURI .
#
# CDs:Best_of_Isaac_Hayes  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Isaac Hayes, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:Isaac_Hayes ;
#         bibliographica:byArtist        SoloMusicArtist:Isaac_Hayes ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2dbe855c-a7e6-4926-872a-4d4d2a577e7c"^^xsd:anyURI .
#
# CDs:Intrusions  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Intrusions" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fc20b713-3dae-4d08-a94a-a140a095619e"^^xsd:anyURI .
#
# CDs:Simple_Soul  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Simple Soul" ;
#         dcterms:creator                SoloMusicArtist:Eddi_Reader ;
#         bibliographica:byArtist        SoloMusicArtist:Eddi_Reader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/837d172e-153b-4fae-8930-2e8e563fe440"^^xsd:anyURI .
#
# CDs:Where_Im_Standing  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Where I'm Standing" ;
#         dcterms:creator          SoloMusicArtist:Julie_Hoest ;
#         bibliographica:byArtist  SoloMusicArtist:Julie_Hoest .
#
# CDs:First_Time  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The First Time" ;
#         dcterms:creator          SoloMusicArtist:Carri_Coltrane ;
#         bibliographica:byArtist  SoloMusicArtist:Carri_Coltrane .
#
# CDs:Under_the_Table  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Under the Table and Dreaming" ;
#         dcterms:creator                SoloMusicArtist:Dave_Matthews ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Matthews ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c5c9dd54-2170-4377-9d0e-7a61d988ebea"^^xsd:anyURI .
#
# CDs:Universal_Men  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Universal Men" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b1d4d1e7-9295-4391-a53b-1e36ac13c88e"^^xsd:anyURI .
#
# CDs:Taos_Tennesse  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Taos to Tennesse" ;
#         dcterms:creator                SoloMusicArtist:Tish_Hinojosa ;
#         bibliographica:byArtist        SoloMusicArtist:Tish_Hinojosa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/683df416-8fef-4437-8eec-bd17fe344830"^^xsd:anyURI .
#
# CDs:Terrapin_Station  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Terrapin Station" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a0d1bd24-cc27-3a6d-b736-079876499ce3"^^xsd:anyURI .
#
# CDs:Live_Around_World  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live Around the World" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c22b1200-e792-4126-b6a9-5b48ac326ee6"^^xsd:anyURI .
#
# CDs:Skiffle_Sessions  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Skiffle Sessions - Live In Belfast" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9ef2312-990e-3e55-9c1d-331c449e8da3"^^xsd:anyURI .
#
# CDs:Que_Allegria  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Qué alegría" ;
#         dcterms:creator                SoloMusicArtist:John_McLaughlin ;
#         bibliographica:byArtist        SoloMusicArtist:John_McLaughlin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b2d1ffc-c183-4222-aa97-a63d61870f30"^^xsd:anyURI .
#
# CDs:Ndangariro  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ndangariro" ;
#         dcterms:creator                SoloMusicArtist:Thomas_Mapfumo ;
#         bibliographica:byArtist        SoloMusicArtist:Thomas_Mapfumo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/88c93a98-6987-40a5-a4a4-ebb455e5dcab"^^xsd:anyURI .
#
# CDs:In_Soulful_Mood  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In A Soulful Mood" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e199a1ad-03cb-48fe-92ae-6a62a6d84d6f"^^xsd:anyURI .
#
# CDs:Pick_Up_On_This  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pick Up On This!" ;
#         dcterms:creator                MusicGroup:BeauJocque_ZydecoHiRollers ;
#         bibliographica:byArtist        MusicGroup:BeauJocque_ZydecoHiRollers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f3ae3377-8a18-41c9-b745-ff6053bb65e5"^^xsd:anyURI .
#
# CDs:Lion_and_Cobra  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lion And The Cobra" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d023fe20-ad38-313f-b09e-489155b9934e"^^xsd:anyURI .
#
# CDs:Allegria  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Allegria" ;
#         dcterms:creator                MusicGroup:Gipsy_Kings ;
#         bibliographica:byArtist        MusicGroup:Gipsy_Kings ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ba8fcbc-2d64-4298-a122-a355707214f8"^^xsd:anyURI .
#
# CDs:Sao_Vicente  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "São Vicente" ;
#         dcterms:creator                SoloMusicArtist:Cesaria_Evora ;
#         bibliographica:byArtist        SoloMusicArtist:Cesaria_Evora ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/616471c7-0442-47d8-bacb-054bc013d83e"^^xsd:anyURI .
#
# CDs:Oh_My_Girl  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Oh, My Girl" ;
#         dcterms:creator                MusicGroup:Jesse_Sykes_Sweet_Hereafter ;
#         bibliographica:byArtist        MusicGroup:Jesse_Sykes_Sweet_Hereafter ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/006ab8c7-e9f5-4aa3-9ebb-d5c9baaa3107"^^xsd:anyURI .
#
# CDs:Mexican_Moon  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mexican Moon" ;
#         dcterms:creator                MusicGroup:Concrete_Blonde ;
#         bibliographica:byArtist        MusicGroup:Concrete_Blonde ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b38cf694-5447-42a7-a6ad-c434bdc0cbc8"^^xsd:anyURI .
#
# CDs:Lounge_Against_Machine
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lounge Against the Machine" ;
#         dcterms:creator                SoloMusicArtist:Richard_Cheese ;
#         bibliographica:byArtist        SoloMusicArtist:Richard_Cheese ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4fecbf14-179d-41fb-9a39-7eb44a4c4634"^^xsd:anyURI .
#
# CDs:Trout_Mask_Replica  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Trout Mask Replica" ;
#         dcterms:creator                MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:byArtist        MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/e6a580bd-5d29-3acd-a959-0bfab002ee6f"^^xsd:anyURI .
#
# CDs:Revolution_Not_Televised
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Revolution Will Not Be Televised" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5e15d8b8-bd80-3c0b-be2f-b66c68620435"^^xsd:anyURI .
#
# CDs:Jazz_Round_Midnight_CP
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz 'Round Midnight" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ae4ed2e2-08a7-4efa-b819-906f29484669"^^xsd:anyURI .
#
# CDs:Hoy_Hoy  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hoy-Hoy!" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fd7dfb4e-b614-4f2a-b35e-fdb66b54cca6"^^xsd:anyURI .
#
# CDs:Outward_Bound  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Outward Bound" ;
#         dcterms:creator                SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:byArtist        SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/680b39e1-a9a5-437d-8c1c-357a663a3b60"^^xsd:anyURI .
#
# CDs:Freedom_Sessions  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Freedom Sessions" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e641afd0-098c-4153-9860-e29339f42716"^^xsd:anyURI .
#
# CDs:Ziggy_Stardust_Spiders_Mars
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ziggy Stardust and The Spiders From Mars" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3eaa9c40-1b63-4678-ba49-06d9c56c75b2"^^xsd:anyURI .
#
# CDs:Too_Good_to_Be_Forgotten
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Too Good to Be Forgotten" ;
#         dcterms:creator                MusicGroup:Amazulu ;
#         bibliographica:byArtist        MusicGroup:Amazulu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/87921985-431d-307c-9627-e3ecbda9e3a7"^^xsd:anyURI .
#
# CDs:Whats_Inside  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What’s Inside" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/25b54e54-def3-3d8b-a193-f3cafc566a03"^^xsd:anyURI .
#
# CDs:The_Live_One  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Live One" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/50929cd8-866d-4899-9184-90693362422d"^^xsd:anyURI .
#
# CDs:Try_Whistling_This  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Try Whistling This" ;
#         dcterms:creator                SoloMusicArtist:Tim_Finn ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_Finn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b569700-0195-3c0a-a522-104eadc603a6"^^xsd:anyURI .
#
# CDs:Regatta_de_Blanc  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Regatta de Blanc" ;
#         dcterms:creator                MusicGroup:Police ;
#         bibliographica:byArtist        MusicGroup:Police ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e104844e-3ff4-3388-9d13-0e527a77cf3b"^^xsd:anyURI .
#
# CDs:Its_Monks_Time  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "It's Monk's Time" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9d66e969-64c8-4444-a9c2-7a7c28a52da8"^^xsd:anyURI .
#
# CDs:Dart_to_Heart  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dart to the Heart" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/678bef56-4dc4-39b2-9d2f-e0ede6c0a7b9"^^xsd:anyURI .
#
# CDs:The_First_Day  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The First Day" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/995790b4-6ed3-41d9-aa05-5a68b06bbfa0"^^xsd:anyURI .
#
# CDs:Boys_for_Pele  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Boys for Pele" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/127fbc4c-b309-38bf-af91-624f03b134c4"^^xsd:anyURI .
#
# CDs:Free_Like_We_Want  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Free Like We Want 2 B" ;
#         dcterms:creator                MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:byArtist        MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:musicbrainzURI  "https://beta.musicbrainz.org/release/341b9964-e1e3-423a-8424-6acecd22603c"^^xsd:anyURI .
#
# CDs:While_You_Werent_Looking
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "While You Weren't Looking" ;
#         dcterms:creator                SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:byArtist        SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/284ce5a4-1b89-4e35-9bf4-e9058736747a"^^xsd:anyURI .
#
# CDs:Nashville_Skyline  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nashville Skyline" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/2ca28746-8987-3015-b54c-75b3aa8ca1a1"^^xsd:anyURI .
#
# CDs:Emmylou  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "emmylou" ;
#         dcterms:creator          SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist  SoloMusicArtist:Emmylou_Harris .
#
# CDs:Family  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Family" ;
#         dcterms:creator                MusicGroup:Del_McCoury_Band ;
#         bibliographica:byArtist        MusicGroup:Del_McCoury_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2e3d3e30-5d78-438a-a669-38ac2bac1327"^^xsd:anyURI .
#
# CDs:Do_Re_Mi  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Do Re Mi" ;
#         dcterms:creator          SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist  SoloMusicArtist:Ry_Cooder .
#
# CDs:Live_Maxs_KC  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Max’s Kansas City 11-15-77" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa8b3217-3e89-45c4-a119-2ed8d71a64fa"^^xsd:anyURI .
#
# CDs:Essence_of_Louis_Armstrong
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Essence of Louis Armstrong" ;
#         dcterms:creator                SoloMusicArtist:Louis_Armstrong ;
#         bibliographica:byArtist        SoloMusicArtist:Louis_Armstrong ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ca64f31e-a574-4241-a7fc-abadd12ca93d"^^xsd:anyURI .
#
# CDs:Bye_Bye_Route_66  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bye Bye Route 66" ;
#         dcterms:creator                MusicGroup:Devonsquare ;
#         bibliographica:byArtist        MusicGroup:Devonsquare ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5477049-bcb0-482a-b6a7-51983b80163c"^^xsd:anyURI .
#
# CDs:Rising_For_Moon  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rising for the Moon" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/63418eb7-79a5-4437-bc10-f920503024f5"^^xsd:anyURI .
#
# CDs:Dancing_Blues  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dancing the Blues" ;
#         dcterms:creator                SoloMusicArtist:Taj_Mahal ;
#         bibliographica:byArtist        SoloMusicArtist:Taj_Mahal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2bd7c5d-efa5-4652-a1e7-9f8a89ef2ca1"^^xsd:anyURI .
#
# CDs:You_Cant_Do_That_On_Stage_v1
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a352e30-05e4-45f8-aee7-f7a8835c2633"^^xsd:anyURI .
#
# CDs:On_the_Blvd  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "On the Boulevard" ;
#         dcterms:creator                MusicGroup:New_Grass_Revival ;
#         bibliographica:byArtist        MusicGroup:New_Grass_Revival ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2f3828b5-e8b3-439b-aacd-39a3e47104c8"^^xsd:anyURI .
#
# CDs:The_Wishing_Chair  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Wishing Chair" ;
#         dcterms:creator                MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:byArtist        MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b54bc4b-f8a5-43c4-80e4-b5b4fe4b93c4"^^xsd:anyURI .
#
# CDs:Trey_Anastasio_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Trey Anastasio" ;
#         dcterms:creator                SoloMusicArtist:Trey_Anastasio ;
#         bibliographica:byArtist        SoloMusicArtist:Trey_Anastasio ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/87f0328c-7f3e-41d9-8032-9f2a6c9a25da"^^xsd:anyURI .
#
# CDs:Genuine_Negro_Jig  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Genuine Negro Jig" ;
#         dcterms:creator                MusicGroup:Carolina_Chocolate_Drops ;
#         bibliographica:byArtist        MusicGroup:Carolina_Chocolate_Drops ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c8480d46-bfbc-3213-9717-51d843483f51"^^xsd:anyURI .
#
# CDs:Ive_Got_Rock_Sock  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I've Got a Rock in My Sock!" ;
#         dcterms:creator                SoloMusicArtist:Rory_Block ;
#         bibliographica:byArtist        SoloMusicArtist:Rory_Block ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7011b880-c734-4b43-92f7-acf746045b30"^^xsd:anyURI .
#
# CDs:One_Down_One_Up  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Down, One Up: Live at the Half Note" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4e73212d-bfdd-4cb7-9fd7-066fd38e984d"^^xsd:anyURI .
#
# CDs:Unplugged_TM  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unplugged" ;
#         dcterms:creator                MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:byArtist        MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/90bfbec9-862c-4334-b235-43ff5111de03"^^xsd:anyURI .
#
# CDs:Swedish_Schnapps  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Swedish Schnapps" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cf6e387b-144f-4132-a0db-79c64b8d5cb9"^^xsd:anyURI .
#
# CDs:Tone_Poems_II  a                      mo:CD , mo:Record , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Tone Poems II" ;
#         dcterms:creator                SoloMusicArtist:Martin_Taylor , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:Martin_Taylor , SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6c41d347-eb91-494e-afae-d334ea5f447b"^^xsd:anyURI .
#
# CDs:The_Look_of_Love  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Look of Love" ;
#         dcterms:creator                SoloMusicArtist:Diana_Krall ;
#         bibliographica:byArtist        SoloMusicArtist:Diana_Krall ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/73881b92-df90-4a36-9f0a-d01dfdd7b885"^^xsd:anyURI .
#
# CDs:Intergalactic_Boogie
#         a                              schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Intergalactic Boogie Express: Live in Europe 1991" ;
#         dcterms:creator                MusicGroup:League_Crafty_Guitarists , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp , MusicGroup:League_Crafty_Guitarists ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eedc7af4-db61-4802-9758-f9e11516a516"^^xsd:anyURI .
#
# CDs:Burn_to_Shine  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Burn to Shine" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a2611b7b-593a-4d9f-8b04-81c746e2312f"^^xsd:anyURI .
#
# CDs:A_Love_Supreme_Live  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "A Love Supreme (Live in Antibes France) 1965)" ;
#         dcterms:creator          SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist  SoloMusicArtist:John_Coltrane .
#
# CDs:Full_Moon_Story  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Full Moon Story" ;
#         dcterms:creator                SoloMusicArtist:Kitaro ;
#         bibliographica:byArtist        SoloMusicArtist:Kitaro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3dcefd74-06a3-451d-8dcb-d0ae99fac043"^^xsd:anyURI .
#
# CDs:In_the_Mouth_Crocodile
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Mouth of the Crocodile: Live in Seattle" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3bafdd01-b13d-4d27-8625-8a7fba81c096"^^xsd:anyURI .
#
# CDs:L_Amour_ou_la_Folie  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "L'Amour ou la Folie" ;
#         dcterms:creator                MusicGroup:BeauSoleil ;
#         bibliographica:byArtist        MusicGroup:BeauSoleil ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5311e9f9-fe6d-4d1c-ba21-46d4b8e0bd71"^^xsd:anyURI .
#
# CDs:Bye_Bye_Blackbird  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bye Bye Blackbird" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c881c5ea-8ceb-4f9f-91ec-8fdaed34fe66"^^xsd:anyURI .
#
# CDs:The_Neighborhood  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Neighborhood" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a7a7747b-a032-4c45-bd4e-be0090589cfd"^^xsd:anyURI .
#
# CDs:Strong_Enough  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strong Enough" ;
#         dcterms:creator                SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:byArtist        SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cafd8e50-93df-40e8-96ad-240180b81c63"^^xsd:anyURI .
#
# CDs:Gospel_Oak  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gospel Oak" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4c4b4d8c-3f54-4d3e-8a78-912b0fbf3b04"^^xsd:anyURI .
#
# CDs:Blue_Moon_Swamp  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Moon Swamp" ;
#         dcterms:creator                SoloMusicArtist:John_Fogerty ;
#         bibliographica:byArtist        SoloMusicArtist:John_Fogerty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b37ce1bf-5900-422f-a23e-fa93cfa94521"^^xsd:anyURI .
#
# CDs:The_Secret_Language_Birds
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Secret Language of Birds" ;
#         dcterms:creator                SoloMusicArtist:Ian_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Ian_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b573b6e9-eb93-469e-ba51-bea5c68ce5a8"^^xsd:anyURI .
#
# CDs:Discovered_Covered  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Late Great Daniel Johnston: Discovered Covered" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Johnston ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Johnston ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a785805a-ed71-4982-a842-17048f148a7d"^^xsd:anyURI .
#
# CDs:Van_Lear_Rose  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Van Lear Rose" ;
#         dcterms:creator                SoloMusicArtist:Loretta_Lynn ;
#         bibliographica:byArtist        SoloMusicArtist:Loretta_Lynn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4df009ce-78de-4515-8499-19cc56d66eba"^^xsd:anyURI .
#
# CDs:Bareback  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bareback" ;
#         dcterms:creator                MusicGroup:Hank_Dogs ;
#         bibliographica:byArtist        MusicGroup:Hank_Dogs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/45d4af12-b415-4fc7-b1d3-06b2e267bd8b"^^xsd:anyURI .
#
# CDs:Big_Wide_Grin  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big Wide Grin" ;
#         dcterms:creator                SoloMusicArtist:Keb_Mo ;
#         bibliographica:byArtist        SoloMusicArtist:Keb_Mo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b006e488-d072-499b-bb72-5e6bd5c062de"^^xsd:anyURI .
#
# CDs:Fight_for_Your_Mind  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fight for Your Mind" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d9d8e0e1-ed72-3662-a0f8-5dc78125a973"^^xsd:anyURI .
#
# CDs:Letter_From_Home  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Letter From Home" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/19721ca4-81da-4a29-bae6-97dc46334d4b"^^xsd:anyURI .
#
# CDs:Thirteen_Years_Herbs
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "13 Years of Herbs: The Best Of" ;
#         dcterms:creator                MusicGroup:Herbs ;
#         bibliographica:byArtist        MusicGroup:Herbs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53e3591e-6ab0-4f2b-a40c-83b0dc016b88"^^xsd:anyURI .
#
# CDs:Hi_How_Are_You_Today
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hi How Are You Today?" ;
#         dcterms:creator                SoloMusicArtist:Ashley_MacIsaac ;
#         bibliographica:byArtist        SoloMusicArtist:Ashley_MacIsaac ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/09607773-5cc3-4d75-8eb1-8bb343f037bd"^^xsd:anyURI .
#
# CDs:Don_Juans_Reclkess_Daughter
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Don Juan's Reckless Daughter" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bc7d3926-3356-3bb2-903c-7d29d694d638"^^xsd:anyURI .
#
# CDs:Hidden_Harvest  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hidden Harvest" ;
#         dcterms:creator                SoloMusicArtist:Mary_Black ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Black ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2d5bddef-479e-42f3-87a3-dca74ed987b7"^^xsd:anyURI .
#
# CDs:Southern_Surroundings
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Southern Surroundings: The Ultimate Skynyrd Collection" ;
#         dcterms:creator                MusicGroup:Lynyrd_Skynyrd ;
#         bibliographica:byArtist        MusicGroup:Lynyrd_Skynyrd ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/638f9c11-77d1-4cb9-aa67-ce025dbe32ff"^^xsd:anyURI .
#
# CDs:Lookout_for_Hope  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lookout for Hope" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0cefe3fa-a5fd-41ba-9b89-ae4b2a3f26e8"^^xsd:anyURI .
#
# CDs:Open_Road  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Open Road" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c9c9db42-6c95-4b8f-b827-6aed11f145c1"^^xsd:anyURI .
#
# CDs:Light_My_Fire  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Light My Fire" ;
#         dcterms:creator                MusicGroup:The_Doors ;
#         bibliographica:byArtist        MusicGroup:The_Doors ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a65c8000-6154-4168-a823-828b949f66a9"^^xsd:anyURI .
#
# CDs:Buy_Me_Bring_Me_Take_Me
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buy Me Bring Me Take Me: Don't Mess My Hair!!!" ;
#         dcterms:creator                MusicGroup:Four_Bitchin_Babes ;
#         bibliographica:byArtist        MusicGroup:Four_Bitchin_Babes ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/573e7d2c-a594-4506-bc88-3882836063a9"^^xsd:anyURI .
#
# CDs:How_West_Was_Won  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "How the West Was Won" ;
#         dcterms:creator                MusicGroup:Led_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Led_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df7eb1e1-a9a5-410b-ab78-36e38ae338d4"^^xsd:anyURI .
#
# CDs:Love_Loss_Lunacy  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Love, Loss & Lunacy" ;
#         dcterms:creator          MusicGroup:Mary_Lees_Corvette ;
#         bibliographica:byArtist  MusicGroup:Mary_Lees_Corvette .
#
# CDs:Before_the_Moon  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Before the Moon" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32250a4b-1cc6-4cfa-a148-5ac819bd340b"^^xsd:anyURI .
#
# CDs:Rum_Sodomy_Lash  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rum, Sodomy, & the Lash" ;
#         dcterms:creator                MusicGroup:Pogues ;
#         bibliographica:byArtist        MusicGroup:Pogues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83a9039a-8c6b-42fa-836e-a57c179e5fb7"^^xsd:anyURI .
#
# CDs:Filles_de_Kilamanjaro
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Filles De Kilimanjaro" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa5cc77b-f8fa-32da-8b0f-4d4eab9cbb10"^^xsd:anyURI .
#
# CDs:Family_Man  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Family Man" ;
#         dcterms:creator                MusicGroup:Black_Flag ;
#         bibliographica:byArtist        MusicGroup:Black_Flag ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/29888d56-d9f0-41d3-b77c-b42f46200d14"^^xsd:anyURI .
#
# CDs:Shuffletown  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shuffletown" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8a495034-5cf3-46cf-a2c3-668fb0125d56"^^xsd:anyURI .
#
# CDs:Another_Stoney_Evening
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Another Stoney Evening" ;
#         dcterms:creator                MusicGroup:Crosby_Nash ;
#         bibliographica:byArtist        MusicGroup:Crosby_Nash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7bfad5e9-1f77-45ec-9580-dcb2c2db87d4"^^xsd:anyURI .
#
# CDs:Dont_Be_Afraid_Dark  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Don’t Be Afraid of the Dark" ;
#         dcterms:creator                SoloMusicArtist:Robert_Cray ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Cray ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cffad015-5d86-47cd-a383-c5ad5024c0ab"^^xsd:anyURI .
#
# CDs:Dire_Straits_CD  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dire Straits" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2b3e222e-90c4-304e-a90a-1e07eac842df"^^xsd:anyURI .
#
# CDs:Bags_Trane  a                         schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Bags & Trane" ;
#         dcterms:creator                SoloMusicArtist:Milt_Jackson , SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane , SoloMusicArtist:Milt_Jackson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b359464-9ace-4130-bda3-7fe01fc55299"^^xsd:anyURI .
#
# CDs:No_Pain_For_Cakes  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Pain For Cakes" ;
#         dcterms:creator                MusicGroup:Lounge_Lizards ;
#         bibliographica:byArtist        MusicGroup:Lounge_Lizards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1c424f56-cc7d-439e-87f6-fd24de470c91"^^xsd:anyURI .
#
# CDs:Steal_Your_Face  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Steal Your Face" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92bae6ff-2458-4879-91eb-e6f46797bccb"^^xsd:anyURI .
#
# CDs:Fairport_Convention_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fairport Convention" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1547cfe-52c2-3ff2-a487-d7a27f2f5c68"^^xsd:anyURI .
#
# CDs:Belladonna  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Belladonna" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e2bf4e10-885d-471a-b1be-ddee0ba29205"^^xsd:anyURI .
#
# CDs:Nils_Sangit  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Nils Sangit" ;
#         dcterms:creator          SoloMusicArtist:Georges_Kazazian ;
#         bibliographica:byArtist  SoloMusicArtist:Georges_Kazazian .
#
# CDs:Welcome_Our_World  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Welcome to Our World (For Members Only)" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3cef3f1-f5e4-4a4f-94ea-d701248a3a11"^^xsd:anyURI .
#
# CDs:Meet_Me_Midnite  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Meet Me at Midnite" ;
#         dcterms:creator                SoloMusicArtist:Maria_Muldaur ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_Muldaur ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d008aebf-b341-49d8-ac65-54c8dc527990"^^xsd:anyURI .
#
# CDs:Gentle_Side_John_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Gentle Side Of John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cae584e6-3e98-435f-94ce-7c9ca788b63b"^^xsd:anyURI .
#
# CDs:Funky_Good_Time  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Funky Good Time - The Anthology" ;
#         dcterms:creator                MusicGroup:JBs ;
#         bibliographica:byArtist        MusicGroup:JBs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e41f472-ed3d-41ef-a5fe-956d6e1aeecc"^^xsd:anyURI .
#
# CDs:Third_World_Child  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Third World Child" ;
#         dcterms:creator                MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:byArtist        MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b515895b-dcbf-43b0-8821-7ac4aa77c923"^^xsd:anyURI .
#
# CDs:Joan_Armatrading_CD  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Joan Armatrading" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd79f706-0743-398a-976f-761e35c128e6"^^xsd:anyURI .
#
# CDs:Big_Dirt  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Big Dirt" ;
#         dcterms:creator          MusicGroup:My_Sister_Kate ;
#         bibliographica:byArtist  MusicGroup:My_Sister_Kate .
#
# CDs:Fugitives  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fugitives" ;
#         dcterms:creator                SoloMusicArtist:Vance_Gilbert ;
#         bibliographica:byArtist        SoloMusicArtist:Vance_Gilbert ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/11eaa656-08e6-4649-9c6d-3200a06ccb9f"^^xsd:anyURI .
#
# CDs:Emmett_Grogan_Acetates
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Emmett Grogan Acetates" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d05fa3ed-3cd3-48d5-95e0-48f90882d476"^^xsd:anyURI .
#
# CDs:Angel_With_Lariat  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Angel With a Lariat" ;
#         dcterms:creator                SoloMusicArtist:KD_Lang ;
#         bibliographica:byArtist        SoloMusicArtist:KD_Lang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ab93b1bd-6a96-47a4-a613-42439e129e0f"^^xsd:anyURI .
#
# CDs:Concert_For_Bangladesh
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Concert for Bangladesh" ;
#         dcterms:creator                SoloMusicArtist:George_Harrison ;
#         bibliographica:byArtist        SoloMusicArtist:George_Harrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/078b1ccf-0db9-46ed-a645-4278e384f575"^^xsd:anyURI .
#
# CDs:Blue_Country_Heart  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Country Heart" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/66087e86-47d6-494d-8ddf-19a86612bf15"^^xsd:anyURI .
#
# CDs:Live_From_Mars  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live From Mars" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/94861915-41de-4b7d-9211-bf713bb3f93f"^^xsd:anyURI .
#
# CDs:Very_Best_Of_Nicolette
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Very Best of Nicolette Larson" ;
#         dcterms:creator                SoloMusicArtist:Nicolette_Larson ;
#         bibliographica:byArtist        SoloMusicArtist:Nicolette_Larson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a471cfb8-c161-42bd-a472-21641fcc820a"^^xsd:anyURI .
#
# CDs:The_Magazine  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Magazine" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7f1e9aaf-ffc3-4f4b-a8c7-7619d57c0b38"^^xsd:anyURI .
#
# CDs:No_Talking_Just_Head
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Talking Just Head" ;
#         dcterms:creator                MusicGroup:Heads ;
#         bibliographica:byArtist        MusicGroup:Heads ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7f28d946-7ebf-427f-86c0-177e1ae075b6"^^xsd:anyURI .
#
# CDs:New_Skin  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New Skin for the Old Ceremony" ;
#         dcterms:creator                SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:byArtist        SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e26274ca-69a0-491d-b742-2c999d06dbc2"^^xsd:anyURI .
#
# CDs:Empire_Burlesque  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Empire Burlesque" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a90b32b2-c84d-35ad-bab3-07e6799cde5b"^^xsd:anyURI .
#
# CDs:Kick_Out_Jams  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kick Out the Jams" ;
#         dcterms:creator                MusicGroup:MC5 ;
#         bibliographica:byArtist        MusicGroup:MC5 ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9eebeb73-6d3f-48a9-b70d-97e91f42ae67"^^xsd:anyURI .
#
# CDs:Live_at_Red_Rocks_DM
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Red Rocks 8.15.95" ;
#         dcterms:creator                SoloMusicArtist:Dave_Matthews ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Matthews ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5b1582c-65aa-4df5-ab2f-9d8ad2953be3"^^xsd:anyURI .
#
# CDs:Drums_of_Passion  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Drums of Passion" ;
#         dcterms:creator                SoloMusicArtist:Babatunde_Olatunji ;
#         bibliographica:byArtist        SoloMusicArtist:Babatunde_Olatunji ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2a387ccf-9d99-3c3e-a0fe-2922d15ecb39"^^xsd:anyURI .
#
# CDs:How_Long_Going_On  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "How Long Has This Been Going On" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/18a25a67-748e-440a-98c1-e1c8e2737811"^^xsd:anyURI .
#
# CDs:Unledded  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Un-led-ed" ;
#         dcterms:creator                MusicGroup:Dread_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Dread_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b0b79978-f1c1-444f-b071-885be775450b"^^xsd:anyURI .
#
# CDs:Trouble_Bound  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Trouble Bound" ;
#         dcterms:creator                MusicGroup:The_Blasters ;
#         bibliographica:byArtist        MusicGroup:The_Blasters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ce0a5b20-7485-4074-85c8-bdb6a3668d12"^^xsd:anyURI .
#
# CDs:Give_It_Up  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Give It Up" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aaeb3a56-00c3-3fb2-b183-f65e6355af33"^^xsd:anyURI .
#
# CDs:Biograph  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Biograph" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b5cbeb61-6e9c-38a8-9cb7-caf456782361"^^xsd:anyURI .
#
# CDs:Guitar_Town  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Guitar Town" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Earle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a633eb47-8b0d-4b82-8132-cc5cf09d7e7e"^^xsd:anyURI .
#
# CDs:Monks_Blues  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Monk’s Blues" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3e38dbee-ba5b-4686-9298-ffc256cf0cd2"^^xsd:anyURI .
#
# CDs:Get_Up_With_It  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Get Up With It" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b8a32bb4-9858-3dfb-b0a2-0a67e05ee80a"^^xsd:anyURI .
#
# CDs:Bottomless_Cup  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bottomless Cup" ;
#         dcterms:creator                MusicGroup:Chris_Maggie ;
#         bibliographica:byArtist        MusicGroup:Chris_Maggie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/45cdf271-5e94-4589-8add-71b6d20419de"^^xsd:anyURI .
#
# CDs:Zydeco_Dynamite  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zydeco Dynamite" ;
#         dcterms:creator                SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:byArtist        SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5c9f3aa-9232-49a2-83f0-fef476d10ce2"^^xsd:anyURI .
#
# CDs:Ladies_of_the_Road  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ladies of the Road" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3e9a227c-4432-4f7b-b474-339cb3754377"^^xsd:anyURI .
#
# CDs:Live_Unreleased  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live & Unreleased: The Radio Show" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c0a9334f-bd50-4b14-82b1-282c64aa9fd9"^^xsd:anyURI .
#
# CDs:Perfectly_Good_Guitar
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Perfectly Good Guitar" ;
#         dcterms:creator                SoloMusicArtist:John_Hiatt ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hiatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5bbb4214-72d9-4525-be52-90619ae016cc"^^xsd:anyURI .
#
# CDs:Peter_Gabriel_Melt  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peter Gabriel (Melt)" ;
#         dcterms:creator                SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:byArtist        SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3a90044-9258-3e46-a77f-b33ca78c5503"^^xsd:anyURI .
#
# CDs:School_Days  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "School Days" ;
#         dcterms:creator                SoloMusicArtist:Stanley_Clarke ;
#         bibliographica:byArtist        SoloMusicArtist:Stanley_Clarke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/33e9f93c-4996-4e4c-a20a-9fba4e0446e1"^^xsd:anyURI .
#
# CDs:Chinatown  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chinatown" ;
#         dcterms:creator                MusicGroup:The_Be_Good_Tanyas ;
#         bibliographica:byArtist        MusicGroup:The_Be_Good_Tanyas ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d83a156e-46b0-4f23-9205-a8fe06ef6936"^^xsd:anyURI .
#
# CDs:Labour_of_Lust  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Labour of Lust" ;
#         dcterms:creator                SoloMusicArtist:Nick_Lowe ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Lowe ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/90c818a1-77a9-488c-b4a5-be4867d386c5"^^xsd:anyURI .
#
# CDs:Open   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Open" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dd18208e-946d-3f05-ac0c-e2a14be0d318"^^xsd:anyURI .
#
# CDs:Heyday_BBC  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Heyday: BBC Radio Sessions 1968-1969" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b1dfd603-67d2-44a3-b043-8af8cd23e76d"^^xsd:anyURI .
#
# CDs:Audio_Visualscapes  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Audio Visualscapes" ;
#         dcterms:creator                SoloMusicArtist:Jack_DeJohnette ;
#         bibliographica:byArtist        SoloMusicArtist:Jack_DeJohnette ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41c8c97f-3db5-479e-aba0-f4ebd1ec6f52"^^xsd:anyURI .
#
# CDs:Tonight_at_Noon  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tonight at Noon" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cf2393b9-76a1-3e8e-b89a-a9759cb13b8f"^^xsd:anyURI .
#
# CDs:From_SAfrica_SCarolina
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "From South Africa to South Carolina" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d47aa95f-15f7-43e2-91da-61753a8b9f15"^^xsd:anyURI .
#
# CDs:Beginning_of_Survival
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Beginning of Survival" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3c488fb-c0c9-4e05-9d92-ecbd4b120487"^^xsd:anyURI .
#
# CDs:Unhalfbricking  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unhalfbricking" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/def57daf-3f7c-4614-a302-3bd8083d41a7"^^xsd:anyURI .
#
# CDs:For_Beauty_Wynona  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "For the Beauty of Wynona" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4204c64c-c3a4-4401-865b-14e112c031a1"^^xsd:anyURI .
#
# CDs:Night_Vision  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Night Vision" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/c663c0fb-c739-3191-b099-13ed01fd6df8"^^xsd:anyURI .
#
# CDs:Best_of_Mary_Black  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Mary Black 1991-2001" ;
#         dcterms:creator                SoloMusicArtist:Mary_Black ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Black ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cbe190bc-8048-45cd-9b6d-8a0656c71a79"^^xsd:anyURI .
#
# CDs:I_Love_Everybody  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I Love Everybody" ;
#         dcterms:creator                SoloMusicArtist:Lyle_Lovett ;
#         bibliographica:byArtist        SoloMusicArtist:Lyle_Lovett ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aea36fb5-706f-4bc7-bdb8-b3a98614afe3"^^xsd:anyURI .
#
# CDs:Keep_the_Dog  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Keep the Dog: That House We Lived In" ;
#         dcterms:creator                SoloMusicArtist:Fred_Frith ;
#         bibliographica:byArtist        SoloMusicArtist:Fred_Frith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/07264117-6a5d-4400-857d-56dade30ceb3"^^xsd:anyURI .
#
# CDs:When_Juniper_Sleeps  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "When Juniper Sleeps" ;
#         dcterms:creator                SoloMusicArtist:Seamus_Egan ;
#         bibliographica:byArtist        SoloMusicArtist:Seamus_Egan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/37ab533c-3dc7-4462-8257-f34ad179fd73"^^xsd:anyURI .
#
# CDs:First_Rays_Rising_Sun
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "First Rays of the New Rising Sun" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e37dbca5-99bc-4b79-b707-b66d31de4f2f"^^xsd:anyURI .
#
# CDs:Without_a_Net  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Without a Net" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a9ef2528-9b35-4014-9ba1-7a44a6f81173"^^xsd:anyURI .
#
# CDs:Walkin_in_Shadows  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Walkin' in the Shadow of Life" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8fc0a126-5f09-4ebf-bda8-48118b8f291e"^^xsd:anyURI .
#
# CDs:New_on_Earth  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New on Earth" ;
#         dcterms:creator                SoloMusicArtist:Shona_Laing ;
#         bibliographica:byArtist        SoloMusicArtist:Shona_Laing ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a72b0612-e0e7-4d7b-b90e-8cec19d32632"^^xsd:anyURI .
#
# CDs:Workingmans_Dead  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Workingman's Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e42901c5-74f0-3055-9c70-54cc5fb2516c"^^xsd:anyURI .
#
# CDs:So_Much_Shouting_So_Much_Laughter
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "So Much Shouting, So Much Laughter" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a9675493-dd84-3a94-94e7-71fe28279742"^^xsd:anyURI .
#
# CDs:Brothers_Keeper  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Brother's Keeper" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a081c797-b52f-4ef6-9657-d3c0fc704074"^^xsd:anyURI .
#
# CDs:Root_of_Steely_Dan  a                 schema:MusicAlbum , mo:Release , mo:CD , mo:Record ;
#         rdfs:label                     "The Root of Steely Dan" ;
#         dcterms:creator                SoloMusicArtist:Walter_Becker , SoloMusicArtist:Donald_Fagen ;
#         bibliographica:byArtist        SoloMusicArtist:Donald_Fagen , SoloMusicArtist:Walter_Becker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/127fbd4a-f67a-4797-b360-75a9cf448bc5"^^xsd:anyURI .
#
# CDs:In_Dark_With_You  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Dark With You" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f8925577-36ce-408e-b78d-a9209b028a53"^^xsd:anyURI .
#
# CDs:Jazz_Round_Midnight  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz 'Round Midnight" ;
#         dcterms:creator                SoloMusicArtist:Clifford_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Clifford_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/09a540e2-8a84-4124-bacf-76693aead849"^^xsd:anyURI .
#
# CDs:Another_Green_World  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Another Green World" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e565733-dddf-3041-b5f3-60c4705d7a97"^^xsd:anyURI .
#
# CDs:Poetic_Champions_Compose
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Poetic Champions Compose" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0dc8620c-325d-4057-a6d2-06c007e3168c"^^xsd:anyURI .
#
# CDs:Complete_Greatest_Hits
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Complete Greatest Hits" ;
#         dcterms:creator                SoloMusicArtist:Gordon_Lightfoot ;
#         bibliographica:byArtist        SoloMusicArtist:Gordon_Lightfoot ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/84be735c-4438-45a6-b5a1-9caf6b6870ba"^^xsd:anyURI .
#
# CDs:Mirror_Ball  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mirror Ball" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4fc8612c-8660-4866-85c3-75b7bb226c81"^^xsd:anyURI .
#
# CDs:Weaving_Ancestors_Voices
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Weaving My Ancestors’ Voices" ;
#         dcterms:creator                SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:byArtist        SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/57cf757d-c486-47b2-a314-ac113fee9417"^^xsd:anyURI .
#
# CDs:Acoustic_Motor_Bike  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Acoustic Motorbike" ;
#         dcterms:creator                SoloMusicArtist:Luka_Bloom ;
#         bibliographica:byArtist        SoloMusicArtist:Luka_Bloom ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/406ec17c-b23e-4cfd-817a-4923a0cf9e43"^^xsd:anyURI .
#
# CDs:Live_BC  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/0f8aefe0-47e3-394b-83cd-c8e7cb85010d"^^xsd:anyURI .
#
# CDs:Best_of_Word_Jazz  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Word Jazz, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:Ken_Nordine ;
#         bibliographica:byArtist        SoloMusicArtist:Ken_Nordine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ec64128-e2a1-4a93-b30d-0208a56ddfbd"^^xsd:anyURI .
#
# CDs:The_First_Ten_Years  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The First Ten Years: 1986 / 1995" ;
#         dcterms:creator                MusicGroup:Altan ;
#         bibliographica:byArtist        MusicGroup:Altan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02a9ce0a-fdb4-42fe-8c54-15471708cbed"^^xsd:anyURI .
#
# CDs:Mr_Lucky  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mr. Lucky" ;
#         dcterms:creator                SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/51a517d8-4c7e-41c4-9619-f861fc22da13"^^xsd:anyURI .
#
# CDs:Miles_Quincy_at_Montreux
#         a                              mo:CD , mo:Release , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "Miles & Quincy Live at Montreux" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis , SoloMusicArtist:Quincy_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Quincy_Jones , SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d5811f0e-4f7e-4498-90fe-cd82fcde7baf"^^xsd:anyURI .
#
# CDs:Indecent  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Indecent" ;
#         dcterms:creator          MusicGroup:Faith_No_More ;
#         bibliographica:byArtist  MusicGroup:Faith_No_More .
#
# CDs:The_Glow  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Glow" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60b0a161-5a4c-33c0-80ec-2c5b92d6d100"^^xsd:anyURI .
#
# CDs:The_Collection  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Collection" ;
#         dcterms:creator                SoloMusicArtist:Bessie_Smith ;
#         bibliographica:byArtist        SoloMusicArtist:Bessie_Smith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6d005c05-2c56-48ad-a660-fd66657c5160"^^xsd:anyURI .
#
# CDs:Live_with_Jan_Hammer
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jeff Beck with the Jan Hammer Group Live" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Beck ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Beck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/95420b2e-d645-4582-b7ad-6c5f28bfec76"^^xsd:anyURI .
#
# CDs:Space_Oddity  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Space Oddity" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ede9ad56-aebd-4442-9961-2685d86a7441"^^xsd:anyURI .
#
# CDs:Saturday_Rolling_Around
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Saturday Rolling Around" ;
#         dcterms:creator                MusicGroup:Golden_Palominos ;
#         bibliographica:byArtist        MusicGroup:Golden_Palominos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/669b389f-9b58-42b8-a618-2cfcd2beccfb"^^xsd:anyURI .
#
# CDs:Live_in_Japan  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Japan" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8f74470d-0504-483f-973d-24db67de6453"^^xsd:anyURI .
#
# CDs:Flux_Mutability  a                    schema:MusicAlbum , mo:Release , mo:CD , mo:Record ;
#         rdfs:label                     "Flux + Mutability" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian , SoloMusicArtist:Holger_Czukay ;
#         bibliographica:byArtist        SoloMusicArtist:Holger_Czukay , SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7f23c936-a112-3417-9c0d-499d22e403c0"^^xsd:anyURI .
#
# CDs:Crawfish_Fiesta  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crawfish Fiesta" ;
#         dcterms:creator                SoloMusicArtist:Professor_Longhair ;
#         bibliographica:byArtist        SoloMusicArtist:Professor_Longhair ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/337b4885-265d-33e7-a252-816e2e0e66fc"^^xsd:anyURI .
#
# CDs:Winter_In_America  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Winter in America" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/299533ea-deef-4f3a-b245-913661e5ba97"^^xsd:anyURI .
#
# CDs:Blurring_Edges  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blurring the Edges" ;
#         dcterms:creator                SoloMusicArtist:Meredith_Brooks ;
#         bibliographica:byArtist        SoloMusicArtist:Meredith_Brooks ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ab34777-3a00-39c6-a43e-4b997916bb3c"^^xsd:anyURI .
#
# CDs:Ambient_2  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ambient 2: The Plateaux of Mirror" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e8e9a090-7250-35d0-9265-5182ea520573"^^xsd:anyURI .
#
# CDs:After_Midnight  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "After Midnight" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3d62e65-367e-44fd-a760-c3d6dc955a99"^^xsd:anyURI .
#
# CDs:Compact_Jazz_Duke  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Compact Jazz: Duke Ellington and Friends" ;
#         dcterms:creator                SoloMusicArtist:Duke_Ellington ;
#         bibliographica:byArtist        SoloMusicArtist:Duke_Ellington ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/67673582-c680-484a-8d6f-5dfecf1ff82a"^^xsd:anyURI .
#
# CDs:Tapoafom  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "T.A.P.O.A.F.O.M." ;
#         dcterms:creator                SoloMusicArtist:George_Clinton ;
#         bibliographica:byArtist        SoloMusicArtist:George_Clinton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/414012b2-4a20-416f-a946-7b79fd772436"^^xsd:anyURI .
#
# CDs:You_Gotta_Sin_Saved  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Gotta Sin to Get Saved" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e72fedda-e371-45f6-9b33-4b14845b2c91"^^xsd:anyURI .
#
# CDs:Miles_in_Stockholm  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles Davis in Stockholm 1960" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2ada97ef-b91f-44d6-805b-9fddecda0813"^^xsd:anyURI .
#
# CDs:Shadows_and_Light  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shadows and Light" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2ae2376-9b10-4f03-b74a-f832b28f3d8e"^^xsd:anyURI .
#
# CDs:Grayfolded  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Grayfolded" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1ef366bf-40fd-4698-9550-47953b1632b4"^^xsd:anyURI .
#
# CDs:Chicken_Skin_Music  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chicken Skin Music" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86f7cb74-90e8-3922-a496-720b0fa97f0f"^^xsd:anyURI .
#
# CDs:Attainable_Love  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Attainable Love" ;
#         dcterms:creator                SoloMusicArtist:Christine_Lavin ;
#         bibliographica:byArtist        SoloMusicArtist:Christine_Lavin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/96a076c0-dec7-4920-9f99-c9ef0af9a395"^^xsd:anyURI .
#
# CDs:Magic_Time  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Magic Time" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/511cf35a-c926-342c-ba91-f05da225cb5e"^^xsd:anyURI .
#
# CDs:Get_Rhythm  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Get Rhythm" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/030eba30-be0d-4fa3-accc-6ac3cd85409c"^^xsd:anyURI .
#
# CDs:CD_of_JB  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The CD of JB" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b44bd792-65d6-4ffa-a74b-db8b701603a2"^^xsd:anyURI .
#
# CDs:Killing_Time  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Killing Time" ;
#         dcterms:creator                MusicGroup:Massacre ;
#         bibliographica:byArtist        MusicGroup:Massacre ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e8c7f6a-86b3-426a-80c6-6b80bf3c3ef9"^^xsd:anyURI .
#
# CDs:Breakfast_NO_Dinner_Tim
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Breakfast in New Orleans, Dinner in Timbuktu" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/08bc0277-fcb2-3a52-8bbc-f7411d76d6df"^^xsd:anyURI .
#
# CDs:Peace_Beyond_Passion
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peace Beyond Passion" ;
#         dcterms:creator                SoloMusicArtist:Meshell_Ndegeocello ;
#         bibliographica:byArtist        SoloMusicArtist:Meshell_Ndegeocello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/71d559e1-e986-3bd8-942a-d836b558bb91"^^xsd:anyURI .
#
# CDs:Miles_in_Tokyo  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles in Tokyo" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4fd557ad-9e26-456b-a5c1-aec0104440e6"^^xsd:anyURI .
#
# CDs:Rounder_CD  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The David Grisman Rounder CD" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ead94b0f-3d70-4fae-8f24-d0cb3e9883ad"^^xsd:anyURI .
#
# CDs:Compilation_Four_Discs
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Compilation of 4 Discs" ;
#         dcterms:creator          SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist  SoloMusicArtist:John_Coltrane .
#
# CDs:One_More_Mile  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One More Mile" ;
#         dcterms:creator                SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/26c50e80-659f-4f51-ade7-0c8230b39274"^^xsd:anyURI .
#
# CDs:Panthalassa  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Panthalassa: The Music of Miles Davis 1969–1974" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a14daf0-a529-440a-ab0e-c85faf790fe6"^^xsd:anyURI .
#
# CDs:Best_of_Sidney_Bechet
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Sidney Bechet" ;
#         dcterms:creator                SoloMusicArtist:Sidney_Bechet ;
#         bibliographica:byArtist        SoloMusicArtist:Sidney_Bechet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83bdc6a4-6f08-4a30-9832-7cc05af59f65"^^xsd:anyURI .
#
# CDs:Cattin_with_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cattin’ with Coltrane and Quinichette" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cf4ff06c-3306-4603-a402-c9874b419656"^^xsd:anyURI .
#
# CDs:Small_Repairs  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Few Small Repairs" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/64e8c9e5-3f0a-4b85-9a8b-1c4521563c5d"^^xsd:anyURI .
#
# CDs:David_Live  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "David Live" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1352a8a5-2494-3f02-bfa5-496d10e04c52"^^xsd:anyURI .
#
# CDs:Go_Tell_It_On_The_Mountain
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Go Tell It On The Mountain" ;
#         dcterms:creator                MusicGroup:Blind_Boys_of_Alabama ;
#         bibliographica:byArtist        MusicGroup:Blind_Boys_of_Alabama ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/da61b4b3-33c4-4995-92a2-ecc58c46c4d8"^^xsd:anyURI .
#
# CDs:Between_Nothingness_Eternity
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Between Nothingness & Eternity" ;
#         dcterms:creator                MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:byArtist        MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ab78a2c3-9695-4d46-aba5-4e18b5d43c5a"^^xsd:anyURI .
#
# CDs:Labyrinth  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Labyrinth" ;
#         dcterms:creator                SoloMusicArtist:Kerri_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Kerri_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53a6438f-7cc4-47dd-8f8a-3990e6cbdbe0"^^xsd:anyURI .
#
# CDs:Creation_Dream  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Creation Dream" ;
#         dcterms:creator                SoloMusicArtist:Michael_Occhipinti ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Occhipinti ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/589520df-79b6-4e17-87e4-2c0395445a24"^^xsd:anyURI .
#
# CDs:The_Captain  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Captain" ;
#         dcterms:creator                SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:byArtist        SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1522382e-f2d4-3298-92f8-e4a04e2f4e3c"^^xsd:anyURI .
#
# CDs:Rules_of_Travel  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rules of Travel" ;
#         dcterms:creator                SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b2646a5-fe87-49e8-aaf5-b875e9cce57d"^^xsd:anyURI .
#
# CDs:Kill_Eugene  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kill Eugene" ;
#         dcterms:creator                SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:byArtist        SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/09452801-1dbd-4788-8fe6-9da91b62164f"^^xsd:anyURI .
#
# CDs:Still_in_Hollywood  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Still in Hollywood" ;
#         dcterms:creator                MusicGroup:Concrete_Blonde ;
#         bibliographica:byArtist        MusicGroup:Concrete_Blonde ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdce4869-cd60-4a21-adab-74f3d85136eb"^^xsd:anyURI .
#
# CDs:Live_at_Sweetwater_II
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Sweetwater II" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e6895acc-ed64-4ab7-8f5e-3035e926b170"^^xsd:anyURI .
#
# CDs:Live_RF_LCG  a                        schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Live!" ;
#         dcterms:creator                MusicGroup:League_Crafty_Guitarists , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        MusicGroup:League_Crafty_Guitarists , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f9871a60-2d3b-45ca-a304-b5b40dc5ecbc"^^xsd:anyURI .
#
# CDs:Axis_Bold_As_love  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Axis: Bold as Love" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e4b2047-7329-3dda-9328-db05daee0c96"^^xsd:anyURI .
#
# CDs:The_Wilderness  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Nomad Series, Volume 4: The Wilderness" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/27bcbca0-f3d3-44b6-9b88-4af26bd79bc3"^^xsd:anyURI .
#
# CDs:Pale_Sun_Crescent_Moon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pale Sun, Crescent Moon" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bcdd7fc9-7c6c-42f2-9d3e-bb99e382c291"^^xsd:anyURI .
#
# CDs:Johnny_Cash_Sings_Best
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Johnny Cash Sings His Best" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0376d8fa-f35d-46ca-9444-2b77746b1dee"^^xsd:anyURI .
#
# CDs:Le_Hoogie_Boogie  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Le Hoogie Boogie: Louisiana French Music for Children" ;
#         dcterms:creator                SoloMusicArtist:Michael_Doucet ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Doucet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/47b63911-581a-4948-a181-2a8b7799e129"^^xsd:anyURI .
#
# CDs:Diga   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Diga" ;
#         dcterms:creator                MusicGroup:Diga_Rhythm_Band ;
#         bibliographica:byArtist        MusicGroup:Diga_Rhythm_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1406468e-eca4-4686-b44b-f918ebd50599"^^xsd:anyURI .
#
# CDs:Listener_Supported  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Listener Supported" ;
#         dcterms:creator                SoloMusicArtist:Dave_Matthews ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Matthews ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/087d2304-b7f5-446a-96af-446c594b4f85"^^xsd:anyURI .
#
# CDs:By_Light_Moon  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "By the Light of the Moon" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b7944583-eaa5-418a-9976-aba4aa8200cb"^^xsd:anyURI .
#
# CDs:You_Pay_Your_Money  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Pay Your Money and You Take Your Chance" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/9a900f5d-28dd-3efa-b3c1-298fc84fc11b"^^xsd:anyURI .
#
# CDs:There_Must_Be_a_Better_World
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "There Must Be a Better World" ;
#         dcterms:creator                SoloMusicArtist:BB_King ;
#         bibliographica:byArtist        SoloMusicArtist:BB_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/09f8ede5-4767-41ee-9831-24475a8cf2d2"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_5
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bootleg Series, Vol. 5: Live 1975: The Rolling Thunder Revue" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/8ca47636-6fd8-3e17-9095-09503f605440"^^xsd:anyURI .
#
# CDs:Eu_Sei  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eu sei que vou te amar (ao vivo)" ;
#         dcterms:creator                SoloMusicArtist:Joao_Gilberto ;
#         bibliographica:byArtist        SoloMusicArtist:Joao_Gilberto ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a65d7e44-4d58-3eb3-9075-51cd98b78f93"^^xsd:anyURI .
#
# CDs:Ice_Caps_Peaks_Telluride
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ice Caps, Peaks of Telluride" ;
#         dcterms:creator                SoloMusicArtist:Sam_Bush ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Bush ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7f0b00f-2fd0-4f2a-83d3-a8f795df4e95"^^xsd:anyURI .
#
# CDs:Smokin_at_Half_Note  a                mo:CD , mo:Release , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "Smokin’ at the Half Note" ;
#         dcterms:creator                MusicGroup:Wynton_Kelly_Trio , SoloMusicArtist:Wes_Montgomery ;
#         bibliographica:byArtist        MusicGroup:Wynton_Kelly_Trio , SoloMusicArtist:Wes_Montgomery ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bc484406-5475-423b-9509-95c67ae30431"^^xsd:anyURI .
#
# CDs:Scar   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Scar" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3ea1f107-3ad8-42c5-9598-f77e3c794403"^^xsd:anyURI .
#
# CDs:Moving_Target  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moving Target" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fd9bcc76-a65f-3bd5-95db-4371bfcf7a0c"^^xsd:anyURI .
#
# CDs:Pizza_Tapes  a                        mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "The Pizza Tapes" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia , SoloMusicArtist:Tony_Rice , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Rice , SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/74e17c67-f7e3-498c-973e-28883258f4ac"^^xsd:anyURI .
#
# CDs:Talk_With_Jerry  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Talk With Jerry Garcia" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83086fdc-75c5-4930-8776-6d093d5557eb"^^xsd:anyURI .
#
# CDs:Dawgnation  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dawgnation" ;
#         dcterms:creator                MusicGroup:David_Grisman_Quintet ;
#         bibliographica:byArtist        MusicGroup:David_Grisman_Quintet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7593fea5-4f0e-4ee5-ad61-c249bbc4c560"^^xsd:anyURI .
#
# CDs:Sailing_to_Philiadelphia
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sailing to Philadelphia" ;
#         dcterms:creator                SoloMusicArtist:Mark_Knopfler ;
#         bibliographica:byArtist        SoloMusicArtist:Mark_Knopfler ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4426ad55-d292-4aca-bab4-b2606622f411"^^xsd:anyURI .
#
# CDs:Here_Come_Noise_Makers
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Here Come the Noise Makers" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Hornsby ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Hornsby ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f335ddf4-f31f-40c8-bd5b-672e0dceeabd"^^xsd:anyURI .
#
# CDs:Phase_2  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Phase 2" ;
#         dcterms:creator                MusicGroup:Mahavishnu_Project ;
#         bibliographica:byArtist        MusicGroup:Mahavishnu_Project ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/adf4206e-0200-4ce5-81af-d9c4f6a89c7d"^^xsd:anyURI .
#
# CDs:Free_Jazz  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Free Jazz" ;
#         dcterms:creator                SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:byArtist        SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/204968d5-4394-445f-a5ad-9ea36de63a69"^^xsd:anyURI .
#
# CDs:Blood_on_the_Fields  a                mo:Release , mo:CD , mo:Record , schema:MusicAlbum ;
#         rdfs:label                     "Blood on the Fields" ;
#         dcterms:creator                MusicGroup:Lincoln_Center_Jazz_Orchestra , SoloMusicArtist:Wynton_Marsalis ;
#         bibliographica:byArtist        SoloMusicArtist:Wynton_Marsalis , MusicGroup:Lincoln_Center_Jazz_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6bdb222-5b49-4edd-89cc-a03c44a03471"^^xsd:anyURI .
#
# CDs:From_Clare_Here  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "From Clare to Here: The Songs of Ralph McTell" ;
#         dcterms:creator                SoloMusicArtist:Ralph_McTell ;
#         bibliographica:byArtist        SoloMusicArtist:Ralph_McTell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/43998c33-405c-4fc8-8c2a-e18a82bb569b"^^xsd:anyURI .
#
# CDs:First_Instrument  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "First Instrument" ;
#         dcterms:creator                SoloMusicArtist:Rachelle_Ferrell ;
#         bibliographica:byArtist        SoloMusicArtist:Rachelle_Ferrell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/23856e41-cd13-43f5-ba2d-2e122c469351"^^xsd:anyURI .
#
# CDs:Firstborn_Is_Dead  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Firstborn Is Dead" ;
#         dcterms:creator                MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:byArtist        MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3adbcc25-34f0-4790-832e-61dc0dc75705"^^xsd:anyURI .
#
# CDs:Side_One  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Side One" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c28052f6-e133-3e90-aa7e-ac5727d649d6"^^xsd:anyURI .
#
# CDs:Secret_Life_Eddy_Fink
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Secret Life of J. Eddy Fink" ;
#         dcterms:creator                SoloMusicArtist:Janis_Ian ;
#         bibliographica:byArtist        SoloMusicArtist:Janis_Ian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/79523269-1500-43e5-ace3-af8442cf1d31"^^xsd:anyURI .
#
# CDs:Waltzie  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Waltzie" ;
#         dcterms:creator                SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:byArtist        SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4942576d-9f1a-467e-9b13-b710dc77e187"^^xsd:anyURI .
#
# CDs:Sings_Leonard_Cohen  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sings Leonard Cohen: Democracy" ;
#         dcterms:creator                SoloMusicArtist:Judy_Collins ;
#         bibliographica:byArtist        SoloMusicArtist:Judy_Collins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b7148fd-59de-491a-ba74-cfe1d0df8ea8"^^xsd:anyURI .
#
# CDs:Ellington_Meets_Hawkins
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Duke Ellington Meets Coleman Hawkins" ;
#         dcterms:creator                SoloMusicArtist:Coleman_Hawkins , SoloMusicArtist:Duke_Ellington ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5f7d4263-aff6-4405-abcf-fc9bbb332d3a"^^xsd:anyURI .
#
# CDs:Secrets_Beehive  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Secrets of the Beehive" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05ace6c9-6453-325d-9eff-f5975c842e59"^^xsd:anyURI .
#
# CDs:Key_Lime_Pie  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Key Lime Pie" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d826b19f-df20-4a9c-9a49-f10328c9b245"^^xsd:anyURI .
#
# CDs:Make_City_Ours  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Make This City Ours" ;
#         dcterms:creator                SoloMusicArtist:Claire_Martin ;
#         bibliographica:byArtist        SoloMusicArtist:Claire_Martin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ccb17bc7-cead-410e-b1ae-57aa99ba789e"^^xsd:anyURI .
#
# CDs:Amazulu  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Amazulu" ;
#         dcterms:creator                MusicGroup:Amazulu ;
#         bibliographica:byArtist        MusicGroup:Amazulu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/609cbe7e-fcb3-4965-a392-5cbb51f22b2c"^^xsd:anyURI .
#
# CDs:Hot_Dawg  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Dawg" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/afb060ab-3528-4d85-9e42-94cff7acc66e"^^xsd:anyURI .
#
# CDs:Blue_Aconite  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Aconite" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist        SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d5ec305f-193a-41eb-b93b-98b30f02d48d"^^xsd:anyURI .
#
# CDs:Those_Who_Know  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Those Who Know History Are Doomed to Repeat It" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/183216a8-6623-4f7e-8e46-e53c701258e6"^^xsd:anyURI .
#
# CDs:Turtles_Dream  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Turtle's Dream" ;
#         dcterms:creator                SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:byArtist        SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c415ccb6-432f-478e-ab9b-469231b6febb"^^xsd:anyURI .
#
# CDs:The_Last_Trane  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Last Trane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/14017672-f68b-4377-a99b-7ed9a1f6e19e"^^xsd:anyURI .
#
# CDs:What_a_Wonderful_World
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What a Wonderful World" ;
#         dcterms:creator                SoloMusicArtist:Willie_Nelson ;
#         bibliographica:byArtist        SoloMusicArtist:Willie_Nelson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cde578e1-758d-4f85-940b-1bbdd5ab3805"^^xsd:anyURI .
#
# CDs:Homenaje  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Homenaje" ;
#         dcterms:creator          MusicGroup:Artistas_Cubanos ;
#         bibliographica:byArtist  MusicGroup:Artistas_Cubanos .
#
# CDs:Dead_Men_Cant_Die  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Dead Men Can't Die" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Basement_Tapes  a                     mo:CD , mo:Record , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "The Basement Tapes" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan , MusicGroup:The_Band ;
#         bibliographica:byArtist        MusicGroup:The_Band , SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/47873729-6db0-3431-99e7-0292e939dadf"^^xsd:anyURI .
#
# CDs:Agua_de_Luna  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Agua de Luna" ;
#         dcterms:creator                SoloMusicArtist:Ruben_Blades ;
#         bibliographica:byArtist        SoloMusicArtist:Ruben_Blades ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9bd891c9-37e0-4bee-ba8f-4998cc392174"^^xsd:anyURI .
#
# CDs:Move_To_Groove  a                     mo:CD , mo:Record , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "The Move to the Groove Session" ;
#         dcterms:creator                MusicGroup:Heath_Brothers , SoloMusicArtist:Pat_Metheny ;
#         bibliographica:byArtist        MusicGroup:Heath_Brothers , SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7d299ae0-cba2-4ae1-9fa1-734ba982c5e4"^^xsd:anyURI .
#
# CDs:Black_Pearls  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Black Pearls" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/896beb5e-700b-3b68-9141-29bc9437ac69"^^xsd:anyURI .
#
# CDs:Theme_Time_Radio_Hour
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Theme Time Radio Hour" ;
#         dcterms:creator          MusicGroup:VariousDylan ;
#         bibliographica:byArtist  MusicGroup:VariousDylan ;
#         skos:related             SoloMusicArtist:Bob_Dylan .
#
# CDs:Best_of_John_Hammond
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best Of John Hammond" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/44586617-b6d9-437d-bbc5-3355e1cf0811"^^xsd:anyURI .
#
# CDs:Live_at_Royalty  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Royalty Theatre" ;
#         dcterms:creator                SoloMusicArtist:Sandy_Denny ;
#         bibliographica:byArtist        SoloMusicArtist:Sandy_Denny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e771cfaf-35a3-4dd0-8626-513ac2511c84"^^xsd:anyURI .
#
# CDs:Stumble_Into_Grace  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stumble Into Grace" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cc3c00a5-d6fd-43d2-add9-f9eaffd1fda4"^^xsd:anyURI .
#
# CDs:Red_and_Gold  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Red & Gold" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/00e36e59-d2cd-3339-8b16-cdeb609291a8"^^xsd:anyURI .
#
# CDs:Savoy_Brown_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Savoy Brown Collection" ;
#         dcterms:creator                MusicGroup:Savoy_Brown ;
#         bibliographica:byArtist        MusicGroup:Savoy_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dd457c2d-9b31-4883-bbfe-277b99b8df81"^^xsd:anyURI .
#
# CDs:Alone_Together  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Alone Together" ;
#         dcterms:creator                SoloMusicArtist:Dave_Mason ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Mason ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b689e03-03ae-4223-8e65-eb88e2b3a94b"^^xsd:anyURI .
#
# CDs:Kingfish_CD  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kingfish" ;
#         dcterms:creator                MusicGroup:Kingfish ;
#         bibliographica:byArtist        MusicGroup:Kingfish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ba793ccf-e648-4ad6-90f8-0d272606b5d7"^^xsd:anyURI .
#
# CDs:Kiko   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kiko" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8fd762a1-57c7-4560-9d63-9378c9e8198d"^^xsd:anyURI .
#
# CDs:Hymns_49th_Parallel  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hymns of the 49th Parallel" ;
#         dcterms:creator                SoloMusicArtist:KD_Lang ;
#         bibliographica:byArtist        SoloMusicArtist:KD_Lang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4115e2d2-27e8-4a7c-b43e-47b1381409ae"^^xsd:anyURI .
#
# CDs:Du_Jazz  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Du Jazz Dans Le Ravin" ;
#         dcterms:creator                SoloMusicArtist:Serge_Gainsbourg ;
#         bibliographica:byArtist        SoloMusicArtist:Serge_Gainsbourg ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/976dbda1-c41e-4515-a31a-f5c153b3c6bf"^^xsd:anyURI .
#
# CDs:Blue_Trane  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Trane: John Coltrane Plays the Blues" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b39536e-0aee-4e9d-92df-fb3c266b7ea4"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_22  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 22: Kings Beach Bowl, Kings Beach, Lake Tahoe, CA 2/23-24/68" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83b118e4-5a95-4904-b11b-7d4a038f57b8"^^xsd:anyURI .
#
# CDs:To_Terrapin_Hartford
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "To Terrapin: Hartford '77" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/96f38a95-6410-489e-a34b-61ba4da4ca4e"^^xsd:anyURI .
#
# CDs:Live_88  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live '88" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6869f25a-d581-4090-936e-8abe828bd302"^^xsd:anyURI .
#
# CDs:North_Star_Grassman  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The North Star Grassman and the Ravens" ;
#         dcterms:creator                SoloMusicArtist:Sandy_Denny ;
#         bibliographica:byArtist        SoloMusicArtist:Sandy_Denny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05c5458e-3b78-3f33-8c93-0911e8fdd315"^^xsd:anyURI .
#
# CDs:Aerial_Boundaries  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Aerial Boundaries" ;
#         dcterms:creator                SoloMusicArtist:Michael_Hedges ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Hedges ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2734a2ba-5df6-4863-88f7-4aa86fc332a7"^^xsd:anyURI .
#
# CDs:Draw_Them_Near  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Draw Them Near" ;
#         dcterms:creator                SoloMusicArtist:Jess_Klein ;
#         bibliographica:byArtist        SoloMusicArtist:Jess_Klein ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10af3ff8-cff8-4dfb-b30d-68c424034121"^^xsd:anyURI .
#
# CDs:Four_Sixty_One_Ocean_Blvd
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "461 Ocean Boulevard" ;
#         dcterms:creator                SoloMusicArtist:Eric_Clapton ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Clapton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a29ef6cf-df7b-393a-ad99-acff43d17181"^^xsd:anyURI .
#
# CDs:Carried_to_Dust  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Carried to Dust" ;
#         dcterms:creator                MusicGroup:Calexico ;
#         bibliographica:byArtist        MusicGroup:Calexico ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b83cc750-3ed1-458d-b7f8-a8bbb73e1d21"^^xsd:anyURI .
#
# CDs:Will_to_Live  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Will to Live" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/49249137-b123-4414-a196-3e8c77548ad3"^^xsd:anyURI .
#
# CDs:Calling_Card  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Calling Card" ;
#         dcterms:creator                SoloMusicArtist:Rory_Gallagher ;
#         bibliographica:byArtist        SoloMusicArtist:Rory_Gallagher ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/acfcfd68-ee32-323d-a608-f9d50ef5c5ee"^^xsd:anyURI .
#
# CDs:Billies_Best  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Billie’s Best" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2dd56925-4780-404d-b3d5-62987f4678c1"^^xsd:anyURI .
#
# CDs:Days_Like_This  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Days Like This" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6818f85b-ce05-4562-a732-9d2f83d8e302"^^xsd:anyURI .
#
# CDs:Boomers_Story  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Boomer's Story" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05c82074-8425-4c24-a832-69bda422055b"^^xsd:anyURI .
#
# CDs:Firin_in_Fouta  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Firin' in Fouta" ;
#         dcterms:creator                SoloMusicArtist:Baaba_Maal ;
#         bibliographica:byArtist        SoloMusicArtist:Baaba_Maal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9ad488a3-03da-4958-a7bb-f4c2176bae5b"^^xsd:anyURI .
#
# CDs:Live_in_Chateauvallon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live In Chateauvallon, 1972" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5d2910f3-fb1e-4e82-b700-b06a4101683d"^^xsd:anyURI .
#
# CDs:Traditional_Ties  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Traditional Ties" ;
#         dcterms:creator                MusicGroup:Hot_Rize ;
#         bibliographica:byArtist        MusicGroup:Hot_Rize ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eff7e4fa-f5ea-4ce6-8839-6963a5ca6c0d"^^xsd:anyURI .
#
# CDs:Hymns_To_Silence  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hymns to the Silence" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bb62a753-cf14-47d2-8431-405c924db045"^^xsd:anyURI .
#
# CDs:Jazzmatazz_Vol_1  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazzmatazz, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:Guru ;
#         bibliographica:byArtist        SoloMusicArtist:Guru ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b249a0bc-6ca9-476c-94c1-67c272ad7a58"^^xsd:anyURI .
#
# CDs:World_Out_of_Time_3  a                mo:Record , mo:Release , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "A World Out of Time, Volume 3: Music of Madagascar" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley , SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley , SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dbaf69a6-9a19-479c-a9bf-75c603351d75"^^xsd:anyURI .
#
# CDs:Just_Like_You  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Just Like You" ;
#         dcterms:creator                SoloMusicArtist:Keb_Mo ;
#         bibliographica:byArtist        SoloMusicArtist:Keb_Mo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/0360c55f-8b6d-3b4c-a564-9a7646240c2e"^^xsd:anyURI .
#
# CDs:This_Land  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Land" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1cc59083-6a89-4836-81a2-90956775c714"^^xsd:anyURI .
#
# CDs:Recorded_Live_Prelude
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Recorded Live at the Prelude (1960)" ;
#         dcterms:creator          SoloMusicArtist:Billy_Taylor ;
#         bibliographica:byArtist  SoloMusicArtist:Billy_Taylor .
#
# CDs:The_Peel_Session_Album
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Peel Session Album" ;
#         dcterms:creator                SoloMusicArtist:Billy_Bragg ;
#         bibliographica:byArtist        SoloMusicArtist:Billy_Bragg ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8fc495a8-129d-404f-a7e5-9fba28997c3f"^^xsd:anyURI .
#
# CDs:Old_Testaments  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Old Testaments & New Revelations" ;
#         dcterms:creator                SoloMusicArtist:Kinky_Friedman ;
#         bibliographica:byArtist        SoloMusicArtist:Kinky_Friedman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d85ca1cb-2285-3421-99e6-4096de345240"^^xsd:anyURI .
#
# CDs:Four_Way_Street  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "4 Way Street" ;
#         dcterms:creator                MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:byArtist        MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0adb00ae-d2f6-4e33-8394-aff5d89c9adb"^^xsd:anyURI .
#
# CDs:Live_in_Hamburg  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Hamburg" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e1d9d6e2-4994-4a66-a045-51b32ff3c840"^^xsd:anyURI .
#
# CDs:Jonathan_Edwards_CD  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jonathan Edwards" ;
#         dcterms:creator                SoloMusicArtist:Jonathan_Edwards ;
#         bibliographica:byArtist        SoloMusicArtist:Jonathan_Edwards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9489083-2071-4332-930d-3ffdbb1d4917"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_9  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 9: Madison Square Garden 9/16/90" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05fcf2e7-a108-4b78-96ee-d8f9d82f4a3f"^^xsd:anyURI .
#
# CDs:Live_at_Red_Rocks  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Red Rocks" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/439142c6-4da6-4659-b497-321a60087ee6"^^xsd:anyURI .
#
# CDs:Hits   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hits" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/999e6a8e-374c-41ab-864b-78527f8f8166"^^xsd:anyURI .
#
# CDs:Freedom_of_Choice  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Freedom of Choice" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/977d7c01-a90c-4815-b01e-4b0fbb139a6c"^^xsd:anyURI .
#
# CDs:Yell_Fire  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yell Fire" ;
#         dcterms:creator                SoloMusicArtist:Michael_Franti ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Franti ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/08a62e01-a89f-432c-ba97-89efeea39dac"^^xsd:anyURI .
#
# CDs:Up_Up_Up_Up_Up_Up  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Up Up Up Up Up Up" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/07a48cd5-2fd5-3c3f-b61b-569ecd2c86e0"^^xsd:anyURI .
#
# CDs:Little_Plastic_Castle
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Little Plastic Castle" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/585b0223-d5a5-3839-880f-590a64a62bc7"^^xsd:anyURI .
#
# CDs:Night_Ride_Home  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Night Ride Home" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05a029a5-2b7d-3f20-8184-39e9927aa526"^^xsd:anyURI .
#
# CDs:The_Evening_My_Best_Day
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Evening of My Best Day" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38105434-2eef-4cd9-a216-ad7bcf441ac7"^^xsd:anyURI .
#
# CDs:Slow_Circle  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slow Circle" ;
#         dcterms:creator                SoloMusicArtist:Alex_de_Grassi ;
#         bibliographica:byArtist        SoloMusicArtist:Alex_de_Grassi ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/63e51a74-53c0-3b9b-bf4c-4ab15734967c"^^xsd:anyURI .
#
# CDs:Black_Saint_Sinner  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Black Saint & the Sinner Lady" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d1b8d7db-2808-4255-8056-678b3fd1e5e2"^^xsd:anyURI .
#
# CDs:Black_Sheets  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Black Sheets of Rain" ;
#         dcterms:creator                SoloMusicArtist:Bob_Mould ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Mould ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cb385205-868d-3ae1-b52e-7525a5111c04"^^xsd:anyURI .
#
# CDs:Things_To_Remember  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Things To Remember" ;
#         dcterms:creator                SoloMusicArtist:Willie_Nelson ;
#         bibliographica:byArtist        SoloMusicArtist:Willie_Nelson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/370a4011-025f-41dc-967e-9f7e048f975c"^^xsd:anyURI .
#
# CDs:Black_Sand_Shore  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Black Sand Shore" ;
#         dcterms:creator          SoloMusicArtist:Grace ;
#         bibliographica:byArtist  SoloMusicArtist:Grace .
#
# CDs:Nothing_But_Burning_Light
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nothing But a Burning Light" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/49fb19c2-b8a3-3462-94ba-8847841024ce"^^xsd:anyURI .
#
# CDs:Days_Future_Passed  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Days of Future Passed" ;
#         dcterms:creator                MusicGroup:Moody_Blues ;
#         bibliographica:byArtist        MusicGroup:Moody_Blues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/11b50920-aef2-38a1-94e8-766157b6bed6"^^xsd:anyURI .
#
# CDs:Sorcerer  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sorcerer" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/30562d07-82e7-4cec-a16f-b407550210ff"^^xsd:anyURI .
#
# CDs:Johnny_Cash_at_MSG  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Johnny Cash at Madison Square Garden" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bc009fea-0933-4d00-9ec9-8ae385de3641"^^xsd:anyURI .
#
# CDs:The_Modern_Lovers  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Modern Lovers" ;
#         dcterms:creator                MusicGroup:Modern_Lovers ;
#         bibliographica:byArtist        MusicGroup:Modern_Lovers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/caf21f2d-3bc5-4313-9126-902a2ae45851"^^xsd:anyURI .
#
# CDs:Bebel_Gilberto_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bebel Gilberto (CD)" ;
#         dcterms:creator                SoloMusicArtist:Bebel_Gilberto ;
#         bibliographica:byArtist        SoloMusicArtist:Bebel_Gilberto ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2c996e0f-e8c2-3167-894c-ab59a7c74989"^^xsd:anyURI .
#
# CDs:Anything_Anytime_Anywhere
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anything Anytime Anywhere (Singles 1979-2002)" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a570c094-2522-3717-8236-1b6cf1863536"^^xsd:anyURI .
#
# CDs:Two_Hundred_Miles  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "200 More Miles" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f875da30-52f0-4990-b584-636340fa87fe"^^xsd:anyURI .
#
# CDs:Dear_Heather  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dear Heather" ;
#         dcterms:creator                SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:byArtist        SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c15c2b7f-0164-439b-af47-be1c474e4446"^^xsd:anyURI .
#
# CDs:Charles_Mingus_Friends
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Charles Mingus And Friends In Concert" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d461c131-c94d-4ea5-adc9-dedce780d69a"^^xsd:anyURI .
#
# CDs:Radio_One  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Radio One" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8935134e-3584-4267-971e-1e8e6fba5263"^^xsd:anyURI .
#
# CDs:Miles_of_Aisles  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles of Aisles" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7cdd1abc-d3ff-34b7-b68d-395b421ccb4b"^^xsd:anyURI .
#
# CDs:St_Dominics_Preview  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Saint Dominic’s Preview" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92f27292-5be9-36fb-af96-2a434d1bdb7c"^^xsd:anyURI .
#
# CDs:Talking_Timbuktu  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Talking Timbuktu" ;
#         dcterms:creator                SoloMusicArtist:Ali_Farka_Toure ;
#         bibliographica:byArtist        SoloMusicArtist:Ali_Farka_Toure ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1e54dda5-c64b-42e8-9eed-ed50639e134b"^^xsd:anyURI .
#
# CDs:Go_Fer_Your_Funk  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Go Fer Yer Funk, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:George_Clinton ;
#         bibliographica:byArtist        SoloMusicArtist:George_Clinton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/228f54c1-56e8-4952-bf0a-3df1b6e0d95a"^^xsd:anyURI .
#
# CDs:Infidels  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Infidels" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/60f27712-263a-348c-8eda-b5315a67e8c2"^^xsd:anyURI .
#
# CDs:Interstate_City  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Interstate City" ;
#         dcterms:creator                MusicGroup:Dave_Alvin_Guilty_Men ;
#         bibliographica:byArtist        MusicGroup:Dave_Alvin_Guilty_Men ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aaf69fd9-e60c-495e-ad54-f50b50bec59f"^^xsd:anyURI .
#
# CDs:Retrospective  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Retrospective" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86e55f2d-617c-4daa-a91b-46ee5db96c72"^^xsd:anyURI .
#
# CDs:The_Town_and_City  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Town and the City" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ae2fd95-f2db-406f-a375-a183716b286e"^^xsd:anyURI .
#
# CDs:Fumbling_Towards_Ecstasy
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fumbling Towards Ecstasy" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10f4de1d-7fed-47d2-8dd6-eff8aac0ec2d"^^xsd:anyURI .
#
# CDs:To_Kingdom_Come  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "To Kingdom Come" ;
#         dcterms:creator                MusicGroup:The_Band ;
#         bibliographica:byArtist        MusicGroup:The_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e2e80584-2c2f-488d-983b-6292f04f3598"^^xsd:anyURI .
#
# CDs:Wavelength  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wavelength" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8382dc5e-4bc6-4d80-87a4-0d6b1b7df1c1"^^xsd:anyURI .
#
# CDs:At_Golden_Circle  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At the Golden Circle, Volume One" ;
#         dcterms:creator                SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:byArtist        SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/601cbbc7-a873-4e2e-9b8a-dacc49b84d27"^^xsd:anyURI .
#
# CDs:Payin_Dues  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Payin' Dues" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3ef90d5b-4406-4649-8867-c8595b3a4282"^^xsd:anyURI .
#
# CDs:Not_For_Kids_Only  a                  mo:CD , mo:Release , mo:Record , schema:MusicAlbum ;
#         rdfs:label                     "Not For Kids Only" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ef633c3-f345-4d86-a52a-3a55b4509a3f"^^xsd:anyURI .
#
# CDs:Blue_Pony  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Pony" ;
#         dcterms:creator                SoloMusicArtist:Julie_Miller ;
#         bibliographica:byArtist        SoloMusicArtist:Julie_Miller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5c2103db-5dab-469f-9697-02c9e542ad4a"^^xsd:anyURI .
#
# CDs:Nightcap  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nightcap: The Unreleased Masters 1973–1991" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c2b5b2e5-ede5-3b6e-9eec-8b6eae2468fe"^^xsd:anyURI .
#
# CDs:Verve_Masters_Stan_Getz
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Verve Jazz Masters 8: Stan Getz" ;
#         dcterms:creator                SoloMusicArtist:Stan_Getz ;
#         bibliographica:byArtist        SoloMusicArtist:Stan_Getz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0aa514bf-5be2-475a-ac1b-0222f9d4c881"^^xsd:anyURI .
#
# CDs:Wish_You_Were_Here  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wish You Were Here" ;
#         dcterms:creator                MusicGroup:Pink_Floyd ;
#         bibliographica:byArtist        MusicGroup:Pink_Floyd ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d578454b-f725-33a0-afee-7bd82f33588f"^^xsd:anyURI .
#
# CDs:Hey_Man_Smell_My_Finger
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hey Man... Smell My Finger" ;
#         dcterms:creator                SoloMusicArtist:George_Clinton ;
#         bibliographica:byArtist        SoloMusicArtist:George_Clinton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9a5e3b0-69b2-4584-a29b-b383286d9f1a"^^xsd:anyURI .
#
# CDs:Dead_at_Cornell  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dead at Cornell 5.8.77" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aa0d7d7e-1d78-4f78-ba03-7a32c200f660"^^xsd:anyURI .
#
# CDs:Son_of_the_Wind  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Son of the Wind" ;
#         dcterms:creator                SoloMusicArtist:Arlo_Guthrie ;
#         bibliographica:byArtist        SoloMusicArtist:Arlo_Guthrie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e981afd2-c54b-4023-8c37-1b78ac69bfeb"^^xsd:anyURI .
#
# CDs:Strange_Fire  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strange Fire" ;
#         dcterms:creator                MusicGroup:Indigo_Girls ;
#         bibliographica:byArtist        MusicGroup:Indigo_Girls ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ac8156a0-3953-4d89-9101-c70c678c5165"^^xsd:anyURI .
#
# CDs:Relix_Bay_Rock_Shop  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Relix Bay Rock Shop, Volume 3: Part 1" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e17f6c5e-0436-4299-9791-ee509be18367"^^xsd:anyURI .
#
# CDs:Id_Like_a_Virgin  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I'd Like a Virgin" ;
#         dcterms:creator                SoloMusicArtist:Richard_Cheese ;
#         bibliographica:byArtist        SoloMusicArtist:Richard_Cheese ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ed2498fe-7fe2-4c24-99f4-05dd2bbea157"^^xsd:anyURI .
#
# CDs:Lamb_Lies_Down_Broadway
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lamb Lies Down on Broadway" ;
#         dcterms:creator                MusicGroup:Genesis ;
#         bibliographica:byArtist        MusicGroup:Genesis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05d1e408-2d0c-49ce-97ca-5b7bdc308b9c"^^xsd:anyURI .
#
# CDs:When_I_Was_Cruel  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "When I Was Cruel" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bedd4ab5-d28b-4792-a9d6-84e91d6f0149"^^xsd:anyURI .
#
# CDs:Newport_63  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Newport '63" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c20373dd-3767-4b62-8328-3e135d4198da"^^xsd:anyURI .
#
# CDs:I_Do_Not_Want  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I Do Not Want What I Haven't Got" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92f17814-57bb-4c9b-8948-fee1f0677472"^^xsd:anyURI .
#
# CDs:In_Person_On_Stage  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Person & On Stage" ;
#         dcterms:creator                SoloMusicArtist:John_Prine ;
#         bibliographica:byArtist        SoloMusicArtist:John_Prine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/19709fd2-ac39-4184-973c-673e7db00472"^^xsd:anyURI .
#
# CDs:Honey_Lions_Head  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Honey in the Lion's Head" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/518b738b-a47c-48f9-ad66-b90df93c1c73"^^xsd:anyURI .
#
# CDs:Live_Toulouse  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live (Toulouse Bluegrass Festival)" ;
#         dcterms:creator                MusicGroup:New_Grass_Revival ;
#         bibliographica:byArtist        MusicGroup:New_Grass_Revival ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6b86902-8881-4bea-9f81-b87853687921"^^xsd:anyURI .
#
# CDs:Mystic_Dreams  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mystic Dreams" ;
#         dcterms:creator                MusicGroup:Danu ;
#         bibliographica:byArtist        MusicGroup:Danu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b60975b-2aca-4c16-bfbb-aba2aca446e4"^^xsd:anyURI .
#
# CDs:ReEntry  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Re-Entry" ;
#         dcterms:creator                SoloMusicArtist:Horace_Silver ;
#         bibliographica:byArtist        SoloMusicArtist:Horace_Silver ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a61ffb05-9ebc-4079-b302-4dba349415fc"^^xsd:anyURI .
#
# CDs:Making_Movies  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Making Movies" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c5d981c9-b044-487c-9a0c-b3af72802c43"^^xsd:anyURI .
#
# CDs:Rise_and_Fall_Ziggy_Stardust
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Rise and Fall of Ziggy Stardust and the Spiders From Mars" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34763364-8570-33ab-8618-65d05cb87f6e"^^xsd:anyURI .
#
# CDs:Tales_Gil_Scott_Heron
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tales of Gil Scott-Heron" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/edae5047-b350-43e8-b75e-44469458c746"^^xsd:anyURI .
#
# CDs:Showdown  a                           schema:MusicAlbum , mo:Record , mo:Release , mo:CD ;
#         rdfs:label                     "Showdown!" ;
#         dcterms:creator                SoloMusicArtist:Albert_Collins , SoloMusicArtist:Johnny_Copeland , SoloMusicArtist:Robert_Cray ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Cray , SoloMusicArtist:Johnny_Copeland , SoloMusicArtist:Albert_Collins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a4e3c15f-4052-49e8-9787-9b7d5d53aefc"^^xsd:anyURI .
#
# CDs:Fanning_the_Flames  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fanning the Flames" ;
#         dcterms:creator                SoloMusicArtist:Maria_Muldaur ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_Muldaur ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/39c60bf4-73ad-425c-ba86-0afc870f907d"^^xsd:anyURI .
#
# CDs:Really  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Really" ;
#         dcterms:creator                SoloMusicArtist:JJ_Cale ;
#         bibliographica:byArtist        SoloMusicArtist:JJ_Cale ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8b903798-53f7-409d-bcad-9ce4db46c921"^^xsd:anyURI .
#
# CDs:Lyle_Lovett_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lyle Lovett" ;
#         dcterms:creator                SoloMusicArtist:Lyle_Lovett ;
#         bibliographica:byArtist        SoloMusicArtist:Lyle_Lovett ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8fcbb190-d993-4bf3-bac2-05512bcab6a7"^^xsd:anyURI .
#
# CDs:Life_On_Bottom  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Life on the Bottom" ;
#         dcterms:creator                MusicGroup:Halibuts ;
#         bibliographica:byArtist        MusicGroup:Halibuts ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eb96cb63-6815-46d6-a3c8-beb1837527a9"^^xsd:anyURI .
#
# CDs:First_Circle  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "First Circle" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1095fab2-8acf-40c1-9d30-dd955500d6d4"^^xsd:anyURI .
#
# CDs:You_Cant_Do_That_On_Stage_v5
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 5" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5f9e6c1-e42d-4a39-820f-43e64b58c29b"^^xsd:anyURI .
#
# CDs:In_the_Moment  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Moment" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8a759e23-76e4-4a97-88f6-20c8cd78f6c8"^^xsd:anyURI .
#
# CDs:Mile_Marker  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Mile Marker" ;
#         dcterms:creator          SoloMusicArtist:Ana_Egge ;
#         bibliographica:byArtist  SoloMusicArtist:Ana_Egge .
#
# CDs:Beneath_Gruff_Exterior
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Beneath This Gruff Exterior" ;
#         dcterms:creator                SoloMusicArtist:John_Hiatt ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hiatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b7c89c38-4e68-4820-9bfc-499832b387ed"^^xsd:anyURI .
#
# CDs:Mambo_Sinuendo  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mambo Sinuendo" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4d90c45e-691e-4723-aaa2-26f576c7e64a"^^xsd:anyURI .
#
# CDs:Tanto_Tempo  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tanto Tempo" ;
#         dcterms:creator                SoloMusicArtist:Bebel_Gilberto ;
#         bibliographica:byArtist        SoloMusicArtist:Bebel_Gilberto ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/27b97cd4-5ab6-3a6f-a1f1-edbc6248e5c9"^^xsd:anyURI .
#
# CDs:Live_Dead  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9ab55bce-4aef-31dc-b3db-701b53f0d9e2"^^xsd:anyURI .
#
# CDs:Blue_Ridge  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Ridge" ;
#         dcterms:creator                SoloMusicArtist:Jonathan_Edwards ;
#         bibliographica:byArtist        SoloMusicArtist:Jonathan_Edwards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/396657da-b49e-4d6e-a5d8-4876ef4aa129"^^xsd:anyURI .
#
# CDs:Ask_The_Fish  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ask the Fish" ;
#         dcterms:creator                MusicGroup:Leftover_Salmon ;
#         bibliographica:byArtist        MusicGroup:Leftover_Salmon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b2f58a79-088f-4b1a-8355-1bd7e8ba0175"^^xsd:anyURI .
#
# CDs:Eternity_Blue  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eternity Blue" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3ee5f2a-c8d3-4e7d-92f8-600f6ade6d89"^^xsd:anyURI .
#
# CDs:Homecoming_Village  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Homecoming, Live At The Village Vanguard" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2813136-2495-4fd8-bff0-f473c0b11fd6"^^xsd:anyURI .
#
# CDs:Ultra_Hi_Fidelity  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:comment                   "A bonus CD from While You Weren't Looking" ;
#         rdfs:label                     "Ultra Hi-Fidelity" ;
#         dcterms:creator                SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:byArtist        SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/284ce5a4-1b89-4e35-9bf4-e9058736747a"^^xsd:anyURI .
#
# CDs:Red_Rocks_78  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Red Rocks 7-8-78" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/933ad42b-7d73-491e-92c4-a056803e697f"^^xsd:anyURI .
#
# CDs:Misty_Eyed_Adventures
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Misty Eyed Adventures" ;
#         dcterms:creator                SoloMusicArtist:Maire_Brennan ;
#         bibliographica:byArtist        SoloMusicArtist:Maire_Brennan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e85bf538-9976-4d2e-9238-c32352a1a4d6"^^xsd:anyURI .
#
# CDs:World_Gone_Wrong  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "World Gone Wrong" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3cba7f03-13b4-4c2c-9307-f8dc3db4a678"^^xsd:anyURI .
#
# CDs:Pay_The_Devil  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pay the Devil" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/958f38b3-e709-32fc-bdf6-5239217afda3"^^xsd:anyURI .
#
# CDs:Shining_Star  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shining Star" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a39c36e8-88f3-4977-a6e5-fd96908da3f0"^^xsd:anyURI .
#
# CDs:The_Winds_Begin_Sing
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Winds Begin to Sing" ;
#         dcterms:creator                SoloMusicArtist:Karan_Casey ;
#         bibliographica:byArtist        SoloMusicArtist:Karan_Casey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f7606328-dc46-4cbd-bb85-fa226a8ef235"^^xsd:anyURI .
#
# CDs:Allies  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Allies" ;
#         dcterms:creator                MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:byArtist        MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/caa689c7-3a25-41a9-aa54-dd48a2e0fa06"^^xsd:anyURI .
#
# CDs:Ultimate_Anita_O-Day
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ultimate Anita O'Day" ;
#         dcterms:creator                SoloMusicArtist:Anita_O_Day ;
#         bibliographica:byArtist        SoloMusicArtist:Anita_O_Day ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/68c030aa-d70b-4c14-92bb-feebcca9eb6f"^^xsd:anyURI .
#
# CDs:Caberet_Diosa_CD  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cajun Conja" ;
#         dcterms:creator                MusicGroup:Caberet_Diosa ;
#         bibliographica:byArtist        MusicGroup:Caberet_Diosa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d0bda965-b993-4a69-a128-f246531287f6"^^xsd:anyURI .
#
# CDs:Travels  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Travels" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7c2b1fd2-d590-4052-b351-b73ad9b0aa52"^^xsd:anyURI .
#
# CDs:Rat_Patrol_Ft_Bragg  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rat Patrol From Fort Bragg" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f3330aa5-4047-4a2d-996f-7e82fe2374e5"^^xsd:anyURI .
#
# CDs:Born_Under_Bad_Sign  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Born Under a Bad Sign" ;
#         dcterms:creator                SoloMusicArtist:Albert_King ;
#         bibliographica:byArtist        SoloMusicArtist:Albert_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9fa36ff8-ba96-3201-bda1-729389a87620"^^xsd:anyURI .
#
# CDs:Intimate_Barrios  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Intimate Barrios" ;
#         dcterms:creator                SoloMusicArtist:Berta_Rojas ;
#         bibliographica:byArtist        SoloMusicArtist:Berta_Rojas ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/96cd9411-8899-4866-8189-841848f6f7dd"^^xsd:anyURI .
#
# CDs:Miles_Miles_Miles  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles! Miles! Miles! : Live in Japan" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b790eec-a7b4-43a1-86eb-56fc1f894aff"^^xsd:anyURI .
#
# CDs:Steppin_Out_England_72
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Steppin' Out With the Grateful Dead: England '72" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/134a2bea-2c61-47d3-9403-cf7581512e88"^^xsd:anyURI .
#
# CDs:Shelter  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shelter" ;
#         dcterms:creator                MusicGroup:Lone_Justice ;
#         bibliographica:byArtist        MusicGroup:Lone_Justice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ff60dab1-b459-4732-a188-93018485224d"^^xsd:anyURI .
#
# CDs:Unplugged_Nirv  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unplugged in New York" ;
#         dcterms:creator                MusicGroup:Nirvana ;
#         bibliographica:byArtist        MusicGroup:Nirvana ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2ff3be28-f74f-40c9-bdde-c19b6e4384ee"^^xsd:anyURI .
#
# CDs:Small_Source_of_Comfort
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Small Source of Comfort" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/2cd80143-986c-480d-867e-3cd90ddea154"^^xsd:anyURI .
#
# CDs:Die_Grossen_Tangos  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Die Grossen Tangos" ;
#         dcterms:creator                MusicGroup:Alfred_Hause_Tango_Orchestra ;
#         bibliographica:byArtist        MusicGroup:Alfred_Hause_Tango_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3609ac3b-8fce-426c-a08a-b04ee69c3cbd"^^xsd:anyURI .
#
# CDs:Twenty_Four_Hour_Concierge
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "24 Hour Concierge" ;
#         dcterms:creator          SoloMusicArtist:Jim_McCaffrey ;
#         bibliographica:byArtist  SoloMusicArtist:Jim_McCaffrey .
#
# CDs:Year_of_the_Cat  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Year of the Cat" ;
#         dcterms:creator                SoloMusicArtist:Al_Stewart ;
#         bibliographica:byArtist        SoloMusicArtist:Al_Stewart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8f195fea-549e-4659-97a8-d9e619361ab0"^^xsd:anyURI .
#
# CDs:Bitches_Brew  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bitches Brew" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d1759292-f663-4366-8317-9dcd821babfc"^^xsd:anyURI .
#
# CDs:Tori_and_Her_Mask  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tori And Her Mask (disc 1)" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cc59fc2d-a733-43f3-9c5d-911dba436f67"^^xsd:anyURI .
#
# CDs:Slide_Dropdown_D  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slide on Dropdown D" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/24940aba-ee1b-4c99-90f8-3e9b8bfca90c"^^xsd:anyURI .
#
# CDs:Gershwins_World  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gershwin's World" ;
#         dcterms:creator                SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:byArtist        SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/43f62d3f-65ff-3432-af96-e1898340b7a8"^^xsd:anyURI .
#
# CDs:Live_on_Planet_Earth
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live on Planet Earth" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c185f59d-a5fb-4bdb-a388-02a55b8eb230"^^xsd:anyURI .
#
# CDs:Live_at_Sahara_Tahoe
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Sahara Tahoe" ;
#         dcterms:creator                SoloMusicArtist:Isaac_Hayes ;
#         bibliographica:byArtist        SoloMusicArtist:Isaac_Hayes ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f39437a9-fb5b-4202-8e9c-07269a2dc131"^^xsd:anyURI .
#
# CDs:Turf   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Turf" ;
#         dcterms:creator                SoloMusicArtist:Luka_Bloom ;
#         bibliographica:byArtist        SoloMusicArtist:Luka_Bloom ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ab11f948-32bd-373b-a397-8d966ca16928"^^xsd:anyURI .
#
# CDs:Slightly_Haunted  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slightly Haunted" ;
#         dcterms:creator                SoloMusicArtist:Lynn_Miles ;
#         bibliographica:byArtist        SoloMusicArtist:Lynn_Miles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8974385f-25fc-4baf-8395-01c0fa41877a"^^xsd:anyURI .
#
# CDs:Running_Scared  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Running Scared" ;
#         dcterms:creator                SoloMusicArtist:Exene_Cervenka ;
#         bibliographica:byArtist        SoloMusicArtist:Exene_Cervenka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/370a64f8-4762-4a05-8693-8cf5252906b4"^^xsd:anyURI .
#
# CDs:Mitakuye_Oyasin  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mitakuye Oyasin Oyasin (All My Relations)" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4caabff5-6a38-4002-9284-550c3d5c6d3a"^^xsd:anyURI .
#
# CDs:You_Were_Here  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Were Here" ;
#         dcterms:creator                SoloMusicArtist:Sarah_Harmer ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_Harmer ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be8ea099-7d30-45c4-8b86-fb5d5238d339"^^xsd:anyURI .
#
# CDs:Miles_in_the_Sky  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles in the Sky" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2b24087e-3695-49de-9815-2a94d105da50"^^xsd:anyURI .
#
# CDs:Home   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Home" ;
#         dcterms:creator                SoloMusicArtist:Michael_Franti ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Franti ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ccf6beb3-a589-409f-bf03-e577d347e42f"^^xsd:anyURI .
#
# CDs:TB_Sheets  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "T.B. Sheets" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5e824071-d6dd-31c7-b60e-116a2f2fc779"^^xsd:anyURI .
#
# CDs:Complete_Savoy_Sessions
#         a                              mo:CD , mo:Record , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "The Complete Savoy Sessions" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane , SoloMusicArtist:Wilbur_Harden ;
#         bibliographica:byArtist        SoloMusicArtist:Wilbur_Harden , SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d65a76a3-a44e-4c17-9d3d-904dcfab9a5a"^^xsd:anyURI .
#
# CDs:Man_Music  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Man and His Music" ;
#         dcterms:creator                SoloMusicArtist:Sam_Bush ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Bush ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/597577a8-05d3-4b45-9754-0162661cffdd"^^xsd:anyURI .
#
# CDs:Traffic_From_Paradise
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Traffic From Paradise" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/16385add-9084-44a3-a746-244fe7544a7e"^^xsd:anyURI .
#
# CDs:Majikat  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Majikat: Earth Tour 1976" ;
#         dcterms:creator                SoloMusicArtist:Cat_Stevens ;
#         bibliographica:byArtist        SoloMusicArtist:Cat_Stevens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e9bd451-1017-4f70-8d31-f7bb8e61b95f"^^xsd:anyURI .
#
# CDs:Heroes  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Heroes" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8caa9a0e-9063-3497-b73e-3165ea2f75a6"^^xsd:anyURI .
#
# CDs:Blues_Roots  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blues & Roots" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6843d7b4-e99a-4748-a4c8-5bc87a494262"^^xsd:anyURI .
#
# CDs:Perro  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Perro" ;
#         dcterms:creator          SoloMusicArtist:Paul_Kantner ;
#         bibliographica:byArtist  SoloMusicArtist:Paul_Kantner .
#
# CDs:Paradise_Lunch  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Paradise & Lunch" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9964568f-8da7-33cd-815a-eae1eef4d30b"^^xsd:anyURI .
#
# CDs:Little_Queen  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Little Queen" ;
#         dcterms:creator                MusicGroup:Heart ;
#         bibliographica:byArtist        MusicGroup:Heart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f14c6b7a-382c-42a2-a7bc-e4aff3891d72"^^xsd:anyURI .
#
# CDs:My_Baby_Dont_Wear_Shoes
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "My Baby Don't Wear No Shoes" ;
#         dcterms:creator                SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:byArtist        SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eeaa31c9-056c-4d06-8f3c-909fbf7d18ce"^^xsd:anyURI .
#
# CDs:Rickie_Lee_Jones_CD  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rickie Lee Jones" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dad30215-3b7c-48cc-8086-006b6c8051fa"^^xsd:anyURI .
#
# CDs:Rise_Up_Like_Sun  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rise Up Like The Sun" ;
#         dcterms:creator                MusicGroup:Albion_Country_Band ;
#         bibliographica:byArtist        MusicGroup:Albion_Country_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b42cf846-b4a9-46a6-84fd-d5ae129beca7"^^xsd:anyURI .
#
# CDs:No_Quarter  a                         mo:Release , schema:MusicAlbum , mo:CD , mo:Record ;
#         rdfs:label                     "No Quarter - Unledded" ;
#         dcterms:creator                SoloMusicArtist:Jimmy_Page , SoloMusicArtist:Robert_Plant ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Plant , SoloMusicArtist:Jimmy_Page ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6f75f697-346b-499d-8ef8-55cee0e49159"^^xsd:anyURI .
#
# CDs:Pop_Pop  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pop Pop" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/71709dc1-8f41-4404-a55a-0ae72b7e906f"^^xsd:anyURI .
#
# CDs:Plantation_Lullabies
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plantation Lullabies" ;
#         dcterms:creator                SoloMusicArtist:Meshell_Ndegeocello ;
#         bibliographica:byArtist        SoloMusicArtist:Meshell_Ndegeocello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9dcd1190-36ac-40ef-bb98-f4bfabe51e2a"^^xsd:anyURI .
#
# CDs:Live_Art  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live Art" ;
#         dcterms:creator                MusicGroup:Bela_Fleck_and_the_Flecktones ;
#         bibliographica:byArtist        MusicGroup:Bela_Fleck_and_the_Flecktones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/61282502-0f84-4c30-aea1-90b9e823107c"^^xsd:anyURI .
#
# CDs:Nick_of_Time  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nick of Time" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32fdca94-c832-4f04-96b2-701d17223853"^^xsd:anyURI .
#
# CDs:Living_Space  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Living Space" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3ec0ff23-08e3-48ab-92b7-e68ff60d9c72"^^xsd:anyURI .
#
# CDs:Built_to_Last  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Built to Last" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d6c92867-ef82-4932-956c-7844bf97582f"^^xsd:anyURI .
#
# CDs:Red_Dog_Blues  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Red Dog Blues" ;
#         dcterms:creator          SoloMusicArtist:Michael_Fracasso ;
#         bibliographica:byArtist  SoloMusicArtist:Michael_Fracasso .
#
# CDs:Circles_Round  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Circle in the Round" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/61ddef65-836b-3136-9ae6-53d9c9e48ad8"^^xsd:anyURI .
#
# CDs:Sings_Cole_Porter  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ella Fitzgerald Sings the Cole Porter Song Book" ;
#         dcterms:creator                SoloMusicArtist:Ella_Fitzgerald ;
#         bibliographica:byArtist        SoloMusicArtist:Ella_Fitzgerald ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d235f8b1-84c0-4b82-8f1a-4363d0091968"^^xsd:anyURI .
#
# CDs:Jazz   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8dc73edb-dcaf-45f0-9a95-35b81755f205"^^xsd:anyURI .
#
# CDs:Reveries  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Reveries" ;
#         dcterms:creator                SoloMusicArtist:Paolo_Conte ;
#         bibliographica:byArtist        SoloMusicArtist:Paolo_Conte ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9fb2f9f-ae8c-490c-949f-ec7bf1373266"^^xsd:anyURI .
#
# CDs:Peculiaroso  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peculiaroso" ;
#         dcterms:creator                SoloMusicArtist:Leo_Kottke ;
#         bibliographica:byArtist        SoloMusicArtist:Leo_Kottke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4401db6d-6ea1-466a-81a1-4dd6af2c3b45"^^xsd:anyURI .
#
# CDs:Essential_Larry_Coryell
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Essential Larry Coryell" ;
#         dcterms:creator                SoloMusicArtist:Larry_Coryell ;
#         bibliographica:byArtist        SoloMusicArtist:Larry_Coryell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0bd4099c-4bae-4e47-b3d0-421d7acb0568"^^xsd:anyURI .
#
# CDs:American_Garage  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American Garage" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5119fe43-dfdc-3182-bfc5-0e8b87baf716"^^xsd:anyURI .
#
# CDs:Desire_Of_The_Rhino_King
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Desire Of The Rhino King" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0396203d-228f-4d43-9e1b-a311d2796916"^^xsd:anyURI .
#
# CDs:Bug_Toast_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Bug Toast" ;
#         dcterms:creator          MusicGroup:Bug_Toast ;
#         bibliographica:byArtist  MusicGroup:Bug_Toast .
#
# CDs:Old_In_the_Way_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Old & In The Way" ;
#         dcterms:creator                MusicGroup:Old_In_the_Way ;
#         bibliographica:byArtist        MusicGroup:Old_In_the_Way ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7814430b-7fb3-4213-8d05-34c812d82deb"^^xsd:anyURI .
#
# CDs:Wayward_Angel  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wayward Angel" ;
#         dcterms:creator                SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:byArtist        SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91731a50-03ca-4cf3-a434-a779734e0c47"^^xsd:anyURI .
#
# CDs:Walls_and_Bridges  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Walls and Bridges" ;
#         dcterms:creator                SoloMusicArtist:John_Lennon ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lennon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/54c153f9-6df9-469b-af40-8358737c050e"^^xsd:anyURI .
#
# CDs:Walkabout  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Walkabout" ;
#         dcterms:creator          MusicGroup:Nomad ;
#         bibliographica:byArtist  MusicGroup:Nomad .
#
# CDs:Live_Last_Troubador  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live: The Last of HC Troubador" ;
#         dcterms:creator          SoloMusicArtist:Steve_Earle ;
#         bibliographica:byArtist  SoloMusicArtist:Steve_Earle .
#
# CDs:Green_Light  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Green Light" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/589af027-6f93-4be3-b49f-ad0e8c22148c"^^xsd:anyURI .
#
# CDs:Change_in_Weather  a                  mo:CD , schema:MusicAlbum , mo:Record , mo:Release ;
#         rdfs:label                     "A Change In The Weather" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister , SoloMusicArtist:Clive_Gregson ;
#         bibliographica:byArtist        SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2f571c59-0e8c-4c3e-9ee4-63ae749457c8"^^xsd:anyURI .
#
# CDs:Secret_Story  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Secret Story" ;
#         dcterms:creator                SoloMusicArtist:Pat_Metheny ;
#         bibliographica:byArtist        SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5e8cd65-ae9a-40de-bb84-cab40402d58b"^^xsd:anyURI .
#
# CDs:Five_Million  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "5,000,000" ;
#         dcterms:creator                MusicGroup:Dread_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Dread_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f06c4dd0-d1f6-4db0-9a9f-257138ddf69f"^^xsd:anyURI .
#
# CDs:Small_Minds  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Small Minds" ;
#         dcterms:creator                MusicGroup:Austin_Lounge_Lizards ;
#         bibliographica:byArtist        MusicGroup:Austin_Lounge_Lizards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/718c57ed-3fd4-45d0-be22-75366f83c4ca"^^xsd:anyURI .
#
# CDs:Hampton_Comes_Alive  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hampton Comes Alive" ;
#         dcterms:creator                MusicGroup:Phish ;
#         bibliographica:byArtist        MusicGroup:Phish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/75382dc8-4b6e-4c7d-a62a-e9865139a794"^^xsd:anyURI .
#
# CDs:Night_in_Strange_Town
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Night in a Strange Town" ;
#         dcterms:creator                SoloMusicArtist:Lynn_Miles ;
#         bibliographica:byArtist        SoloMusicArtist:Lynn_Miles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/359176c2-956e-4dba-a525-48132e067c39"^^xsd:anyURI .
#
# CDs:House_Full  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "House Full" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9a54a18e-dd4c-3962-ad51-b0e19d5af0af"^^xsd:anyURI .
#
# CDs:Jerry_Garcia_Band_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jerry Garcia Band" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0475ea5d-16d5-4f27-b65a-a7b8d018d811"^^xsd:anyURI .
#
# CDs:Live_Dead_NY_71  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "New York 2-21-71" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Favorite_Ball_Chain  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Favorite Ball and Chain" ;
#         dcterms:creator                SoloMusicArtist:Marlee_MacLeod ;
#         bibliographica:byArtist        SoloMusicArtist:Marlee_MacLeod ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c2e4d802-7b1b-4162-b506-b2782c452f63"^^xsd:anyURI .
#
# CDs:I_Blow_Minds  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I Blow Minds for a Living" ;
#         dcterms:creator                SoloMusicArtist:Jello_Biafra ;
#         bibliographica:byArtist        SoloMusicArtist:Jello_Biafra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/58341600-22ee-4d94-9633-63e6d173e82f"^^xsd:anyURI .
#
# CDs:Apostrophe_Overnite_Sensation
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Apostrophe/Over-Nite Sensation" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/865af106-5b21-4fb3-aaea-c6ee35197178"^^xsd:anyURI .
#
# CDs:Cut_Me_Loose  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cut Me Loose" ;
#         dcterms:creator                MusicGroup:The_Assassins ;
#         bibliographica:byArtist        MusicGroup:The_Assassins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b452115-016f-4253-967a-21ef6c661ea8"^^xsd:anyURI .
#
# CDs:Po_Girl_CD  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Po' Girl" ;
#         dcterms:creator                MusicGroup:Po_Girl ;
#         bibliographica:byArtist        MusicGroup:Po_Girl ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e14ef630-eace-4058-8351-82e38a19cf0d"^^xsd:anyURI .
#
# CDs:Planet_Drum  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Planet Drum" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cae9ea41-74c6-47cc-aed8-cda2963c5b0a"^^xsd:anyURI .
#
# CDs:Bare   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bare" ;
#         dcterms:creator                SoloMusicArtist:Annie_Lennox ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Lennox ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/148045ee-7fb7-4978-aefe-bcb162ac2941"^^xsd:anyURI .
#
# CDs:Rich_Kid_Blues  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rich Kid Blues" ;
#         dcterms:creator                SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:byArtist        SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/941d8ace-2faf-46de-a77b-dff1a063e2ce"^^xsd:anyURI .
#
# CDs:Tender_City  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tender City" ;
#         dcterms:creator                SoloMusicArtist:Joy_Askew ;
#         bibliographica:byArtist        SoloMusicArtist:Joy_Askew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aa51f2f2-1bb5-4306-8e82-53ab10e522f8"^^xsd:anyURI .
#
# CDs:The_Messenger  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Messenger" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cc5de41c-b952-47d2-9b87-62c7d5b87de0"^^xsd:anyURI .
#
# CDs:Charity_of_Night  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Charity of Night" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/79f2f3a8-102a-3046-b2ff-bdfa2a1c63db"^^xsd:anyURI .
#
# CDs:Back_on_Street_Again
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Back on the Street Again" ;
#         dcterms:creator                MusicGroup:Laurel_Canyon_Ramblers ;
#         bibliographica:byArtist        MusicGroup:Laurel_Canyon_Ramblers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4f562a56-79de-4ec8-b76c-3faaf9bc14b4"^^xsd:anyURI .
#
# CDs:Private_Eyes  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Private Eyes" ;
#         dcterms:creator                SoloMusicArtist:Tommy_Bolin ;
#         bibliographica:byArtist        SoloMusicArtist:Tommy_Bolin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/63d543b4-7e5f-4586-86cf-f1d797eb0419"^^xsd:anyURI .
#
# CDs:Grass_Is_Blue  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Grass Is Blue" ;
#         dcterms:creator                SoloMusicArtist:Dolly_Parton ;
#         bibliographica:byArtist        SoloMusicArtist:Dolly_Parton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9df2807e-e1b8-4056-9c90-7cc84442d264"^^xsd:anyURI .
#
# CDs:Dancing_Dragons_Jaws
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dancing in the Dragon's Jaws" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/ba5f83b8-90cb-306c-b445-ca4bf0d6eb03"^^xsd:anyURI .
#
# CDs:Chatterbox_Session  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Eddie Chatterbox Double Trio Love Album" ;
#         dcterms:creator                SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:byArtist        SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32722bff-196b-34e1-8112-f09828c719f8"^^xsd:anyURI .
#
# CDs:Tapestry_CK  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tapestry" ;
#         dcterms:creator                SoloMusicArtist:Chantal_Kreviazuk ;
#         bibliographica:byArtist        SoloMusicArtist:Chantal_Kreviazuk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/570f5f29-bf35-38ed-8e6e-26ea1f8e24f4"^^xsd:anyURI .
#
# CDs:Uncommon_Ritual  a                    schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Uncommon Ritual" ;
#         dcterms:creator                SoloMusicArtist:Mike_Marshall , SoloMusicArtist:Bela_Fleck , SoloMusicArtist:Edgar_Meyer ;
#         bibliographica:byArtist        SoloMusicArtist:Edgar_Meyer , SoloMusicArtist:Mike_Marshall , SoloMusicArtist:Bela_Fleck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc1efc0e-16bf-4d5c-baf4-fdd2607470a3"^^xsd:anyURI .
#
# CDs:Best_Of  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Best of" ;
#         dcterms:creator          MusicGroup:Crosby_Nash ;
#         bibliographica:byArtist  MusicGroup:Crosby_Nash .
#
# CDs:In_New_Orleans  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In New Orleans" ;
#         dcterms:creator                MusicGroup:Clifton_Chenier_Red_Hot ;
#         bibliographica:byArtist        MusicGroup:Clifton_Chenier_Red_Hot ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ae5a184c-5187-4a22-b673-8752311df6ce"^^xsd:anyURI .
#
# CDs:Simmer_Reduce_Garnish_Serve
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Simmer, Reduce, Garnish, & Serve" ;
#         dcterms:creator                SoloMusicArtist:Rahsaan_Roland_Kirk ;
#         bibliographica:byArtist        SoloMusicArtist:Rahsaan_Roland_Kirk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4aa03b59-ca8e-4281-9038-e092a903adbc"^^xsd:anyURI .
#
# CDs:Chuys_Tape_Box  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chuy’s Tape Box, Vol. 1" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6d5fc6f-fcaf-4e2e-a3ab-b7133f311dfc"^^xsd:anyURI .
#
# CDs:Jazz_From_Hell  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz From Hell" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8455513b-aed5-3d30-a510-0f7754e71378"^^xsd:anyURI .
#
# CDs:Dont_Give_Up_On_Me  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Don’t Give Up On Me" ;
#         dcterms:creator                SoloMusicArtist:Solomon_Burke ;
#         bibliographica:byArtist        SoloMusicArtist:Solomon_Burke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c506273f-d462-3fb8-833f-82e472edc43e"^^xsd:anyURI .
#
# CDs:When_Theres_No_One  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "When No One's Around" ;
#         dcterms:creator                SoloMusicArtist:Tim_OBrien ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_OBrien ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/63d25d19-9112-46f7-ae69-6dab49311fb1"^^xsd:anyURI .
#
# CDs:Eddi_Reader_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eddi Reader" ;
#         dcterms:creator                SoloMusicArtist:Eddi_Reader ;
#         bibliographica:byArtist        SoloMusicArtist:Eddi_Reader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1dd8235c-a6c9-4559-bd7f-7aaf40be136e"^^xsd:anyURI .
#
# CDs:Live_at_VV_II  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live At The Village Vanguard II" ;
#         dcterms:creator                SoloMusicArtist:Junko_Onishi ;
#         bibliographica:byArtist        SoloMusicArtist:Junko_Onishi ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8454bf86-0d78-48d0-9b72-dda8e92ecf23"^^xsd:anyURI .
#
# CDs:Ten_Song_Demo  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "10 Song Demo" ;
#         dcterms:creator                SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f3293d60-db10-4ea7-9cc3-7c551bd5ac8a"^^xsd:anyURI .
#
# CDs:Bursting_Out  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bursting Out" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9c4482ae-01fe-3566-9b48-e340bf79ab65"^^xsd:anyURI .
#
# CDs:Stepmother_City  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stepmother City" ;
#         dcterms:creator                SoloMusicArtist:Sainkho_Namtchylak ;
#         bibliographica:byArtist        SoloMusicArtist:Sainkho_Namtchylak ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ef9d4a11-ac71-46d1-9ab6-fc17b74a1aff"^^xsd:anyURI .
#
# CDs:Ole_Coltrane  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Olé Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aad5ea8e-93d0-3010-8b01-80a14a0ef393"^^xsd:anyURI .
#
# CDs:Aura   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Aura" ;
#         dcterms:creator                SoloMusicArtist:Steve_Hillage ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Hillage ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4223e666-afda-4930-945d-af0b0b6b6c98"^^xsd:anyURI .
#
# CDs:Mingus_Dynasty  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus Dynasty" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99daa87a-0b4c-4f2c-8c2d-9d00e0e16ef2"^^xsd:anyURI .
#
# CDs:Night_in_Tunisia  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Night In Tunisia" ;
#         dcterms:creator                SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:byArtist        SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4b79d9d1-4301-4c32-bc22-640ea7659d84"^^xsd:anyURI .
#
# CDs:Zoot_Suit_Riot  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zoot Suit Riot" ;
#         dcterms:creator                MusicGroup:Cherry_Poppin_Daddies ;
#         bibliographica:byArtist        MusicGroup:Cherry_Poppin_Daddies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9798eeb9-1974-4729-a105-fd8498553ebc"^^xsd:anyURI .
#
# CDs:World_of_Wonders  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "World of Wonders" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/4abb4993-7960-3331-8535-471c71cf9d76"^^xsd:anyURI .
#
# CDs:Playing_Even_Better  a                schema:MusicAlbum , mo:CD , mo:Record , mo:Release ;
#         rdfs:label                     "Playing Even Better" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley , SoloMusicArtist:Hani_Naser ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley , SoloMusicArtist:Hani_Naser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0172a202-ba62-42e5-a145-54c9a9eda26f"^^xsd:anyURI .
#
# CDs:Elite_Hotel  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Elite Hotel" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/25d144a4-b8ed-46f5-bef4-21b266dc1332"^^xsd:anyURI .
#
# CDs:Grace  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Grace" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b2f862e5-a1f3-475d-85a1-6cb1160286aa"^^xsd:anyURI .
#
# CDs:Classical_Soul  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Classical Soul" ;
#         dcterms:creator                SoloMusicArtist:Marc_Antoine ;
#         bibliographica:byArtist        SoloMusicArtist:Marc_Antoine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/63b9a1a4-f72d-49b7-8696-8d3549763bdf"^^xsd:anyURI .
#
# CDs:Shall_We_Dance  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shall We Dance" ;
#         dcterms:creator                SoloMusicArtist:Beth_Quist ;
#         bibliographica:byArtist        SoloMusicArtist:Beth_Quist ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c0abb484-98cb-44dc-8631-3107af68fcc5"^^xsd:anyURI .
#
# CDs:Tiny_Voices  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tiny Voices" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60b7d7d1-2ec4-3272-845b-f2b2d17862a7"^^xsd:anyURI .
#
# CDs:Sandinista  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sandinista!" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a42ad822-7bdc-4272-93fa-2e04e9f09ce9"^^xsd:anyURI .
#
# CDs:Everybody_Loves_You  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Everybody Loves You" ;
#         dcterms:creator                SoloMusicArtist:Kaki_King ;
#         bibliographica:byArtist        SoloMusicArtist:Kaki_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdc3145c-b84f-4d07-a4e4-d3f52a0ee5aa"^^xsd:anyURI .
#
# CDs:Women_of_World  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Women of the World" ;
#         dcterms:creator                MusicGroup:Mahotella_Queens ;
#         bibliographica:byArtist        MusicGroup:Mahotella_Queens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d5ee6fa8-c853-4ff4-b541-a47f0f7d08bb"^^xsd:anyURI .
#
# CDs:Christmas  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Christmas" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/3d92083e-0fb5-3196-bc5c-8caf855f5f24"^^xsd:anyURI .
#
# CDs:Dream_Cafe  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dream Café" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41f653f9-234a-4f89-8922-f7843186db51"^^xsd:anyURI .
#
# CDs:White_Album  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Beatles (“The White Album”)" ;
#         dcterms:creator                MusicGroup:Beatles ;
#         bibliographica:byArtist        MusicGroup:Beatles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/034e0c73-c2df-328b-861c-3db28217aeed"^^xsd:anyURI .
#
# CDs:Goodnight_Venus  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Goodnight Venus" ;
#         dcterms:creator          SoloMusicArtist:Libby_Kirkpatrick ;
#         bibliographica:byArtist  SoloMusicArtist:Libby_Kirkpatrick .
#
# CDs:Telling_Stories_To_The_Sea
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Telling Stories To The Sea" ;
#         dcterms:creator                MusicGroup:Adventures_in_Afropea ;
#         bibliographica:byArtist        MusicGroup:Adventures_in_Afropea ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/072a4350-7b24-47f9-af50-b66e1aa6b3c8"^^xsd:anyURI .
#
# CDs:John_Fahey_Anthology
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Return of the Repressed: The John Fahey Anthology" ;
#         dcterms:creator                SoloMusicArtist:John_Fahey ;
#         bibliographica:byArtist        SoloMusicArtist:John_Fahey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ff83d695-ddf3-4a99-bfdd-2b1710163c59"^^xsd:anyURI .
#
# CDs:Funny_Valentine  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Funny Valentine" ;
#         dcterms:creator                MusicGroup:Massacre ;
#         bibliographica:byArtist        MusicGroup:Massacre ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/00055492-830d-4d2f-ae29-69cd09eeab23"^^xsd:anyURI .
#
# CDs:Zakir_Hussain_Rhythm_Exp
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zakir Hussain & the Rhythm Experience" ;
#         dcterms:creator                SoloMusicArtist:Zakir_Hussain ;
#         bibliographica:byArtist        SoloMusicArtist:Zakir_Hussain ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ded265fc-db65-49ee-a417-ebd49be3b632"^^xsd:anyURI .
#
# CDs:MTV_Unplugged  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "MTV Unplugged" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/3ee15c41-77b1-32bd-9513-d6035444a34e"^^xsd:anyURI .
#
# CDs:Dose   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dose" ;
#         dcterms:creator                MusicGroup:Latin_Playboys ;
#         bibliographica:byArtist        MusicGroup:Latin_Playboys ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/12f2d5ef-c565-4e3e-b473-858699141dfe"^^xsd:anyURI .
#
# CDs:Blue_Haze  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Haze" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a46128d0-d0a5-4e27-9eef-2379e136904c"^^xsd:anyURI .
#
# CDs:Madeleine_Peyroux_album
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Madeleine Peyroux (untitled)" ;
#         dcterms:creator          SoloMusicArtist:Madeleine_Peyroux ;
#         bibliographica:byArtist  SoloMusicArtist:Madeleine_Peyroux .
#
# CDs:Essex_Junction_71206
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Essex Junction, VT 7.12.06" ;
#         dcterms:creator          SoloMusicArtist:Phil_Lesh ;
#         bibliographica:byArtist  SoloMusicArtist:Phil_Lesh .
#
# CDs:Wildflowers  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wildflowers" ;
#         dcterms:creator                SoloMusicArtist:Tom_Petty ;
#         bibliographica:byArtist        SoloMusicArtist:Tom_Petty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4b5e44fd-018b-4fc7-9729-c9d9b011e459"^^xsd:anyURI .
#
# CDs:The_Murmurs  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Murmurs" ;
#         dcterms:creator                MusicGroup:Murmurs ;
#         bibliographica:byArtist        MusicGroup:Murmurs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5941dfb0-209a-4661-9301-ae665b30223d"^^xsd:anyURI .
#
# CDs:Pink_Moon  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pink Moon" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/608de3ea-c08f-36f5-9ac6-53d401940de7"^^xsd:anyURI .
#
# CDs:Passion_Soundtrack  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Passion: Music for the Last Temptation of Christ" ;
#         dcterms:creator                SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:byArtist        SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c0cf7ebb-2db9-3dcf-8029-67f487316ea0"^^xsd:anyURI .
#
# CDs:Bird_Hi_Hat  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bird at the Hi-Hat" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/94d22b67-1931-4174-926d-03117da20fc5"^^xsd:anyURI .
#
# CDs:New_Chautauqua  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New Chautauqua" ;
#         dcterms:creator                SoloMusicArtist:Pat_Metheny ;
#         bibliographica:byArtist        SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4936fc5d-db31-4a62-81db-9ebce3049b1e"^^xsd:anyURI .
#
# CDs:Songhai_2  a                          mo:Record , mo:Release , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Songhai 2" ;
#         dcterms:creator                MusicGroup:Ketama , SoloMusicArtist:Danny_Thompson , SoloMusicArtist:Jose_Soto , SoloMusicArtist:Toumani_Diabate ;
#         bibliographica:byArtist        SoloMusicArtist:Jose_Soto , SoloMusicArtist:Toumani_Diabate , MusicGroup:Ketama , SoloMusicArtist:Danny_Thompson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f1da490b-cd4b-4ddb-929e-429a499564c8"^^xsd:anyURI .
#
# CDs:Meeting_By_River  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Meeting by the River" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c66a6bfa-bfc5-4bc2-902b-2251234e751c"^^xsd:anyURI .
#
# CDs:Post_Card  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Post Card" ;
#         dcterms:creator                SoloMusicArtist:Mary_Hopkin ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Hopkin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/65080847-d682-4011-b1ca-86326ec9d1af"^^xsd:anyURI .
#
# CDs:Live_at_Hollywood_Bowl
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Hollywood Bowl (ep)" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fdbc1df8-5572-4fd7-9812-8bc5f325dec1"^^xsd:anyURI .
#
# CDs:Rats   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rats" ;
#         dcterms:creator                SoloMusicArtist:Sass_Jordan ;
#         bibliographica:byArtist        SoloMusicArtist:Sass_Jordan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a14e77d7-720b-4486-bc8d-ec9697c5170b"^^xsd:anyURI .
#
# CDs:Austin_96  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Austin '96" ;
#         dcterms:creator          MusicGroup:Dave_Alvin_Guilty_Men ;
#         bibliographica:byArtist  SoloMusicArtist:Dave_Alvin_Guilty_Men .
#
# CDs:Philadelphia  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Philadelphia: Original Motion Picture Score" ;
#         dcterms:creator                SoloMusicArtist:Howard_Shore ;
#         bibliographica:byArtist        SoloMusicArtist:Howard_Shore ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7c4e522e-2349-4383-b4c1-eda73c5a02e3"^^xsd:anyURI .
#
# CDs:Hot_Tuna_CD  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Tuna" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8a19938e-b072-49c7-8f49-a4ec67829177"^^xsd:anyURI .
#
# CDs:Arethas_Gold  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Aretha’s Gold" ;
#         dcterms:creator                SoloMusicArtist:Aretha_Franklin ;
#         bibliographica:byArtist        SoloMusicArtist:Aretha_Franklin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6f06ad48-e381-449f-9174-938872d24c92"^^xsd:anyURI .
#
# CDs:History_Mystery_Prophesy
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "History, Mystery & Prophesy" ;
#         dcterms:creator                SoloMusicArtist:Lee_Scratch_Perry ;
#         bibliographica:byArtist        SoloMusicArtist:Lee_Scratch_Perry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/21f7bb22-add6-47f0-8f09-57ba1f425307"^^xsd:anyURI .
#
# CDs:Under_the_Pink  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Under the Pink" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/716ab432-03be-3567-9d9f-1cbb4736e0dc"^^xsd:anyURI .
#
# CDs:The_Moon_Seven_Times_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Moon Seven Times" ;
#         dcterms:creator                MusicGroup:Moon_Seven_Times ;
#         bibliographica:byArtist        MusicGroup:Moon_Seven_Times ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3055aaf2-47f4-4da9-8f94-9be4dc194e07"^^xsd:anyURI .
#
# CDs:Funk_Inc_1971  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Funk, Inc." ;
#         dcterms:creator                MusicGroup:Funk_Inc ;
#         bibliographica:byArtist        MusicGroup:Funk_Inc ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ef533fd-1257-4a00-8b89-87daf7fb7307"^^xsd:anyURI .
#
# CDs:Slide_Rule  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slide Rule" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Douglas ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Douglas ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5f83924-0449-459e-84e3-a71cb22e3a35"^^xsd:anyURI .
#
# CDs:Christmas_MS  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Christmas'" ;
#         dcterms:creator                MusicGroup:Mannheim_Steamroller ;
#         bibliographica:byArtist        MusicGroup:Mannheim_Steamroller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6dd0e464-6c4d-4878-bc3f-7fe5b1e64b9c"^^xsd:anyURI .
#
# CDs:Shaking_Free  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shaking Free" ;
#         dcterms:creator                SoloMusicArtist:Nnenna_Freelon ;
#         bibliographica:byArtist        SoloMusicArtist:Nnenna_Freelon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/074ee03c-5baa-462e-908a-34691ffa00f7"^^xsd:anyURI .
#
# CDs:Friday_Night_San_Fran
#         a                              mo:CD , schema:MusicAlbum , mo:Record , mo:Release ;
#         rdfs:label                     "Friday Night In San Francisco" ;
#         dcterms:creator                SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Al_DiMeola , SoloMusicArtist:Paco_de_Lucia ;
#         bibliographica:byArtist        SoloMusicArtist:Al_DiMeola , SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Paco_de_Lucia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a52c0c4d-475a-3a4d-8119-7bccd3aafb12"^^xsd:anyURI .
#
# CDs:American_Music  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American Music" ;
#         dcterms:creator                MusicGroup:The_Blasters ;
#         bibliographica:byArtist        MusicGroup:The_Blasters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de7b4a4d-316c-4e29-a401-91f76d23db56"^^xsd:anyURI .
#
# CDs:Keb_Mo_CD  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Keb Mo" ;
#         dcterms:creator                SoloMusicArtist:Keb_Mo ;
#         bibliographica:byArtist        SoloMusicArtist:Keb_Mo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7477b3a3-e595-49f5-b2da-085358afbdfb"^^xsd:anyURI .
#
# CDs:Dark_Gift_of_Time  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Dark Gift of Time" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist        SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a53a90c9-e7be-4bc9-85cd-bd27435a8cfc"^^xsd:anyURI .
#
# CDs:Best_of_Big_Bands_LB
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of the Big Bands: Sentimental Journey with Les Brown" ;
#         dcterms:creator                SoloMusicArtist:Les_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Les_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/000845b1-57e7-4c91-a185-9b7888917984"^^xsd:anyURI .
#
# CDs:Flesh_and_Bone  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Flesh and Bone" ;
#         dcterms:creator                SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:byArtist        SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9b30a290-6ab4-4cb0-bc69-5081b312c849"^^xsd:anyURI .
#
# CDs:Telephone_Free_Landslide
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Telephone Free Landslide Victory" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/278cf805-812d-3de8-bfc5-f5d5ef5e00fe"^^xsd:anyURI .
#
# CDs:Joes_Garage  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Joe's Garage - Acts I, II, & III" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b53d319-3f9c-47eb-9a96-8341d7be58f7"^^xsd:anyURI .
#
# CDs:Colour_Moving_Still  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Colour Moving and Still" ;
#         dcterms:creator                SoloMusicArtist:Chantal_Kreviazuk ;
#         bibliographica:byArtist        SoloMusicArtist:Chantal_Kreviazuk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b47b88b4-9c40-4ea0-b5cb-d96e8a6324d2"^^xsd:anyURI .
#
# CDs:Unplugged_TB  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "MTV Unplugged" ;
#         dcterms:creator                SoloMusicArtist:Tony_Bennett ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Bennett ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/56423b70-c722-3882-b261-8b426eda2df5"^^xsd:anyURI .
#
# CDs:Psychefunkapus_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Psychefunkapus" ;
#         dcterms:creator                MusicGroup:Psychefunkapus ;
#         bibliographica:byArtist        MusicGroup:Psychefunkapus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9ea09fdb-da0c-421f-af2e-29ac54cd5069"^^xsd:anyURI .
#
# CDs:Monkey_Siren_CD  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Monkey Siren" ;
#         dcterms:creator          MusicGroup:Monkey_Siren ;
#         bibliographica:byArtist  MusicGroup:Monkey_Siren .
#
# CDs:Histoire_de_Melody  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Histoire de Melody Nelson" ;
#         dcterms:creator                SoloMusicArtist:Serge_Gainsbourg ;
#         bibliographica:byArtist        SoloMusicArtist:Serge_Gainsbourg ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdbe5b7d-6579-4ff6-832f-172b2e83fdb3"^^xsd:anyURI .
#
# CDs:Run_For_Roses  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Run For The Roses" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/03a7627f-b1cd-41ea-af70-ef8fae9c357a"^^xsd:anyURI .
#
# CDs:You_Can_Get_It  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can Get It If You Really Want" ;
#         dcterms:creator                SoloMusicArtist:Jimmy_Cliff ;
#         bibliographica:byArtist        SoloMusicArtist:Jimmy_Cliff ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f7498b7e-c890-4948-9dcc-2a5289f528a5"^^xsd:anyURI .
#
# CDs:African_Litany  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "African Litany" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5cc7ef2-cf3d-4a70-80aa-3b4e5aebcaa9"^^xsd:anyURI .
#
# CDs:The_Catherine_Wheel  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Catherine Wheel" ;
#         dcterms:creator                SoloMusicArtist:David_Byrne ;
#         bibliographica:byArtist        SoloMusicArtist:David_Byrne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/98b1e961-bf84-4e4b-85c1-5de7161dfdef"^^xsd:anyURI .
#
# CDs:Dear_Old_Stockholm  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dear Old Stockholm" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3ea624f-fea0-4aeb-a5df-becd58186f0a"^^xsd:anyURI .
#
# CDs:Fillmore_West_1969  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fillmore West 1969: The Complete Recordings" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f0ccafbc-8f2b-4901-9352-464c29f9d03b"^^xsd:anyURI .
#
# CDs:Mingus_Unknown_Origins
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Mingus - unknown origins" ;
#         dcterms:creator          SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist  SoloMusicArtist:Charles_Mingus .
#
# CDs:American_Four  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American IV: The Man Comes Around" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/261de123-7315-4a2f-8c40-3dad9092313e"^^xsd:anyURI .
#
# CDs:Zappas_Universe  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zappa's Universe" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b1e44c17-9317-4a97-a300-596c999af268"^^xsd:anyURI .
#
# CDs:William_Bloke  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "William Bloke" ;
#         dcterms:creator                SoloMusicArtist:Billy_Bragg ;
#         bibliographica:byArtist        SoloMusicArtist:Billy_Bragg ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01f8a2a0-8996-4277-9f00-10b27b51db78"^^xsd:anyURI .
#
# CDs:Fingerlings_Three  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fingerlings 3" ;
#         dcterms:creator                SoloMusicArtist:Andrew_Bird ;
#         bibliographica:byArtist        SoloMusicArtist:Andrew_Bird ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/fe9668c3-69fd-3e11-ac34-c66fbc329c6c"^^xsd:anyURI .
#
# CDs:Tapestry  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tapestry" ;
#         dcterms:creator                SoloMusicArtist:Carole_King ;
#         bibliographica:byArtist        SoloMusicArtist:Carole_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/26bd4a35-027d-4a0e-8d5b-4458cf6da5b7"^^xsd:anyURI .
#
# CDs:Ambient_1  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ambient 1: Music for Airports" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1496daaf-4b0b-3596-a252-0d3a7068f6e5"^^xsd:anyURI .
#
# CDs:The_Source  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Source" ;
#         dcterms:creator                SoloMusicArtist:Ali_Farka_Toure ;
#         bibliographica:byArtist        SoloMusicArtist:Ali_Farka_Toure ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a21f909e-d675-4302-a143-2914bf3285a3"^^xsd:anyURI .
#
# CDs:Live_DMB  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live" ;
#         dcterms:creator          MusicGroup:Del_McCoury_Band ;
#         bibliographica:byArtist  MusicGroup:Del_McCoury_Band .
#
# CDs:Pure_Jerry_Warner_Theatre
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pure Jerry: Warner Theatre, March 18, 1978" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7da829bd-e0e2-4ae5-abe0-6237aa80c1cc"^^xsd:anyURI .
#
# CDs:Grand  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Grand" ;
#         dcterms:creator                SoloMusicArtist:Erin_McKeown ;
#         bibliographica:byArtist        SoloMusicArtist:Erin_McKeown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60d2ac5f-ac84-4809-850a-7f71dda2a9d3"^^xsd:anyURI .
#
# CDs:Stripping_Cane  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stripping Cane" ;
#         dcterms:creator                SoloMusicArtist:Jeffrey_Foucault ;
#         bibliographica:byArtist        SoloMusicArtist:Jeffrey_Foucault ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ccb9810d-ca31-4283-a715-c59afe4be1a9"^^xsd:anyURI .
#
# CDs:Blue_Blvd  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Boulevard" ;
#         dcterms:creator                SoloMusicArtist:Dave_Alvin ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Alvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/55ad48dd-7b2f-4d98-83ad-f90b1140e79f"^^xsd:anyURI .
#
# CDs:Good_Stuff  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Good Stuff" ;
#         dcterms:creator                MusicGroup:B_Fifty_Twos ;
#         bibliographica:byArtist        MusicGroup:B_Fifty_Twos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1dfcb24-2c29-3f9f-8ee7-b1ea457d44a0"^^xsd:anyURI .
#
# CDs:Red_Dirt_Girl  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Red Dirt Girl" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41ced0c2-94e2-4987-a3f8-2867c904c553"^^xsd:anyURI .
#
# CDs:Another_Side_Dylan  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Another Side of Bob Dylan" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b18ef710-0e47-3c10-ab0b-6631533549ee"^^xsd:anyURI .
#
# CDs:ReTurning  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "ReTurning" ;
#         dcterms:creator                SoloMusicArtist:Jennifer_Berezan ;
#         bibliographica:byArtist        SoloMusicArtist:Jennifer_Berezan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c7181cf6-0e8e-4d2d-8217-768212897024"^^xsd:anyURI .
#
# CDs:BBoom  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "B’BOOM: Official Bootleg – Live in Argentina" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60358613-5c21-4c60-bc55-2ba3c63a8e5d"^^xsd:anyURI .
#
# CDs:Moondance  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moondance" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d36c8d5b-6e2c-372b-9927-1d2533421260"^^xsd:anyURI .
#
# CDs:Acoustic  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Acoustic" ;
#         dcterms:creator                MusicGroup:Everything_but_the_Girl ;
#         bibliographica:byArtist        MusicGroup:Everything_but_the_Girl ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/84cd3aa7-55d8-4114-92be-18800688c0ed"^^xsd:anyURI .
#
# CDs:Blues_Attack  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blues Attack" ;
#         dcterms:creator                SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:byArtist        SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/40a2daab-26e6-44dd-b3d4-af2ef1c29c0d"^^xsd:anyURI .
#
# CDs:Master_Drummers_Dagbon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Master Drummers of Dagbon, Volume 2" ;
#         dcterms:creator                SoloMusicArtist:Ahaji_Ibrahim_Abdulai ;
#         bibliographica:byArtist        SoloMusicArtist:Ahaji_Ibrahim_Abdulai ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a3974583-0052-42e9-8706-d56062c15e68"^^xsd:anyURI .
#
# CDs:The_Hissing_of_Summer_Lawns
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Hissing of Summer Lawns" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/351991f2-036a-423e-b7bd-35dc6782464c"^^xsd:anyURI .
#
# CDs:Jou_a_Rive  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jou A Rive" ;
#         dcterms:creator                MusicGroup:Boukan_Ginen ;
#         bibliographica:byArtist        MusicGroup:Boukan_Ginen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/6e4709d0-47ed-3545-b93f-305d7bce8033"^^xsd:anyURI .
#
# CDs:Best_of_John_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best Of John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a257b218-559f-354d-9e20-919c12e8017b"^^xsd:anyURI .
#
# CDs:Concrete_Blonde_Los_Illegals
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Concrete Blonde y Los Illegals" ;
#         dcterms:creator                MusicGroup:Concrete_Blonde ;
#         bibliographica:byArtist        MusicGroup:Concrete_Blonde ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/06be49dd-3b5c-480e-ba15-8040ec01acd2"^^xsd:anyURI .
#
# CDs:Longing_In_Hearts  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Longing In Their Hearts" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c7be2f58-5816-43fa-8c62-89f83a2c9efd"^^xsd:anyURI .
#
# CDs:Clash_on_Broadway  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Clash on Broadway" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b11870ca-7b14-4505-8164-2ceee7d11dde"^^xsd:anyURI .
#
# CDs:Revenge  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Revenge!" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/938524ac-a9f2-42d7-a263-7f9694c41764"^^xsd:anyURI .
#
# CDs:Twenty_Fifth_Box_Set
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The 25th Anniversary Box Set" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2ee5af01-5742-3cf0-a8df-76878fa777c0"^^xsd:anyURI .
#
# CDs:Side_Trips  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Side Trips - Volume One" ;
#         dcterms:creator                SoloMusicArtist:Howard_Wales , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia , SoloMusicArtist:Howard_Wales ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bee6e9b8-3d68-4cef-bfd7-7903c9b566c7"^^xsd:anyURI .
#
# CDs:Bass_Desires  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bass Desires" ;
#         dcterms:creator                SoloMusicArtist:Marc_Johnson ;
#         bibliographica:byArtist        SoloMusicArtist:Marc_Johnson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4e37210f-975d-46cf-976b-63198d4e195b"^^xsd:anyURI .
#
# CDs:Marvin_Pontiac  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Greatest Hits of Marvin Pontiac" ;
#         dcterms:creator                SoloMusicArtist:John_Lurie ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lurie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4982f664-3584-4d86-a019-b080e1a3fdc7"^^xsd:anyURI .
#
# CDs:Anthymn  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anthymn" ;
#         dcterms:creator                SoloMusicArtist:Cosy_Sheridan ;
#         bibliographica:byArtist        SoloMusicArtist:Cosy_Sheridan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e872443-aaae-4f4c-9eb1-8e63a09905df"^^xsd:anyURI .
#
# CDs:Pieces_of_Me  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pieces of Me" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f1ec7bd9-94dc-48cb-9acb-094e2cbe0b17"^^xsd:anyURI .
#
# CDs:Music_Never_Stopped  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Music Never Stopped: Roots of the Grateful Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b85bb5c-9fd8-463e-b46b-4aa2999889c8"^^xsd:anyURI .
#
# CDs:Passion_Sources  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Passion Sources" ;
#         dcterms:creator          SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:byArtist  SoloMusicArtist:Peter_Gabriel .
#
# CDs:Youre_The_Guy  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You’re the Guy I Want to Share My Money With" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a44d574d-3422-4863-ba53-3a52aad5f550"^^xsd:anyURI .
#
# CDs:El_Ruisenor_Yucateco
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "El Ruiseñor Yucateco" ;
#         dcterms:creator                SoloMusicArtist:Guty_Cardenas ;
#         bibliographica:byArtist        SoloMusicArtist:Guty_Cardenas ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b4ad9372-324a-4aa4-b141-1b5191daa837"^^xsd:anyURI .
#
# CDs:Live_in_Japan_HT  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Japan" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b3981da-0af0-4598-8a09-e56a9fe5269e"^^xsd:anyURI .
#
# CDs:Second_Album_RoyB  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Second Album" ;
#         dcterms:creator                SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:byArtist        SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ea085dcf-d422-4804-a1aa-bc77f701186a"^^xsd:anyURI .
#
# CDs:Man_Made_Miles  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Man Made Miles" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3913e7f1-6986-45c6-8a60-2e2bd15eacc1"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_4
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bootleg Series, Vol. 4: Live 1966: The “Royal Albert Hall” Concert" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/49da924d-13fd-32be-8e22-7093f5ef400e"^^xsd:anyURI .
#
# CDs:Brothers_in_Arms  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Brothers in Arms" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4c618c14-0ed3-3b50-b32a-562e0f4cfe28"^^xsd:anyURI .
#
# CDs:Inner_City_Front  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Inner City Front" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/523af397-7eea-3b7b-8af9-72507fc6a811"^^xsd:anyURI .
#
# CDs:Low    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Low" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02e2a2f6-0da2-34cb-8e65-a05447ed1994"^^xsd:anyURI .
#
# CDs:Devout_Catlyst  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Devout Catlyst" ;
#         dcterms:creator                SoloMusicArtist:Ken_Nordine ;
#         bibliographica:byArtist        SoloMusicArtist:Ken_Nordine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/61ec928e-123d-4bcd-b658-d007cc7c7a1d"^^xsd:anyURI .
#
# CDs:That_High_Lonesome  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "That High Lonesome Sound" ;
#         dcterms:creator                MusicGroup:Old_In_the_Way ;
#         bibliographica:byArtist        MusicGroup:Old_In_the_Way ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b9af56a-7aae-494e-bfcb-b4d2649d3cb8"^^xsd:anyURI .
#
# CDs:Past_the_Mission  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Past The Mission" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/93c840ab-7174-4799-9c6c-6b9051d0ff97"^^xsd:anyURI .
#
# CDs:New_York_Sessions  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New York Sessions ’67" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e614003b-bece-48b2-bfa7-66818622ffa2"^^xsd:anyURI .
#
# CDs:East_West  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "East-West" ;
#         dcterms:creator                MusicGroup:Paul_Butterfield_Blues_Band ;
#         bibliographica:byArtist        MusicGroup:Paul_Butterfield_Blues_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d9d7e377-df4a-301e-8dcc-da7bf391e638"^^xsd:anyURI .
#
# CDs:Epitaph  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Epitaph" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ec311c80-a1ab-4520-b751-31114214aaf2"^^xsd:anyURI .
#
# CDs:Stories_From_City  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stories from the City, Stories from the Sea" ;
#         dcterms:creator                SoloMusicArtist:PJ_Harvey ;
#         bibliographica:byArtist        SoloMusicArtist:PJ_Harvey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a227a9b1-59e1-43fd-93b5-ecdd85da190c"^^xsd:anyURI .
#
# CDs:Short_Mans_Room  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Short Man's Room" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/79c2e686-2afc-475c-8ca1-116391de997d"^^xsd:anyURI .
#
# CDs:Stories_From_Bluebus
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stories From the Bluebus" ;
#         dcterms:creator                SoloMusicArtist:Jill_Cohn ;
#         bibliographica:byArtist        SoloMusicArtist:Jill_Cohn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02fcdf79-3c07-4282-b73e-47d013a87812"^^xsd:anyURI .
#
# CDs:Me_Myself_An_Eye  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Me Myself An Eye" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1658bd0b-5e65-388c-a718-9ab2de506ffd"^^xsd:anyURI .
#
# CDs:Borderline  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Borderline" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3feebe88-8d01-4eec-803d-2635ffb917b4"^^xsd:anyURI .
#
# CDs:Good_As_I_Been_to_You
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Good As I Been to You" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/43f420f8-44ca-3ff2-92c2-c6f285cb163b"^^xsd:anyURI .
#
# CDs:Oracle  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Oracle" ;
#         dcterms:creator                SoloMusicArtist:Michael_Hedges ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Hedges ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5284faf7-e959-44b8-926b-8f5d158bd831"^^xsd:anyURI .
#
# CDs:Coltrane_for_Lovers  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Coltrane for Lovers" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/00e20769-22e6-4bca-b953-8c8aaa3291bd"^^xsd:anyURI .
#
# CDs:Live_JLP  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:Jean_Luc_Ponty ;
#         bibliographica:byArtist        SoloMusicArtist:Jean_Luc_Ponty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6194b1ec-a230-4e61-85fc-93d20abe987c"^^xsd:anyURI .
#
# CDs:Stages  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stages" ;
#         dcterms:creator                SoloMusicArtist:Eric_Andersen ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Andersen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/43a4b6c2-7573-4cfc-be0e-6e10d45e0037"^^xsd:anyURI .
#
# CDs:Radio_1_Live  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Radio 1: Live in Concert" ;
#         dcterms:creator                MusicGroup:Lone_Justice ;
#         bibliographica:byArtist        MusicGroup:Lone_Justice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/51810637-0929-4d07-bd70-a5dec126ed7f"^^xsd:anyURI .
#
# CDs:Uh_Huh_Her  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Uh Huh Her" ;
#         dcterms:creator                SoloMusicArtist:PJ_Harvey ;
#         bibliographica:byArtist        SoloMusicArtist:PJ_Harvey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f86c0b17-f117-45e0-94b2-5dd4664e271e"^^xsd:anyURI .
#
# CDs:From_Choirgirl_Hotel
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "From the Choirgirl Hotel" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/61884327-44ec-3073-a5af-46fda9a81ebb"^^xsd:anyURI .
#
# CDs:Let_Me_Tell_Story  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Let Me Tell You a Story" ;
#         dcterms:creator          SoloMusicArtist:Felina ;
#         bibliographica:byArtist  SoloMusicArtist:Felina .
#
# CDs:Long_Way_Home  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Long Way Home" ;
#         dcterms:creator                SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8bb890e0-dbc1-4c65-a725-b6e686c40729"^^xsd:anyURI .
#
# CDs:Chill_Out_JLH  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chill Out" ;
#         dcterms:creator                SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/55f2abf7-a4f7-4c53-8b6a-5ed152b7cbc8"^^xsd:anyURI .
#
# CDs:Musa_Ukungilandela  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Musa Ukungilandela" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8709ffd3-3f5d-44f6-bad7-3fda74c933b9"^^xsd:anyURI .
#
# CDs:Masked_and_Anonymous
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Masked and Anonymous" ;
#         dcterms:creator                MusicGroup:VariousDylan ;
#         bibliographica:byArtist        MusicGroup:VariousDylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/85acb6fb-8fc2-48b5-9ec5-d764c752d2ec"^^xsd:anyURI ;
#         skos:related                   SoloMusicArtist:Bob_Dylan .
#
# CDs:How_Sweet_It_Is_JO  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "How Sweet It Is" ;
#         dcterms:creator                SoloMusicArtist:Joan_Osborne ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Osborne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9cdba68c-8d15-4b97-8d1e-2023509bdca9"^^xsd:anyURI .
#
# CDs:Down_The_Road  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Down the Road" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/568a58bb-032b-49fc-9872-ae7aead9fb99"^^xsd:anyURI .
#
# CDs:Blonde_on_Blonde  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blonde on Blonde" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/329fb554-2a81-3d8a-8e22-ec2c66810019"^^xsd:anyURI .
#
# CDs:Boom_Boom  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Boom Boom" ;
#         dcterms:creator                SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c9cec95b-ba41-4507-ab1d-92236da72662"^^xsd:anyURI .
#
# CDs:En_el  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "En el malecón de La Habana" ;
#         dcterms:creator                SoloMusicArtist:Juan_Formell ;
#         bibliographica:byArtist        SoloMusicArtist:Juan_Formell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/36ab81ff-9a11-47db-83c9-5b93275b3463"^^xsd:anyURI .
#
# CDs:Red_on_Blonde  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Red On Blonde" ;
#         dcterms:creator                SoloMusicArtist:Tim_OBrien ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_OBrien ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6bac6493-b839-45bc-a8ec-65e0cfa7d5ff"^^xsd:anyURI .
#
# CDs:Lick_My_Decals  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lick My Decals Off, Baby" ;
#         dcterms:creator                MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:byArtist        MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b8f697e9-5f44-4ff9-82b4-87e7a509e978"^^xsd:anyURI .
#
# CDs:Tupelo_Honey  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tupelo Honey" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e2dc9f56-3800-3c59-b6b4-215181342990"^^xsd:anyURI .
#
# CDs:Dog_Eat_Dog  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dog Eat Dog" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3db38f89-bd77-41ba-bb4a-9a84841807dd"^^xsd:anyURI .
#
# CDs:New_Roman_Times  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New Roman Times" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0f2384c4-7ef1-426e-9fdc-efeaf2d443c5"^^xsd:anyURI .
#
# CDs:Station_to_Station  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Station to Station" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a25dc82a-8af3-32f6-8e66-5fb8cf72a45f"^^xsd:anyURI .
#
# CDs:Side_Four  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Side Four" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/9a5c7561-fdde-304f-9f1e-da67e09a55c5"^^xsd:anyURI .
#
# CDs:Shine  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shine" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3d3d3993-ffa7-47ba-a938-d2a4cf49a91d"^^xsd:anyURI .
#
# CDs:Pure_Jerry_Theatre_1839
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pure Jerry: Theatre 1839, San Francisco, July 29 & 30, 1977" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/11aada03-1d30-4b5f-b9d2-30655147cb95"^^xsd:anyURI .
#
# CDs:Cropredy_2002  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cropredy 2002 : Another Gig : Another Palindrome" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a62b6bc8-af5a-4479-862b-f207d24e4a66"^^xsd:anyURI .
#
# CDs:Capital_Years  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Capital Years" ;
#         dcterms:creator          SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist  SoloMusicArtist:Miles_Davis .
#
# CDs:Maria_McKee_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Maria McKee" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c124cf10-1a11-4f65-89cb-0799e3baeea6"^^xsd:anyURI .
#
# CDs:In_A_Gadda_Da_Vida  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In-A-Gadda-Da-Vida" ;
#         dcterms:creator                MusicGroup:Iron_Butterfly ;
#         bibliographica:byArtist        MusicGroup:Iron_Butterfly ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/15275649-a394-4db9-9c4e-04c3c0326ca1"^^xsd:anyURI .
#
# CDs:Idewild  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Idewild" ;
#         dcterms:creator                MusicGroup:Everything_but_the_Girl ;
#         bibliographica:byArtist        MusicGroup:Everything_but_the_Girl ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/833e5d60-d082-4030-b072-5ec35bb8a3e3"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_21  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 21: Richmond Coliseum, Richmond, VA 11/1/85" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4b93a7c5-a635-4364-8939-12cb9fe923f4"^^xsd:anyURI .
#
# CDs:Jewel_in_Crown  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jewel in the Crown" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34155b84-b772-4c9f-8f4b-e559e38e32e3"^^xsd:anyURI .
#
# CDs:Swerve  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Swerve" ;
#         dcterms:creator                SoloMusicArtist:Annie_Gallup ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Gallup ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/445149b9-d4ba-4522-825e-035cd0bc2e4f"^^xsd:anyURI .
#
# CDs:Court_of_Crimson_King
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Court of the Crimson King" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/808b2ebc-175c-3dd8-81f6-d4a5b8f79cef"^^xsd:anyURI .
#
# CDs:Hot_Rize_CD  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Rize" ;
#         dcterms:creator                MusicGroup:Hot_Rize ;
#         bibliographica:byArtist        MusicGroup:Hot_Rize ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/534c4512-3a74-4438-88e2-254fed794679"^^xsd:anyURI .
#
# CDs:Between_Mountain_Moon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Between the Mountain and the Moon" ;
#         dcterms:creator                SoloMusicArtist:Luka_Bloom ;
#         bibliographica:byArtist        SoloMusicArtist:Luka_Bloom ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/336a519c-3770-36ef-9de6-267a6be50d65"^^xsd:anyURI .
#
# CDs:Supralingua  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Supralingua" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c9abf0e9-4bef-4399-a8c8-fccaf2671024"^^xsd:anyURI .
#
# CDs:Blood_on_Tracks_MLC  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blood on the Tracks" ;
#         dcterms:creator                MusicGroup:Mary_Lees_Corvette ;
#         bibliographica:byArtist        MusicGroup:Mary_Lees_Corvette ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/36c5608f-95b1-4235-b137-71821d5979aa"^^xsd:anyURI .
#
# CDs:Bang   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bang" ;
#         dcterms:creator                MusicGroup:James_Gang ;
#         bibliographica:byArtist        MusicGroup:James_Gang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c8f7efb4-1499-4f1d-a072-64488f85358c"^^xsd:anyURI .
#
# CDs:Thin_Wild_Mercury_Music
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thin Wild Mercury Music" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38f40f0f-677a-40ce-ba2f-4da1c93cfa70"^^xsd:anyURI .
#
# CDs:In_Real_Time  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Real Time: Live '87" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d4f87fda-feed-4c6d-9bd6-8416d73f2a86"^^xsd:anyURI .
#
# CDs:The_Sound_Summer_Running
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Sound of Summer Running" ;
#         dcterms:creator                SoloMusicArtist:Marc_Johnson ;
#         bibliographica:byArtist        SoloMusicArtist:Marc_Johnson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5401839f-b68a-4300-83c9-d4a10f54d2e2"^^xsd:anyURI .
#
# CDs:Benefit  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Benefit" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d35ff204-adfe-3ce1-9242-4825af659761"^^xsd:anyURI .
#
# CDs:Home_Fires  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Home Fires" ;
#         dcterms:creator                MusicGroup:Dead_Ringer_Band ;
#         bibliographica:byArtist        MusicGroup:Dead_Ringer_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c6f6637d-41af-4b5d-b16e-41eb44c3b80e"^^xsd:anyURI .
#
# CDs:Pangaea  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pangaea" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e3d9f08-8b6d-4640-8a9f-5cd62c6b5915"^^xsd:anyURI .
#
# CDs:The_Visitor  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Visitor" ;
#         dcterms:creator          SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist  SoloMusicArtist:Loreena_McKennitt .
#
# CDs:Beyond_Innocence  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Beyond Innocence" ;
#         dcterms:creator          SoloMusicArtist:Monica_Augustine ;
#         bibliographica:byArtist  SoloMusicArtist:Monica_Augustine .
#
# CDs:World_Out_of_Time_2  a                schema:MusicAlbum , mo:Record , mo:Release , mo:CD ;
#         rdfs:label                     "A World out of Time, Vol. 2: Henry Kaiser & David Lindley in Madagascar" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser , SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley , SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/40fbdb89-a8e1-4b07-8f56-90653eec5bda"^^xsd:anyURI .
#
# CDs:The_Doors_CD  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Doors" ;
#         dcterms:creator                MusicGroup:The_Doors ;
#         bibliographica:byArtist        MusicGroup:The_Doors ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/25988409-04ef-4da5-ba97-a87d33624204"^^xsd:anyURI .
#
# CDs:Prairie_Home_Invasion
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Prairie Home Invasion" ;
#         dcterms:creator                SoloMusicArtist:Jello_Biafra ;
#         bibliographica:byArtist        SoloMusicArtist:Jello_Biafra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32b15f41-5346-4b4c-afe1-2e5dc554388f"^^xsd:anyURI .
#
# CDs:Death_Rides_Pale_Cow
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Death Rides a Pale Cow: The Ultimate Collection" ;
#         dcterms:creator                MusicGroup:The_Dead_Milkmen ;
#         bibliographica:byArtist        MusicGroup:The_Dead_Milkmen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cfbc9fd8-9ae7-4a27-a8c6-3aad17f1f3fe"^^xsd:anyURI .
#
# CDs:The_Major_Works_of_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Major Works of John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d0a4892d-29a9-406f-8c8d-03cbec42dd87"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_8  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 8: Harpur College, Binghampton, NY 5/2/70" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f037dd16-e631-48c0-bec2-123040473db6"^^xsd:anyURI .
#
# CDs:The_Bonnie_Raitt_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bonnie Raitt Collection" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3905e1fc-9b1c-4c98-a7ca-174265c73c9c"^^xsd:anyURI .
#
# CDs:Love_Power_Peace  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Love Power Peace: Live at The Olympia, Paris, 1971" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/031330b9-644c-4f83-8259-da076b120769"^^xsd:anyURI .
#
# CDs:Bad_Company_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bad Company" ;
#         dcterms:creator                MusicGroup:Bad_Company ;
#         bibliographica:byArtist        MusicGroup:Bad_Company ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/78153b7e-9e3d-4cdf-a35c-2b9b953c83e7"^^xsd:anyURI .
#
# CDs:Disappear_Fear_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Disappear Fear" ;
#         dcterms:creator                MusicGroup:Disappear_Fear ;
#         bibliographica:byArtist        MusicGroup:Disappear_Fear ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2dde37d8-46a6-461b-ae60-9fffd62f60c4"^^xsd:anyURI .
#
# CDs:River_Under_The_Road
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "River Under The Road" ;
#         dcterms:creator                SoloMusicArtist:Ana_Egge ;
#         bibliographica:byArtist        SoloMusicArtist:Ana_Egge ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b42e2f6e-587b-37f7-b750-362ec21a1e52"^^xsd:anyURI .
#
# CDs:Acadie  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Acadie" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ce6c8a5-6125-40c2-ba62-91d143b83a94"^^xsd:anyURI .
#
# CDs:Cockamamie  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cockamamie" ;
#         dcterms:creator                SoloMusicArtist:Jen_Trynin ;
#         bibliographica:byArtist        SoloMusicArtist:Jen_Trynin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4c8f264e-fc91-4799-9b74-7b7eaf1f67bd"^^xsd:anyURI .
#
# CDs:Throw_Down_Arms  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Throw Down Your Arms" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa033070-272e-3b88-8f11-876d90ec6c05"^^xsd:anyURI .
#
# CDs:Crash_of_Rhinos_CD  a           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Crash of Rhinos" ;
#         dcterms:creator          MusicGroup:Crash_of_Rhinos ;
#         bibliographica:byArtist  MusicGroup:Crash_of_Rhinos .
#
# CDs:The_Visit  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Visit" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdfec8a3-63fd-3a77-a724-7f783a64f0d6"^^xsd:anyURI .
#
# CDs:Broken_English  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Broken English" ;
#         dcterms:creator                SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:byArtist        SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/edba5150-2435-4d08-b5e3-6699b0b4bb09"^^xsd:anyURI .
#
# CDs:Story_of_Ghost  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Story of the Ghost" ;
#         dcterms:creator                MusicGroup:Phish ;
#         bibliographica:byArtist        MusicGroup:Phish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9a3f1cb-d336-421d-8305-4a7290993851"^^xsd:anyURI .
#
# CDs:Rockets  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rockets" ;
#         dcterms:creator                SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:byArtist        SoloMusicArtist:Daniel_Lanois ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f57b1695-bc7b-4e59-9301-512d69a4c4a5"^^xsd:anyURI .
#
# CDs:Live_in_New_York  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Town Hall New York City September 19-20, 2001" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fd77117d-b18d-44ae-b677-e2d4bd1b1844"^^xsd:anyURI .
#
# CDs:Renmin_Park  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Nomad Series, Volume 1: Renmin Park" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fbb9c189-64cb-4325-9532-7ac53e658b46"^^xsd:anyURI .
#
# CDs:Queen_All_Ears  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Queen of All Ears" ;
#         dcterms:creator                MusicGroup:Lounge_Lizards ;
#         bibliographica:byArtist        MusicGroup:Lounge_Lizards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e117f547-7248-461d-bfdb-f24e0d67efea"^^xsd:anyURI .
#
# CDs:God_FBI  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "God & The FBI" ;
#         dcterms:creator                SoloMusicArtist:Janis_Ian ;
#         bibliographica:byArtist        SoloMusicArtist:Janis_Ian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/03b758c8-bd37-416d-a07c-0bfea9a85bae"^^xsd:anyURI .
#
# CDs:Blues_For_Allah  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blues for Allah" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e6996642-ae79-395a-af24-ddbf40d06fcc"^^xsd:anyURI .
#
# CDs:Janis  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Janis" ;
#         dcterms:creator                SoloMusicArtist:Janis_Joplin ;
#         bibliographica:byArtist        SoloMusicArtist:Janis_Joplin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05ebfb8b-750c-4160-8268-d1b2692df1ed"^^xsd:anyURI .
#
# CDs:Verve_Jazz_Masters_38
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Verve Jazz Masters 38" ;
#         dcterms:creator                SoloMusicArtist:Django_Reinhardt ;
#         bibliographica:byArtist        SoloMusicArtist:Django_Reinhardt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc739d14-2583-4a8a-89a0-f8852051792c"^^xsd:anyURI .
#
# CDs:Best_of_Shawn_Phillips
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Shawn Phillips" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Phillips ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa235629-a98b-4d03-aee7-8489908bd9c2"^^xsd:anyURI .
#
# CDs:Both_Sides_Now  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Both Sides Now" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/42038990-4e2c-3c40-b74f-4930409f0edb"^^xsd:anyURI .
#
# CDs:The_Squirrel  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Squirrel" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7301e872-b064-495e-ab97-f38febfb27e0"^^xsd:anyURI .
#
# CDs:Old_Boyfriends  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Old Boyfriends" ;
#         dcterms:creator                SoloMusicArtist:Claire_Martin ;
#         bibliographica:byArtist        SoloMusicArtist:Claire_Martin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10cef20d-30a9-432f-a839-b0d96776c8a7"^^xsd:anyURI .
#
# CDs:Shadow_Man  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shadow Man" ;
#         dcterms:creator                MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:byArtist        MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/95eaa4fa-d525-3f74-a518-4d4c0a92629a"^^xsd:anyURI .
#
# CDs:Strays  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strays" ;
#         dcterms:creator                MusicGroup:Janes_Addiction ;
#         bibliographica:byArtist        MusicGroup:Janes_Addiction ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e92c571-8e2b-38e4-bc8a-f87a3da3682b"^^xsd:anyURI .
#
# CDs:Teaser_Firecat  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Teaser And The Firecat" ;
#         dcterms:creator                SoloMusicArtist:Cat_Stevens ;
#         bibliographica:byArtist        SoloMusicArtist:Cat_Stevens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/168326ee-a04d-426f-9f9e-229a8c8095c3"^^xsd:anyURI .
#
# CDs:Ghosts_Great_Highway
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ghosts Of The Great Highway" ;
#         dcterms:creator                MusicGroup:Sun_Kil_Moon ;
#         bibliographica:byArtist        MusicGroup:Sun_Kil_Moon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eab684fc-3c27-41c6-b4f1-c704bdd6edd9"^^xsd:anyURI .
#
# CDs:Peddlin_Dreams  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peddlin' Dreams" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5e0f7487-78a6-4570-9171-627940a38e15"^^xsd:anyURI .
#
# CDs:Spinner  a                            mo:Release , mo:Record , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Spinner" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno , SoloMusicArtist:Jah_Wobble ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno , SoloMusicArtist:Jah_Wobble ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b6c7e5c-f6d7-4b12-8def-a786ffd1266e"^^xsd:anyURI .
#
# CDs:Trouble_With_Normal  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Trouble With Normal" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/27ab04af-2286-3f0d-9793-734b8caa464b"^^xsd:anyURI .
#
# CDs:Lady_in_Autumn  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lady in Autumn: The Best of the Verve Years" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f6007b5-3f40-4d76-84c7-9daf5e2b86b8"^^xsd:anyURI .
#
# CDs:Choc_Supa_High  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chocolate Supa Highway" ;
#         dcterms:creator                SoloMusicArtist:Michael_Franti ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Franti ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/26927dd1-6d6b-4fe9-b785-c7b03cec5111"^^xsd:anyURI .
#
# CDs:Anthology_Bad_Company
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bad Company ‘Original’ Anthology" ;
#         dcterms:creator                MusicGroup:Bad_Company ;
#         bibliographica:byArtist        MusicGroup:Bad_Company ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/df329032-9dc4-39bf-b70e-127c8ae1c2b1"^^xsd:anyURI .
#
# CDs:Best_of_Etta_James  a           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Best of Etta James" ;
#         dcterms:creator          SoloMusicArtist:Etta_James ;
#         bibliographica:byArtist  SoloMusicArtist:Etta_James .
#
# CDs:Levelling_The_Land  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Levelling the Land" ;
#         dcterms:creator                MusicGroup:Levellers ;
#         bibliographica:byArtist        MusicGroup:Levellers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/576dd322-bce3-4bda-a884-5495cdb3207a"^^xsd:anyURI .
#
# CDs:Sparks_Gonna_Fly  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Sparks Are Gonna Fly (promo)" ;
#         dcterms:creator          MusicGroup:Catherine_Wheel ;
#         bibliographica:byArtist  MusicGroup:Catherine_Wheel .
#
# CDs:Royal_Garden_Blues  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Royal Garden Blues" ;
#         dcterms:creator                SoloMusicArtist:Branford_Marsalis ;
#         bibliographica:byArtist        SoloMusicArtist:Branford_Marsalis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/70c5411b-05d5-3eb7-9b88-99a6092d53ef"^^xsd:anyURI .
#
# CDs:Rough_Ready  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rough and Ready" ;
#         dcterms:creator                MusicGroup:Jeff_Beck_Group ;
#         bibliographica:byArtist        MusicGroup:Jeff_Beck_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3fa5d226-7ecf-4751-99a5-4261d70136ea"^^xsd:anyURI .
#
# CDs:Live_at_Carnegie_Hall
#         a                              schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Live Miles: More Music From the Legendary Carnegie Hall Concert" , "Live at Carnegie Hall" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis , SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis , SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53851af0-de37-4bd8-9e2a-e8e664de4003"^^xsd:anyURI , "https://musicbrainz.org/release/a5123b52-0047-47ca-88f3-d537011a6c7e"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_3  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 3: Pembroke Pines, FL 5/22/77" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/40ff133b-8052-4ca4-9d61-2743ca9ea185"^^xsd:anyURI .
#
# CDs:Five_Stories  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Five Stories" ;
#         dcterms:creator                SoloMusicArtist:Kris_Delmhorst ;
#         bibliographica:byArtist        SoloMusicArtist:Kris_Delmhorst ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2fe3cba1-271a-4686-a9c4-9c53e3a9b782"^^xsd:anyURI .
#
# CDs:Logozo  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Logozo" ;
#         dcterms:creator                SoloMusicArtist:Angelique_Kidjo ;
#         bibliographica:byArtist        SoloMusicArtist:Angelique_Kidjo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/942cb3d2-98ad-406d-9e88-1e924427573d"^^xsd:anyURI .
#
# CDs:Painting_Sidewalks  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Painting Sidewalks" ;
#         dcterms:creator                SoloMusicArtist:Wendy_Bucklew ;
#         bibliographica:byArtist        SoloMusicArtist:Wendy_Bucklew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9316104c-a460-4861-8039-ea8e2b5cb5b6"^^xsd:anyURI .
#
# CDs:Elemental  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Elemental" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5d55917a-40b3-341f-9262-069fc6b6d367"^^xsd:anyURI .
#
# CDs:Bigger_Better_Faster_More
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bigger, Better, Faster, More" ;
#         dcterms:creator                MusicGroup:Four_Non_Blondes ;
#         bibliographica:byArtist        MusicGroup:Four_Non_Blondes ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9154385d-5ea3-4dc6-b5bb-b7433ba32243"^^xsd:anyURI .
#
# CDs:Past_Didnt_Go_Anywhere
#         a                              mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "The Past Didn't Go Anywhere" ;
#         dcterms:creator                SoloMusicArtist:Utah_Phillips , SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco , SoloMusicArtist:Utah_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92915da0-5f7a-42e0-8f27-e667dc35e779"^^xsd:anyURI .
#
# CDs:Grown_Backwards  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Grown Backwards" ;
#         dcterms:creator                SoloMusicArtist:David_Byrne ;
#         bibliographica:byArtist        SoloMusicArtist:David_Byrne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d268a3b8-c132-4b95-806d-f7ed72954107"^^xsd:anyURI .
#
# CDs:Pickin_on_Grateful_Dead
#         a                              schema:MusicAlbum , mo:CD , mo:Record , mo:Release ;
#         rdfs:label                     "Pickin' on the Grateful Dead: A Tribute" ;
#         dcterms:creator                MusicGroup:Pickin_on_Project , MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead , MusicGroup:Pickin_on_Project ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/533b6409-0f75-4eff-adc7-d49baedd32cf"^^xsd:anyURI .
#
# CDs:Sublime_Ilusion  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sublime Ilusión" ;
#         dcterms:creator                SoloMusicArtist:Eliades_Ochoa ;
#         bibliographica:byArtist        SoloMusicArtist:Eliades_Ochoa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3a6d5781-400e-4534-9658-d006a76cbbfc"^^xsd:anyURI .
#
# CDs:Desert_Poems  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Desert Poems" ;
#         dcterms:creator                SoloMusicArtist:Stephan_Micus ;
#         bibliographica:byArtist        SoloMusicArtist:Stephan_Micus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ef57c0cd-9ae6-4e7d-8b7c-25d558df324a"^^xsd:anyURI .
#
# CDs:Material_Bill_Laswell
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:comment             "Unspecified release in collection" ;
#         rdfs:label               "Material with Bill Laswell" ;
#         dcterms:creator          SoloMusicArtist:Bill_Laswell ;
#         bibliographica:byArtist  SoloMusicArtist:Bill_Laswell .
#
# CDs:Celine_Dion_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Céline Dion" ;
#         dcterms:creator                SoloMusicArtist:Celine_Dion ;
#         bibliographica:byArtist        SoloMusicArtist:Celine_Dion ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cb514bea-1f43-4594-9db0-5038f0677d38"^^xsd:anyURI .
#
# CDs:Legion_of_Mary_CD  a                  mo:Record , mo:CD , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "The Jerry Garcia Collection, Vol. 1: Legion of Mary" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia , MusicGroup:Legion_of_Mary ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia , MusicGroup:Legion_of_Mary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eae0ce70-bdc7-4fac-8534-4f0cd32ef663"^^xsd:anyURI .
#
# CDs:Definitive_Gold  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Definitive Gold" ;
#         dcterms:creator                MusicGroup:Jam ;
#         bibliographica:byArtist        MusicGroup:Jam ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f1da48e0-97cc-404a-bdbc-699434acc027"^^xsd:anyURI .
#
# CDs:Bloomed  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bloomed" ;
#         dcterms:creator                SoloMusicArtist:Richard_Buckner ;
#         bibliographica:byArtist        SoloMusicArtist:Richard_Buckner ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38e0a606-21c2-4d44-ba51-741816418a20"^^xsd:anyURI .
#
# CDs:Mind_Adventures  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mind Adventures" ;
#         dcterms:creator                SoloMusicArtist:Desree ;
#         bibliographica:byArtist        SoloMusicArtist:Desree ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/789a27a8-c390-4b37-b466-666aed434b7b"^^xsd:anyURI .
#
# CDs:Tell_Me_Something  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tell Me Something - The Songs of Mose Allison" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60cf9736-82f9-4626-9fb2-176a3e6ebae2"^^xsd:anyURI .
#
# CDs:The_Harder_They_Come
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Harder They Come" ;
#         dcterms:creator                SoloMusicArtist:Jimmy_Cliff ;
#         bibliographica:byArtist        SoloMusicArtist:Jimmy_Cliff ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5781be9d-e60e-44e7-b82f-d58f629d865d"^^xsd:anyURI .
#
# CDs:Pogue_Mahone  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pogue Mahone" ;
#         dcterms:creator                MusicGroup:Pogues ;
#         bibliographica:byArtist        MusicGroup:Pogues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5f9c3fa2-2086-4b7b-996f-aa5fe03b3c32"^^xsd:anyURI .
#
# CDs:Time_Out  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Time Out" ;
#         dcterms:creator                SoloMusicArtist:Dave_Brubeck ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Brubeck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ce61b145-c954-4fd4-86a4-bb2617544e62"^^xsd:anyURI .
#
# CDs:Blazing_Away  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blazing Away" ;
#         dcterms:creator                SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:byArtist        SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e6d3ed16-b0c5-402a-88f2-7215a4163f5d"^^xsd:anyURI .
#
# CDs:Angel_Town  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Angel Town" ;
#         dcterms:creator          SoloMusicArtist:Joy_Eden_Harrison ;
#         bibliographica:byArtist  SoloMusicArtist:Joy_Eden_Harrison .
#
# CDs:Angels_Electricity  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Angels & Electricity" ;
#         dcterms:creator                SoloMusicArtist:Eddi_Reader ;
#         bibliographica:byArtist        SoloMusicArtist:Eddi_Reader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6e0c65f5-a609-494f-acca-49ceb03e6aee"^^xsd:anyURI .
#
# CDs:Stolen_Roses  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stolen Roses: Songs of the Grateful Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e49d0df7-ce94-4e44-bb29-3bea02f49c45"^^xsd:anyURI .
#
# CDs:Breakdown  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Breakdown" ;
#         dcterms:creator                MusicGroup:Old_In_the_Way ;
#         bibliographica:byArtist        MusicGroup:Old_In_the_Way ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a70486be-b84d-48e0-8ef6-0dd66c9feb7b"^^xsd:anyURI .
#
# CDs:Book_of_Secrets  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Book of Secrets" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2856792c-10e9-43e2-94ca-ac05585113c6"^^xsd:anyURI .
#
# CDs:Smokin_Java  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Smokin' Java" ;
#         dcterms:creator          SoloMusicArtist:Darrell_Grant ;
#         bibliographica:byArtist  SoloMusicArtist:Darrell_Grant .
#
# CDs:Natty_Dread  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Natty Dread" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d1007b74-c38a-4996-b13f-cd1c67a97814"^^xsd:anyURI .
#
# CDs:Live_at_the_Fillmore
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Fillmore" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b5c17e4a-bf6a-49c1-945a-7c69469a65f7"^^xsd:anyURI .
#
# CDs:Incredible_Jazz_Guitar
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Incredible Jazz Guitar of Wes Montgomery" ;
#         dcterms:creator                SoloMusicArtist:Wes_Montgomery ;
#         bibliographica:byArtist        SoloMusicArtist:Wes_Montgomery ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c5f22716-0df2-3dca-a3a1-fe144bbf0b12"^^xsd:anyURI .
#
# CDs:You_Cant_Do_That_On_Stage_v4
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 4" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a26fd9fe-1c50-4dbc-98dd-e4f6d95fd4ab"^^xsd:anyURI .
#
# CDs:Sympathique  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sympathique" ;
#         dcterms:creator                MusicGroup:Pink_Martini ;
#         bibliographica:byArtist        MusicGroup:Pink_Martini ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/63fb25a0-14e1-4744-a556-847975ff733f"^^xsd:anyURI .
#
# CDs:Childish_Things  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Childish Things" ;
#         dcterms:creator                SoloMusicArtist:James_McMurtry ;
#         bibliographica:byArtist        SoloMusicArtist:James_McMurtry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be523a00-d1ab-4dab-adfe-d6489266ccd9"^^xsd:anyURI .
#
# CDs:New_Thing_Newport  a                  schema:MusicAlbum , mo:CD , mo:Record , mo:Release ;
#         rdfs:label                     "New Thing At Newport" ;
#         dcterms:creator                SoloMusicArtist:Archie_Shepp , SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane , SoloMusicArtist:Archie_Shepp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4e0fd29d-f964-4bb7-bee9-d272b23e6c92"^^xsd:anyURI .
#
# CDs:Goodbye_Cruel_World  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Goodbye Cruel World" ;
#         dcterms:creator                MusicGroup:Elvis_Costello_Attractions ;
#         bibliographica:byArtist        MusicGroup:Elvis_Costello_Attractions ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b056c9e-642e-4084-8716-02cd8b24cc71"^^xsd:anyURI .
#
# CDs:In_Montreux  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Montreux" ;
#         dcterms:creator                SoloMusicArtist:Dee_Dee_Bridgewater ;
#         bibliographica:byArtist        SoloMusicArtist:Dee_Dee_Bridgewater ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d45084bb-3901-4ad8-a833-cbf9657f5ccf"^^xsd:anyURI .
#
# CDs:Led_Zeppelin_Boxed_Set
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Led Zeppelin Boxed Set" ;
#         dcterms:creator                MusicGroup:Led_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Led_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c6ce30ec-ecfd-481c-b666-eea02373c66f"^^xsd:anyURI .
#
# CDs:Drawn_To_Rhythm  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Drawn To The Rhythm" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/601eeacd-ea64-400c-aac6-cd6b857d5959"^^xsd:anyURI .
#
# CDs:Twango_Bango_Deluxe  a                mo:Release , schema:MusicAlbum , mo:Record , mo:CD ;
#         rdfs:label                     "Twango Bango Deluxe" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley , SoloMusicArtist:Wally_Ingram ;
#         bibliographica:byArtist        SoloMusicArtist:Wally_Ingram , SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0172a202-ba62-42e5-a145-54c9a9eda26f"^^xsd:anyURI .
#
# CDs:Danko_Fjeld_Andersen
#         a                              mo:Release , schema:MusicAlbum , mo:Record , mo:CD ;
#         rdfs:label                     "Danko, Fjeld & Andersen" ;
#         dcterms:creator                SoloMusicArtist:Jonas_Fjeld , SoloMusicArtist:Eric_Andersen , SoloMusicArtist: ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Andersen , SoloMusicArtist:Rick_Danko , SoloMusicArtist:Jonas_Fjeld ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e142f726-0629-4b8a-86f9-dfc1caec134c"^^xsd:anyURI .
#
# CDs:Mamas_Gun  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mama’s Gun" ;
#         dcterms:creator                SoloMusicArtist:Erykah_Badu ;
#         bibliographica:byArtist        SoloMusicArtist:Erykah_Badu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3d7d898-c917-4431-b761-e79d71b6172e"^^xsd:anyURI .
#
# CDs:So_What  a                            schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "So What" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/825b6052-5f94-4393-abd7-6537e8baefea"^^xsd:anyURI .
#
# CDs:Stoned_Soul_Picnic  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stoned Soul Picnic: The Best of Laura Nyro" ;
#         dcterms:creator                SoloMusicArtist:Laura_Nyro ;
#         bibliographica:byArtist        SoloMusicArtist:Laura_Nyro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b293737f-ef60-43d1-ae50-b05cd443a214"^^xsd:anyURI .
#
# CDs:Traneing_In  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Traneing In" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a366bd57-44e6-30b6-8cbf-20cc5e419565"^^xsd:anyURI .
#
# CDs:Speaking_With_Angel  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Speaking With the Angel" ;
#         dcterms:creator                SoloMusicArtist:Mary_Black ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Black ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/62147f38-3df7-3624-9cb3-6592761b1e22"^^xsd:anyURI .
#
# CDs:Sampler  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Sampler" ;
#         dcterms:creator          SoloMusicArtist:Andrew_Bird ;
#         bibliographica:byArtist  SoloMusicArtist:Andrew_Bird .
#
# CDs:More_Study_Brown  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "More Study in Brown" ;
#         dcterms:creator                SoloMusicArtist:Clifford_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Clifford_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a21ea995-76a6-47c0-9ca8-5569642236c7"^^xsd:anyURI .
#
# CDs:Baduizm  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Baduizm" ;
#         dcterms:creator                SoloMusicArtist:Erykah_Badu ;
#         bibliographica:byArtist        SoloMusicArtist:Erykah_Badu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/93ef6b76-a6ab-4d01-ae7f-a141d4c4a852"^^xsd:anyURI .
#
# CDs:Got_Love_If_You_Want_It
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Got Love If You Want It" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/228790dc-8ce4-449f-a42c-75ac5f12e31a"^^xsd:anyURI .
#
# CDs:Rastaman_Vibration  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rastaman Vibration" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d306e7dc-cc36-4bb1-b259-389347f5f6b2"^^xsd:anyURI .
#
# CDs:Nothing_Is_Easy_Wight
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nothing Is Easy: Live at the Isle of Wight 1970" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bef53b94-3010-45bc-b9e0-85749393e5d7"^^xsd:anyURI .
#
# CDs:Helvetica_Bold  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Helvetica Bold" ;
#         dcterms:creator                SoloMusicArtist:Laura_Love ;
#         bibliographica:byArtist        SoloMusicArtist:Laura_Love ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bca90eaa-cc41-405f-b53d-ee78edef7868"^^xsd:anyURI .
#
# CDs:Led_Zeppelin_IV  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Led Zeppelin IV" ;
#         dcterms:creator                MusicGroup:Led_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Led_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4779d5d3-e57e-3a0b-9f2d-688ebb25e509"^^xsd:anyURI .
#
# CDs:Blood_on_Tracks  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blood on the Tracks" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/9c1b8072-eb1d-33d2-af8c-984d46e40902"^^xsd:anyURI .
#
# CDs:Mingus_at_Antibes  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus at Antibes" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6d3ad3e-46ae-4cd1-a233-7817355ed9a2"^^xsd:anyURI .
#
# CDs:People_in_Me  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "People in Me" ;
#         dcterms:creator                SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:byArtist        SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/339009a5-8ecc-4f78-af3c-0c7bccd5858a"^^xsd:anyURI .
#
# CDs:On_The_Night  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "On The Night" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5a2c11bb-292f-4e4a-a82f-fd5932612cf3"^^xsd:anyURI .
#
# CDs:Travelogue  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Travelogue" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d644ca21-3371-4519-beaf-b8cb505e0e3f"^^xsd:anyURI .
#
# CDs:In_Flight  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Flight" ;
#         dcterms:creator                SoloMusicArtist:Linda_Perry ;
#         bibliographica:byArtist        SoloMusicArtist:Linda_Perry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32ea2b63-848d-3bcb-9579-ad3ec0071569"^^xsd:anyURI .
#
# CDs:Misc   a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:comment             "Not sure what release this is; could be Anger Management." ;
#         rdfs:label               "Misc" ;
#         dcterms:creator          MusicGroup:Bombay_Black ;
#         bibliographica:byArtist  MusicGroup:Bombay_Black .
#
# CDs:Man_with_Horn  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Man with the Horn" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3303d8d5-1083-3437-8896-c71f5a7dd4c0"^^xsd:anyURI .
#
# CDs:Blind_Faith_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blind Faith" ;
#         dcterms:creator                MusicGroup:Blind_Faith ;
#         bibliographica:byArtist        MusicGroup:Blind_Faith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/53fa91ca-a2b9-463d-b78e-daca9894082a"^^xsd:anyURI .
#
# CDs:Fan_Dance  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fan Dance" ;
#         dcterms:creator                SoloMusicArtist:Sam_Phillips ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f8456548-acd0-4599-8538-05d30c762530"^^xsd:anyURI .
#
# CDs:Original_Recordings_Charlie_Parker
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Original Recordings of Charlie Parker" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05a9ca93-fce8-45c4-bd7f-92054958410d"^^xsd:anyURI .
#
# CDs:Nights_at_Keystone_v3
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nights at the Keystone, Volume 3" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2af210d7-0597-4cfd-af7c-aac3c11a51f5"^^xsd:anyURI .
#
# CDs:Before_Flood  a                       schema:MusicAlbum , mo:CD , mo:Record , mo:Release ;
#         rdfs:label                     "Before the Flood" ;
#         dcterms:creator                MusicGroup:The_Band , SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        MusicGroup:The_Band , SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d11eff0d-e0e7-35f4-b114-c90910028333"^^xsd:anyURI .
#
# CDs:Beautysleep  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Beautysleep" ;
#         dcterms:creator                SoloMusicArtist:Tanya_Donelly ;
#         bibliographica:byArtist        SoloMusicArtist:Tanya_Donelly ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dad3305b-ca1b-4fcb-b7ea-c11d22f5d627"^^xsd:anyURI .
#
# CDs:Homogenic  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Homogenic" ;
#         dcterms:creator                SoloMusicArtist:Bjork ;
#         bibliographica:byArtist        SoloMusicArtist:Bjork ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7a2ad97a-55e9-48a4-953b-45ddc10f7f0f"^^xsd:anyURI .
#
# CDs:Third_Eye_Open  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Third Eye Open" ;
#         dcterms:creator                MusicGroup:Hardware ;
#         bibliographica:byArtist        MusicGroup:Hardware ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ec74c53d-38b2-47ac-8ca6-48327955f4f7"^^xsd:anyURI .
#
# CDs:Irish_Heartbeat  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Irish Heartbeat" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f85eeb18-6079-4860-8c7f-e4a0741c1b58"^^xsd:anyURI .
#
# CDs:Mothers_Nightmare  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Mother's Nightmare" ;
#         dcterms:creator                MusicGroup:Left_Wing_Fascists ;
#         bibliographica:byArtist        MusicGroup:Left_Wing_Fascists ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dd7d1deb-78c0-4f99-845d-d580454cc2a8"^^xsd:anyURI .
#
# CDs:Misses  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Misses" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/62d8d0dc-ac50-3170-b42d-9ed2d2c6cee2"^^xsd:anyURI .
#
# CDs:Taming_the_Tiger  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Taming the Tiger" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a2ff067-a2dd-4755-ad1f-66d39675b00a"^^xsd:anyURI .
#
# CDs:Slidetime  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slidetime" ;
#         dcterms:creator                SoloMusicArtist:Joanna_Conner ;
#         bibliographica:byArtist        SoloMusicArtist:Joanna_Conner ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9d1c3a91-2e35-4516-84a4-19a4233ffd48"^^xsd:anyURI .
#
# CDs:Rise_and_Shine  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rise & Shine" ;
#         dcterms:creator                MusicGroup:The_Bears ;
#         bibliographica:byArtist        MusicGroup:The_Bears ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a9c91c5-09a2-44f4-bc2f-22562c09ec2c"^^xsd:anyURI .
#
# CDs:Retrospective_MF  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Retrospective (Live)" ;
#         dcterms:creator          SoloMusicArtist:Michael_Fracasso ;
#         bibliographica:byArtist  SoloMusicArtist:Michael_Fracasso .
#
# CDs:Dylan_Cash_Sessions  a                mo:Release , mo:Record , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "The Dylan/Cash Sessions" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan , SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash , SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60984c42-154f-46cc-ba2e-e7503f582646"^^xsd:anyURI .
#
# CDs:Hard_Nose_Highway  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hard Nose the Highway" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6002652-a05a-4cf3-bb9b-8941e6089ef4"^^xsd:anyURI .
#
# CDs:Dont_Look_Back  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Don’t Look Back" ;
#         dcterms:creator                SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4a2735a4-0899-4a86-a9fd-8e8800299531"^^xsd:anyURI .
#
# CDs:I_Just_Cant_Stop_It  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I Just Can't Stop It" ;
#         dcterms:creator                MusicGroup:English_Beat ;
#         bibliographica:byArtist        MusicGroup:English_Beat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0248c59e-1c5f-412c-beb9-36eb8ac5cfd6"^^xsd:anyURI .
#
# CDs:Paris_Texas  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Paris, Texas" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ef2780f-9fc1-33ff-80f6-4b4d65c4130a"^^xsd:anyURI .
#
# CDs:Broadway_Hard_Way  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Broadway The Hard Way" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b0e634eb-8a6c-4f85-92ef-57f892b099e7"^^xsd:anyURI .
#
# CDs:Crossing_Muddy_Waters
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crossing Muddy Waters" ;
#         dcterms:creator                SoloMusicArtist:John_Hiatt ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hiatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/754b83fe-d6f8-4bdd-b0d0-9440aea808d9"^^xsd:anyURI .
#
# CDs:Amazonas  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Amazonas" ;
#         dcterms:creator                SoloMusicArtist:Cal_Tjader ;
#         bibliographica:byArtist        SoloMusicArtist:Cal_Tjader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/74805ee7-3a48-4619-9590-e4bc56c0d298"^^xsd:anyURI .
#
# CDs:Sometime_Tuesday_Morning
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sometime Tuesday Morning" ;
#         dcterms:creator                SoloMusicArtist:Johnny_A ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_A ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e9f4277-5f98-4d9f-9429-caf0a9ea1fc6"^^xsd:anyURI .
#
# CDs:Visions_of_Plenty  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Visions of Plenty" ;
#         dcterms:creator                SoloMusicArtist:Kate_Campbell ;
#         bibliographica:byArtist        SoloMusicArtist:Kate_Campbell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3405d086-4c6b-44dc-b6ec-6f963ad22683"^^xsd:anyURI .
#
# CDs:Blues_Traveler_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blues Traveler" ;
#         dcterms:creator                MusicGroup:Blues_Traveler ;
#         bibliographica:byArtist        MusicGroup:Blues_Traveler ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6b28ecf0-94e6-48bb-aa2a-5ede325b675b"^^xsd:anyURI .
#
# CDs:Cold_Hard_Facts  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Cold Hard Facts" ;
#         dcterms:creator                MusicGroup:Del_McCoury_Band ;
#         bibliographica:byArtist        MusicGroup:Del_McCoury_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e428c96d-26e5-4458-a85b-ad4c45e18445"^^xsd:anyURI .
#
# CDs:Planet_Waves  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Planet Waves" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/aedd518d-d7e0-3595-80c7-54d2aad292f8"^^xsd:anyURI .
#
# CDs:Hot_Pants  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Pants" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fbd2ef1b-c9d9-4fc9-a05c-b456ea5ddefb"^^xsd:anyURI .
#
# CDs:Live_at_Luther_College
#         a                              mo:Record , mo:Release , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Live At Luther College" ;
#         dcterms:creator                SoloMusicArtist:Tim_Reynolds , SoloMusicArtist:Dave_Matthews ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_Reynolds , SoloMusicArtist:Dave_Matthews ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/79e912db-4f71-4fcb-b5be-aced98234ed3"^^xsd:anyURI .
#
# CDs:Double_Live  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Double Live" ;
#         dcterms:creator                MusicGroup:Butthole_Surfers ;
#         bibliographica:byArtist        MusicGroup:Butthole_Surfers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34e761bc-583e-4715-ac95-734d9d5c5ab0"^^xsd:anyURI .
#
# CDs:Living_In_Clip  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Living In Clip" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/26e2e2c5-be8f-3588-b845-9379c96b4630"^^xsd:anyURI .
#
# CDs:Flood_Live_Japan  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Flood" ;
#         dcterms:creator                SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:byArtist        SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d59cee98-ab1a-4a00-a629-2bbc7b25f4e7"^^xsd:anyURI .
#
# CDs:Afterglow_Live  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Afterglow Live" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3d410d1f-109a-46bb-96a3-496809e37f09"^^xsd:anyURI .
#
# CDs:Quintessential_Billie_Holiday_v7
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Quintessential Billie Holiday, Vol. 7" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/18383b88-cd98-4f38-a9ea-197092f8ec72"^^xsd:anyURI .
#
# CDs:Farmhouse  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Farmhouse" ;
#         dcterms:creator                MusicGroup:Phish ;
#         bibliographica:byArtist        MusicGroup:Phish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ccc7e75-4f0d-4794-b06b-057a7a6c9b21"^^xsd:anyURI .
#
# CDs:Quiet_Nights  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Quiet Nights" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c49d27d3-f464-4b27-9e74-a9a408b5926b"^^xsd:anyURI .
#
# CDs:Round_Room  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Round Room" ;
#         dcterms:creator                MusicGroup:Phish ;
#         bibliographica:byArtist        MusicGroup:Phish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/46c9f723-b188-49d6-9a29-971ae19198d7"^^xsd:anyURI .
#
# CDs:Retrograss  a                         schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Retrograss" ;
#         dcterms:creator                SoloMusicArtist:John_Hartford , SoloMusicArtist:Mike_Seeger , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hartford , SoloMusicArtist:Mike_Seeger , SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a10c3d7f-ad46-4c90-a7fc-e96b1f30fbf8"^^xsd:anyURI .
#
# CDs:An_Equal_Love  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "An Equal Love" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist        SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91374080-46c3-41f5-8b0e-9ac998f79a8e"^^xsd:anyURI .
#
# CDs:Aye    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ayé" ;
#         dcterms:creator                SoloMusicArtist:Angelique_Kidjo ;
#         bibliographica:byArtist        SoloMusicArtist:Angelique_Kidjo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/85dd67a5-2c3d-41bf-8f50-734ec1601eb7"^^xsd:anyURI .
#
# CDs:Common_One  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Common One" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/67f0303e-8311-4a9a-97f9-34a90d6d7423"^^xsd:anyURI .
#
# CDs:Been_Around_World  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Been All Around This World" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/384fe9c4-ce9f-4da9-8ab4-c7c6d0454d41"^^xsd:anyURI .
#
# CDs:Songs_of_Freedom  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Songs of Freedom" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9bca615a-93c0-4a1a-ae21-3282a955eed4"^^xsd:anyURI .
#
# CDs:Slow_Down  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slow Down" ;
#         dcterms:creator                SoloMusicArtist:Keb_Mo ;
#         bibliographica:byArtist        SoloMusicArtist:Keb_Mo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c539abbd-b84f-462a-b86d-3bab733b7613"^^xsd:anyURI .
#
# CDs:Immortal_Secrets  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Immortal Secrets" ;
#         dcterms:creator          SoloMusicArtist:Sibongile_Khumalo ;
#         bibliographica:byArtist  SoloMusicArtist:Sibongile_Khumalo .
#
# CDs:Waiting_For_Columbus
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Waiting For Columbus" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7689431-f016-48ca-a8c8-fb5a07800f46"^^xsd:anyURI .
#
# CDs:Fundamental  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fundamental" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02bbe911-91b7-41ea-8222-99e44e85617f"^^xsd:anyURI .
#
# CDs:Superfly  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Superfly" ;
#         dcterms:creator                SoloMusicArtist:Curtis_Mayfield ;
#         bibliographica:byArtist        SoloMusicArtist:Curtis_Mayfield ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df1c3d1f-7180-39b1-a367-8a0a7acb296a"^^xsd:anyURI .
#
# CDs:Collectors_Items  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Collectors’ Items" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6bd540a-db53-4919-b0e0-a812eb72d00f"^^xsd:anyURI .
#
# CDs:Tone_Poems  a                         mo:Release , mo:Record , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "Tone Poems" ;
#         dcterms:creator                SoloMusicArtist:Tony_Rice , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman , SoloMusicArtist:Tony_Rice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8f393422-710f-4313-ac0f-aa1c2181899c"^^xsd:anyURI .
#
# CDs:The_Sweet_Sunny_North
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Sweet Sunny North, Vol. 2" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3578718c-e29e-438b-b5b4-a12e3a94454d"^^xsd:anyURI .
#
# CDs:The_Delivery_Man  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Delivery Man" ;
#         dcterms:creator                MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:byArtist        MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/29e8451e-9dd4-447f-836a-a7195014864a"^^xsd:anyURI .
#
# CDs:Cool   a                              mo:Release , mo:Record , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Cool" ;
#         dcterms:creator                SoloMusicArtist:Earl_Klugh , SoloMusicArtist:Bob_James ;
#         bibliographica:byArtist        SoloMusicArtist:Earl_Klugh , SoloMusicArtist:Bob_James ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6f96d073-87ad-4e66-befa-ea3e577c644d"^^xsd:anyURI .
#
# CDs:Live_at_Fillmore_East
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Fillmore East (March 7, 1970): It's About That Time" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6b6ec452-f4c0-4f3d-8191-9d1494af6fa4"^^xsd:anyURI .
#
# CDs:Where_It_Goes  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Where It Goes" ;
#         dcterms:creator                SoloMusicArtist:Lori_Carson ;
#         bibliographica:byArtist        SoloMusicArtist:Lori_Carson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2ed8400-4a81-4585-a275-e2a50f38fa85"^^xsd:anyURI .
#
# CDs:Scary_Monsters  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Scary Monsters (and Super Creeps)" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/968b7e86-4645-3417-b6c0-59d8c2b9862f"^^xsd:anyURI .
#
# CDs:Shamans_Breath  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shaman's Breath" ;
#         dcterms:creator                SoloMusicArtist:Professor_Trance ;
#         bibliographica:byArtist        SoloMusicArtist:Professor_Trance ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/181c48c6-2547-446d-a0ef-9bc84eb5953c"^^xsd:anyURI .
#
# CDs:Gravity_FF  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gravity" ;
#         dcterms:creator                SoloMusicArtist:Fred_Frith ;
#         bibliographica:byArtist        SoloMusicArtist:Fred_Frith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be81c7e1-3488-45de-bd25-8aeaad8a3fad"^^xsd:anyURI .
#
# CDs:Thirty_Anniversaire  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "30e Anniversaire" ;
#         dcterms:creator                SoloMusicArtist:Edith_Piaf ;
#         bibliographica:byArtist        SoloMusicArtist:Edith_Piaf ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86db16e8-deb7-492c-91f4-7dfdf7486644"^^xsd:anyURI .
#
# CDs:Made_To_Love_Magic  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Made to Love Magic" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1e3a0c5-fb34-47a8-83ca-4278aa47905d"^^xsd:anyURI .
#
# CDs:With_Enemies_Like_These
#         a                              schema:MusicAlbum , mo:Release , mo:CD , mo:Record ;
#         rdfs:label                     "With Enemies Like These, Who Needs Friends?" ;
#         dcterms:creator                SoloMusicArtist:Fred_Frith , SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser , SoloMusicArtist:Fred_Frith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fe982b21-5039-4f0c-9224-6203fb1c3ee2"^^xsd:anyURI .
#
# CDs:The_Convincer  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Convincer" ;
#         dcterms:creator                SoloMusicArtist:Nick_Lowe ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Lowe ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/23ede523-1685-4379-9280-6237b785d72b"^^xsd:anyURI .
#
# CDs:Mystery_Box  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mickey Hart's Mystery Box" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92eb602c-ba08-4e11-9082-33506d12f3a8"^^xsd:anyURI .
#
# CDs:Siyabamukela  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Siyabamukela" ;
#         dcterms:creator                MusicGroup:Amaduduzo ;
#         bibliographica:byArtist        MusicGroup:Amaduduzo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/fb46f60d-700f-4de4-b1da-f2a885327eea"^^xsd:anyURI .
#
# CDs:Last_Time_Around  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Last Time Around" ;
#         dcterms:creator                MusicGroup:Buffalo_Springfield ;
#         bibliographica:byArtist        MusicGroup:Buffalo_Springfield ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/fb39d4c7-d68c-36d1-a2c2-93fc7ccbdcc8"^^xsd:anyURI .
#
# CDs:Great_Summit  a                       mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "The Great Summit: The Master Takes" ;
#         dcterms:creator                SoloMusicArtist:Duke_Ellington , SoloMusicArtist:Louis_Armstrong ;
#         bibliographica:byArtist        SoloMusicArtist:Louis_Armstrong , SoloMusicArtist:Duke_Ellington ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c8b5d81f-f4f7-35ee-b183-c76db24dd7e2"^^xsd:anyURI .
#
# CDs:Bachelor_No_2  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bachelor No. 2" ;
#         dcterms:creator                SoloMusicArtist:Aimee_Mann ;
#         bibliographica:byArtist        SoloMusicArtist:Aimee_Mann ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/595565db-6bfd-4772-a865-fa91d0259f53"^^xsd:anyURI .
#
# CDs:Crosswinds  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crosswinds" ;
#         dcterms:creator                MusicGroup:Capercaillie ;
#         bibliographica:byArtist        MusicGroup:Capercaillie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1c2ad27-c1c2-4b6a-9e0e-87a88525cce7"^^xsd:anyURI .
#
# CDs:Frogs_For_Snakes  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Frogs For Snakes" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01c41c91-96d6-42ae-842b-9d11157c4fdf"^^xsd:anyURI .
#
# CDs:Deeper_Still  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deeper Still" ;
#         dcterms:creator                SoloMusicArtist:Beth_Nielsen_Chapman ;
#         bibliographica:byArtist        SoloMusicArtist:Beth_Nielsen_Chapman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9d9560ff-bac3-43ef-8ded-442d34ec8d68"^^xsd:anyURI .
#
# CDs:Live_At_It_Club  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the It Club" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4fd2baec-550d-43a3-a802-2180d2108203"^^xsd:anyURI .
#
# CDs:Magic_Two  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Magic Two" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b8f4399c-05c6-45ec-8213-126cfb4e1c31"^^xsd:anyURI .
#
# CDs:Time_Out_of_Mind  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Time Out of Mind" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/dad1dada-1fda-3186-beb7-3bc80e90f9e0"^^xsd:anyURI .
#
# CDs:Together_Again  a                     mo:Record , schema:MusicAlbum , mo:Release , mo:CD ;
#         rdfs:label                     "Together Again - Live" ;
#         dcterms:creator                SoloMusicArtist:BB_King , SoloMusicArtist:Bobby_Bland ;
#         bibliographica:byArtist        SoloMusicArtist:Bobby_Bland , SoloMusicArtist:BB_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5318f8d-415a-43b5-bcf5-57ef11428c9a"^^xsd:anyURI .
#
# CDs:Together_Through_Life
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Together Through Life" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/2202f7cc-6ce1-3aea-85b0-163347528402"^^xsd:anyURI .
#
# CDs:Nocturama  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nocturama" ;
#         dcterms:creator                MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:byArtist        MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d4c4e73b-295a-3461-9ff8-5607969ae535"^^xsd:anyURI .
#
# CDs:Complete_Recordings_RJ
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Complete Recordings" ;
#         dcterms:creator                SoloMusicArtist:Robert_Johnson ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Johnson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5150f446-9301-4e37-bb9e-c903f44f84bb"^^xsd:anyURI .
#
# CDs:Time_Out_SN  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Time Out" ;
#         dcterms:creator                SoloMusicArtist:Sainkho_Namtchylak ;
#         bibliographica:byArtist        SoloMusicArtist:Sainkho_Namtchylak ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b81ce43f-8bd4-476b-b386-9fde3c30b789"^^xsd:anyURI .
#
# CDs:Me_Myself_I  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Me Myself I" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6e79ccba-7f40-3d24-ab7d-ea8ddd89be75"^^xsd:anyURI .
#
# CDs:Wheels_of_Fire  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wheels of Fire" ;
#         dcterms:creator                MusicGroup:Cream ;
#         bibliographica:byArtist        MusicGroup:Cream ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/747a1c73-5742-3f0f-8c45-e90629a911c9"^^xsd:anyURI .
#
# CDs:Midnight_Lonesome  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Midnight and Lonesome" ;
#         dcterms:creator                SoloMusicArtist:Buddy_Miller ;
#         bibliographica:byArtist        SoloMusicArtist:Buddy_Miller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/156117c2-3c70-475b-ad43-bb92eb2a0d93"^^xsd:anyURI .
#
# CDs:Unmitigated_Audacity
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unmitigated Audacity" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/94be3266-5998-40bf-a62c-996dd89c2a23"^^xsd:anyURI .
#
# CDs:Pieta_Brown_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pieta Brown" ;
#         dcterms:creator                SoloMusicArtist:Pieta_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Pieta_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f4ec25ff-4fd2-4ee6-b9ce-426639f0f63a"^^xsd:anyURI .
#
# CDs:Luck_Of_The_Draw  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Luck of the Draw" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2316a494-0176-426d-abcb-508a420372d3"^^xsd:anyURI .
#
# CDs:The_Legacy  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Legacy 1933-1958" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01ab06a7-49f5-4cb7-9ff6-29b998c2d9c7"^^xsd:anyURI .
#
# CDs:Complete_Concert_1964
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete Concert 1964: My Funny Valentine + Four & More" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f53ce59-1396-4c1f-b31b-52ed735bcece"^^xsd:anyURI .
#
# CDs:League_of_Gentlemen_CD
#         a                              schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "The League of Gentlemen" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp , MusicGroup:League_of_Gentlemen ;
#         bibliographica:byArtist        MusicGroup:League_of_Gentlemen , SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f9871a60-2d3b-45ca-a304-b5b40dc5ecbc"^^xsd:anyURI .
#
# CDs:To_Venus_and_Back  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "To Venus and Back" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/39ea85e0-4db3-3a2b-bc66-fe1ca6caa201"^^xsd:anyURI .
#
# CDs:Premonition  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Premonition" ;
#         dcterms:creator                SoloMusicArtist:John_Fogerty ;
#         bibliographica:byArtist        SoloMusicArtist:John_Fogerty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/06234b1d-bd5a-483e-95f2-7b4c25e7dba2"^^xsd:anyURI .
#
# CDs:Gettin_Around  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gettin' Around" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99ff7940-a89d-4778-8892-abbc65b0bcd5"^^xsd:anyURI .
#
# CDs:Strawberry_Lover  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strawberry Lover" ;
#         dcterms:creator                SoloMusicArtist:Jess_Klein ;
#         bibliographica:byArtist        SoloMusicArtist:Jess_Klein ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be965971-b73d-417d-b950-a002b4400e21"^^xsd:anyURI .
#
# CDs:Guitar_on_Fire  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Guitar on Fire: The Atlantic Sessions" ;
#         dcterms:creator                SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:byArtist        SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/da27dab2-990a-421f-bea4-da368d3e7cc0"^^xsd:anyURI .
#
# CDs:Unearthed  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unearthed" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4321855e-8e8e-4786-8506-28e6d69633b9"^^xsd:anyURI .
#
# CDs:Dixie_Chicken  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dixie Chicken" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c7887534-10f6-4b4c-a96e-9f839bbd3ec6"^^xsd:anyURI .
#
# CDs:Lone_Rhino  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lone Rhino" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e92792f7-ed85-4e80-8e38-c06646222c03"^^xsd:anyURI .
#
# CDs:Footsteps_Dark  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Footsteps in the Dark" ;
#         dcterms:creator                SoloMusicArtist:Cat_Stevens ;
#         bibliographica:byArtist        SoloMusicArtist:Cat_Stevens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/139f1eef-f3c9-4fed-b492-f406fcade9d8"^^xsd:anyURI .
#
# CDs:Feed_Us  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Feed-Us" ;
#         dcterms:creator                MusicGroup:Cradle_of_Thorns ;
#         bibliographica:byArtist        MusicGroup:Cradle_of_Thorns ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd1fac5e-e1d5-4d91-ba01-8ab0ff4430f0"^^xsd:anyURI .
#
# CDs:Desire  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Desire" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/fc325dd3-73ed-36aa-9c77-6b65a958e3cf"^^xsd:anyURI .
#
# CDs:Passion_Grace_Fire  a                 schema:MusicAlbum , mo:Record , mo:Release , mo:CD ;
#         rdfs:label                     "Passion, Grace and Fire" ;
#         dcterms:creator                SoloMusicArtist:Paco_de_Lucia , SoloMusicArtist:Al_DiMeola , SoloMusicArtist:John_McLaughlin ;
#         bibliographica:byArtist        SoloMusicArtist:Al_DiMeola , SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Paco_de_Lucia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/29a412d2-5252-3a6c-8aaf-3f3158e8bbf8"^^xsd:anyURI .
#
# CDs:Bright_Size_Life  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bright Size Life" ;
#         dcterms:creator                SoloMusicArtist:Pat_Metheny ;
#         bibliographica:byArtist        SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91e3f8f6-0c51-4c50-96ca-28bc1757297d"^^xsd:anyURI .
#
# CDs:Vagabond_Lullabies  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Vagabond Lullabies" ;
#         dcterms:creator                MusicGroup:Po_Girl ;
#         bibliographica:byArtist        MusicGroup:Po_Girl ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/50eaecf5-a0e8-4065-82bc-1e29487c2afc"^^xsd:anyURI .
#
# CDs:Quintessential_Billie_Holiday_v2
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Quintessential Billie Holiday, Vol. 2" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b66dec9a-e836-4cdc-9829-ec0dae9ae440"^^xsd:anyURI .
#
# CDs:Ellington_Coltrane  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Duke Ellington & John Coltrane Trio" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane , SoloMusicArtist:Duke_Ellington ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/904b56d3-8fb9-367e-ae5f-f198d2a6bb3b"^^xsd:anyURI .
#
# CDs:Daughters_Celtic_Moon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Daughters Of The Celtic Moon" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Lynne ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Lynne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/647b7461-76f5-49e6-bfb7-bb7234897f69"^^xsd:anyURI .
#
# CDs:Alices_Restaurant  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Alice's Restaurant" ;
#         dcterms:creator                SoloMusicArtist:Arlo_Guthrie ;
#         bibliographica:byArtist        SoloMusicArtist:Arlo_Guthrie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bc0307b3-229a-4952-ab70-d6b95010d6c6"^^xsd:anyURI .
#
# CDs:Blue_Horse  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue Horse" ;
#         dcterms:creator                MusicGroup:The_Be_Good_Tanyas ;
#         bibliographica:byArtist        MusicGroup:The_Be_Good_Tanyas ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1ff4ea24-a87a-4240-a76c-d6249f559db4"^^xsd:anyURI .
#
# CDs:Cal_Soundtrack  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cal (Music from the Film)" ;
#         dcterms:creator                SoloMusicArtist:Mark_Knopfler ;
#         bibliographica:byArtist        SoloMusicArtist:Mark_Knopfler ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0418b46a-fff4-49cb-9b3e-81d985c78ef8"^^xsd:anyURI .
#
# CDs:Rolling_Thunder  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rolling Thunder" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/182ca04f-6c88-4eff-aab5-1fe34c86df0c"^^xsd:anyURI .
#
# CDs:Sweet_Brown_Sugar  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sweet Brown Sugar" ;
#         dcterms:creator                SoloMusicArtist:Rosie_Ledet ;
#         bibliographica:byArtist        SoloMusicArtist:Rosie_Ledet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/60fa5864-c853-4a8b-9605-0c17cc75609a"^^xsd:anyURI .
#
# CDs:Lizard_Music  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Lizard Vision" ;
#         dcterms:creator          MusicGroup:Cheifetz_Johansen ;
#         bibliographica:byArtist  MusicGroup:Cheifetz_Johansen .
#
# CDs:Live_From_Neon_Park  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live from Neon Park" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/48f3bf81-b523-41a4-aa5a-f2f937bd3e63"^^xsd:anyURI .
#
# CDs:Blender  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blender" ;
#         dcterms:creator                MusicGroup:Murmurs ;
#         bibliographica:byArtist        MusicGroup:Murmurs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1161ac28-ed83-4a6c-8ee4-41d0577415a5"^^xsd:anyURI .
#
# CDs:Catfish_Rising  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Catfish Rising" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7c1793d9-7403-3182-a7fd-c5787e8ed788"^^xsd:anyURI .
#
# CDs:Broken_Things  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Broken Things" ;
#         dcterms:creator                SoloMusicArtist:Julie_Miller ;
#         bibliographica:byArtist        SoloMusicArtist:Julie_Miller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83609a0e-d26a-4bc7-9938-3b7775c978b1"^^xsd:anyURI .
#
# CDs:Echoes_of_Brazil  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Echoes of Brazil" ;
#         dcterms:creator                SoloMusicArtist:Badi_Assad ;
#         bibliographica:byArtist        SoloMusicArtist:Badi_Assad ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c69cdb18-5195-4a43-9e26-9d66622fd926"^^xsd:anyURI .
#
# CDs:Mazurka_Berserker  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Mazurka Berserker" ;
#         dcterms:creator          SoloMusicArtist:John_Kirkpatrick ;
#         bibliographica:byArtist  SoloMusicArtist:John_Kirkpatrick .
#
# CDs:Feel_The_Sun  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Feel The Sun" ;
#         dcterms:creator          MusicGroup:Band_Du_Jour ;
#         bibliographica:byArtist  MusicGroup:Band_Du_Jour .
#
# CDs:Parallel_Dreams  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Parallel Dreams" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fe67157b-e812-3228-8b3c-26ada5df48b6"^^xsd:anyURI .
#
# CDs:Ladysmith_Black_Mambazo_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ladysmith Black Mambazo" ;
#         dcterms:creator                MusicGroup:Ladysmith_Black_Mambazo ;
#         bibliographica:byArtist        MusicGroup:Ladysmith_Black_Mambazo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/436851f1-2e35-4666-88c8-c448ba1335e6"^^xsd:anyURI .
#
# CDs:Double_Barrel_Blues  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Double Barrel Blues" ;
#         dcterms:creator                MusicGroup:Barrel_of_Blues ;
#         bibliographica:byArtist        MusicGroup:Barrel_of_Blues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/81ca2960-9b7b-4715-a58b-0ea48965793e"^^xsd:anyURI .
#
# CDs:Birth_of_the_Cool  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Birth of the Cool" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5dd71bc5-612c-46d4-ac9c-d757268750a9"^^xsd:anyURI .
#
# CDs:Alright_Again  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Alright Again!" ;
#         dcterms:creator                SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Clarence_Gatemouth_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2c4f7d83-a2b0-475c-b12f-9aaf498f66a3"^^xsd:anyURI .
#
# CDs:Exposure  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Exposure" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1cd700f5-c2cb-40fa-aa06-6ad14701f7fb"^^xsd:anyURI .
#
# CDs:True_False_Identity  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The True False Identity" ;
#         dcterms:creator                SoloMusicArtist:T_Bone_Burnett ;
#         bibliographica:byArtist        SoloMusicArtist:T_Bone_Burnett ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/198e2965-4436-4a65-a823-36f2944a624b"^^xsd:anyURI .
#
# CDs:Live_BMW  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live!" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/452cf962-f646-4150-ba46-450965e84488"^^xsd:anyURI .
#
# CDs:Michael_Doucet_Cajun_Brew
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Michael Doucet & Cajun Brew" ;
#         dcterms:creator                SoloMusicArtist:Michael_Doucet ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Doucet ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/594585f1-546a-4425-8461-6637d1f2efc2"^^xsd:anyURI .
#
# CDs:Man_Who_Sold_World  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Man Who Sold the World" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/246a9545-4a25-3204-a817-e52f9e5ae730"^^xsd:anyURI .
#
# CDs:Certain_Things  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Certain Things" ;
#         dcterms:creator          SoloMusicArtist:Jano ;
#         bibliographica:byArtist  SoloMusicArtist:Jano .
#
# CDs:Shahen_Shah  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shahen-Shah" ;
#         dcterms:creator                SoloMusicArtist:Nusrat_Fateh_Ali_Khan ;
#         bibliographica:byArtist        SoloMusicArtist:Nusrat_Fateh_Ali_Khan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32a3a19a-803a-4b92-b362-a057cce3a5d7"^^xsd:anyURI .
#
# CDs:Reckoning_Revelling  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Reckoning/Revelling" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/1ebf8024-e2d9-3186-aa40-1f292a4ffa6c"^^xsd:anyURI .
#
# CDs:Latin_Kick  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Latin Kick" ;
#         dcterms:creator                SoloMusicArtist:Cal_Tjader ;
#         bibliographica:byArtist        SoloMusicArtist:Cal_Tjader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5e2f49bb-3e91-32f4-ae3f-f16cf543d255"^^xsd:anyURI .
#
# CDs:Anthology_Emmylou_Harris
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anthology: The Warner/Reprise Years" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e4ac9f81-bd10-488b-9b29-79f45aacfc20"^^xsd:anyURI .
#
# CDs:Aoxomoxoa  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Aoxomoxoa" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/15c10195-596b-4f4f-b62e-552d5df60ca2"^^xsd:anyURI .
#
# CDs:Amanda_Marshall_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Amanda Marshall" ;
#         dcterms:creator                SoloMusicArtist:Amanda_Marshall ;
#         bibliographica:byArtist        SoloMusicArtist:Amanda_Marshall ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0375a849-d8b1-4851-9faf-2ea75e78173b"^^xsd:anyURI .
#
# CDs:Live_in_Seattle  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live In Seattle" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8cc94888-f0cf-4433-a6f5-0a8c1bbd860c"^^xsd:anyURI .
#
# CDs:Gone_To_Earth  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gone To Earth" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1e72db0b-fbff-3eeb-b466-aa07bc3ab2cf"^^xsd:anyURI .
#
# CDs:Live_BF  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d6349333-58c2-4aa1-bc07-be5fb9877e60"^^xsd:anyURI .
#
# CDs:Only_Talking_Sense  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Only Talking Sense" ;
#         dcterms:creator                MusicGroup:Finn_Bros ;
#         bibliographica:byArtist        MusicGroup:Finn_Bros ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/57c8a1d9-653c-41db-bd8a-97b4093acf38"^^xsd:anyURI .
#
# CDs:Barbecue_King  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Barbecue King" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91369b28-e3c5-4e6b-8c2e-bc4020fc4aa3"^^xsd:anyURI .
#
# CDs:Ten_Year_Night  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ten Year Night" ;
#         dcterms:creator                SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:byArtist        SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0805ac90-d2b3-437f-9aee-f9c1221c889e"^^xsd:anyURI .
#
# CDs:Mirror_Ball_Concert  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mirrorball: The Complete Concert" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86d36529-98a4-35ca-8b84-a25103ffa3d2"^^xsd:anyURI .
#
# CDs:Original_Bad_Co_Anthology
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The ‘Original’ Bad Co. Anthology" ;
#         dcterms:creator                MusicGroup:Bad_Company ;
#         bibliographica:byArtist        MusicGroup:Bad_Company ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/191f7ef5-d208-4959-8422-1159844bebb3"^^xsd:anyURI .
#
# CDs:Heavy_Horses  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Heavy Horses" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e2b928b1-4b85-3095-9926-63d3f4af1172"^^xsd:anyURI .
#
# CDs:Whale_Rider  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Whale Rider" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Gerrard ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Gerrard ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b1e8307-ccd4-353a-81b4-16bada756637"^^xsd:anyURI .
#
# CDs:Mingus_Mingus  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus Mingus Mingus Mingus Mingus" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/70d13ec1-e731-3775-b70f-c1a2fb416828"^^xsd:anyURI .
#
# CDs:Chavez_Ravine  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chávez Ravine" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3dbe92e3-772e-41fd-9d6a-a321f6202835"^^xsd:anyURI .
#
# CDs:Someone_to_Love  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Someone to Love" ;
#         dcterms:creator                SoloMusicArtist:Charles_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b673500-3d8d-4899-a373-665849a1cb9e"^^xsd:anyURI .
#
# CDs:Shuggie_Otis_mix  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Shuggie Otis mix" ;
#         dcterms:creator          SoloMusicArtist:Shuggie_Otis ;
#         bibliographica:byArtist  SoloMusicArtist:Shuggie_Otis .
#
# CDs:Like_Never_Before  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Like Never Before" ;
#         dcterms:creator                SoloMusicArtist:Taj_Mahal ;
#         bibliographica:byArtist        SoloMusicArtist:Taj_Mahal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f88cf172-6372-4880-8399-5e004257c885"^^xsd:anyURI .
#
# CDs:Does_Humor_Belong_Music
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Does Humor Belong in Music?" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0a614485-b62c-4d7f-b083-7c603efb2b1c"^^xsd:anyURI .
#
# CDs:Ubuhle_Bemvelo  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ubuhle Bemvelo" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eeab9dd6-ec67-431a-be76-786fa821d1b1"^^xsd:anyURI .
#
# CDs:Vieux_Vinyls  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Vieux Vinyls" ;
#         dcterms:creator                SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c8f60c5b-a1eb-4db0-970f-7ecee06a4b95"^^xsd:anyURI .
#
# CDs:Busters_Happy_Hour  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buster’s Happy Hour" ;
#         dcterms:creator                SoloMusicArtist:David_Johansen ;
#         bibliographica:byArtist        SoloMusicArtist:David_Johansen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc0553c3-3981-4195-a8a3-4f9b20d93328"^^xsd:anyURI .
#
# CDs:Revolution_Starts_Now
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Revolution Starts Now" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Earle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7e249817-bd03-47d4-9ed3-9206d31ce291"^^xsd:anyURI .
#
# CDs:Spirit_of_Forest  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spirit of the Forest" ;
#         dcterms:creator                MusicGroup:Baka_Beyond ;
#         bibliographica:byArtist        MusicGroup:Baka_Beyond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/cd30cc39-3855-3e83-ab92-623831c66829"^^xsd:anyURI .
#
# CDs:Bring_the_Family  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bring the Family" ;
#         dcterms:creator                SoloMusicArtist:John_Hiatt ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hiatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4f77c160-baf5-40bb-9e16-d62d9cce1870"^^xsd:anyURI .
#
# CDs:Buena_Vista_Social_Club_OP
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buenas Vista Social Club Presents Omara Portuondo" ;
#         dcterms:creator                SoloMusicArtist:Omara_Portuondo ;
#         bibliographica:byArtist        SoloMusicArtist:Omara_Portuondo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/42d995d4-a13a-45e1-81e2-2f04694e8918"^^xsd:anyURI .
#
# CDs:Past_Light  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Past Light" ;
#         dcterms:creator                SoloMusicArtist:William_Ackerman ;
#         bibliographica:byArtist        SoloMusicArtist:William_Ackerman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/55c13f29-f80f-4e32-9bcc-564c448ec6cf"^^xsd:anyURI .
#
# CDs:Live_at_Fillmore_East_JH
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Fillmore East" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/54b68e60-4431-444d-b32c-0204c1cedebd"^^xsd:anyURI .
#
# CDs:Billies_Blues  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Billie’s Blues" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fcc703ec-6fe1-4835-ae36-1d515272b030"^^xsd:anyURI .
#
# CDs:Golden_Palminos_History
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Golden Palominos : A History (1982-1985)" ;
#         dcterms:creator                MusicGroup:Golden_Palominos ;
#         bibliographica:byArtist        MusicGroup:Golden_Palominos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d82699c9-aa44-42de-9867-0975a729bca4"^^xsd:anyURI .
#
# CDs:Rainbow_Bridge  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rainbow Bridge" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b54dbe90-c811-3f23-ae53-ff6e6af9c2e0"^^xsd:anyURI .
#
# CDs:Way_Back_to_Paradise
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Way Back to Paradise" ;
#         dcterms:creator                SoloMusicArtist:Ashley_MacIsaac ;
#         bibliographica:byArtist        SoloMusicArtist:Ashley_MacIsaac ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3bacac9f-c0bf-4feb-8b52-cba1fb437c36"^^xsd:anyURI .
#
# CDs:Modern_Times  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Modern Times" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d300b74b-02b4-33e3-998e-e4405e8e6580"^^xsd:anyURI .
#
# CDs:Living_In_Past  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Living in the Past" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/52a31f6c-1e07-4d4c-91f1-ee6675325cf5"^^xsd:anyURI .
#
# CDs:Dizzy_Gillespie_Newport
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dizzy Gillespie At Newport" ;
#         dcterms:creator                SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:byArtist        SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3c457d38-634e-4a0d-93d1-5cf2977d3f43"^^xsd:anyURI .
#
# CDs:Live_at_Sweetwater  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Sweetwater" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e97471b7-7781-45e2-af11-00e8ed9b69fb"^^xsd:anyURI .
#
# CDs:Too_Long_Exile  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Too Long in Exile" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5a043100-4423-4b3a-b28f-77d43c05fde7"^^xsd:anyURI .
#
# CDs:Get_Back  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ghost In The Machine" ;
#         dcterms:creator                MusicGroup:Ike_Tina_Turner ;
#         bibliographica:byArtist        MusicGroup:Ike_Tina_Turner ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9883dc4e-7ea0-4da3-b2ad-2ff824aae591"^^xsd:anyURI .
#
# CDs:For_The_Roses  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "For the Roses" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a1724de5-f3fe-4c9c-88f6-afc465183f53"^^xsd:anyURI .
#
# CDs:The_Promise  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Promise" ;
#         dcterms:creator                SoloMusicArtist:John_McLaughlin ;
#         bibliographica:byArtist        SoloMusicArtist:John_McLaughlin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53cd553c-1924-47bd-a687-636c9ff8c9c8"^^xsd:anyURI .
#
# CDs:Summer_Meltdown  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Summer Meltdown 7" ;
#         dcterms:creator          MusicGroup:Flowmotion ;
#         bibliographica:byArtist  MusicGroup:Flowmotion .
#
# CDs:Euphoria  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Euphoria" ;
#         dcterms:creator                MusicGroup:Leftover_Salmon ;
#         bibliographica:byArtist        MusicGroup:Leftover_Salmon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/87efb923-d665-4ac5-8f94-90d50d67cf04"^^xsd:anyURI .
#
# CDs:Humpty_Dumpty  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Humpty Dumpty" ;
#         dcterms:creator                SoloMusicArtist:Aimee_Mann ;
#         bibliographica:byArtist        SoloMusicArtist:Aimee_Mann ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d4329f26-8577-4806-ab10-825f21846ba3"^^xsd:anyURI .
#
# CDs:Settin_the_Pace  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Settin' the Pace" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2790082e-ca3f-40c6-9e62-05b6bd656f7b"^^xsd:anyURI .
#
# CDs:Blow_By_Blow  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blow By Blow" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Beck ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Beck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/95420b2e-d645-4582-b7ad-6c5f28bfec76"^^xsd:anyURI .
#
# CDs:Complete_Birth_Of_Cool
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete Birth of the Cool" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a089bc8b-1890-4270-b75b-0acaf6493e93"^^xsd:anyURI .
#
# CDs:Madman_Across_Water  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Madman Across the Water" ;
#         dcterms:creator                SoloMusicArtist:Elton_John ;
#         bibliographica:byArtist        SoloMusicArtist:Elton_John ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/255f97cc-a7c5-3691-b3a4-e7146e391d8f"^^xsd:anyURI .
#
# CDs:Hoodoo_Moon  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hoodoo Moon" ;
#         dcterms:creator                SoloMusicArtist:Kenny_Neal ;
#         bibliographica:byArtist        SoloMusicArtist:Kenny_Neal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/73c651d4-1e58-411d-a32e-98c34f82f290"^^xsd:anyURI .
#
# CDs:Faust_RN  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Randy Newman's Faust" ;
#         dcterms:creator                SoloMusicArtist:Randy_Newman ;
#         bibliographica:byArtist        SoloMusicArtist:Randy_Newman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/af5dade3-3251-4a1c-bfb5-0533d56e3e3f"^^xsd:anyURI .
#
# CDs:Clock_Without_Hands  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Clock Without Hands" ;
#         dcterms:creator                SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:byArtist        SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f085d53f-f811-48b6-8c72-058c118923dc"^^xsd:anyURI .
#
# CDs:Coltrane_Plays_Blues
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Coltrane Plays the Blues" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e18b9dad-7dc9-4dbc-a007-d9f658f7d6fe"^^xsd:anyURI .
#
# CDs:Backbone  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Backbone" ;
#         dcterms:creator                SoloMusicArtist:Annie_Gallup ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Gallup ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/307e8ded-3da4-424c-bd66-38ac79738ed1"^^xsd:anyURI .
#
# CDs:Something_for_Everyone
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Something for Everybody" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/1ca7b25c-dd1b-4dff-a3f3-cfacece12c52"^^xsd:anyURI .
#
# CDs:No_Material  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Material" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/414f52a8-9702-44b0-92ac-f00f9cdddc55"^^xsd:anyURI .
#
# CDs:Motor_City_Moments  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Motor City Moments" ;
#         dcterms:creator                SoloMusicArtist:Regina_Carter ;
#         bibliographica:byArtist        SoloMusicArtist:Regina_Carter ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/65ef3f04-39df-44b9-af20-d0046b4db403"^^xsd:anyURI .
#
# CDs:Merriweather_Post_Pavilion
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pure Jerry: Merriweather Post Pavilion - September 1 & 2, 1989" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f45efc80-447d-41f3-91a6-df4a55d5957c"^^xsd:anyURI .
#
# CDs:Smash_Scatteration  a                 schema:MusicAlbum , mo:Release , mo:CD , mo:Record ;
#         rdfs:label                     "Smash & Scatteration" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell , SoloMusicArtist:Vernon_Reid ;
#         bibliographica:byArtist        SoloMusicArtist:Vernon_Reid , SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5545706b-ba5b-48ab-9b68-022b450963d9"^^xsd:anyURI .
#
# CDs:It_Had_To_Happen  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "It Had to Happen" ;
#         dcterms:creator                SoloMusicArtist:James_McMurtry ;
#         bibliographica:byArtist        SoloMusicArtist:James_McMurtry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/abe45edf-b97a-40e5-8f2c-b8edd6a76f59"^^xsd:anyURI .
#
# CDs:Hells_Ditch  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hell's Ditch" ;
#         dcterms:creator                MusicGroup:Pogues ;
#         bibliographica:byArtist        MusicGroup:Pogues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/16d76ea5-fcfd-3e36-af70-c6d5cf26a0c7"^^xsd:anyURI .
#
# CDs:Edgewise  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Edgewise" ;
#         dcterms:creator                SoloMusicArtist:Vance_Gilbert ;
#         bibliographica:byArtist        SoloMusicArtist:Vance_Gilbert ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/64580a64-749a-4941-84e2-691ab4e08945"^^xsd:anyURI .
#
# CDs:Feed_Your_Dog  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Feed Your Dog" ;
#         dcterms:creator          SoloMusicArtist:Junis_Ponds ;
#         bibliographica:byArtist  SoloMusicArtist:Junis_Ponds .
#
# CDs:Do_What_You_Like  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Do What You Like" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/288ebe0d-ec8c-47fd-971b-448fbb32c8ec"^^xsd:anyURI .
#
# CDs:Complete_Columbia_Recordings
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete Columbia Studio Recordings 1965-1968" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/20106bf8-d701-49e6-8c80-84ade7eadd2d"^^xsd:anyURI .
#
# CDs:Live_at_Blues_Alley  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Blues Alley" ;
#         dcterms:creator                SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:byArtist        SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2c63797-efe3-46a0-b916-cebc93169eb1"^^xsd:anyURI .
#
# CDs:Air_Force  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ginger Baker's Air Force" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c46332ee-1a92-421a-bef5-ddbc5da77002"^^xsd:anyURI .
#
# CDs:Victims  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Victims" ;
#         dcterms:creator                SoloMusicArtist:Lucky_Dube ;
#         bibliographica:byArtist        SoloMusicArtist:Lucky_Dube ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/eb26c05b-519d-478b-9281-021969b1bdff"^^xsd:anyURI .
#
# CDs:Gravity_bonus_disc  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gravity (bonus disc)" ;
#         dcterms:creator                SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:byArtist        SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/30183d1e-5e82-4e4e-aa21-24acb295d0d3"^^xsd:anyURI .
#
# CDs:Buena_Vista_Social_Club_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buena Vista Social Club" ;
#         dcterms:creator                MusicGroup:Buena_Vista_Social_Club ;
#         bibliographica:byArtist        MusicGroup:Buena_Vista_Social_Club ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/32bbab8e-02c0-30d2-9e23-a19739864b84"^^xsd:anyURI .
#
# CDs:Morris_On  a                          schema:MusicAlbum , mo:Release , mo:CD , mo:Record ;
#         rdfs:label                     "Morris On" ;
#         dcterms:creator                SoloMusicArtist:Richard_Thompson , SoloMusicArtist:Ashley_Hutchings , SoloMusicArtist:John_Kirkpatrick ;
#         bibliographica:byArtist        SoloMusicArtist:Richard_Thompson , SoloMusicArtist:John_Kirkpatrick , SoloMusicArtist:Ashley_Hutchings ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a6949ea3-e29c-3fa3-a21a-2c87b38c4e72"^^xsd:anyURI .
#
# CDs:Greatest_Hits_Vol_1  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Greatest Hits, Vol. 1" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/75978af5-eb92-469e-81b8-a9b60be45d3e"^^xsd:anyURI .
#
# CDs:Eyes_Open  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eyes Open" ;
#         dcterms:creator                SoloMusicArtist:Youssou_NDour ;
#         bibliographica:byArtist        SoloMusicArtist:Youssou_NDour ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3c973976-c1c6-42e3-af41-ffed66c39014"^^xsd:anyURI .
#
# CDs:Sweet_Forgiveness  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sweet Forgiveness" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ce55d23a-d234-3791-82c4-3b046c988b80"^^xsd:anyURI .
#
# CDs:Lonesome_Prison_Blues
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lonesome Prison Blues" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a9ce011c-aad7-4b1f-9ba4-14f33a0b3258"^^xsd:anyURI .
#
# CDs:Dream_Letter_Live  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dream Letter Live In London 1968" ;
#         dcterms:creator                SoloMusicArtist:Tim_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/64faad1f-ecf1-41c8-8f74-d08bcf503966"^^xsd:anyURI .
#
# CDs:Deadicated  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deadicated" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01eaaacc-1e9e-478e-ba3e-ed88b8b01c45"^^xsd:anyURI .
#
# CDs:Invisible_Means  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Invisible Means" ;
#         dcterms:creator                MusicGroup:French_Frith_Kaiser_Thompson ;
#         bibliographica:byArtist        MusicGroup:French_Frith_Kaiser_Thompson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f9fb142f-82ef-4426-83b7-6b886c92698e"^^xsd:anyURI .
#
# CDs:Buddy_Julie_Miller  a                 mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Buddy & Julie Miller" ;
#         dcterms:creator                SoloMusicArtist:Buddy_Miller , SoloMusicArtist:Julie_Miller ;
#         bibliographica:byArtist        SoloMusicArtist:Julie_Miller , SoloMusicArtist:Buddy_Miller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bb9f1eff-9363-42fd-9b4b-aaae51940252"^^xsd:anyURI .
#
# CDs:King_Tubby_Meets_Rockers
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "King Tubby Meets Rockers Downtown" ;
#         dcterms:creator          MusicGroup:King_Tubby ;
#         bibliographica:byArtist  MusicGroup:King_Tubby .
#
# CDs:Happiness  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Happiness" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Germano ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Germano ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5171b1d2-ca3e-4c23-a578-b184f2fbab04"^^xsd:anyURI .
#
# CDs:Miles_Davis_Quintet  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The New Miles Davis Quintet" ;
#         dcterms:creator          SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist  SoloMusicArtist:Miles_Davis .
#
# CDs:Steady_On  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Steady On" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b5e3fbcf-c9f8-4c84-acf3-7db35ab586a0"^^xsd:anyURI .
#
# CDs:No_Word_From_Tom  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Word From Tom" ;
#         dcterms:creator                MusicGroup:Hem ;
#         bibliographica:byArtist        MusicGroup:Hem ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/12544026-b8af-4c3b-9f4c-1411221461ba"^^xsd:anyURI .
#
# CDs:World_Mix  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "World Mix" ;
#         dcterms:creator                MusicGroup:Deep_Forest ;
#         bibliographica:byArtist        MusicGroup:Deep_Forest ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a402410c-204e-41ea-b1ac-b22b2516ca33"^^xsd:anyURI .
#
# CDs:Stranger_to_This_Land
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Stranger to This Land" ;
#         dcterms:creator          SoloMusicArtist:Barbara_Kessler ;
#         bibliographica:byArtist  SoloMusicArtist:Barbara_Kessler .
#
# CDs:The_Sensual_World  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Sensual World" ;
#         dcterms:creator                SoloMusicArtist:Kate_Bush ;
#         bibliographica:byArtist        SoloMusicArtist:Kate_Bush ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d7fe4164-109f-48d2-a35a-53f6502f3f3d"^^xsd:anyURI .
#
# CDs:Abbatoir_Blues  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Abattoir Blues / The Lyre of Orpheus" ;
#         dcterms:creator                MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:byArtist        MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/206c6806-2254-3565-a0c4-6731700d4a12"^^xsd:anyURI .
#
# CDs:Casual_Gods  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Casual Gods" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Harrison ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Harrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b81192c-84c2-4f0b-950e-4f7e546835d5"^^xsd:anyURI .
#
# CDs:Miles_and_Coltrane  a                 schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Miles & Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane , SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis , SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c9b31691-3d31-313e-b114-9a0a8ca19e6c"^^xsd:anyURI .
#
# CDs:Christine_Kane_Live  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Christine Kane Live" ;
#         dcterms:creator                SoloMusicArtist:Christine_Kane ;
#         bibliographica:byArtist        SoloMusicArtist:Christine_Kane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/17c91d2f-df86-4355-b7c0-55d4046e0cb2"^^xsd:anyURI .
#
# CDs:King_of_Trumpets  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "King of Trumpets" ;
#         dcterms:creator          SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist  SoloMusicArtist:Miles_Davis .
#
# CDs:Walking_Shadow_Big_Man
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Walking in the Shadow of the Big Man" ;
#         dcterms:creator                MusicGroup:Guadalcanal_Diary ;
#         bibliographica:byArtist        MusicGroup:Guadalcanal_Diary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6dac5350-5c91-44bf-8a72-00661a750651"^^xsd:anyURI .
#
# CDs:Open_Ears_Eyes  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Open Ears, Open Eyes with Allen Ginsburg" ;
#         dcterms:creator          SoloMusicArtist:Allen_Ginsberg ;
#         bibliographica:byArtist  SoloMusicArtist:Allen_Ginsberg .
#
# CDs:Abbey_is_Blue  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Abbey is Blue" ;
#         dcterms:creator                SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:byArtist        SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/2fa972a2-9165-3423-9ab1-38ed7b07e807"^^xsd:anyURI .
#
# CDs:Sinsemilla  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sinsemilla" ;
#         dcterms:creator                MusicGroup:Black_Uhuru ;
#         bibliographica:byArtist        MusicGroup:Black_Uhuru ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3a34cfd-e931-43ca-acbb-f0a820cd9340"^^xsd:anyURI .
#
# CDs:Manifold  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Manifold" ;
#         dcterms:creator                MusicGroup:The_Beat_Farmers ;
#         bibliographica:byArtist        MusicGroup:The_Beat_Farmers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/57df3412-99e4-479b-a8df-5bada7c48926"^^xsd:anyURI .
#
# CDs:Night_in_San_Fran  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Night in San Francisco" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f397097a-1162-4bf1-8527-6cdee0d87167"^^xsd:anyURI .
#
# CDs:Terminal_Hold  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Terminal Hold" ;
#         dcterms:creator                SoloMusicArtist:Tret_Fure ;
#         bibliographica:byArtist        SoloMusicArtist:Tret_Fure ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ba18b6eb-5344-4d56-825e-1bb9bda817d4"^^xsd:anyURI .
#
# CDs:Jerusalem  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jerusalem" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Earle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b7bf8fa-ed80-41f1-a04b-7b73e648550d"^^xsd:anyURI .
#
# CDs:Good_Hope_Concerts  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live: The Good Hope Concerts" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/50702c57-713a-4e7a-baaa-8e4d73327c45"^^xsd:anyURI .
#
# CDs:Dance_Afro_Beat  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dance Afro Beat" ;
#         dcterms:creator                SoloMusicArtist:Orlando_Julius ;
#         bibliographica:byArtist        SoloMusicArtist:Orlando_Julius ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6118a545-4fc7-4cdb-b01c-4c50682c2317"^^xsd:anyURI .
#
# CDs:Set    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Set" ;
#         dcterms:creator                SoloMusicArtist:Youssou_NDour ;
#         bibliographica:byArtist        SoloMusicArtist:Youssou_NDour ;
#         bibliographica:musicbrainzURI  "https://beta.musicbrainz.org/release/378e7256-f707-3d34-8290-5ec7c697418c"^^xsd:anyURI .
#
# CDs:Rainforest_Benefit_Show
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Rainforest Benefit Show" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Rites_of_Passage  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rites of Passage" ;
#         dcterms:creator                MusicGroup:Indigo_Girls ;
#         bibliographica:byArtist        MusicGroup:Indigo_Girls ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d5bfb4ba-39db-4c54-834a-cbd5bb67ac7f"^^xsd:anyURI .
#
# CDs:Zenyatta_Mondatta  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zenyattà Mondatta" ;
#         dcterms:creator                MusicGroup:Police ;
#         bibliographica:byArtist        MusicGroup:Police ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/56ad6149-5632-4d83-a0e9-689d00cecab9"^^xsd:anyURI .
#
# CDs:We_Care_A_Lot  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "We Care a Lot" ;
#         dcterms:creator                MusicGroup:Faith_No_More ;
#         bibliographica:byArtist        MusicGroup:Faith_No_More ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a239de83-d2dd-3792-a9d5-3a73cb0da71b"^^xsd:anyURI .
#
# CDs:Live_at_Montreux  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Montreux" ;
#         dcterms:creator                SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:byArtist        SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cb51cdc5-16d8-4219-9104-f09243f0b77d"^^xsd:anyURI .
#
# CDs:This_Sentence_Is_True
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Sentence Is True (The Previous Sentence Is False)" ;
#         dcterms:creator                SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:byArtist        SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/beda19c8-9cce-445e-b7de-deb96fe322a1"^^xsd:anyURI .
#
# CDs:Zero_Zero_Zero  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Zero Zero Zero" ;
#         dcterms:creator                SoloMusicArtist:Sam_Phillips ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/19552deb-711e-4caa-a9e6-bdaad8b85af0"^^xsd:anyURI .
#
# CDs:Stage  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stage" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1f1e37cd-88bb-4797-ba9d-5e0bf5887583"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_12  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 12: Providence Civic 6/26/74, Boston Garden 6/28/74" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/59729eb0-9066-4382-9c1b-f8702604b518"^^xsd:anyURI .
#
# CDs:Anthology_Laurie_Anderson
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anthology" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8179bb9b-1a37-4fdc-908c-a7b646cd1eb9"^^xsd:anyURI .
#
# CDs:Juju_Music  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Juju Music" ;
#         dcterms:creator                SoloMusicArtist:King_Sunny_Ade ;
#         bibliographica:byArtist        SoloMusicArtist:King_Sunny_Ade ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b42705ad-218f-46b0-8483-fdc8917081ad"^^xsd:anyURI .
#
# CDs:New_World_Order  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New World Order" ;
#         dcterms:creator                SoloMusicArtist:Curtis_Mayfield ;
#         bibliographica:byArtist        SoloMusicArtist:Curtis_Mayfield ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c6169099-94aa-46f2-b722-29db8fcf8690"^^xsd:anyURI .
#
# CDs:Tokyo_Blues  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Tokyo Blues" ;
#         dcterms:creator                SoloMusicArtist:Horace_Silver ;
#         bibliographica:byArtist        SoloMusicArtist:Horace_Silver ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/774d05ea-d579-3745-a3fb-365ac561f7e2"^^xsd:anyURI .
#
# CDs:The_Bethlehem_Years  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bethlehem Years" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c806639b-f8db-4e52-b96f-acfcc07da536"^^xsd:anyURI .
#
# CDs:Painless  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Painless" ;
#         dcterms:creator          MusicGroup:Freetown ;
#         bibliographica:byArtist  MusicGroup:Freetown .
#
# CDs:Lemon_of_Pink  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lemon of Pink" ;
#         dcterms:creator                MusicGroup:The_Books ;
#         bibliographica:byArtist        MusicGroup:The_Books ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3f59ccb0-a63b-3ac6-beaa-bca629030969"^^xsd:anyURI .
#
# CDs:Red_and_Black  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Red and the Black" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Harrison ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Harrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d14ecfe0-2268-4621-b6c7-d46802e299de"^^xsd:anyURI .
#
# CDs:Dead_City_Radio  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dead City Radio" ;
#         dcterms:creator                SoloMusicArtist:William_S_Burroughs ;
#         bibliographica:byArtist        SoloMusicArtist:William_S_Burroughs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a8821dcf-4e78-4291-a102-0606b79213a3"^^xsd:anyURI .
#
# CDs:These_Four_Walls  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "These Four Walls" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f81db7e2-68b7-3725-b98d-5c5efde603a1"^^xsd:anyURI .
#
# CDs:Mystery_White_Boy_live
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mystery White Boy: Live ’95-’96" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b68b23eb-6623-4a6c-a5dc-06e76e0947bd"^^xsd:anyURI .
#
# CDs:Just_Another_Band_East_LA
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Just Another Band From East L.A." ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6d9ee237-a415-4910-9a29-98295620b52f"^^xsd:anyURI .
#
# CDs:Snapshots  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Snapshots" ;
#         dcterms:creator                SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:byArtist        SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8d8e3fcd-0385-4259-b1ab-555540b69f29"^^xsd:anyURI .
#
# CDs:Fat_City  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fat City" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ca4634f5-6694-4bae-aac7-35df2c1c82db"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_3
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Bootleg Series, Volume 3" ;
#         dcterms:creator          SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist  SoloMusicArtist:Bob_Dylan .
#
# CDs:Miles_in_Europe  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles Davis in Europe" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5c9ae7c2-58b4-48a4-80fc-cbb6731f35df"^^xsd:anyURI .
#
# CDs:New_Album  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "New Album" ;
#         dcterms:creator          MusicGroup:Janes_Addiction ;
#         bibliographica:byArtist  MusicGroup:Janes_Addiction .
#
# CDs:Age_of_Possibility  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Age of Possibility" ;
#         dcterms:creator                SoloMusicArtist:Carrie_Newcomer ;
#         bibliographica:byArtist        SoloMusicArtist:Carrie_Newcomer ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/daf593b0-1b61-4d4d-b70b-5663b9970c86"^^xsd:anyURI .
#
# CDs:Live_at_Apollo  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Apollo, 1962" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ecd66e8-08d7-4807-b1e6-7f7f3d57c6c2"^^xsd:anyURI .
#
# CDs:Lay_It_Down  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lay It Down" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e04e5f1c-e502-47b9-9f5c-04dc26ce922d"^^xsd:anyURI .
#
# CDs:Revolver  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Revolver" ;
#         dcterms:creator                MusicGroup:Beatles ;
#         bibliographica:byArtist        MusicGroup:Beatles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/faa47611-ff6f-3e08-b27c-7e56583c08e4"^^xsd:anyURI .
#
# CDs:Hawk_Eyes  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hawk Eyes" ;
#         dcterms:creator                SoloMusicArtist:Coleman_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Coleman_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/97e33a2f-e108-4f42-bb01-7f831912bde9"^^xsd:anyURI .
#
# CDs:Five_Miles_From_Hope
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Five Miles From Hope" ;
#         dcterms:creator                SoloMusicArtist:Mindy_Jostyn ;
#         bibliographica:byArtist        SoloMusicArtist:Mindy_Jostyn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/147ad48b-bb86-4430-b9e2-22f25d68c1af"^^xsd:anyURI .
#
# CDs:Fresh_Fruit_Rotting_Veg
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fresh Fruit for Rotting Vegetables" ;
#         dcterms:creator                MusicGroup:Dead_Kennedys ;
#         bibliographica:byArtist        MusicGroup:Dead_Kennedys ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/038d3b87-705d-3a2c-8f4a-e8cee042b9ea"^^xsd:anyURI .
#
# CDs:Thelonius_Plays_Duke
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thelonious Monk Plays Duke Ellington" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/902af2fa-f8b7-49c0-9c77-767fa2ae2354"^^xsd:anyURI .
#
# CDs:Loose_in_World  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Loose in the World" ;
#         dcterms:creator                SoloMusicArtist:Judy_Henske ;
#         bibliographica:byArtist        SoloMusicArtist:Judy_Henske ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/06a07c86-8865-43e8-9e83-7ae0441b65e4"^^xsd:anyURI .
#
# CDs:Swing_39  a                           mo:Release , mo:Record , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Swing 39 (Jazz in Paris)" ;
#         dcterms:creator                SoloMusicArtist:Stephane_Grapelli , SoloMusicArtist:Django_Reinhardt ;
#         bibliographica:byArtist        SoloMusicArtist:Stephane_Grapelli , SoloMusicArtist:Django_Reinhardt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/589dc3a0-c61e-3aa7-a160-6d3bba1d7b82"^^xsd:anyURI .
#
# CDs:Best_of_Dexter_Gordon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Dexter Gordon" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e868a962-67a7-43e4-9e19-3cc6f17357df"^^xsd:anyURI .
#
# CDs:Hot_Burritos  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Burritos! Anthology: 1969-1972" ;
#         dcterms:creator                MusicGroup:Flying_Burrito_Brothers ;
#         bibliographica:byArtist        MusicGroup:Flying_Burrito_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/234fcc00-8912-456a-8fa6-e74d9afd0449"^^xsd:anyURI .
#
# CDs:Fasiya  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fasiya" ;
#         dcterms:creator                SoloMusicArtist:Sona_Jobarteh ;
#         bibliographica:byArtist        SoloMusicArtist:Sona_Jobarteh ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1fe3a801-4018-4ce4-9387-be15572ab69b"^^xsd:anyURI .
#
# CDs:Chanchullo  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chanchullo" ;
#         dcterms:creator                SoloMusicArtist:Ruben_Gonzalez ;
#         bibliographica:byArtist        SoloMusicArtist:Ruben_Gonzalez ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fc690b04-9d4f-4eb0-a35b-bc1c9bab618b"^^xsd:anyURI .
#
# CDs:Vintage_Years  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Vintage Years" ;
#         dcterms:creator                MusicGroup:Fleetwood_Mac ;
#         bibliographica:byArtist        MusicGroup:Fleetwood_Mac ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0fc4bf32-8aff-39ac-9fe3-1ae4e7034483"^^xsd:anyURI .
#
# CDs:Virgin_Beauty  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Virgin Beauty" ;
#         dcterms:creator                SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:byArtist        SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aa36f047-1133-4412-a794-1b05c7e6e4d9"^^xsd:anyURI .
#
# CDs:A_Passion_Play  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Passion Play" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7cf0a00c-e607-45f6-ab95-0f178b81ea36"^^xsd:anyURI .
#
# CDs:Slant_Six_Mind  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slant 6 Mind" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c83abec9-22bf-4d39-ba44-c688e056ab05"^^xsd:anyURI .
#
# CDs:Show_Of_Hands  a                      mo:Record , mo:Release , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "Show of Hands" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp , MusicGroup:League_Crafty_Guitarists ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp , MusicGroup:League_Crafty_Guitarists ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/08afb1e1-fdeb-4bb3-9859-e943fdbccf90"^^xsd:anyURI .
#
# CDs:Showtime  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Showtime" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83b96844-9085-4b51-af74-2710c76001e8"^^xsd:anyURI .
#
# CDs:Boot_and_Shoe  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Boot and a Shoe" ;
#         dcterms:creator                SoloMusicArtist:Sam_Phillips ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdea53a4-7fab-409b-b70f-6ec3f8a06029"^^xsd:anyURI .
#
# CDs:Grateful_Dead_Interview
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Grateful Dead Interview Picture Disc" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Live_in_Paris_DK  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Paris" ;
#         dcterms:creator                SoloMusicArtist:Diana_Krall ;
#         bibliographica:byArtist        SoloMusicArtist:Diana_Krall ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4abb7376-f2b2-4fb4-a003-1f80d877ae63"^^xsd:anyURI .
#
# CDs:Big_Circumstance  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big Circumstance" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a6949ea3-e29c-3fa3-a21a-2c87b38c4e72"^^xsd:anyURI .
#
# CDs:Shaka_Zulu  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shaka Zulu" ;
#         dcterms:creator                MusicGroup:Ladysmith_Black_Mambazo ;
#         bibliographica:byArtist        MusicGroup:Ladysmith_Black_Mambazo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cbe96d3c-8ae3-34fe-81c3-7340dc39651e"^^xsd:anyURI .
#
# CDs:Apollo  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Apollo" ;
#         dcterms:creator                SoloMusicArtist:Kerry_Getz ;
#         bibliographica:byArtist        SoloMusicArtist:Kerry_Getz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/66a5420a-85e3-4864-af02-a4d828d0a091"^^xsd:anyURI .
#
# CDs:Howling_at_Moon  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Howlin’ at the Moon" ;
#         dcterms:creator                SoloMusicArtist:Sam_Bush ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Bush ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cc53db7a-f01f-4cf4-ae07-8c2ab4f4f63f"^^xsd:anyURI .
#
# CDs:Soultrane  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Soultrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e0c3968d-041d-4375-ba63-28c0505a5524"^^xsd:anyURI .
#
# CDs:Coward_of_County  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Coward of the County" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/80479a5b-61f2-4d27-a232-ba439df0c75b"^^xsd:anyURI .
#
# CDs:Now_You_See_Now_You_Dont
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Now You See It... Now You Don't" ;
#         dcterms:creator                SoloMusicArtist:Michael_Brecker ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Brecker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8084b1bb-0ac7-4396-b3f7-21e7db13b022"^^xsd:anyURI .
#
# CDs:Shadowland  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shadowland" ;
#         dcterms:creator                SoloMusicArtist:KD_Lang ;
#         bibliographica:byArtist        SoloMusicArtist:KD_Lang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2d1d66f2-8ec7-4a74-a5f0-4921c888d937"^^xsd:anyURI .
#
# CDs:Long_Journey_Home  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Long Journey Home" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d54aef42-1ed1-4600-9719-0d33aaa1fbaf"^^xsd:anyURI .
#
# CDs:What_About_Regret  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What About Regret" ;
#         dcterms:creator                SoloMusicArtist:Kate_Jacobs ;
#         bibliographica:byArtist        SoloMusicArtist:Kate_Jacobs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f8bb402a-234c-4fd3-8ac1-255879efdbef"^^xsd:anyURI .
#
# CDs:Influence_Vol_2  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Influence Vol. 2: I Was Young When I Left Home" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0187ebe9-bc40-48d5-bee0-716ec5c4996d"^^xsd:anyURI .
#
# CDs:Forty_Four_Sixty_Six
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "44 & 66" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f5256c3f-f85f-368f-8e9c-5b464b1e1146"^^xsd:anyURI .
#
# CDs:Bonnie_Raitt_CD  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bonnie Raitt" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5eb8446-d37a-35cf-8e06-cc3968bd0f8e"^^xsd:anyURI .
#
# CDs:Righteous_Love  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Righteous Love" ;
#         dcterms:creator                SoloMusicArtist:Joan_Osborne ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Osborne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5f093672-f27c-4103-96ca-6a9278a94cb2"^^xsd:anyURI .
#
# CDs:Bent_By_Nature  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bent By Nature" ;
#         dcterms:creator                MusicGroup:Glass_Eye ;
#         bibliographica:byArtist        MusicGroup:Glass_Eye ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/579dc43c-bad4-40ff-a277-37c874906865"^^xsd:anyURI .
#
# CDs:Songs_of_Innocence_Experience
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Songs of Innocence and of Experience" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/30497783-ca69-314f-8bf4-9e225ed81bbc"^^xsd:anyURI .
#
# CDs:MTV_Unplugged_2  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "MTV Unplugged 2.0" ;
#         dcterms:creator                SoloMusicArtist:Lauryn_Hill ;
#         bibliographica:byArtist        SoloMusicArtist:Lauryn_Hill ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d1334b72-0294-4ea4-98ed-147e1473fd09"^^xsd:anyURI .
#
# CDs:Columbia_Records  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Columbia Records 1958-1986" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e8dd3ab1-4cd9-4652-af16-a3fa5f92f742"^^xsd:anyURI .
#
# CDs:Latin_Playboys_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Latin Playboys" ;
#         dcterms:creator                MusicGroup:Latin_Playboys ;
#         bibliographica:byArtist        MusicGroup:Latin_Playboys ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fe4d0355-674d-4e79-a37a-1b6a7c44afe8"^^xsd:anyURI .
#
# CDs:Further_Adventures_Of
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Further Adventures Of" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/6b80ccf2-7b73-3f5d-81e4-482f9ba038bd"^^xsd:anyURI .
#
# CDs:Roots_Revisited  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Roots Revisited" ;
#         dcterms:creator                SoloMusicArtist:Maceo_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Maceo_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f479673d-6f8e-4ea7-a112-3b064084e307"^^xsd:anyURI .
#
# CDs:One_More_Goodnight_Kiss
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One More Goodnight Kiss" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/193a405b-afb0-4ed6-890a-8586c66490c7"^^xsd:anyURI .
#
# CDs:Live_At_Jazz_Workshop
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Jazz Workshop" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3631d6af-40dc-423a-ae41-94eff3c4fc45"^^xsd:anyURI .
#
# CDs:Live_GK  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gipsy Kings Live" ;
#         dcterms:creator                MusicGroup:Gipsy_Kings ;
#         bibliographica:byArtist        MusicGroup:Gipsy_Kings ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bf9d860f-a99b-41f9-9357-e98516d5552e"^^xsd:anyURI .
#
# CDs:America_Live  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "America" ;
#         dcterms:creator                MusicGroup:America ;
#         bibliographica:byArtist        MusicGroup:America ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1c08f8c7-ba86-4c66-be7f-0a0f3e87cc8b"^^xsd:anyURI .
#
# CDs:Reservation_Blues  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Reservation Blues" ;
#         dcterms:creator          SoloMusicArtist:Ben_Stevens ;
#         bibliographica:byArtist  SoloMusicArtist:Ben_Stevens .
#
# CDs:Transition  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Transition" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6be28f83-dcad-41d4-9e62-115f7190db55"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_20  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 20: Capital Centre, Landover, MD 9/25/76, Onondaga County War Memorial, Syracuse, NY 9/28/76" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/65abd6df-8758-4b72-8fde-62fbdaf3458e"^^xsd:anyURI .
#
# CDs:Strange_Weather  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strange Weather" ;
#         dcterms:creator                SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:byArtist        SoloMusicArtist:Marianne_Faithfull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d2c29675-45cb-4488-9f37-5558b52bad53"^^xsd:anyURI .
#
# CDs:Live_at_Habibi  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Habibi Temple" ;
#         dcterms:creator                SoloMusicArtist:Boo_Zoo_Chavis ;
#         bibliographica:byArtist        SoloMusicArtist:Boo_Zoo_Chavis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/ca5d4a18-67d1-416c-80c2-68a916d8ba3e"^^xsd:anyURI .
#
# CDs:Plays_Music_Zappa  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plays the Music of Frank Zappa" ;
#         dcterms:creator                MusicGroup:Ed_Palermo_Big_Band ;
#         bibliographica:byArtist        MusicGroup:Ed_Palermo_Big_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e4b4d1e-97c5-471b-a377-ef039d456115"^^xsd:anyURI .
#
# CDs:Live_on_World_Cafe  a           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:comment             "Can't locate on Musicbrainz." ;
#         rdfs:label               "Live" ;
#         dcterms:creator          SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist  SoloMusicArtist:Bruce_Cockburn .
#
# CDs:Chalk_Mark_Rain_Storm
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chalk Mark in a Rain Storm" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/240a5bb8-5e21-358b-ad03-b2077a84eee7"^^xsd:anyURI .
#
# CDs:Mister_Heartbreak  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mister Heartbreak" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/42307ee3-4f7c-430a-bb10-e025d8cfa255"^^xsd:anyURI .
#
# CDs:Birds_Best_Bop  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bird's Best Bop on Verve" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/520060d9-72ae-4a95-8d2c-bf477f29a8c0"^^xsd:anyURI .
#
# CDs:Generative_Music  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Generative Music" ;
#         dcterms:creator          SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist  SoloMusicArtist:Brian_Eno .
#
# CDs:Changes_One  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Changes One" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4489c864-3ca5-3463-b3b1-69738b25809c"^^xsd:anyURI .
#
# CDs:Ghostyhead  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ghostyhead" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de20a560-2311-42b9-8445-60873be2f80f"^^xsd:anyURI .
#
# CDs:Venus_Kissed_Moon  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Venus Kissed The Moon" ;
#         dcterms:creator                SoloMusicArtist:Loey_Nelson ;
#         bibliographica:byArtist        SoloMusicArtist:Loey_Nelson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1957c8c1-2c1a-49a5-b6ab-39defa748787"^^xsd:anyURI .
#
# CDs:Left_in_Vaults  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Left In The Vaults, Vol. 3" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:There_Will_Be_Light  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "There Will Be A Light" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b45b9be8-7f09-4b84-abe5-09e6bb4ac68f"^^xsd:anyURI .
#
# CDs:Africa_Brass  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Africa Brass, Volume 1 & 2" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e4d4c059-3700-4826-895a-74d7c477484a"^^xsd:anyURI .
#
# CDs:Small_Talk_125th_Lenox
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Small Talk at 125th and Lenox" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5cfa6373-1e6a-4a59-bd54-e9ed53a446a4"^^xsd:anyURI .
#
# CDs:Unravel  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unravel" ;
#         dcterms:creator                SoloMusicArtist:Lynn_Miles ;
#         bibliographica:byArtist        SoloMusicArtist:Lynn_Miles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10f51d29-352d-30fb-a687-153a66dcb319"^^xsd:anyURI .
#
# CDs:Ladies_of_the_Canyon
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ladies of the Canyon" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4cc0f84c-bbb4-384d-b0e8-c4ec68e1875b"^^xsd:anyURI .
#
# CDs:Still_Life_Talking  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Still Life (Talking)" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/85a9a3d8-955c-451c-827a-74b6507fb91d"^^xsd:anyURI .
#
# CDs:One_Soul_Now  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Soul Now" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a9abedf5-06aa-433c-b79c-9f8c51be0f5b"^^xsd:anyURI .
#
# CDs:Live_JT  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:James_Taylor ;
#         bibliographica:byArtist        SoloMusicArtist:James_Taylor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6fc02e86-7cb5-452c-99eb-46fa6c226879"^^xsd:anyURI .
#
# CDs:Last_Scream_Missing_Neighbors
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Last Scream of the Missing Neighbors" ;
#         dcterms:creator                SoloMusicArtist:Jello_Biafra ;
#         bibliographica:byArtist        SoloMusicArtist:Jello_Biafra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f0674151-7b24-3167-a510-d61b4c5d1b59"^^xsd:anyURI .
#
# CDs:One_Kind  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One of a Kind" ;
#         dcterms:creator                SoloMusicArtist:Bill_Bruford ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Bruford ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d2595b71-5353-3ae7-853d-3490e0622353"^^xsd:anyURI .
#
# CDs:Peek_A_Boo  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peek-A-Boo: the Best of NRBQ 1969-1989" ;
#         dcterms:creator                MusicGroup:NRBQ ;
#         bibliographica:byArtist        MusicGroup:NRBQ ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/04e824df-e47b-4fab-9ddf-dea84a72c355"^^xsd:anyURI .
#
# CDs:Coltrane_CD  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0ec8227a-6314-4324-ab26-b1d8ee009adc"^^xsd:anyURI .
#
# CDs:Eric_Clapton_CD  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eric Clapton" ;
#         dcterms:creator                SoloMusicArtist:Eric_Clapton ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Clapton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8c01b7e0-6cff-470e-9ad3-ff73b3c8f411"^^xsd:anyURI .
#
# CDs:We_Live_Here  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "We Live Here" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7d6dfc9a-4d3f-3aa3-8827-55ffab3ea276"^^xsd:anyURI .
#
# CDs:Silver_Cloud  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Silver Cloud" ;
#         dcterms:creator                SoloMusicArtist:Kitaro ;
#         bibliographica:byArtist        SoloMusicArtist:Kitaro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/17140502-4918-335a-9b19-c97ec75952ac"^^xsd:anyURI .
#
# CDs:Live_in_Paris_Toronto
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Paris and Toronto" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/44cc33da-547b-3406-afd0-a45270741ec6"^^xsd:anyURI .
#
# CDs:Covenant  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Covenant" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5a3756fd-d849-44a9-ab3b-ec1f8eccb303"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_7  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 7: Alexandra Palace, London England, September 1974" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5437e0cd-0e79-46ef-9a15-c3aa1f8b24e0"^^xsd:anyURI .
#
# CDs:Super_Black_Market_Clash
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Super Black Market Clash" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a35d4f4f-28b7-4d41-b7c4-0d482cc45794"^^xsd:anyURI .
#
# CDs:The_Complete_Town_Hall
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete Town Hall Concert" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fc665fe7-cf5b-4071-9c0f-91e4eb7d8d8f"^^xsd:anyURI .
#
# CDs:Under_Red_Sky  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Under the Red Sky" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/8d231aa3-4a4e-306a-a3f9-4421e846bb1a"^^xsd:anyURI .
#
# CDs:Little_Feat_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Little Feat" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/545966cc-10cd-3c18-ad9f-4d826501a974"^^xsd:anyURI .
#
# CDs:Nnenna_Freelon_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nnenna Freelon" ;
#         dcterms:creator                SoloMusicArtist:Nnenna_Freelon ;
#         bibliographica:byArtist        SoloMusicArtist:Nnenna_Freelon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/023ba167-d4de-4f74-bf48-995b2ef1582d"^^xsd:anyURI .
#
# CDs:Hotel_California  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hotel California" ;
#         dcterms:creator                MusicGroup:Eagles ;
#         bibliographica:byArtist        MusicGroup:Eagles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/304a548c-85a2-3926-8379-cdbfdf891a12"^^xsd:anyURI .
#
# CDs:The_Impulse_Years  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A John Coltrane Retrospective: The Impulse! Years" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4c86092a-3dfa-4c91-84d9-513b4f659b76"^^xsd:anyURI .
#
# CDs:Surfacing  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Surfacing" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/931cfa58-02a7-4a85-b042-bc8b321d0891"^^xsd:anyURI .
#
# CDs:Looking_Forward  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Looking Forward" ;
#         dcterms:creator                MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:byArtist        MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a7780b66-8058-4d9e-af4c-1ca0e50bb7fc"^^xsd:anyURI .
#
# CDs:Home_of_the_Brave  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Home of the Brave" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4458273b-9450-45fe-9ada-fa9e49e43b2b"^^xsd:anyURI .
#
# CDs:The_Spirit_Room  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Spirit Room" ;
#         dcterms:creator                SoloMusicArtist:Michelle_Branch ;
#         bibliographica:byArtist        SoloMusicArtist:Michelle_Branch ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f54e9d9-529a-3652-8805-3b5e84debd8d"^^xsd:anyURI .
#
# CDs:Directions  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Directions" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ec6cb906-ffc1-410d-8fdf-78e0f6f54b57"^^xsd:anyURI .
#
# CDs:Sketches_of_Spain  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sketches of Spain" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8709a882-a7c4-4c77-9edf-744521ec4ee2"^^xsd:anyURI .
#
# CDs:Yola   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yola" ;
#         dcterms:creator                SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:byArtist        SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6df9ecc-a746-4bcc-9ca6-91a18c777e06"^^xsd:anyURI .
#
# CDs:Strange_Angels  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strange Angels" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/367a065c-44d2-405c-8a00-2f0d97c707fe"^^xsd:anyURI .
#
# CDs:Paranoid  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Paranoid" ;
#         dcterms:creator                MusicGroup:Black_Sabbath ;
#         bibliographica:byArtist        MusicGroup:Black_Sabbath ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/40b08941-d5e9-49d6-bb75-625db9381d32"^^xsd:anyURI .
#
# CDs:Temptation  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Temptation" ;
#         dcterms:creator                SoloMusicArtist:Holly_Cole ;
#         bibliographica:byArtist        SoloMusicArtist:Holly_Cole ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b531c9a-5f29-38cc-b780-f053bf865cfa"^^xsd:anyURI .
#
# CDs:Yellow_Fever  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yellow Fever" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2d612997-d5b8-4c00-8fbc-33ae8962eb36"^^xsd:anyURI .
#
# CDs:Kind_of_Blue  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kind of Blue" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f8f79f3a-3a63-3286-a43d-0135c1a59fea"^^xsd:anyURI .
#
# CDs:Peace_Orchestra_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peace Orchestra" ;
#         dcterms:creator                MusicGroup:Peace_Orchestra ;
#         bibliographica:byArtist        MusicGroup:Peace_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/82c24fe2-36e7-40c2-8ece-55d6bfedd1cd"^^xsd:anyURI .
#
# CDs:Tree   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tree" ;
#         dcterms:creator                MusicGroup:Gaelic_Storm ;
#         bibliographica:byArtist        MusicGroup:Gaelic_Storm ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99335960-be55-49ad-bd12-4b31b96195eb"^^xsd:anyURI .
#
# CDs:Dead_Bees  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dead Bees on a Cake" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/94e8d28b-7563-4d8a-9112-aebdff755c42"^^xsd:anyURI .
#
# CDs:Outcry  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Outcry" ;
#         dcterms:creator                SoloMusicArtist:Mutabaruka ;
#         bibliographica:byArtist        SoloMusicArtist:Mutabaruka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9433bb5a-3a7c-47ba-96d8-b0b60d5f6e0b"^^xsd:anyURI .
#
# CDs:Further_Down_Old_Plank
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Further Down the Old Plank Road" ;
#         dcterms:creator                MusicGroup:The_Chieftains ;
#         bibliographica:byArtist        MusicGroup:The_Chieftains ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/84f75123-23d3-4080-9886-a22b78ab87be"^^xsd:anyURI .
#
# CDs:Prairie_Girl  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Prairie Girl" ;
#         dcterms:creator          SoloMusicArtist:Chante ;
#         bibliographica:byArtist  SoloMusicArtist:Chante .
#
# CDs:Crazy_Moon  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crazy Moon" ;
#         dcterms:creator                MusicGroup:Crazy_Horse ;
#         bibliographica:byArtist        MusicGroup:Crazy_Horse ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a428807e-af55-42c6-a185-e6b35a2d571e"^^xsd:anyURI .
#
# CDs:Gotham_City  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gotham City" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd23f9b2-e4ea-4b96-992d-08bafdb5b3af"^^xsd:anyURI .
#
# CDs:Best_of_Bothy_Band  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of the Bothy Band" ;
#         dcterms:creator                MusicGroup:The_Bothy_Band ;
#         bibliographica:byArtist        MusicGroup:The_Bothy_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5f2882ca-1fdf-4e0e-a93f-abeba3a3349a"^^xsd:anyURI .
#
# CDs:White_Rabbit  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "White Rabbit" ;
#         dcterms:creator                MusicGroup:Murmurs ;
#         bibliographica:byArtist        MusicGroup:Murmurs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/33d33f57-83cd-4b04-88e2-d66f2d08966b"^^xsd:anyURI .
#
# CDs:Truth_and_Soul  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Truth and Soul" ;
#         dcterms:creator                MusicGroup:Fishbone ;
#         bibliographica:byArtist        MusicGroup:Fishbone ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b95f31a-eec4-4478-866e-6d9714a57743"^^xsd:anyURI .
#
# CDs:Tears_of_Stone  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tears of Stone" ;
#         dcterms:creator                MusicGroup:The_Chieftains ;
#         bibliographica:byArtist        MusicGroup:The_Chieftains ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a0ae4d7f-49a3-48d9-83aa-92c39dab6b49"^^xsd:anyURI .
#
# CDs:Painted_From_Memory  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Painted From Memory" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/47deeec9-1b3c-4711-941a-cf6425d82373"^^xsd:anyURI .
#
# CDs:Under_Heavy_Manners  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "God Save the Queen/Under Heavy Manners" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3ec31875-9480-3432-bc0f-445b2972b4e5"^^xsd:anyURI .
#
# CDs:High_Dive  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "High Dive" ;
#         dcterms:creator          MusicGroup:Little_Beirut ;
#         bibliographica:byArtist  MusicGroup:Little_Beirut .
#
# CDs:Five_Leaves_Left  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Five Leaves Left" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3c0db05c-3b02-3be0-bab6-c4b233de21da"^^xsd:anyURI .
#
# CDs:Who_Knows_Where_Time_Goes
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Who Knows Where the Time Goes?" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6e0adcf-79d3-49a8-b777-72ead8527fb5"^^xsd:anyURI .
#
# CDs:Scarlets_Walk  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Scarlet's Walk" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1846904b-f47a-3745-a2e0-4469e3a50702"^^xsd:anyURI .
#
# CDs:Soneros_de_Verdad  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Soneros de Verdad Present: Pío Leiva" ;
#         dcterms:creator                SoloMusicArtist:Pio_Leyva ;
#         bibliographica:byArtist        SoloMusicArtist:Pio_Leyva ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/689eb8d1-e8f7-4379-a02f-b5ab8069dccb"^^xsd:anyURI .
#
# CDs:Spiritual_Appliances
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spiritual Appliances" ;
#         dcterms:creator                SoloMusicArtist:Sara_Hickman ;
#         bibliographica:byArtist        SoloMusicArtist:Sara_Hickman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/147ecce2-d4ae-4a2f-99a7-7ea23e226054"^^xsd:anyURI .
#
# CDs:Cannonball_and_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cannonball & Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane , SoloMusicArtist:Cannonball_Adderley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/28858094-3ec6-3156-abbb-da11691ee6f0"^^xsd:anyURI .
#
# CDs:The_Wheel  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Wheel" ;
#         dcterms:creator                SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Rosanne_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a17243ba-a0d7-4d86-8fb2-fdc2bae07bc7"^^xsd:anyURI .
#
# CDs:Talk_on_Corners  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Talk on Corners" ;
#         dcterms:creator                MusicGroup:The_Corrs ;
#         bibliographica:byArtist        MusicGroup:The_Corrs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5779728a-9d41-4304-81ba-3d68d8611893"^^xsd:anyURI .
#
# CDs:Untold_Stories  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Untold Stories" ;
#         dcterms:creator                MusicGroup:Hot_Rize ;
#         bibliographica:byArtist        MusicGroup:Hot_Rize ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/68d55852-da2f-4330-9b3c-ea699d37fee7"^^xsd:anyURI .
#
# CDs:Miami  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miami" ;
#         dcterms:creator                MusicGroup:James_Gang ;
#         bibliographica:byArtist        MusicGroup:James_Gang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05c59759-d169-497e-868b-3d5e07ef6b60"^^xsd:anyURI .
#
# CDs:Sharing_the_Night_Together
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sharing the Night Together" ;
#         dcterms:creator                MusicGroup:Dr_Hook ;
#         bibliographica:byArtist        MusicGroup:Dr_Hook ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df7c0611-2731-43ee-82ac-13280282d458"^^xsd:anyURI .
#
# CDs:Outbound  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Outbound" ;
#         dcterms:creator                MusicGroup:Bela_Fleck_and_the_Flecktones ;
#         bibliographica:byArtist        MusicGroup:Bela_Fleck_and_the_Flecktones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2b766264-7cd9-408b-a73f-bc2b8d270a76"^^xsd:anyURI .
#
# CDs:Trio_I  a                             schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Trio I - Eponymous" ;
#         dcterms:creator                SoloMusicArtist:Linda_Ronstadt , SoloMusicArtist:Emmylou_Harris , SoloMusicArtist:Dolly_Parton ;
#         bibliographica:byArtist        SoloMusicArtist:Linda_Ronstadt , SoloMusicArtist:Emmylou_Harris , SoloMusicArtist:Dolly_Parton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8656cd1f-0f26-4159-8f4f-50ded1a45462"^^xsd:anyURI .
#
# CDs:Never_The_Bride_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Never The Bride" ;
#         dcterms:creator                MusicGroup:Never_The_Bride ;
#         bibliographica:byArtist        MusicGroup:Never_The_Bride ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/31aca7f9-6d9b-4328-9b21-5f154558083f"^^xsd:anyURI .
#
# CDs:Candyland  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Candyland" ;
#         dcterms:creator                SoloMusicArtist:James_McMurtry ;
#         bibliographica:byArtist        SoloMusicArtist:James_McMurtry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7bce5c84-6ffb-430a-bad8-8d28ff5c4938"^^xsd:anyURI .
#
# CDs:Love_Over_Gold  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Love Over Gold" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a3b62e6e-92f9-4e76-a518-1a9e43d910c6"^^xsd:anyURI .
#
# CDs:Self_Portrait  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Self Portrait" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/6163aa70-d97f-34e5-a5bf-54b7d85a7ea0"^^xsd:anyURI .
#
# CDs:Working_Wonders  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Working Wonders" ;
#         dcterms:creator                SoloMusicArtist:Judy_Mowatt ;
#         bibliographica:byArtist        SoloMusicArtist:Judy_Mowatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df939f67-612a-4b49-a438-9a818bd472a6"^^xsd:anyURI .
#
# CDs:At_Fillmore_East  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At Fillmore East (Deluxe Edition)" ;
#         dcterms:creator                MusicGroup:Allman_Brothers ;
#         bibliographica:byArtist        MusicGroup:Allman_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/29e18ce2-3777-432b-bff6-c446e71b21e7"^^xsd:anyURI .
#
# CDs:War_Child  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "War Child" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa27969e-544a-4020-ac3b-2ba6332a5549"^^xsd:anyURI .
#
# CDs:Sabil  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Sabil" ;
#         dcterms:creator          SoloMusicArtist:Georges_Kazazian ;
#         bibliographica:byArtist  SoloMusicArtist:Georges_Kazazian .
#
# CDs:Electric_Ladyland  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Electric Ladyland" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a2e3ee0e-b3b4-3129-8fb6-89fbbb9b2b85"^^xsd:anyURI .
#
# CDs:Mingus_in_Europe  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus in Europe" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c43bd8ef-ece3-470a-ac39-a2c8401e1a06"^^xsd:anyURI .
#
# CDs:Live_SM  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live (Limited Edition)" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3d696f34-7e48-4de9-8156-4d7b663326dc"^^xsd:anyURI .
#
# CDs:Ive_Been_Everywhere  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "I've Been Everywhere" ;
#         dcterms:creator          SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:byArtist  SoloMusicArtist:Eugene_Chadbourne .
#
# CDs:Big_Science  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big Science" ;
#         dcterms:creator                SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Laurie_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b9e6ad2-8f80-4713-bb8b-2e1f977c4808"^^xsd:anyURI .
#
# CDs:Upper_Extremities  a                  mo:CD , mo:Record , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Upper Extremities" ;
#         dcterms:creator                SoloMusicArtist:Tony_Levin , SoloMusicArtist:Bill_Bruford ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Bruford , SoloMusicArtist:Tony_Levin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a485361f-b525-4543-ac0b-61c97421b13d"^^xsd:anyURI .
#
# CDs:Lizard_Vision  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lizard Vision" ;
#         dcterms:creator                SoloMusicArtist:Austin_Lounge_Lizards ;
#         bibliographica:byArtist        SoloMusicArtist:Austin_Lounge_Lizards ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7185f82b-32dc-48d7-8308-a67e6ff73290"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_2  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 2: Columbus, Ohio 10/31/71" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/93a909e5-1c42-4754-bcc2-663ba661d305"^^xsd:anyURI .
#
# CDs:Whole_New_You  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Whole New You" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32cb3543-fb44-32f4-88df-ee97ce486fa8"^^xsd:anyURI .
#
# CDs:Getz_Gilberto  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Getz/Gilberto" ;
#         dcterms:creator                SoloMusicArtist:Stan_Getz ;
#         bibliographica:byArtist        SoloMusicArtist:Stan_Getz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b36a7186-8a86-47b1-ad97-f2278ef0da5f"^^xsd:anyURI .
#
# CDs:Tumblin_Down  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Tumblin' Down" ;
#         dcterms:creator          MusicGroup:Bleecker_Street ;
#         bibliographica:byArtist  MusicGroup:Bleecker_Street .
#
# CDs:Repercussions_Angleic_Behavior
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Repercussions of Angelic Behavior" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0fcc1d02-9575-49eb-99c8-4abacdb5a224"^^xsd:anyURI .
#
# CDs:Angels_Cigarettes  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Angels & Cigarettes" ;
#         dcterms:creator                SoloMusicArtist:Eliza_Carthy ;
#         bibliographica:byArtist        SoloMusicArtist:Eliza_Carthy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1d70f325-3145-4927-8cff-d3094a5b74e0"^^xsd:anyURI .
#
# CDs:Infamous_Angel  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Infamous Angel" ;
#         dcterms:creator                SoloMusicArtist:Iris_DeMent ;
#         bibliographica:byArtist        SoloMusicArtist:Iris_DeMent ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ee0f4047-e49d-4bfa-9afb-abb267972df4"^^xsd:anyURI .
#
# CDs:Glad_n_Greasy  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Glad 'n' Greasy" ;
#         dcterms:creator                MusicGroup:The_Beat_Farmers ;
#         bibliographica:byArtist        MusicGroup:The_Beat_Farmers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3f03b021-c02d-40d9-b9ec-54a535d307d2"^^xsd:anyURI .
#
# CDs:Milestones  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Milestones" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4bc372d6-e214-4180-8428-b43e9fa479dd"^^xsd:anyURI .
#
# CDs:Atlanta_62506  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Atlanta 6.25.06" ;
#         dcterms:creator          SoloMusicArtist:Phil_Lesh ;
#         bibliographica:byArtist  SoloMusicArtist:Phil_Lesh .
#
# CDs:Inner_Mounting_Flame
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Inner Mounting Flame" ;
#         dcterms:creator                MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:byArtist        MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ed110c7b-6963-43d8-b353-646c164eb4e3"^^xsd:anyURI .
#
# CDs:One_From_Vault  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One From the Vault" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/761ec65c-9fc9-4b37-a0e5-5c83cc512251"^^xsd:anyURI .
#
# CDs:Welela  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Welela" ;
#         dcterms:creator                SoloMusicArtist:Miriam_Makeba ;
#         bibliographica:byArtist        SoloMusicArtist:Miriam_Makeba ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83b48a2f-4de3-442a-b5c1-a7dc61d010ba"^^xsd:anyURI .
#
# CDs:Uprising  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Uprising" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f05b59f2-edc1-4c33-8dc9-795ace7f1c3e"^^xsd:anyURI .
#
# CDs:The_Beekeeper  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Beekeeper" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/668d26d7-1ab8-40f8-9a23-57ef58ab86f0"^^xsd:anyURI .
#
# CDs:At_Budokan  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At Budokan" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/77c2d53b-072c-3bd6-91ae-5d66a28ebd2f"^^xsd:anyURI .
#
# CDs:Bridges  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bridges" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4598715f-8d54-478b-90bb-a613bb739a59"^^xsd:anyURI .
#
# CDs:Yellow_Moon  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yellow Moon" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de131056-0927-4875-82fb-725f2285e87c"^^xsd:anyURI .
#
# CDs:Man_Under_the_Influence
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Man Under the Influence" ;
#         dcterms:creator                SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:byArtist        SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0a805b94-52b6-4c74-8eff-744d213f9d2e"^^xsd:anyURI .
#
# CDs:Soul_Sauce  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Soul Sauce" ;
#         dcterms:creator                SoloMusicArtist:Cal_Tjader ;
#         bibliographica:byArtist        SoloMusicArtist:Cal_Tjader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5d568366-e2fa-4c84-b4b0-e8b7e98b1773"^^xsd:anyURI .
#
# CDs:Chess_Box  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Chess Box" ;
#         dcterms:creator                SoloMusicArtist:Willie_Dixon ;
#         bibliographica:byArtist        SoloMusicArtist:Willie_Dixon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5763fe9e-95bf-4b66-9f06-db6e543219d4"^^xsd:anyURI .
#
# CDs:Chocolat  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chocolat" ;
#         dcterms:creator                SoloMusicArtist:Rachel_Portman ;
#         bibliographica:byArtist        SoloMusicArtist:Rachel_Portman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3b3ffba-f9f0-41a1-a113-9f25ace8c85f"^^xsd:anyURI .
#
# CDs:Lone_Justice_CD  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lone Justice" ;
#         dcterms:creator                MusicGroup:Lone_Justice ;
#         bibliographica:byArtist        MusicGroup:Lone_Justice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/31e96b19-43f4-41b2-95b7-872a0103d353"^^xsd:anyURI .
#
# CDs:Both_Sides_Gun  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Both Sides of the Gun" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4acd5fe4-d4e4-45a2-9a2b-d226df5f2933"^^xsd:anyURI .
#
# CDs:Para_Bailar_Casino  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Para Bailar Casino" ;
#         dcterms:creator                MusicGroup:Adalberto_Alvarez_Y_Su_Son ;
#         bibliographica:byArtist        MusicGroup:Adalberto_Alvarez_Y_Su_Son ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d06a18be-bdc4-417c-9e3c-2235e2fc71a7"^^xsd:anyURI .
#
# CDs:You_Cant_Do_That_On_Stage_v3
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 3" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ac2b8315-ffac-4513-bafb-2fd9e453a981"^^xsd:anyURI .
#
# CDs:Outlaws_Angels  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Outlaws & Angels" ;
#         dcterms:creator                MusicGroup:Willie_Nelson_Friends ;
#         bibliographica:byArtist        MusicGroup:Willie_Nelson_Friends ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9dea003c-9513-4b55-a451-802e2c12da3f"^^xsd:anyURI .
#
# CDs:Let_Them_Say  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Let Them Say" ;
#         dcterms:creator                MusicGroup:Montreux ;
#         bibliographica:byArtist        MusicGroup:Montreux ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d687f694-a209-4bc5-bca9-52833518681b"^^xsd:anyURI .
#
# CDs:Things_That_Show  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Things That Show" ;
#         dcterms:creator                SoloMusicArtist:Kris_McKay ;
#         bibliographica:byArtist        SoloMusicArtist:Kris_McKay ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7bc6591a-9557-4ace-a9e1-bdca4baae570"^^xsd:anyURI .
#
# CDs:Strangers_World  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stranger's World" ;
#         dcterms:creator                SoloMusicArtist:Patty_Larkin ;
#         bibliographica:byArtist        SoloMusicArtist:Patty_Larkin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/af835e59-c5e8-464a-a662-c247d6f27249"^^xsd:anyURI .
#
# CDs:April_Fools_Day  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "April Fool's Day" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Almost_Acoustic  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Almost Acoustic" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0cfc1fbf-1784-4b0d-9149-91fe926caf6a"^^xsd:anyURI .
#
# CDs:Mambo_RO  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mambo" ;
#         dcterms:creator                SoloMusicArtist:Remmy_Ongala ;
#         bibliographica:byArtist        SoloMusicArtist:Remmy_Ongala ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7430d37e-0ac5-4333-8142-1b27d865cd93"^^xsd:anyURI .
#
# CDs:Live_IG  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live" ;
#         dcterms:creator          MusicGroup:Indigo_Girls ;
#         bibliographica:byArtist  MusicGroup:Indigo_Girls .
#
# CDs:Catie_Curtis_CD  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Catie Curtis" ;
#         dcterms:creator                SoloMusicArtist:Catie_Curtis ;
#         bibliographica:byArtist        SoloMusicArtist:Catie_Curtis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/06a1ea99-732d-477e-ac07-1abb3a09e255"^^xsd:anyURI .
#
# CDs:Way_After_Midnight  a           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Way After Midnight" ;
#         dcterms:creator          SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist  SoloMusicArtist:Jerry_Garcia .
#
# CDs:Danu_CD  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Danú" ;
#         dcterms:creator                MusicGroup:Danu ;
#         bibliographica:byArtist        MusicGroup:Danu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f3b43c7a-11c3-488a-a2b4-327e985d132d"^^xsd:anyURI .
#
# CDs:Combat_Rock  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Combat Rock" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/912e77ed-015a-33cc-b6c0-fed80d9de0b7"^^xsd:anyURI .
#
# CDs:Thelonius_With_Coltrane_Five
#         a                              mo:CD , mo:Record , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "Live at the Five Spot Discovery!" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane , SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk , SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3e0755b6-6746-438a-873c-53e45baeaebe"^^xsd:anyURI .
#
# CDs:Nights_at_Keystone_v2
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nights at the Keystone, Volume 2" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/900e43f7-e3fe-4560-a90a-fe0a4408c63b"^^xsd:anyURI .
#
# CDs:Acoustic_Band_Alive  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Acoustic Band Alive" ;
#         dcterms:creator                MusicGroup:Chick_Corea_Akoustic ;
#         bibliographica:byArtist        MusicGroup:Chick_Corea_Akoustic ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/81a1687c-bc01-4e27-b2b2-4f0f89e60c87"^^xsd:anyURI .
#
# CDs:Chunky_Pecan_Pie  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chunky Pecan Pie" ;
#         dcterms:creator                SoloMusicArtist:Karl_Denson ;
#         bibliographica:byArtist        SoloMusicArtist:Karl_Denson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e0e5f6b3-59e4-4d9f-b3a6-3ee95bf8dd22"^^xsd:anyURI .
#
# CDs:For_All_Seasons_Mind
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "For All the Seasons of Your Mind" ;
#         dcterms:creator                SoloMusicArtist:Janis_Ian ;
#         bibliographica:byArtist        SoloMusicArtist:Janis_Ian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/54d5e90d-7c87-4e59-bb9e-bfc206bf8e07"^^xsd:anyURI .
#
# CDs:Best_of_Airto  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best Of Airto" ;
#         dcterms:creator                SoloMusicArtist:Airto_Moreira ;
#         bibliographica:byArtist        SoloMusicArtist:Airto_Moreira ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a0f0593e-8b75-401a-a90c-78c1e2192f38"^^xsd:anyURI .
#
# CDs:Duets  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Duets" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3ee293e6-f8fa-402a-9e68-b5614ebaf006"^^xsd:anyURI .
#
# CDs:Beat   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Beat" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c09a72e8-2b12-44b2-91ce-b0ef65f05b9c"^^xsd:anyURI .
#
# CDs:Strange_Persuasions  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Strange Persuasions" ;
#         dcterms:creator          SoloMusicArtist:Clive_Gregson ;
#         bibliographica:byArtist  SoloMusicArtist:Clive_Gregson .
#
# CDs:Strange_Little_Girls
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strange Little Girls" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cf58ebaa-1834-410a-bd9d-0f0f85706a4b"^^xsd:anyURI .
#
# CDs:Cropredy_Capers  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cropredy Capers: Twenty Five Years of Fairport Convention and Friends at Cropredy Festival" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9c5b2b35-ceee-4152-94e4-758749b35f63"^^xsd:anyURI .
#
# CDs:Helpless_Heart  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Helpless Heart" ;
#         dcterms:creator                SoloMusicArtist:Maura_OConnell ;
#         bibliographica:byArtist        SoloMusicArtist:Maura_OConnell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dec70e34-aa50-4d04-8daf-36a7eee2e16f"^^xsd:anyURI .
#
# CDs:Anthem  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anthem" ;
#         dcterms:creator                MusicGroup:Black_Uhuru ;
#         bibliographica:byArtist        MusicGroup:Black_Uhuru ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a4fe9bb1-1790-4d5f-93b1-aabe513ec6ff"^^xsd:anyURI .
#
# CDs:Led_Zeppelin_III  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Led Zeppelin III" ;
#         dcterms:creator                MusicGroup:Led_Zeppelin ;
#         bibliographica:byArtist        MusicGroup:Led_Zeppelin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/721180e3-88f0-40a1-83cc-468215819a0d"^^xsd:anyURI .
#
# CDs:Live_at_Grand_Opera  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Grand Opera House Belfast" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/557776b7-e60c-358b-87b7-e219e672622c"^^xsd:anyURI .
#
# CDs:Best_of_Horace_Silver_Vol2
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Horace Silver, Vol. 2" ;
#         dcterms:creator                SoloMusicArtist:Horace_Silver ;
#         bibliographica:byArtist        SoloMusicArtist:Horace_Silver ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9a5a41e9-9bdb-445a-af99-693a8584b4ba"^^xsd:anyURI .
#
# CDs:Whatevers_For_Us  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Whatever's for Us" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d6cc906e-107c-3636-9890-8df3b80cbf22"^^xsd:anyURI .
#
# CDs:Best_Band_You_Never_Heard
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best Band You Never Heard In Your Life" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4edce4cf-a3ea-41fb-8690-db4a1a13430c"^^xsd:anyURI .
#
# CDs:Doo_Bop  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Doo-Bop" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc311d36-6df0-4efc-8568-a50b727a281c"^^xsd:anyURI .
#
# CDs:Salt_Sun_Time  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Salt, Sun and Time" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/f13f7bb7-94bf-3630-8b3b-27cbe824da29"^^xsd:anyURI .
#
# CDs:All_Understood  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "All Understood" ;
#         dcterms:creator                MusicGroup:Buchanan ;
#         bibliographica:byArtist        MusicGroup:Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/37668bae-12e8-312e-8a75-5746a27f4d3a"^^xsd:anyURI .
#
# CDs:Live_Bottom_Line  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The David Johansen Group Live" ;
#         dcterms:creator                SoloMusicArtist:David_Johansen ;
#         bibliographica:byArtist        SoloMusicArtist:David_Johansen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c123545e-9547-4dcd-b662-2e527fac24cb"^^xsd:anyURI .
#
# CDs:Nightclubbing  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nightclubbing" ;
#         dcterms:creator                SoloMusicArtist:Grace_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Grace_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/095e2e2e-60c4-4f9f-a14a-2cc1b468bf66"^^xsd:anyURI .
#
# CDs:Time_No_Reply  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Time of No Reply" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/72ae1df2-7af0-3758-b4a1-c0ac2f1769d6"^^xsd:anyURI .
#
# CDs:Thelonius_With_Coltrane
#         a                              mo:CD , mo:Release , mo:Record , schema:MusicAlbum ;
#         rdfs:label                     "Thelonious Monk with John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk , SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane , SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dbd2be34-6a00-4f1d-8010-ae910ec7dde5"^^xsd:anyURI .
#
# CDs:Cmon_Cmon  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "C’mon, C’mon" ;
#         dcterms:creator                SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:byArtist        SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ac4e672f-0d31-47d4-ad3b-32bbbb1c2ffb"^^xsd:anyURI .
#
# CDs:All_Time_Greatest_Hits
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "All-Time Greatest Hits" ;
#         dcterms:creator                SoloMusicArtist:Kris_Kristofferson ;
#         bibliographica:byArtist        SoloMusicArtist:Kris_Kristofferson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9258409f-92d7-4efd-bd50-84d885c40007"^^xsd:anyURI .
#
# CDs:Teaser  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Teaser" ;
#         dcterms:creator                SoloMusicArtist:Tommy_Bolin ;
#         bibliographica:byArtist        SoloMusicArtist:Tommy_Bolin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/42919bed-aeda-398a-9501-0ae088ec7c66"^^xsd:anyURI .
#
# CDs:Solo   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Solo" ;
#         dcterms:creator                SoloMusicArtist:Badi_Assad ;
#         bibliographica:byArtist        SoloMusicArtist:Badi_Assad ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df16587e-9f53-4ff2-98c6-4afe28b1f34d"^^xsd:anyURI .
#
# CDs:Other_Voices_Present
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Other Voices, Present Echoes" ;
#         dcterms:creator          SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:byArtist  SoloMusicArtist:Nanci_Griffith .
#
# CDs:Quintessential_Billie_Holiday_v6
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Quintessential Billie Holiday, Vol. 6" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e1f19810-150b-4073-a24a-64c9e58faf4a"^^xsd:anyURI .
#
# CDs:The_Red_Thread  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Red Thread" ;
#         dcterms:creator                SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:byArtist        SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86be63b7-8125-4b96-95e5-a590307c1220"^^xsd:anyURI .
#
# CDs:Chameleon  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chameleon" ;
#         dcterms:creator                SoloMusicArtist:Badi_Assad ;
#         bibliographica:byArtist        SoloMusicArtist:Badi_Assad ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7f2ed214-9239-4c78-8059-4da3bcd50b0e"^^xsd:anyURI .
#
# CDs:Lonesome_Standard_Time
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lonesome Standard Time" ;
#         dcterms:creator                SoloMusicArtist:Kathy_Mattea ;
#         bibliographica:byArtist        SoloMusicArtist:Kathy_Mattea ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1e121095-85b1-45ca-9b32-b1878b809ccb"^^xsd:anyURI .
#
# CDs:Colossal_Head  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Colossal Head" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b298c604-1d8d-4920-b7f4-bd93900f92e9"^^xsd:anyURI .
#
# CDs:Sun_Ship  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sun Ship" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b05393d-e6cf-4c91-a95d-9047d7470a93"^^xsd:anyURI .
#
# CDs:Catalyst  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Catalyst" ;
#         dcterms:creator                SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:byArtist        SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/04e64829-bf6b-4776-b295-27194ce1b31e"^^xsd:anyURI .
#
# CDs:Hot_Rats  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hot Rats" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd527306-0dd8-4d99-93c4-4267ff649776"^^xsd:anyURI .
#
# CDs:Here_Come_Warm_Jets  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Here Come the Warm Jets" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e890ced7-f2ab-4e07-aabd-f793e1b4c858"^^xsd:anyURI .
#
# CDs:Life_Is_Sweet  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Life Is Sweet" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e1e49fd5-1e81-4974-8135-df62bec22ace"^^xsd:anyURI .
#
# CDs:Moonlight_Becomes_You
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moonlight Becomes You" ;
#         dcterms:creator                SoloMusicArtist:Willie_Nelson ;
#         bibliographica:byArtist        SoloMusicArtist:Willie_Nelson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92764d0c-f1a5-49f7-b458-01c6c0ba931d"^^xsd:anyURI .
#
# CDs:Babes_in_the_Wood  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Babes in the Wood" ;
#         dcterms:creator                SoloMusicArtist:Mary_Black ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Black ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02875b9d-ac3d-324c-b185-f9e9c429a76a"^^xsd:anyURI .
#
# CDs:Viva_Zapata  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "¡Viva Zapata!" ;
#         dcterms:creator                MusicGroup:Seven_Year_Bitch ;
#         bibliographica:byArtist        MusicGroup:Seven_Year_Bitch ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f36d8ca5-df31-4f0a-8b30-644dd61c9874"^^xsd:anyURI .
#
# CDs:My_Aim_Is_True  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "My Aim Is True" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a8d724e0-feca-4ab0-808d-4fb22a7cee9d"^^xsd:anyURI .
#
# CDs:Cook   a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Cook" ;
#         dcterms:creator          SoloMusicArtist:Jim_McCaffrey ;
#         bibliographica:byArtist  SoloMusicArtist:Jim_McCaffrey .
#
# CDs:Poison_Love  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Poison Love" ;
#         dcterms:creator                SoloMusicArtist:Buddy_Miller ;
#         bibliographica:byArtist        SoloMusicArtist:Buddy_Miller ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/156117c2-3c70-475b-ad43-bb92eb2a0d93"^^xsd:anyURI .
#
# CDs:Societys_Child  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Society's Child" ;
#         dcterms:creator                SoloMusicArtist:Janis_Ian ;
#         bibliographica:byArtist        SoloMusicArtist:Janis_Ian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f03d1ee8-8cb9-45ba-b280-3bb6cbc24fda"^^xsd:anyURI .
#
# CDs:Verve_Silver_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Silver Collection" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0aa514bf-5be2-475a-ac1b-0222f9d4c881"^^xsd:anyURI .
#
# CDs:The_Ultimate_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Ultimate Collection" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a48f89b1-602f-4c2e-a124-89a4df8110e3"^^xsd:anyURI .
#
# CDs:My_Life_Bush_Ghosts  a                mo:CD , mo:Record , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "My Life in the Bush of Ghosts" ;
#         dcterms:creator                SoloMusicArtist:David_Byrne , SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:David_Byrne , SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/598d521e-0cbf-4088-927e-0bbe3ef40dd6"^^xsd:anyURI .
#
# CDs:State_of_Wonder  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A State of Wonder: The Complete Goldberg Variations 1955 & 1981" ;
#         dcterms:creator                SoloMusicArtist:Glenn_Gould ;
#         bibliographica:byArtist        SoloMusicArtist:Glenn_Gould ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/75b299db-e90e-4ed1-b9e1-0fcb3169e4a5"^^xsd:anyURI .
#
# CDs:The_Govnor  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Gov'nor" ;
#         dcterms:creator          SoloMusicArtist:Ashley_Hutchings ;
#         bibliographica:byArtist  SoloMusicArtist:Ashley_Hutchings .
#
# CDs:As_Falls_Wichita  a                   mo:Record , mo:Release , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "As Falls Wichita, So Falls Wichita Falls" ;
#         dcterms:creator                SoloMusicArtist:Pat_Metheny , SoloMusicArtist:Lyle_Mays ;
#         bibliographica:byArtist        SoloMusicArtist:Lyle_Mays , SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3f13728e-a143-4f2b-811a-cd8440176664"^^xsd:anyURI .
#
# CDs:Mischief  a                           mo:CD , mo:Record , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "Mischief" ;
#         dcterms:creator                SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist        SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5d1ee880-f007-4248-b014-a000bda5148e"^^xsd:anyURI .
#
# CDs:Johnny_Handsome  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Johnny Handsome" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e6619929-cf9d-4721-8da5-008a47934a96"^^xsd:anyURI .
#
# CDs:Carlpole_Mudbomb  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Carlpole & Buddy Mudbomb" ;
#         dcterms:creator          MusicGroup:Carlpole ;
#         bibliographica:byArtist  MusicGroup:Carlpole .
#
# CDs:The_Poet_Game  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Poet Game" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01e3de8d-d11d-4aec-95e5-44df3f984aef"^^xsd:anyURI .
#
# CDs:Bop_Til_Drop  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bop Till You Drop" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9ae37a5b-08c0-48bc-a320-f8566cf4306f"^^xsd:anyURI .
#
# CDs:Go_to_Nassau  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Go to Nassau" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de7e554f-e658-4d95-97aa-7ba6febecc01"^^xsd:anyURI .
#
# CDs:Fillmore_East_Live  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Fillmore East" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2a267575-38bd-43d9-9d18-7d1f5190ca62"^^xsd:anyURI .
#
# CDs:Winter_Garden  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Winter Garden: Five Songs for the Season" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/716b1f1c-9756-4258-8985-048bc6b5f886"^^xsd:anyURI .
#
# CDs:Wake_of_Flood  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wake of the Flood" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38770ad0-e77a-4fdb-a6b4-aca09b2ee816"^^xsd:anyURI .
#
# CDs:To_Bring_Love  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "To Bring You My Love" ;
#         dcterms:creator                SoloMusicArtist:PJ_Harvey ;
#         bibliographica:byArtist        SoloMusicArtist:PJ_Harvey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ed790ac9-8562-3192-adce-7aa890dab146"^^xsd:anyURI .
#
# CDs:Live_at_Troubadour  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Troubadour 1969" ;
#         dcterms:creator                SoloMusicArtist:Tim_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d65324a9-5ec6-4cb4-bc40-3cb78f2babfa"^^xsd:anyURI .
#
# CDs:Thelonius_in_Italy  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thelonius Monk in Italy" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b0f80bc3-0bb9-4bdf-8449-5324e316a3f0"^^xsd:anyURI .
#
# CDs:Rice   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rice" ;
#         dcterms:creator                SoloMusicArtist:Eliza_Carthy ;
#         bibliographica:byArtist        SoloMusicArtist:Eliza_Carthy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f0528ace-13ff-4537-ba03-b6206fc6a986"^^xsd:anyURI .
#
# CDs:The_Right_Time  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Right Time" ;
#         dcterms:creator                SoloMusicArtist:Etta_James ;
#         bibliographica:byArtist        SoloMusicArtist:Etta_James ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/96c2def4-e840-443d-845a-5405f1d00fb0"^^xsd:anyURI .
#
# CDs:American_Dream  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American Dream" ;
#         dcterms:creator                MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:byArtist        MusicGroup:Crosby_Stills_Nash_Young ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/21b59084-8dd2-4f42-9bef-a11827c0dc0a"^^xsd:anyURI .
#
# CDs:Q_Are_We_Not_Men  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Q: Are We Not Men? A: We Are Devo!" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d4bfdd53-f9ac-35d8-b30d-f750b4420af4"^^xsd:anyURI .
#
# CDs:Black_Music_White_People
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Black Music For White People" ;
#         dcterms:creator                SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e597524a-29be-4217-9922-3d523925096a"^^xsd:anyURI .
#
# CDs:Brilliant_Corners  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Brilliant Corners" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f361d90f-99ff-4ad2-ac46-a5207a464261"^^xsd:anyURI .
#
# CDs:Trouble_Shangri_La  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Trouble in Shangri-La" ;
#         dcterms:creator                SoloMusicArtist:Stevie_Nicks ;
#         bibliographica:byArtist        SoloMusicArtist:Stevie_Nicks ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99ca654a-f6d3-4385-afb5-ebee6d5e0ff5"^^xsd:anyURI .
#
# CDs:Week_In_January  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Week in January" ;
#         dcterms:creator                SoloMusicArtist:Seamus_Egan ;
#         bibliographica:byArtist        SoloMusicArtist:Seamus_Egan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2d2dc571-adcc-4367-916a-0582131befd3"^^xsd:anyURI .
#
# CDs:Good_Morning_Aztlan  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Good Morning Aztlán" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d51a14b5-7c1d-4c57-99d9-f1361d513761"^^xsd:anyURI .
#
# CDs:Work_For_All  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Work For All" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b096d90d-40e5-41ab-9041-7bb371bdc734"^^xsd:anyURI .
#
# CDs:Dakar  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dakar" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02d67c19-6959-43f1-98b1-47255cb9685e"^^xsd:anyURI .
#
# CDs:Kiss_of_Fire  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kiss of Fire" ;
#         dcterms:creator                MusicGroup:Brave_Combo ;
#         bibliographica:byArtist        MusicGroup:Brave_Combo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/397ee5d4-80b5-33a1-8a10-77da7e5c1f19"^^xsd:anyURI .
#
# CDs:Pigpen_Apt_Demos  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Pigpen Apartment Demos" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Roll_Away_Stone  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Roll Away the Stone" ;
#         dcterms:creator                SoloMusicArtist:Kelly_Joe_Phelps ;
#         bibliographica:byArtist        SoloMusicArtist:Kelly_Joe_Phelps ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f392a32-e85a-47f3-a0ea-d1d8335da62f"^^xsd:anyURI .
#
# CDs:The_White_Album  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The White Album" ;
#         dcterms:creator                MusicGroup:The_Beatles ;
#         bibliographica:byArtist        MusicGroup:The_Beatles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0d8e06e2-95d6-3dd4-bfb2-7781af900bdb"^^xsd:anyURI .
#
# CDs:Short_Trip_Home  a                    mo:Release , mo:Record , mo:CD , schema:MusicAlbum ;
#         rdfs:label                     "Short Trip Home" ;
#         dcterms:creator                SoloMusicArtist:Sam_Bush , SoloMusicArtist:Mike_Marshall , SoloMusicArtist:Edgar_Meyer , SoloMusicArtist:Joshua_Bell ;
#         bibliographica:byArtist        SoloMusicArtist:Edgar_Meyer , SoloMusicArtist:Sam_Bush , SoloMusicArtist:Joshua_Bell , SoloMusicArtist:Mike_Marshall ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/58bc4ccf-8c41-49aa-b94b-819855121faa"^^xsd:anyURI .
#
# CDs:Smoke_and_Mirrors  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Smoke And Mirrors" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Cosmic_Thing  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cosmic Thing" ;
#         dcterms:creator                MusicGroup:B_Fifty_Twos ;
#         bibliographica:byArtist        MusicGroup:B_Fifty_Twos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92915e3d-32ee-3e26-8503-cc05b8db296b"^^xsd:anyURI .
#
# CDs:Fifth_of_Funk  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Fifth of Funk, Vol. 5" ;
#         dcterms:creator                SoloMusicArtist:George_Clinton ;
#         bibliographica:byArtist        SoloMusicArtist:George_Clinton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a676432d-4adb-4caf-bc18-80c1f51d6662"^^xsd:anyURI .
#
# CDs:Let_It_Roll  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Let It Roll" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d7c437e0-a62f-43c6-ae2f-ff6a92e7865b"^^xsd:anyURI .
#
# CDs:Gords_Gold  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gord's Gold" ;
#         dcterms:creator                SoloMusicArtist:Gordon_Lightfoot ;
#         bibliographica:byArtist        SoloMusicArtist:Gordon_Lightfoot ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a833945-4192-4b25-8b75-e3fabde55eba"^^xsd:anyURI .
#
# CDs:Other_Voices_Too  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Other Voices, Too (A Trip Back to Bountiful)" ;
#         dcterms:creator                SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:byArtist        SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b2c841cd-38ff-464c-8a51-93c39638e850"^^xsd:anyURI .
#
# CDs:Seven_Steps  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Seven Steps Boxset CD 6" ;
#         dcterms:creator          SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist  SoloMusicArtist:Miles_Davis .
#
# CDs:Live_At_Jaszczury_Club
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live At Jaszczury Club" ;
#         dcterms:creator          MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist  MusicGroup:Pat_Metheny_Group .
#
# CDs:Deuces_Wild  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deuces Wild" ;
#         dcterms:creator                SoloMusicArtist:BB_King ;
#         bibliographica:byArtist        SoloMusicArtist:BB_King ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/55229cad-2f4f-4b02-8530-7e9d199018fc"^^xsd:anyURI .
#
# CDs:Let_My_Children_Hear_Music
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Let My Children Hear Music" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5834e2a5-d1e8-4aab-adac-e5cc55d5143d"^^xsd:anyURI .
#
# CDs:Too_Much_Fun  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Too Much Fun" ;
#         dcterms:creator                SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:byArtist        SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8662b84c-87f7-4414-8f5b-ab1b82f544e4"^^xsd:anyURI .
#
# CDs:Maire  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Máire" ;
#         dcterms:creator                SoloMusicArtist:Maire_Brennan ;
#         bibliographica:byArtist        SoloMusicArtist:Maire_Brennan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4b0978a6-d511-339d-8ffe-e62deda4eb48"^^xsd:anyURI .
#
# CDs:Down_in_Louisiana  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Down in Louisiana" ;
#         dcterms:creator                SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:byArtist        SoloMusicArtist:Sonny_Landreth ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ea746873-089a-3bb7-b504-5b42818d7558"^^xsd:anyURI .
#
# CDs:Garcia_CD  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Garcia" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e58f1f3b-41ca-4408-a671-5a7a118f9f13"^^xsd:anyURI .
#
# CDs:String_Wizards_Picks
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "String Wizard's Picks" ;
#         dcterms:creator                SoloMusicArtist:John_McEuen ;
#         bibliographica:byArtist        SoloMusicArtist:John_McEuen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8803ba57-77e8-48d9-a8da-2a448aca9e50"^^xsd:anyURI .
#
# CDs:Sheryl_Crow_Friends_Live
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sheryl Crow & Friends Live From Central Park" ;
#         dcterms:creator                SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:byArtist        SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9c1007f2-b70a-4334-ac91-7b9cd4e8d182"^^xsd:anyURI .
#
# CDs:Best_of_Leonard_Cohen
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Leonard Cohen" ;
#         dcterms:creator                SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:byArtist        SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4aaca24f-a467-480d-ba01-51caf489d677"^^xsd:anyURI .
#
# CDs:Gravity  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gravity" ;
#         dcterms:creator                SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:byArtist        SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/e125f303-665b-3487-8b19-a5edb6a46c25"^^xsd:anyURI .
#
# CDs:Sheryl_Crow_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sheryl Crow" ;
#         dcterms:creator                SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:byArtist        SoloMusicArtist:Sheryl_Crow ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c6f9452b-1f6d-4ad5-a55e-700b90471332"^^xsd:anyURI .
#
# CDs:Friends_and_Enemies  a                mo:Release , mo:CD , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "Friends & Enemies" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser , SoloMusicArtist:Fred_Frith ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser , SoloMusicArtist:Fred_Frith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a54cfe28-1e1a-4991-bbce-8a8e8ee2a004"^^xsd:anyURI .
#
# CDs:Bridges_To_Bert  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bridges to Bert" ;
#         dcterms:creator                MusicGroup:Leftover_Salmon ;
#         bibliographica:byArtist        MusicGroup:Leftover_Salmon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9dbf87e4-239f-4678-b18d-cf8732425490"^^xsd:anyURI .
#
# CDs:Live_at_El_Macambo  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the El Mocambo" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ecbf31e-bef2-48d9-ac2b-08188a811970"^^xsd:anyURI .
#
# CDs:Road_Tested  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Road Tested" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f1f2b219-6224-426c-9742-c75010e68fb4"^^xsd:anyURI .
#
# CDs:Exodus  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Exodus" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02beea32-c645-37c4-abb9-8c311bc36a6d"^^xsd:anyURI .
#
# CDs:Tomorrow_Knows  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tomorrow Knows Where You Live" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e8aca49c-f6c2-4843-a344-506668a397e5"^^xsd:anyURI .
#
# CDs:Giant_Step  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Giant Step / De Ole Folks at Home" ;
#         dcterms:creator                SoloMusicArtist:Taj_Mahal ;
#         bibliographica:byArtist        SoloMusicArtist:Taj_Mahal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e046953a-895f-3ce2-a1db-10b99bf1a1c7"^^xsd:anyURI .
#
# CDs:Middle_Passage  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Middle Passage" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e241af7a-38e9-4ca5-ac4c-be83978dea58"^^xsd:anyURI .
#
# CDs:Live_At_Newport_1963
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Newport 1963" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/deeda71b-e4ab-4f1e-94bb-653b849bb7eb"^^xsd:anyURI .
#
# CDs:Joy_Will_Find_a_Way  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Joy Will Find a Way" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/993cbfb4-ae76-3ca0-a7ba-fba4eeb4e1fa"^^xsd:anyURI .
#
# CDs:Odu    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Odù" ;
#         dcterms:creator                SoloMusicArtist:King_Sunny_Ade ;
#         bibliographica:byArtist        SoloMusicArtist:King_Sunny_Ade ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b73ab90d-0ce8-4801-8da3-0a331b9d9392"^^xsd:anyURI .
#
# CDs:Visions_and_Dreams  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Visions and Dreams" ;
#         dcterms:creator                SoloMusicArtist:Carrie_Newcomer ;
#         bibliographica:byArtist        SoloMusicArtist:Carrie_Newcomer ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ecd33132-7c79-4153-8719-37a22f9c8378"^^xsd:anyURI .
#
# CDs:Ghost_in_Machine  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ghost In The Machine" ;
#         dcterms:creator                MusicGroup:Police ;
#         bibliographica:byArtist        MusicGroup:Police ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8921b63d-64eb-4bbd-85af-2aeee0f75181"^^xsd:anyURI .
#
# CDs:Lost_Trident_Sessions
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lost Trident Sessions" ;
#         dcterms:creator                MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:byArtist        MusicGroup:Mahavishnu_Orchestra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a0928437-d1da-4451-b331-da43d97e2ac3"^^xsd:anyURI .
#
# CDs:Cohen_Live  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cohen Live: Leonard Cohen in Concert" ;
#         dcterms:creator                SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:byArtist        SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f624632-bf08-34f9-b87b-cdd3ceefb496"^^xsd:anyURI .
#
# CDs:The_Womans_Boat  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Woman's Boat" ;
#         dcterms:creator                SoloMusicArtist:Toni_Childs ;
#         bibliographica:byArtist        SoloMusicArtist:Toni_Childs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/0e2a8f50-4ab1-3761-9c5c-6b53b2d63521"^^xsd:anyURI .
#
# CDs:Live_at_Birdland  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Birdland" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ba40c4fd-d39f-4d6c-8c24-6bb28c24dfd4"^^xsd:anyURI .
#
# CDs:This_Years_Model  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Year’s Model" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e8101296-9ef3-457f-b2c4-56e014e4d3dc"^^xsd:anyURI .
#
# CDs:More_Creedence_Gold  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "More Creedence Gold" ;
#         dcterms:creator                MusicGroup:Creedence_Clearwater_Revival ;
#         bibliographica:byArtist        MusicGroup:Creedence_Clearwater_Revival ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/80b30b91-5b5b-433b-8cf7-3590aa31ad79"^^xsd:anyURI .
#
# CDs:Love_and_Theft  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Love and Theft" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/9980ffe5-c5b5-3a83-8c1e-1ec6618f97ca"^^xsd:anyURI .
#
# CDs:Kaya   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kaya" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6571aa7a-5de8-34df-acce-d3ab13b775c1"^^xsd:anyURI .
#
# CDs:Spirit  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Spirit" ;
#         dcterms:creator          SoloMusicArtist:Darrell_Grant ;
#         bibliographica:byArtist  SoloMusicArtist:Darrell_Grant .
#
# CDs:Wake_Up  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wake Up!" ;
#         dcterms:creator                SoloMusicArtist:Susan_Greenbaum ;
#         bibliographica:byArtist        SoloMusicArtist:Susan_Greenbaum ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5a5a35ed-1ae5-4203-85f7-87edfaf23c32"^^xsd:anyURI .
#
# CDs:Mama_Mosambiki  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mama Mosambiki" ;
#         dcterms:creator                MusicGroup:Eyuphuro ;
#         bibliographica:byArtist        MusicGroup:Eyuphuro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/37acce6a-1c60-4ee6-abb5-0c931217bb3c"^^xsd:anyURI .
#
# CDs:El_Sonida_Nuevo  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "El Sonido Nuevo" ;
#         dcterms:creator                SoloMusicArtist:Cal_Tjader ;
#         bibliographica:byArtist        SoloMusicArtist:Cal_Tjader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3fd45eb0-b51a-4f54-98cd-89891c5a124f"^^xsd:anyURI .
#
# CDs:Live_at_BBC  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the BBC" ;
#         dcterms:creator                MusicGroup:Dire_Straits ;
#         bibliographica:byArtist        MusicGroup:Dire_Straits ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/11ce3b4c-2310-36b2-ab4a-146449463099"^^xsd:anyURI .
#
# CDs:Tipplers_Tales  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tipplers Tales" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d95e019c-d94b-4776-9810-a0d915ce4559"^^xsd:anyURI .
#
# CDs:Apollo_Atmospheres  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Apollo: Atmospheres & Soundtracks" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/978ce480-cf4b-468d-985b-daee3976e7e7"^^xsd:anyURI .
#
# CDs:Humans  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Humans" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/ccac25e5-6b0b-3c3a-aef9-9a8acec87cc9"^^xsd:anyURI .
#
# CDs:Malagasy_Guitar  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Malagasy Guitar" ;
#         dcterms:creator                SoloMusicArtist:DGary ;
#         bibliographica:byArtist        SoloMusicArtist:DGary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6cd3293d-1fe5-4c0b-b3cc-216be034c87f"^^xsd:anyURI .
#
# CDs:Look_at_Love  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Look at Love" ;
#         dcterms:creator                SoloMusicArtist:Judy_Mowatt ;
#         bibliographica:byArtist        SoloMusicArtist:Judy_Mowatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4c95cc7b-23ff-48db-ac25-8e9276afaa09"^^xsd:anyURI .
#
# CDs:Missing_You  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Missing You (Mi Yeewnii)" ;
#         dcterms:creator                SoloMusicArtist:Baaba_Maal ;
#         bibliographica:byArtist        SoloMusicArtist:Baaba_Maal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/93859bb6-d21e-4cb8-94cc-3e067d19d42c"^^xsd:anyURI .
#
# CDs:Recorded_Live_Electric
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Recorded Live Electric" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1964e201-9b62-4a61-91a6-7be9494e8be8"^^xsd:anyURI .
#
# CDs:Whered_You_Hide  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Where'd You Hide the Body" ;
#         dcterms:creator                SoloMusicArtist:James_McMurtry ;
#         bibliographica:byArtist        SoloMusicArtist:James_McMurtry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4a435208-2306-4589-834e-2d550bdc1dbb"^^xsd:anyURI .
#
# CDs:Up_From_Skies  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Up From the Skies - the Polydor Years" ;
#         dcterms:creator                SoloMusicArtist:Ellen_McIlwaine ;
#         bibliographica:byArtist        SoloMusicArtist:Ellen_McIlwaine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2f62133b-8f2e-4e5a-9359-f39d174d83b9"^^xsd:anyURI .
#
# CDs:Thirty_Greatest_Hits
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "30 Greatest Hits" ;
#         dcterms:creator                SoloMusicArtist:Aretha_Franklin ;
#         bibliographica:byArtist        SoloMusicArtist:Aretha_Franklin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a9ca845f-7221-4f19-a207-b81e9fc511ec"^^xsd:anyURI .
#
# CDs:The_Tide  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Tide" ;
#         dcterms:creator                SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:byArtist        SoloMusicArtist:Lucy_Kaplansky ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fc1d5715-92ed-4115-bb47-8925b5e1aa9e"^^xsd:anyURI .
#
# CDs:New_Era  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "New Era" ;
#         dcterms:creator                SoloMusicArtist:Sipho_Gumede ;
#         bibliographica:byArtist        SoloMusicArtist:Sipho_Gumede ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92758ea7-5f4e-4816-bc34-ec8cff0d5f0c"^^xsd:anyURI .
#
# CDs:Plastic_Ono_Band_JL  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plastic Ono Band" ;
#         dcterms:creator                SoloMusicArtist:John_Lennon ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lennon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c4144425-e510-4289-9653-22d6c85d0aa5"^^xsd:anyURI .
#
# CDs:Welcome_Cruel_World  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Welcome to the Cruel World" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ec54bef-a930-3842-89f1-395c26b4d42a"^^xsd:anyURI .
#
# CDs:The_Lion_Roars  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lion Roars" ;
#         dcterms:creator                MusicGroup:Mahlathini_Mahotella_Queens ;
#         bibliographica:byArtist        MusicGroup:Mahlathini_Mahotella_Queens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/72434d40-ba41-4672-89c7-0e8963691124"^^xsd:anyURI .
#
# CDs:Ambient_4  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ambient 4: On Land" ;
#         dcterms:creator                SoloMusicArtist:Brian_Eno ;
#         bibliographica:byArtist        SoloMusicArtist:Brian_Eno ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ceae0e07-e2dc-43fe-ab2d-9568c0da4490"^^xsd:anyURI .
#
# CDs:The_Complete_1961_VV
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete 1961 Village Vanguard Recordings" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ed4218e-4b96-47e0-986d-391b3aa9f5f5"^^xsd:anyURI .
#
# CDs:Mingus_at_Bohemia  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus at The Bohemia" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c554dc81-4d40-471a-b94e-3b65c33fbd14"^^xsd:anyURI .
#
# CDs:Flying_Cowboys  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Flying Cowboys" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fd595b60-e4cf-4dc5-8a14-06d457a7bbfd"^^xsd:anyURI .
#
# CDs:Show_Some_Emotion  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Show Some Emotion" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f664553e-17df-498b-b67a-788fa391aa31"^^xsd:anyURI .
#
# CDs:Come_Away_With_Me  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Come Away With Me" ;
#         dcterms:creator                SoloMusicArtist:Norah_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Norah_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c88138cf-00f3-3c70-8757-3bbe0e4713d1"^^xsd:anyURI .
#
# CDs:All_Things_Must_Pass
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "All Things Must Pass" ;
#         dcterms:creator                SoloMusicArtist:George_Harrison ;
#         bibliographica:byArtist        SoloMusicArtist:George_Harrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9690e98d-d226-3e79-b206-7bfd2c1c15bf"^^xsd:anyURI .
#
# CDs:Pat_Metheny_Group_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pat Metheny Group" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1f16df07-1c36-483d-b18a-b57b1e1d6cee"^^xsd:anyURI .
#
# CDs:Fate_Nations  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fate of Nations" ;
#         dcterms:creator                SoloMusicArtist:Robert_Plant ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Plant ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c384c098-ce20-4e62-a417-3503d0748a66"^^xsd:anyURI .
#
# CDs:Lost_Episodes  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Lost Episodes" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/203df859-5128-46e5-93ee-f0b650614167"^^xsd:anyURI .
#
# CDs:Timbre  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Timbre" ;
#         dcterms:creator                SoloMusicArtist:Sophie_B_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Sophie_B_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ac1519b3-01b0-4448-894a-ae15ea26c5ed"^^xsd:anyURI .
#
# CDs:The_Kid_and_Brute  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Kid and the Brute" ;
#         dcterms:creator                MusicGroup:Illinois_Jacquet_Ben_Webster ;
#         bibliographica:byArtist        MusicGroup:Illinois_Jacquet_Ben_Webster ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d3851f2c-48dd-466c-9222-1a72490ac570"^^xsd:anyURI .
#
# CDs:Hey_Eugene  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hey Eugene!" ;
#         dcterms:creator                MusicGroup:Pink_Martini ;
#         bibliographica:byArtist        MusicGroup:Pink_Martini ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8ccfba1d-72f5-4614-90fd-3c5056106622"^^xsd:anyURI .
#
# CDs:Holladay_Cole_CD  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Holladay Cole" ;
#         dcterms:creator          SoloMusicArtist:Holladay_Cole ;
#         bibliographica:byArtist  SoloMusicArtist:Holladay_Cole .
#
# CDs:The_Forest  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Forest" ;
#         dcterms:creator                SoloMusicArtist:David_Byrne ;
#         bibliographica:byArtist        SoloMusicArtist:David_Byrne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a737d458-40b3-4860-8cfb-661f6eaf6eb1"^^xsd:anyURI .
#
# CDs:Bluegrass_Reunion  a                  mo:Record , mo:CD , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Bluegrass Reunion" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , MusicGroup:BluegrassReunion ;
#         bibliographica:byArtist        SoloMusicArtist:David_Grisman , MusicGroup:BluegrassReunion ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ebd26d0e-217d-450a-94cb-e55c2758107b"^^xsd:anyURI .
#
# CDs:Rock_Of_Ages  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rock of Ages" ;
#         dcterms:creator                MusicGroup:The_Band ;
#         bibliographica:byArtist        MusicGroup:The_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7f657970-99ce-40e8-ae6a-69989231577d"^^xsd:anyURI .
#
# CDs:Nothing_Is_Easy_Aragon
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Nothing Is Easy: Live - Aragon Ballroom Chicago 1970" ;
#         dcterms:creator          MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist  MusicGroup:Jethro_Tull .
#
# CDs:Cover_Girl  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cover Girl" ;
#         dcterms:creator                SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:byArtist        SoloMusicArtist:Shawn_Colvin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9bd2dd72-369f-4277-a199-0fc20df5b4f5"^^xsd:anyURI .
#
# CDs:Big_City_Blues  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big City Blues" ;
#         dcterms:creator                SoloMusicArtist:Sue_Foley ;
#         bibliographica:byArtist        SoloMusicArtist:Sue_Foley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/89d74f1b-acab-429b-8b6f-6faa022c5e4c"^^xsd:anyURI .
#
# CDs:Life_Planet_Groove  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Life on Planet Groove" ;
#         dcterms:creator                SoloMusicArtist:Maceo_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Maceo_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ecdce2c1-3ed5-3347-8bcc-581df2f0a6ac"^^xsd:anyURI .
#
# CDs:Seven_Year_Surrender
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Seven Year Surrender" ;
#         dcterms:creator          SoloMusicArtist:Jill_Cohn ;
#         bibliographica:byArtist  SoloMusicArtist:Jill_Cohn .
#
# CDs:Tusk_CVB  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tusk" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4eb272d9-99cb-462d-a2d9-a6a4fd9bdce0"^^xsd:anyURI .
#
# CDs:Synchronicity  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Synchronicity" ;
#         dcterms:creator                MusicGroup:Police ;
#         bibliographica:byArtist        MusicGroup:Police ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53a7e6d5-077f-31a1-bd4d-9c4081dbd8f4"^^xsd:anyURI .
#
# CDs:Playing_Real_Good  a                  schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Playing Real Good" ;
#         dcterms:creator                SoloMusicArtist:Hani_Naser , SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:Hani_Naser , SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5822d80-c0fa-487f-8d25-e304e6708c16"^^xsd:anyURI .
#
# CDs:London_Calling  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "London Calling" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/64cbd9c8-7446-3e26-8db0-81653eadc8dd"^^xsd:anyURI .
#
# CDs:Southern_Exposure  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Southern Exposure" ;
#         dcterms:creator                SoloMusicArtist:Alex_de_Grassi ;
#         bibliographica:byArtist        SoloMusicArtist:Alex_de_Grassi ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d87c9431-cc3e-37e8-9181-5fc69a917c3a"^^xsd:anyURI .
#
# CDs:Paradise_Lost_Found  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Paradise Lost & Found" ;
#         dcterms:creator                SoloMusicArtist:Anne_Hills ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Gallup ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/307e8ded-3da4-424c-bd66-38ac79738ed1"^^xsd:anyURI .
#
# CDs:Deep_Soul_Diver  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deep Soul Diver" ;
#         dcterms:creator                MusicGroup:Disappear_Fear ;
#         bibliographica:byArtist        MusicGroup:Disappear_Fear ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0973170d-e3a3-4aba-b940-252b10f9beb2"^^xsd:anyURI .
#
# CDs:No_Big_Surprise  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Big Surprise" ;
#         dcterms:creator                SoloMusicArtist:Steve_Goodman ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Goodman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b433114f-3cb8-4b18-92ea-ada3b14e4003"^^xsd:anyURI .
#
# CDs:Diamond_Dogs  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Diamond Dogs" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4f00baf4-c11c-41dc-bdca-4267180077f7"^^xsd:anyURI .
#
# CDs:Deep_Forest_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deep Forest" ;
#         dcterms:creator                MusicGroup:Deep_Forest ;
#         bibliographica:byArtist        MusicGroup:Deep_Forest ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d012fe43-aadf-487d-bdb5-a38d885f9dd2"^^xsd:anyURI .
#
# CDs:Talkin_Blues  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Talkin' Blues" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f7d5ae0c-52bd-4379-9360-0ef771b47265"^^xsd:anyURI .
#
# CDs:Mingus  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e689e2ce-449a-3a41-8185-99e195e78f2e"^^xsd:anyURI .
#
# CDs:In_Search_Lost_Riddim
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Search of the Lost Riddim" ;
#         dcterms:creator                SoloMusicArtist:Ernest_Ranglin ;
#         bibliographica:byArtist        SoloMusicArtist:Ernest_Ranglin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9bbaaa58-f1bd-4673-99c2-8a6ee48faf02"^^xsd:anyURI .
#
# CDs:Breakfast_In_Field  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Breakfast in the Field" ;
#         dcterms:creator                SoloMusicArtist:Michael_Hedges ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Hedges ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f3cd188c-884e-46dc-90eb-b03a9f07a0c8"^^xsd:anyURI .
#
# CDs:Bird_Savoy_Recordings
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bird/The Savoy Recordings (Master Takes)" ;
#         dcterms:creator                SoloMusicArtist:Charlie_Parker ;
#         bibliographica:byArtist        SoloMusicArtist:Charlie_Parker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/20bb99f7-c54b-4336-bea5-020e53b19447"^^xsd:anyURI .
#
# CDs:Who_Got_The_10_1_2  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Who's Got the 10½?" ;
#         dcterms:creator                MusicGroup:Black_Flag ;
#         bibliographica:byArtist        MusicGroup:Black_Flag ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dcaf0cab-da06-4ea7-86b5-66f0e9996bec"^^xsd:anyURI .
#
# CDs:Half_Moon_Bay  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Half Moon Bay" ;
#         dcterms:creator          SoloMusicArtist:William_Aura ;
#         bibliographica:byArtist  SoloMusicArtist:William_Aura .
#
# CDs:Something_Like_Bird  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Something Like A Bird" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2c8c6a0-27d0-454e-8f44-2866a41f7069"^^xsd:anyURI .
#
# CDs:Headkeeper  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Headkeeper" ;
#         dcterms:creator                SoloMusicArtist:Dave_Mason ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Mason ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3cdda51c-ab21-4dba-9e85-df83a365d577"^^xsd:anyURI .
#
# CDs:Live_Badu  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:Erykah_Badu ;
#         bibliographica:byArtist        SoloMusicArtist:Erykah_Badu ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a481f663-c7e1-36ee-bf8a-f235971587fe"^^xsd:anyURI .
#
# CDs:Rendezvous  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rendezvous" ;
#         dcterms:creator                SoloMusicArtist:Sandy_Denny ;
#         bibliographica:byArtist        SoloMusicArtist:Sandy_Denny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/80731efc-77e7-401a-9fef-6ed2033bc6b5"^^xsd:anyURI .
#
# CDs:Dead_Dogs_Eyeball  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dead Dog's Eyeball" ;
#         dcterms:creator                SoloMusicArtist:K_McCarty ;
#         bibliographica:byArtist        SoloMusicArtist:K_McCarty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/65eb363d-40a6-4dff-93c4-234eec4a67eb"^^xsd:anyURI .
#
# CDs:Moonpie_Dreams  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moonpie Dreams" ;
#         dcterms:creator                SoloMusicArtist:Kate_Campbell ;
#         bibliographica:byArtist        SoloMusicArtist:Kate_Campbell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2873857a-18e3-4aa0-933d-8e9a84fdd83e"^^xsd:anyURI .
#
# CDs:Armed_Forces  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Armed Forces" ;
#         dcterms:creator                MusicGroup:Elvis_Costello_Attractions ;
#         bibliographica:byArtist        MusicGroup:Elvis_Costello_Attractions ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fea946a8-c05d-3a9b-a6fb-df5e592342a5"^^xsd:anyURI .
#
# CDs:No_Guru  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Guru, No Method, No Teacher" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0430d132-cfb7-487c-ac19-b5d33e5b794d"^^xsd:anyURI .
#
# CDs:Kicking_Against_Pricks
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kicking Against the Pricks" ;
#         dcterms:creator                MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:byArtist        MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/37be9e09-e5d5-3337-bde0-13382a0461cf"^^xsd:anyURI .
#
# CDs:Girl_Like_Me  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Girl Like Me" ;
#         dcterms:creator          SoloMusicArtist:KJ_Denhert ;
#         bibliographica:byArtist  SoloMusicArtist:KJ_Denhert .
#
# CDs:On_the_Corner  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "On the Corner" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/33d97eb3-0cdc-3342-950b-c200b736c048"^^xsd:anyURI .
#
# CDs:TNT_Dynamite  a                       mo:Record , mo:CD , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "Drinkin' TNT 'n' Smokin' Dynamite" ;
#         dcterms:creator                SoloMusicArtist:Junior_Wells , SoloMusicArtist:Buddy_Guy ;
#         bibliographica:byArtist        SoloMusicArtist:Junior_Wells , SoloMusicArtist:Buddy_Guy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e24908ef-cf56-4e0e-a8d6-14001e647ca7"^^xsd:anyURI .
#
# CDs:Im_Staying_Out  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I'm Staying Out" ;
#         dcterms:creator                SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:byArtist        SoloMusicArtist:Caitlin_Cary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a49b0395-f239-48d3-aa65-4149365a9e71"^^xsd:anyURI .
#
# CDs:Ziggy_Stardust  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Rise and Fall of Ziggy Stardust and the Spiders From Mars" ;
#         dcterms:creator                SoloMusicArtist:David_Bowie ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bowie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b2ef43e-74fd-3e12-afdb-f486d971c408"^^xsd:anyURI .
#
# CDs:Quiet_After_Storm  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Quiet After The Storm" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92916f94-7fc4-48fa-94b3-ec6331a82f3c"^^xsd:anyURI .
#
# CDs:Cruel_Crazy_Beautiful_World
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cruel, Crazy, Beautiful World" ;
#         dcterms:creator                MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:byArtist        MusicGroup:Johnny_Clegg_Savuka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ff26461b-cfd9-40bf-9a55-9185c75f41f7"^^xsd:anyURI .
#
# CDs:World_Out_of_Time  a                  mo:Record , mo:Release , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "A World out of Time: Henry Kaiser & David Lindley in Madagascar" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser , SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley , SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fbc6053f-5bcf-422c-8f98-83cf223cc964"^^xsd:anyURI .
#
# CDs:Other_Side_Round_Midnight
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Other Side Of Round Midnight" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7437d8af-bd07-44e9-98b4-deace01b515b"^^xsd:anyURI .
#
# CDs:Classic_Tenors  a                     mo:Record , mo:Release , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "Classic Tenors" ;
#         dcterms:creator                SoloMusicArtist:Lester_Young , SoloMusicArtist:Coleman_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Coleman_Hawkins , SoloMusicArtist:Lester_Young ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/97e33a2f-e108-4f42-bb01-7f831912bde9"^^xsd:anyURI .
#
# CDs:High_Winds_White_Sky
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "High Winds White Sky" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/98b7b16f-650d-3e95-92ff-5ee1f822adb9"^^xsd:anyURI .
#
# CDs:Uninvisible  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Uninvisible" ;
#         dcterms:creator                MusicGroup:Medeski_Martin_Wood ;
#         bibliographica:byArtist        MusicGroup:Medeski_Martin_Wood ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/933fe97b-1791-4a3a-a480-c6f406680dff"^^xsd:anyURI .
#
# CDs:Mingus_at_Carnegie_Hall
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus at Carnegie Hall" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b00d5414-c543-4818-bb7a-026489e4ddd5"^^xsd:anyURI .
#
# CDs:Trio_of_Doom  a                       mo:CD , mo:Release , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "Trio of Doom" ;
#         dcterms:creator                SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Jaco_Pastorius , SoloMusicArtist:Tony_Williams ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Williams , SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Jaco_Pastorius ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/23cdf4bc-d149-4b11-bc83-7167b2d59d57"^^xsd:anyURI .
#
# CDs:King_Delta_Blues_Singers
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "King of the Delta Blues Singers" ;
#         dcterms:creator                SoloMusicArtist:Robert_Johnson ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Johnson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7800ceb3-33c0-3081-8093-55d7f9d14fc1"^^xsd:anyURI .
#
# CDs:I_Need_A_Gun_And_A_Drunk
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "I Need A Gun And A Drunk" ;
#         dcterms:creator          MusicGroup:Bleecker_Street ;
#         bibliographica:byArtist  MusicGroup:Bleecker_Street .
#
# CDs:Fiyo_on_Bayou  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fiyo on the Bayou" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e62f7f81-3068-4d20-ab3b-aacdcaa2a41a"^^xsd:anyURI .
#
# CDs:Union  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Union" ;
#         dcterms:creator                SoloMusicArtist:Toni_Childs ;
#         bibliographica:byArtist        SoloMusicArtist:Toni_Childs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/90f0009d-a9bd-4aca-a08c-63bcc0854f95"^^xsd:anyURI .
#
# CDs:Live_at_Cropredy  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live at Cropredy" ;
#         dcterms:creator          SoloMusicArtist:Richard_Thompson , MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist  SoloMusicArtist:Richard_Thompson , MusicGroup:Fairport_Convention .
#
# CDs:Harbourfront  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:comment             "Can't locate on Musicbrainz." ;
#         rdfs:label               "Harbourfront" ;
#         dcterms:creator          SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist  SoloMusicArtist:Bruce_Cockburn .
#
# CDs:Del_And_The_Boys  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Del And The Boys" ;
#         dcterms:creator                MusicGroup:Del_McCoury_Band ;
#         bibliographica:byArtist        MusicGroup:Del_McCoury_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/31fce93f-44e1-46a5-98cb-6f8491f0d1b3"^^xsd:anyURI .
#
# CDs:House_of_Hope  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "House of Hope" ;
#         dcterms:creator                SoloMusicArtist:Toni_Childs ;
#         bibliographica:byArtist        SoloMusicArtist:Toni_Childs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e77a0f88-956b-45ba-bb70-553ef0e9bd17"^^xsd:anyURI .
#
# CDs:Home_Ground  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Home Ground" ;
#         dcterms:creator                MusicGroup:Battlefield_Band ;
#         bibliographica:byArtist        MusicGroup:Battlefield_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92b39563-db48-43f9-aea6-4202f23c392a"^^xsd:anyURI .
#
# CDs:Cello_Suites  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Cello Suites: Inspired by Bach" ;
#         dcterms:creator                SoloMusicArtist:YoYo_Ma ;
#         bibliographica:byArtist        SoloMusicArtist:YoYo_Ma ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2a018799-55cb-43f1-a0ae-4a54a319d768"^^xsd:anyURI .
#
# CDs:Stick_Man  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stick Man" ;
#         dcterms:creator                SoloMusicArtist:Tony_Levin ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Levin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/12002bd7-07f7-4b18-9cda-347c4114dec1"^^xsd:anyURI .
#
# CDs:Lost_Songs  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lost Songs 95-98" ;
#         dcterms:creator                SoloMusicArtist:David_Gray ;
#         bibliographica:byArtist        SoloMusicArtist:David_Gray ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4fd093d7-41a9-42f9-97df-10041c05d0a6"^^xsd:anyURI .
#
# CDs:Friends_of_Mine  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Friends of Mine" ;
#         dcterms:creator                SoloMusicArtist:Ramblin_Jack_Elliott ;
#         bibliographica:byArtist        SoloMusicArtist:Ramblin_Jack_Elliott ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de57dcee-7b73-43f3-8165-e7b4fa5c263f"^^xsd:anyURI .
#
# CDs:Blood_Red_Cherry  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blood Red Cherry" ;
#         dcterms:creator                SoloMusicArtist:Jann_Arden ;
#         bibliographica:byArtist        SoloMusicArtist:Jann_Arden ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d1d86815-32e7-4d1c-ba24-469f0c65986a"^^xsd:anyURI .
#
# CDs:Spread_Your_Wings  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spread Your Wings and Fly: Live at the Fillmore East May 30, 1971" ;
#         dcterms:creator                SoloMusicArtist:Laura_Nyro ;
#         bibliographica:byArtist        SoloMusicArtist:Laura_Nyro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8b85e63c-0538-4807-8c3b-565f8d87aa9b"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_11  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 11: Stanley Theater 9/27/72" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8cfe7765-572a-4de5-85ed-8cb51f86f3be"^^xsd:anyURI .
#
# CDs:Immortal_Little_Sparrow
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Édith Piaf: Immortal Little Sparrow of France" ;
#         dcterms:creator                SoloMusicArtist:Edith_Piaf ;
#         bibliographica:byArtist        SoloMusicArtist:Edith_Piaf ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/568be438-b7be-45ea-8fc0-58294d329d5e"^^xsd:anyURI .
#
# CDs:Hello_Young_Lovers  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hello Young Lovers" ;
#         dcterms:creator                MusicGroup:Glass_Eye ;
#         bibliographica:byArtist        MusicGroup:Glass_Eye ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c77ce024-dcd1-4bbb-b1c1-18f1cd6a2961"^^xsd:anyURI .
#
# CDs:Swamped  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Swamped" ;
#         dcterms:creator                SoloMusicArtist:Tony_Furtado ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Furtado ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2e4ebca9-0a83-4f7f-83d0-e298d9dac84a"^^xsd:anyURI .
#
# CDs:Plasma  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plasma" ;
#         dcterms:creator                SoloMusicArtist:Trey_Anastasio ;
#         bibliographica:byArtist        SoloMusicArtist:Trey_Anastasio ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c4144425-e510-4289-9653-22d6c85d0aa5"^^xsd:anyURI .
#
# CDs:Taproot  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Taproot" ;
#         dcterms:creator                SoloMusicArtist:Michael_Hedges ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Hedges ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3002e163-3164-4072-9d63-f577a6194e39"^^xsd:anyURI .
#
# CDs:Family_Groove  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Family Groove" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ac44531-ffcb-4d1d-a68f-f7818db13d2b"^^xsd:anyURI .
#
# CDs:Dark_Side_Moon  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dark Side Of The Moon" ;
#         dcterms:creator                MusicGroup:Pink_Floyd ;
#         bibliographica:byArtist        MusicGroup:Pink_Floyd ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10600476-3b48-4709-a91d-3fdf6d2455e6"^^xsd:anyURI .
#
# CDs:Novemeber_Suite  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Novemeber Suite" ;
#         dcterms:creator                SoloMusicArtist:Robert_Fripp ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Fripp ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1db41d2-528e-46ac-be9c-bd9f3190e554"^^xsd:anyURI .
#
# CDs:We_Want_Miles  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "We Want Miles" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e87ad418-0e38-460d-b971-9f31b221d327"^^xsd:anyURI .
#
# CDs:European_Tour_JT  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "A Live Passion - European Tour, May 1973" ;
#         dcterms:creator          MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist  MusicGroup:Jethro_Tull .
#
# CDs:Dry    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dry" ;
#         dcterms:creator                SoloMusicArtist:PJ_Harvey ;
#         bibliographica:byArtist        SoloMusicArtist:PJ_Harvey ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ecaba33-4323-41ca-8129-18699d105562"^^xsd:anyURI .
#
# CDs:Young_Lions  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Young Lions" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/38a32ba3-77e1-35c1-83aa-828b7913fd1a"^^xsd:anyURI .
#
# CDs:The_Best_of_Coltrane
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9646ee50-d2d8-4bac-bf56-1a93d6b4f91b"^^xsd:anyURI .
#
# CDs:The_Bears_CD  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bears" ;
#         dcterms:creator                MusicGroup:The_Bears ;
#         bibliographica:byArtist        MusicGroup:The_Bears ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/89b93d72-16eb-4a33-b67f-2c9c02fe8b1b"^^xsd:anyURI .
#
# CDs:Saturday_Night_Blackhawk
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Person: Saturday Night at the Blackhawk, San Francisco, Vol 2" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b0083b56-90aa-4da0-bb07-519b7c85332b"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_2
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Bootleg Series, Volume 2" ;
#         dcterms:creator          SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist  SoloMusicArtist:Bob_Dylan .
#
# CDs:Live_75_85  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live 1975-1985" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Springsteen ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Springsteen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/75553328-91a7-492e-a04f-baf72dbc1aaf"^^xsd:anyURI .
#
# CDs:Beaupres_Home  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Beaupré's Home" ;
#         dcterms:creator                MusicGroup:Hart_Rouge ;
#         bibliographica:byArtist        MusicGroup:Hart_Rouge ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6cc4d53-5a8c-4eb4-a49f-2134ab5876f9"^^xsd:anyURI .
#
# CDs:Like_Sonny  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Like Sonny" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/32ad9d9e-7a30-4d59-b54e-da97dad7bb06"^^xsd:anyURI .
#
# CDs:Jack_Kerouac_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Jack Kerouac Collection" ;
#         dcterms:creator                SoloMusicArtist:Jack_Kerouac ;
#         bibliographica:byArtist        SoloMusicArtist:Jack_Kerouac ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f94f0038-f95c-426c-9d16-f051df02e440"^^xsd:anyURI .
#
# CDs:Catch_a_Fire  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Catch a Fire" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/776a48b4-2e3a-440d-9b62-dfac8a3e40a8"^^xsd:anyURI .
#
# CDs:Without_Warning  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Without a Warning" ;
#         dcterms:creator                SoloMusicArtist:Sue_Foley ;
#         bibliographica:byArtist        SoloMusicArtist:Sue_Foley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/954981aa-bdba-4c5a-af64-deeb9707f1cf"^^xsd:anyURI .
#
# CDs:Song_Is_You  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Song Is You" ;
#         dcterms:creator                SoloMusicArtist:Stan_Getz ;
#         bibliographica:byArtist        SoloMusicArtist:Stan_Getz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ef3e3867-213f-49d8-be70-6392ed86d792"^^xsd:anyURI .
#
# CDs:Live_in_Paris  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Paris: Zenith '88" ;
#         dcterms:creator                MusicGroup:Burning_Spear ;
#         bibliographica:byArtist        MusicGroup:Burning_Spear ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5960fe04-1b1c-4fe0-a557-bdd05dc952ae"^^xsd:anyURI .
#
# CDs:Big_Fun  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big Fun" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6549c4e-6b9a-4bfa-8786-15705082a136"^^xsd:anyURI .
#
# CDs:Live_Modern_Lovers  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Modern Lovers Live" ;
#         dcterms:creator                MusicGroup:Modern_Lovers ;
#         bibliographica:byArtist        MusicGroup:Modern_Lovers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aaadd03c-d5df-4155-8d91-18dbf637c0a1"^^xsd:anyURI .
#
# CDs:Nouveau_Flamenco  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nouveau Flamenco" ;
#         dcterms:creator                SoloMusicArtist:Ottmar_Liebert ;
#         bibliographica:byArtist        SoloMusicArtist:Ottmar_Liebert ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/65515613-c20c-462c-a846-a43284d9cc15"^^xsd:anyURI .
#
# CDs:Animals  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Animals" ;
#         dcterms:creator                MusicGroup:Pink_Floyd ;
#         bibliographica:byArtist        MusicGroup:Pink_Floyd ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8ce2b094-cf95-4c99-a5ba-6ac03859f53b"^^xsd:anyURI .
#
# CDs:Freak_Out  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Freak Out" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/10c866e8-cfbf-49bc-8857-27f46c74e422"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_1_3
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bootleg Series, Volumes 1–3: 1961–1991: Rare and Unreleased" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/695c83f9-0919-32b0-af9a-4e58eaf0411e"^^xsd:anyURI .
#
# CDs:Bawdy_Sea_Chanties  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bawdy Sea Chanties" ;
#         dcterms:creator                SoloMusicArtist:Oscar_Brand ;
#         bibliographica:byArtist        SoloMusicArtist:Oscar_Brand ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b1c591ab-1cc6-472f-b7b2-f36be51b182e"^^xsd:anyURI .
#
# CDs:Dreamland  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dreamland" ;
#         dcterms:creator                SoloMusicArtist:Robert_Plant ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Plant ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8664cefa-06ef-4c10-b7c7-8c485c79c241"^^xsd:anyURI .
#
# CDs:Live_Mongoloid_Years
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live: The Mongoloid Years" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3f76215-9179-4206-921a-aea6ffba6643"^^xsd:anyURI .
#
# CDs:At_Folsom_San_Quetin
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At Folsom Prison and San Quentin" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a4fffe0-8a1a-41e9-9021-8eaf609e0221"^^xsd:anyURI .
#
# CDs:Supreme  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Supreme" ;
#         dcterms:creator                SoloMusicArtist:Coleman_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Coleman_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/415ae0d2-3608-43b3-8b70-d0764a177fe9"^^xsd:anyURI .
#
# CDs:Momofuku  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Momofuku" ;
#         dcterms:creator                MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:byArtist        MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e651a61d-d955-49a4-89d1-37b3a81dc82e"^^xsd:anyURI .
#
# CDs:Introducing_Ruben  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Introducing… Rubén González" ;
#         dcterms:creator                SoloMusicArtist:Ruben_Gonzalez ;
#         bibliographica:byArtist        SoloMusicArtist:Ruben_Gonzalez ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/92eff59f-da6e-36b7-b025-6e90e6c0d6f8"^^xsd:anyURI .
#
# CDs:Ladys_Decca_Days  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lady's Decca Days, Volume One" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/561e20b5-6bb1-4bc1-bd13-bad2881a0b01"^^xsd:anyURI .
#
# CDs:Me_Oh_My  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Me Oh My How the Time Does Fly" ;
#         dcterms:creator          SoloMusicArtist:John_Hartford ;
#         bibliographica:byArtist  SoloMusicArtist:John_Hartford ;
#         bibliographica:musicbrainzSoloMusicArtistURI
#                 "https://musicbrainz.org/release/1290ff1d-53f1-4bd9-a4d0-a63d05449ae3"^^xsd:anyURI .
#
# CDs:Ocean_of_Tears  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ocean of Tears" ;
#         dcterms:creator                MusicGroup:The_Paul_deLay_Band ;
#         bibliographica:byArtist        MusicGroup:The_Paul_deLay_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d081f9e8-ddd0-43f3-948f-b75596f8b33b"^^xsd:anyURI .
#
# CDs:Black_Beauty  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Black Beauty" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a46128d0-d0a5-4e27-9eef-2379e136904c"^^xsd:anyURI .
#
# CDs:Three_Years_5_Months
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "3 Years, 5 Months & 2 Days in the Life of…" ;
#         dcterms:creator                MusicGroup:Arrested_Development ;
#         bibliographica:byArtist        MusicGroup:Arrested_Development ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/ede793b4-4976-3b7a-ba3b-fde6801de64c"^^xsd:anyURI .
#
# CDs:Horses_In_Mines  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Horses In The Mines" ;
#         dcterms:creator                MusicGroup:Bad_Livers ;
#         bibliographica:byArtist        MusicGroup:Bad_Livers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/325514f8-6c84-454e-a082-1801e5334730"^^xsd:anyURI .
#
# CDs:Nomads_Indians_Saints
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nomads - Indians - Saints" ;
#         dcterms:creator                MusicGroup:Indigo_Girls ;
#         bibliographica:byArtist        MusicGroup:Indigo_Girls ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0882cb9b-226f-463f-8d26-1f3a62708d27"^^xsd:anyURI .
#
# CDs:Sally_Mack_Originals
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Sally Mack: Originals" ;
#         dcterms:creator          SoloMusicArtist:Sally_Mack ;
#         bibliographica:byArtist  SoloMusicArtist:Sally_Mack .
#
# CDs:Dragonfly  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dragonfly" ;
#         dcterms:creator                MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:byArtist        MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/470a6f6b-d9ef-4d0f-9908-3448b1ae5c3a"^^xsd:anyURI .
#
# CDs:One_Big_Town  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Big Town" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/66cd5917-1fbc-4a72-a4f3-484f4583ab4c"^^xsd:anyURI .
#
# CDs:Keeper_of_Flame  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Keeper of the Flame" ;
#         dcterms:creator                SoloMusicArtist:Luka_Bloom ;
#         bibliographica:byArtist        SoloMusicArtist:Luka_Bloom ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bb8d84f1-f9e5-41cf-a24a-2208927eef47"^^xsd:anyURI .
#
# CDs:Fifty_eight_Sessions
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "'58 Sessions" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a745856f-23b2-3934-a8a9-d706ed69938f"^^xsd:anyURI .
#
# CDs:Criss_Cross  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Criss-Cross" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1c59f8d0-fbe3-4ffc-98e5-e64b69576708"^^xsd:anyURI .
#
# CDs:Trampoline  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Trampoline" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a0250859-9900-4008-b954-edad2585fc58"^^xsd:anyURI .
#
# CDs:Edie_Brickell_mix  a            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Edie Brickell Mix" ;
#         dcterms:creator          SoloMusicArtist:Edie_Brickell ;
#         bibliographica:byArtist  SoloMusicArtist:Edie_Brickell .
#
# CDs:Fairport_Unconventional
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fairport Unconventional" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/512c8445-223f-4124-9c4a-edb346aa05a2"^^xsd:anyURI .
#
# CDs:World_Diary  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "World Diary" ;
#         dcterms:creator                SoloMusicArtist:Tony_Levin ;
#         bibliographica:byArtist        SoloMusicArtist:Tony_Levin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bb4c3b38-0467-483e-bd59-586290858502"^^xsd:anyURI .
#
# CDs:Double_Dose  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Double Dose" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7395bf2-fcc8-4089-9960-c4f02bf2030d"^^xsd:anyURI .
#
# CDs:Corrs_Live_in_Dublin
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "VH1 Presents The Corrs Live in Dublin" ;
#         dcterms:creator                MusicGroup:The_Corrs ;
#         bibliographica:byArtist        MusicGroup:The_Corrs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f9964148-b49a-4567-83e2-8e27d3a069f7"^^xsd:anyURI .
#
# CDs:The_Sermon_Exposition_Blvd
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Sermon on Exposition Boulevard" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d309b897-829c-49b9-9028-43472e605a3a"^^xsd:anyURI .
#
# CDs:Last_Word  a                          schema:MusicAlbum , mo:Record , mo:Release , mo:CD ;
#         rdfs:label                     "The Last Word" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister , SoloMusicArtist:Clive_Gregson ;
#         bibliographica:byArtist        SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/342c2233-f551-49bc-8148-cc0dcce065a7"^^xsd:anyURI .
#
# CDs:Mighty_Joe_Moon  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mighty Joe Moon" ;
#         dcterms:creator                MusicGroup:Grant_Lee_Buffalo ;
#         bibliographica:byArtist        MusicGroup:Grant_Lee_Buffalo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/35adc396-c0f9-4b40-9947-8d493d5b9a6b"^^xsd:anyURI .
#
# CDs:Hanging_Around_Observatory
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hangin’ Around the Observatory" ;
#         dcterms:creator                SoloMusicArtist:John_Hiatt ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hiatt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bfb6fc30-063b-4132-845f-442c57184ec7"^^xsd:anyURI .
#
# CDs:Circles_Stream  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Circles in the Stream" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/c0177a80-ebea-33e5-a68b-4427f315337c"^^xsd:anyURI .
#
# CDs:Good_Dog_Happy_Man  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Good Dog, Happy Man" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/77e5859c-f164-42b6-bb5a-6dd2724003bc"^^xsd:anyURI .
#
# CDs:Live_Hammersmith  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Hammersmith '84" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c944c47b-a036-4910-8364-672f8d9c7d0d"^^xsd:anyURI .
#
# CDs:Super_Session  a                      schema:MusicAlbum , mo:Record , mo:Release , mo:CD ;
#         rdfs:label                     "Super Session" ;
#         dcterms:creator                SoloMusicArtist:Mike_Bloomfield , SoloMusicArtist:Stephen_Stills , SoloMusicArtist:Al_Kooper ;
#         bibliographica:byArtist        SoloMusicArtist:Stephen_Stills , SoloMusicArtist:Al_Kooper , SoloMusicArtist:Mike_Bloomfield ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/26fa86bf-be86-4d45-843d-4f48fc2ecfc9"^^xsd:anyURI .
#
# CDs:Perfect_Alibi  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Perfect Alibi" ;
#         dcterms:creator                SoloMusicArtist:Claire_Martin ;
#         bibliographica:byArtist        SoloMusicArtist:Claire_Martin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/24101b8b-8cc3-4019-b116-b090c58d7f15"^^xsd:anyURI .
#
# CDs:Drum_Call  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Drum Call" ;
#         dcterms:creator          SoloMusicArtist:Nurudafina_Pili_Adena ;
#         bibliographica:byArtist  SoloMusicArtist:Nurudafina_Pili_Adena .
#
# CDs:Hopeville  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hopeville" ;
#         dcterms:creator                MusicGroup:Dead_Ringer_Band ;
#         bibliographica:byArtist        MusicGroup:Dead_Ringer_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ca84647c-508c-46d2-b653-043044c7bdfc"^^xsd:anyURI .
#
# CDs:Wicked_Grin  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wicked Grin" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6e3d3613-086c-4de9-8bc4-e9aa2ad8b73c"^^xsd:anyURI .
#
# CDs:Jazz_Profile  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz Profile" ;
#         dcterms:creator                SoloMusicArtist:Cannonball_Adderley ;
#         bibliographica:byArtist        SoloMusicArtist:Cannonball_Adderley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ad7e5fe8-6182-4574-b10c-ae65877026b1s"^^xsd:anyURI .
#
# CDs:Broken_Moon  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Broken Moon" ;
#         dcterms:creator                MusicGroup:Lowen_Navarro ;
#         bibliographica:byArtist        MusicGroup:Lowen_Navarro ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41d97dba-8bf6-49af-a887-d1db4e5e1093"^^xsd:anyURI .
#
# CDs:Funky_Sitar_Man  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Funky Sitar Man" ;
#         dcterms:creator                MusicGroup:Ravi_Harris_Prophets ;
#         bibliographica:byArtist        MusicGroup:Ravi_Harris_Prophets ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d797a165-8495-46f0-8a89-07df37eb3ed7"^^xsd:anyURI .
#
# CDs:Best_of_Van_Morrison
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Van Morrison" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/df6b2da1-5132-3fff-9441-e388982b5bd9"^^xsd:anyURI .
#
# CDs:The_Healer  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Healer" ;
#         dcterms:creator                SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lee_Hooker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3e196cb-9f35-4cdb-ac3b-ed0905a856d7"^^xsd:anyURI .
#
# CDs:Sketches_for_My_Sweetheart
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sketches for My Sweetheart the Drunk" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0e87c249-2b8a-442e-b044-9d2b4bfb7eb1"^^xsd:anyURI .
#
# CDs:Fire_on_Mountain_Reggae
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fire on the Mountain: Reggae Celebrates the Grateful Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f46a8d48-048c-4baf-902d-79d123cfdbc0"^^xsd:anyURI .
#
# CDs:In_the_Falling_Dark  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Falling Dark" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d24828c6-ac62-33eb-8ac5-284cb38e3b8a"^^xsd:anyURI .
#
# CDs:Fictionary  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fictionary" ;
#         dcterms:creator                SoloMusicArtist:Lyle_Mays ;
#         bibliographica:byArtist        SoloMusicArtist:Lyle_Mays ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91cac4ea-4e6b-469e-a9d4-fc218e29b5eb"^^xsd:anyURI .
#
# CDs:Secret_Handshake  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Secret Handshake" ;
#         dcterms:creator                SoloMusicArtist:Geoff_Muldaur ;
#         bibliographica:byArtist        SoloMusicArtist:Geoff_Muldaur ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd6fdcd2-200a-449e-864c-f807f57b4fb2"^^xsd:anyURI .
#
# CDs:Little_Earthquakes  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Little Earthquakes" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6de2fbe2-e705-3008-8174-5e19ff067ccb"^^xsd:anyURI .
#
# CDs:Amaduduzo_compilation
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Amaduduzo (compilation)" ;
#         dcterms:creator                MusicGroup:Amaduduzo ;
#         bibliographica:byArtist        MusicGroup:Amaduduzo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be3a6956-3b0d-4e98-b8ef-7475970c929e"^^xsd:anyURI .
#
# CDs:Which_Way_to_Here  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Which Way to Here" ;
#         dcterms:creator                SoloMusicArtist:Anders_Osborne ;
#         bibliographica:byArtist        SoloMusicArtist:Anders_Osborne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e3107a4a-d7d7-4a10-9e4d-5e95d795629f"^^xsd:anyURI .
#
# CDs:Friend_of_Mine  a                     schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Friend of Mine" ;
#         dcterms:creator                SoloMusicArtist:Bill_Morrissey , SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Morrissey , SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8070e370-5fe6-48c7-bad5-77c9a013da13"^^xsd:anyURI .
#
# CDs:This_Was  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Was" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1e7d01af-7983-4d80-a4a8-2f83fe43fbd7"^^xsd:anyURI .
#
# CDs:Thelonius_Himself  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thelonious Himself" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ed69ed54-0130-422c-af13-d3edf74344a2"^^xsd:anyURI .
#
# CDs:The_Long_Way_Home  a                  mo:Release , mo:Record , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "The Long Way Home" ;
#         dcterms:creator                SoloMusicArtist:Dama , SoloMusicArtist:DGary ;
#         bibliographica:byArtist        SoloMusicArtist:Dama , SoloMusicArtist:DGary ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c8fafdaa-1843-4076-b1f3-f9a7ef680d64"^^xsd:anyURI .
#
# CDs:Pet_Sounds  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pet Sounds" ;
#         dcterms:creator                MusicGroup:The_Beach_Boys ;
#         bibliographica:byArtist        MusicGroup:The_Beach_Boys ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/865cad65-0ee4-4ba3-89e8-66e23e8e0b53"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_6  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 6: Hartford Civic Center 10/14/83" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c9f5b330-8ceb-4c19-b153-ae43121707fc"^^xsd:anyURI .
#
# CDs:Naked_Songs  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Naked Songs: Live and Acoustic" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ca525c7b-9eee-4724-a962-9a4a6308f8be"^^xsd:anyURI .
#
# CDs:Total_Eclipse  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Total Eclipse" ;
#         dcterms:creator                SoloMusicArtist:Billy_Cobham ;
#         bibliographica:byArtist        SoloMusicArtist:Billy_Cobham ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6c895bc5-7781-3cef-829e-0e1449b9c2f1"^^xsd:anyURI .
#
# CDs:Visit_to_Scandanavia
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Visit to Scandinavia" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ff57f42-bb62-4979-aaf1-9e1a065384b5"^^xsd:anyURI .
#
# CDs:Through_Looking_Glass
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Through the Looking Glass" ;
#         dcterms:creator                SoloMusicArtist:Eliza_Gilkyson ;
#         bibliographica:byArtist        SoloMusicArtist:Eliza_Gilkyson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/00eef7ce-64a2-455e-97c9-3adcfcb73669"^^xsd:anyURI .
#
# CDs:Love_Is_A_Truck  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Love Is A Truck" ;
#         dcterms:creator                SoloMusicArtist:Connie_Kaldor ;
#         bibliographica:byArtist        SoloMusicArtist:Connie_Kaldor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0c307b37-f849-485b-ae2f-c2cbd1591269"^^xsd:anyURI .
#
# CDs:Iowa_Waltz  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Iowa Waltz" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ec55b56-b04f-36f9-92de-013acedf4ab8"^^xsd:anyURI .
#
# CDs:Sings_Songs_Robert_Burns
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sings The Songs Of Robert Burns" ;
#         dcterms:creator                SoloMusicArtist:Eddi_Reader ;
#         bibliographica:byArtist        SoloMusicArtist:Eddi_Reader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/476d4d29-460c-4441-a952-022584d77763"^^xsd:anyURI .
#
# CDs:Over_and_Under  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Over and Under" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9aee2be3-20a5-4df0-9498-7d80d84a6417"^^xsd:anyURI .
#
# CDs:You_Win_Again  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Win Again" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6aaae8ed-d00d-3c90-a3d2-eac36641ad7d"^^xsd:anyURI .
#
# CDs:Dark_Massive_Disengage
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dark Massive Disengage Ambient Compendium" ;
#         dcterms:creator                SoloMusicArtist:Bill_Laswell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Laswell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/26c06ad5-e1c3-44e5-b0e8-ca17c6a25e7c"^^xsd:anyURI .
#
# CDs:Live_From_Around_World
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live From Around the World" ;
#         dcterms:creator                SoloMusicArtist:Kristina_Olsen ;
#         bibliographica:byArtist        SoloMusicArtist:Kristina_Olsen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e3a16d72-d579-46cf-a832-4b2f294962e4"^^xsd:anyURI .
#
# CDs:Way_to_Blue  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Way to Blue: An Introduction to Nick Drake" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ebda8aec-0d87-338e-996a-b42da02f5edf"^^xsd:anyURI .
#
# CDs:Discipline  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Discipline" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e0fdf2b4-f3db-3d5e-8789-1aeba880fc1b"^^xsd:anyURI .
#
# CDs:Found_True_Love  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Found True Love" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d000fd6f-883f-4f99-bbcb-74455446aecd"^^xsd:anyURI .
#
# CDs:Porcelain  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Porcelain" ;
#         dcterms:creator                SoloMusicArtist:Julia_Fordham ;
#         bibliographica:byArtist        SoloMusicArtist:Julia_Fordham ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b9af0f53-e47b-4292-b4fd-6750888b8d3d"^^xsd:anyURI .
#
# CDs:Tales_From_the_Hudson
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tales From the Hudson" ;
#         dcterms:creator                SoloMusicArtist:Michael_Brecker ;
#         bibliographica:byArtist        SoloMusicArtist:Michael_Brecker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7a3d2ee5-e885-458e-88ca-f434c127ca9c"^^xsd:anyURI .
#
# CDs:Imagine  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Imagine" ;
#         dcterms:creator                SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:byArtist        SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/255dc784-0832-4718-99d3-ef4533449c76"^^xsd:anyURI .
#
# CDs:Indigenous  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Indigenous" ;
#         dcterms:creator                MusicGroup:Indigenous ;
#         bibliographica:byArtist        MusicGroup:Indigenous ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c3700e54-0790-41c6-8374-36c7996eed06"^^xsd:anyURI .
#
# CDs:Voodoo_Soup  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Voodoo Soup" ;
#         dcterms:creator                SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:byArtist        SoloMusicArtist:Jimi_Hendrix ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7aef041c-3566-431a-b5df-54bb73d49156"^^xsd:anyURI .
#
# CDs:Cajun_Conja  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cajun Conja" ;
#         dcterms:creator                MusicGroup:BeauSoleil ;
#         bibliographica:byArtist        MusicGroup:BeauSoleil ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b34eef68-3932-4565-ba34-296fffa71caf"^^xsd:anyURI .
#
# CDs:Thirteen_Sept_Sixth  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "13September6" ;
#         dcterms:creator          SoloMusicArtist:Jill_Cohn ;
#         bibliographica:byArtist  SoloMusicArtist:Jill_Cohn .
#
# CDs:Taking_My_Time  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Takin' My Time" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2b0b8715-6052-3384-aa1c-4d81b7e727c4"^^xsd:anyURI .
#
# CDs:Candyfloss_Medicine  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Candyfloss and Medicine" ;
#         dcterms:creator                SoloMusicArtist:Eddi_Reader ;
#         bibliographica:byArtist        SoloMusicArtist:Eddi_Reader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01c3e6a4-8f6f-4c08-8595-3dc467480b31"^^xsd:anyURI .
#
# CDs:Third_Album_Plus_Vampire
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Third Album plus Vampire Can Mating Oven" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9535e03a-51e0-4919-b508-4391c046c538"^^xsd:anyURI .
#
# CDs:Crucify  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crucify" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b134d0f-848d-49f4-b831-030abf0cb487"^^xsd:anyURI .
#
# CDs:XXL_Left_Bank  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "XXL: Live at the Left Bank" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7bb2d6b-29d6-45ee-a29e-fffbe2142423"^^xsd:anyURI .
#
# CDs:Murder_Ballads  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Murder Ballads" ;
#         dcterms:creator                MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:byArtist        MusicGroup:Nick_Cave_Bad_Seeds ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/871130d5-477a-3919-a7e8-ae909f718ee0"^^xsd:anyURI .
#
# CDs:Theres_One_Every_Crowd
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "There’s One in Every Crowd" ;
#         dcterms:creator                SoloMusicArtist:Eric_Clapton ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Clapton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ade49a97-f45b-429e-a37e-4207bf384c80"^^xsd:anyURI .
#
# CDs:Rarities_B_Sides  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rarities, B-Sides, & Other Stuff" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/afe931d6-8641-4538-a097-f229da68001d"^^xsd:anyURI .
#
# CDs:Camper_Van_Beethoven_Is_Dead
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Camper Van Beethoven Is Dead. Long Live Camper Van Beethoven" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6d301dde-12d6-436b-9ebe-b57fc3dd6696"^^xsd:anyURI .
#
# CDs:Cantaloupe_Island  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cantaloupe Island" ;
#         dcterms:creator                SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:byArtist        SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5ec7bbc6-ce49-4ce2-b32b-152f8af58b83"^^xsd:anyURI .
#
# CDs:Ride_This  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ride This" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/495ca722-abdc-47a6-8423-198e9697fe97"^^xsd:anyURI .
#
# CDs:Amchitka  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Amchitka" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1e7ca3cf-099b-4deb-8a8e-871abb680eaa"^^xsd:anyURI .
#
# CDs:Take_It_Home  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Take It Home" ;
#         dcterms:creator                MusicGroup:Hot_Rize ;
#         bibliographica:byArtist        MusicGroup:Hot_Rize ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1f70105a-92ec-467c-81fa-809d4d5ce5ff"^^xsd:anyURI .
#
# CDs:Seastones  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Seastones" ;
#         dcterms:creator                SoloMusicArtist:Ned_Lagin ;
#         bibliographica:byArtist        SoloMusicArtist:Ned_Lagin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f15a07b8-1e8c-4ec2-b934-0cb4f8af4d22"^^xsd:anyURI .
#
# CDs:Buckshot_LeFonque  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buckshot LeFonque" ;
#         dcterms:creator                SoloMusicArtist:Branford_Marsalis ;
#         bibliographica:byArtist        SoloMusicArtist:Branford_Marsalis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/04f9ee33-d824-31fd-857a-e48f92582a76"^^xsd:anyURI .
#
# CDs:Live_at_Chene_Park  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Chene Park" ;
#         dcterms:creator                SoloMusicArtist:Jean_Luc_Ponty ;
#         bibliographica:byArtist        SoloMusicArtist:Jean_Luc_Ponty ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1127cbf5-b763-4623-8fc7-26fa6a4e0a22"^^xsd:anyURI .
#
# CDs:Tails  a                              mo:CD , schema:MusicAlbum , mo:Release , mo:Record ;
#         rdfs:label                     "Tails" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Loeb , MusicGroup:Nine_Stories ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Loeb , MusicGroup:Nine_Stories ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/958dd336-ed7d-4984-b70e-af795ddd4c93"^^xsd:anyURI .
#
# CDs:Live_at_Village_Vanguard_Again
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Village Vanguard Again!" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/15e885fc-a37c-4eef-b4b2-e44500711442"^^xsd:anyURI .
#
# CDs:Divinities  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Divinities: Twelve Dances With God" ;
#         dcterms:creator                SoloMusicArtist:Ian_Anderson ;
#         bibliographica:byArtist        SoloMusicArtist:Ian_Anderson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9c8acdde-5e60-4513-83a2-0bf674bcd819"^^xsd:anyURI .
#
# CDs:Pulse_Where_Rhythm_Begins
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pulse - Where the Rhythm Begins" ;
#         dcterms:creator                SoloMusicArtist:Brent_Lewis ;
#         bibliographica:byArtist        SoloMusicArtist:Brent_Lewis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bff31636-944b-4d39-8bab-5f6e7e5dd3be"^^xsd:anyURI .
#
# CDs:Home_Plate  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Home Plate" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dbbdfc5e-940d-4721-a86f-7179e7c27c46"^^xsd:anyURI .
#
# CDs:Swept  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Swept" ;
#         dcterms:creator                SoloMusicArtist:Julia_Fordham ;
#         bibliographica:byArtist        SoloMusicArtist:Julia_Fordham ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/37720bac-0506-4f95-a4ad-4eb0da624bfb"^^xsd:anyURI .
#
# CDs:Dianne_Reeves_CD  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dianne Reeves" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/27c1cb41-1eff-4417-a75f-21ccc361eec3"^^xsd:anyURI .
#
# CDs:Acoustic_En_Vivo  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Acoustic En Vivo" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fea6c2b9-2e55-44af-92a9-93395e9c5df7"^^xsd:anyURI .
#
# CDs:Corruption  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Corruption" ;
#         dcterms:creator                SoloMusicArtist:Thomas_Mapfumo ;
#         bibliographica:byArtist        SoloMusicArtist:Thomas_Mapfumo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e204785e-d943-4cc6-bfe7-6e4974ac97b7"^^xsd:anyURI .
#
# CDs:Unknown_Territory  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unknown Territory" ;
#         dcterms:creator                SoloMusicArtist:Dick_Dale ;
#         bibliographica:byArtist        SoloMusicArtist:Dick_Dale ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f2674024-e465-459e-97dd-952f5f3bda81"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_1  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 1: Tampa Florida 12/19/73" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6f45d450-599d-478c-8f3a-2198023d86c0"^^xsd:anyURI .
#
# CDs:Pair_Dice_Found  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pair a Dice Found" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2e2a5fd4-4ad0-4fa7-bbc5-a832bb30de55"^^xsd:anyURI .
#
# CDs:Art_of_Rakoto  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Art of Rakoto Frah & Randafison Sylvestre / Madagascar" ;
#         dcterms:creator                SoloMusicArtist:Rakoto_Frah ;
#         bibliographica:byArtist        SoloMusicArtist:Rakoto_Frah ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3a6bff5a-58eb-4a49-b166-b020597ef8c5"^^xsd:anyURI .
#
# CDs:Sonny_Lester_Collection
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Sonny Lester Collection" ;
#         dcterms:creator          SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:byArtist  SoloMusicArtist:Dizzy_Gillespie .
#
# CDs:Standard_Coltrane  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Standard Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b9bfc68-b38c-47c2-8337-51977b224708"^^xsd:anyURI .
#
# CDs:Live_From_Left_Coast
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live! From the Left Coast" ;
#         dcterms:creator                MusicGroup:BeauSoleil ;
#         bibliographica:byArtist        MusicGroup:BeauSoleil ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e848f2d0-2506-4378-8f2f-dbd599cf853f"^^xsd:anyURI .
#
# CDs:Deserters  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Deserters" ;
#         dcterms:creator                MusicGroup:Oysterband ;
#         bibliographica:byArtist        MusicGroup:Oysterband ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c88bc7af-6234-4dd0-a71c-bff78b9b5527"^^xsd:anyURI .
#
# CDs:A_Little_Light_Music
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Little Light Music" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a710d7f-672c-3c87-a409-258477235e72"^^xsd:anyURI .
#
# CDs:The_Road_To_You  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Road To You" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/564c1efa-e119-4137-8327-9dee46cccf48"^^xsd:anyURI .
#
# CDs:Coltranes_Sound  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Coltrane's Sound" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7f8bf39-7b90-427d-bc39-fe8dba26e39d"^^xsd:anyURI .
#
# CDs:Now_It_Can_Be_Told  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Now It Can Be Told: DEVO at the Palace 12/9/88" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/080e64d1-a18c-4904-acb5-9843f1b57090"^^xsd:anyURI .
#
# CDs:Eleven_Tracks_Whack  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "11 Tracks of Whack" ;
#         dcterms:creator                SoloMusicArtist:Walter_Becker ;
#         bibliographica:byArtist        SoloMusicArtist:Walter_Becker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fd9c2a7f-4f53-4600-85d3-d6ddcb1e865c"^^xsd:anyURI .
#
# CDs:Songs_From_a_Room  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Songs From a Room" ;
#         dcterms:creator                SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:byArtist        SoloMusicArtist:Leonard_Cohen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ffce248e-e94e-40c5-b2d8-ad15069bbc52"^^xsd:anyURI .
#
# CDs:Very_Best_Meters  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Very Best of the Meters" ;
#         dcterms:creator                MusicGroup:Meters ;
#         bibliographica:byArtist        MusicGroup:Meters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aef4c964-2602-43ea-b39a-62cb4f91f09c"^^xsd:anyURI .
#
# CDs:Plays_in_Paris  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plays in Paris" ;
#         dcterms:creator                SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:byArtist        SoloMusicArtist:Dizzy_Gillespie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a52de013-9bba-4858-b58f-0178cc026f83"^^xsd:anyURI .
#
# CDs:Let_It_Rain  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Let It Rain" ;
#         dcterms:creator                SoloMusicArtist:Tracy_Chapman ;
#         bibliographica:byArtist        SoloMusicArtist:Tracy_Chapman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa0d9560-3cde-4733-b0e5-5a5bea253027"^^xsd:anyURI .
#
# CDs:American_Legends  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American Legends : Patsy Cline" ;
#         dcterms:creator                SoloMusicArtist:Patsy_Cline ;
#         bibliographica:byArtist        SoloMusicArtist:Patsy_Cline ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/287f3bf5-ae46-4481-8f07-09f86b57274e"^^xsd:anyURI .
#
# CDs:Outlandos_dAmour  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Outlandos D'Amour" ;
#         dcterms:creator                MusicGroup:Police ;
#         bibliographica:byArtist        MusicGroup:Police ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e92ffe25-ca8e-4a53-a68b-fee26f427280"^^xsd:anyURI .
#
# CDs:Uptown_Rulers  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Uptown Rulers!: The Meters Live on the Queen Mary" ;
#         dcterms:creator                MusicGroup:Meters ;
#         bibliographica:byArtist        MusicGroup:Meters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0dfa9708-f10c-4eb1-acfe-b0c2e3292b48"^^xsd:anyURI .
#
# CDs:Promontory_Rider  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Promontory Rider" ;
#         dcterms:creator          SoloMusicArtist:Robert_Hunter ;
#         bibliographica:byArtist  SoloMusicArtist:Robert_Hunter .
#
# CDs:John_Prine_CD  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "John Prine" ;
#         dcterms:creator                SoloMusicArtist:John_Prine ;
#         bibliographica:byArtist        SoloMusicArtist:John_Prine ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8e04e5d7-ed79-3e2e-8558-6df68bab5f6d"^^xsd:anyURI .
#
# CDs:Buena_Vista_Social_Club_IF
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Buena Vista Social Club Presents Ibrahim Ferrer" ;
#         dcterms:creator                SoloMusicArtist:Ibrahim_Ferrer ;
#         bibliographica:byArtist        SoloMusicArtist:Ibrahim_Ferrer ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/231dc0e9-bcfa-449f-b445-ae6835c09b2a"^^xsd:anyURI .
#
# CDs:Regina_Carter_CD  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Regina Carter" ;
#         dcterms:creator                SoloMusicArtist:Regina_Carter ;
#         bibliographica:byArtist        SoloMusicArtist:Regina_Carter ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ddbaf869-bbf3-4efb-bc91-d1cf4eaba1c9"^^xsd:anyURI .
#
# CDs:You_Cant_Do_That_On_Stage_v2
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Can't Do That On Stage Anymore, Vol. 2" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b4a1408f-eb94-41db-a8d1-745da0e41faf"^^xsd:anyURI .
#
# CDs:This_How_It_Feels  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Is How It Feels" ;
#         dcterms:creator                MusicGroup:Golden_Palominos ;
#         bibliographica:byArtist        MusicGroup:Golden_Palominos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4789640c-3da1-4cad-a07e-05dee40ecd30"^^xsd:anyURI .
#
# CDs:Larry_Carlton_CD  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Larry Carlton" ;
#         dcterms:creator                SoloMusicArtist:Larry_Carlton ;
#         bibliographica:byArtist        SoloMusicArtist:Larry_Carlton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d7ef922e-a465-4951-9488-ef2624c02bee"^^xsd:anyURI .
#
# CDs:Charles_Mingus_Presents
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Charles Mingus Presents Charles Mingus" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dcb1f17e-558f-3bdf-b7ce-7a01903d636f"^^xsd:anyURI .
#
# CDs:Bouncing_Off_Satellites
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bouncing Off The Satellites" ;
#         dcterms:creator                MusicGroup:B_Fifty_Twos ;
#         bibliographica:byArtist        MusicGroup:B_Fifty_Twos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8a01d8cb-52dd-464f-9f3f-82feed851ee2"^^xsd:anyURI .
#
# CDs:Wrecking_Ball  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wrecking Ball" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5356227c-f489-4dd8-aeee-621866b1882c"^^xsd:anyURI .
#
# CDs:Speechless  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Speechless" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/6d83ea55-2b3a-3aaf-a9f8-e84d21fc04ef"^^xsd:anyURI .
#
# CDs:Big_Calm  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Big Calm" ;
#         dcterms:creator                MusicGroup:Morcheeba ;
#         bibliographica:byArtist        MusicGroup:Morcheeba ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0c0f9ff9-0b07-4d12-8978-6522601eca9d"^^xsd:anyURI .
#
# CDs:Watermark  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Watermark" ;
#         dcterms:creator                SoloMusicArtist:Enya ;
#         bibliographica:byArtist        SoloMusicArtist:Enya ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c57034fa-c08b-4aaa-bcaa-b207ba760de9"^^xsd:anyURI .
#
# CDs:Transit  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Transit" ;
#         dcterms:creator                SoloMusicArtist:Russel_Walder , SoloMusicArtist:Ira_Stein ;
#         bibliographica:byArtist        SoloMusicArtist:Ira_Stein , SoloMusicArtist:Russel_Walder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/763c51a6-56bb-4015-9697-b632ed64b18e"^^xsd:anyURI .
#
# CDs:Spike  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spike" ;
#         dcterms:creator                SoloMusicArtist:Elvis_Costello ;
#         bibliographica:byArtist        SoloMusicArtist:Elvis_Costello ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dcdd5fd1-788d-45da-8990-82c6ecd5dc76"^^xsd:anyURI .
#
# CDs:Live_at_Newport  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Newport 1958" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/29667c9a-0395-420c-9bbc-1dbebf9af189"^^xsd:anyURI .
#
# CDs:Welcome_To_My_World  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Welcome to My World" ;
#         dcterms:creator          SoloMusicArtist:Mykel_Perkins ;
#         bibliographica:byArtist  SoloMusicArtist:Mykel_Perkins .
#
# CDs:Live_at_Paradiso  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at Paradiso" ;
#         dcterms:creator                SoloMusicArtist:Beth_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Beth_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0dd495ee-57c6-4b2f-871b-b91891512a9b"^^xsd:anyURI .
#
# CDs:So     a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "So" ;
#         dcterms:creator                SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:byArtist        SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e0778052-5b59-39f2-a0b0-48515b64a94d"^^xsd:anyURI .
#
# CDs:Full_House  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Full House" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/168e1820-028a-3237-b6f7-5e4413e2336f"^^xsd:anyURI .
#
# CDs:Wired  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wired" ;
#         dcterms:creator                SoloMusicArtist:Jeff_Beck ;
#         bibliographica:byArtist        SoloMusicArtist:Jeff_Beck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1755f2a8-1581-43c8-a3f1-646302c0bb59"^^xsd:anyURI .
#
# CDs:Cruel_Smile  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cruel Smile" ;
#         dcterms:creator                MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:byArtist        MusicGroup:Elvis_Costello_Imposters ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/02bc211c-8600-42ba-9879-712b6e923430"^^xsd:anyURI .
#
# CDs:Patrick_Street_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Patrick Street" ;
#         dcterms:creator                MusicGroup:Patrick_Street ;
#         bibliographica:byArtist        MusicGroup:Patrick_Street ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/510a7d28-bd98-45ab-a16f-8bb06b7517c6"^^xsd:anyURI .
#
# CDs:Rolling_Turtle  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Rolling Turtle and the End of the Beginning" ;
#         dcterms:creator          MusicGroup:Old_School_String_Band ;
#         bibliographica:byArtist  MusicGroup:Old_School_String_Band .
#
# CDs:Nights_at_Keystone_v1
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nights at the Keystone, Volume 1" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d52baec0-62bd-48f7-a583-7c5e9b2f5d51"^^xsd:anyURI .
#
# CDs:Its_My_Sin  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "It's My Sin" ;
#         dcterms:creator                SoloMusicArtist:Jan_Hellriegel ;
#         bibliographica:byArtist        SoloMusicArtist:Jan_Hellriegel ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/740888a7-7ba1-4d75-a08c-6f73b9fda605"^^xsd:anyURI .
#
# CDs:Journey_to_Love  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Journey to Love" ;
#         dcterms:creator                SoloMusicArtist:Stanley_Clarke ;
#         bibliographica:byArtist        SoloMusicArtist:Stanley_Clarke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b9622cc5-242d-39bc-a499-3f91ccce5eb5"^^xsd:anyURI .
#
# CDs:Sand_Water  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sand and Water" ;
#         dcterms:creator                SoloMusicArtist:Beth_Nielsen_Chapman ;
#         bibliographica:byArtist        SoloMusicArtist:Beth_Nielsen_Chapman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b44ebc7f-0564-3c9e-b2f5-47f9abc78e7a"^^xsd:anyURI .
#
# CDs:White_Lilies_Island  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "White Lilies Island" ;
#         dcterms:creator                SoloMusicArtist:Natalie_Imbruglia ;
#         bibliographica:byArtist        SoloMusicArtist:Natalie_Imbruglia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4ae2f4b3-b35d-3210-b955-b3ebecd2829d"^^xsd:anyURI .
#
# CDs:Whats_Following_Me  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What’s Following Me?" ;
#         dcterms:creator                SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:byArtist        SoloMusicArtist:Eleanor_McEvoy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc2bbb3b-394c-4e0e-bf73-8a5a6ad217c2"^^xsd:anyURI .
#
# CDs:Cropredy_Box  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Cropredy Box" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ce4a696a-0016-46a8-b9c3-368aa5057f86"^^xsd:anyURI .
#
# CDs:Absolute_Torch_Twang
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Absolute Torch And Twang" ;
#         dcterms:creator                SoloMusicArtist:KD_Lang ;
#         bibliographica:byArtist        SoloMusicArtist:KD_Lang ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b0522f34-7d72-45bb-bd64-58c1c0a6163e"^^xsd:anyURI .
#
# CDs:Loading_Zone  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Loading Zone" ;
#         dcterms:creator                SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:byArtist        SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6d2fc2f7-ddbb-450b-9d8e-5c6df74ad27e"^^xsd:anyURI .
#
# CDs:Seven_Waves  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Seven Waves" ;
#         dcterms:creator                SoloMusicArtist:Suzanne_Ciani ;
#         bibliographica:byArtist        SoloMusicArtist:Suzanne_Ciani ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fb560d3f-495e-45c8-a97f-5b7e339aebd1"^^xsd:anyURI .
#
# CDs:Mingus_in_Wonderland
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus in Wonderland" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e891955d-36d7-3395-966b-432326833616"^^xsd:anyURI .
#
# CDs:Greatest_Hits_Live  a           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Greatest Hits Live 1972-1993" ;
#         dcterms:creator          SoloMusicArtist:George_Clinton ;
#         bibliographica:byArtist  SoloMusicArtist:George_Clinton .
#
# CDs:Cornflake_Girl  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cornflake Girl" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3e0102f2-cf6f-4646-8b0d-cd16e7dbdde7"^^xsd:anyURI .
#
# CDs:Eva_By_Heart  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eva By Heart" ;
#         dcterms:creator                SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:byArtist        SoloMusicArtist:Eva_Cassidy ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e8e9c42a-7f80-4f7f-b388-9e9bbe35d8ac"^^xsd:anyURI .
#
# CDs:Songs_of_our_Fathers
#         a                              mo:Record , mo:CD , schema:MusicAlbum , mo:Release ;
#         rdfs:label                     "Songs of our Fathers" ;
#         dcterms:creator                SoloMusicArtist:Andy_Statman , SoloMusicArtist:David_Grisman ;
#         bibliographica:byArtist        SoloMusicArtist:Andy_Statman , SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/839e4f2e-a089-4dc4-9375-36c2b8ffd249"^^xsd:anyURI .
#
# CDs:Into_Purple_Valley  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Into The Purple Valley" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/33fe641f-2459-3049-8edd-ad0167e6f59b"^^xsd:anyURI .
#
# CDs:Plays_Live  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Plays Live" ;
#         dcterms:creator                SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:byArtist        SoloMusicArtist:Peter_Gabriel ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9d897884-ac56-4edf-97e7-8ee450cd57c3"^^xsd:anyURI .
#
# CDs:Essential_the_Very_Best_Of
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Essential, the Very Best Of" ;
#         dcterms:creator                SoloMusicArtist:Airto_Moreira ;
#         bibliographica:byArtist        SoloMusicArtist:Airto_Moreira ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7903ef07-4f6a-4450-b573-38b2af7328da"^^xsd:anyURI .
#
# CDs:Universal_Language  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Universal Language" ;
#         dcterms:creator                SoloMusicArtist:Kevyn_Lettau ;
#         bibliographica:byArtist        SoloMusicArtist:Kevyn_Lettau ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e4bad0d1-ff07-4b68-a256-965006f3e9a0"^^xsd:anyURI .
#
# CDs:Wave_of_Hand  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wave of the Hand: The Best of Carla Olson" ;
#         dcterms:creator                SoloMusicArtist:Carla_Olson ;
#         bibliographica:byArtist        SoloMusicArtist:Carla_Olson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/387ecedb-f133-46f7-9298-773905601a03"^^xsd:anyURI .
#
# CDs:Girl_From_Impanema  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Girl from Ipanema: The Bossa Nova Years" ;
#         dcterms:creator                SoloMusicArtist:Stan_Getz ;
#         bibliographica:byArtist        SoloMusicArtist:Stan_Getz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9b9cbb73-0d08-4c1b-9595-708b178c0be4"^^xsd:anyURI .
#
# CDs:Colores_del_Alma_CD  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Colores del Alma" ;
#         dcterms:creator          MusicGroup:Colores_del_Alma ;
#         bibliographica:byArtist  MusicGroup:Colores_del_Alma .
#
# CDs:Oh_Moscow  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Oh Moscow" ;
#         dcterms:creator                SoloMusicArtist:Lindsay_Cooper ;
#         bibliographica:byArtist        SoloMusicArtist:Lindsay_Cooper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e4f20302-1951-42ab-bacd-fd3b6f4cc6f1"^^xsd:anyURI .
#
# CDs:This_World_Not_My_Home
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This World Is Not My Home" ;
#         dcterms:creator                MusicGroup:Lone_Justice ;
#         bibliographica:byArtist        MusicGroup:Lone_Justice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/afc22dc0-2f18-4199-b834-2af6095466e6"^^xsd:anyURI .
#
# CDs:Cookin_with_Miles_Davis
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cookin' with the Miles Davis Quintet" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/82633f2f-cba1-40e8-b5e9-a3bfde53922e"^^xsd:anyURI .
#
# CDs:Further_In  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Further In" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c675171a-4c25-43be-b99d-98cc620dfa44"^^xsd:anyURI .
#
# CDs:Kingfish_II  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Kingfish II" ;
#         dcterms:creator                MusicGroup:Kingfish ;
#         bibliographica:byArtist        MusicGroup:Kingfish ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b895db7-1459-41da-939b-072d8bb36843"^^xsd:anyURI .
#
# CDs:One_Fair_Summer  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Fair Summer Evening" ;
#         dcterms:creator                SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:byArtist        SoloMusicArtist:Nanci_Griffith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc0add73-4dff-470a-8fc3-c4bffbc1fa38"^^xsd:anyURI .
#
# CDs:Quintessential_Billie_Holiday_v5
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Quintessential Billie Holiday, Vol. 5" ;
#         dcterms:creator                SoloMusicArtist:Billie_Holiday ;
#         bibliographica:byArtist        SoloMusicArtist:Billie_Holiday ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38932f89-2cf0-4af6-ac14-d0fd2e66189f"^^xsd:anyURI .
#
# CDs:Will_to_Live_EP  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Will to Live : The Live EP" ;
#         dcterms:creator                SoloMusicArtist:Ben_Harper ;
#         bibliographica:byArtist        SoloMusicArtist:Ben_Harper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7ef39e4b-9e2e-405f-89bf-bbd1fee91164"^^xsd:anyURI .
#
# CDs:Check_It_Out  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Check It Out, Lock It In, Crank It Up!" ;
#         dcterms:creator                MusicGroup:BeauJocque_ZydecoHiRollers ;
#         bibliographica:byArtist        MusicGroup:BeauJocque_ZydecoHiRollers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/007195e3-cc99-4408-a81b-82f4577f85ce"^^xsd:anyURI .
#
# CDs:American_Recordings  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "American Recordings" ;
#         dcterms:creator                SoloMusicArtist:Johnny_Cash ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_Cash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5223c055-c717-35c8-9571-4353d147e9d7"^^xsd:anyURI .
#
# CDs:Conscious_Party  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Conscious Party" ;
#         dcterms:creator                MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:byArtist        MusicGroup:Ziggy_Marley_Melody_Makers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0cdfe20c-8502-4590-86ce-174ad8ee1fdd"^^xsd:anyURI .
#
# CDs:By_The_Hand_Of_The_Father
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "By The Hand Of The Father" ;
#         dcterms:creator                SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:byArtist        SoloMusicArtist:Alejandro_Escovedo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0e7e13a7-0aa9-4d45-9213-2c86581d0ae7"^^xsd:anyURI .
#
# CDs:An_Evening_Acoustic_Music
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "An Evening of Acoustic Music" ;
#         dcterms:creator                SoloMusicArtist:Taj_Mahal ;
#         bibliographica:byArtist        SoloMusicArtist:Taj_Mahal ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/de99cef2-157c-4919-8ebf-123922fd9272"^^xsd:anyURI .
#
# CDs:Standing_In_Shoes  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Standing in My Shoes" ;
#         dcterms:creator                SoloMusicArtist:Leo_Kottke ;
#         bibliographica:byArtist        SoloMusicArtist:Leo_Kottke ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f81b3472-1c96-4b0d-a5dd-7bcf5723cb64"^^xsd:anyURI .
#
# CDs:Dozin_at_Knick  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dozin' at the Knick" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/72ed7718-2e82-402e-8543-2d2d586a2c12"^^xsd:anyURI .
#
# CDs:Burnin  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Burnin'" ;
#         dcterms:creator                MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:byArtist        MusicGroup:Bob_Marley_Wailers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d31904ea-2257-41e9-b5f0-4ff970a5bce8"^^xsd:anyURI .
#
# CDs:Catch_Bull_Four  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Catch Bull at Four" ;
#         dcterms:creator                SoloMusicArtist:Cat_Stevens ;
#         bibliographica:byArtist        SoloMusicArtist:Cat_Stevens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/91c192d5-f097-3036-9aec-bc3ac148efd3"^^xsd:anyURI .
#
# CDs:Jazz_Profile_CB  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazz Profile" ;
#         dcterms:creator                SoloMusicArtist:Chet_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Chet_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b12de027-ba2a-4b5c-a7a6-d4b9f3bb5eef"^^xsd:anyURI .
#
# CDs:Songs_From_Wood  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Songs From The Wood" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fc6570d5-e24f-4348-a512-8165cf0d3515"^^xsd:anyURI .
#
# CDs:Turtles_Navel  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Search of the Turtle's Navel" ;
#         dcterms:creator                SoloMusicArtist:William_Ackerman ;
#         bibliographica:byArtist        SoloMusicArtist:William_Ackerman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0ce56c40-6f9a-4a86-9fed-b156dcbcb4ca"^^xsd:anyURI .
#
# CDs:The_Last_Waltz  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Last Waltz" ;
#         dcterms:creator                MusicGroup:The_Band ;
#         bibliographica:byArtist        MusicGroup:The_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fa9d2c01-1ecb-4c94-ac3f-3b57d9a2081e"^^xsd:anyURI .
#
# CDs:Great_Red_Rocks  a              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Great Red Rocks" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Slide_Area  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Slide Area" ;
#         dcterms:creator                SoloMusicArtist:Ry_Cooder ;
#         bibliographica:byArtist        SoloMusicArtist:Ry_Cooder ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/38b8bb57-0e69-3531-9fad-1ab2dd983b0f"^^xsd:anyURI .
#
# CDs:Dig    a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dig (Featuring Sonny Rollins)" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/89386d3e-6494-4947-bf99-6039d6bb5850"^^xsd:anyURI .
#
# CDs:Eugene_JID  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Live in Eugene" ;
#         dcterms:creator          MusicGroup:Jazz_Is_Dead ;
#         bibliographica:byArtist  MusicGroup:Jazz_Is_Dead .
#
# CDs:Big_Squeeze  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Big Squeeze" ;
#         dcterms:creator                SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:byArtist        SoloMusicArtist:Clifton_Chenier ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d2b16d45-69ea-463b-847b-2e18dd48bfab"^^xsd:anyURI .
#
# CDs:Live_Black_Sheep  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Black Sheep" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6914db2d-8add-4fa3-9fca-d8520e4a4b5d"^^xsd:anyURI .
#
# CDs:Real_Live  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Real Live" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/c071ff9b-51f6-3999-aaba-594002dc6022"^^xsd:anyURI .
#
# CDs:The_Ride  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Ride" ;
#         dcterms:creator                MusicGroup:Los_Lobos ;
#         bibliographica:byArtist        MusicGroup:Los_Lobos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b7c010d8-4f32-492d-a7a6-cc83ff9b34ac"^^xsd:anyURI .
#
# CDs:Motherland  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Motherland" ;
#         dcterms:creator                SoloMusicArtist:Natalie_Merchant ;
#         bibliographica:byArtist        SoloMusicArtist:Natalie_Merchant ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2b04d52e-4560-40d6-820b-db47cdffea72"^^xsd:anyURI .
#
# CDs:You_Are_What_You_Is  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You Are What You Is" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6915f5d4-f5c2-49dc-bb41-61f0e2ff70be"^^xsd:anyURI .
#
# CDs:The_Believer  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Believer" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3aaa100a-8ced-4454-8a3e-6aab7e185ff4"^^xsd:anyURI .
#
# CDs:The_Classic_Years  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Classic Years" ;
#         dcterms:creator                SoloMusicArtist:Nico ;
#         bibliographica:byArtist        SoloMusicArtist:Nico ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8d41f27e-b1c7-4b04-a118-0863628d812a"^^xsd:anyURI .
#
# CDs:Standards_Monk  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Standards" ;
#         dcterms:creator                SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:byArtist        SoloMusicArtist:Thelonious_Monk ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/316e1316-6437-4810-a32a-c0d506ce01d6"^^xsd:anyURI .
#
# CDs:Life_Short_Call_Now  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Life Short Call Now" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/8e1b0c51-eafb-38dd-b6cc-c4903f554d1a"^^xsd:anyURI .
#
# CDs:Their_Greatest_Hits  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Their Greatest Hits 1971–1975" ;
#         dcterms:creator                MusicGroup:Eagles ;
#         bibliographica:byArtist        MusicGroup:Eagles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bfea3a29-e5bd-36c4-9feb-f13dd6cbbb69"^^xsd:anyURI .
#
# CDs:Chooglin  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chooglin'" ;
#         dcterms:creator                MusicGroup:Creedence_Clearwater_Revival ;
#         bibliographica:byArtist        MusicGroup:Creedence_Clearwater_Revival ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bdfa0b7c-10eb-46f2-b5e1-d82bf00c9606"^^xsd:anyURI .
#
# CDs:Dub_Side_Moon  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dub Side of the Moon" ;
#         dcterms:creator                MusicGroup:Easy_Star_All_Stars ;
#         bibliographica:byArtist        MusicGroup:Easy_Star_All_Stars ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5c285b48-a2ee-4328-9398-d7b971272c05"^^xsd:anyURI .
#
# CDs:Whats_Wrong_Picture  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What's Wrong With This Picture" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d7aa46d5-d936-47b4-8f21-a336bb558f61"^^xsd:anyURI .
#
# CDs:Laughing_Hands_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Laughing Hands" ;
#         dcterms:creator                MusicGroup:Laughing_Hands ;
#         bibliographica:byArtist        MusicGroup:Laughing_Hands ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc082c8f-d010-4a04-af3a-a59f776c5862"^^xsd:anyURI .
#
# CDs:When_There_is_Love  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "When There is Love" ;
#         dcterms:creator                SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:byArtist        SoloMusicArtist:Hank_Jones , SoloMusicArtist:Abbey_Lincoln ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d20eecae-2fd1-45e9-895b-8a8089a02461"^^xsd:anyURI .
#
# CDs:Unfinished_Business  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Unfinished Business: Dave Davies Kronikles, 1963|1998" ;
#         dcterms:creator                SoloMusicArtist:Dave_Davies ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Davies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3284e038-a18a-46e0-a311-7dc0c9d714f1"^^xsd:anyURI .
#
# CDs:Shona_Laing_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shona Laing" ;
#         dcterms:creator                SoloMusicArtist:Shona_Laing ;
#         bibliographica:byArtist        SoloMusicArtist:Shona_Laing ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2bf7c414-b90a-4190-863b-07d746a98107"^^xsd:anyURI .
#
# CDs:Just_Us_Kids  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Just Us Kids" ;
#         dcterms:creator                SoloMusicArtist:James_McMurtry ;
#         bibliographica:byArtist        SoloMusicArtist:James_McMurtry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e2972a28-0991-4e6c-98a0-39b5b8556285"^^xsd:anyURI .
#
# CDs:Art_Survival  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Art And Survival" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1541c381-0780-4a7c-97f2-0d520c74a20e"^^xsd:anyURI .
#
# CDs:Versions  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Versions" ;
#         dcterms:creator                SoloMusicArtist:Robbie_Krieger ;
#         bibliographica:byArtist        SoloMusicArtist:Robbie_Krieger ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c976404a-22ab-4ba7-920d-2509573df51b"^^xsd:anyURI .
#
# CDs:Camper_Vantiquities  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Camper Vantiquities" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/76c70a24-7fb9-4714-a34c-8b1a7d0d98d2"^^xsd:anyURI .
#
# CDs:Sense_of_Wonder  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Sense of Wonder" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dc4789a2-96ba-3d1e-a302-b2b97bdf41f1"^^xsd:anyURI .
#
# CDs:Either_Or  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Either/Or" ;
#         dcterms:creator                SoloMusicArtist:Elliott_Smith ;
#         bibliographica:byArtist        SoloMusicArtist:Elliott_Smith ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0a5aa565-8158-4e81-9776-af8044f6cc1e"^^xsd:anyURI .
#
# CDs:The_Healing_Game  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Healing Game" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1087a6fc-ed3b-4713-8270-a94cf34760b9"^^xsd:anyURI .
#
# CDs:Naked_and_True  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Naked and True" ;
#         dcterms:creator                SoloMusicArtist:Randy_Crawford ;
#         bibliographica:byArtist        SoloMusicArtist:Randy_Crawford ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b08c15ec-f1bd-4d4c-ad6b-48e554f492ae"^^xsd:anyURI .
#
# CDs:Get_Inside  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Get Inside" ;
#         dcterms:creator                SoloMusicArtist:Johnny_A ;
#         bibliographica:byArtist        SoloMusicArtist:Johnny_A ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/384d9a6f-a980-3106-a43c-da280bb177cf"^^xsd:anyURI .
#
# CDs:Spirit_in_the_Sky  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spirit in the Sky" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b4a7956c-71dd-4b5e-a710-91a7b18953d3"^^xsd:anyURI .
#
# CDs:Pristine_Smut  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pristine Smut" ;
#         dcterms:creator                MusicGroup:Murmurs ;
#         bibliographica:byArtist        MusicGroup:Murmurs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/86095749-a188-47b9-bbdd-bb1ad5c24ded"^^xsd:anyURI .
#
# CDs:Pirates  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pirates" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/954dcb1f-c559-428f-aad8-923b5fe78169"^^xsd:anyURI .
#
# CDs:Mustt_Mustt  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mustt Mustt" ;
#         dcterms:creator                SoloMusicArtist:Nusrat_Fateh_Ali_Khan ;
#         bibliographica:byArtist        SoloMusicArtist:Nusrat_Fateh_Ali_Khan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f215e4c5-bd6e-3fd2-8acf-10e5c2e16dca"^^xsd:anyURI .
#
# CDs:Octoroon  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Octoroon" ;
#         dcterms:creator                SoloMusicArtist:Laura_Love ;
#         bibliographica:byArtist        SoloMusicArtist:Laura_Love ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f575c47-264c-4921-abb2-49ba56a785e1"^^xsd:anyURI .
#
# CDs:Best_Kept_Secret  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Best Kept Secret" ;
#         dcterms:creator                SoloMusicArtist:Lady_Bianca ;
#         bibliographica:byArtist        SoloMusicArtist:Lady_Bianca ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5adb955f-e0af-4e85-9abd-d39fe69fc0e0"^^xsd:anyURI .
#
# CDs:El_Rayo_X_Live  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "El Rayo-X Live!!" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aef90364-a168-40b7-a0a1-c64269a75d56"^^xsd:anyURI .
#
# CDs:Portland_Youth_Orchestra
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Portland Youth Philharmonic" ;
#         dcterms:creator          MusicGroup:Oregon_Composers ;
#         bibliographica:byArtist  MusicGroup:Oregon_Composers .
#
# CDs:Neath_Your_Covers  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Neath Your Covers, Part 1" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e182adf6-e2a8-444f-9b1f-43bec130ba82"^^xsd:anyURI .
#
# CDs:Scatterlings  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Scatterlings" ;
#         dcterms:creator                MusicGroup:Juluka ;
#         bibliographica:byArtist        MusicGroup:Juluka ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2d8ea5ef-1247-4e71-9bd9-77c9a391054a"^^xsd:anyURI .
#
# CDs:Excerpts_Love_Circus
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Excerpts From A Love Circus" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Germano ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Germano ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d93bd03b-116f-4c26-9f4e-188c68df9a1b"^^xsd:anyURI .
#
# CDs:Love_Call  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Love Call" ;
#         dcterms:creator                SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:byArtist        SoloMusicArtist:Ornette_Coleman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d39df5bc-1321-4a27-b86b-5055ba0478ac"^^xsd:anyURI .
#
# CDs:Dafos  a                              schema:MusicAlbum , mo:Record , mo:CD , mo:Release ;
#         rdfs:label                     "Däfos" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart , SoloMusicArtist:Airto_Moreira , SoloMusicArtist:Flora_Purim ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart , SoloMusicArtist:Airto_Moreira , SoloMusicArtist:Flora_Purim ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a8145191-ef19-49e8-af44-a586e9d1f142"^^xsd:anyURI .
#
# CDs:Time_Passes_By  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Time Passes By" ;
#         dcterms:creator                SoloMusicArtist:Kathy_Mattea ;
#         bibliographica:byArtist        SoloMusicArtist:Kathy_Mattea ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0ac5302c-f924-4696-8d55-c50c20144b67"^^xsd:anyURI .
#
# CDs:Eat_a_Peach  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eat a Peach" ;
#         dcterms:creator                MusicGroup:Allman_Brothers ;
#         bibliographica:byArtist        MusicGroup:Allman_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/0b1189ad-0bdf-34bc-89e4-ff05133ec51b"^^xsd:anyURI .
#
# CDs:Diamonds_and_Rust  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Diamonds & Rust" ;
#         dcterms:creator                SoloMusicArtist:Joan_Baez ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Baez ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3a9a3cd7-0274-4025-b467-44cbd174f1ba"^^xsd:anyURI .
#
# CDs:John_Hammond_Live  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "John Hammond Live" ;
#         dcterms:creator                SoloMusicArtist:John_Hammond ;
#         bibliographica:byArtist        SoloMusicArtist:John_Hammond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e046559f-b69e-42d3-af37-424d9be394f3"^^xsd:anyURI .
#
# CDs:Lucidity  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lucidity" ;
#         dcterms:creator                SoloMusicArtist:Beth_Quist ;
#         bibliographica:byArtist        SoloMusicArtist:Beth_Quist ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/344c8b8f-b04f-4927-a27a-708f601d2638"^^xsd:anyURI .
#
# CDs:Yellow_Dog  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yellow Dog" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5e349f2a-65f1-4f87-9327-ddfbbc1ef024"^^xsd:anyURI .
#
# CDs:Stormy_Weather  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Stormy Weather In San Anselmo" ;
#         dcterms:creator          SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist  SoloMusicArtist:Van_Morrison .
#
# CDs:Rainbow_Concert  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Eric Clapton's Rainbow Concert" ;
#         dcterms:creator                SoloMusicArtist:Eric_Clapton ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Clapton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b802a64e-c8a3-4a72-9b1e-f37c3b134c2f"^^xsd:anyURI .
#
# CDs:Poi_Dog_Pondering_CD
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Poi Dog Pondering" ;
#         dcterms:creator                MusicGroup:Poi_Dog_Pondering ;
#         bibliographica:byArtist        MusicGroup:Poi_Dog_Pondering ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d3ce480c-fab9-4e1e-b741-13aceabc74f1"^^xsd:anyURI .
#
# CDs:Hey_Jupiter  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hey Jupiter" ;
#         dcterms:creator                SoloMusicArtist:Tori_Amos ;
#         bibliographica:byArtist        SoloMusicArtist:Tori_Amos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5a63b51-69d4-48c3-9943-255834664748"^^xsd:anyURI .
#
# CDs:Brothers_And_Sisters
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Brothers And Sisters" ;
#         dcterms:creator                MusicGroup:Allman_Brothers ;
#         bibliographica:byArtist        MusicGroup:Allman_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d4766e51-f342-33c6-924c-f33f6180775f"^^xsd:anyURI .
#
# CDs:Let_It_Be  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Let It Be" ;
#         dcterms:creator                MusicGroup:Beatles ;
#         bibliographica:byArtist        MusicGroup:Beatles ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/79c313a5-0e50-4572-8aa6-fd0d297abd97"^^xsd:anyURI .
#
# CDs:Concrete_Blonde_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Concrete Blonde" ;
#         dcterms:creator                MusicGroup:Concrete_Blonde ;
#         bibliographica:byArtist        MusicGroup:Concrete_Blonde ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/14f09b2b-60a5-4f6b-8e53-f388c81eeb06"^^xsd:anyURI .
#
# CDs:Into_the_Light  a               schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Into the Light" ;
#         dcterms:creator          SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist  SoloMusicArtist:Christine_Collister .
#
# CDs:Grand_Piano_Canyon  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Grand Piano Canyon" ;
#         dcterms:creator                SoloMusicArtist:Bob_James ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_James ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0fa56e29-96cd-4800-8b98-26d6687788c0"^^xsd:anyURI .
#
# CDs:Dana_Owens_Album  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Dana Owens Album" ;
#         dcterms:creator                SoloMusicArtist:Queen_Latifah ;
#         bibliographica:byArtist        SoloMusicArtist:Queen_Latifah ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/157cd7ee-ec0f-4ed1-8b85-4510c5c68abd"^^xsd:anyURI .
#
# CDs:Dont_Let_Go  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Don't Let Go" ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/99c2c64b-a0eb-4696-b344-be22e6f0666c"^^xsd:anyURI .
#
# CDs:One_Flight_Up  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Flight Up" ;
#         dcterms:creator                SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:byArtist        SoloMusicArtist:Dexter_Gordon ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1dd4d180-7dc4-4d78-b098-2561a06adc14"^^xsd:anyURI .
#
# CDs:Tongue_Tails  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tongues and Tails" ;
#         dcterms:creator                SoloMusicArtist:Sophie_B_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Sophie_B_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b6ffacd-0db8-33cb-952b-7a8f3fd9b8a9"^^xsd:anyURI .
#
# CDs:Access_All_Areas  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Access To All Areas" ;
#         dcterms:creator          MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist  MusicGroup:Grateful_Dead .
#
# CDs:Happy_Hour  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Happy Hour" ;
#         dcterms:creator                MusicGroup:King_Missile ;
#         bibliographica:byArtist        MusicGroup:King_Missile ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8c45c5da-aaef-4c05-89c5-b54822f219b8"^^xsd:anyURI .
#
# CDs:Dilate  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dilate" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b835bf06-e50b-397c-9f28-e7211a2f014d"^^xsd:anyURI .
#
# CDs:Chill_Out  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Chill Out" ;
#         dcterms:creator                MusicGroup:Black_Uhuru ;
#         bibliographica:byArtist        MusicGroup:Black_Uhuru ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2fac5b16-6da2-3dae-bdb5-9d3b7db2919b"^^xsd:anyURI .
#
# CDs:No_Boundaries  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "No Boundaries" ;
#         dcterms:creator                SoloMusicArtist:Natalie_MacMaster ;
#         bibliographica:byArtist        SoloMusicArtist:Natalie_MacMaster ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2f5918e8-e367-4d9c-ad9f-b47df913619e"^^xsd:anyURI .
#
# CDs:Voodoo_Jive  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Voodoo Jive: The Best of Screamin' Jay Hawkins" ;
#         dcterms:creator                SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:byArtist        SoloMusicArtist:Screamin_Jay_Hawkins ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fb761a5f-1639-4cc2-882c-05008b562d2d"^^xsd:anyURI .
#
# CDs:Rich_and_Poor  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Rich and Poor" ;
#         dcterms:creator                SoloMusicArtist:Randy_Crawford ;
#         bibliographica:byArtist        SoloMusicArtist:Randy_Crawford ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b6c4e193-bddd-417f-a17a-a4e0c071fbe5"^^xsd:anyURI .
#
# CDs:A_Bone_Crone_Drone  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "ABoneCroneDrone" ;
#         dcterms:creator                SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:byArtist        SoloMusicArtist:Sheila_Chandra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d0511f81-348f-3778-aa3e-8d30221980d2"^^xsd:anyURI .
#
# CDs:Fishing_With_John  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fishing with John" ;
#         dcterms:creator                SoloMusicArtist:John_Lurie ;
#         bibliographica:byArtist        SoloMusicArtist:John_Lurie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83cd542a-2b13-4471-b5fc-6551fb9fd9b3"^^xsd:anyURI .
#
# CDs:Blue_River  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue River" ;
#         dcterms:creator                SoloMusicArtist:Eric_Andersen ;
#         bibliographica:byArtist        SoloMusicArtist:Eric_Andersen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/94a0ffb6-39b9-409c-a49d-ad4eb805bb20"^^xsd:anyURI .
#
# CDs:The_Long_Black_Veil  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Long Black Veil" ;
#         dcterms:creator                MusicGroup:The_Chieftains ;
#         bibliographica:byArtist        MusicGroup:The_Chieftains ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7002335a-8473-3056-a52a-aa36a350e5a6"^^xsd:anyURI .
#
# CDs:Stand_Up  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stand Up" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6bd9ac39-6fb6-3eba-a684-78d98a8ddd72"^^xsd:anyURI .
#
# CDs:Down_on_the_Farm  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Down on the Farm" ;
#         dcterms:creator                MusicGroup:Little_Feat ;
#         bibliographica:byArtist        MusicGroup:Little_Feat ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aec1511c-4a9a-41e1-90c4-f330fcfcb522"^^xsd:anyURI .
#
# CDs:At_Last  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At Last" ;
#         dcterms:creator                SoloMusicArtist:Cyndi_Lauper ;
#         bibliographica:byArtist        SoloMusicArtist:Cyndi_Lauper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c863ec7a-8930-4e1e-8209-3293333dc83e"^^xsd:anyURI .
#
# CDs:How_Sweet_It_Is  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "How Sweet It Is..." ;
#         dcterms:creator                MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:byArtist        MusicGroup:Jerry_Garcia_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/079f8a91-b504-4a83-af13-d7f855403512"^^xsd:anyURI .
#
# CDs:Spirits  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spirits" ;
#         dcterms:creator                SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:byArtist        SoloMusicArtist:Gil_Scott_Heron ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/64b8cc26-0ca3-47d7-bee7-759a04511bcd"^^xsd:anyURI .
#
# CDs:Bryter_Layter  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Bryter Layter" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/93d4c2fa-6749-3820-88df-b1f6df8cf48b"^^xsd:anyURI .
#
# CDs:City_Garden  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "City Garden" ;
#         dcterms:creator                SoloMusicArtist:Jess_Klein ;
#         bibliographica:byArtist        SoloMusicArtist:Jess_Klein ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b12dff80-34d7-45a9-9def-03a12363a725"^^xsd:anyURI .
#
# CDs:Anthology_New_Grass  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Anthology" ;
#         dcterms:creator                MusicGroup:New_Grass_Revival ;
#         bibliographica:byArtist        MusicGroup:New_Grass_Revival ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9b52467f-7594-4a23-a377-970eec293051"^^xsd:anyURI .
#
# CDs:Best_of_Freddie_Hubbard
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Freddie Hubbard" ;
#         dcterms:creator                SoloMusicArtist:Freddie_Hubbard ;
#         bibliographica:byArtist        SoloMusicArtist:Freddie_Hubbard ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f9b1745a-e2f4-4a22-b2c9-68b0b51d3e3d"^^xsd:anyURI .
#
# CDs:I_Remember  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "I Remember" ;
#         dcterms:creator                SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:byArtist        SoloMusicArtist:Dianne_Reeves ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b2cd4ed5-7931-4cfc-ac38-8afea50f762b"^^xsd:anyURI .
#
# CDs:Grateful_Dead_Movie  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Grateful Dead Movie Soundtrack" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5d4f2f57-1791-43a8-86da-d9de173a6a67"^^xsd:anyURI .
#
# CDs:The_Big_Time  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Big Time" ;
#         dcterms:creator                SoloMusicArtist:Robin_Holcomb ;
#         bibliographica:byArtist        SoloMusicArtist:Robin_Holcomb ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b9a7a401-5fb7-4697-bac0-78aa685bb9e5"^^xsd:anyURI .
#
# CDs:Period_of_Transition
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Period Of Transition" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4000b258-46ad-46ea-82ed-0485c935521b"^^xsd:anyURI .
#
# CDs:Moat_on_Ledge  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moat on the Ledge" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/532d55f6-2d7b-4d08-b01e-106e1510a9bd"^^xsd:anyURI .
#
# CDs:Songs_From_Ether  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Songs From the Ether" ;
#         dcterms:creator                SoloMusicArtist:Libby_Kirkpatrick ;
#         bibliographica:byArtist        SoloMusicArtist:Libby_Kirkpatrick ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/e843e1c0-a590-308c-af74-47ee7c60e215"^^xsd:anyURI .
#
# CDs:Twang_Bar_King  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Twang Bar King" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ddcaf4c-d7e7-47f6-89c3-b28716bf79d0"^^xsd:anyURI .
#
# CDs:Twenty_Fifth_Anniv_Concert
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "25th Anniversary Concert" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/05550067-18c3-45c0-b964-46357fdf36b2"^^xsd:anyURI .
#
# CDs:In_The_Round  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pentangle" ;
#         dcterms:creator                MusicGroup:Pentangle ;
#         bibliographica:byArtist        MusicGroup:Pentangle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ee6d0adc-5745-4c8d-818f-5a3fb47eb399"^^xsd:anyURI .
#
# CDs:Odd_Man_In  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Odd Man In" ;
#         dcterms:creator                SoloMusicArtist:Tim_OBrien ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_OBrien ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4e5b86e2-8bf3-40b3-8e8c-74dab84fb691"^^xsd:anyURI .
#
# CDs:Strikes_Twice  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Friends" ;
#         dcterms:creator                SoloMusicArtist:Larry_Carlton ;
#         bibliographica:byArtist        SoloMusicArtist:Larry_Carlton ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/763f1a88-fb23-3d94-be12-4439a9eefc0b"^^xsd:anyURI .
#
# CDs:Too_Many_Years  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Too Many Years" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/80c1431a-485f-465a-85d8-ad153623c173"^^xsd:anyURI .
#
# CDs:AniDiFranco_CD  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Ani DiFranco" ;
#         dcterms:creator                SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:byArtist        SoloMusicArtist:Ani_DiFranco ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/2f220c9c-9f5f-35dc-8c62-b9b48827032e"^^xsd:anyURI .
#
# CDs:The_Art_of_Coltrane  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Art of John Coltrane" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/764d90b5-bcbe-4f74-9485-6aad20b0cdac"^^xsd:anyURI .
#
# CDs:Red_Desert_Sky  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Red Desert Sky" ;
#         dcterms:creator                MusicGroup:Dead_Ringer_Band ;
#         bibliographica:byArtist        MusicGroup:Dead_Ringer_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e251e3a-b04d-4c30-9494-de52b84bed98"^^xsd:anyURI .
#
# CDs:Its_Too_Late_Stop_Now
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "It’s Too Late to Stop Now" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/557776b7-e60c-358b-87b7-e219e672622c"^^xsd:anyURI .
#
# CDs:Dream_City  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dream City" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0b42a7e7-2a1a-41d3-b322-f52fec4f08a9"^^xsd:anyURI .
#
# CDs:Infrared_Roses  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Infrared Roses" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c923aa9e-804c-4da5-981c-5de05f3d645e"^^xsd:anyURI .
#
# CDs:Trio_II  a                            mo:Release , schema:MusicAlbum , mo:CD , mo:Record ;
#         rdfs:label                     "Trio II" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris , SoloMusicArtist:Linda_Ronstadt , SoloMusicArtist:Dolly_Parton ;
#         bibliographica:byArtist        SoloMusicArtist:Dolly_Parton , SoloMusicArtist:Emmylou_Harris , SoloMusicArtist:Linda_Ronstadt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/fcd5649e-c971-3c22-bd61-e1718da92b24"^^xsd:anyURI .
#
# CDs:Solace  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Solace" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/792f388f-78d3-4c87-8375-4b956251d7e9"^^xsd:anyURI .
#
# CDs:Hogs_on_the_Highway  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hogs on the Highway" ;
#         dcterms:creator                MusicGroup:Bad_Livers ;
#         bibliographica:byArtist        MusicGroup:Bad_Livers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d287713d-7548-4ffa-a917-be29d8dcc5fa"^^xsd:anyURI .
#
# CDs:One_Mans_Trash  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Man's Trash Is Another Man's Treasure" ;
#         dcterms:creator                MusicGroup:Jody_Grind ;
#         bibliographica:byArtist        MusicGroup:Jody_Grind ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/47bdb44f-a22c-489a-be3f-1c6d3181f25a"^^xsd:anyURI .
#
# CDs:Sherri_Jackson_CD  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sherri Jackson" ;
#         dcterms:creator                SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:byArtist        SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/413dae8f-59be-487c-b351-a64118ff4d89"^^xsd:anyURI .
#
# CDs:In_the_Hills_California
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Hills of California" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7a9deef5-30dc-4d5b-a331-fea7ae630f0d"^^xsd:anyURI .
#
# CDs:Together_at_Bluebird
#         a                              mo:CD , schema:MusicAlbum , mo:Release , mo:Record ;
#         rdfs:label                     "Together at the Bluebird Cafe" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle , SoloMusicArtist:Townes_Van_Zandt , SoloMusicArtist:Guy_Clark ;
#         bibliographica:byArtist        SoloMusicArtist:Guy_Clark , SoloMusicArtist:Townes_Van_Zandt , SoloMusicArtist:Steve_Earle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41ffcd14-8368-450e-a53b-54c5503b1df2"^^xsd:anyURI .
#
# CDs:Phosphorescent_Rat  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Phosphorescent Rat" ;
#         dcterms:creator                MusicGroup:Hot_Tuna ;
#         bibliographica:byArtist        MusicGroup:Hot_Tuna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/303f2eb3-bf48-49fb-93fa-e08699b358ac"^^xsd:anyURI .
#
# CDs:Shiny_Beast  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Shiny Beast (Bat Chain Puller)" ;
#         dcterms:creator                MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:byArtist        MusicGroup:Captain_Beefheart_Magic_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/5887c600-15a7-3c40-9b8b-49aac410be6d"^^xsd:anyURI .
#
# CDs:Court_and_Spark  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Court and Spark" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b26f58eb-5cc3-3cf6-a077-1fab1d70e8e6"^^xsd:anyURI .
#
# CDs:Nightfall_of_Diamonds
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Nightfall of Diamonds" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/90189871-381e-4ad0-9f5d-cfb35b174bbc"^^xsd:anyURI .
#
# CDs:In_Wake_of_Poseidon  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In the Wake of Poseidon" ;
#         dcterms:creator                MusicGroup:King_Crimson ;
#         bibliographica:byArtist        MusicGroup:King_Crimson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d2f3245f-670b-358f-9695-24eea8cbfdfb"^^xsd:anyURI .
#
# CDs:Valence_Street  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Valence Street" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b3ea04ae-c833-47cb-814f-67418542c786"^^xsd:anyURI .
#
# CDs:Spare_Ass_Annie  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spare Ass Annie and Other Tales" ;
#         dcterms:creator                SoloMusicArtist:William_S_Burroughs ;
#         bibliographica:byArtist        SoloMusicArtist:William_S_Burroughs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/572eec6a-ec80-4a8d-a772-1727dff36ab5"^^xsd:anyURI .
#
# CDs:When_Woman_Gets_Blues
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "When A Woman Gets The Blues" ;
#         dcterms:creator                SoloMusicArtist:Rory_Block ;
#         bibliographica:byArtist        SoloMusicArtist:Rory_Block ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/da3b4358-40bd-4259-854b-c0ce4d2cb6bb"^^xsd:anyURI .
#
# CDs:Very_Best_Of_Nina  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Very Best of Nina Hagen" ;
#         dcterms:creator                SoloMusicArtist:Nina_Hagen ;
#         bibliographica:byArtist        SoloMusicArtist:Nina_Hagen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/00e45b6d-29d6-47e7-86b4-ec85b37ee439"^^xsd:anyURI .
#
# CDs:Old_In_the_Gray_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Old & In The Gray" ;
#         dcterms:creator                MusicGroup:Old_In_the_Gray ;
#         bibliographica:byArtist        MusicGroup:Old_In_the_Gray ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/825cba3f-e674-4082-b3d5-47dbd20a8507"^^xsd:anyURI .
#
# CDs:Fulton_Street  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "2400 Fulton Street" ;
#         dcterms:creator                MusicGroup:Jefferson_Airplane ;
#         bibliographica:byArtist        MusicGroup:Jefferson_Airplane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/007195e3-cc99-4408-a81b-82f4577f85ce"^^xsd:anyURI .
#
# CDs:Mardi_Gras_Baton_Rouge
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mardi Gras in Baton Rouge" ;
#         dcterms:creator                SoloMusicArtist:Professor_Longhair ;
#         bibliographica:byArtist        SoloMusicArtist:Professor_Longhair ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/462fc1a2-1d02-472b-9dd2-bc93c6dbc2c5"^^xsd:anyURI .
#
# CDs:Loud_Plowed_Live  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Loud And Plowed And... Live!!" ;
#         dcterms:creator                MusicGroup:The_Beat_Farmers ;
#         bibliographica:byArtist        MusicGroup:The_Beat_Farmers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8ea95945-252f-481d-a914-d5d54de5a9e1"^^xsd:anyURI .
#
# CDs:Pieces_of_Sky  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Pieces of the Sky" ;
#         dcterms:creator                SoloMusicArtist:Lori_McKenna ;
#         bibliographica:byArtist        SoloMusicArtist:Lori_McKenna ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ec58426-57a5-4af3-8011-a4032d48211f"^^xsd:anyURI .
#
# CDs:Is_That_You  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Is That You?" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9dacd67b-3d67-4c82-9093-62ea9109f4a2"^^xsd:anyURI .
#
# CDs:Afro_Blue_Impressions
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Afro Blue Impressions" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7c00822f-f645-43f6-ae90-0b0d763f9487"^^xsd:anyURI .
#
# CDs:Mr_Music_Head  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mr Music Head" ;
#         dcterms:creator                SoloMusicArtist:Adrian_Belew ;
#         bibliographica:byArtist        SoloMusicArtist:Adrian_Belew ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/12a04743-dff0-49b8-a5cb-e4368920cd30"^^xsd:anyURI .
#
# CDs:Cookin_at_Plugged_Nickel
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cookin' At The Plugged Nickel" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01152ef7-52cd-44f2-819a-839722f09636"^^xsd:anyURI .
#
# CDs:Live_at_Apollo_95  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live at the Apollo, 1995" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f36e0590-15c8-4dc6-8c77-e10ed4f3b36a"^^xsd:anyURI .
#
# CDs:Wild_Planet  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Wild Planet" ;
#         dcterms:creator                MusicGroup:B_Fifty_Twos ;
#         bibliographica:byArtist        MusicGroup:B_Fifty_Twos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34c9f3a8-898a-3d33-92bc-64a46ad75928"^^xsd:anyURI .
#
# CDs:Llego_Van_Van  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Llegó... Van Van" ;
#         dcterms:creator                MusicGroup:Los_Van_Van ;
#         bibliographica:byArtist        MusicGroup:Los_Van_Van ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f598b9c2-30ba-4119-b523-52144679578f"^^xsd:anyURI .
#
# CDs:Be_Yourself_Tonight  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Be Yourself Tonight" ;
#         dcterms:creator                MusicGroup:Eurythmics ;
#         bibliographica:byArtist        MusicGroup:Eurythmics ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/54daca91-4e82-320e-8aa8-1896e46bf69e"^^xsd:anyURI .
#
# CDs:Milk_of_The_moon  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Milk of the Moon" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f33eccbd-f9a3-436a-acb2-8ccd2cb5e6dc"^^xsd:anyURI .
#
# CDs:The_Clown  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Clown" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/910c0ae4-e0f6-35da-a9fd-786390756c5a"^^xsd:anyURI .
#
# CDs:Friday_Night_Blackhawk
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In Person: Friday Night at the Blackhawk, San Francisco, Vol 1" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/59709a91-559a-44fb-9cd4-89dfd441b281"^^xsd:anyURI .
#
# CDs:Groovegrass_101  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Groovegrass 101" ;
#         dcterms:creator                MusicGroup:GrooveGrass_Boyz ;
#         bibliographica:byArtist        MusicGroup:GrooveGrass_Boyz ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/24abd2f2-f159-4314-a07f-fb85992fe67e"^^xsd:anyURI .
#
# CDs:Bootleg_Series_Vol_6
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Bootleg Series, Vol. 6: Live 1964: Concert at Philharmonic Hall" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/a7a11770-e2e5-38a3-8c5b-9280d65dd9a5"^^xsd:anyURI .
#
# CDs:Shady_Grove  a                        mo:Release , schema:MusicAlbum , mo:CD , mo:Record ;
#         rdfs:label                     "Shady Grove" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia , SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/238a43ae-317b-42ca-9029-e75f8b97efe5"^^xsd:anyURI .
#
# CDs:Best_of_Marvin_Gaye  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best Of Marvin Gaye, Vol. 2: The '70s" ;
#         dcterms:creator                SoloMusicArtist:Marvin_Gaye ;
#         bibliographica:byArtist        SoloMusicArtist:Marvin_Gaye ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/518efc81-ed01-479d-97eb-9f0c4ba4f940"^^xsd:anyURI .
#
# CDs:Terrapin_Station_Live
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Terrapin Station Live" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f87924fd-8725-4b3a-892c-2492456aea52"^^xsd:anyURI .
#
# CDs:Retrospective_SL  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "1905-1990 A Retrospective" ;
#         dcterms:creator          SoloMusicArtist:Shona_Laing ;
#         bibliographica:byArtist  SoloMusicArtist:Shona_Laing .
#
# CDs:Glamor_Grits  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Glamor & Grits" ;
#         dcterms:creator                SoloMusicArtist:Sam_Bush ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Bush ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7a751055-026d-4a02-93df-cb50260ed30a"^^xsd:anyURI .
#
# CDs:Afterglow  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Afterglow" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6d1d2e4-dac8-3afa-9e3f-9c4a2019b51b"^^xsd:anyURI .
#
# CDs:II_and_III  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "II & III" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a505ccef-2315-3339-8a6b-c183dfa9e7c1"^^xsd:anyURI .
#
# CDs:Living_With_Ghosts  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Living With Ghosts" ;
#         dcterms:creator                SoloMusicArtist:Patty_Griffin ;
#         bibliographica:byArtist        SoloMusicArtist:Patty_Griffin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7fe6a811-5c22-4211-b0b6-a7b8e0a270bd"^^xsd:anyURI .
#
# CDs:Perishable_Fruit  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Perishable Fruit" ;
#         dcterms:creator                SoloMusicArtist:Patty_Larkin ;
#         bibliographica:byArtist        SoloMusicArtist:Patty_Larkin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1098b562-805c-41ac-8bd5-cc801b7eb8a9"^^xsd:anyURI .
#
# CDs:Liege_and_Lief  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Liege & Lief" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b68bf54c-5e26-410e-984f-dc5b720b7526"^^xsd:anyURI .
#
# CDs:Oh_Yeah  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Oh Yeah" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/315d2d84-3bd2-4644-babb-3338881177fd"^^xsd:anyURI .
#
# CDs:Highway_61_Revisited
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Highway 61 Revisited" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/fb48b1dc-412f-36aa-8820-1023c08c46c6"^^xsd:anyURI .
#
# CDs:When_Words_Disappear
#         a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "When Words Disappear" ;
#         dcterms:creator          SoloMusicArtist:Zakir_Hussain ;
#         bibliographica:byArtist  SoloMusicArtist:Zakir_Hussain .
#
# CDs:Thundering_Herd  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thundering Herd (disc 1)" ;
#         dcterms:creator                MusicGroup:Golden_Palominos ;
#         bibliographica:byArtist        MusicGroup:Golden_Palominos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/565c2bb2-5277-467d-ad36-97e8be01ce6e"^^xsd:anyURI .
#
# CDs:Blue   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Blue" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a575174c-36c5-4ba5-8f34-1d752815fd99"^^xsd:anyURI .
#
# CDs:Live_at_Tiptinas  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live At Tipitina's" ;
#         dcterms:creator                MusicGroup:Neville_Brothers ;
#         bibliographica:byArtist        MusicGroup:Neville_Brothers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be5e88fa-3a34-4c6d-8932-eff1d304a84a"^^xsd:anyURI .
#
# CDs:Headhunters  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Headhunters" ;
#         dcterms:creator                SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:byArtist        SoloMusicArtist:Herbie_Hancock ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8f2f47b4-880d-30be-a525-cc9be061c909"^^xsd:anyURI .
#
# CDs:Cats_Under_Stars  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Cats Under the Stars" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e5317817-1c5e-4250-8d11-47982ec09c46"^^xsd:anyURI .
#
# CDs:Oh_Mercy  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Oh Mercy" ;
#         dcterms:creator                SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/36675813-6c3c-33fa-8eaf-b1cd66d4f006"^^xsd:anyURI .
#
# CDs:In_My_Tribe  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "In My Tribe" ;
#         dcterms:creator                MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:byArtist        MusicGroup:Ten_Thousand_Maniacs ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/53349b3c-d994-465e-a317-01853338178b"^^xsd:anyURI .
#
# CDs:Faith_Courage  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Faith and Courage" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d6ad238d-d759-4740-a39a-1bfb93d75409"^^xsd:anyURI .
#
# CDs:On_Way_Down  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "On the Way Down From the Moon Palace" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Germano ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Germano ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2eb278d1-ca26-456f-8d00-7f4855f9c9c0"^^xsd:anyURI .
#
# CDs:Greatest_Show_Earth  a          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "The Greatest Show On Earth" ;
#         dcterms:creator          SoloMusicArtist:Katy_Moffatt ;
#         bibliographica:byArtist  SoloMusicArtist:Katy_Moffatt .
#
# CDs:Country_Protest  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Country Protest" ;
#         dcterms:creator                SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:byArtist        SoloMusicArtist:Eugene_Chadbourne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/281cf50b-93aa-38b2-a239-15d4eb0f9d8a"^^xsd:anyURI .
#
# CDs:Tribute_to_Jack_Johnson
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "A Tribute to Jack Johnson" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9f14ff98-128e-3dff-a603-0555d66f9fca"^^xsd:anyURI .
#
# CDs:Relish  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Relish" ;
#         dcterms:creator                SoloMusicArtist:Joan_Osborne ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Osborne ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/41517c1e-45a2-4ddd-ae9c-220707577ef0"^^xsd:anyURI .
#
# CDs:Pizza_Tapes_II  a                     mo:CD , schema:MusicAlbum , mo:Record , mo:Release ;
#         rdfs:label                     "The Pizza Tapes II" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Tony_Rice , SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia , SoloMusicArtist:David_Grisman , SoloMusicArtist:Tony_Rice ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c0aeaa9d-e474-41a9-821a-fdc62515a069"^^xsd:anyURI .
#
# CDs:Hundred_Year_Hall  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Hundred Year Hall" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/98b5c41e-2288-46b1-9152-d711fca024fe"^^xsd:anyURI .
#
# CDs:Medusa  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Medusa" ;
#         dcterms:creator                SoloMusicArtist:Annie_Lennox ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Lennox ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/55229cad-2f4f-4b02-8530-7e9d199018fc"^^xsd:anyURI .
#
# CDs:Family_Tree  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Family Tree" ;
#         dcterms:creator                SoloMusicArtist:Nick_Drake ;
#         bibliographica:byArtist        SoloMusicArtist:Nick_Drake ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/beba85a6-8a05-3bf8-99d6-2a5e9f38f12e"^^xsd:anyURI .
#
# CDs:Miss_Perfumado  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miss Perfumado" ;
#         dcterms:creator                SoloMusicArtist:Cesaria_Evora ;
#         bibliographica:byArtist        SoloMusicArtist:Cesaria_Evora ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/be6a1a44-c856-4569-b832-44c75d307f2b"^^xsd:anyURI .
#
# CDs:Down_in_There  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Down in There" ;
#         dcterms:creator                SoloMusicArtist:Greg_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:Greg_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7747bc60-5d1e-4c07-847d-a55436ffcae4"^^xsd:anyURI .
#
# CDs:Streetlights  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Streetlights" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/21233587-1796-32b2-8f79-aedfb6395496"^^xsd:anyURI .
#
# CDs:Everything_Nothing  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Everything And Nothing" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/f1b6219e-6953-31ed-9502-d6c2f3a25af1"^^xsd:anyURI .
#
# CDs:Miles_in_Berlin  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Miles in Berlin" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5a3c7f11-9877-4d33-9c07-d0ecfc942ed4"^^xsd:anyURI .
#
# CDs:Transcendental_Blues
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Transcendental Blues" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Earle ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b09571d4-8b90-4b6e-b698-087d7cf9957a"^^xsd:anyURI .
#
# CDs:Living_End  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Living End" ;
#         dcterms:creator                MusicGroup:Husker_Du ;
#         bibliographica:byArtist        MusicGroup:Husker_Du ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b09e966-c453-4c01-bcd5-02cc92478c57"^^xsd:anyURI .
#
# CDs:Postcards_of_Hanging
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Postcards of the Hanging: Grateful Dead Perform the Songs of Bob Dylan" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/795c6176-83d9-4905-8663-65b572ce1133"^^xsd:anyURI .
#
# CDs:Mirror_Pool  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Mirror Pool" ;
#         dcterms:creator                SoloMusicArtist:Lisa_Gerrard ;
#         bibliographica:byArtist        SoloMusicArtist:Lisa_Gerrard ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d3fb7a2d-1507-32da-8fcf-3b15fa633e92"^^xsd:anyURI .
#
# CDs:Riverside  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Riverside" ;
#         dcterms:creator                SoloMusicArtist:Luka_Bloom ;
#         bibliographica:byArtist        SoloMusicArtist:Luka_Bloom ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7da06982-bbeb-4033-a6b6-a7161f19c518"^^xsd:anyURI .
#
# CDs:Hangmans_Beautiful_Daughter
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Hangman’s Beautiful Daughter" ;
#         dcterms:creator                MusicGroup:Incredible_String_Band ;
#         bibliographica:byArtist        MusicGroup:Incredible_String_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/37bef007-fcdf-4b6b-b95b-7773d119344c"^^xsd:anyURI .
#
# CDs:Inspiration_Information
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Inspiration Information" ;
#         dcterms:creator                SoloMusicArtist:Shuggie_Otis ;
#         bibliographica:byArtist        SoloMusicArtist:Shuggie_Otis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a5fd58e5-feae-497e-95f0-63a940b0fd87"^^xsd:anyURI .
#
# CDs:Home_and_Away  a                      schema:MusicAlbum , mo:CD , mo:Release , mo:Record ;
#         rdfs:label                     "Home and Away" ;
#         dcterms:creator                SoloMusicArtist:Christine_Collister , SoloMusicArtist:Clive_Gregson ;
#         bibliographica:byArtist        SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a4ac31a8-2eb9-4ae2-924a-1837b41ae96d"^^xsd:anyURI .
#
# CDs:Gold_Medal_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Gold Medal Collection" ;
#         dcterms:creator                SoloMusicArtist:Harry_Chapin ;
#         bibliographica:byArtist        SoloMusicArtist:Harry_Chapin ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/68193220-9e8e-493d-8589-bc945eba0796"^^xsd:anyURI .
#
# CDs:Peace_and_Love  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Peace And Love" ;
#         dcterms:creator                MusicGroup:Pogues ;
#         bibliographica:byArtist        MusicGroup:Pogues ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a4c8eba1-5be1-3c22-9d52-658998abd5a5"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_10  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 10: Winterland Arena 12/29/77" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/01bb8254-f53d-43ef-bb49-af77832c778a"^^xsd:anyURI .
#
# CDs:Touch  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Touch" ;
#         dcterms:creator                SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:byArtist        SoloMusicArtist:Sarah_McLachlan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2600414a-c91c-4265-8f3b-53de75bcc981"^^xsd:anyURI .
#
# CDs:Columbia_River_Collection
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Columbia River Collection" ;
#         dcterms:creator                SoloMusicArtist:Woody_Guthrie ;
#         bibliographica:byArtist        SoloMusicArtist:Woody_Guthrie ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7d67047e-a859-4a47-8454-9b709a6f57cc"^^xsd:anyURI .
#
# CDs:Europe_72  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Europe ’72" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/97006c03-a9b5-4e10-8f52-39fa91c9836b"^^xsd:anyURI .
#
# CDs:Edge_of_City  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Edge of the City" ;
#         dcterms:creator                MusicGroup:Kinsey_Report ;
#         bibliographica:byArtist        MusicGroup:Kinsey_Report ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7f9f5ac-1bb5-4fce-8f2c-5a02c9684aee"^^xsd:anyURI .
#
# CDs:Offramp  a                            schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Offramp" ;
#         dcterms:creator                MusicGroup:Pat_Metheny_Group ;
#         bibliographica:byArtist        MusicGroup:Pat_Metheny_Group ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e9a6637a-9612-3cc4-88c9-50c7ac5d4330"^^xsd:anyURI .
#
# CDs:Jazz_Masters_39  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Verve Jazz Masters 39" ;
#         dcterms:creator                SoloMusicArtist:Cal_Tjader ;
#         bibliographica:byArtist        SoloMusicArtist:Cal_Tjader ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a03d77cf-9606-44ba-bc9b-4b98a768e740"^^xsd:anyURI .
#
# CDs:Radio_Boogie  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Radio Boogie" ;
#         dcterms:creator                MusicGroup:Hot_Rize ;
#         bibliographica:byArtist        MusicGroup:Hot_Rize ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b818648d-83fe-4cff-be38-f6e2729525dc"^^xsd:anyURI .
#
# CDs:Made_in_Dakar  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Made In Dakar" ;
#         dcterms:creator                MusicGroup:Orchestra_Baobab ;
#         bibliographica:byArtist        MusicGroup:Orchestra_Baobab ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e6b2afe4-7244-4596-b80a-1bf48c09e003"^^xsd:anyURI .
#
# CDs:Last_Man_Standing  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Last Man Standing" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Lee_Lewis ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Lee_Lewis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e5dff1b6-b26f-4f25-82cb-5902999af48d"^^xsd:anyURI .
#
# CDs:Quah   a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Quah" ;
#         dcterms:creator                SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:byArtist        SoloMusicArtist:Jorma_Kaukonen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9573da27-0a80-47cd-8427-3494efd5b6f8"^^xsd:anyURI .
#
# CDs:Astral_Weeks  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Astral Weeks" ;
#         dcterms:creator                SoloMusicArtist:Van_Morrison ;
#         bibliographica:byArtist        SoloMusicArtist:Van_Morrison ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ead5ec3-50e1-3ad0-af61-f650b9ead9d0"^^xsd:anyURI .
#
# CDs:Guitar_Trio  a                        mo:CD , mo:Release , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "The Guitar Trio" ;
#         dcterms:creator                SoloMusicArtist:Al_DiMeola , SoloMusicArtist:Paco_de_Lucia , SoloMusicArtist:John_McLaughlin ;
#         bibliographica:byArtist        SoloMusicArtist:John_McLaughlin , SoloMusicArtist:Al_DiMeola , SoloMusicArtist:Paco_de_Lucia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e7f00093-ed11-4d77-970e-ae4351fdb41e"^^xsd:anyURI .
#
# CDs:Firemans_Wedding  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Fireman's Wedding" ;
#         dcterms:creator                SoloMusicArtist:Joe_Henry ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Henry ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/afbb98f2-8fec-4c6d-98bc-b137bb0169e1"^^xsd:anyURI .
#
# CDs:Song_To_A_Seagull  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Song to a Seagull" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/16e70bd8-a702-3e8a-a008-0de4b98030c1"^^xsd:anyURI .
#
# CDs:Walk_Under_Ladders  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Walk Under Ladders" ;
#         dcterms:creator                SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:byArtist        SoloMusicArtist:Joan_Armatrading ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/dee917dc-6a8a-4164-b3ca-44f7761f9f8b"^^xsd:anyURI .
#
# CDs:Mask_and_Mirror  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Mask and Mirror" ;
#         dcterms:creator                SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:byArtist        SoloMusicArtist:Loreena_McKennitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/246344ba-959b-4e52-96ba-c31c23e74bdf"^^xsd:anyURI .
#
# CDs:Los_Lonely_Boys_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Los Lonely Boys" ;
#         dcterms:creator                MusicGroup:Los_Lonely_Boys ;
#         bibliographica:byArtist        MusicGroup:Los_Lonely_Boys ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6e4df799-c739-4a05-8783-af9dc3fe40ef"^^xsd:anyURI .
#
# CDs:Youve_Never_Seen_Anything
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "You've Never Seen Everything" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/6c88bc8e-eaee-3670-ad6b-e37cef8b3e1c"^^xsd:anyURI .
#
# CDs:Tone_Poems_III  a                     mo:Release , mo:CD , schema:MusicAlbum , mo:Record ;
#         rdfs:label                     "Tone Poems III" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Mike_Auldridge , SoloMusicArtist:Bob_Brozman ;
#         bibliographica:byArtist        SoloMusicArtist:Mike_Auldridge , SoloMusicArtist:David_Grisman , SoloMusicArtist:Bob_Brozman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/8b6fea72-5e21-41dd-84b9-25c54a2c016a"^^xsd:anyURI .
#
# CDs:Complete_Live_Plugged_Nickel
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Complete Live at The Plugged Nickel 1965" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/12df4b65-a928-4424-ae95-1df40303a774"^^xsd:anyURI .
#
# CDs:Crossing_Jordan_CD  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crossing Jordan" ;
#         dcterms:creator                MusicGroup:Crossing_Jordan ;
#         bibliographica:byArtist        MusicGroup:Crossing_Jordan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/aaa87e9d-f665-44eb-875e-d712e07c61c8"^^xsd:anyURI .
#
# CDs:Love_Is_Strange_Hotel
#         a                              mo:Release , mo:Record , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "Love Is a Strange Hotel" ;
#         dcterms:creator                SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:byArtist        SoloMusicArtist:Clive_Gregson , SoloMusicArtist:Christine_Collister ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/d30028f3-dc15-4baf-b2ed-b621a2ffe8e3"^^xsd:anyURI .
#
# CDs:Best_of_Whats_Around
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of What's Around" ;
#         dcterms:creator                SoloMusicArtist:Dave_Matthews ;
#         bibliographica:byArtist        SoloMusicArtist:Dave_Matthews ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/67269ee5-a963-4cca-bafc-31e3821d4e13"^^xsd:anyURI .
#
# CDs:Reflections  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Reflections" ;
#         dcterms:creator                SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:byArtist        SoloMusicArtist:Jerry_Garcia ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9e14c789-02b3-4544-a0bf-fc6a0350fc03"^^xsd:anyURI .
#
# CDs:Lemon_Fish_Tweezer  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lemon Fish Tweezer" ;
#         dcterms:creator                SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:byArtist        SoloMusicArtist:Henry_Kaiser ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6ed6c188-8b6d-4369-9577-eef16a3515a8"^^xsd:anyURI .
#
# CDs:Mingus_at_Monterey  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mingus At Monterey" ;
#         dcterms:creator                SoloMusicArtist:Charles_Mingus ;
#         bibliographica:byArtist        SoloMusicArtist:Charles_Mingus ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c4b3d1a1-7627-43db-bda7-510e06d16cb0"^^xsd:anyURI .
#
# CDs:Very_Greasy  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Very Greasy" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/102015a6-3b86-4085-aa1f-8f4a9854535d"^^xsd:anyURI .
#
# CDs:My_Funny_Valentine  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "My Funny Valentine" ;
#         dcterms:creator                SoloMusicArtist:Chet_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Chet_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7c343bdc-f9bf-4960-8830-27bb0672ab4c"^^xsd:anyURI .
#
# CDs:Jazzmatazz_Vol_2  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Jazzmatazz, Vol. 2: The New Reality" ;
#         dcterms:creator                SoloMusicArtist:Guru ;
#         bibliographica:byArtist        SoloMusicArtist:Guru ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cf40162e-85bc-433d-b285-3665782652f1"^^xsd:anyURI .
#
# CDs:High_Dive_MM  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "High Dive" ;
#         dcterms:creator                SoloMusicArtist:Maria_McKee ;
#         bibliographica:byArtist        SoloMusicArtist:Maria_McKee ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/9ede9440-d062-4639-be30-3a293f92f1f6"^^xsd:anyURI .
#
# CDs:From_Here_to_Eternity
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "From Here to Eternity: Live" ;
#         dcterms:creator                MusicGroup:Clash ;
#         bibliographica:byArtist        MusicGroup:Clash ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/23b1c9f4-4e89-4c20-b497-517a51953e7b"^^xsd:anyURI .
#
# CDs:Universal_Mother  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Universal Mother" ;
#         dcterms:creator                SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:byArtist        SoloMusicArtist:Sinead_OConnor ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/312f5c6f-06eb-309d-aaca-a95a360bc5ed"^^xsd:anyURI .
#
# CDs:The_Sky_is_Falling  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Sky Is Falling and I Want My Mommy" ;
#         dcterms:creator                SoloMusicArtist:Jello_Biafra ;
#         bibliographica:byArtist        SoloMusicArtist:Jello_Biafra ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/693748be-7c18-39c3-af2e-2e62092090cf"^^xsd:anyURI .
#
# CDs:More_Legend_Than_Band
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "More a Legend Than a Band" ;
#         dcterms:creator                MusicGroup:Flatlanders ;
#         bibliographica:byArtist        MusicGroup:Flatlanders ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a96c8956-5c21-4b05-a44b-0c6d725659fb"^^xsd:anyURI .
#
# CDs:Southern_Rock_Opera  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Southern Rock Opera" ;
#         dcterms:creator                MusicGroup:Drive_By_Truckers ;
#         bibliographica:byArtist        MusicGroup:Drive_By_Truckers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bd3a9303-06c3-342e-9209-aeb2e194b02b"^^xsd:anyURI .
#
# CDs:Greetings_From_LA  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Greetings From LA" ;
#         dcterms:creator                SoloMusicArtist:Tim_Buckley ;
#         bibliographica:byArtist        SoloMusicArtist:Tim_Buckley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/e3a1953f-0e09-4b8d-adcf-708947bf5685"^^xsd:anyURI .
#
# CDs:Silver_Lining  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Silver Lining" ;
#         dcterms:creator                SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:byArtist        SoloMusicArtist:Bonnie_Raitt ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/28a9bfa4-c397-49aa-914e-68c6df75bfbd"^^xsd:anyURI .
#
# CDs:Martinis_Bikinis  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Martinis & Bikinis" ;
#         dcterms:creator                SoloMusicArtist:Sam_Phillips ;
#         bibliographica:byArtist        SoloMusicArtist:Sam_Phillips ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/322d784a-30ed-4402-8b16-8afdbb8c4e38"^^xsd:anyURI .
#
# CDs:Lost_In_Space  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Lost In Space" ;
#         dcterms:creator                SoloMusicArtist:Aimee_Mann ;
#         bibliographica:byArtist        SoloMusicArtist:Aimee_Mann ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1b5879b4-b093-45e0-9ac6-a63f24b965d3"^^xsd:anyURI .
#
# CDs:Lo_Cura  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Lo Cura!" ;
#         dcterms:creator          MusicGroup:Lo_Cura ;
#         bibliographica:byArtist  MusicGroup:Lo_Cura .
#
# CDs:At_The_Edge  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "At the Edge" ;
#         dcterms:creator                SoloMusicArtist:Mickey_Hart ;
#         bibliographica:byArtist        SoloMusicArtist:Mickey_Hart ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b1c578a1-5cbd-4ccd-9e42-20eba161c84c"^^xsd:anyURI .
#
# CDs:Strong_Persuader  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Strong Persuader" ;
#         dcterms:creator                SoloMusicArtist:Robert_Cray ;
#         bibliographica:byArtist        SoloMusicArtist:Robert_Cray ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/201f1501-368e-4529-8146-ad9232bcb297"^^xsd:anyURI .
#
# CDs:The_Mountain  a                       mo:Record , schema:MusicAlbum , mo:Release , mo:CD ;
#         rdfs:label                     "The Mountain" ;
#         dcterms:creator                SoloMusicArtist:Steve_Earle , MusicGroup:Del_McCoury_Band ;
#         bibliographica:byArtist        SoloMusicArtist:Steve_Earle , MusicGroup:Del_McCoury_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/46600b98-3c33-42d4-b66c-0617013a6d6f"^^xsd:anyURI .
#
# CDs:Now_Again  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Now Again" ;
#         dcterms:creator                MusicGroup:Flatlanders ;
#         bibliographica:byArtist        MusicGroup:Flatlanders ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/34aec3dc-a788-47cc-b9bf-02c8c11b5150"^^xsd:anyURI .
#
# CDs:Sunny_Border_Blue  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sunny Border Blue" ;
#         dcterms:creator                SoloMusicArtist:Kristin_Hersh ;
#         bibliographica:byArtist        SoloMusicArtist:Kristin_Hersh ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c1eedf21-be23-48eb-b079-61ff3c2941e5"^^xsd:anyURI .
#
# CDs:Weary_Blues  a                        schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Weary Blues" ;
#         dcterms:creator                SoloMusicArtist:Langston_Hughes ;
#         bibliographica:byArtist        SoloMusicArtist:Langston_Hughes ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/81b695b6-c88c-4a74-96d2-a45352688266"^^xsd:anyURI .
#
# CDs:African_Force  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "African Force" ;
#         dcterms:creator                SoloMusicArtist:Ginger_Baker ;
#         bibliographica:byArtist        SoloMusicArtist:Ginger_Baker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/7bbaa2a8-1fcc-4e7c-b31f-1c5a461e77c7"^^xsd:anyURI .
#
# CDs:Trinity_Session  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Trinity Session" ;
#         dcterms:creator                MusicGroup:Cowboy_Junkies ;
#         bibliographica:byArtist        MusicGroup:Cowboy_Junkies ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/faada5d1-971b-499c-b902-5bab9e03bc1b"^^xsd:anyURI .
#
# CDs:Thick_As_Brick  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thick As A Brick" ;
#         dcterms:creator                MusicGroup:Jethro_Tull ;
#         bibliographica:byArtist        MusicGroup:Jethro_Tull ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0e31a7b5-a753-3330-9418-8a32efd1141d"^^xsd:anyURI .
#
# CDs:Live_SG_DG  a                         mo:Release , mo:Record , schema:MusicAlbum , mo:CD ;
#         rdfs:label                     "Live" ;
#         dcterms:creator                SoloMusicArtist:David_Grisman , SoloMusicArtist:Stephane_Grappelli ;
#         bibliographica:byArtist        SoloMusicArtist:Stephane_Grappelli , SoloMusicArtist:David_Grisman ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/5b27476a-2710-4fc3-a5d8-25d994b79e09"^^xsd:anyURI .
#
# CDs:Sunwheel_Dance  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sunwheel Dance" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/d85e6674-9ff4-3e11-be8f-eb6b11c5f47d"^^xsd:anyURI .
#
# CDs:Dylan_and_Dead  a                     schema:MusicAlbum , mo:CD , mo:Record , mo:Release ;
#         rdfs:label                     "Dylan & the Dead" ;
#         dcterms:creator                MusicGroup:Grateful_Dead , SoloMusicArtist:Bob_Dylan ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Dylan , MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4eed761b-1e14-43ec-902c-852656fa91fd"^^xsd:anyURI .
#
# CDs:Our_Beloved_Revolutionary
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Our Beloved Revolutionary Sweetheart" ;
#         dcterms:creator                MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:byArtist        MusicGroup:Camper_Van_Beethoven ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3a3d0f74-3487-4976-9093-b6414adc6963"^^xsd:anyURI .
#
# CDs:Darkness_Edge_Town  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Darkness On The Edge Of Town" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Springsteen ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Springsteen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/c4b01581-df6a-492d-bf98-31d36affb9b1"^^xsd:anyURI .
#
# CDs:Clouds  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Clouds" ;
#         dcterms:creator                SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:byArtist        SoloMusicArtist:Joni_Mitchell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b26f58eb-5cc3-3cf6-a077-1fab1d70e8e6"^^xsd:anyURI .
#
# CDs:Twenty_Greatest_Hits
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "20 All Time Greatest Hits!" ;
#         dcterms:creator                SoloMusicArtist:James_Brown ;
#         bibliographica:byArtist        SoloMusicArtist:James_Brown ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/2c6b376f-0357-4683-a1d8-2a5df30f0ad0"^^xsd:anyURI .
#
# CDs:Carnival  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Carnival" ;
#         dcterms:creator                SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:byArtist        SoloMusicArtist:Kasey_Chambers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/422c79b0-9b1a-435b-b490-e5235e54093f"^^xsd:anyURI .
#
# CDs:Columbia_Years  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Columbia Years 1955–1985" ;
#         dcterms:creator                SoloMusicArtist:Miles_Davis ;
#         bibliographica:byArtist        SoloMusicArtist:Miles_Davis ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/31c639d3-ff84-4fdc-baf7-93d1c71e9320"^^xsd:anyURI .
#
# CDs:Moments_in_Denial  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Moments in Denial" ;
#         dcterms:creator                SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:byArtist        SoloMusicArtist:Sherri_Jackson ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/f60e284b-1bb8-40ad-9a52-2d90447031d0"^^xsd:anyURI .
#
# CDs:Mummy_Dust  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Mummy Dust" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/b802a83a-e993-35fb-b193-e471df209127"^^xsd:anyURI .
#
# CDs:Crescent  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Crescent" ;
#         dcterms:creator                SoloMusicArtist:John_Coltrane ;
#         bibliographica:byArtist        SoloMusicArtist:John_Coltrane ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bb4eb994-5863-47d2-b040-e2834110b667"^^xsd:anyURI .
#
# CDs:Levellers_CD  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Levellers" ;
#         dcterms:creator                MusicGroup:Levellers ;
#         bibliographica:byArtist        MusicGroup:Levellers ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/da580b73-6614-417f-b819-a9755620195e"^^xsd:anyURI .
#
# CDs:Validation_Music  a             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label               "Validation Music" ;
#         dcterms:creator          MusicGroup:New_Shining_Soul_Band ;
#         bibliographica:byArtist  MusicGroup:New_Shining_Soul_Band .
#
# CDs:Devo_Live  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "DEV‐O Live" ;
#         dcterms:creator                MusicGroup:Devo ;
#         bibliographica:byArtist        MusicGroup:Devo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/519d76df-ef9f-42f6-97fe-f3f18d32ce85"^^xsd:anyURI .
#
# CDs:Living_In_Circle  a                   schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Living in the Circle" ;
#         dcterms:creator                MusicGroup:Dead_Ringer_Band ;
#         bibliographica:byArtist        MusicGroup:Dead_Ringer_Band ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/83e0c31d-82a6-4951-8de6-81da797d6fa9"^^xsd:anyURI .
#
# CDs:Spyboy  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spyboy" ;
#         dcterms:creator                SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:byArtist        SoloMusicArtist:Emmylou_Harris ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/104ec1b8-adb5-4f4a-af80-9041ddc55bf0"^^xsd:anyURI .
#
# CDs:Live_Adventures  a                    mo:CD , mo:Record , mo:Release , schema:MusicAlbum ;
#         rdfs:label                     "Live Adventures" ;
#         dcterms:creator                SoloMusicArtist:Al_Kooper , SoloMusicArtist:Mike_Bloomfield ;
#         bibliographica:byArtist        SoloMusicArtist:Mike_Bloomfield , SoloMusicArtist:Al_Kooper ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/af443909-b1fb-3be9-bd9f-452821fbb26d"^^xsd:anyURI .
#
# CDs:Spirit_of_Century  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Spirit of the Century" ;
#         dcterms:creator                MusicGroup:Blind_Boys_of_Alabama ;
#         bibliographica:byArtist        MusicGroup:Blind_Boys_of_Alabama ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/0a1e35f6-255f-4701-b6ec-7e0a9e376c08"^^xsd:anyURI .
#
# CDs:Best_of_Horace_Silver
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Best of Horace Silver" ;
#         dcterms:creator                SoloMusicArtist:Horace_Silver ;
#         bibliographica:byArtist        SoloMusicArtist:Horace_Silver ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a2376094-1070-47ae-8fef-5aff84c95031"^^xsd:anyURI .
#
# CDs:Live_Japan  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live in Japan" ;
#         dcterms:creator                SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:byArtist        SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4cade5d8-6560-4487-b0b6-24770d2aadfe"^^xsd:anyURI .
#
# CDs:Win_This_Record  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Win This Record!" ;
#         dcterms:creator                SoloMusicArtist:David_Lindley ;
#         bibliographica:byArtist        SoloMusicArtist:David_Lindley ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/6cc7d654-1334-3a01-9cc0-71e1f4b49b0a"^^xsd:anyURI .
#
# CDs:Best_of_David_Bromberg
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Out of the Blues: The Best of David Bromberg" ;
#         dcterms:creator                SoloMusicArtist:David_Bromberg ;
#         bibliographica:byArtist        SoloMusicArtist:David_Bromberg ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/40c7238d-dd71-4542-863d-59e072225a6f"^^xsd:anyURI .
#
# CDs:Works  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Works" ;
#         dcterms:creator                SoloMusicArtist:Bill_Frisell ;
#         bibliographica:byArtist        SoloMusicArtist:Bill_Frisell ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/af1d4584-2aad-4344-b124-d8325efd8f2e"^^xsd:anyURI .
#
# CDs:Yelling_at_Mary  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Yelling at Mary" ;
#         dcterms:creator                SoloMusicArtist:Mary_Karlzen ;
#         bibliographica:byArtist        SoloMusicArtist:Mary_Karlzen ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ecff2e1a-6c7c-4660-816b-17faee96ba9b"^^xsd:anyURI .
#
# CDs:Thing_Fish  a                         schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Thing Fish" ;
#         dcterms:creator                SoloMusicArtist:Frank_Zappa ;
#         bibliographica:byArtist        SoloMusicArtist:Frank_Zappa ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a7b02d0c-71f7-4405-9d3a-27296e1356df"^^xsd:anyURI .
#
# CDs:Slice_o_Life  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Slice o Life: Bruce Cockburn Live Solo" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/c0a1e7f5-c3c1-3bfc-8b06-31c5996928b2"^^xsd:anyURI .
#
# CDs:Collection_CS  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "The Collection" ;
#         dcterms:creator                SoloMusicArtist:Cat_Stevens ;
#         bibliographica:byArtist        SoloMusicArtist:Cat_Stevens ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/cd1bc0a3-6732-4813-a509-a02cb6582d69"^^xsd:anyURI .
#
# CDs:This_Fire  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "This Fire" ;
#         dcterms:creator                SoloMusicArtist:Paula_Cole ;
#         bibliographica:byArtist        SoloMusicArtist:Paula_Cole ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3b487094-e321-4c3d-9633-872719d84d9b"^^xsd:anyURI .
#
# CDs:One_Quiet_Night  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "One Quiet Night" ;
#         dcterms:creator                SoloMusicArtist:Pat_Metheny ;
#         bibliographica:byArtist        SoloMusicArtist:Pat_Metheny ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/afaf7f86-3ec9-3bce-b58b-48231c57ed89"^^xsd:anyURI .
#
# CDs:Places  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Places" ;
#         dcterms:creator                SoloMusicArtist:Bela_Fleck ;
#         bibliographica:byArtist        SoloMusicArtist:Bela_Fleck ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/420c81ba-31a2-4475-8c8d-3dfa94a44985"^^xsd:anyURI .
#
# CDs:La_Mejor_Vida  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "La Mejor de la Vida" ;
#         dcterms:creator                SoloMusicArtist:Compay_Segundo ;
#         bibliographica:byArtist        SoloMusicArtist:Compay_Segundo ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bcfd6306-a3bf-43e0-9316-930fb50a869c"^^xsd:anyURI .
#
# CDs:Live_1973  a                          schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Live 1973" ;
#         dcterms:creator                SoloMusicArtist:Gram_Parsons ;
#         bibliographica:byArtist        SoloMusicArtist:Gram_Parsons ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ad696dc8-afec-432c-a7a0-3ec91a299560"^^xsd:anyURI .
#
# CDs:Heart_and_Soul  a                     schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Heart & Soul" ;
#         dcterms:creator                SoloMusicArtist:Joe_Cocker ;
#         bibliographica:byArtist        SoloMusicArtist:Joe_Cocker ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/39914131-4cbf-4102-bc2e-27b47fb087b4"^^xsd:anyURI .
#
# CDs:Workbook  a                           schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Workbook" ;
#         dcterms:creator                SoloMusicArtist:Bob_Mould ;
#         bibliographica:byArtist        SoloMusicArtist:Bob_Mould ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/1a547adc-c99e-4c55-87b1-5d7da769d743"^^xsd:anyURI .
#
# CDs:What_We_Did_Holidays
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "What We Did on Our Holidays" ;
#         dcterms:creator                MusicGroup:Fairport_Convention ;
#         bibliographica:byArtist        MusicGroup:Fairport_Convention ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/21e5d2c3-5223-4744-8d4d-a43ff3c3aa8b"^^xsd:anyURI .
#
# CDs:Its_Like_This  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "It's Like This" ;
#         dcterms:creator                SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:byArtist        SoloMusicArtist:Rickie_Lee_Jones ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/3066d8ca-115c-4b05-bc9b-565d0af415f3"^^xsd:anyURI .
#
# CDs:Stealing_Fire  a                      schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Stealing Fire" ;
#         dcterms:creator                SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:byArtist        SoloMusicArtist:Bruce_Cockburn ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/57fa6f1e-4a34-3bc5-9120-5afbbe1ae8a1"^^xsd:anyURI .
#
# CDs:Courage_My_Love  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Courage My Love" ;
#         dcterms:creator                SoloMusicArtist:Annie_Gallup ;
#         bibliographica:byArtist        SoloMusicArtist:Annie_Gallup ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a4603320-5599-4bc4-894e-b1d6cf523616"^^xsd:anyURI .
#
# CDs:Tell_It_Like_It_Is  a                 schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Tell It Like It T-I-Is" ;
#         dcterms:creator                MusicGroup:B_Fifty_Twos ;
#         bibliographica:byArtist        MusicGroup:B_Fifty_Twos ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a6876b95-aa4a-4ebc-8bed-1becf8f43d11"^^xsd:anyURI .
#
# CDs:Racine  a                             schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Racine" ;
#         dcterms:creator                SoloMusicArtist:Sass_Jordan ;
#         bibliographica:byArtist        SoloMusicArtist:Sass_Jordan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/db4ea45e-9905-45ae-959d-f07fbe2eced1"^^xsd:anyURI .
#
# CDs:Dicks_Picks_Vol_5  a                  schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Dick’s Picks, Volume 5: Oakland Auditorium Arena 12/26/79" ;
#         dcterms:creator                MusicGroup:Grateful_Dead ;
#         bibliographica:byArtist        MusicGroup:Grateful_Dead ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/b78e978e-0cef-47a8-89d1-627f648eae9c"^^xsd:anyURI .
#
# CDs:Sweet_Dreams  a                       schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Sweet Dreams: The Anthology" ;
#         dcterms:creator                SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:byArtist        SoloMusicArtist:Roy_Buchanan ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/4999fb78-a139-4b34-963f-e2deebbc6a58"^^xsd:anyURI .
#
# CDs:Genre  a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Genre" ;
#         dcterms:creator                SoloMusicArtist:Shona_Laing ;
#         bibliographica:byArtist        SoloMusicArtist:Shona_Laing ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/a72b0612-e0e7-4d7b-b90e-8cec19d32632"^^xsd:anyURI .
#
# CDs:Heart_of_the_Forest  a                schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Heart of the Forest" ;
#         dcterms:creator                MusicGroup:Baka_Beyond ;
#         bibliographica:byArtist        MusicGroup:Baka_Beyond ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/30258950-da8c-4b26-b3eb-42ab828e682d"^^xsd:anyURI .
#
# CDs:Become_What_Are  a                    schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Become What You Are" ;
#         dcterms:creator                SoloMusicArtist:Juliana_Hatfield ;
#         bibliographica:byArtist        SoloMusicArtist:Juliana_Hatfield ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/498e1991-8a25-4283-816e-01789040c05a"^^xsd:anyURI .
#
# CDs:Brilliant_Trees_Shaman
#         a                              schema:MusicAlbum , mo:Release , mo:Record , mo:CD ;
#         rdfs:label                     "Brilliant Trees/Words with the Shaman" ;
#         dcterms:creator                SoloMusicArtist:David_Sylvian ;
#         bibliographica:byArtist        SoloMusicArtist:David_Sylvian ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/bcf17be7-bb8d-4622-8b2c-df59a6424a8d"^^xsd:anyURI .
#
# }

# %% [markdown]
# #### eBooks

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
#     <http://www.connaissance.io/onto/biblio/ebooks>
#         a                    dctype:Dataset ;
#         dcterms:description  "eBook collection, cataloged and serialized in RDF. Links to WorldCat." ;
#         dcterms:modified     "2022-10-20" ;
#         schema:license       "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI , "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#         owl:imports          <http://www.connaissance.io/onto/biblio/authors> , <http://www.connaissance.io/onto/biblio/bibliographica> ;
#         owl:versionInfo      "Developed by M Lane" .
#
# ebooks:Great_House  a                     schema:Book ;
#         dcterms:creator             authors:Nicole_Krauss ;
#         dcterms:title               "Great House" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9781461814580" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1052654323.ttl"^^xsd:anyURI .
#
# ebooks:Spenser_31  a                      schema:Book ;
#         dcterms:creator             authors:Robert_B_Parker ;
#         dcterms:title               "Spenser 31 - Bad Business" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9781101204801" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/651627779.ttl"^^xsd:anyURI .
#
# ebooks:Dream_Hunter  a                    schema:Book ;
#         dcterms:creator             authors:Neil_Gaiman ;
#         dcterms:title               "The Dream Hunters" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "prc" ;
#         schema:isbn                 "9781779503350" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1126079844.ttl"^^xsd:anyURI .
#
# ebooks:Lottery  a                         schema:Book ;
#         dcterms:creator             authors:Shirley_Jackson ;
#         dcterms:title               "The Lottery" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9781479419579" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1127549199.ttl"^^xsd:anyURI .
#
# ebooks:Bridget_Joness_Diary
#         a                           schema:Book ;
#         dcterms:creator             authors:Helen_Fielding ;
#         dcterms:title               "Bridget Jones's Diary" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9782806281166" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/1162180053.ttl"^^xsd:anyURI .
#
# ebooks:Rain_Wilds_Chronicles_02
#         a                           schema:Book ;
#         dcterms:creator             authors:Robin_Hobb ;
#         dcterms:title               "Rain Wilds Chronicles 02 - Dragon Haven" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9780061993480" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/871347788.ttl"^^xsd:anyURI .
#
# ebooks:Vampire_Chronicles_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 02 - The Vampire Lestat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eat_Pray_Love  a              schema:Book ;
#         dcterms:creator        authors:Elizabeth_Gilbert ;
#         dcterms:title          "Eat, Pray, Love" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_11  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 11 - Last Precinct" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_13  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 13 - Micah" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_01  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 01 - One for the Money" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Runaway_Jury  a               schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Runaway Jury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blasphemy  a                  schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Blasphemy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_04  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 04 - Mort" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Death_Sentence  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Death Sentence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jane_Eyre  a                  schema:Book ;
#         dcterms:creator        authors:Charlotte_Bronte ;
#         dcterms:title          "Jane Eyre" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Firm   a                      schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Firm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Suffer_Children  a            schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Suffer The Children" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:In_Death_08  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 08 - Conspiracy in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_14  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 14 - Fearless Fourteen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_01  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 01 - Killing Floor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_13  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 13 - The Thirteen Gun Salute" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dress_Your_Family  a          schema:Book ;
#         dcterms:creator        authors:David_Sedaris ;
#         dcterms:title          "Dress Your Family in Corduroy and Denim" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_17  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 17 - Interesting Times" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Infinite_Jest  a              schema:Book ;
#         dcterms:creator        authors:David_Wallace ;
#         dcterms:title          "Infinite Jest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_07  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 07 - The Forsaken" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Misery  a                     schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Misery" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Greywalker_01  a              schema:Book ;
#         dcterms:creator        authors:Kat_Richardson ;
#         dcterms:title          "Greywalker 01 - Greywalker" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Art_of_War  a                 schema:Book ;
#         dcterms:creator        authors:Sun_Tzu ;
#         dcterms:title          "The Art of War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_14  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 14 - 61 Hours" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lions_Game  a                 schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "The Lion's Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prince_of_Nothing_02
#         a                      schema:Book ;
#         dcterms:creator        authors:R_Scott_Bakker ;
#         dcterms:title          "Prince of Nothing 02 - The Warrior Prophet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Of_Summer  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Dark Of Summer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Going_Rogue  a                schema:Book ;
#         dcterms:creator        authors:Sarah_Palin ;
#         dcterms:title          "Going Rogue" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dexter_02  a                  schema:Book ;
#         dcterms:creator        authors:Jeff_Lindsay ;
#         dcterms:title          "Dexter 02 - Dearly Devoted Dexter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beastchild2  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Beastchild" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Burning_Chrome  a             schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Burning Chrome" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_10  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 10 - Small Favor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_10
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 10 - Dead in the Family" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Devils_Kiss  a                schema:Book ;
#         dcterms:creator        authors:William_Johnstone ;
#         dcterms:title          "The Devil's Kiss" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Arms_of_Kali  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Arms of Kali" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:His_Dark_Materials_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Philip_Pullman ;
#         dcterms:title          "His Dark Materials 02 - The Subtle Knife" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Napalm_and_Silly_Putty
#         a                      schema:Book ;
#         dcterms:creator        authors:George_Carlin ;
#         dcterms:title          "Napalm and Silly Putty" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shopaholic_Ties_Knot
#         a                      schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Shopaholic Ties the Knot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Percy_Jackson_4  a            schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "Percy Jackson 4 - The Battle of the Labyrinth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Venetian_Betrayal  a          schema:Book ;
#         dcterms:creator        authors:Steve_Berry ;
#         dcterms:title          "The Venetian Betrayal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Blood_Risk  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Blood Risk" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Moby_Dick  a                  schema:Book ;
#         dcterms:creator        authors:Herman_Melville ;
#         dcterms:title          "Moby Dick" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rainbow_Six  a                schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "Rainbow Six" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Silver_Borne  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "Silver Borne" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gullivers_Travels  a          schema:Book ;
#         dcterms:creator        authors:Jonathan_Swift ;
#         dcterms:title          "Gulliver's Travels" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Coldfire  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Coldfire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Books_Of_Art_02  a            schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Books Of The Art 02 - Everville" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Ice_Hunt  a                   schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Ice Hunt" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Hyperion_Cantos_02  a         schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Hyperion Cantos 02 - The Fall of Hyperion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_07  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 07 - Lover Avenged" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eyes_of_Dragon  a             schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Eyes of the Dragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:K_Killer  a                   schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "K is for Killer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ghost_Road_Blues  a           schema:Book ;
#         dcterms:creator        authors:Jonathan_Maberry ;
#         dcterms:title          "Ghost Road Blues" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_10
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 10 - Blood Canticle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Burning  a                    schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Burning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Memoir_Kathy_Griffin
#         a                      schema:Book ;
#         dcterms:creator        authors:Kathy_Griffin ;
#         dcterms:title          "A Memoir According to Kathy Griffin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_03  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 03 - Immortal in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Chance_to_See  a         schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Last Chance to See" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Simple_Plan  a                schema:Book ;
#         dcterms:creator        authors:Scott_Smith ;
#         dcterms:title          "A Simple Plan" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_09  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 09 - Pale Demon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_of_Storm  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Night of the Storm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_12  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 12 - Witches Abroad" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Metamorphosis_Other_Stories
#         a                      schema:Book ;
#         dcterms:creator        authors:Franz_Kafka ;
#         dcterms:title          "The Metamorphosis and Other Stories" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_World_02  a           schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Vampire World 02 - Last Aerie" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Neverwhere  a                 schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Neverwhere" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_16  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 16 - Portrait in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_02  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 02 - Awakening" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Bend_in_Road  a               schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "A Bend in the Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ford_County  a                schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "Ford County" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_25  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 25 - The Truth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Song_of_Ice_and_Fire_03
#         a                      schema:Book ;
#         dcterms:creator        authors:George_RR_Martin ;
#         dcterms:title          "A Song of Ice and Fire 03 - A Storm of Swords" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_6  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 6 - Night Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Player_of_Games  a            schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "The Player of Games" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_29  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 29 - Kindred in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hyperion  a                   schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Hyperion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_06  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 06 - Angels Flight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pet_Sematary  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Pet Sematary" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Naked  a                      schema:Book ;
#         dcterms:creator        authors:David_Sedaris ;
#         dcterms:title          "Naked" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_Yesterday  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Lost Yesterday" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_38  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 38 - I Shall Wear Midnight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Can_You_Keep_a_Secret
#         a                      schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Can You Keep a Secret" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Da_Vinci_Code2  a             schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "The Da Vinci Code" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Year_of_Living_Biblically
#         a                      schema:Book ;
#         dcterms:creator        authors:AJ_Jacobs ;
#         dcterms:title          "The Year of Living Biblically" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Henry_Thompson_01  a          schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Henry Thompson 01 - Caught Stealing" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jennifer_Government  a        schema:Book ;
#         dcterms:creator        authors:Max_Barry ;
#         dcterms:title          "Jennifer Government" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Super_Fetus  a                schema:Book ;
#         dcterms:creator        authors:Adam_Pepper ;
#         dcterms:title          "Super Fetus" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Faithful_Place  a             schema:Book ;
#         dcterms:creator        authors:Tana_French ;
#         dcterms:title          "Faithful Place" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_08  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 08 - The Wheel of Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Shattered  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Shattered" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bonfire_of_Vanities  a        schema:Book ;
#         dcterms:creator        authors:Tom_Wolfe ;
#         dcterms:title          "Bonfire of the Vanities" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Perdido_Street_Station
#         a                      schema:Book ;
#         dcterms:creator        authors:China_Mieville ;
#         dcterms:title          "Perdido Street Station" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gold_Coast  a                 schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "The Gold Coast" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Roses_Are_Red  a              schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Roses Are Red" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Helmet_for_My_Pillow
#         a                      schema:Book ;
#         dcterms:creator        authors:Robert_Leckie ;
#         dcterms:title          "Helmet for My Pillow, From Parris Island to the Pacific" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hedge_Knight  a               schema:Book ;
#         dcterms:creator        authors:George_RR_Martin ;
#         dcterms:title          "The Hedge Knight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Power_of_Now  a               schema:Book ;
#         dcterms:creator        authors:Eckhart_Tolle ;
#         dcterms:title          "The Power of Now" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tara_Road  a                  schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Tara Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:L_Lawless  a                  schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "L is for Lawless" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Known_and_Unknown  a          schema:Book ;
#         dcterms:creator        authors:Donald_Rumsfeld ;
#         dcterms:title          "Known and Unknown" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blind_Side  a                 schema:Book ;
#         dcterms:creator        authors:Michael_Lewis ;
#         dcterms:title          "The Blind Side" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Neuromancer  a                schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Neuromancer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_09  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 09 - Chainfire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prayer_for_Owen_Meany
#         a                      schema:Book ;
#         dcterms:creator        authors:John_Irving ;
#         dcterms:title          "A Prayer for Owen Meany" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Imperial_Bedrooms  a          schema:Book ;
#         dcterms:creator        authors:Bret_Easton_Ellis ;
#         dcterms:title          "Imperial Bedrooms" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tale_of_Two_Cities  a         schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "A Tale of Two Cities" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lord_of_Rings_02  a           schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Lord of the Rings 02 - The Two Towers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Postman  a                    schema:Book ;
#         dcterms:creator        authors:David_Brin ;
#         dcterms:title          "The Postman" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_02  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 02 - Lover Eternal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Lord_of_Flies  a              schema:Book ;
#         dcterms:creator        authors:William_Golding ;
#         dcterms:title          "Lord of the Flies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_06
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 06 - The Ersatz Elevator" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Green_Mile  a                 schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Green Mile" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mistborn_01  a                schema:Book ;
#         dcterms:creator        authors:Brandon_Sanderson ;
#         dcterms:title          "Mistborn 01 - Mistborn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Belgariad_05  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Belgariad 05 - Enchanter's End Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Leaves_of_Grass  a            schema:Book ;
#         dcterms:creator        authors:Walt_Whitman ;
#         dcterms:title          "Leaves of Grass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unfinished_Tales_of_Middle
#         a                      schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "Unfinished Tales of Middle Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Clockwork_Orange  a           schema:Book ;
#         dcterms:creator        authors:Anthony_Burgess ;
#         dcterms:title          "A Clockwork Orange" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mystic_River  a               schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "Mystic River" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_05  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 05 - Dominion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Life_of_Pi  a                 schema:Book ;
#         dcterms:creator        authors:Yann_Martel ;
#         dcterms:title          "Life of Pi" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Inheritance_Cycle_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Christopher_Paolini ;
#         dcterms:title          "The Inheritance Cycle 01 - Eragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Tower_03  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 03 - The Waste Lands" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_World  a                 schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "The Lost World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:AntiMan2  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Anti-Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:River_Marked  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "River Marked" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kingdom_Besieged  a           schema:Book ;
#         dcterms:creator        authors:Raymond_E_Feist ;
#         dcterms:title          "A Kingdom Besieged" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_04  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 04 - A Fistful of Charms" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Love_in_Time_of_Cholera
#         a                      schema:Book ;
#         dcterms:creator        authors:Gabriel_Marquez ;
#         dcterms:title          "Love in the Time of Cholera" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Othello  a                    schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "Othello" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Shift  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Night Shift" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_11  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 11 - Judgment in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Invasion  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Invasion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Decision_Points  a            schema:Book ;
#         dcterms:creator        authors:George_W_Bush ;
#         dcterms:title          "Decision Points" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_20  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 20 - Hogfather" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_02  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 02 - Dune Messiah" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:61_Hours  a                   schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "61 Hours" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_1  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 1 - Rules of Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ilium  a                      schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Ilium" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Troubled_Waters  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Troubled Waters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Glass_Castle  a               schema:Book ;
#         dcterms:creator        authors:Jeannette_Walls ;
#         dcterms:title          "The Glass Castle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_24  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 24 - Innocent in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_10  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 10 - The Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Serial_Uncut  a               schema:Book ;
#         dcterms:creator        authors:JA_Konrath ;
#         dcterms:title          "Serial (Uncut)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Grimms_Fairy_Tales  a         schema:Book ;
#         dcterms:creator        authors:Wilhelm_Grimm ;
#         dcterms:title          "Grimm's Fairy Tales" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_01  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 01 - The Black Echo" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_33  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 33 - Going Postal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Common_Sense_and_Rights_of_Man
#         a                      schema:Book ;
#         dcterms:creator        authors:Thomas_Paine ;
#         dcterms:title          "Common Sense and The Rights of Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Glamorama  a                  schema:Book ;
#         dcterms:creator        authors:Bret_Easton_Ellis ;
#         dcterms:title          "Glamorama" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lullaby  a                    schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Lullaby" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Velocity  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Velocity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fear_Nothing  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Fear Nothing" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cry_for_Strangers  a          schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Cry for the Strangers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Hour_I_First_Believed
#         a                      schema:Book ;
#         dcterms:creator        authors:Wally_Lamb ;
#         dcterms:title          "The Hour I First Believed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jason_Bourne_01  a            schema:Book ;
#         dcterms:creator        authors:Robert_Ludlum ;
#         dcterms:title          "Jason Bourne 01 - The Bourne Identity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_03  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 03 - The Cabinent of Curiosities" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Satanic_Verses  a             schema:Book ;
#         dcterms:creator        authors:Salman_Rushdie ;
#         dcterms:title          "The Satanic Verses" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_14  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 14 - 9 Dragons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ivanhoe  a                    schema:Book ;
#         dcterms:creator        authors:Walter_Scott ;
#         dcterms:title          "Ivanhoe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Under_Banner_of_Heaven
#         a                      schema:Book ;
#         dcterms:creator        authors:Jon_Krakauer ;
#         dcterms:title          "Under the Banner of Heaven" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Less_Than_Zero  a             schema:Book ;
#         dcterms:creator        authors:Bret_Easton_Ellis ;
#         dcterms:title          "Less Than Zero" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:My_Antonia  a                 schema:Book ;
#         dcterms:creator        authors:Willa_Cather ;
#         dcterms:title          "My Antonia" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Atlas_Shrugged  a             schema:Book ;
#         dcterms:creator        authors:Ayn_Rand ;
#         dcterms:title          "Atlas Shrugged" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wolf_Hall  a                  schema:Book ;
#         dcterms:creator        authors:Hilary_Mantel ;
#         dcterms:title          "Wolf Hall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unbearable_Lightness
#         a                      schema:Book ;
#         dcterms:creator        authors:Portia_de_Rossi ;
#         dcterms:title          "Unbearable Lightness, A Story of Loss and Gain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bright_Shiny_Morning
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Frey ;
#         dcterms:title          "Bright Shiny Morning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Columbine  a                  schema:Book ;
#         dcterms:creator        authors:Dave_Cullen ;
#         dcterms:title          "Columbine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_04  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 04 - Temple of the Winds" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Digital_Fortress  a           schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Digital Fortress" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Great_and_Secret_Show
#         a                      schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "The Great and Secret Show" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Interpreter_of_Maladies
#         a                      schema:Book ;
#         dcterms:creator        authors:Jhumpa_Lahiri ;
#         dcterms:title          "Interpreter of Maladies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:To_Kill_a_Mockingbird
#         a                      schema:Book ;
#         dcterms:creator        authors:Harper_Lee ;
#         dcterms:title          "To Kill a Mockingbird" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Middlesex  a                  schema:Book ;
#         dcterms:creator        authors:Jeffrey_Eugenides ;
#         dcterms:title          "Middlesex" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 01 - The Bad Beginning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ignored  a                    schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Ignored" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Odd_Thomas_03  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Odd Thomas 03 - Brother Odd" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Of_Mice_and_Men  a            schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "Of Mice and Men" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jungle  a                     schema:Book ;
#         dcterms:creator        authors:Upton_Sinclair ;
#         dcterms:title          "The Jungle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Farewell_to_Arms  a           schema:Book ;
#         dcterms:creator        authors:Ernest_Hemingway ;
#         dcterms:title          "A Farewell to Arms" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Second_Child  a               schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Second Child" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Sigma_Force_06  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 06 - The Doomsday Key" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:B_Burglar  a                  schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "B is for Burglar" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Paris_Wife  a                 schema:Book ;
#         dcterms:creator        authors:Paula_McLain ;
#         dcterms:title          "The Paris Wife" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Farseer_Trilogy_02  a         schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Farseer Trilogy 02 - Royal Assassin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blindness  a                  schema:Book ;
#         dcterms:creator        authors:Jose_Saramago ;
#         dcterms:title          "Blindness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dirk_Gently_01  a             schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Dirk Gently 01 - Dirk Gently's Holistic Detective Agency" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Darkness  a                   schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Safe_Haven  a                 schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "Safe Haven" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_Hero  a                  schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "The Lost Hero" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_04  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 04 - Children of the Mind" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Perfect_Storm  a              schema:Book ;
#         dcterms:creator        authors:Sebastian_Junger ;
#         dcterms:title          "The Perfect Storm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Iron_Kissed  a                schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "Iron Kissed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Time_Travelers_Wife  a        schema:Book ;
#         dcterms:creator        authors:Audrey_Niffenegger ;
#         dcterms:title          "The Time Traveler's Wife" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_32  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 32 - Treachery in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pitt_2  a                 schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Joe Pitt 2 - No Dominion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_06  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 06 - Looking for Rachel Wallace" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Relentless  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Relentless" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:John_Adams  a                 schema:Book ;
#         dcterms:creator        authors:David_McCullough ;
#         dcterms:title          "John Adams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beach_House  a                schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "The Beach House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Seventh_Stone  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Seventh Stone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rabbit_02  a                  schema:Book ;
#         dcterms:creator        authors:John_Updike ;
#         dcterms:title          "Rabbit 02 - Rabbit Redux" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crying_of_Lot_49  a           schema:Book ;
#         dcterms:creator        authors:Thomas_Pynchon ;
#         dcterms:title          "The Crying of Lot 49" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Armor  a                      schema:Book ;
#         dcterms:creator        authors:John_Steakley ;
#         dcterms:title          "Armor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_19  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 19 - Double Deuce" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Packing_for_Mars  a           schema:Book ;
#         dcterms:creator        authors:Mary_Roach ;
#         dcterms:title          "Packing for Mars" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Time_Thieves  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Time Thieves" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eating_Animals  a             schema:Book ;
#         dcterms:creator        authors:Jonathan_Safran_Foer ;
#         dcterms:title          "Eating Animals" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_01  a                schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "Twilight 01 - Twilight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:E_Evidence  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "E is for Evidence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fever_Pitch  a                schema:Book ;
#         dcterms:creator        authors:Nick_Hornby ;
#         dcterms:title          "Fever Pitch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wise_Blood  a                 schema:Book ;
#         dcterms:creator        authors:Flannery_OConnor ;
#         dcterms:title          "Wise Blood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foucaults_Pendulum  a         schema:Book ;
#         dcterms:creator        authors:Umberto_Eco ;
#         dcterms:title          "Foucault's Pendulum" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bad_Moon_Rising  a            schema:Book ;
#         dcterms:creator        authors:Jonathan_Maberry ;
#         dcterms:title          "Bad Moon Rising" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_08  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 08 - L.A. Requiem" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_15  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 15 - Hidden Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Imperfectionists  a           schema:Book ;
#         dcterms:creator        authors:Tom_Rachman ;
#         dcterms:title          "The Imperfectionists" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lust_Lizard_Melancholy_Cove
#         a                      schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "The Lust Lizard of Melancholy Cove" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:My_Sisters_Keeper  a          schema:Book ;
#         dcterms:creator        authors:Jodi_Picoult ;
#         dcterms:title          "My Sister's Keeper" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Store  a                      schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Store" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Something_Wicked  a           schema:Book ;
#         dcterms:creator        authors:Ray_Bradbury ;
#         dcterms:title          "Something Wicked This Way Comes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_05  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 05 - Deadspawn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Win_Friends_Influence_People
#         a                      schema:Book ;
#         dcterms:creator        authors:Dale_Carnegie ;
#         dcterms:title          "How To Win Friends and Influence People" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_09
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 09 - Dust of Dreams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sigma_Force_01  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 01 - Sandstorm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malloreon_01  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Malloreon 01 - Guardians of the West" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Born_Standing_Up_A_Comics_Life
#         a                      schema:Book ;
#         dcterms:creator        authors:Steve_Martin ;
#         dcterms:title          "Born Standing Up, A Comic's Life" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Coldheart_Canyon  a           schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Coldheart Canyon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Count_of_Monte_Cristo
#         a                      schema:Book ;
#         dcterms:creator        authors:Alexandre_Dumas ;
#         dcterms:title          "The Count of Monte Cristo" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:ebook_1776  a                 schema:Book ;
#         dcterms:creator        authors:David_McCullough ;
#         dcterms:title          "1776" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Da_Vinci_Code  a              schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "The Da Vinci Code" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Gun_Seller  a                 schema:Book ;
#         dcterms:creator        authors:Hugh_Laurie ;
#         dcterms:title          "The Gun Seller" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Glass_Lake  a                 schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "The Glass Lake" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Persuasion  a                 schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Persuasion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_09  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 09 - Winter's Heart" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Four-Hour_Body  a             schema:Book ;
#         dcterms:creator        authors:Tim_Ferriss ;
#         dcterms:title          "The 4-Hour Body" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Giver  a                      schema:Book ;
#         dcterms:creator        authors:Lois_Lowry ;
#         dcterms:title          "The Giver" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crash  a                      schema:Book ;
#         dcterms:creator        authors:JG_Ballard ;
#         dcterms:title          "Crash" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:U_Undertow  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "U is for Undertow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dreamlands_Hero_Of_Dreams
#         a                      schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Dreamlands 1 - Hero Of Dreams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Thirteenth_Tale  a            schema:Book ;
#         dcterms:creator        authors:Diane_Setterfield ;
#         dcterms:title          "The Thirteenth Tale" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Heart-Shaped_Box  a           schema:Book ;
#         dcterms:creator        authors:Joe_Hill ;
#         dcterms:title          "Heart-Shaped Box" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:How_to_Beat_Up_Anybody
#         a                      schema:Book ;
#         dcterms:creator        authors:Judah_Friedlander ;
#         dcterms:title          "How to Beat Up Anybody" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shane_Schofield_03  a         schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Shane Schofield 03 - Scarecrow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Rose_Madder  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Rose Madder" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Magicians  a                  schema:Book ;
#         dcterms:creator        authors:Lev_Grossman ;
#         dcterms:title          "The Magicians" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eating_Dinosaur  a            schema:Book ;
#         dcterms:creator        authors:Chuck_Klosterman ;
#         dcterms:title          "Eating the Dinosaur" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Altar_of_Eden  a              schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Altar of Eden" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Takeshi_Kovacs_03  a          schema:Book ;
#         dcterms:creator        authors:Richard_Morgan ;
#         dcterms:title          "Takeshi Kovacs 03 - Woken Furies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_01  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 01 - The Godwulf Manuscript" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Age_of_Innocence  a           schema:Book ;
#         dcterms:creator        authors:Edith_Wharton ;
#         dcterms:title          "The Age of Innocence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:They_Thirst  a                schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "They Thirst" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Jack_and_Jill  a              schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Jack and Jill" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Night_in_Twisted_River
#         a                      schema:Book ;
#         dcterms:creator        authors:John_Irving ;
#         dcterms:title          "Last Night in Twisted River" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Little_Earthquakes  a         schema:Book ;
#         dcterms:creator        authors:Jennifer_Weiner ;
#         dcterms:title          "Little Earthquakes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elizabeth_Street  a           schema:Book ;
#         dcterms:creator        authors:Laurie_Fabiano ;
#         dcterms:title          "Elizabeth Street" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fairy_Tales  a                schema:Book ;
#         dcterms:creator        authors:Hans_Christian_Andersen ;
#         dcterms:title          "Fairy Tales" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_14  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 14 - Pale Kings and Princes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Backwoods  a                  schema:Book ;
#         dcterms:creator        authors:Edward_Lee ;
#         dcterms:title          "The Backwoods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Hitchhiker_04  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Hitchhiker 04 - So Long, and Thanks For All the Fish" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wolfs_Hour  a                 schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "The Wolfs Hour" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Spenser_27  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 27 - Hugger Mugger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Made_in_America  a            schema:Book ;
#         dcterms:creator        authors:Bill_Bryson ;
#         dcterms:title          "Made in America" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chronicles_of_Narnia_07
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 07 - The Last Battle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nineteen_Minutes  a           schema:Book ;
#         dcterms:creator        authors:Jodi_Picoult ;
#         dcterms:title          "Nineteen Minutes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Year_of_Flood  a              schema:Book ;
#         dcterms:creator        authors:Margaret_Atwood ;
#         dcterms:title          "The Year of the Flood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_Eyes2  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Twilight Eyes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Elvis_Cole_03  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 03 - Lullaby Town" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Witch_and_Wizard  a           schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Witch and Wizard" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_10  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 10 - Certain Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Client  a                     schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Client" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Know_It_All  a                schema:Book ;
#         dcterms:creator        authors:AJ_Jacobs ;
#         dcterms:title          "Know-It-All" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kiss_Girls  a                 schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Kiss the Girls" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Skipping_Christmas  a         schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "Skipping Christmas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pike_01  a                schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Joe Pike 01 - The Watchman" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Catch22  a                    schema:Book ;
#         dcterms:creator        authors:Joseph_Heller ;
#         dcterms:title          "Catch-22" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:All_Pretty_Horses  a          schema:Book ;
#         dcterms:creator        authors:Cormac_McCarthy ;
#         dcterms:title          "All the Pretty Horses" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jurassic_Park  a              schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Jurassic Park" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mine   a                      schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Mine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Scarpetta_07  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 07 - Cause of Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_09  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 09 - Obsidian Butterfly" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Postman_Always_Rings_Twice
#         a                      schema:Book ;
#         dcterms:creator        authors:James_M_Cain ;
#         dcterms:title          "The Postman Always Rings Twice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Your_Heart_Belongs_to_Me
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Your Heart Belongs to Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_04
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 04 - House of Chains" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Final_Crusade  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Final Crusade" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deadly_Genes  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Deadly Genes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Inversions  a                 schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Inversions" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Confession  a                 schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Confession" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hannibal_02  a                schema:Book ;
#         dcterms:creator        authors:Thomas_Harris ;
#         dcterms:title          "Hannibal 02 - The Silence of the Lambs" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_09  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 09 - Treason's Harbour" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cradle_and_All  a             schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Cradle and All" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_Collection
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "A Malazan Book of the Fallen Collection" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vision  a                     schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Vision" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:V      a                      schema:Book ;
#         dcterms:creator        authors:Thomas_Pynchon ;
#         dcterms:title          "V" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hunger_Games_02  a            schema:Book ;
#         dcterms:creator        authors:Suzanne_Collins ;
#         dcterms:title          "The Hunger Games 02 - Catching Fire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mickey_Haller_03  a           schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Mickey Haller 03 - The Reversal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex_Alera_04  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 04 - Captain's Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Audacity_of_Hope  a           schema:Book ;
#         dcterms:creator        authors:Barack_Obama ;
#         dcterms:title          "The Audacity of Hope" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Reading_Like_a_Writer
#         a                      schema:Book ;
#         dcterms:creator        authors:Francine_Prose ;
#         dcterms:title          "Reading Like a Writer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_06  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 06 - High Profile" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Resident_Evil_06  a           schema:Book ;
#         dcterms:creator        authors:SD_Perry ;
#         dcterms:title          "Resident Evil 06 - Code Veronica" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Squirrel_Seeks_Chipmunk
#         a                      schema:Book ;
#         dcterms:creator        authors:David_Sedaris ;
#         dcterms:title          "Squirrel Seeks Chipmunk" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scanner_Darkly  a             schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "A Scanner Darkly" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Void_Moon  a                  schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Void Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex  a                      schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "The Codex" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Words  a                 schema:Book ;
#         dcterms:creator        authors:George_Carlin ;
#         dcterms:title          "Last Words" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shadowfires  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Shadowfires" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Day_Off  a                    schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Day Off" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Graveyard_Book  a             schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "The Graveyard Book" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_04  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 04 - The Shadow Rising" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:At_First_Sight  a             schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "At First Sight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Surrounded  a                 schema:Book ;
#         dcterms:creator        authors:Brian_Coffey ;
#         dcterms:title          "Surrounded" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_07  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 07 - Forward the Foundation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Santas_Twin  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Santa's Twin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cleopatra  a                  schema:Book ;
#         dcterms:creator        authors:Stacy_Schiff ;
#         dcterms:title          "Cleopatra" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_04  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 04 - The Plains of Passage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deadeye_Dick  a               schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Deadeye Dick" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bamboo_Dragon  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Bamboo Dragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hunchback_of_Notre_Dame
#         a                      schema:Book ;
#         dcterms:creator        authors:Victor_Hugo ;
#         dcterms:title          "The Hunchback of Notre Dame" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_06  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 06 - Blood Rites" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_06
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 06 - Definitely Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hanging_On  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Hanging On" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wrong_Stuff  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Wrong Stuff" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Baroque_Cycle_01  a           schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "The Baroque Cycle 01 - Quicksilver" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aesops_Fables  a              schema:Book ;
#         dcterms:creator        authors:Aesop ;
#         dcterms:title          "Aesop's Fables" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Adventures_of_Tom_Sawyer
#         a                      schema:Book ;
#         dcterms:creator        authors:Mark_Twain ;
#         dcterms:title          "The Adventures of Tom Sawyer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mist   a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Mist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Key_To_Midnight  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Key To Midnight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_04  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 04 - Harry Potter and the Goblet Of Fire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Chance_Saloon  a         schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Last Chance Saloon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nights_in_Rodanthe  a         schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "Nights in Rodanthe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Next   a                      schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Next" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bachman_Books_Complete
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Bachman Books (Complete)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tawny_Man_01  a               schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Tawny Man 01 - Fool's Errand" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_22  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 22 - Thin Air" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gentlemen_Bastards_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Scott_Lynch ;
#         dcterms:title          "Gentlemen Bastards 02 - Red Seas Under Red Skies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Henry_IV_Pt_2  a              schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "Henry IV (Part 2)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chronicles_of_Narnia_02
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 02 - Prince Caspian" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unite_and_Conquer  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Unite and Conquer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Servants_Of_Twilight
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Servants Of Twilight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_35  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 35 - Now and Then" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blood_Lust  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Blood Lust" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_02  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 02 - Body of Evidence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:LT_Theory_of_Pets  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "L.T.'s Theory of Pets" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_11  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 11 - Chasing Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_07  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 07 - Swallowing Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shotgun_Rule  a               schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "The Shotgun Rule" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_04  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 04 - The Lunatic Cafe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fountainhead  a               schema:Book ;
#         dcterms:creator        authors:Ayn_Rand ;
#         dcterms:title          "The Fountainhead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Legend_of_Sleepy_Hollow
#         a                      schema:Book ;
#         dcterms:creator        authors:Washington_Irving ;
#         dcterms:title          "The Legend of Sleepy Hollow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Adventures_of_Tom_Bomb
#         a                      schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Adventures of Tom Bomb" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_06
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 06 - The Vampire Armand" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hellfire  a                   schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Hellfire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Plum_Lovin  a                 schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Plum Lovin'" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_15  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 15 - Book of the Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_17  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 17 - Skin Trade" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_05  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 05 - High Five" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Choke  a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Choke" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Moon_Is_Harsh_Mistress
#         a                      schema:Book ;
#         dcterms:creator        authors:Robert_A_Heinlein ;
#         dcterms:title          "The Moon Is a Harsh Mistress" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tishomingo_Blue  a            schema:Book ;
#         dcterms:creator        authors:Elmore_Leonard ;
#         dcterms:title          "Tishomingo Blue" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_04  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 04 - The Mauritius Command" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Greatest_Show_on_Earth
#         a                      schema:Book ;
#         dcterms:creator        authors:Richard_Dawkins ;
#         dcterms:title          "The Greatest Show on Earth, The Evidence for Evolution" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_08  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 08 - Guards! Guards!" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Women  a                      schema:Book ;
#         dcterms:creator        authors:Charles_Bukowski ;
#         dcterms:title          "Women" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_01  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 01 - Night Passage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Man_in_High_Castle  a         schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "The Man in the High Castle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_05  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 05 - Echo Burning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tipping_Point  a              schema:Book ;
#         dcterms:creator        authors:Malcolm_Gladwell ;
#         dcterms:title          "The Tipping Point, How Little Things Can Make a Big Difference" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_17  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 17 - The Commodore" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Identity_Crisis  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Identity Crisis" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Starblood  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Starblood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chrysalids  a                 schema:Book ;
#         dcterms:creator        authors:John_Wyndham ;
#         dcterms:title          "The Chrysalids" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sacrament  a                  schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Sacrament" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Desperation  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Desperation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_02  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 02 - Foundation and Empire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_01  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 01 - Storm Front" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_12  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 12 - The Gathering Storm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Inca_Gold  a                  schema:Book ;
#         dcterms:creator        authors:Clive_Cussler ;
#         dcterms:title          "Inca Gold" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Princess_Bride  a             schema:Book ;
#         dcterms:creator        authors:William_Golding ;
#         dcterms:title          "The Princess Bride" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_West_02  a               schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Jack West 02 - The Six Sacred Stones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Sookie_Stackhouse_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 01 - Dead Until Dark" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ghost_in_Machine  a           schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Ghost in the Machine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Summer_of_Night  a            schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Summer of Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Monarch  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Last Monarch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Man_in_Iron_Mask  a           schema:Book ;
#         dcterms:creator        authors:Alexandre_Dumas ;
#         dcterms:title          "The Man in the Iron Mask" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Alexandria_Link  a            schema:Book ;
#         dcterms:creator        authors:Steve_Berry ;
#         dcterms:title          "The Alexandria Link" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Guernsey_Literary_Society
#         a                      schema:Book ;
#         dcterms:creator        authors:Mary_Ann_Shaffer ;
#         dcterms:title          "The Guernsey Literary and Potato Peel Pie Society" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kings_Ransom  a               schema:Book ;
#         dcterms:creator        authors:James_Grippando ;
#         dcterms:title          "A King's Ransom" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Finn_Ryan_04  a               schema:Book ;
#         dcterms:creator        authors:Christopher_Paul ;
#         dcterms:title          "Finn Ryan 04 - The Aztec Heresy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Spenser_30  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 30 - Back Story" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Zeitoun  a                    schema:Book ;
#         dcterms:creator        authors:Dave_Eggers ;
#         dcterms:title          "Zeitoun" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Thief_of_Always  a            schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "The Thief of Always" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Meredith_Gentry_02  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 02 - A Caress of Twilight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Narrative_of_Frederick_Douglass
#         a                      schema:Book ;
#         dcterms:creator        authors:Frederick_Douglass ;
#         dcterms:title          "Narrative of the Life of Frederick Douglass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rain_Wilds_Chronicles_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "Rain Wilds Chronicles 01 - Dragon Keeper" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 01 - Interview with the Vampire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Return_Engagement  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Return Engagement" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fear_That_Man  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Fear That Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rain_of_Terror  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Rain of Terror" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_10  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 10 - Black Notice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_12  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 12 - Incubus Dreams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Old_Man_and_Sea  a            schema:Book ;
#         dcterms:creator        authors:Ernest_Hemingway ;
#         dcterms:title          "The Old Man and the Sea" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_03  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 03 - Equal Rites" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Survivor  a                   schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Survivor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_07  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 07 - Holiday in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Firestarter  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Firestarter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_13  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 13 - Lean Mean Thirteen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Art_of_Racing_in_Rain
#         a                      schema:Book ;
#         dcterms:creator        authors:Garth_Stein ;
#         dcterms:title          "The Art of Racing in the Rain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_12  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 12 - The Letter Of Marque" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_16  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 16 - Soul Music" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Innocent_Man  a               schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Innocent Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Grand_Design  a               schema:Book ;
#         dcterms:creator        authors:Stephen_Hawking ;
#         dcterms:title          "The Grand Design" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_06  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 06 - The Damned" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachels_Holiday  a            schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Rachel's Holiday" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_13  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 13 - Gone Tomorrow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sacred_Vault  a               schema:Book ;
#         dcterms:creator        authors:Andy_McDermott ;
#         dcterms:title          "The Sacred Vault" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Prince_of_Nothing_01
#         a                      schema:Book ;
#         dcterms:creator        authors:R_Scott_Bakker ;
#         dcterms:title          "Prince of Nothing 01 - The Darkness That Comes Before" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_29  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 29 - Night Watch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dexter_01  a                  schema:Book ;
#         dcterms:creator        authors:Jeff_Lindsay ;
#         dcterms:title          "Dexter 01 - Darkly Dreaming Dexter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Angels_Game  a                schema:Book ;
#         dcterms:creator        authors:Carlos_Zafon ;
#         dcterms:title          "The Angel's Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Thinner  a                    schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Thinner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Boat  a                 schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "The Night Boat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Symphony  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Dark Symphony" , "Dark Symphony" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Temple  a                     schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Temple" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Notebook  a                   schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "The Notebook" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Chills  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Night Chills" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Invisible_Monsters  a         schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Invisible Monsters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:His_Dark_Materials_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Philip_Pullman ;
#         dcterms:title          "His Dark Materials 01 - The Golden Compass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Maze_of_Worlds  a             schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Maze of Worlds" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Appeal  a                     schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Appeal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:From_a_Buick_8  a             schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "From a Buick 8" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Third_Degree  a               schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "3rd Degree" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Romeo_and_Juliet  a           schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "Romeo and Juliet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Percy_Jackson_3  a            schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "Percy Jackson 3 - The Titan's Curse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tortilla_Flat  a              schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "Tortilla Flat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Three_Musketeers  a           schema:Book ;
#         dcterms:creator        authors:Alexandre_Dumas ;
#         dcterms:title          "The Three Musketeers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Robinson_Crusoe  a            schema:Book ;
#         dcterms:creator        authors:Daniel_Defoe ;
#         dcterms:title          "Robinson Crusoe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fall_of_Giants  a             schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "Fall of Giants" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:It     a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "It" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hyperion_Cantos_01  a         schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Hyperion Cantos 01 - Hyperion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_06  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 06 - Lover Enshrined" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Look_to_Windward  a           schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Look to Windward" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Infidel  a                    schema:Book ;
#         dcterms:creator        authors:Ayaan_Hirsi_Ali ;
#         dcterms:title          "Infidel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nightshade  a                 schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Nightshade" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:American_Gods  a              schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "American Gods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Day_of_Triffids  a            schema:Book ;
#         dcterms:creator        authors:John_Wyndham ;
#         dcterms:title          "The Day of the Triffids" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Room   a                      schema:Book ;
#         dcterms:creator        authors:Emma_Donoghue ;
#         dcterms:title          "Room" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pride_and_Prejudice  a        schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Pride and Prejudice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Tower_07  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 07 - The Dark Tower" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lake_House  a                 schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "The Lake House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_09  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 09 - A Sharpness on the Neck" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Return  a                     schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Return" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:In_Death_02  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 02 - Glory in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Alchemist  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Last Alchemist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Catcher_in_Rye  a             schema:Book ;
#         dcterms:creator        authors:JD_Salinger ;
#         dcterms:title          "The Catcher in the Rye" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:H_Homicide  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "H is for Homicide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_08  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 08 - Black Magic Sanction" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cats_Cradle  a                schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Cat's Cradle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_11  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 11 - Reaper Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Umneys_Last_Case  a           schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Umney's Last Case" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_World_01  a           schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Vampire World 01 - Blood Brothers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Failing_Marks  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Failing Marks" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_01  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 01 - Minion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:In_Death_15  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 15 - Purity in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hunt_for_Red_October
#         a                      schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "The Hunt for Red October" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_20  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 20 - Blue at the Mizzen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarecrow  a                  schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "The Scarecrow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_06  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 06 - Chapterhouse Dune" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_24  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 24 - The Fifth Elephant" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Song_of_Ice_and_Fire_02
#         a                      schema:Book ;
#         dcterms:creator        authors:George_RR_Martin ;
#         dcterms:title          "A Song of Ice and Fire 02 - A Clash of Kings" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_5  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 5 - Winter Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_28  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 28 - Promises in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Encyclopedia_Of_Fantasy
#         a                      schema:Book ;
#         dcterms:creator        authors:Don_DAmmassa ;
#         dcterms:title          "Encyclopedia Of Fantasy And Horror Fiction" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Carrion_Comfort  a            schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Carrion Comfort" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_05  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 05 - Trunk Music" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_37  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 37 - Unseen Academicals" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cloud_Atlas  a                schema:Book ;
#         dcterms:creator        authors:David_Mitchell ;
#         dcterms:title          "Cloud Atlas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Right_Stuff  a                schema:Book ;
#         dcterms:creator        authors:Tom_Wolfe ;
#         dcterms:title          "The Right Stuff" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Selfish_Gene  a               schema:Book ;
#         dcterms:creator        authors:Richard_Dawkins ;
#         dcterms:title          "The Selfish Gene" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shit_My_Dad_Says  a           schema:Book ;
#         dcterms:creator        authors:Justin_Halpern ;
#         dcterms:title          "Shit My Dad Says" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_07  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 07 - The Book of the Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:We_Three  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "We Three" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sue_Me  a                     schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Sue Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:My_Life  a                    schema:Book ;
#         dcterms:creator        authors:Bill_Clinton ;
#         dcterms:title          "My Life" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Salems_Lot  a                 schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Salem's Lot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hostile_Takeover  a           schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Hostile Takeover" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Life   a                      schema:Book ;
#         dcterms:creator        authors:Keith_Richards ;
#         dcterms:title          "Life" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:An_Old_Fashioned_War
#         a                      schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "An Old Fashioned War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:House_of_Mirth  a             schema:Book ;
#         dcterms:creator        authors:Edith_Wharton ;
#         dcterms:title          "The House of Mirth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_08  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 08 - Naked Empire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wonderful_Wizard_of_Oz
#         a                      schema:Book ;
#         dcterms:creator        authors:L_Frank_Baum ;
#         dcterms:title          "The Wonderful Wizard of Oz" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Color_of_Fear  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Color of Fear" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lord_of_Rings_01  a           schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Lord of the Rings 01 - The Fellowship of the Ring" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stand  a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Stand" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Along_Came_a_Spider  a        schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Along Came a Spider" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_01  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 01 - Dark Lover" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Time_Machine_Invisible_Man
#         a                      schema:Book ;
#         dcterms:creator        authors:HG_Wells ;
#         dcterms:title          "The Time Machine and the Invisible Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Psychomech_03  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Psychomech 03 - Psychamok" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Series_Unfortunate_Events_05
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 05 - The Austere Academy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Colonel_Roosevelt  a          schema:Book ;
#         dcterms:creator        authors:Edmund_Morris ;
#         dcterms:title          "Colonel Roosevelt" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_Symbol2  a               schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "The Lost Symbol" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Sarahs_Key  a                 schema:Book ;
#         dcterms:creator        authors:Tatiana_de_Rosnay ;
#         dcterms:title          "Sarah's Key" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Oryx_and_Crake  a             schema:Book ;
#         dcterms:creator        authors:Margaret_Atwood ;
#         dcterms:title          "Oryx and Crake" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Talisman  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Talisman" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Children_of_Hurin  a          schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Children of Hurin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Belgariad_04  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Belgariad 04 - Castle of Wizardry" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Disgrace  a                   schema:Book ;
#         dcterms:creator        authors:JM_Coetzee ;
#         dcterms:title          "Disgrace" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Feeding_Frenzy  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Feeding Frenzy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Tower_02  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 02 - The Drawing of the Three" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_04  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 04 - Thorn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Khai_Of_Khem  a               schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Khai Of Khem" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Death_Instinct  a             schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "Death Instinct" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_03  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 03 - Every Which Way But Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prince  a                     schema:Book ;
#         dcterms:creator        authors:Niccolo_Machiavelli ;
#         dcterms:title          "The Prince" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tommyknockers  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Tommyknockers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Godfather  a                  schema:Book ;
#         dcterms:creator        authors:Mario_Puzo ;
#         dcterms:title          "The Godfather" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_10  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 10 - Witness in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Target_of_Opportunity
#         a                      schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Target of Opportunity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Darkness_In_My_Soul2
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "A Darkness In My Soul" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Thing_at_Bottom_of_Well
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "People, Places & Things - The Thing at the Bottom of the Well" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brief_Wondrous_Life_Oscar_Wao
#         a                      schema:Book ;
#         dcterms:creator        authors:Junot_Diaz ;
#         dcterms:title          "The Brief Wondrous Life of Oscar Wao" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:High_Priestess  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "High Priestess" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_01  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 01 - Dune" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_23  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 23 - Born in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Engines_of_Destruction
#         a                      schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Engines of Destruction" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarlet_Letter  a             schema:Book ;
#         dcterms:creator        authors:Nathaniel_Hawthorne ;
#         dcterms:title          "The Scarlet Letter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kidd_4  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Kidd 4 - Hanged Man's Song" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_08  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 08 - Shadow of the Giant" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_32  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 32 - A Hat Full Of Sky" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Innocent  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "I is for Innocent" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:F_Fugitive  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "F is for Fugitive" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:God_Delusion  a               schema:Book ;
#         dcterms:creator        authors:Richard_Dawkins ;
#         dcterms:title          "The God Delusion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blue_Smoke_and_Mirrors
#         a                      schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Blue Smoke and Mirrors" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_02  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 02 - Reliquary" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_13  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 13 - The Overlook" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sister_Carrie  a              schema:Book ;
#         dcterms:creator        authors:Theodore_Dreiser ;
#         dcterms:title          "Sister Carrie" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Matterhorn  a                 schema:Book ;
#         dcterms:creator        authors:Karl_Marlantes ;
#         dcterms:title          "Matterhorn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lady_Chatterleys_Lover
#         a                      schema:Book ;
#         dcterms:creator        authors:DH_Lawrence ;
#         dcterms:title          "Lady Chatterley's Lover" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Always_Looking_Up  a          schema:Book ;
#         dcterms:creator        authors:Michael_J_Fox ;
#         dcterms:title          "Always Looking Up, The Adventures of an Incurable Optimist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Everything_Kills_Everybody
#         a                      schema:Book ;
#         dcterms:creator        authors:Robert_Brockway ;
#         dcterms:title          "Everything Is Going to Kill Everybody" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:The_Stranger  a               schema:Book ;
#         dcterms:creator        authors:Albert_Camus ;
#         dcterms:title          "The Stranger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Contagious  a                 schema:Book ;
#         dcterms:creator        authors:Scott_Sigler ;
#         dcterms:title          "Contagious" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Sword_of_Truth_03  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 03 - Blood of the Fold" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:World_War_Z  a                schema:Book ;
#         dcterms:creator        authors:Max_Brooks ;
#         dcterms:title          "World War Z" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_19  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 19 - Wicked Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Soultaker  a                  schema:Book ;
#         dcterms:creator        authors:Bryan_Smith ;
#         dcterms:title          "Soultaker" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mr._Murder  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Mr. Murder" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:University  a                 schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The University" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Bone_Crossed  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "Bone Crossed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Face   a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Face" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Our_Mutual_Friend  a          schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "Our Mutual Friend" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Okinawa_Last_Battle  a        schema:Book ;
#         dcterms:creator        authors:Robert_Leckie ;
#         dcterms:title          "Okinawa, The Last Battle of World War II" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Odd_Thomas_02  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Odd Thomas 02 - Forever Odd" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mere_Christianity  a          schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "Mere Christianity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_09  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 09 - E-Branch 02 - Defilers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Fade_to_Black  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Fade to Black" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mother_Night  a               schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Mother Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_13
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 13 - The End" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sigma_Force_05  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 05 - The Last Oracle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malloreon_05  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Malloreon 05 - The Seeress of Kell" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:House  a                      schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Farseer_Trilogy_01  a         schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Farseer Trilogy 01 - Assassin's Apprentice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Red_Pyramid  a                schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "The Red Pyramid" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Are_You_There_Vodka  a        schema:Book ;
#         dcterms:creator        authors:Chelsea_Handler ;
#         dcterms:title          "Are You There, Vodka. It's Me, Chelsea" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Voice_Of_Night  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Voice Of The Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Slaughterhouse_Five  a        schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Slaughterhouse Five" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Key    a                      schema:Book ;
#         dcterms:creator        authors:James_Frey ;
#         dcterms:title          "The Key" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Suzannes_Diary_Nicholas
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Suzanne's Diary for Nicholas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Diary  a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Diary" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Boleyn_Inheritance  a         schema:Book ;
#         dcterms:creator        authors:Philippa_Gregory ;
#         dcterms:title          "The Boleyn Inheritance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:From_Corner_of_His_Eye
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "From the Corner of His Eye" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Essays_and_Poems  a           schema:Book ;
#         dcterms:creator        authors:Ralph_Waldo_Emerson ;
#         dcterms:title          "Essays and Poems" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Winner  a                     schema:Book ;
#         dcterms:creator        authors:David_Baldacci ;
#         dcterms:title          "The Winner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Defense_of_Food  a         schema:Book ;
#         dcterms:creator        authors:Michael_Pollan ;
#         dcterms:title          "In Defense of Food" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Four-Hour_Workweek  a         schema:Book ;
#         dcterms:creator        authors:Tim_Ferriss ;
#         dcterms:title          "The 4-Hour Workweek" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_03  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 03 - Xenocide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:American_on_Purpose  a        schema:Book ;
#         dcterms:creator        authors:Craig_Ferguson ;
#         dcterms:title          "American on Purpose" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Surely_Youre_Joking_Mr_Feynman
#         a                      schema:Book ;
#         dcterms:creator        authors:Richard_Feynman ;
#         dcterms:title          "Surely You're Joking, Mr. Feynman!" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vanishing  a                  schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Vanishing" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_31  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 31 - Indulgence in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pitt_1  a                 schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Joe Pitt 1 - Already Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_05  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 05 - The Judas Goat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Strain_Trilogy_02  a          schema:Book ;
#         dcterms:creator        authors:Guillermo_Del_Toro ;
#         dcterms:title          "The Strain Trilogy 02 - The Fall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rabbit_01  a                  schema:Book ;
#         dcterms:creator        authors:John_Updike ;
#         dcterms:title          "Rabbit 01 - Rabbit, Run" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_18  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 18 - Pastime" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_10  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 10 - Fever Dream" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bag_of_Bones  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Bag of Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tree_Grows_Brooklyn  a        schema:Book ;
#         dcterms:creator        authors:Betty_Smith ;
#         dcterms:title          "A Tree Grows in Brooklyn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Great_Derangement  a          schema:Book ;
#         dcterms:creator        authors:Matt_Taibbi ;
#         dcterms:title          "The Great Derangement" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lords_of_Earth  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Lords of the Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_07  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 07 - Indigo Slam" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_14  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 14 - Naked Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Big_Nowhere  a                schema:Book ;
#         dcterms:creator        authors:James_Ellroy ;
#         dcterms:title          "The Big Nowhere" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Me_Talk_Pretty  a             schema:Book ;
#         dcterms:creator        authors:David_Sedaris ;
#         dcterms:title          "Me Talk Pretty One Day" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_11  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 11 - Confessor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Phantoms  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Phantoms" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cathedral  a                  schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "Cathedral" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Four_Past_Midnight  a         schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Four Past Midnight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:War    a                      schema:Book ;
#         dcterms:creator        authors:Sebastian_Junger ;
#         dcterms:title          "War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Walk_in_Woods  a              schema:Book ;
#         dcterms:creator        authors:Bill_Bryson ;
#         dcterms:title          "A Walk in the Woods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_04  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 04 - Deadspeak" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malazan_Book_of_Fallen_08
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 08 - Toll the Hounds" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Practical_Guide_to_Racism
#         a                      schema:Book ;
#         dcterms:creator        authors:CH_Dalton ;
#         dcterms:title          "A Practical Guide to Racism" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Zero_History  a               schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Zero History" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Places  a                schema:Book ;
#         dcterms:creator        authors:Gillian_Flynn ;
#         dcterms:title          "Dark Places" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wicked  a                     schema:Book ;
#         dcterms:creator        authors:Gregory_Maguire ;
#         dcterms:title          "Wicked" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_Dogs  a                  schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "The Lost Dogs" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:John_Dies_at_End  a           schema:Book ;
#         dcterms:creator        authors:Jason_Pargin ;
#         dcterms:title          "John Dies at the End" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Imajica_02  a                 schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Imajica 02 - The Reconciliator" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Wheel_of_Time_08  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 08 - The Path of Daggers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Abraham_Lincoln_Vampire_Hunter
#         a                      schema:Book ;
#         dcterms:creator        authors:Seth_Grahame_Smith ;
#         dcterms:title          "Abraham Lincoln, Vampire Hunter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Essays_on_Middle_Earth
#         a                      schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "Essays on Middle Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Of_Woods2  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dark Of The Woods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:After_Last_Race  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "After The Last Race" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Count_Zero  a                 schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Count Zero" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shane_Schofield_02  a         schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Shane Schofield 02 - Area 7" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Takeshi_Kovacs_02  a          schema:Book ;
#         dcterms:creator        authors:Richard_Morgan ;
#         dcterms:title          "Takeshi Kovacs 02 - Broken Angels" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chamber  a                    schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Chamber" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Seize_Night  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Seize the Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Digital_Fortress2  a          schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Digital Fortress" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Rage   a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Rage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mob_Psychology  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Mob Psychology" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bob_Lee_Swagger_01  a         schema:Book ;
#         dcterms:creator        authors:Stephen_Hunter ;
#         dcterms:title          "Bob Lee Swagger 01 - Point Of Impact" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Key_to_Rebecca  a             schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "The Key to Rebecca" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kite_Runner  a                schema:Book ;
#         dcterms:creator        authors:Khaled_Hosseini ;
#         dcterms:title          "The Kite Runner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_13  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 13 - Taming a Sea Horse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitchhiker_03  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Hitchhiker 03 - Life, the Universe and Everything" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Grapes_of_Wrath  a            schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "The Grapes of Wrath" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Artemis_Fowl  a               schema:Book ;
#         dcterms:creator        authors:Eoin_Colfer ;
#         dcterms:title          "Artemis Fowl" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pygmy  a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Pygmy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Christmas_Carol  a            schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "A Christmas Carol" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_26  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 26 - Hush Money" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chronicles_of_Narnia_06
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 06 - The Magician's Nephew" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Black_Company  a              schema:Book ;
#         dcterms:creator        authors:Glen_Cook ;
#         dcterms:title          "The Black Company" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_02  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 02 - Stalking the Angel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Consider_Phlebas  a           schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Consider Phlebas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jesus_Bring_Pork_Chops
#         a                      schema:Book ;
#         dcterms:creator        authors:George_Carlin ;
#         dcterms:title          "When Will Jesus Bring the Pork Chops" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bite_Me  a                    schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "Bite Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_06  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 06 - From Potters Field" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_08  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 08 - Blue Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sun_Also_Rises  a             schema:Book ;
#         dcterms:creator        authors:Ernest_Hemingway ;
#         dcterms:title          "The Sun Also Rises" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Street_Lawyer  a              schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Street Lawyer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chomsky_Reader  a             schema:Book ;
#         dcterms:creator        authors:Noam_Chomsky ;
#         dcterms:title          "The Chomsky Reader" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 03 - Memories of Ice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:If_Chins_Could_Kill  a        schema:Book ;
#         dcterms:creator        authors:Bruce_Campbell ;
#         dcterms:title          "If Chins Could Kill, Confessions of a B Movie Actor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Surface_Detail  a             schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Surface Detail" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ubik   a                      schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "Ubik" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Legacy_Of_Terror  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Legacy Of Terror" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hannibal_01  a                schema:Book ;
#         dcterms:creator        authors:Thomas_Harris ;
#         dcterms:title          "Hannibal 01 - Red Dragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_09  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 09 - To the Nines" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rise_Theodore_Roosevelt
#         a                      schema:Book ;
#         dcterms:creator        authors:Edmund_Morris ;
#         dcterms:title          "The Rise of Theodore Roosevelt" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pillars_of_Earth  a           schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "The Pillars of the Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hunger_Games_01  a            schema:Book ;
#         dcterms:creator        authors:Suzanne_Collins ;
#         dcterms:title          "The Hunger Games 01 - The Hunger Games" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_08  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 08 - The Ionian Mission" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mickey_Haller_02  a           schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Mickey Haller 02 - The Brass Verdict" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex_Alera_03  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 03 - Cursor's Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_12  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 12 - The Touch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Daisy_Miller_Other_Stories
#         a                      schema:Book ;
#         dcterms:creator        authors:Henry_James ;
#         dcterms:title          "Daisy Miller and Other Stories" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_05  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 05 - Sea Change" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Resident_Evil_05  a           schema:Book ;
#         dcterms:creator        authors:SD_Perry ;
#         dcterms:title          "Resident Evil 05 - Nemesis" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Of_Human_Bondage  a           schema:Book ;
#         dcterms:creator        authors:W_Somerset_Maugham ;
#         dcterms:title          "Of Human Bondage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_09  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 09 - One Shot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Weaveworld  a                 schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Weaveworld" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Girl_Who_Loved_Tom_Gordon
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Girl Who Loved Tom Gordon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bedwetter  a                  schema:Book ;
#         dcterms:creator        authors:Sarah_Silverman ;
#         dcterms:title          "The Bedwetter, Stories of Courage, Redemption, and Pee" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_03  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 03 - The Dragon Reborn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Syndication_Rites  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Syndication Rites" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_06  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 06 - Prelude to Foundation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_03  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 03 - The Mammoth Hunters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Iron_Council  a               schema:Book ;
#         dcterms:creator        authors:China_Mieville ;
#         dcterms:title          "Iron Council" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_05  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 05 - Death Masks" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beyond_Exile_  a              schema:Book ;
#         dcterms:creator        authors:JL_Bourne ;
#         dcterms:title          "Beyond Exile" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scar   a                      schema:Book ;
#         dcterms:creator        authors:China_Mieville ;
#         dcterms:title          "The Scar" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Plum_Lucky  a                 schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Plum Lucky" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_05
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 05 - Dead as a Doornail" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ringworld  a                  schema:Book ;
#         dcterms:creator        authors:Larry_Niven ;
#         dcterms:title          "Ringworld" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lucy_Sullivan_Getting_Married
#         a                      schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Lucy Sullivan is Getting Married" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_03  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 03 - Harry Potter and the Prisoner of Azkaban" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Demolished_Man  a             schema:Book ;
#         dcterms:creator        authors:Alfred_Bester ;
#         dcterms:title          "The Demolished Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Haunted  a                    schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Haunted" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Psychedelic_Children
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Psychedelic Children" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Demon_Child  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Demon Child" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beach_Road  a                 schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Beach Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nathaniel  a                  schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Nathaniel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Spenser_21  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 21 - Walking Shadow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Afraid  a                     schema:Book ;
#         dcterms:creator        authors:JA_Konrath ;
#         dcterms:title          "Afraid" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fragment_  a                  schema:Book ;
#         dcterms:creator        authors:Warren_Fahy ;
#         dcterms:title          "Fragment" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Henry_IV_Pt_1  a              schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "Henry IV (Part 1)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gentlemen_Bastards_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Scott_Lynch ;
#         dcterms:title          "Gentlemen Bastards 01 - The Lies of Locke Lamora" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chronicles_of_Narnia_01
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 01 - The Lion, the Witch and the Wardrobe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Black_House  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Black House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harlequin_Valentine  a        schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Harlequin Valentine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Definitive_HP_Lovecraft
#         a                      schema:Book ;
#         dcterms:creator        authors:HP_Lovecraft ;
#         dcterms:title          "Definitive H.P. Lovecraft" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Day_By_Day_Armageddon
#         a                      schema:Book ;
#         dcterms:creator        authors:JL_Bourne ;
#         dcterms:title          "Day By Day Armageddon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_34  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 34 - Hundred Dollar Baby" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tyrannosaur_Canyon  a         schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Tyrannosaur Canyon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Look_Into_My_Eyes  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Look Into My Eyes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_10  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 10 - The Forgotten Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_01  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 01 - Postmortem" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_06  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 06 - A Lick of Frost" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_03  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 03 - Circus of the Damned" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_05
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 05 - Memnoch the Devil" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hearts_In_Atlantis  a         schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Hearts In Atlantis" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:By_Eminent_Domain  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "By Eminent Domain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Terminal_Transmission
#         a                      schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Terminal Transmission" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_04  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 04 - Four to Score" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Big_Short_Doomsday_Machine
#         a                      schema:Book ;
#         dcterms:creator        authors:Michael_Lewis ;
#         dcterms:title          "The Big Short, Inside the Doomsday Machine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_16  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 16 - Blood Noir" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:King_Family  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The King Family" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_14  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 14 - Predator" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Am_Legend  a                schema:Book ;
#         dcterms:creator        authors:Richard_Matheson ;
#         dcterms:title          "I Am Legend" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bush_At_War  a                schema:Book ;
#         dcterms:creator        authors:Bob_Woodward ;
#         dcterms:title          "Bush At War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_03  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 03 - H.M.S. Surprise" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bonesetters_Daughter
#         a                      schema:Book ;
#         dcterms:creator        authors:Amy_Tan ;
#         dcterms:title          "The Bonesetter's Daughter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_07  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 07 - Pyramids" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bloodsucking_Fiends  a        schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "Bloodsucking Fiends" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brain_Droppings  a            schema:Book ;
#         dcterms:creator        authors:George_Carlin ;
#         dcterms:title          "Brain Droppings" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_04  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 04 - Running Blind" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Face_Of_Fear  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Face Of Fear" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_16  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 16 - The Wine-Dark Sea" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Moonlight_Mile  a             schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "Moonlight Mile" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kraken  a                     schema:Book ;
#         dcterms:creator        authors:China_Mieville ;
#         dcterms:title          "Kraken" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Greywalker_04  a              schema:Book ;
#         dcterms:creator        authors:Kat_Richardson ;
#         dcterms:title          "Greywalker 04 - Vanished" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Foundation_01  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 01 - Foundation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blink  a                      schema:Book ;
#         dcterms:creator        authors:Malcolm_Gladwell ;
#         dcterms:title          "Blink, The Power of Thinking Without Thinking" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brothers_Karamazov  a         schema:Book ;
#         dcterms:creator        authors:Fyodor_Dostoevsky ;
#         dcterms:title          "The Brothers Karamazov" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hideaway  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Hideaway" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Road   a                      schema:Book ;
#         dcterms:creator        authors:Cormac_McCarthy ;
#         dcterms:title          "The Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_11  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 11 - Knife of Dreams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anthem  a                     schema:Book ;
#         dcterms:creator        authors:Ayn_Rand ;
#         dcterms:title          "Anthem" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dexter_05  a                  schema:Book ;
#         dcterms:creator        authors:Jeff_Lindsay ;
#         dcterms:title          "Dexter 05 - Dexter is Delicious" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_West_01  a               schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Jack West 01 - Seven Ancient Wonders" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Depraved  a                   schema:Book ;
#         dcterms:creator        authors:Bryan_Smith ;
#         dcterms:title          "Depraved" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ulysses  a                    schema:Book ;
#         dcterms:creator        authors:James_Joyce ;
#         dcterms:title          "Ulysses" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Breakfast_at_Tiffanys
#         a                      schema:Book ;
#         dcterms:creator        authors:Truman_Capote ;
#         dcterms:title          "Breakfast at Tiffany's" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Three_Stigmata_Palmer_Eldritch
#         a                      schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "The Three Stigmata of Palmer Eldritch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Other_Side_of_Fog  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "People, Places & Things - The Other Side of the Fog" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_13  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 13 - Side Jobs" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beautiful_and_Damned
#         a                      schema:Book ;
#         dcterms:creator        authors:F_Scott_Fitzgerald ;
#         dcterms:title          "The Beautiful and Damned" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hostage  a                    schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Hostage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Everythings_Eventual
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Everything's Eventual" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Zombie_Survival_Guide
#         a                      schema:Book ;
#         dcterms:creator        authors:Max_Brooks ;
#         dcterms:title          "The Zombie Survival Guide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spook_Country  a              schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Spook Country" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Luckey_Quarter  a             schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Luckey Quarter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Symphony2  a             schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dark Symphony" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Finn_Ryan_03  a               schema:Book ;
#         dcterms:creator        authors:Christopher_Paul ;
#         dcterms:title          "Finn Ryan 03 - Rembrandts Ghost" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Animal_Farm  a                schema:Book ;
#         dcterms:creator        authors:George_Orwell ;
#         dcterms:title          "Animal Farm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_01  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 01 - A Kiss of Shadows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Liveship_Traders_03  a        schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Liveship Traders 03 - Ship of Destiny" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_11  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 11 - Cerulean Sins" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blackstone_Chronicles
#         a                      schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Blackstone Chronicles" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Republic  a                   schema:Book ;
#         dcterms:creator        authors:Plato ;
#         dcterms:title          "The Republic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bloody_Tourists  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Bloody Tourists" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_02  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 02 - The Light Fantastic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Complete_Grimms_Fairy_Tales
#         a                      schema:Book ;
#         dcterms:creator        authors:Wilhelm_Grimm ;
#         dcterms:title          "The Complete Grimm's Fairy Tales" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:About_a_Boy  a                schema:Book ;
#         dcterms:creator        authors:Nick_Hornby ;
#         dcterms:title          "About a Boy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_06  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 06 - Vengeance in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_12  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 12 - Twelve Sharp" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Coming_of_Third_Reich
#         a                      schema:Book ;
#         dcterms:creator        authors:Richard_J_Evans ;
#         dcterms:title          "The Coming of the Third Reich" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_11  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 11 - The Reverse Of The Medal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lovely_Bones  a               schema:Book ;
#         dcterms:creator        authors:Alice_Sebold ;
#         dcterms:title          "The Lovely Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Game   a                      schema:Book ;
#         dcterms:creator        authors:Neil_Strauss ;
#         dcterms:title          "The Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_15  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 15 - Men at Arms" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sleepwalk_With_Me  a          schema:Book ;
#         dcterms:creator        authors:Mike_Birbiglia ;
#         dcterms:title          "Sleepwalk With Me, and Other Painfully True Stories" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_19  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 19 - Visions in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_05  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 05 - The Forbidden" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Jack_Reacher_12  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 12 - Nothing to Lose" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jackdaws  a                   schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "Jackdaws" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_28  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 28 - The Amazing Maurice and His Educated Rodents" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_9  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 9 - Secret Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shack  a                      schema:Book ;
#         dcterms:creator        authors:William_Young ;
#         dcterms:title          "The Shack" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Odyssey  a                    schema:Book ;
#         dcterms:creator        authors:Homer ;
#         dcterms:title          "The Odyssey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Id_Rather_We_Got_Casinos
#         a                      schema:Book ;
#         dcterms:creator        authors:Larry_Wilmore ;
#         dcterms:title          "I'd Rather We Got Casinos, And Other Black Thoughts" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Galilee  a                    schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Galilee" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Harry_Bosch_09  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 09 - Lost Light" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Big_Bad_Wolf  a               schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "The Big Bad Wolf" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wolfs_Bain  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Wolf's Bain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:By_Light_of_Moon  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "By the Light of the Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dolores_Claiborne  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Dolores Claiborne" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Factoring_Humanity  a         schema:Book ;
#         dcterms:creator        authors:Robert_J_Sawyer ;
#         dcterms:title          "Factoring Humanity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Percy_Jackson_2  a            schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "Percy Jackson 2 - The Sea of Monsters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:M_Malice  a                   schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "M is for Malice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hide_and_Seek  a              schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Hide and Seek" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shadow_of_Wind  a             schema:Book ;
#         dcterms:creator        authors:Carlos_Zafon ;
#         dcterms:title          "The Shadow of the Wind" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Watership_Down  a             schema:Book ;
#         dcterms:creator        authors:Richard_Adams ;
#         dcterms:title          "Watership Down" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:NineteenEightyFour  a         schema:Book ;
#         dcterms:creator        authors:George_Orwell ;
#         dcterms:title          "1984" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Warlock  a                    schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Warlock" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Decoded  a                    schema:Book ;
#         dcterms:creator        authors:Jay_Z ;
#         dcterms:title          "Decoded" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:War_of_Dwarves  a             schema:Book ;
#         dcterms:creator        authors:Markus_Heitz ;
#         dcterms:title          "The War of the Dwarves" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cross  a                      schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Cross" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Johnny_Mnemonic  a            schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Johnny Mnemonic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_05  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 05 - Lover Unbound" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blade_Itself  a               schema:Book ;
#         dcterms:creator        authors:Joe_Abercrombie ;
#         dcterms:title          "The Blade Itself" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_09
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 09 - The Carnivorous Carnival" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Treasure_Island  a            schema:Book ;
#         dcterms:creator        authors:Robert_Louis_Stevenson ;
#         dcterms:title          "Treasure Island" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Algebraist  a                 schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "The Algebraist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Little_Women  a               schema:Book ;
#         dcterms:creator        authors:Louisa_May_Alcott ;
#         dcterms:title          "Little Women" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gone_with_Wind  a             schema:Book ;
#         dcterms:creator        authors:Margaret_Mitchell ;
#         dcterms:title          "Gone with the Wind" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:C_Corpse  a                   schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "C is for Corpse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_08  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 08 - Seance for a Vampire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Tower_06  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 06 - Song of Susannah" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_01  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 01 - Naked in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cold_Warrior  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Cold Warrior" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Reploids  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Reploids" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Heat_Wave  a                  schema:Book ;
#         dcterms:creator        authors:Richard_Castle ;
#         dcterms:title          "Heat Wave" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_07  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 07 - White Witch Black Curse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_10  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 10 - Moving Pictures" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Walden  a                     schema:Book ;
#         dcterms:creator        authors:Henry_David_Thoreau ;
#         dcterms:title          "Walden" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Painted_House  a              schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "A Painted House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_14  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 14 - Reunion in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Push   a                      schema:Book ;
#         dcterms:creator        authors:Sapphire ;
#         dcterms:title          "Push" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sons_and_Lovers  dcterms:creator  authors:DH_Lawrence ;
#         dcterms:title          "Sons and Lovers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_05  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 05 - Heretics of Dune" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_23  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 23 - Carpe Jugulum" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Song_of_Ice_and_Fire_01
#         a                      schema:Book ;
#         dcterms:creator        authors:George_RR_Martin ;
#         dcterms:title          "A Song of Ice and Fire 01 - A Game Of Thrones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_4  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 4 - Silent Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Lecture  a               schema:Book ;
#         dcterms:creator        authors:Randy_Pausch ;
#         dcterms:title          "The Last Lecture" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joy_Luck_Club  a              schema:Book ;
#         dcterms:creator        authors:Amy_Tan ;
#         dcterms:title          "The Joy Luck Club" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_27  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 27 - Salvation in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Walking  a                    schema:Book ;
#         dcterms:creator        authors:Bentley_Little , authors:Stephen_King ;
#         dcterms:title          "The Walking" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" , "prc" .
#
# ebooks:Harry_Bosch_04  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 04 - The Last Coyote" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_36  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 36 - Making Money" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foul_Play  a                  schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Foul Play" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Geek_Love  dcterms:creator    authors:Katherine_Dunn ;
#         dcterms:title          "Geek Love" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_06  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 06 - Dance of Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Requiem_for_Dream  a          schema:Book ;
#         dcterms:creator        authors:Hubert_Selby_Jr ;
#         dcterms:title          "Requiem for a Dream" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Confessions_of_Shopaholic
#         a                      schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Confessions of a Shopaholic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:A_Wrinkle_in_Time  a          schema:Book ;
#         dcterms:creator        authors:Madeleine_Lengle ;
#         dcterms:title          "A Wrinkle in Time" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Remember_Me  a                schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Remember Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sleepwalk  a                  schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Sleepwalk" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Swan_Song  a                  schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Swan Song" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Contest  a                    schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Contest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Mrs._Dalloway  a              schema:Book ;
#         dcterms:creator        authors:Virginia_Woolf ;
#         dcterms:title          "Mrs. Dalloway" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Illustrated_Man  a            schema:Book ;
#         dcterms:creator        authors:Ray_Bradbury ;
#         dcterms:title          "The Illustrated Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Book_of_New_Sun_02  a         schema:Book ;
#         dcterms:creator        authors:Gene_Wolfe ;
#         dcterms:title          "Book of the New Sun 02 - Sword and Citadel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_07  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 07 - The Pillars of Creation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Different_Seasons  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Different Seasons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula  a                    schema:Book ;
#         dcterms:creator        authors:Bram_Stoker ;
#         dcterms:title          "Dracula" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Superfreakonomics  a          schema:Book ;
#         dcterms:creator        authors:Steven_Levitt ;
#         dcterms:title          "Superfreakonomics" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Terminal_Freeze  a            schema:Book ;
#         dcterms:creator        authors:Lincoln_Child ;
#         dcterms:title          "Terminal Freeze" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Black_Pumpkin  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Black Pumpkin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crucible  a                   schema:Book ;
#         dcterms:creator        authors:Arthur_Miller ;
#         dcterms:title          "The Crucible" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Psychomech_02  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Psychomech 02 - Psychosphere" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Series_Unfortunate_Events_04
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 04 - The Miserable Mill" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Darkness_In_My_Soul  a        schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "A Darkness In My Soul" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fragile_Things  a             schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Fragile Things" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stardust  a                   schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Stardust" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Emma   a                      schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Emma" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Belgariad_03  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Belgariad 03 - Magician's Gambit" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Winter_Moon  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Winter Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blood_Meridian  a             schema:Book ;
#         dcterms:creator        authors:Cormac_McCarthy ;
#         dcterms:title          "Blood Meridian" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pride_Prejudice_Zombies
#         a                      schema:Book ;
#         dcterms:creator        authors:Seth_Grahame_Smith ;
#         dcterms:title          "Pride and Prejudice and Zombies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Help   a                      schema:Book ;
#         dcterms:creator        authors:Kathryn_Stockett ;
#         dcterms:title          "The Help" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_03  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 03 - The Vlad Tapes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Tower_01  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 01 - The Gunslinger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Virgil_Flowers2  a            schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Virgil Flowers2 - Heat Lightning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Snow_Glass_Apples  a          schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Snow Glass Apples" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Monster_of_Florence  a        schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "The Monster of Florence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ultimate_Death  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Ultimate Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_02  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 02 - The Good, The Bad, and the Undead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Message_in_a_Bottle  a        schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "Message in a Bottle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:One_Flew_Over_Cuckoos_Nest
#         a                      schema:Book ;
#         dcterms:creator        authors:Ken_Kesey ;
#         dcterms:title          "One Flew Over the Cuckoo's Nest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bleak_House  a                schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "Bleak House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Winters_Night_Traveller
#         a                      schema:Book ;
#         dcterms:creator        authors:Italo_Calvino ;
#         dcterms:title          "If On a Winters Night a Traveller" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Comes_Blind_Fury  a           schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Comes The Blind Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:First_Five_Page  a            schema:Book ;
#         dcterms:creator        authors:Noah_Lukeman ;
#         dcterms:title          "The First Five Page" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Good_Omens  a                 schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Good Omens" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_22  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 22 - Memory in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_07  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 07 - Shadow Puppets" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kidd_3  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Kidd 3 - The Devils Code" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_31  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 31 - Monstrous Regiment" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:End_of_Beginning  a           schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The End of the Beginning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Queen_of_Blood  a             schema:Book ;
#         dcterms:creator        authors:Bryan_Smith ;
#         dcterms:title          "Queen of Blood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:One_Door_Away_From_Heaven
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "One Door Away From Heaven" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pitt_5  a                 schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Joe Pitt 5 - My Dead Body" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_09  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 09 - Ceremony" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_01  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 01 - Relic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Trapped  a                    schema:Book ;
#         dcterms:creator        authors:JA_Konrath ;
#         dcterms:title          "Trapped" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_12  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 12 - Echo Park" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Waste_Land_Other_Poems
#         a                      schema:Book ;
#         dcterms:creator        authors:TS_Eliot ;
#         dcterms:title          "Waste Land and Other Poems" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night  a                      schema:Book ;
#         dcterms:creator        authors:Elie_Wiesel ;
#         dcterms:title          "Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey   a                      schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:First_to_Die  a               schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "1st to Die" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pop_Goes_Weasel  a            schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Pop Goes the Weasel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_04  a                schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "Twilight 04 - Breaking Dawn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Name_of_Wind  a               schema:Book ;
#         dcterms:creator        authors:Philip_Roth ;
#         dcterms:title          "The Name of the Wind" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stranger_Here_Myself
#         a                      schema:Book ;
#         dcterms:creator        authors:Bill_Bryson ;
#         dcterms:title          "I'm a Stranger Here Myself" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Plan_of_Attack  a             schema:Book ;
#         dcterms:creator        authors:Bob_Woodward ;
#         dcterms:title          "Plan of Attack" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Living_Dead  a                schema:Book ;
#         dcterms:creator        authors:John_Joseph_Adams ;
#         dcterms:title          "The Living Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Use_of_Weapons  a             schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Use of Weapons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_02  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 02 - Stone of Tears" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:End_of_Game  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The End of the Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_18  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 18 - Phantom Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitch22  a                    schema:Book ;
#         dcterms:creator        authors:Christopher_Hitchens ;
#         dcterms:title          "Hitch-22" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:False_Memory  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "False Memory" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Odd_Thomas_01  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Odd Thomas 01 - Odd Thomas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Iliad  a                      schema:Book ;
#         dcterms:creator        authors:Homer ;
#         dcterms:title          "The Iliad" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Omnivores_Dilemma  a          schema:Book ;
#         dcterms:creator        authors:Michael_Pollan ;
#         dcterms:title          "The Omnivore's Dilemma" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jaws   a                      schema:Book ;
#         dcterms:creator        authors:Peter_Benchley ;
#         dcterms:title          "Jaws" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Good_In_Bed  a                schema:Book ;
#         dcterms:creator        authors:Jennifer_Weiner ;
#         dcterms:title          "Good In Bed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_08  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 08 - E-Branch 01 - Invaders" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Contact  a                    schema:Book ;
#         dcterms:creator        authors:Carl_Sagan ;
#         dcterms:title          "Contact" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_12
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 12 - The Penultimate Peril" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sigma_Force_04  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 04 - Judas Strain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malloreon_04  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Malloreon 04 - Sorceress of Darshiva" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Flashforward  a               schema:Book ;
#         dcterms:creator        authors:Robert_J_Sawyer ;
#         dcterms:title          "Flashforward" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Angel_Trilogy_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Brent_Weeks ;
#         dcterms:title          "Night Angel Trilogy 03 - Beyond the Shadows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dharma_Bums  a                schema:Book ;
#         dcterms:creator        authors:Jack_Kerouac ;
#         dcterms:title          "The Dharma Bums" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:State_of_Fear  a              schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "State of Fear" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Excession  a                  schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Excession" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Terror  a                     schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "The Terror" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:American_Tabloid  a           schema:Book ;
#         dcterms:creator        authors:James_Ellroy ;
#         dcterms:title          "American Tabloid" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cult_of_Osiris  a             schema:Book ;
#         dcterms:creator        authors:Andy_McDermott ;
#         dcterms:title          "The Cult of Osiris" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:EarthCore  a                  schema:Book ;
#         dcterms:creator        authors:Scott_Sigler ;
#         dcterms:title          "EarthCore" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Murder_on_Orient_Express
#         a                      schema:Book ;
#         dcterms:creator        authors:Agatha_Christie ;
#         dcterms:title          "Murder on the Orient Express" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Great_Expectations  a         schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "Great Expectations" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Visions_of_Sugar_Plums
#         a                      schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Visions of Sugar Plums" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Monkey  a                     schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Monkey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_02  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 02 - Speaker for the Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Darkest_Evening_of_Year
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Darkest Evening of the Year" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blood_Ties  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Blood Ties" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Half_Broke_Horses  a          schema:Book ;
#         dcterms:creator        authors:Jeannette_Walls ;
#         dcterms:title          "Half Broke Horses" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_30  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 30 - Fantasy in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wild_Seed  a                  schema:Book ;
#         dcterms:creator        authors:Octavia_E_Butler ;
#         dcterms:title          "Wild Seed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_04  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 04 - Promised Land" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Strain_Trilogy_01  a          schema:Book ;
#         dcterms:creator        authors:Guillermo_Del_Toro ;
#         dcterms:title          "The Strain Trilogy 01 - The Strain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Girl_Dragon_Tattoo  a         schema:Book ;
#         dcterms:creator        authors:Stieg_Larsson ;
#         dcterms:title          "The Girl with the Dragon Tattoo" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Am_America  a               schema:Book ;
#         dcterms:creator        authors:Stephen_Colbert ;
#         dcterms:title          "I Am America (And So Can You!)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blood_Work  a                 schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Blood Work" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_17  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 17 - Stardust" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:American_Obsession  a         schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "American Obsession" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Half  a                  schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Half" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dubliners  a                  schema:Book ;
#         dcterms:creator        authors:James_Joyce ;
#         dcterms:title          "Dubliners" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prayers_for_Rain  a           schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "Prayers for Rain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_06  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 06 - Sunset Express" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_13  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 13 - Mortal Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Way_of_Kings  a               schema:Book ;
#         dcterms:creator        authors:Brandon_Sanderson ;
#         dcterms:title          "The Way of Kings" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tess_of_DUrbervilles
#         a                      schema:Book ;
#         dcterms:creator        authors:Thomas_Hardy ;
#         dcterms:title          "Tess of the D'Urbervilles" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dance  a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_10  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 10 - Phantom" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Collection  a                 schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Collection" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anybody_Out_There  a          schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Anybody Out There" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_03  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 03 - The Source" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malazan_Book_of_Fallen_07
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 07 - Reaper's Gale" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Winters_Tale  a               schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "The Winter's Tale" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Shannara  a          schema:Book ;
#         dcterms:creator        authors:Terry_Brooks ;
#         dcterms:title          "The Sword of Shannara" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prison_of_Ice  a              schema:Book ;
#         dcterms:creator        authors:David_Axton ;
#         dcterms:title          "Prison of Ice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_09  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 09 - Split Image" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Collected_Stories  a          schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "The Collected Stories" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Fiasco  a                     schema:Book ;
#         dcterms:creator        authors:Thomas_Ricks ;
#         dcterms:title          "Fiasco, The American Military Adventure in Iraq" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Space_Odyssey  a              schema:Book ;
#         dcterms:creator        authors:Arthur_C_Clarke ;
#         dcterms:title          "2001 A Space Odyssey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sleepless  a                  schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Sleepless" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Catch_Me_If_You_Can  a        schema:Book ;
#         dcterms:creator        authors:Frank_Abagnale ;
#         dcterms:title          "Catch Me If You Can" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Partner  a                    schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Partner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fugitives_and_Refugees
#         a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Fugitives and Refugees" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Imajica_01  a                 schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Imajica 01 - Fifth Dominion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Wheel_of_Time_07  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 07 - A Crown of Swords" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Road_Not_Taken  a             schema:Book ;
#         dcterms:creator        authors:Robert_Frost ;
#         dcterms:title          "The Road Not Taken" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shame_Devil  a                schema:Book ;
#         dcterms:creator        authors:George_Pelecanos ;
#         dcterms:title          "Shame the Devil" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Everything_That_Rises
#         a                      schema:Book ;
#         dcterms:creator        authors:Flannery_OConnor ;
#         dcterms:title          "Everything That Rises Must Converge" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_of_Mohicans  a           schema:Book ;
#         dcterms:creator        authors:James_Fenimore_Cooper ;
#         dcterms:title          "The Last of the Mohicans" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shane_Schofield_01  a         schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Shane Schofield 01 - Ice Station" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Harry_Dresden_09  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 09 - White Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Extremely_Loud_Incredibly_Close
#         a                      schema:Book ;
#         dcterms:creator        authors:Jonathan_Safran_Foer ;
#         dcterms:title          "Extremely Loud & Incredibly Close" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_09
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 09 - Dead and Gone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Takeshi_Kovacs_01  dcterms:creator  authors:Richard_Morgan ;
#         dcterms:title          "Takeshi Kovacs 01 - Altered Carbon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Irresistible_Henry_House
#         a                      schema:Book ;
#         dcterms:creator        authors:Lisa_Grunwald ;
#         dcterms:title          "The Irresistible Henry House" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Calculating_God  a            schema:Book ;
#         dcterms:creator        authors:Robert_J_Sawyer ;
#         dcterms:title          "Calculating God" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Her_Shoes  a               schema:Book ;
#         dcterms:creator        authors:Jennifer_Weiner ;
#         dcterms:title          "In Her Shoes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_07  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 07 - Harry Potter and the Deathly Hallows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Midnight  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Midnight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_12  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 12 - A Catskill Eagle" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitchhiker_02  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Hitchhiker 02 - The Restaurant at the End of the Universe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dragon_Tears  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dragon Tears" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Call_of_Wild_White_Fang
#         a                      schema:Book ;
#         dcterms:creator        authors:Jack_London ;
#         dcterms:title          "The Call of the Wild and White Fang" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gravitys_Rainbow  a           schema:Book ;
#         dcterms:creator        authors:Thomas_Pynchon ;
#         dcterms:title          "Gravity's Rainbow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_01  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 01 - The Monkey's Raincoat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Black_Hawk_Down  a            schema:Book ;
#         dcterms:creator        authors:Mark_Bowden ;
#         dcterms:title          "Black Hawk Down" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_25  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 25 - Sudden Mischief" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sex    a                      schema:Book ;
#         dcterms:creator        authors:Madonna ;
#         dcterms:title          "Sex" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pound_of_Prevention  a        schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "A Pound of Prevention" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Host   a                      schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "The Host" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Husband  a                    schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Husband" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deep_Fathom  a                schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Deep Fathom" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Chronicles_of_Narnia_05
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 05 - The Horse and His Boy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hobbit  a                     schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Hobbit" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cat_and_Mouse  a              schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Cat and Mouse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cannery_Row  a                schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "Cannery Row" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Band_of_Brothers  a           schema:Book ;
#         dcterms:creator        authors:Stephen_Ambrose ;
#         dcterms:title          "Band of Brothers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Other_Side_of_Story  a        schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "The Other Side of the Story" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Frankenstein_03  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Frankenstein - Dead and Alive" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Walking_Wounded  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Walking Wounded" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_38  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 38 - Painted Ladies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_05  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 05 - The Body Farm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_07  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 07 - Burnt Offerings" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Academy  a                    schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Academy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Flood_Tide  a                 schema:Book ;
#         dcterms:creator        authors:Clive_Cussler ;
#         dcterms:title          "Flood Tide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_09
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 09 - Blackwood Farm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Zen_Art_Motorcycle_Maintenance
#         a                      schema:Book ;
#         dcterms:creator        authors:Robert_Pirsig ;
#         dcterms:title          "Zen and the Art of Motorcycle Maintenance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 02 - Deadhouse Gates" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpettas_Winter_Table
#         a                      schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpettas Winter Table" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Stephanie_Plum_08  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 08 - Hard Eight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:This_Side_of_Paradise
#         a                      schema:Book ;
#         dcterms:creator        authors:F_Scott_Fitzgerald ;
#         dcterms:title          "This Side of Paradise" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_07  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 07 - The Surgeon's Mate" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mickey_Haller_01  a           schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Mickey Haller 01 - The Lincoln Lawyer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex_Alera_02  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 02 - Academ's Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Angels_and_Demons2  a         schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Angels and Demons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:White_Queen  a                schema:Book ;
#         dcterms:creator        authors:Philippa_Gregory ;
#         dcterms:title          "The White Queen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_11  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 11 - Harry Keogh Necroscope and Other Heroes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Stone_04  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 04 - Stone Cold" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Resident_Evil_04  a           schema:Book ;
#         dcterms:creator        authors:SD_Perry ;
#         dcterms:title          "Resident Evil 04 - Underworld" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Idiot  a                      schema:Book ;
#         dcterms:creator        authors:Fyodor_Dostoevsky ;
#         dcterms:title          "The Idiot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Seduced_by_Moonlight
#         a                           schema:Book ;
#         dcterms:creator             authors:Laurell_K_Hamilton ;
#         dcterms:title               "Meredith Gentry 03 - Seduced by Moonlight" ;
#         schema:bookFormat           schema:Ebook ;
#         schema:encodingFormat       "mobi" ;
#         schema:isbn                 "9780345472069" ;
#         bibliographica:worldcatURI  "http://www.worldcat.org/oclc/234177749.ttl"^^xsd:anyURI .
#
# ebooks:Jack_Reacher_08  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 08 - The Enemy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Assholes_Finish_First
#         a                      schema:Book ;
#         dcterms:creator        authors:Tucker_Max ;
#         dcterms:title          "Assholes Finish First" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_02  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 02 - The Great Hunt" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Drama_City  a                 schema:Book ;
#         dcterms:creator        authors:George_Pelecanos ;
#         dcterms:title          "Drama City" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_05  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 05 - Foundation and Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Q_Quarry  a                   schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "Q is for Quarry" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_02  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 02 - The Valley of Horse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_04  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 04 - Summer Knight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gone_South  a                 schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Gone South" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Sausagey_Santa  a             schema:Book ;
#         dcterms:creator        authors:Carlton_Mellick ;
#         dcterms:title          "Sausagey Santa" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chase  a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Chase" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_04
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 04 - Dead to the World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_Eyes  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Twilight Eyes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Horse  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Dark Horse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dirty_Job  a                  schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "A Dirty Job" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_02  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 02 - Harry Potter and the Chamber of Secrets" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hells_Gate  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Hells Gate" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Strange_Highways  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Strange Highways" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:House_of_Blood  a             schema:Book ;
#         dcterms:creator        authors:Bryan_Smith ;
#         dcterms:title          "House of Blood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Why_We_Suck  a                schema:Book ;
#         dcterms:creator        authors:Denis_Leary ;
#         dcterms:title          "Why We Suck" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Master_and_Margarita
#         a                      schema:Book ;
#         dcterms:creator        authors:Mikhail_Bulgakov ;
#         dcterms:title          "The Master and Margarita" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Boys_Life  a                  schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Boy's Life" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Feast_or_Famine  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Feast or Famine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:G_Gumshoe  a                  schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "G is for Gumshoe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_20  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 20 - Paper Doll" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:R_Ricochet  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "R is for Ricochet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Merchant_of_Venice  a         schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "The Merchant of Venice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Know_This_Much_Is_True
#         a                      schema:Book ;
#         dcterms:creator        authors:Wally_Lamb ;
#         dcterms:title          "I Know This Much Is True" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mary_Mary  a                  schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Mary, Mary" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_33  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 33 - School Days" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shutter_Island  a             schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "Shutter Island" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ruins  a                      schema:Book ;
#         dcterms:creator        authors:Scott_Smith ;
#         dcterms:title          "The Ruins" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sushi_for_Beginner  a         schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Sushi for Beginner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_02  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 02 - The Laughing Corpse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Rites  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Last Rites" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_05  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 05 - Mistral's Kiss" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_04
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 04 - The Tale of the Body Thief" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Big_Trouble  a                schema:Book ;
#         dcterms:creator        authors:Dave_Barry ;
#         dcterms:title          "Big Trouble" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unwanted  a                   schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Unwanted" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Transition  a                 schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Transition" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Where_Men_Win_Glory  a        schema:Book ;
#         dcterms:creator        authors:Jon_Krakauer ;
#         dcterms:title          "Where Men Win Glory" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Heart_and_Soul  a             schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Heart and Soul" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_13  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 13 - Trace" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_15  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 15 - The Harlequin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_03  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 03 - Three to Get Deadly" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Snatcher_2  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Snatcher 2" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_02  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 02 - Post Captain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Summons  a                    schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Summons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Snow_Crash  a                 schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "Snow Crash" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stand_Uncut  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Stand (Uncut)" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_06  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 06 - Wyrd Sisters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_10
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 10 - The Crippled God" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Drood  a                      schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Drood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_03  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 03 - Tripwire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_16  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 16 - Sizzling Sixteen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Skeleton_Crew  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Skeleton Crew" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_15  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 15 - Clarissa Oakes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Citizen_Soldiers  a           schema:Book ;
#         dcterms:creator        authors:Stephen_Ambrose ;
#         dcterms:title          "Citizen Soldiers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_19  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 19 - Feet of Clay" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hard_Times  a                 schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "Hard Times" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Thousand_Splendid_Suns
#         a                      schema:Book ;
#         dcterms:creator        authors:Khaled_Hosseini ;
#         dcterms:title          "A Thousand Splendid Suns" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Blind_Assassin  a             schema:Book ;
#         dcterms:creator        authors:Margaret_Atwood ;
#         dcterms:title          "The Blind Assassin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_09  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 09 - The Cursed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:History_of_Middle-Earth
#         a                      schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The History of Middle-Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:When_Wind_Blows  a            schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "When the Wind Blows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Greywalker_03  a              schema:Book ;
#         dcterms:creator        authors:Kat_Richardson ;
#         dcterms:title          "Greywalker 03 - Underground" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Playing_for_Pizza  a          schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "Playing for Pizza" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_10  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 10 - Crossroads of Twilight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dexter_04  a                  schema:Book ;
#         dcterms:creator        authors:Jeff_Lindsay ;
#         dcterms:title          "Dexter 04 - Dexter by Design" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:When_You_Ride_Alone  a        schema:Book ;
#         dcterms:creator        authors:Bill_Maher ;
#         dcterms:title          "When You Ride Alone You Ride with Bin Laden" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rant   a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Rant" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Dragon  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Last Dragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Market_Forces  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Market Forces" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_12  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 12 - Changes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Executive_Orders  a           schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "Executive Orders" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Amazonia  a                   schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Amazonia" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Moon_Called  a                schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "Moon Called" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Minding_Frankie  a            schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Minding Frankie" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Full_Dark_No_Stars  a         schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Full Dark, No Stars" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Final_Reel  a                 schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Final Reel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Zen_Art_of_Writing  a         schema:Book ;
#         dcterms:creator        authors:Ray_Bradbury ;
#         dcterms:title          "Zen in the Art of Writing" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Finn_Ryan_02  a               schema:Book ;
#         dcterms:creator        authors:Christopher_Paul ;
#         dcterms:title          "Finn Ryan 02 - The Lucifer Gospel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Beastchild  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Beastchild" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:J_Judgement  a                schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "J is for Judgement" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:High_Fidelity  a              schema:Book ;
#         dcterms:creator        authors:Nick_Hornby ;
#         dcterms:title          "High Fidelity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Four_Blind_Mice  a            schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Four Blind Mice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jigsaw_Man  a                 schema:Book ;
#         dcterms:creator        authors:Gord_Rollo ;
#         dcterms:title          "The Jigsaw Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Coraline  a                   schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Coraline" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hyperion_Cantos_04  a         schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Hyperion Cantos 04 - The Rise of Endymion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_09  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 09 - Lover Unleashed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Portrait_of_Artist_As_Young_Man
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Joyce ;
#         dcterms:title          "A Portrait of the Artist As a Young Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Time_to_Kill  a               schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "A Time to Kill" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Great_Gatsby  a               schema:Book ;
#         dcterms:creator        authors:F_Scott_Fitzgerald ;
#         dcterms:title          "The Great Gatsby" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Liveship_Traders_02  a        schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Liveship Traders 02 - Mad Ship" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_10  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 10 - Narcissus in Chains" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_Of_Dawn  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Twilight Of The Dawn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Team_of_Rivals  a             schema:Book ;
#         dcterms:creator        authors:Doris_Kearns_Goodwin ;
#         dcterms:title          "Team of Rivals" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_01  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 01 - The Colour of Magic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Waste_Not_Want_Not  a         schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Waste Not, Want Not" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_05  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 05 - Ceremony in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_11  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 11 - Eleven on Top" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:For_Whom_Bell_Tolls  a        schema:Book ;
#         dcterms:creator        authors:Ernest_Hemingway ;
#         dcterms:title          "For Whom the Bell Tolls" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_10  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 10 - The Far Side of the World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Colorado_Kid  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Colorado Kid" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Soft_Come_Dragons  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Soft Come The Dragons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_14  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 14 - Lords and Ladies" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_18  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 18 - Divided in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_04  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 04 - The Bitten" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Jack_Reacher_11  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 11 - Bad Luck and Trouble" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sole_Survivor  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy , authors:Dean_Koontz ;
#         dcterms:title          "Sole Survivor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Woods  a                   schema:Book ;
#         dcterms:creator        authors:Tana_French ;
#         dcterms:title          "In the Woods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bell_Jar  a                   schema:Book ;
#         dcterms:creator        authors:Sylvia_Plath ;
#         dcterms:title          "The Bell Jar" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_27  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 27 - The Last Hero" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_8  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 8 - Sudden Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tempest  a                    schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "The Tempest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_08  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 08 - City of Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:New_Earth  a                  schema:Book ;
#         dcterms:creator        authors:Eckhart_Tolle ;
#         dcterms:title          "A New Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Devils_Heart  a               schema:Book ;
#         dcterms:creator        authors:William_Johnstone ;
#         dcterms:title          "The Devils Heart" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Henry_Thompson_03  a          schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Henry Thompson 03 - A Dangerous Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fire_Upon_Deep  a             schema:Book ;
#         dcterms:creator        authors:Vernor_Vinge ;
#         dcterms:title          "A Fire Upon the Deep" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dispatch  a                   schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "Dispatch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Magician_Apprentice  a        schema:Book ;
#         dcterms:creator        authors:Raymond_E_Feist ;
#         dcterms:title          "Magician, Apprentice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Percy_Jackson_1  a            schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "Percy Jackson 1 - The Lightning Thief" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dominion  a                   schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "Dominion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:End_Fed  a                    schema:Book ;
#         dcterms:creator        authors:Ron_Paul ;
#         dcterms:title          "End the Fed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mona_Lisa_Overdrive  a        schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Mona Lisa Overdrive" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Just_After_Sunset  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Just After Sunset" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deception_Point2  a           schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Deception Point" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Trainspotting  a              schema:Book ;
#         dcterms:creator        authors:Irvine_Welsh ;
#         dcterms:title          "Trainspotting" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lord_of_Light  a              schema:Book ;
#         dcterms:creator        authors:Roger_Zelazny ;
#         dcterms:title          "Lord of Light" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Girl_Kicked_Hornets_Nest
#         a                      schema:Book ;
#         dcterms:creator        authors:Stieg_Larsson ;
#         dcterms:title          "The Girl Who Kicked the Hornet's Nest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cycle_of_Werewolf  a          schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Cycle of the Werewolf" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Drink_Before_War  a           schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "A Drink Before the War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Riptide  a                    schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Riptide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Die_Trying  a                 schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Die Trying" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Galapagos  a                  schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Galapagos" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Drink_for_a_Reason
#         a                      schema:Book ;
#         dcterms:creator        authors:David_Cross ;
#         dcterms:title          "I Drink for a Reason" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_04  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 04 - Lover Revealed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_08
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 08 - The Hostile Hospital" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Two_Minute_Rule  a            schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "The Two Minute Rule" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unloved  a                    schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Unloved" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Mistborn_03  a                schema:Book ;
#         dcterms:creator        authors:Brandon_Sanderson ;
#         dcterms:title          "Mistborn 03 - The Hero of Ages" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Never_Let_Me_Go  a            schema:Book ;
#         dcterms:creator        authors:Kazuo_Ishiguro ;
#         dcterms:title          "Never Let Me Go" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Moll_Flanders  a              schema:Book ;
#         dcterms:creator        authors:Daniel_Defoe ;
#         dcterms:title          "Moll Flanders" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Andromeda_Strain  a           schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "The Andromeda Strain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Inheritance_Cycle_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Christopher_Paolini ;
#         dcterms:title          "The Inheritance Cycle 03 - Brisingr" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_07  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 07 - A Question of Time" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Tower_05  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 05 - Wolves of the Calla" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Word_of_Honor  a              schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "Word of Honor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Freedom  a                    schema:Book ;
#         dcterms:creator        authors:Jonathan_Franzen ;
#         dcterms:title          "Freedom" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unbroken_WWII_Story_Survival
#         a                      schema:Book ;
#         dcterms:creator        authors:Laura_Hillenbrand ;
#         dcterms:title          "Unbroken, A World War II Story of Survival" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_06  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 06 - The Outlaw Demon Wails" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:We_Living  a                  schema:Book ;
#         dcterms:creator        authors:Ayn_Rand ;
#         dcterms:title          "We the Living" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Book_Of_Counted_Sorrows
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Book Of Counted Sorrows" , "Book Of Counted Sorrows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_13  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 13 - Seduction in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ollies_Hands  a               schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Ollie's Hands" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:What_is_What  a               schema:Book ;
#         dcterms:creator        authors:Dave_Eggers ;
#         dcterms:title          "What is the What" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_22  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 22 - The Last Continent" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Steven_Wright_Humor  a        schema:Book ;
#         dcterms:creator        authors:Steven_Wright ;
#         dcterms:title          "Steven Wright Humor" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_04  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 04 - God Emperor of Dune" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Flesh_In_Furnace  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Flesh In The Furnace" , "Flesh In The Furnace" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Insomnia  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Insomnia" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_3  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 3 - Eyes of Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_26  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 26 - Strangers in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Journey_to_Center_of_Earth
#         a                      schema:Book ;
#         dcterms:creator        authors:Jules_Verne ;
#         dcterms:title          "A Journey to the Center of the Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_35  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 35 - Wintersmith" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_03  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 03 - The Concrete Blonde" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Airframe  a                   schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Airframe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prophet_of_Doom  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Prophet of Doom" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Collected_Works_Jules_Verne
#         a                      schema:Book ;
#         dcterms:creator        authors:Jules_Verne ;
#         dcterms:title          "Collected Works of Jules Verne" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brief_History_of_Time
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_Hawking ;
#         dcterms:title          "A Brief History of Time" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Am_Ozzy  a                  schema:Book ;
#         dcterms:creator        authors:Ozzy_Osbourne ;
#         dcterms:title          "I Am Ozzy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jason_Bourne_03  a            schema:Book ;
#         dcterms:creator        authors:Robert_Ludlum ;
#         dcterms:title          "Jason Bourne 03 - The Bourne Ultimatum" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ghost_Story  a                schema:Book ;
#         dcterms:creator        authors:Peter_Straub ;
#         dcterms:title          "Ghost Story" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_05  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 05 - Brimstone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Echoes  a                     schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Echoes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cobra_Event  a                schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "The Cobra Event" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Angels_and_Demons  a          schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Angels and Demons" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Under_Dome  a                 schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Under the Dome" , "Under The Dome" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" , "mobi" .
#
# ebooks:Alas_Babylon  a               schema:Book ;
#         dcterms:creator        authors:Pat_Frank ;
#         dcterms:title          "Alas, Babylon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Machine_of_Death  a           schema:Book ;
#         dcterms:creator        authors:Misc ;
#         dcterms:title          "Machine of Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Corner_His_Eye  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "In The Corner of His Eye" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stiff_Curious_Lives  a        schema:Book ;
#         dcterms:creator        authors:Mary_Roach ;
#         dcterms:title          "Stiff, The Curious Lives of Human Cadavers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Good_Guy  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Good Guy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eyes_Of_Darkness  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Eyes Of Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Book_of_New_Sun_01  a         schema:Book ;
#         dcterms:creator        authors:Gene_Wolfe ;
#         dcterms:title          "Book of the New Sun 01 - Shadow & Claw" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shopaholic_and_Sister
#         a                      schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Shopaholic and Sister" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fifty_Years_All_Be_Chicks
#         a                      schema:Book ;
#         dcterms:creator        authors:Adam_Carolla ;
#         dcterms:title          "In Fifty Years We'll All Be Chicks" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_06  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 06 - Faith of the Fallen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Seven_Habits_Effective_People
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_Covey ;
#         dcterms:title          "Seven Habits of Highly Effective People" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pale_Blue_Dot  a              schema:Book ;
#         dcterms:creator        authors:Carl_Sagan ;
#         dcterms:title          "Pale Blue Dot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:N_Noose  a                    schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "N is for Noose" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Psychomech_01  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Psychomech 01 - Psychomech" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Series_Unfortunate_Events_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 03 - The Wide Window" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Then_There_Were_None
#         a                      schema:Book ;
#         dcterms:creator        authors:Agatha_Christie ;
#         dcterms:title          "And Then There Were None" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Thunderhead  a                schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Thunderhead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sum_of_All_Fears  a           schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "The Sum of All Fears" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Belgariad_02  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Belgariad 02 - Queen of Sorcery" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shopaholic_Takes_Manhattan
#         a                      schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Shopaholic Takes Manhattan" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Genius_Life_Science_Richard_Feynman
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Gleick ;
#         dcterms:title          "Genius, The Life and Science of Richard Feynman" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dracula_02  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 02 - The Holmes-Dracula File" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Oliver_Twist  a               schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "Oliver Twist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Virgil_Flowers1  a            schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Virgil Flowers1 - Dark of the Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prince_and_Pauper  a          schema:Book ;
#         dcterms:creator        authors:Mark_Twain ;
#         dcterms:title          "The Prince and the Pauper" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:UR     a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "UR" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tropic_of_Cancer  a           schema:Book ;
#         dcterms:creator        authors:Henry_Miller ;
#         dcterms:title          "Tropic of Cancer" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_01  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 01 - Dead Witch Walking" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Silmarillion  a               schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Silmarillion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:White_Jazz  a                 schema:Book ;
#         dcterms:creator        authors:James_Ellroy ;
#         dcterms:title          "White Jazz" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Plum_Spooky  a                schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Plum Spooky" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Phantom_Tollbooth  a          schema:Book ;
#         dcterms:creator        authors:Norton_Juster ;
#         dcterms:title          "The Phantom Tollbooth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_21  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 21 - Origin in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Flatland  a                   schema:Book ;
#         dcterms:creator        authors:Edwin_Abbott ;
#         dcterms:title          "Flatland" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sentimental_Education
#         a                      schema:Book ;
#         dcterms:creator        authors:Gustave_Flaubert ;
#         dcterms:title          "Sentimental Education" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pearl  a                      schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "The Pearl" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_06  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 06 - Shadow of the Hegemon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kidd_2  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Kidd 2 - The Empress File" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Candide  a                    schema:Book ;
#         dcterms:creator        authors:Voltaire ;
#         dcterms:title          "Candide" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Broker  a                     schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Broker" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_30  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 30 - The Wee Free Men" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bel_Canto  a                  schema:Book ;
#         dcterms:creator        authors:Ann_Patchett ;
#         dcterms:title          "Bel Canto" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pitt_4  a                 schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Joe Pitt 4 - Every Last Drop" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_08  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 08 - A Savage Place" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Infected  a                   schema:Book ;
#         dcterms:creator        authors:Scott_Sigler ;
#         dcterms:title          "Infected" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" , "mobi" .
#
# ebooks:Rabbit_04  a                  schema:Book ;
#         dcterms:creator        authors:John_Updike ;
#         dcterms:title          "Rabbit 04 - Rabbit at Rest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eaters_of_Dead  a             schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Eaters of the Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gone_Baby_Gone  a             schema:Book ;
#         dcterms:creator        authors:Dennis_Lehane ;
#         dcterms:title          "Gone, Baby, Gone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lightning  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Lightning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_11  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 11 - The Closers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codeword_Pentagon  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Codeword Pentagon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shock_Wave  a                 schema:Book ;
#         dcterms:creator        authors:Clive_Cussler ;
#         dcterms:title          "Shock Wave" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chelsea_Chelsea_Bang_Bang
#         a                      schema:Book ;
#         dcterms:creator        authors:Chelsea_Handler ;
#         dcterms:title          "Chelsea Chelsea Bang Bang" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bruno  a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Bruno" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:S_Silence  a                  schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "S is for Silence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Twilight_03  a                schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "Twilight 03 - Eclipse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Charlie_Chocolate_Factory
#         a                      schema:Book ;
#         dcterms:creator        authors:Roald_Dahl ;
#         dcterms:title          "Charlie and the Chocolate Factory" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rainmaker  a                  schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Rainmaker" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Judge_and_Jury  a             schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Judge and Jury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shardik  a                    schema:Book ;
#         dcterms:creator        authors:Richard_Adams ;
#         dcterms:title          "Shardik" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deepness_in_Sky  a            schema:Book ;
#         dcterms:creator        authors:Vernor_Vinge ;
#         dcterms:title          "A Deepness in the Sky" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_01  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 01 - Wizard's First Rule" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Heroin_Diaries  a             schema:Book ;
#         dcterms:creator        authors:Nikki_Sixx ;
#         dcterms:title          "The Heroin Diaries" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Demon_Haunted_World  a        schema:Book ;
#         dcterms:creator        authors:Carl_Sagan ;
#         dcterms:title          "The Demon Haunted World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Naked_Lunch  a                schema:Book ;
#         dcterms:creator        authors:William_S_Burroughs ;
#         dcterms:title          "Naked Lunch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Association  a                schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Association" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Of_Woods  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dark Of The Woods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stranger  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "People, Places & Things - The Stranger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_07  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 07 - Lost Years 02 - Resurgence" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Series_Unfortunate_Events_11
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 11 - The Grim Grotto" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sigma_Force_03  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 03 - Black Order" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malloreon_03  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Malloreon 03 - Demon Lord of Karanda" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Native_Son  a                 schema:Book ;
#         dcterms:creator        authors:Richard_Wright ;
#         dcterms:title          "Native Son" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Life_Expectancy  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Life Expectancy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cell   a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Cell" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:An_Object_of_Beauty  a        schema:Book ;
#         dcterms:creator        authors:Steve_Martin ;
#         dcterms:title          "An Object of Beauty" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Angel_Trilogy_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Brent_Weeks ;
#         dcterms:title          "Night Angel Trilogy 02 - Shadow's Edge" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Poisonwood_Bible  a           schema:Book ;
#         dcterms:creator        authors:Barbara_Kingsolver ;
#         dcterms:title          "The Poisonwood Bible" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Minority_Report  a            schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "The Minority Report" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Picture_of_Dorian_Gray
#         a                      schema:Book ;
#         dcterms:creator        authors:Oscar_Wilde ;
#         dcterms:title          "The Picture of Dorian Gray" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Siddhartha  a                 schema:Book ;
#         dcterms:creator        authors:Hermann_Hesse ;
#         dcterms:title          "Siddhartha" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_01  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 01 - Ender's Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dead_Mans_Song  a             schema:Book ;
#         dcterms:creator        authors:Jonathan_Maberry ;
#         dcterms:title          "Dead Man's Song" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Succubi  a                    schema:Book ;
#         dcterms:creator        authors:Edward_Lee ;
#         dcterms:title          "Succubi" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Spenser_03  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 03 - Mortal Stakes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Let_Right_One_In  a           schema:Book ;
#         dcterms:creator        authors:John_A_Lindquist ;
#         dcterms:title          "Let the Right One In" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bleachers  a                  schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "Bleachers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chase2  a                     schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Chase" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Spenser_16  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 16 - Playmates" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Disloyal_Opposition  a        schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Disloyal Opposition" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elegant_Universe  a           schema:Book ;
#         dcterms:creator        authors:Brian_Greene ;
#         dcterms:title          "The Elegant Universe" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:You_Might_Be_a_Zombie
#         a                      schema:Book ;
#         dcterms:creator        authors:Cracked ;
#         dcterms:title          "You Might Be a Zombie and Other Bad News" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Deception_Point  a            schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "Deception Point" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Eleventh_Hour  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Eleventh Hour" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Man_Without_a_Country
#         a                      schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "A Man Without a Country" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_29  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 29 - Widow's Walk" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Flow_My_Tears  a              schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "Flow My Tears, The Policeman Said" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scorched_Earth  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Scorched Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_05  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 05 - Voodoo River" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:God_Project  a                schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "God Project" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Prey_12  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 12 - Chosen Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Outsiders  a                  schema:Book ;
#         dcterms:creator        authors:SE_Hinton ;
#         dcterms:title          "The Outsiders" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Second_Chance  a              schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "2nd Chance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Air_Raid  a                   schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Air Raid" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Argument_of_Kings
#         a                      schema:Book ;
#         dcterms:creator        authors:Joe_Abercrombie ;
#         dcterms:title          "Last Argument of Kings" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_09  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 09 - Point of Origin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Day_Late_Dollar_Short
#         a                      schema:Book ;
#         dcterms:creator        authors:Terry_McMillan ;
#         dcterms:title          "A Day Late and a Dollar Short" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_02  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 02 - Wamphyri" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malazan_Book_of_Fallen_06
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 06 - The Bonehunters" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Angry_White_Mailmen  a        schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Angry White Mailmen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Memory_Keepers_Daughter
#         a                      schema:Book ;
#         dcterms:creator        authors:Kim_Edwards ;
#         dcterms:title          "The Memory Keeper's Daughter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Haunted_Earth  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Haunted Earth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Subterranean  a               schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Subterranean" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Codex_Alera_06  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 06 - First Lord's Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Moral_Landscape  a            schema:Book ;
#         dcterms:creator        authors:Sam_Harris ;
#         dcterms:title          "The Moral Landscape" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_08  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 08 - Night and Day" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Before_They_Are_Hanged
#         a                      schema:Book ;
#         dcterms:creator        authors:Joe_Abercrombie ;
#         dcterms:title          "Before They Are Hanged" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Outliers  a                   schema:Book ;
#         dcterms:creator        authors:Malcolm_Gladwell ;
#         dcterms:title          "Outliers, The Story of Success" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:I_Hope_They_Serve_Beer_In_Hell
#         a                      schema:Book ;
#         dcterms:creator        authors:Tucker_Max ;
#         dcterms:title          "I Hope They Serve Beer In Hell" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Trial  a                      schema:Book ;
#         dcterms:creator        authors:Franz_Kafka ;
#         dcterms:title          "The Trial" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_06  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 06 - The Fires of Heaven" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Arabian_Nightmare  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Arabian Nightmare" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Northanger_Abbey  a           schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Northanger Abbey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crime_and_Punishment
#         a                      schema:Book ;
#         dcterms:creator        authors:Fyodor_Dostoevsky ;
#         dcterms:title          "Crime and Punishment" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_06  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 06 - The Land of Painted Caves" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Walk_to_Remember  a           schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "A Walk to Remember" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_08  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 08 - Proven Guilty" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Revolution  a                 schema:Book ;
#         dcterms:creator        authors:Ron_Paul ;
#         dcterms:title          "The Revolution" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_08
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 08 - From Dead to Worse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Murder_Mysteries  a           schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Murder Mysteries" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Blood_Bound  a                schema:Book ;
#         dcterms:creator        authors:Patricia_Briggs ;
#         dcterms:title          "Blood Bound" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Baroque_Cycle_03  a           schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "The Baroque Cycle 03 - The System of the World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Skull_Duggery  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Skull Duggery" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Misfortune_Teller  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Misfortune Teller" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Poet   a                      schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "The Poet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_06  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 06 - Harry Potter and the Half-Blood Prince" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Man_from_St_Petersburg
#         a                      schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "The Man from St. Petersburg" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Five_People_In_Heaven
#         a                      schema:Book ;
#         dcterms:creator        authors:Mitch_Albom ;
#         dcterms:title          "The Five People You Meet In Heaven" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_11  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 11 - Valediction" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tawny_Man_03  a               schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Tawny Man 03 - Fool's Fate" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitchhiker_01  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Hitchhiker 01 - The Hitchhiker's Guide to the Galaxy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Imajica  a                    schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "Imajica" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Killer_Watts  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Killer Watts" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Seventh_Son  a                schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Seventh Son" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_24  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 24 - Small Vices" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tuesdays_With_Morrie
#         a                      schema:Book ;
#         dcterms:creator        authors:Mitch_Albom ;
#         dcterms:title          "Tuesdays With Morrie" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Canticle_for_Leibowitz
#         a                      schema:Book ;
#         dcterms:creator        authors:Walter_Miller ;
#         dcterms:title          "A Canticle for Leibowitz" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dreamcatcher  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Dreamcatcher" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Amber_Room  a                 schema:Book ;
#         dcterms:creator        authors:Steve_Berry ;
#         dcterms:title          "The Amber Room" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Chronicles_of_Narnia_04
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 04 - The Silver Chair" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Feed   a                      schema:Book ;
#         dcterms:creator        authors:Mira_Grant ;
#         dcterms:title          "Feed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stars_My_Destination
#         a                      schema:Book ;
#         dcterms:creator        authors:Alfred_Bester ;
#         dcterms:title          "The Stars My Destination" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Road_Virus_Heads_North
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Road Virus Heads North" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Red_Badge_of_Courage
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_Crane ;
#         dcterms:title          "The Red Badge of Courage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Frankenstein_02  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Frankenstein - 02 - City Of Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Atonement  a                  schema:Book ;
#         dcterms:creator        authors:Ian_McEwan ;
#         dcterms:title          "Atonement" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Childhoods_End  a             schema:Book ;
#         dcterms:creator        authors:Arthur_C_Clarke ;
#         dcterms:title          "Childhood's End" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_37  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 37 - The Professional" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_06  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 06 - The Killing Dance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_20  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 20 - Storm Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_04  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 04 - Cruel and Unusual" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:An_Evening_at_Gods  a         schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "An Evening at God's" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_08
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 08 - Blood and Gold" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Just_Kids  a                  schema:Book ;
#         dcterms:creator        authors:Patti_Smith ;
#         dcterms:title          "Just Kids" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Calls_Green_Falcon
#         a                      schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Night Calls The Green Falcon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Malazan_Book_of_Fallen_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 01 - Gardens of the Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Last_Juror  a                 schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Last Juror" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Power_of_Myth  a              schema:Book ;
#         dcterms:creator        authors:Joseph_Campbell ;
#         dcterms:title          "The Power of Myth" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_19  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 19 - Bullet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_07  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 07 - Seven Up" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cryptonomicon  a              schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "Cryptonomicon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Resident_Evil_03  a           schema:Book ;
#         dcterms:creator        authors:SD_Perry ;
#         dcterms:title          "Resident Evil 03 - City Of The Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Passage  a                    schema:Book ;
#         dcterms:creator        authors:Justin_Cronin ;
#         dcterms:title          "The Passage" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_06  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 06 - The Fortune of War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_03  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 03 - Death in Paradise" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex_Alera_01  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 01 - Furies of Calderon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:World_Without_Us  a           schema:Book ;
#         dcterms:creator        authors:Alan_Weisman ;
#         dcterms:title          "The World Without Us" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scariest_Thing_I_Know
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Scariest Thing I Know" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_10  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 10 - E-Branch 03 - Avengers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Homing  a                     schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Homing" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Tell_All  a                   schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Tell-All" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lies_My_Teacher_Told_Me
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Loewen ;
#         dcterms:title          "Lies My Teacher Told Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Survival_Course  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Survival Course" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:On_Road  a                    schema:Book ;
#         dcterms:creator        authors:Jack_Kerouac ;
#         dcterms:title          "On The Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_07  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 07 - Persuader" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bidding_War  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Bidding War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Short_Second_Life_Bree_Tanner
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "The Short Second Life of Bree Tanner" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_19  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 19 - The Hundred Days" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Timeline  a                   schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Timeline" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Living_Dead_2  a              schema:Book ;
#         dcterms:creator        authors:John_Joseph_Adams ;
#         dcterms:title          "The Living Dead 2" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_01  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 01 - The Eye of the World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hot_Zone  a                   schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "The Hot Zone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bad_Place  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Bad Place" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:A_Alibi  a                    schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "A is for Alibi" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_04  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 04 - Foundation's Edge" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_01  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 01 - The Clan of the Cave Bear" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Patriot_Games  a              schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "Patriot Games" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:AntiMan  a                    schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Anti-Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Whispers  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Whispers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_03  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 03 - Grave Peril" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 03 - Club Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Name_of_Rose  a               schema:Book ;
#         dcterms:creator        authors:Umberto_Eco ;
#         dcterms:title          "The Name of the Rose" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_01  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 01 - Harry Potter and the Sorcerer's Stone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Summoning  a                  schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Summoning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Taking  a                     schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Taking" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mount_Dragon  a               schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Mount Dragon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Brother_Odd  a                schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Brother Odd" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Family  a                     schema:Book ;
#         dcterms:creator        authors:Jeff_Sharlet ;
#         dcterms:title          "The Family" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shopaholic_and_Baby  a        schema:Book ;
#         dcterms:creator        authors:Sophie_Kinsella ;
#         dcterms:title          "Shopaholic and Baby" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dead_Zone  a                  schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dead Zone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hamlet  a                     schema:Book ;
#         dcterms:creator        authors:William_Shakespeare ;
#         dcterms:title          "Hamlet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_32  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 32 - Cold Service" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:History_of_God  a             schema:Book ;
#         dcterms:creator        authors:Karen_Armstrong ;
#         dcterms:title          "A History of God" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Guns_Germs_Steel  a           schema:Book ;
#         dcterms:creator        authors:Jared_Diamond ;
#         dcterms:title          "Guns, Germs and Steel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_01  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 01 - Guilty Pleasures" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Coin_of_Realm  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Coin of the Realm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_of_Tiger  a             schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Night of the Tiger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Fall  a                 schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "Night Fall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 03 - The Queen of the Damned" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Essential_Tales_and_Poems
#         a                      schema:Book ;
#         dcterms:creator        authors:Edgar_Allan_Poe ;
#         dcterms:title          "Essential Tales and Poems" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hours  a                      schema:Book ;
#         dcterms:creator        authors:Michael_Cunningham ;
#         dcterms:title          "The Hours" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_12  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 12 - Blow Fly" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ultimate_Hitchhikers_Guide
#         a                      schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "The Ultimate Hitchhiker's Guide to the Galaxy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Empire_Dreams  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Empire Dreams" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_14  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 14 - Danse Macabre" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_02  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 02 - Two for the Dough" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Snatcher_1  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Snatcher 1" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_01  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 01 - Master and Commander" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Physics_of_Impossible
#         a                      schema:Book ;
#         dcterms:creator        authors:Michio_Kaku ;
#         dcterms:title          "Physics of the Impossible" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_05  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 05 - Sourcery" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Big_Sleep  a                  schema:Book ;
#         dcterms:creator        authors:Raymond_Chandler ;
#         dcterms:title          "The Big Sleep" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Portnoys_Complaint  a         schema:Book ;
#         dcterms:creator        authors:Philip_Roth ;
#         dcterms:title          "Portnoy's Complaint" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_09  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 09 - Loyalty in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Regulators  a                 schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Regulators" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_15  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 15 - Finger Lickin' Fifteen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_02  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 02 - Die Trying" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_14  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 14 - The Nutmeg Of Consolation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cutting_for_Stone  a          schema:Book ;
#         dcterms:creator        authors:Abraham_Verghese ;
#         dcterms:title          "Cutting for Stone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_18  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 18 - Maskerade" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Player_Piano  a               schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Player Piano" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Greywalker_02  a              schema:Book ;
#         dcterms:creator        authors:Kat_Richardson ;
#         dcterms:title          "Greywalker 02 - Poltergeist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Vampire_Huntress_08  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 08 - The Wicked" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Les_Miserables  a             schema:Book ;
#         dcterms:creator        authors:Victor_Hugo ;
#         dcterms:title          "Les Miserables" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dragonfly  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Dragonfly" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Divine_Comedy  a              schema:Book ;
#         dcterms:creator        authors:Dante_Alighieri ;
#         dcterms:title          "The Divine Comedy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_15  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 15 - Worth Dying For" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Likeness  a                   schema:Book ;
#         dcterms:creator        authors:Tana_French ;
#         dcterms:title          "The Likeness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prince_of_Nothing_03
#         a                      schema:Book ;
#         dcterms:creator        authors:R_Scott_Bakker ;
#         dcterms:title          "Prince of Nothing 03 - The Thousandfold Thought" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elegance_of_Hedgehog
#         a                      schema:Book ;
#         dcterms:creator        authors:Muriel_Barbery ;
#         dcterms:title          "The Elegance of the Hedgehog" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Roadwork  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Roadwork" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Line_of_Succession  a         schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Line of Succession" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:How_to_Survive_End_of_World
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Wesley_Rawles ;
#         dcterms:title          "How to Survive the End of the World as We Know It" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dexter_03  a                  schema:Book ;
#         dcterms:creator        authors:Jeff_Lindsay ;
#         dcterms:title          "Dexter 03 - Dexter in the Dark" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Demolition_Angel  a           schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Demolition Angel" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_11  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 11 - Turn Coat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Father_to_Son  a              schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Father to Son" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Christine  a                  schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Christine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Adventures_Kavalier_Clay
#         a                      schema:Book ;
#         dcterms:creator        authors:Michael_Chabon ;
#         dcterms:title          "The Amazing Adventures of Kavalier and Clay" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:P_Peril  a                    schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "P is for Peril" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:His_Dark_Materials_03
#         a                      schema:Book ;
#         dcterms:creator        authors:Philip_Pullman ;
#         dcterms:title          "His Dark Materials 03 - The Amber Spyglass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Revelation  a                 schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Revelation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Percy_Jackson_5  a            schema:Book ;
#         dcterms:creator        authors:Rick_Riordan ;
#         dcterms:title          "Percy Jackson 5 - The Last Olympian" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Word_Processor_of_Gods
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Word Processor of the Gods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Isle_Of_Dogs  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Isle Of Dogs" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Other_Boleyn_Girl  a          schema:Book ;
#         dcterms:creator        authors:Philippa_Gregory ;
#         dcterms:title          "The Other Boleyn Girl" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Finn_Ryan_01  a               schema:Book ;
#         dcterms:creator        authors:Christopher_Paul ;
#         dcterms:title          "Finn Ryan 01 - Michelangelo's Notebook" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Hardest_Working_Man_in_Showbiz
#         a                      schema:Book ;
#         dcterms:creator        authors:Ron_Jeremy ;
#         dcterms:title          "The Hardest (Working) Man in Showbiz" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Teachings_of_Don_Juan
#         a                      schema:Book ;
#         dcterms:creator        authors:Carlos_Castaneda ;
#         dcterms:title          "The Teachings of Don Juan" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:American_Psycho  a            schema:Book ;
#         dcterms:creator        authors:Bret_Easton_Ellis ;
#         dcterms:title          "American Psycho" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Echo_Burning  a               schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Echo Burning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fall_of_Dream_Machine
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Fall of the Dream Machine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Olympos  a                    schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Olympos" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hyperion_Cantos_03  a         schema:Book ;
#         dcterms:creator        authors:Dan_Simmons ;
#         dcterms:title          "Hyperion Cantos 03 - Endymion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Watermelon  a                 schema:Book ;
#         dcterms:creator        authors:Marian_Keyes ;
#         dcterms:title          "Watermelon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Werewolf_Among_Us  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "A Werewolf Among Us" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_08  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 08 - Lover Mine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Difference_Engine  a          schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "The Difference Engine" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sky_is_Falling  a             schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "The Sky is Falling" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Liveship_Traders_01  a        schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Liveship Traders 01 - Ship of Magic" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sense_and_Sensibility
#         a                      schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Sense and Sensibility" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Into_Wild  a                  schema:Book ;
#         dcterms:creator        authors:Jon_Krakauer ;
#         dcterms:title          "Into the Wild" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Things_Fall_Apart  a          schema:Book ;
#         dcterms:creator        authors:Chinua_Achebe ;
#         dcterms:title          "Things Fall Apart" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_04  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 04 - Rapture in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_10  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 10 - Ten Big Ones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:D_Deadbeat  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "D is for Deadbeat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Devil_in_White_City  a        schema:Book ;
#         dcterms:creator        authors:Erik_Larson ;
#         dcterms:title          "Devil in the White City" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hammer_02  dcterms:creator    authors:Patricia_Cornwell ;
#         dcterms:title          "Hammer 02 - Southern Cross" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Darkfall  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Darkfall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_13  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 13 - Small Gods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_17  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 17 - Imitation in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_World_03  a           schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Vampire World 03 - Bloodwars" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Liseys_Story  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Lisey's Story" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Matter  a                     schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "Matter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crow_Road  a                  schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "The Crow Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_03  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 03 - The Hunted" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Jack_Reacher_10  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 10 - The Hard Way" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anansi_Boys  a                schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Anansi Boys" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ethan_Frome  a                schema:Book ;
#         dcterms:creator        authors:Edith_Wharton ;
#         dcterms:title          "Ethan Frome" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_26  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 26 - Thief of Time" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Song_of_Ice_and_Fire_04
#         a                      schema:Book ;
#         dcterms:creator        authors:George_RR_Martin ;
#         dcterms:title          "A Song of Ice and Fire 04 - A Feast for Crows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Freakonomics  a               schema:Book ;
#         dcterms:creator        authors:Steven_Levitt ;
#         dcterms:title          "Freakonomics" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_7  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 7 - Mind Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brethren  a                   schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Brethren" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Town   a                      schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Town" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Cosmos  dcterms:creator       authors:Carl_Sagan ;
#         dcterms:title          "Cosmos" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pattern_Recognition  a        schema:Book ;
#         dcterms:creator        authors:William_Gibson ;
#         dcterms:title          "Pattern Recognition" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Containment  a                schema:Book ;
#         dcterms:creator        authors:Christian_Cantrell ;
#         dcterms:title          "Containment" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_07  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 07 - A Darkness More Than Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Henry_Thompson_02  a          schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Henry Thompson 02 - Six Bad Things" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Handmaids_Tale  a             schema:Book ;
#         dcterms:creator        authors:Margaret_Atwood ;
#         dcterms:title          "The Handmaid's Tale" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_09  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 09 - Cemetery Dance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Disclosure  a                 schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Disclosure" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Cold_Blood  a              schema:Book ;
#         dcterms:creator        authors:Truman_Capote ;
#         dcterms:title          "In Cold Blood" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Unnatural_Selection  a        schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Unnatural Selection" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Red_Tent  a                   schema:Book ;
#         dcterms:creator        authors:Anita_Diamant ;
#         dcterms:title          "The Red Tent" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Up_Country  a                 schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "Up Country" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:O_Outlaw  a                   schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "O is for Outlaw" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Food_of_Gods  a               schema:Book ;
#         dcterms:creator        authors:Terence_McKenna ;
#         dcterms:title          "Food of the Gods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Connecticut_Yankee_in_King_Arthurs_Court
#         a                      schema:Book ;
#         dcterms:creator        authors:Mark_Twain ;
#         dcterms:title          "A Connecticut Yankee in King Arthur's Court" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ishmael  a                    schema:Book ;
#         dcterms:creator        authors:Daniel_Quinn ;
#         dcterms:title          "Ishmael" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Running_Man  a                schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Running Man" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lord_of_Rings_03  a           schema:Book ;
#         dcterms:creator        authors:JRR_Tolkien ;
#         dcterms:title          "The Lord of the Rings 03 - The Return of the King" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Clear_Present_Danger
#         a                      schema:Book ;
#         dcterms:creator        authors:Tom_Clancy ;
#         dcterms:title          "Clear and Present Danger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brotherhood_03  a             schema:Book ;
#         dcterms:creator        authors:Jessica_Bird ;
#         dcterms:title          "Brotherhood 03 - Lover Awakened" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Tender_is_Night  a            schema:Book ;
#         dcterms:creator        authors:F_Scott_Fitzgerald ;
#         dcterms:title          "Tender is the Night" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_07
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 07 - The Vile Village" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Duma_Key  a                   schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Duma Key" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mistborn_02  a                schema:Book ;
#         dcterms:creator        authors:Brandon_Sanderson ;
#         dcterms:title          "Mistborn 02 - The Well of Ascension" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:King_of_Torts  a              schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The King of Torts" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Alchemist  a                  schema:Book ;
#         dcterms:creator        authors:Paulo_Coelho ;
#         dcterms:title          "The Alchemist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Third_Secret  a               schema:Book ;
#         dcterms:creator        authors:Steve_Berry ;
#         dcterms:title          "The Third Secret" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dracula_06  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 06 - A Matter of Taste" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Inheritance_Cycle_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Christopher_Paolini ;
#         dcterms:title          "The Inheritance Cycle 02 - Eldest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dark_Tower_04  a              schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower 04 - Wizard and Glass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:White_Water  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "White Water" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mansfield_Park  a             schema:Book ;
#         dcterms:creator        authors:Jane_Austen ;
#         dcterms:title          "Mansfield Park" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Thousand_Autumns_Jacob_de_Zoet
#         a                      schema:Book ;
#         dcterms:creator        authors:David_Mitchell ;
#         dcterms:title          "The Thousand Autumns of Jacob de Zoet" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Holy_Blood_Holy_Grail
#         a                      schema:Book ;
#         dcterms:creator        authors:Michael_Baigent ;
#         dcterms:title          "Holy Blood Holy Grail" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Twenty_Thousand_Leagues_Under_Sea
#         a                      schema:Book ;
#         dcterms:creator        authors:Jules_Verne ;
#         dcterms:title          "Twenty Thousand Leagues Under the Sea" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Rachel_Morgan_05  a           schema:Book ;
#         dcterms:creator        authors:Kim_Harrison ;
#         dcterms:title          "Rachel Morgan 05 - For a Few Demons More" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_0  a          schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 04 - A Stroke of Midnight" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wetbones  a                   schema:Book ;
#         dcterms:creator        authors:John_Shirley ;
#         dcterms:title          "Wetbones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Icebound  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Icebound" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_12  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 12 - Betrayal in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dear_John  a                  schema:Book ;
#         dcterms:creator        authors:Nicholas_Sparks ;
#         dcterms:title          "Dear John" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Corrections  a                schema:Book ;
#         dcterms:creator        authors:Jonathan_Franzen ;
#         dcterms:title          "The Corrections" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Revolutionary_Road  a         schema:Book ;
#         dcterms:creator        authors:Richard_Yates ;
#         dcterms:title          "Revolutionary Road" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Violets_Are_Blue  a           schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "Violets Are Blue" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Plum_Island  a                schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "Plum Island" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Book_Thief  a                 schema:Book ;
#         dcterms:creator        authors:Markus_Zusak ;
#         dcterms:title          "The Book Thief" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dirty_Sexy_Politics  a        schema:Book ;
#         dcterms:creator        authors:Meghan_McCain ;
#         dcterms:title          "Dirty Sexy Politics" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nightmare_Journey  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Nightmare Journey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dune_03  a                    schema:Book ;
#         dcterms:creator        authors:Frank_Herbert ;
#         dcterms:title          "Dune 03 - Children of Dune" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_21  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 21 - Jingo" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Suck_It_Wonder_Woman
#         a                      schema:Book ;
#         dcterms:creator        authors:Olivia_Munn ;
#         dcterms:title          "Suck It, Wonder Woman!" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_2  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 2 - Shadow Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_25  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 25 - Creation in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Huntress_11  a        schema:Book ;
#         dcterms:creator        authors:Leslie_Esdaile_Banks ;
#         dcterms:title          "Vampire Huntress 11 - The Shadows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Heart_Of_Darkness  a          schema:Book ;
#         dcterms:creator        authors:Joseph_Conrad ;
#         dcterms:title          "Heart Of Darkness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:All_Quiet_on_Western_Front
#         a                      schema:Book ;
#         dcterms:creator        authors:Erich_Maria_Remarque ;
#         dcterms:title          "All Quiet on the Western Front" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:By_Light_Of_Moon  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "By The Light Of The Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Discworld_34  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 34 - Thud!" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_02  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 02 - The Black Ice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Million_Little_Pieces
#         a                      schema:Book ;
#         dcterms:creator        authors:James_Frey ;
#         dcterms:title          "A Million Little Pieces" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vanity_Fair  a                schema:Book ;
#         dcterms:creator        authors:William_Thackeray ;
#         dcterms:title          "Vanity Fair" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Strangers  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Strangers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:London_Bridges  a             schema:Book ;
#         dcterms:creator        authors:James_Patterson ;
#         dcterms:title          "London Bridges" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pendergast_04  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Pendergast 04 - Still Life With Crows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Rich_Dad_Poor_Dad  a          schema:Book ;
#         dcterms:creator        authors:Robert_Kiyosaki ;
#         dcterms:title          "Rich Dad, Poor Dad" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jason_Bourne_02  a            schema:Book ;
#         dcterms:creator        authors:Robert_Ludlum ;
#         dcterms:title          "Jason Bourne 02 - The Bourne Supremacy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Carrie  a                     schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Carrie" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Adventures_of_Huckleberry_Finn
#         a                      schema:Book ;
#         dcterms:creator        authors:Mark_Twain ;
#         dcterms:title          "The Adventures of Huckleberry Finn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Diamond_Age  a                schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "The Diamond Age" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:New_York  a                   schema:Book ;
#         dcterms:creator        authors:Edward_Rutherfurd ;
#         dcterms:title          "New York" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Generals_Daughter  a          schema:Book ;
#         dcterms:creator        authors:Nelson_DeMille ;
#         dcterms:title          "The General's Daughter" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:War_of_Worlds  a              schema:Book ;
#         dcterms:creator        authors:HG_Wells ;
#         dcterms:title          "The War of the Worlds" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Demon_Seed  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Demon Seed" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Once_and_Future_King
#         a                      schema:Book ;
#         dcterms:creator        authors:TH_White ;
#         dcterms:title          "The Once and Future King" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Breakfast_of_Champions
#         a                      schema:Book ;
#         dcterms:creator        authors:Kurt_Vonnegut ;
#         dcterms:title          "Breakfast of Champions" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Date_With_Death  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Date With Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_05  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 05 - Soul of the Fire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fool   a                      schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "Fool" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:A_Discovery_of_Witches
#         a                      schema:Book ;
#         dcterms:creator        authors:Deborah_Harkness ;
#         dcterms:title          "A Discovery of Witches" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Bad_Luck_and_Trouble
#         a                      schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Bad Luck and Trouble" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Madame_Bovary  a              schema:Book ;
#         dcterms:creator        authors:Gustave_Flaubert ;
#         dcterms:title          "Madame Bovary" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 02 - The Reptile Room" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Will_Grayson_Will_Grayson
#         a                      schema:Book ;
#         dcterms:creator        authors:John_Green ;
#         dcterms:title          "Will Grayson, Will Grayson" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Odd_Thomas_04  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Odd Thomas 04 - Odd Hours" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sphere  a                     schema:Book ;
#         dcterms:creator        authors:Michael_Crichton ;
#         dcterms:title          "Sphere" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Belgariad_01  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Belgariad 01 - Pawn of Prophecy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Romanov_Prophecy  a           schema:Book ;
#         dcterms:creator        authors:Steve_Berry ;
#         dcterms:title          "The Romanov Prophecy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dracula_01  a                 schema:Book ;
#         dcterms:creator        authors:Fred_Saberhagen ;
#         dcterms:title          "Dracula 01 - The Dracula Tape" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Alienist  a                   schema:Book ;
#         dcterms:creator        authors:Caleb_Carr ;
#         dcterms:title          "The Alienist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Farseer_Trilogy_03  a         schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Farseer Trilogy 03 - Assassin's Quest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fahrenheit_451  a             schema:Book ;
#         dcterms:creator        authors:Ray_Bradbury ;
#         dcterms:title          "Fahrenheit 451" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:American_Pastoral  a          schema:Book ;
#         dcterms:creator        authors:Philip_Roth ;
#         dcterms:title          "American Pastoral" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dirk_Gently_02  a             schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Dirk Gently 02 - The Long Dark Tea-Time of the Soul" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Woman_in_White  a             schema:Book ;
#         dcterms:creator        authors:Wilkie_Collins ;
#         dcterms:title          "The Woman in White" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anathem  a                    schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "Anathem" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Guardian  a                   schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Guardian" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Adventures_in_Wonderland
#         a                      schema:Book ;
#         dcterms:creator        authors:Lewis_Carroll ;
#         dcterms:title          "Alice's Adventures in Wonderland and Through the Looking-Glass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:In_Death_20  a                schema:Book ;
#         dcterms:creator        authors:Nora_Roberts ;
#         dcterms:title          "In Death 20 - Survivor in Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Circle_of_Friends  a          schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Circle of Friends" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Their_Eyes_Were_Watching_God
#         a                      schema:Book ;
#         dcterms:creator        authors:Zora_Neale_Hurston ;
#         dcterms:title          "Their Eyes Were Watching God" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Obamas_Wars  a                schema:Book ;
#         dcterms:creator        authors:Bob_Woodward ;
#         dcterms:title          "Obama's Wars" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Kidd_1  a                     schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Kidd 1 - The Fool's Run" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Funhouse  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Funhouse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Boneshaker  a                 schema:Book ;
#         dcterms:creator        authors:Cherie_Priest ;
#         dcterms:title          "Boneshaker" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Door_to_December  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Door to December" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Whitethorn_Woods  a           schema:Book ;
#         dcterms:creator        authors:Maeve_Binchy ;
#         dcterms:title          "Whitethorn Woods" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ender_05  a                   schema:Book ;
#         dcterms:creator        authors:Orson_Scott_Card ;
#         dcterms:title          "Ender 05 - Ender's Shadow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:World_Without_End  a          schema:Book ;
#         dcterms:creator        authors:Ken_Follett ;
#         dcterms:title          "World Without End" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Marley_and_Me  a              schema:Book ;
#         dcterms:creator        authors:John_Grogan ;
#         dcterms:title          "Marley & Me" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lost_Symbol  a                schema:Book ;
#         dcterms:creator        authors:Dan_Brown ;
#         dcterms:title          "The Lost Symbol" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pitt_3  a                 schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "Joe Pitt 3 - Half the Blood of Brooklyn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_07  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 07 - Early Autumn" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:My_Horizontal_Life  a         schema:Book ;
#         dcterms:creator        authors:Chelsea_Handler ;
#         dcterms:title          "My Horizontal Life, A Collection of One Night Stands" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Nightmares_Dreamscapes
#         a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Nightmares and Dreamscapes" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Encounter_Group  a            schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Encounter Group" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Frankenstein_Lost_Souls
#         a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Frankenstein - Lost Souls" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Rabbit_03  a                  schema:Book ;
#         dcterms:creator        authors:John_Updike ;
#         dcterms:title          "Rabbit 03 - Rabbit is Rich" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Bosch_10  a             schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Harry Bosch 10 - The Narrows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Southern_Cross  a             schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Southern Cross" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Twilight_02  a                schema:Book ;
#         dcterms:creator        authors:Stephenie_Meyer ;
#         dcterms:title          "Twilight 02 - New Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Watchers  a                   schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Watchers" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Forever_War  a                schema:Book ;
#         dcterms:creator        authors:Joe_Haldeman ;
#         dcterms:title          "The Forever War" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Origin_of_Species  a          schema:Book ;
#         dcterms:creator        authors:Charles_Darwin ;
#         dcterms:title          "The Origin of Species" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wasp_Factory  a               schema:Book ;
#         dcterms:creator        authors:Iain_Banks ;
#         dcterms:title          "The Wasp Factory" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sword_of_Truth_00  a          schema:Book ;
#         dcterms:creator        authors:Terry_Goodkind ;
#         dcterms:title          "Sword of Truth 00 - Debt of Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_09  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 09 - The Last Detective" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_16  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 16 - Invisible Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stuff_White_People_Like
#         a                      schema:Book ;
#         dcterms:creator        authors:Christian_Lander ;
#         dcterms:title          "Stuff White People Like" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Diary_of_Young_Girl  a        schema:Book ;
#         dcterms:creator        authors:Anne_Frank ;
#         dcterms:title          "The Diary of a Young Girl" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Crimson_Witch  a              schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Crimson Witch" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitler  a                     schema:Book ;
#         dcterms:creator        authors:Ian_Kershaw ;
#         dcterms:title          "Hitler" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_06  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 06 - Lost Years 01 - The Lost Years" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:East_of_Eden  a               schema:Book ;
#         dcterms:creator        authors:John_Steinbeck ;
#         dcterms:title          "East of Eden" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malloreon_02  a               schema:Book ;
#         dcterms:creator        authors:David_Eddings ;
#         dcterms:title          "Malloreon 02 - King of The Murgos" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Series_Unfortunate_Events_10
#         a                      schema:Book ;
#         dcterms:creator        authors:Lemony_Snicket ;
#         dcterms:title          "A Series of Unfortunate Events 10 - The Slippery Slope" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sigma_Force_02  a             schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Sigma Force 02 - Map Of Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dude_Wheres_My_Country
#         a                      schema:Book ;
#         dcterms:creator        authors:Michael_Moore ;
#         dcterms:title          "Dude, Where's My Country" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Infernal_Revenue  a           schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Infernal Revenue" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cash_Autobiography  a         schema:Book ;
#         dcterms:creator        authors:Johnny_Cash ;
#         dcterms:title          "Cash, The Autobiography" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Red_Queen  a                  schema:Book ;
#         dcterms:creator        authors:Philippa_Gregory ;
#         dcterms:title          "The Red Queen" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Night_Angel_Trilogy_01
#         a                      schema:Book ;
#         dcterms:creator        authors:Brent_Weeks ;
#         dcterms:title          "Night Angel Trilogy 01 - The Way of Shadows" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:To_Lighthouse  a              schema:Book ;
#         dcterms:creator        authors:Virginia_Woolf ;
#         dcterms:title          "To the Lighthouse" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Virtue_of_Selfishness
#         a                      schema:Book ;
#         dcterms:creator        authors:Ayn_Rand ;
#         dcterms:title          "The Virtue of Selfishness" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Black_Lightning  a            schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "Black Lightning" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Portable_Atheist  a           schema:Book ;
#         dcterms:creator        authors:Christopher_Hitchens ;
#         dcterms:title          "The Portable Atheist" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:LA_Confidential  a            schema:Book ;
#         dcterms:creator        authors:James_Ellroy ;
#         dcterms:title          "L.A. Confidential" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Lolita  a                     schema:Book ;
#         dcterms:creator        authors:Vladimir_Nabokov ;
#         dcterms:title          "Lolita" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shane_Schofield_04  a         schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Shane Schofield 04 - Hell Island" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Impact  a                     schema:Book ;
#         dcterms:creator        authors:Douglas_Preston ;
#         dcterms:title          "Impact" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mystic_Arts_Erasing_All_Signs_of_Death
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlie_Huston ;
#         dcterms:title          "The Mystic Arts of Erasing All Signs of Death" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:No_Country_Old_Men  a         schema:Book ;
#         dcterms:creator        authors:Cormac_McCarthy ;
#         dcterms:title          "No Country for Old Men" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Botany_of_Desire  a           schema:Book ;
#         dcterms:creator        authors:Michael_Pollan ;
#         dcterms:title          "The Botany of Desire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_02  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 02 - God Save the Child" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fight_Club  a                 schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Fight Club" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Snuff  a                      schema:Book ;
#         dcterms:creator        authors:Chuck_Palahniuk ;
#         dcterms:title          "Snuff" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Uncle_Toms_Cabin  a           schema:Book ;
#         dcterms:creator        authors:Harriet_Beecher_Stowe ;
#         dcterms:title          "Uncle Tom's Cabin" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_1  a                schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 16 - Scarpetta" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_15  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 15 - Crimson Joy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hitchhiker_05  a              schema:Book ;
#         dcterms:creator        authors:Douglas_Adams ;
#         dcterms:title          "Hitchhiker 05 - Mostly Harmless" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Black_Dahlia  a               schema:Book ;
#         dcterms:creator        authors:James_Ellroy ;
#         dcterms:title          "The Black Dahlia" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Frankenstein  a               schema:Book ;
#         dcterms:creator        authors:Mary_Shelley ;
#         dcterms:title          "Frankenstein" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pact   a                      schema:Book ;
#         dcterms:creator        authors:Jodi_Picoult ;
#         dcterms:title          "The Pact" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_28  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 28 - Potshot" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Elvis_Cole_04  a              schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Elvis Cole 04 - Free Fall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Prey_11  a                    schema:Book ;
#         dcterms:creator        authors:John_Sandford ;
#         dcterms:title          "Prey 11 - Easy Prey" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stinger  a                    schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Stinger" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Confederacy_of_Dunces
#         a                      schema:Book ;
#         dcterms:creator        authors:John_Kennedy_Toole ;
#         dcterms:title          "A Confederacy of Dunces" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Cujo   a                      schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Cujo" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Joe_Pike_02  a                schema:Book ;
#         dcterms:creator        authors:Robert_Crais ;
#         dcterms:title          "Joe Pike 02 - The First Rule" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Get_Shorty  a                 schema:Book ;
#         dcterms:creator        authors:Elmore_Leonard ;
#         dcterms:title          "Get Shorty" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_08  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 08 - Unnatural.Exprosure" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Theodore_Rex  a               schema:Book ;
#         dcterms:creator        authors:Edmund_Morris ;
#         dcterms:title          "Theodore Rex" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sherlock_Holmes_Illustrated
#         a                      schema:Book ;
#         dcterms:creator        authors:Arthur_Conan_Doyle ;
#         dcterms:title          "Sherlock Holmes Illustrated" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Fear_Loathing_Las_Vegas
#         a                      schema:Book ;
#         dcterms:creator        authors:Hunter_S_Thompson ;
#         dcterms:title          "Fear and Loathing in Las Vegas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Necroscope_01  a              schema:Book ;
#         dcterms:creator        authors:Brian_Lumley ;
#         dcterms:title          "Necroscope 01 - Necroscope" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Haunted_Vagina  a             schema:Book ;
#         dcterms:creator        authors:Carlton_Mellick ;
#         dcterms:title          "Haunted Vagina" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Malazan_Book_of_Fallen_05
#         a                      schema:Book ;
#         dcterms:creator        authors:Steven_Erikson ;
#         dcterms:title          "Malazan Book of the Fallen 05 - Midnight Tides" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pacific  a                    schema:Book ;
#         dcterms:creator        authors:Hugh_Ambrose ;
#         dcterms:title          "The Pacific" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Netherland  a                 schema:Book ;
#         dcterms:creator        authors:Joseph_ONeill ;
#         dcterms:title          "Netherland" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hannibal_03  a                schema:Book ;
#         dcterms:creator        authors:Thomas_Harris ;
#         dcterms:title          "Hannibal 03 - Hannibal" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Beyond_Good_and_Evil
#         a                      schema:Book ;
#         dcterms:creator        authors:Friedrick_Nietzsche ;
#         dcterms:title          "Beyond Good and Evil" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hunger_Games_03  a            schema:Book ;
#         dcterms:creator        authors:Suzanne_Collins ;
#         dcterms:title          "The Hunger Games 03 - Mockingjay" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Human_Stain  a                schema:Book ;
#         dcterms:creator        authors:Philip_Roth ;
#         dcterms:title          "The Human Stain" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Codex_Alera_05  a             schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Codex Alera 05 - Princeps' Fury" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Basic_Writing_of_Nietzsche
#         a                      schema:Book ;
#         dcterms:creator        authors:Friedrick_Nietzsche ;
#         dcterms:title          "Basic Writing of Nietzsche" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_07  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 07 - Stranger in Paradise" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Girl_Played_with_Fire
#         a                      schema:Book ;
#         dcterms:creator        authors:Stieg_Larsson ;
#         dcterms:title          "The Girl Who Played with Fire" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tooth_And_Nail  a             schema:Book ;
#         dcterms:creator        authors:Craig_DiLouie ;
#         dcterms:title          "Tooth And Nail" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Ground_Zero  a                schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Ground Zero" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:House_Of_Thunder  a           schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The House Of Thunder" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_05  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 05 - Lord of Chaos" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:No_One_Belongs_Here  a        schema:Book ;
#         dcterms:creator        authors:Miranda_July ;
#         dcterms:title          "No One Belongs Here More Than You" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Hornets_Nest  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "The Hornets Nest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:You_Suck  a                   schema:Book ;
#         dcterms:creator        authors:Christopher_Moore ;
#         dcterms:title          "You Suck" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Damnation_Game  a             schema:Book ;
#         dcterms:creator        authors:Clive_Barker ;
#         dcterms:title          "The Damnation Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Earths_Children_05  a         schema:Book ;
#         dcterms:creator        authors:Jean_Auel ;
#         dcterms:title          "Earth's Children 05 - The Shelters of Stone" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tales_in_Sand  a              schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Tales in the Sand" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Harry_Dresden_07  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 07 - Dead Beat" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Total_Recall  a               schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Total Recall" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_07
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 07 - All Together Dead" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:One_Hundred_Years_of_Solitude
#         a                      schema:Book ;
#         dcterms:creator        authors:Gabriel_Marquez ;
#         dcterms:title          "One Hundred Years of Solitude" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Baroque_Cycle_02  a           schema:Book ;
#         dcterms:creator        authors:Neal_Stephenson ;
#         dcterms:title          "The Baroque Cycle 02 - The Confusion" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jackie_Brown  a               schema:Book ;
#         dcterms:creator        authors:Elmore_Leonard ;
#         dcterms:title          "Jackie Brown" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tick_Tock  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Tick Tock" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Short_History_of_Everything
#         a                      schema:Book ;
#         dcterms:creator        authors:Bill_Bryson ;
#         dcterms:title          "A Short History of Nearly Everything" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Potter_05  a            schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "Harry Potter 05 - Harry Potter and the Order of the Phoenix" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_10  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 10 - The Widening Gyre" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tawny_Man_02  a               schema:Book ;
#         dcterms:creator        authors:Robin_Hobb ;
#         dcterms:title          "The Tawny Man 02 - Golden Fool" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mailman  a                    schema:Book ;
#         dcterms:creator        authors:Bentley_Little ;
#         dcterms:title          "The Mailman" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Star_Quest  a                 schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Star Quest" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:T_Trespass  a                 schema:Book ;
#         dcterms:creator        authors:Sue_Grafton ;
#         dcterms:title          "T is for Trespass" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:David_Copperfield  a          schema:Book ;
#         dcterms:creator        authors:Charles_Dickens ;
#         dcterms:title          "David Copperfield" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_23  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 23 - Chance" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Chronicles_of_Narnia_03
#         a                      schema:Book ;
#         dcterms:creator        authors:CS_Lewis ;
#         dcterms:title          "The Chronicles of Narnia 03 - The Voyage of the Dawn Treader" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Pelican_Brief  a              schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Pelican Brief" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Brave_New_World  a            schema:Book ;
#         dcterms:creator        authors:Aldous_Huxley ;
#         dcterms:title          "Brave New World" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:City_City  a                  schema:Book ;
#         dcterms:creator        authors:China_Mieville ;
#         dcterms:title          "The City & The City" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Children_Of_Storm  a          schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Children Of The Storm" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Associate  a                  schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Associate" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Tales_of_Beedle_Bard
#         a                      schema:Book ;
#         dcterms:creator        authors:JK_Rowling ;
#         dcterms:title          "The Tales of Beedle the Bard" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Shooting_Schedule  a          schema:Book ;
#         dcterms:creator        authors:Warren_Murphy ;
#         dcterms:title          "Shooting Schedule" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Frankenstein_01  a            schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Frankenstein - 01 - Prodigal Son" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Spenser_36  a                 schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Spenser 36 - Rough Weather" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Meredith_Gentry_08  a         schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Meredith Gentry 08 - Divine Misdemeanors" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Scarpetta_03  a               schema:Book ;
#         dcterms:creator        authors:Patricia_Cornwell ;
#         dcterms:title          "Scarpetta 03 - All That Remains" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_05  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 05 - Bloody Bones" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Right_Hand_of_Evil  a         schema:Book ;
#         dcterms:creator        authors:John_Saul ;
#         dcterms:title          "The Right Hand of Evil" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Shining  a                    schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Shining" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Vampire_Chronicles_07
#         a                      schema:Book ;
#         dcterms:creator        authors:Anne_Rice ;
#         dcterms:title          "The Vampire Chronicles 07 - Merrick" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Intensity  a                  schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "Intensity" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Solar  a                      schema:Book ;
#         dcterms:creator        authors:Ian_McEwan ;
#         dcterms:title          "Solar" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Mask   a                      schema:Book ;
#         dcterms:creator        authors:Dean_Koontz ;
#         dcterms:title          "The Mask" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Long_Walk  a                  schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Long Walk" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Anita_Blake_18  a             schema:Book ;
#         dcterms:creator        authors:Laurell_K_Hamilton ;
#         dcterms:title          "Anita Blake 18 - Flirt" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stephanie_Plum_06  a          schema:Book ;
#         dcterms:creator        authors:Janet_Evanovich ;
#         dcterms:title          "Stephanie Plum 06 - Hot Six" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Why_We_Get_Fat  a             schema:Book ;
#         dcterms:creator        authors:Gary_Taubes ;
#         dcterms:title          "Why We Get Fat and What To Do About It" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Testament  a                  schema:Book ;
#         dcterms:creator        authors:John_Grisham ;
#         dcterms:title          "The Testament" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_05  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 05 - Desolation Island" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Excavation  a                 schema:Book ;
#         dcterms:creator        authors:James_Rollins ;
#         dcterms:title          "Excavation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Discworld_09  a               schema:Book ;
#         dcterms:creator        authors:Terry_Pratchett ;
#         dcterms:title          "Discworld 09 - Eric" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Stone_02  a                   schema:Book ;
#         dcterms:creator        authors:Robert_B_Parker ;
#         dcterms:title          "Stone 02 - Trouble in Paradise" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_Reacher_06  a            schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Jack Reacher 06 - Without Fail" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Aubrey_Maturin_18  a          schema:Book ;
#         dcterms:creator        authors:Patrick_OBrian ;
#         dcterms:title          "Aubrey Maturin 18 - The Yellow Admiral" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sophies_Choice  a             schema:Book ;
#         dcterms:creator        authors:William_Styron ;
#         dcterms:title          "Sophie's Choice" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Warslut  a                    schema:Book ;
#         dcterms:creator        authors:Carlton_Mellick ;
#         dcterms:title          "Warslut" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Wheel_of_Time_00  a           schema:Book ;
#         dcterms:creator        authors:Robert_Jordan ;
#         dcterms:title          "Wheel of Time 00 - New Spring" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Geralds_Game  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "Gerald's Game" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Foundation_03  a              schema:Book ;
#         dcterms:creator        authors:Isaac_Asimov ;
#         dcterms:title          "Foundation 03 - Second Foundation" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Harry_Dresden_02  a           schema:Book ;
#         dcterms:creator        authors:Jim_Butcher ;
#         dcterms:title          "Harry Dresden 02 - Fool Moon" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Doom_City  a                  schema:Book ;
#         dcterms:creator        authors:Robert_McCammon ;
#         dcterms:title          "Doom City" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Water_for_Elephants  a        schema:Book ;
#         dcterms:creator        authors:Sara_Gruen ;
#         dcterms:title          "Water for Elephants" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Jack_West_03  a               schema:Book ;
#         dcterms:creator        authors:Matthew_Reilly ;
#         dcterms:title          "Jack West 03 - The Five Greatest Warriors" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Chasing_Dime  a               schema:Book ;
#         dcterms:creator        authors:Michael_Connelly ;
#         dcterms:title          "Chasing the Dime" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Sookie_Stackhouse_02
#         a                      schema:Book ;
#         dcterms:creator        authors:Charlaine_Harris ;
#         dcterms:title          "Sookie Stackhouse 02 - Living Dead in Dallas" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Good_Calories_Bad_Calories
#         a                      schema:Book ;
#         dcterms:creator        authors:Gary_Taubes ;
#         dcterms:title          "Good Calories, Bad Calories" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Valis  a                      schema:Book ;
#         dcterms:creator        authors:Philip_K_Dick ;
#         dcterms:title          "Valis" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Gone_Tomorrow  a              schema:Book ;
#         dcterms:creator        authors:Lee_Child ;
#         dcterms:title          "Gone Tomorrow" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Autobiography_Malcolm_X
#         a                      schema:Book ;
#         dcterms:creator        authors:Malcolm_X ;
#         dcterms:title          "The Autobiography of Malcolm X" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# ebooks:Dont_Panic  a                 schema:Book ;
#         dcterms:creator        authors:Neil_Gaiman ;
#         dcterms:title          "Don't Panic - The Official Guide to the Hitchikers Guide to the Galaxy" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "prc" .
#
# ebooks:Dark_Tower_V  a               schema:Book ;
#         dcterms:creator        authors:Stephen_King ;
#         dcterms:title          "The Dark Tower V - Prologue" ;
#         schema:bookFormat      schema:Ebook ;
#         schema:encodingFormat  "mobi" .
#
# }

# %% [markdown]
# #### Bootlegs

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# <http://www.connaissance.io/onto/biblio/boots>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-20" ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#   dcterms:description "Live music event records, cataloged and serialized in RDF." ;
#   rdfs:comment "Event dates are at times expressed as xxxx-01-01 (xsd:date), or the first day of the year when no known event date is recorded in files." ;
#   owl:imports <http://www.connaissance.io/onto/biblio/MusicGroup> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/SoloMusicArtist> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Developed by M Lane, Portland, Oregon" .
#
#
# boots:Yardbirds_Cambridge_MA_6.1.03
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Yardbirds Cambridge MA 6.1.03 fm" ;
#         dcterms:creator               bibliographica:Yardbirds ;
#         dcterms:date                  "2003-06-01"^^xsd:date ;
#         dcterms:title                 "Yardbirds Cambridge MA 6.1.03 fm" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Yardbirds_Cambridge_MA_6.1.03_fm.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Cambridge" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Yardbirds Cambridge MA 6.1.03 fm" .
#
# boots:BrianEno_Music_for_Nile
#         a                           schema:MusicRelease ;
#         rdfs:label                  "Brian Eno Music for Nile" ;
#         dcterms:creator             bibliographica:Brian_Eno ;
#         dcterms:title               "Brian Eno Music for Nile" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/BrianEno_Music_for_Nile.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Brian Eno Music for Nile" .
#
# boots:Zappa_Boston_11.9.74
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Boston 11.9.74 sbd" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1974-11-09"^^xsd:date ;
#         dcterms:title                 "Zappa Boston 11.9.74 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Boston_11.9.74_sbd.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Boston" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Zappa Boston 11.9.74 sbd" .
#
# boots:AniDiFranco_Stockholm_3.2.99
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Ani DiFranco - Stockholm 3.2.99 fm" ;
#         dcterms:creator               bibliographica:Ani_DiFranco ;
#         dcterms:date                  "1999-03-02"^^xsd:date ;
#         dcterms:title                 "Ani DiFranco - Stockholm 3.2.99 fm" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AniDiFranco_Stockholm_3.2.99.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Studion" , "Stockholm" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Ani DiFranco - Stockholm 3.2.99 fm" .
#
# boots:AdrianBelew_WorldCafe_8.14.06
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Power Trio World Cafe 8.14.06" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2006-08-14"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Power Trio World Cafe 8.14.06" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_WorldCafe_8.14.06.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "World Cafe" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Power Trio World Cafe 8.14.06" .
#
# boots:Zappa_Los_Angeles_7.22.84
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Los Angeles 7.22.84 sbd" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1984-07-22"^^xsd:date ;
#         dcterms:title                 "Zappa Los Angeles 7.22.84 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Los Angeles_7.22.84_sbd.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Palace Theater" , "Los Angeles" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Zappa Los Angeles 7.22.84 sbd" .
#
# boots:Al_Dimeola_World_Sinfonia_Tucson_2010
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Al Dimeola & World Sinfonia Tucson 2.18.10" ;
#         dcterms:creator               bibliographica:Al_DiMeola ;
#         dcterms:date                  "2010-02-18"^^xsd:date ;
#         dcterms:title                 "Al DiMeola - Tucson 2.18.10" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Al_Dimeola_Tucson_2010.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Rialto Theater" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Al Dimeola & World Sinfonia Tucson 2.18.10" .
#
# boots:Weather_Report_6.26.82
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Weather Report  6.26.82" ;
#         dcterms:creator               bibliographica:Weather_Report ;
#         dcterms:date                  "1982-06-26"^^xsd:date ;
#         dcterms:title                 "Weather Report  6.26.82" ;
#         bibliographica:locationVenue  "unknown" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Weather Report  6.26.82" .
#
# boots:BassDesires_Cambridge_1.22.85
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Bass Desires Cambridge, MA 1.22.85" ;
#         dcterms:creator               bibliographica:Bass_Desires ;
#         dcterms:date                  "1985-01-22"^^xsd:date ;
#         dcterms:title                 "Bass Desires Cambridge, MA 1.22.85" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BassDesires_Cambridge_1.22.85.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Cambridge, MA" , "Ryles Jazz Club" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Bass Desires Cambridge, MA 1.22.85" .
#
# boots:Zappa_Ann_Arbor_12.3.67
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Ann Arbor 12.3.67 sbd" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1967-12-03"^^xsd:date ;
#         dcterms:title                 "Zappa Ann Arbor 12.3.67 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Ann_Arbor_12.3.67_sbd.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Ann Arbor" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Zappa Ann Arbor 12.3.67 sbd" .
#
# boots:Björk_Glastonbury_6.22.07
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Björk Glastonbury Festival, UK 6.22.07" ;
#         dcterms:creator               bibliographica:Björk ;
#         dcterms:date                  "2007-06-22"^^xsd:date ;
#         dcterms:title                 "Björk - Glastonbury 2007" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Bjork_Glastonbury_6.22.07.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Glastonbury, UK" , "Glastonbury Festival" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Björk Glastonbury Festival, UK 6.22.07" .
#
# boots:Alejandro_Escovedo_Austin_3.18.10
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Alejandro Escovedo - Austin 3.18.10" ;
#         dcterms:creator               bibliographica:Alejandro_Escovedo ;
#         dcterms:date                  "2010-03-18"^^xsd:date ;
#         dcterms:title                 "Alejandro Escovedo - Austin 3.18.10" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AlejandroEscovedo_Austin_3.18.10.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Gibson Room at Maggie Maes" , "Austin" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Alejandro Escovedo - Austin 3.18.10" .
#
# boots:Zappa_Fillmore_East_11.13.70
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Fillmore East 11.13.70" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1970-11-13"^^xsd:date ;
#         dcterms:title                 "Zappa Fillmore East 11.13.70" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Fillmore_East_11.13.70.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "San Francisco" , "Fillmore East" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Fillmore East 11.13.70" .
#
# boots:AcousticAllstars_Alexandria_1.23.88
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Acoustic Allstars Alexandria, VA 1.23.88" ;
#         dcterms:creator               bibliographica:Acoustic_Allstars ;
#         dcterms:date                  "1988-01-23"^^xsd:date ;
#         dcterms:title                 "Acoustic Allstars Alexandria, VA 1.23.88" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AcousticAllstars_Alexandria.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Alexandria, VA" , "The Birchmere" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Acoustic Allstars Alexandria, VA 1.23.88" .
#
# boots:AdrianBelew_Carrboro_06.05.08
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Power Trio Carrboro NC 06.05.08" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2008-06-05"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Power Trio Carrboro NC 06.05.08" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Carrboro_06.05.08.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "The Cat's Cradle" , "Carrboro" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Power Trio Carrboro NC 06.05.08" .
#
# boots:Barenberg_Bush_Douglas_Meyer_Greenville_1.18.92_dsbd
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Barenberg Bush Douglas Meyer Greenville 1.18.92 dsbd" ;
#         dcterms:creator               bibliographica:Maura_OConnell , bibliographica:Barenberg_Bush_Douglas_Meyer ;
#         dcterms:date                  "1992-01-18"^^xsd:date ;
#         dcterms:title                 "Barenberg Bush Douglas Meyer with Maura O'Connell 1992-01-18 Peace Center Greenville SC DSBD" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BarenbergBushDouglasMeyer_Greenville_1.18.92.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Peace Center " , "Greenville SC" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Barenberg Bush Douglas Meyer Greenville 1.18.92 dsbd" .
#
# boots:B-52s_Amsterdam_11.17.79
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "B-52s Amsterdam 11.17.79" ;
#         dcterms:creator               bibliographica:B-52s ;
#         dcterms:date                  "1979-11-17"^^xsd:date ;
#         dcterms:title                 "B-52s Amsterdam 11.17.79" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/B-52s_Amsterdam_11.17.79.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Amsterdam" , "Paradiso" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "B-52s Amsterdam 11.17.79" .
#
# boots:Bjork_Barcelona_11.4.01
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Björk Barcelona 11.4.01" ;
#         dcterms:creator               bibliographica:Björk ;
#         dcterms:date                  "2001-11-04"^^xsd:date ;
#         dcterms:title                 "Björk - Barcelona 11.4.01" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Bjork_Barcelona_11.4.01.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Barcelona Spain" , "El Liceu" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Björk Barcelona 11.4.01" .
#
# boots:Alison_Krauss_Palo_Alto_8.29.90
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Alison Krauss - Palo Alto 8.29.90" ;
#         dcterms:creator               bibliographica:Alison_Krauss ;
#         dcterms:date                  "1990-08-29"^^xsd:date ;
#         dcterms:title                 "Alison Krauss - Palo Alto 8.29.90" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Alison_Krauss_Palo_Alto_8.29.90.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Palo Alto" , "Palo Alto Unitarian Church" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int .
#
# boots:AbdullahIbrahim_Montreux_7.15.88
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Abdullah Ibrahim Montreux 7.15.88 FM" ;
#         dcterms:creator               bibliographica:Abdullah_Ibrahim ;
#         dcterms:date                  "1988-07-15"^^xsd:date ;
#         dcterms:title                 "Abdullah Ibrahim Montreux 7.15.88 FM" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Abdullah_Ibrahim_Montreux_7.15.88.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Casino" , "Montreux Jazz Festival" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int .
#
# boots:BrianEno_Amsterdam_6.20.99
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Brian Eno - Amsterdam 6.20.99 fm" ;
#         dcterms:creator               bibliographica:Brian_Eno ;
#         dcterms:date                  "1999-06-20"^^xsd:date ;
#         dcterms:title                 "Brian Eno - Amsterdam 6.20.99 fm" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BrianEno_Amsterdam_6.20.99.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Paradiso" , "Amsterdam" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Brian Eno - Amsterdam 6.20.99 fm" .
#
# boots:Word_Boulder_1.14.02
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Word - Boulder 1.14.02" ;
#         dcterms:creator               bibliographica:Word ;
#         dcterms:date                  "2002-01-14"^^xsd:date ;
#         dcterms:title                 "Word - Boulder 1.14.02" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Word_Boulder_1.14.02.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Boulder" , "Fox Theater" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Word - Boulder 1.14.02" .
#
# boots:AdrianBelew_Buffalo_8.11.06
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Buffalo 8.11.06" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2006-08-11"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Buffalo 8.11.06" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Buffalo_8.11.06.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Buffalo" , "The Buffalo Icon" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Buffalo 8.11.06" .
#
# boots:ArtZoyd_Stockholm_3.10.79
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Art Zoyd - Stockholm 3.10.79" ;
#         dcterms:creator               bibliographica:Art_Zoyd ;
#         dcterms:date                  "1979-03-10"^^xsd:date ;
#         dcterms:title                 "Art Zoyd - Stockholm 3.10.79" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/ArtZoyd_Stockholm_3.10.79.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Cotuit, MA" , "Cotuit Center For The Arts" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Art Zoyd - Stockholm 3.10.79" .
#
# boots:DaveGreenTrioEvanParkerBBC_11.5.04
#         a                           bibliographica:LiveMusicRec ;
#         rdfs:label                  "Dave Green Trio with Evan Parker - BBC 11.5.04" ;
#         dcterms:creator             bibliographica:Dave_Green , bibliographica:Evan_Parker ;
#         dcterms:date                "2004-11-05"^^xsd:date ;
#         dcterms:title               "Dave Green Trio with Evan Parker - BBC 11.5.04" ;
#         bibliographica:infoFileURL  "DaveGreenTrioEvan Parker_11.5.04.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Dave Green Trio with Evan Parker - BBC 11.5.04" .
#
# boots:BillyBragg_Arcore_1987
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Billy Bragg - Arcore 1987" ;
#         dcterms:creator               bibliographica:Billy_Bragg ;
#         dcterms:date                  "1987-10-16"^^xsd:date ;
#         dcterms:title                 "Billy Bragg - Arcore 1987" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BillyBragg_Arcore_1987.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Milano, Italy" , "Arcore" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Billy Bragg - Arcore 1987" .
#
# boots:Zappa_Arlington_3.11.73
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Arlington 3.11.73" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1973-03-11"^^xsd:date ;
#         dcterms:title                 "Zappa Arlington 3.11.73" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Arlington_3.11.73.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Ann Arbor" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Zappa Arlington 3.11.73" .
#
# boots:Zappa_Vancouver_BC_10.1.75
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Vancouver BC 10.1.75" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1975-10-01"^^xsd:date ;
#         dcterms:title                 "Zappa Vancouver BC 10.1.75" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Vancouver_BC_10.1.75.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Vancouver" , "War Memorial Gym" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Zappa Vancouver BC 10.1.75" .
#
# boots:Zappa_Petit_Wazoo_Portland_72
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:comment                  "Plus an array of other shows in that era." ;
#         rdfs:label                    "Zappa Petit Wazoo Portland 72" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1972-01-01"^^xsd:date ;
#         dcterms:title                 "Zappa Petit Wazoo Portland 72" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Petit_Wazoo_Portland_72.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Portland" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Petit Wazoo Portland 72" .
#
# boots:AdrianBelew_Boston_7.18.89
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Boston 7.18.89" ;
#         dcterms:creator               "Adrian Belew" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "1989-07-18"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Boston 7.18.89" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Boston_7.18.89.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Boston" , "Paradise Theatre" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Boston 7.18.89" .
#
# boots:AlejandroEscovedo_6.24.06
#         a                           bibliographica:LiveMusicRec ;
#         rdfs:label                  "Alejandro Escovedo 6.24.06" ;
#         dcterms:creator             bibliographica:Alejandro_Escovedo ;
#         dcterms:date                "2006-06-24"^^xsd:date ;
#         dcterms:title               "Alejandro Escovedo 6.24.06" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/AlejandroEscovedo_6.24.06.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel              "Alejandro Escovedo 6.24.06" .
#
# boots:AdrianBelew_School_Of_Rock
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew School Of Rock Falls Church VA 02.10.06" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2006-02-10"^^xsd:date ;
#         dcterms:title                 "Adrian Belew School Of Rock Falls Church VA 02.10.06" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_School_Of_Rock.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "The State Theatre" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew School Of Rock Falls Church VA 02.10.06" .
#
# boots:BenFolds_Tuscon_8.5.03
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Ben Folds - Tuscon 8.5.03" ;
#         dcterms:creator               bibliographica:Ben_Folds ;
#         dcterms:date                  "1989-01-01"^^xsd:date ;
#         dcterms:title                 "Ben Folds - Tuscon 8.5.03" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BenFolds_Tuscon_8.5.03.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Anselmo Valencia Tori Amphitheatre" , "Tuscon" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Ben Folds - Tuscon 8.5.03" .
#
# boots:Ahmad_Jamal_Ramatuelle_8.16.04
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Ahmad Jamal - Ramatuelle 8.16.04 fm" ;
#         dcterms:creator               bibliographica:Ahmad_Jamal ;
#         dcterms:date                  "2004-08-16"^^xsd:date ;
#         dcterms:title                 "Ahmad Jamal - Ramatuelle 8.16.04" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Ahmad_Jamal_Ramatuelle_8.16.04.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Théâtre de Verdure" , "Ramatuelle, France" , "Ramatuelle Jazz Festival" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int .
#
# boots:AndreCeccarelli_Vienna
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "André Ceccarelli - Vienna 04" ;
#         dcterms:creator               bibliographica:Andre_Ceccarelli ;
#         dcterms:date                  "2004-01-01"^^xsd:date ;
#         dcterms:title                 "André Ceccarelli - Vienna 04" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AndreCeccarelli_Vienna.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Jazz A Vienne" , "Vienna" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "André Ceccarelli - Vienna 04" .
#
# boots:BigAudioDynamite_Modeno_5.26.87
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Big Audio Dynamite Modeno 5.26.87" ;
#         dcterms:creator               bibliographica:Big_Audio_Dynamite ;
#         dcterms:date                  "1987-05-29"^^xsd:date ;
#         dcterms:title                 "Big Audio Dynamite Modeno 5.26.87" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BigAudioDynamite_Modeno_5.26.87.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Modena, Italy" , "Stadio Comunale" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "2"^^xsd:int ;
#         skos:prefLabel                "Big Audio Dynamite Modeno 5.26.87" .
#
# boots:AdrianBelew_Cotuit_9.3.09
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Power Trio; Cotuit, MA 9.3.09" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2009-09-03"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Power Trio, Cotuit MA 9.3.09" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Cotuit_9.3.09.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Cotuit, MA" , "Cotuit Center For The Arts" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Power Trio; Cotuit, MA 9.3.09" .
#
# boots:CarltonHaneyBluegrass_Roanoke
#         a                           bibliographica:LiveMusicRec ;
#         rdfs:label                  "Carlton Haney Bluegrass Festival - Roanoke '65" ;
#         dcterms:creator             bibliographica:VariousBluegrass ;
#         dcterms:date                "1965-09-01"^^xsd:date ;
#         dcterms:title               "Carlton Haney Bluegrass Festival - Roanoke '65" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/CarltonHaneyBluegrass_Roanoke.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Carlton Haney Bluegrass Festival - Roanoke '65" .
#
# boots:AdrianBelew_Buffalo_6.17.05
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Buffalo 6.17.05" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2005-06-17"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Buffalo 6.17.05" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Buffalo_6.17.05.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Buffalo" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Buffalo 6.17.05" .
#
# boots:AdrianBelew_Milwaukee_10.23.93
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew (solo acoustic) Milwaukee 10.23.93" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "1993-10-23"^^xsd:date ;
#         dcterms:title                 "Adrian Belew (solo acoustic) Milwaukee 10.23.93" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Milwaukee_10.23.93.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Shank Hall" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew (solo acoustic) Milwaukee 10.23.93" .
#
# boots:AlbertCollins_Hollywood_5.10.87
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Albert Collins Hollywood 5.10.87" ;
#         dcterms:creator               bibliographica:Albert_Collins ;
#         dcterms:date                  "1987-05-10"^^xsd:date ;
#         dcterms:title                 "Albert Collins Hollywood 5.10.87" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AlbertCollins_Hollywood_5.10.87.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Ford Theatre" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Albert Collins Hollywood 5.10.87" .
#
# boots:Zappa_Geneva_6.21.80
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Geneva 6.21.80 sbd" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1980-06-21"^^xsd:date ;
#         dcterms:title                 "Zappa Geneva 6.21.80 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Geneva_6.21.80_sbd.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Patinoire des Vernets" , "Geneva" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Geneva 6.21.80 sbd" .
#
# boots:YoMiles_Fillmore_3.4.02
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Yo Miles - Fillmore 3.4.02" ;
#         dcterms:creator               bibliographica:YoMiles ;
#         dcterms:date                  "2002-03-04"^^xsd:date ;
#         dcterms:title                 "Yo Miles - Fillmore 3.4.02" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Yo_Miles_Fillmore_3.4.02.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Fillmore Auditorium" , "San Francisco" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Yo Miles - Fillmore 3.4.02" .
#
# boots:Al_DiMeola_Montreal_1988
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Al DiMeola Project - Montreal 7.88 fm" ;
#         dcterms:creator               bibliographica:Al_DiMeola ;
#         dcterms:date                  "1988-07-01"^^xsd:date ;
#         dcterms:title                 "Al DiMeola Project - Montreal 7.88 fm" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Al_DiMeola_Montreal_1988.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Jazzfest Montreal" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Al DiMeola Project - Montreal 7.88 fm" .
#
# boots:ZappaPlaysZappa_London_6.14.09
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Plays Zappa - London 6.14.09" ;
#         dcterms:creator               bibliographica:ZappaPlaysZappa ;
#         dcterms:date                  "2009-06-14"^^xsd:date ;
#         dcterms:title                 "Zappa Plays Zappa - London 6.14.09" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Plays_Zappa_London_6.14.09.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "London" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Plays Zappa - London 6.14.09" .
#
# boots:Albion_Country_Band_w_Richard_Linda_London_12.29.72
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Albion Country Band w Richard & Linda - London 12.29.72" ;
#         dcterms:creator               bibliographica:Linda_Thompson , bibliographica:Richard_Thompson , bibliographica:Albion_Country_Band ;
#         dcterms:date                  "1972-12-29"^^xsd:date ;
#         dcterms:title                 "Albion Country Band w Richard & Linda - London 12.29.72" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Albion_Country_Band_w_Richard_Linda_London_12.29.72.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "London" , "The Howff, Chalk Farm" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Albion Country Band w Richard & Linda - London 12.29.72" .
#
# boots:AllanHoldsworth_Miami
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Allan Holdsworth - Miami 89 sbd" ;
#         dcterms:creator               bibliographica:Allan_Holdsworth ;
#         dcterms:date                  "1989-01-01"^^xsd:date ;
#         dcterms:title                 "Allan Holdsworth - Miami 89 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AllanHoldsworth_Miami.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Miami" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Allan Holdsworth - Miami 89 sbd" .
#
# boots:Al_DiMeola_Denver_9.29.80
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Al Dimeola Netherlands 1987" ;
#         dcterms:creator               bibliographica:Al_DiMeola ;
#         dcterms:date                  "1980-09-29"^^xsd:date ;
#         dcterms:title                 "Al DiMeola Denver 9.29.80" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Al_DiMeola_Denver_9.29.80.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Netherlands" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Al Dimeola Netherlands 1987" .
#
# boots:Zappa_Fillmore_West_66
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Fillmore West 66" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1966-06-01"^^xsd:date ;
#         dcterms:title                 "Zappa Fillmore West 66" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Fillmore_West_66.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Fillmore West" , "San Francisco" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Fillmore West 66" .
#
# boots:BassDesires_Bochum_2.16.86
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Bass Desires Bochum, Germany 2.16.86" ;
#         dcterms:creator               bibliographica:Bass_Desires ;
#         dcterms:date                  "1986-02-16"^^xsd:date ;
#         dcterms:title                 "Bass Desires Bochum, Germany 2.16.86" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BassDesires_Bochum_2.16.86.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Bochum, Germany" , "Güter-Bahnhof Langendreer" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Bass Desires Bochum, Germany 2.16.86" .
#
# boots:AdrianBelew_Farmington_7.19.05
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Farmington, NY 7.19.05" ;
#         dcterms:creator               "Adrian_Belew" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2005-07-19"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Farmington NY 7.19.05" ;
#         bibliographica:locationVenue  "Farmington, NY" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Farmington NY 7.19.05" .
#
# boots:BassDesires_Münster_2.20.87
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Bass Desires Münster, Germany 2.20.87" ;
#         dcterms:creator               bibliographica:Bass_Desires ;
#         dcterms:date                  "1987-02-20"^^xsd:date ;
#         dcterms:title                 "Bass Desires Münster, Germany 2.20.87" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BassDesires_M%C3%BCnster_2.20.87.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Jugendzentrum Am Berg Fidel" , "Münster, Germany" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Bass Desires Münster, Germany 2.20.87" .
#
# boots:Adalberto_Alvarez_Y_Su_Son
#         dcterms:creator  bibliographica:Adalberto_Alvarez_Y_Su_Son .
#
# boots:WeatherReport_London_11.16.80
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Weather Report London 11.16.80" ;
#         dcterms:creator               bibliographica:Weather_Report ;
#         dcterms:date                  "1980-11-16"^^xsd:date ;
#         dcterms:title                 "Weather Report London 11.16.80" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Weather_Report_11.16.80.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Hammersmith Odeon" , "London" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Weather Report London 11.16.80" .
#
# boots:HornsbyFleck_Kalamazoo_4.24.96
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Bruce Hornsby & Bela Fleck - Kalamazoo 4.24.96 sbd" ;
#         dcterms:creator               bibliographica:Bela_Fleck , bibliographica:Bruce_Hornsby ;
#         dcterms:date                  "1996-04-24"^^xsd:date ;
#         dcterms:title                 "Bruce Hornsby & Bela Fleck - Kalamazoo 4.24.96 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/HornsbyFleck_Kalamazoo_4.24.96.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Miller Auditorium" , "Kalamazoo" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Bruce Hornsby & Bela Fleck - Kalamazoo 4.24.96 sbd" .
#
# boots:WhiteStripes_Boston_9.23.00
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "White Stripes Boston 9.23.00 fm" ;
#         dcterms:creator               bibliographica:White_Stripes ;
#         dcterms:date                  "2000-09-23"^^xsd:date ;
#         dcterms:title                 "White Stripes Boston 9.23.00 fm" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/White_Stripes_Boston_9.23.00_fm.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Boston" , "WMBR Radio Sessions" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "White Stripes Boston 9.23.00 fm" .
#
# boots:BryanFerry_Brussels_10.9.02
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Bryan Ferry - Brussels 10.9.02" ;
#         dcterms:creator               bibliographica:Bryan_Ferry ;
#         dcterms:date                  "2002-10-09"^^xsd:date ;
#         dcterms:title                 "Bryan Ferry - Brussels 10.9.02" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BryanFerry_Brussels_10.9.02.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Brussels" , "Palais des Beaux-Arts" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Bryan Ferry - Brussels 10.9.02" .
#
# boots:AdrianBelew_TheBears_Philadelphia_5.5.88
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew & The Bears Philadelphia 5.5.88" ;
#         dcterms:creator               bibliographica:The_Bears , bibliographica:Adrian_Belew ;
#         dcterms:date                  "1988-05-05"^^xsd:date ;
#         dcterms:title                 "Adrian Belew & The Bears Philadelphia 5.5.88" ;
#         bibliographica:byArtist       bibliographica:The_Bears ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelewBears_Philadelphia_5.5.88.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Philadelphia" , "Chestnut Cabaret" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew & The Bears Philadelphia 5.5.88" .
#
# boots:ColinHay_NYC_10.21.09
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Colin Hay - NYC 10.21.09" ;
#         dcterms:creator               bibliographica:Colin_Hay ;
#         dcterms:date                  "2009-10-21"^^xsd:date ;
#         dcterms:title                 "Colin Hay - NYC 10.21.09" ;
#         bibliographica:locationVenue  "Anselmo Valencia Tori Amphitheatre" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Colin Hay - NYC 10.21.09" .
#
# boots:AdrianBelew_LoneRhino_Outtakes
#         a                           bibliographica:LiveMusicRec ;
#         rdfs:label                  "Adrian Belew Lone Rhino Outtakes" ;
#         dcterms:creator             bibliographica:Adrian_Belew ;
#         dcterms:title               "Adrian Belew Lone Rhino Outtakes" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/AdrianBelew_LoneRhino_Outtakes.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 3 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel              "Adrian Belew Lone Rhino Outtakes" .
#
# boots:Bjork_NYC_1993
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Björk - NYC 1993" ;
#         dcterms:creator               bibliographica:Björk ;
#         dcterms:date                  "1993-01-01"^^xsd:date ;
#         dcterms:title                 "Björk - NYC 1993" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Bjork_NYC_1993.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "New York City" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Björk - NYC 1993" .
#
# boots:AlexChilton_Dornbirn_2.14.88
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Alex Chilton Dornbirn, Austria (fm) 2.14.88" ;
#         dcterms:creator               bibliographica:Alex_Chilton ;
#         dcterms:date                  "1988-02-14"^^xsd:date ;
#         dcterms:title                 "Alex Chilton Dornbirn, Austria (fm) 2.14.88" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AlexChilton_Dornbirn_2.14.88.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Spielboden" , "Dornbirn, Austria" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Alex Chilton Dornbirn, Austria (fm) 2.14.88" .
#
# boots:BrianEno_DavidByrne_Ghosts
#         a                           schema:MusicRelease ;
#         rdfs:label                  "Brian Eno & David Byrne - Ghosts" ;
#         dcterms:creator             bibliographica:David_Byrne , bibliographica:Brian_Eno ;
#         dcterms:title               "Brian Eno & David Byrne - Ghosts" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/BrianEno_DavidByrne_Ghosts.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel              "Brian Eno & David Byrne - Ghosts" .
#
# boots:AdrianBelew_Lugano_10.18.08
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Power Trio Lugano 10.18.08" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2008-10-18"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Power Trio Lugano 10.18.08" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Lugano_10.18.08.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Besso RSI Auditorio SM" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Power Trio Lugano 10.18.08" .
#
# boots:Bjork_Aarhus_9.9.93
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Björk - Aarhus 9.9.93" ;
#         dcterms:creator               bibliographica:Björk ;
#         dcterms:date                  "1993-09-09"^^xsd:date ;
#         dcterms:title                 "Björk - Aarhus 9.9.93" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Bjork_Aarhus_9.9.93.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Aarhus, Denmark" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Björk - Aarhus 9.9.93" .
#
# boots:BrianEno_Music_for_Prague
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Brian Eno - Music for Prague" ;
#         dcterms:creator               bibliographica:Brian_Eno ;
#         dcterms:date                  "1998-04-12"^^xsd:date , "1998-04-14"^^xsd:date ;
#         dcterms:title                 "Brian Eno - Music for Prague" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BrianEno_Music_for_Prague.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Nova Sin Gallery" , "Prague" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Brian Eno - Music for Prague" .
#
# boots:Brian_Eno_Future_Light
#         a                bibliographica:LiveMusicRec ;
#         rdfs:label       "Brian Eno - Future Light Lounge Proposal Bonn 1998" ;
#         dcterms:creator  bibliographica:Brian_Eno ;
#         dcterms:date     "1998-01-01"^^xsd:date ;
#         dcterms:title    "Brian Eno - Future Light Lounge Proposal Bonn 1998" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel   "Brian Eno - Future Light Lounge Proposal Bonn 1998" .
#
# boots:BrianEno_Music_for_Glitterbug
#         a                           schema:MusicRelease ;
#         rdfs:comment                "Also released as Eno's \"Spinner\" album by Jah Wobble." ;
#         rdfs:label                  "Brian Eno - Music for Glitterbug" ;
#         dcterms:creator             bibliographica:Brian_Eno ;
#         dcterms:title               "Brian Eno - Music for Glitterbug" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/BrianEno_Music_for_Glitterbug.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Brian Eno - Music for Glitterbug" .
#
# boots:AdrianBelew_Vienna_VA_3.15.08
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Adrian Belew Vienna VA 3.15.08" ;
#         dcterms:creator               bibliographica:Adrian_Belew ;
#         dcterms:date                  "2008-03-15"^^xsd:date ;
#         dcterms:title                 "Adrian Belew Vienna VA 3.15.08" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AdrianBelew_Vienna_3.15.08.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Jammin' Java" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Adrian Belew Vienna VA 3.15.08" .
#
# boots:Beausoleil_NOLA_Jazz_Fest_4.29.04
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Beausoleil NOLA Jazz Fest 4.29.04" ;
#         dcterms:creator               bibliographica:BeauSoleil ;
#         dcterms:date                  "2004-04-29"^^xsd:date ;
#         dcterms:description           "Beausoleil NOLA Jazz Fest 4.29.04" ;
#         dcterms:title                 "Beausoleil NOLA Jazz Fest 4.29.04" ;
#         bibliographica:locationVenue  "New Orleans" , "Jazz Fest" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Beausoleil NOLA Jazz Fest 4.29.04" .
#
# boots:Zappa_NYC_8.3.68
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa NYC 8.3.68" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1968-08-03"^^xsd:date ;
#         dcterms:title                 "Zappa NYC 8.3.68" ;
#         bibliographica:locationVenue  "New York City" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "3"^^xsd:int ;
#         skos:prefLabel                "Zappa NYC 8.3.68" .
#
# boots:AndrewBird_Newport_7.31.10
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Andrew Bird - Newport 7.31.10" ;
#         dcterms:creator               bibliographica:Andrew_Bird ;
#         dcterms:date                  "2010-07-31"^^xsd:date ;
#         dcterms:title                 "Andrew Bird - Newport 7.31.10" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AndrewBird_Newport_7.31.10.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Newport Folk Festival" , "Newport, RI" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Andrew Bird - Newport 7.31.10" .
#
# boots:Alpha_Blondy_ReggaeOnTheRiver
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Alpha Blondy - Reggae On The River 8.2.92 sbd" ;
#         dcterms:creator               bibliographica:Alpha_Blondy ;
#         dcterms:date                  "1992-08-02"^^xsd:date ;
#         dcterms:title                 "Alpha Blondy - Reggae On The River 8.2.92 sbd" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Alpha_Blondy_ReggaeOnTheRiver.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "French's Camp" , "London" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Alpha Blondy - Reggae On The River 8.2.92 sbd" .
#
# boots:B-52s_MontegoBay_11.25.82
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "B-52s - Montego Bay, Jamaica 11.25.82" ;
#         dcterms:creator               bibliographica:B-52s ;
#         dcterms:date                  "1982-11-25"^^xsd:date ;
#         dcterms:title                 "B-52s - Montego Bay, Jamaica 11.25.82" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/B-52s_MontegoBay_11.25.82.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Montego Bay, Jamaica" , "Jamaica World Music Festival" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "B-52s - Montego Bay, Jamaica 11.25.82" .
#
# boots:ZappaPlaysZappa_Milwaukee_8.22.09
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Plays Zappa - Milwaukee 8.22.09" ;
#         dcterms:creator               bibliographica:ZappaPlaysZappa ;
#         dcterms:date                  "2009-08-22"^^xsd:date ;
#         dcterms:title                 "Zappa Plays Zappa - Milwaukee 8.22.09" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Plays_Zappa_Milwaukee_8.22.09.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Milwaukee" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Plays Zappa - Milwaukee 8.22.09" .
#
# boots:AmadouMariam_Biddinghuizen_8.21.05
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Amadou & Mariam - Biddinghuizen 8.21.05" ;
#         dcterms:creator               bibliographica:Amadou_and_Mariam ;
#         dcterms:date                  "2005-08-21"^^xsd:date ;
#         dcterms:title                 "Amadou & Mariam - Biddinghuizen 8.21.05" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/AmadouMariam_Biddinghuizen_8.21.05.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Biddinghuizen" , "Lowlands Festival" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Amadou & Mariam - Biddinghuizen 8.21.05" .
#
# boots:BrianEno_RareTracks
#         a                           schema:MusicRelease ;
#         rdfs:label                  "Brian Eno - Rare Tracks" ;
#         dcterms:creator             bibliographica:Brian_Eno ;
#         dcterms:title               "Brian Eno - Rare Tracks" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/BrianEno_RareTracks.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Brian Eno - Rare Tracks" .
#
# boots:Eno_Schwalm_Mt_Fuji_2001
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Eno & Schwalm - Mt Fuji 2001" ;
#         dcterms:creator               bibliographica:Brian_Eno , bibliographica:Jan_Peter_Schwalm ;
#         dcterms:date                  "2001-10-13"^^xsd:date ;
#         dcterms:title                 "Eno & Schwalm - Mt Fuji 2001" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Eno_Schwalm_Mt_Fuji_2001.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Fuji Rock Festival" , "Naeba Ski Resort, Niigata" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Eno & Schwalm - Mt Fuji 2001" .
#
# boots:BrianEno_ConversationUmbrella
#         a                           schema:MusicRelease ;
#         rdfs:label                  "Brian Eno - Conversation with Umbrella" ;
#         dcterms:creator             bibliographica:Brian_Eno ;
#         dcterms:title               "Brian Eno - Conversation with Umbrella" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/BrianEno_ConversationUmbrella.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "Brian Eno - Conversation with Umbrella" .
#
# boots:DiMeola_Coryell_Lagrene_6.15.89
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "DiMeola Coryell Lagrene 6.15.89" ;
#         dcterms:creator               bibliographica:Al_DiMeola , bibliographica:Larry_Coryell ;
#         dcterms:date                  "1989-06-15"^^xsd:date ;
#         dcterms:title                 "DiMeola Coryell Lagrene 6.15.89" ;
#         bibliographica:locationVenue  "Lagrene" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "DiMeola Coryell Lagrene 6.15.89" .
#
# boots:Bjork_Toronto_8.17.95
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Björk - Toronto 8.17.95" ;
#         dcterms:creator               bibliographica:Björk ;
#         dcterms:date                  "1995-08-17"^^xsd:date ;
#         dcterms:title                 "Björk - Toronto 8.17.95" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Bjork_Toronto_8.17.95.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Toronto" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Björk - Toronto 8.17.95" .
#
# boots:B-52s_unknown_venue_8.11.01
#         a                           bibliographica:LiveMusicRec ;
#         rdfs:label                  "B-52s - unknown venue 8.11.01" ;
#         dcterms:creator             bibliographica:B-52s ;
#         dcterms:date                "2001-08-11"^^xsd:date ;
#         dcterms:title               "B-52s - unknown venue 8.11.01" ;
#         bibliographica:infoFileURL  "http://www.connaissance.io/onto/biblio/info/B-52s_unknown_venue_8.11.01.txt"^^xsd:anyURI ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel              "B-52s - unknown venue 8.11.01" .
#
# boots:Zappa_Stuttgart_5.24.88
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Zappa Stuttgart 5.24.88" ;
#         dcterms:creator               bibliographica:Frank_Zappa ;
#         dcterms:date                  "1988-05-24"^^xsd:date ;
#         dcterms:title                 "Zappa Stuttgart 5.24.88" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Zappa_Stuttgart_5.24.88.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Stuttgart" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Zappa Stuttgart 5.24.88" .
#
# boots:BrianEno_Sydney_6.14.09
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Brian Eno - Sydney 6.14.09" ;
#         dcterms:creator               bibliographica:Brian_Eno ;
#         dcterms:date                  "2009-06-14"^^xsd:date ;
#         dcterms:title                 "Brian Eno - Sydney 6.14.09" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/BrianEno_Sydney_6.14.09.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Sydney" , "Sydney Opera House Concert Hall" ;
#         bibliographica:performanceRating
#                 4 ;
#         bibliographica:soundQualityValue
#                 "4"^^xsd:int ;
#         skos:prefLabel                "Brian Eno - Sydney 6.14.09" .
#
# boots:Al_Dimeola_Netherlands_1987
#         a                             bibliographica:LiveMusicRec ;
#         rdfs:label                    "Al Dimeola Netherlands 1987" ;
#         dcterms:creator               bibliographica:Al_DiMeola ;
#         dcterms:date                  "1987-01-01"^^xsd:date ;
#         dcterms:title                 "Al Dimeola Netherlands 1987" ;
#         bibliographica:infoFileURL    "http://www.connaissance.io/onto/biblio/info/Al_Dimeola_Netherlands_1987.txt"^^xsd:anyURI ;
#         bibliographica:locationVenue  "Netherlands" ;
#         bibliographica:performanceRating
#                 5 ;
#         bibliographica:soundQualityValue
#                 "5"^^xsd:int ;
#         skos:prefLabel                "Al Dimeola Netherlands 1987" .
#
# }

# %% [markdown]
# #### Solo Music Artists

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# <http://www.connaissance.io/onto/biblio/SoloMusicArtist>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-20"^^xsd:date ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/"^^xsd:anyURI ;
#   schema:license "https://creativecommons.org/licenses/by-nc-sa/4.0/legalcode"^^xsd:anyURI ;
#   dcterms:description "Solo music artists, cataloged and serialized in RDF. Links to DBpedia and Musibrainz." ;
#   owl:imports <http://www.connaissance.io/onto/biblio/MusicGroup> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/authors> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Developed by M Lane" .
#
#
# SoloMusicArtist:Russel_Walder  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Russel Walder" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5b964a8f-462b-4653-8d96-159f989f8674"^^xsd:anyURI .
#
# SoloMusicArtist:Natalie_MacMaster  a                  bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Natalie MacMaster" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Natalie_MacMaster.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4fccc5ba-950d-4698-8655-10844cad67b4"^^xsd:anyURI .
#
# SoloMusicArtist:Allan_Holdsworth  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Allan Holdsworth" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Allan_Holdsworth.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a6396e33-9298-493e-9409-f0e1366b326b"^^xsd:anyURI .
#
# SoloMusicArtist:Mark_Knopfler  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Mark Knopfler" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mark_Knopfler.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e49f69da-17d5-4c5c-bac0-dadcb0e588f5"^^xsd:anyURI .
#
# SoloMusicArtist:John_McEuen  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "John McEuen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_McEuen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8c47bd34-449b-404e-a261-7be4d7c0e662"^^xsd:anyURI .
#
# SoloMusicArtist:Tom_Petty  a                          bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Tom Petty" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tom_Petty.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5ca3f318-d028-4151-ac73-78e2b2d6cdcc"^^xsd:anyURI .
#
# SoloMusicArtist:Stephane_Grappelli  a                 bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Stéphane Grappelli" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/St%C3%A9phane_Grappelli.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bfc03211-a3a2-4700-8fa3-00968c02c5d0"^^xsd:anyURI .
#
# SoloMusicArtist:Jerry_Douglas  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jerry Douglas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Douglas.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f94a59be-8e2f-456b-9ccb-e742048c6654"^^xsd:anyURI .
#
# SoloMusicArtist:Miles_Davis  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Miles Davis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Miles_Davis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/561d854a-6a28-4aa7-8c99-323e6ce46c2a"^^xsd:anyURI .
#
# SoloMusicArtist:Rahsaan_Roland_Kirk  a                bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Rahsaan Roland Kirk" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rahsaan_Roland_Kirk.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4a1f7fe0-e509-4c4a-9fa1-9cf6c3ca891c"^^xsd:anyURI .
#
# SoloMusicArtist:John_Fogerty  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Fogerty" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Fogerty.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c3649208-0ebe-449b-b1d7-4bd6c560f109"^^xsd:anyURI .
#
# SoloMusicArtist:Rakoto_Frah  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Rakoto Frah" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rakoto_Frah.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8cb11aab-f38e-4923-8897-bafa553e66f5"^^xsd:anyURI .
#
# SoloMusicArtist:Rickie_Lee_Jones  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Rickie Lee Jones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rickie_Lee_Jones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9cd9232e-7a3e-4eb9-8043-ee05c1e396ec"^^xsd:anyURI .
#
# SoloMusicArtist:Robben_Ford  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Robben Ford" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robben_Ford.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9c17c956-de06-4463-9a87-234652c306dc"^^xsd:anyURI .
#
# SoloMusicArtist:Albert_Collins  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Albert Collins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Albert_Collins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/73b8dddb-ec29-4d11-b449-d97fde73f07b"^^xsd:anyURI .
#
# SoloMusicArtist:Stanley_Clarke  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Stanley Clarke" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stanley_Clarke.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5ab6ca23-9e17-43f2-ad92-869d28bdbf11"^^xsd:anyURI .
#
# SoloMusicArtist:Kinky_Friedman  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kinky Friedman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kinky_Friedman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8d22894d-5105-44d4-923d-0c2f3f515da6"^^xsd:anyURI .
#
# SoloMusicArtist:Nanci_Griffith  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Nanci Griffith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nanci_Griffith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b9ffd0e7-7f95-46db-bc1c-8094d459f084"^^xsd:anyURI .
#
# SoloMusicArtist:Babatunde_Olatunji  a                 bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Babatunde Olatunji" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Babatunde_Olatunji.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/afe0acea-f6be-418a-b1dd-3ef0e06c3672"^^xsd:anyURI .
#
# SoloMusicArtist:Christine_Lavin  a                    bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Christine Lavin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Christine_Lavin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/03172678-72c4-423a-b3ca-4bbc7fc89d04"^^xsd:anyURI .
#
# SoloMusicArtist:Jeffrey_Foucault  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jeffrey Foucault" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jeffrey_Foucault.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fb5efe24-591d-40a7-9587-36f44b21c2bd"^^xsd:anyURI .
#
# SoloMusicArtist:William_Aura  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "William Aura" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f03b269c-24f8-4c0f-b2ae-dddca0e7ec67"^^xsd:anyURI .
#
# SoloMusicArtist:Ottmar_Liebert  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Ottmar Liebert" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ottmar_Liebert.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/40476880-65b5-4bf3-a8f7-16f168e5815c"^^xsd:anyURI .
#
# SoloMusicArtist:Ravel  a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Maurice Ravel" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Maurice_Ravel.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6fdd3b3e-1ea6-4da9-8d6f-8f8de01c133a"^^xsd:anyURI .
#
# SoloMusicArtist:Johnny_A  a                           bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Johnny A" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Johnny_A..ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d12ce6b4-1785-4fee-8ec5-dc4e3c149978"^^xsd:anyURI .
#
# SoloMusicArtist:Nancy_Wilson  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Nancy Wilson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nancy_Wilson_(jazz_singer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f597eafc-4dc5-4bc4-a019-a5035a3c8502"^^xsd:anyURI .
#
# SoloMusicArtist:Professor_Trance  a                   bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Professor Trance" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a205be98-186b-44e8-a753-cd1d22b62215"^^xsd:anyURI .
#
# SoloMusicArtist:Kris_McKay  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Kri McKay" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/eb5f8a60-a198-46c9-93b4-4e62b1277242"^^xsd:anyURI .
#
# SoloMusicArtist:Russ_Barenberg  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Russ Barenberg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Russ_Barenberg.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/10df6b2d-e016-4a51-a97c-f9f8814cabef"^^xsd:anyURI .
#
# SoloMusicArtist:Loudon_Wainwright_III
#         a                              bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Loudon Wainwright III" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Loudon_Wainwright_III.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3ddc1fe4-0abb-4af0-9392-e36720386842"^^xsd:anyURI .
#
# SoloMusicArtist:Caitlin_Cary  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Caitlin Cary" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Caitlin_Cary.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/efa0679e-e1f0-4f84-a76a-6482da009343"^^xsd:anyURI .
#
# SoloMusicArtist:Karan_Casey  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Karan Casey" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Karan_Casey.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c713c7d1-7b9b-4910-973e-17b0340961c3"^^xsd:anyURI .
#
# SoloMusicArtist:Zachary_Richard  a                    bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Zachary Richard" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Zachary_Richard.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2b1999ba-5256-4e9b-84be-4a23b9283e84"^^xsd:anyURI .
#
# SoloMusicArtist:Dexter_Gordon  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Dexter Gordon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dexter_Gordon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cc1588e1-5ba3-45a6-b80c-b31035c89339"^^xsd:anyURI .
#
# SoloMusicArtist:Lisa_Gerrard  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Lisa Gerrard" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lisa_Gerrard.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cd645207-1664-46af-9953-264e9ae54089"^^xsd:anyURI .
#
# SoloMusicArtist:Mary_Youngblood  a                    bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Mary Youngblood" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mary_Youngblood.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf680ee4-dc8c-4cf9-97b3-fee421b13854"^^xsd:anyURI .
#
# SoloMusicArtist:Eliades_Ochoa  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Eliades Ochoa" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eliades_Ochoa.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1de8629a-9dd3-444c-86a0-9f9bd8c02218"^^xsd:anyURI .
#
# SoloMusicArtist:Carole_King  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Carole King" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Carole_King.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bf6c29f5-b69f-4842-9031-37f9645d365d"^^xsd:anyURI .
#
# SoloMusicArtist:Tanita_Tikaram  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Tanita Tikaram" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tanita_Tikaram.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/43554fe6-840b-4f61-b54b-8168398cb1e7"^^xsd:anyURI .
#
# SoloMusicArtist:Ana_Egge  a                           bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ana Egge" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ana_Egge.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/aca491ac-34bf-4332-a1b6-2ebf288db65e"^^xsd:anyURI .
#
# SoloMusicArtist:Jerry_Jeff_Walker  a                  bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jerry Jeff Walker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Jeff_Walker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3faa019a-ad91-4ddf-87d5-fdcbdfd8327c"^^xsd:anyURI .
#
# SoloMusicArtist:Etta_James  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Etta James" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Etta_James.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e22d2f66-881e-41ca-9356-544697ee5f90"^^xsd:anyURI .
#
# SoloMusicArtist:John_Lurie  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "John Lurie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Lurie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ecf89d69-b832-4194-bddf-ce4459d2bd3b"^^xsd:anyURI .
#
# SoloMusicArtist:Patty_Griffin  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Patty Griffin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patty_Griffin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6fddcfc3-20b6-48d0-87ba-8211eca3420c"^^xsd:anyURI .
#
# SoloMusicArtist:Utah_Phillips  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Utah Phillips" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Utah_Phillips.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c80cc23a-690e-498f-9e61-bea2509ca096"^^xsd:anyURI .
#
# SoloMusicArtist:Duke_Ellington  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Duke Ellington" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Duke_Ellington.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3af06bc4-68ad-4cae-bb7a-7eeeb45e411f"^^xsd:anyURI .
#
# SoloMusicArtist:Trey_Anastasio  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Trey Anastasio" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Trey_Anastasio.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d942f71b-09d3-406c-8f7d-c52eba3135c1"^^xsd:anyURI .
#
# SoloMusicArtist:Ben_Folds  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ben Folds" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ben_Folds.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/51b7f46f-6c0f-46f2-9496-08c9ec2624d4"^^xsd:anyURI .
#
# SoloMusicArtist:Eugene_Chadbourne  a                  bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Eugene Chadbourne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eugene_Chadbourne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0edbeff1-5b4f-4793-b3e3-9e9bd9c0b8d5"^^xsd:anyURI .
#
# SoloMusicArtist:David_Johansen  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "David Johansen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Johansen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3cb2ba2a-81f9-49b6-8e9d-71dcf5fb56cc"^^xsd:anyURI ;
#         skos:related                   "Buster Poindexter" .
#
# SoloMusicArtist:Michael_Shrieve  a                    bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Shrieve" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Shrieve.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3a0fbd71-4613-45e3-bbe2-40752a0b69aa"^^xsd:anyURI .
#
# SoloMusicArtist:James_McMurtry  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "James McMurtry" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/James_McMurtry.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0d842c11-3f11-4dae-aa41-4e6e8beccc09"^^xsd:anyURI .
#
# SoloMusicArtist:Mindy_Jostyn  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Mindy Jostyn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mindy_Jostyn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a2f2405d-1874-4646-bb68-a18c1d920385"^^xsd:anyURI .
#
# SoloMusicArtist:Juan_Formell  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Juan Formell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Juan_Formell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cc57e7c9-d99d-4955-bc89-a35f2122be82"^^xsd:anyURI .
#
# SoloMusicArtist:Jimmy_Page  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jimmy Page" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jimmy_Page.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/519774a4-3b18-4042-b8c0-927845a616c9"^^xsd:anyURI .
#
# SoloMusicArtist:Bela_Fleck  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Béla Fleck" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Béla_Fleck.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e1a889b7-5e45-447f-baa0-b9c6cbc0d39f"^^xsd:anyURI .
#
# SoloMusicArtist:Mike_Seeger  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Mike Seeger" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mike_Seeger.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/22baef3d-f490-43da-bea8-3a9a4d149143"^^xsd:anyURI .
#
# SoloMusicArtist:Celine_Dion  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Céline Dion" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Celine_Dion.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/48d0bd2b-0507-334b-8b67-6ab3897b9a3b"^^xsd:anyURI .
#
# SoloMusicArtist:Mick_Taylor  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Mick Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mick_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c7a99436-6da3-4190-8ce7-9cd44d62fcd4"^^xsd:anyURI .
#
# SoloMusicArtist:Alejandro_Escovedo  a                 bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Alejandro Escovedo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Alejandro_Escovedo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bf103bec-70e3-45a5-9d1b-97715db04a96"^^xsd:anyURI .
#
# SoloMusicArtist:Tim_Finn  a                           bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Tim Finn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tim_Finn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/380221b2-54de-4801-b256-6a0f28e28d6f"^^xsd:anyURI .
#
# SoloMusicArtist:Jane_Kelly_Williams  a                bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jane Kelly Williams" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cd4acf2c-c148-4da0-a526-102cf69be557"^^xsd:anyURI .
#
# SoloMusicArtist:Eva_Cassidy  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Eva Cassidy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eva_Cassidy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6f2dfabb-f0bb-4801-a392-592489a148e7"^^xsd:anyURI .
#
# SoloMusicArtist:Erin_McKeown  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Erin McKeown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Erin_McKeown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3f55dbb0-8ba0-4eda-b4dd-5a9169c5d29c"^^xsd:anyURI .
#
# SoloMusicArtist:Wally_Ingram  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Wally Ingram" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wally_Ingram.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a7f5c003-5ef7-498a-a0a9-68701510ba83"^^xsd:anyURI .
#
# SoloMusicArtist:Elvis_Costello  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Elvis Costello" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Elvis_Costello.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8a338e06-d182-46f2-bd16-30a09bc840ba"^^xsd:anyURI .
#
# SoloMusicArtist:Nick_Lowe  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Nick Lowe" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nick_Lowe.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a3d5a6bf-c86d-44d3-969b-f345620009c6"^^xsd:anyURI .
#
# SoloMusicArtist:PJ_Harvey  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "PJ Harvey" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/PJ_Harvey.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e795e03d-b5d5-4a5f-834d-162cfb308a2c"^^xsd:anyURI .
#
# SoloMusicArtist:Maria_McKee  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Maria McKee" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Maria_McKee.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f8276a46-0c87-4d2f-a0d3-f22900f9cbfe"^^xsd:anyURI .
#
# SoloMusicArtist:Patty_Larkin  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Patty Larkin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patty_Larkin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2450c460-5a4f-44b0-a6d9-847f281599a1"^^xsd:anyURI .
#
# SoloMusicArtist:Monguito_Santamaria  a                bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Monguito Santamaria" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5294059e-8118-4978-9060-6db975403715"^^xsd:anyURI .
#
# SoloMusicArtist:Julie_Hoest  a     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label  "Julie Hoest" .
#
# SoloMusicArtist:Poncho_Sanchez  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Poncho Sanchez" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Poncho_Sanchez.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62da2ead-f055-4ad0-b939-3274bb2c54b2"^^xsd:anyURI .
#
# SoloMusicArtist:YoYo_Ma  a                            bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Yo-Yo Ma" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Yo-Yo_Ma.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62fe877d-b7a5-43e8-952e-2610d7614bff"^^xsd:anyURI .
#
# SoloMusicArtist:Jim_Harvey  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jim Harvey" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/113131a3-205a-4e78-87e5-daf3c52ffd43"^^xsd:anyURI .
#
# SoloMusicArtist:David_Grisman  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "David Grisman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Grisman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/402e4f4f-33aa-4b2b-9fdb-3cb4eb38f729"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_Weir  a                           bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Bob Weir" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Weir.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c8a63580-9e6b-4852-bf93-c09760035e76"^^xsd:anyURI .
#
# SoloMusicArtist:Kristina_Olsen  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Kristina Olsen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kristina_Olsen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9961275-cd64-4a4a-acfb-04346d48bcda"^^xsd:anyURI .
#
# SoloMusicArtist:Jonathan_Edwards  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jonathan Edwards" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jonathan_Edwards_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/83a81b17-e725-4e5d-a607-375d66306e09"^^xsd:anyURI .
#
# SoloMusicArtist:Ahaji_Ibrahim_Abdulai
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Alhaji Ibrahim Abdulai" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ec253150-7438-4403-bcb1-ff261ee3fe9e"^^xsd:anyURI .
#
# SoloMusicArtist:Carla_Olson  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Carla Olson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Carla_Olson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d749f8b5-f620-4203-848f-4e877d53aad6"^^xsd:anyURI .
#
# SoloMusicArtist:Warren_Zevon  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Warren Zevon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Warren_Zevon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/970fb29f-e288-403e-a388-d2a7889bfa47"^^xsd:anyURI .
#
# SoloMusicArtist:Tori_Amos  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Tori Amos" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tori_Amos.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c0b2500e-0cef-4130-869d-732b23ed9df5"^^xsd:anyURI .
#
# SoloMusicArtist:David_Byrne  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "David Byrne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Byrne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d4659efb-b8eb-4f03-95e9-f69ce35967a9"^^xsd:anyURI .
#
# SoloMusicArtist:Sam_Cooke  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sam Cooke" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sam_Cooke.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6c8fd0be-d961-454c-aee0-4366a6dbc993"^^xsd:anyURI .
#
# SoloMusicArtist:Patsy_Cline  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Patsy Cline" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patsy_Cline.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbra.org/artist/ad82dd72-0df3-4a09-8d7a-1af9c9e80522"^^xsd:anyURI .
#
# SoloMusicArtist:Andy_Statman  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Andy Statman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Andy_Statman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5a3586cd-87a7-41b2-ad60-7d83d6363afd"^^xsd:anyURI .
#
# SoloMusicArtist:Carri_Coltrane  a  bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label  "Carri Coltrane" .
#
# SoloMusicArtist:Albert_King  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Albert King" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Albert_King.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/10f89195-3af1-46f5-aa36-504aa3309f5a"^^xsd:anyURI .
#
# SoloMusicArtist:Bruce_Hornsby  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Bruce Hornsby" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bruce_Hornsby.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e60dbba7-6f55-429a-bd22-5e9c6a87ae70"^^xsd:anyURI .
#
# SoloMusicArtist:Townes_Van_Zandt  a                   bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Townes Van Zandt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Townes_Van_Zandt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d67d1a21-6e45-4dd6-aef0-0191ba3796e0"^^xsd:anyURI .
#
# SoloMusicArtist:Mickey_Hart  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Mickey Hart" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mickey_Hart.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/915e673d-eff5-479a-a917-2fecfc26dc2e"^^xsd:anyURI .
#
# SoloMusicArtist:Savoy_Brown  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Savoy Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Savoy_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f0167ca4-f151-4194-813f-021bca2ecf7b"^^xsd:anyURI .
#
# SoloMusicArtist:John_McLaughlin  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "John McLaughlin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_McLaughlin_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fcbc2086-5863-4659-b03d-44be704697d2"^^xsd:anyURI .
#
# SoloMusicArtist:Holly_Cole  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Holly Cole" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Holly_Cole.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/08160a8d-d768-4664-9afa-5720196d16e9"^^xsd:anyURI .
#
# SoloMusicArtist:Anders_Osborne  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Anders Osborne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Anders_Osborne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/96fa47fc-6175-45c9-9686-7a3362671137"^^xsd:anyURI .
#
# SoloMusicArtist:Bebel_Gilberto  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Bebel Gilberto" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bebel_Gilberto.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8777a849-fb4e-4430-9918-170f619c5286"^^xsd:anyURI .
#
# SoloMusicArtist:Jerry_Harrison  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jerry Harrison" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Harrison.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/675f9fe6-7e2c-4ce7-b3dc-147169c64d31"^^xsd:anyURI .
#
# SoloMusicArtist:Taj_Mahal  a                          bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Taj Mahal" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Taj_Mahal_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f48167c-29b8-4bde-a749-6803ce0a3922"^^xsd:anyURI .
#
# SoloMusicArtist:Maria_Muldaur  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Maria Muldaur" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Maria_Muldaur.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3aeb9e89-4fc3-46f4-a5a8-cf6c1b7e66a0"^^xsd:anyURI .
#
# SoloMusicArtist:Billie_Holiday  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Billie Holiday" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Billie_Holiday.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d59c4cda-11d9-48db-8bfe-b557ee602aed"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_Brozman  a                        bibliographica:AlphaClassAD ;
#         rdfs:label                     "Bob Brozman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Brozman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e38ea6d7-825d-490f-8a5d-795e15dac7a9"^^xsd:anyURI .
#
# SoloMusicArtist:Alison_Krauss  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Alison Krauss" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Alison_Krauss.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6b064ead-91a4-4ac8-8076-b1febe4f4aac"^^xsd:anyURI .
#
# SoloMusicArtist:Bonnie_Raitt  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Bonnie Raitt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bonnie_Raitt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0f0da09c-3940-4cb5-879f-4cea28907810"^^xsd:anyURI .
#
# SoloMusicArtist:Kris_Kristofferson  a                 bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kris Kristofferson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kris_Kristofferson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cb1ca13a-4821-4e66-aff0-0fd6b3dc9a81"^^xsd:anyURI .
#
# SoloMusicArtist:Joe_Henry  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Joe Henry" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joe_Henry.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7ea95bc8-7c97-4b8c-baf5-f3720bc94b40"^^xsd:anyURI .
#
# SoloMusicArtist:Ellen_McIlwaine  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Ellen McIlwaine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ellen_McIlwaine.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d55a7204-c17b-412b-87ce-b4d32e2eeae7"^^xsd:anyURI .
#
# SoloMusicArtist:Jeff_Buckley  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jeff Buckley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jeff_Buckley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e6e879c0-3d56-4f12-b3c5-3ce459661a8e"^^xsd:anyURI .
#
# SoloMusicArtist:Glenn_Gould  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Glenn Gould" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Glenn_Gould.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7002bf88-1269-4965-a772-4ba1e7a91eaa"^^xsd:anyURI .
#
# SoloMusicArtist:Ella_Fitzgerald  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ella Fitzgerald" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ella_Fitzgerald.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/54799c0e-eb45-4eea-996d-c4d71a63c499"^^xsd:anyURI .
#
# SoloMusicArtist:Sarah_Spelsberg  a  bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label  "Sarah Spelsberg" .
#
# SoloMusicArtist:Elton_John  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Elton John" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Elton_John.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b83bc61f-8451-4a5d-8b8e-7e9ed295e822"^^xsd:anyURI .
#
# SoloMusicArtist:Darol_Anger  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Darol Anger" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Darol_Anger.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3bbd5ed8-8a84-41e7-91cf-945162aa7cdb"^^xsd:anyURI .
#
# SoloMusicArtist:Pieta_Brown  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Pieta Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pieta_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8d1e1f75-ddc2-4a45-a63f-e8ea61bb4175"^^xsd:anyURI .
#
# SoloMusicArtist:Natalie_Merchant  a                   bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Natalie Merchant" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Natalie_Merchant.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ba03daa8-0a45-4432-881f-4de8e0e05305"^^xsd:anyURI .
#
# SoloMusicArtist:Fred_Frith  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Fred Frith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Fred_Frith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4801bad4-1b42-4c9e-84b1-bf61067ab67c"^^xsd:anyURI .
#
# SoloMusicArtist:Kris_Delmhorst  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Kris Delmhorst" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kris_Delmhorst.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/67f50b10-79fb-487d-a6a0-1e8cc51e622b"^^xsd:anyURI .
#
# SoloMusicArtist:Sade   a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sade Adu" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sade_(singer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/67930b3e-e00b-469f-8c74-fd69f20522ec"^^xsd:anyURI .
#
# SoloMusicArtist:Tim_Buckley  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Tim Buckley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tim_Buckley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8546949d-f46c-45ab-8391-85b26dda6b65"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Brecker  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Brecker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Brecker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/795058e7-927e-4fcd-a5a0-f57c2fe9d3d1"^^xsd:anyURI .
#
# SoloMusicArtist:Sipho_Gumede  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sipho Gumede" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/54062aba-54e4-433e-a0b4-870d91120c03"^^xsd:anyURI .
#
# SoloMusicArtist:Shawn_Colvin  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Shawn Colvin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shawn_Colvin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/42222090-c5e5-4243-8582-c29bc8b63ec6"^^xsd:anyURI .
#
# SoloMusicArtist:Rod_Stewart  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Rod Stewart" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rod_Stewart.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a35237a0-4f47-40a6-b6f3-1e786db23402"^^xsd:anyURI .
#
# SoloMusicArtist:Larry_Coryell  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Larry Coryell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Larry_Coryell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5a8f286f-cb7c-4e31-b021-935173f160ed"^^xsd:anyURI .
#
# SoloMusicArtist:Michelle_Branch  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Michelle Branch" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michelle_Branch.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a10f94a9-2a3c-4166-b9fa-a7bed0bf7d96"^^xsd:anyURI .
#
# SoloMusicArtist:Chris_Whitley  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Chris Whitley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chris_Whitley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/828d31c5-d15a-4109-9619-ba350309834b"^^xsd:anyURI .
#
# SoloMusicArtist:Felina  a                             bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Felina" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6f393ff8-1f77-40f5-8515-2f72b0c28cf2"^^xsd:anyURI .
#
# SoloMusicArtist:Joshua_Bell  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Joshua Bell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joshua_Bell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9b248b09-a736-4591-bdce-9dccb8391cc4"^^xsd:anyURI .
#
# SoloMusicArtist:Madeleine_Peyroux  a                  bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Madeleine Peyroux" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Madeleine_Peyroux.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7f260b9c-bea7-469b-9ba8-0daec7d2c85c"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Furtado  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Furtado" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Furtado.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8d8cc066-fbae-4f60-8d42-ef627a06a78d"^^xsd:anyURI .
#
# SoloMusicArtist:Sam_Phillips  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Sam Phillips" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sam_Phillips.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/19af19b7-5018-4dd8-bf3f-6c17a2ee4098"^^xsd:anyURI .
#
# SoloMusicArtist:Connie_Kaldor  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Connie Kaldor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Connie_Kaldor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c582ec4d-6482-45b0-8f17-356c225c36a8"^^xsd:anyURI .
#
# SoloMusicArtist:Lee_Ritenour  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Lee Ritenour" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lee_Ritenour.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0c361ea5-98c6-4947-900b-201833f2dd84"^^xsd:anyURI .
#
# SoloMusicArtist:Louis_Armstrong  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Louis Armstrong" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Louis_Armstrong.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/eea8a864-fcda-4602-9569-38ab446decd6"^^xsd:anyURI .
#
# SoloMusicArtist:Chick_Corea  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Chick Corea" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chick_Corea.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8446fcca-109e-4c6d-a2ff-5a269b32b4c2"^^xsd:anyURI .
#
# SoloMusicArtist:Jaco_Pastorius  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Jaco Pastorius" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jaco_Pastorius.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/46a6fac0-2e14-4214-b08e-3bdb1cffa5aa"^^xsd:anyURI .
#
# SoloMusicArtist:Loretta_Lynn  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Loretta Lynn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Loretta_Lynn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/613260c3-d620-4645-94cd-33cd55f29b1e"^^xsd:anyURI .
#
# SoloMusicArtist:Wilson_Pickett  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Wilson Pickett" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wilson_Pickett.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fc6214b3-6d82-4803-be74-01ece1723e42"^^xsd:anyURI .
#
# SoloMusicArtist:Keb_Mo  a                             bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Keb' Mo'" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Keb'_Mo'.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/280ddd36-ac7d-4446-8689-a548d6f3458e"^^xsd:anyURI .
#
# SoloMusicArtist:Steve_Goodman  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Steve Goodman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steve_Goodman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6dcf3c49-6293-4bd3-bcff-ddaefc967089"^^xsd:anyURI .
#
# SoloMusicArtist:Norma_Waterson  a                     bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Norma Waterson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Norma_Waterson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ffe1207b-e6ea-40d3-a16b-20de2c012216"^^xsd:anyURI .
#
# SoloMusicArtist:Anne_Hills  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Anne Hills" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Anne_Hills.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/70bec691-4503-4219-9013-15802ed4bb65"^^xsd:anyURI .
#
# SoloMusicArtist:Kate_Bush  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Kate Bush" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kate_Bush.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4b585938-f271-45e2-b19a-91c634b5e396"^^xsd:anyURI .
#
# SoloMusicArtist:Sarah_Vaughan  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Sarah Vaughan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sarah_Vaughan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/351d8bdf-33a1-45e2-8c04-c85fad20da55"^^xsd:anyURI .
#
# SoloMusicArtist:Sun_Ra  a                             bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sun Ra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sun_Ra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c27cac8e-4c4a-48c0-a4ba-41399b9c176d"^^xsd:anyURI .
#
# SoloMusicArtist:Steve_Winwood  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Steve Winwood" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steve_Winwood.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/885f90ef-6bd9-409a-b2df-e165e553c68e"^^xsd:anyURI .
#
# SoloMusicArtist:JoEl_Sonnier  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Jo-El Sonnier" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jo-El_Sonnier.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cae92fc4-ebf8-4940-badf-d54cc6b8e6d3"^^xsd:anyURI .
#
# SoloMusicArtist:Hani_Naser  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Hani Naser" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hani_Naser.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e08b8270-b8a2-4efc-bf2c-105da36a3dfb"^^xsd:anyURI .
#
# SoloMusicArtist:Stephan_Micus  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Stephan Micus" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stephan_Micus.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a04ceabd-1f20-4d29-b579-24810ac2da88"^^xsd:anyURI .
#
# SoloMusicArtist:Fats_Waller  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Fats Waller" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Fats_Waller.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/569fc5bf-bcb6-4bc5-9a00-bd0d258e34f1"^^xsd:anyURI .
#
# SoloMusicArtist:Joanna_Conner  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Joanna Connor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joanna_Connor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c02ca344-39b4-44a9-b6bd-d1dbe0821804"^^xsd:anyURI .
#
# SoloMusicArtist:Tracy_Chapman  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Tracy Chapman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tracy_Chapman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1129817c-488a-4096-80c1-77fc1b107c93"^^xsd:anyURI .
#
# SoloMusicArtist:Guru   a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Guru" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Guru_(rapper).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/215c6ab2-7888-4061-bd56-9fb650328106"^^xsd:anyURI .
#
# SoloMusicArtist:Carrie_Newcomer  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Carrie Newcomer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Carrie_Newcomer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/efc2524f-20a3-4942-8fe2-869fa09e3ea1"^^xsd:anyURI .
#
# SoloMusicArtist:Ornette_Coleman  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Ornette Coleman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ornette_Coleman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/169c0d1b-fcb8-4a43-9097-829aa7b39205"^^xsd:anyURI .
#
# SoloMusicArtist:Syd_Straw  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Syd Straw" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Syd_Straw.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c7d2526a-b5eb-48fb-a66c-d9e0800cdb8c"^^xsd:anyURI .
#
# SoloMusicArtist:Rob_Wasserman  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Rob Wasserman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rob_Wasserman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/77b5f0ca-5c13-4348-8d4d-d6b15440e3ec"^^xsd:anyURI .
#
# SoloMusicArtist:Sibongile_Khumalo  a                  bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Sibongile Khumalo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sibongile_Khumalo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/18808c4d-524b-4e4e-a5fa-b62eb6ae0e23"^^xsd:anyURI .
#
# SoloMusicArtist:Koko_Taylor  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Koko Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Koko_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9ebffe22-c6e0-49bc-a6c2-f79a97bc38b3"^^xsd:anyURI .
#
# SoloMusicArtist:KJ_Denhert  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "KJ Denhert" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/KJ_Denhert.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/89513c0d-6322-426d-87c6-9e3f302e4d70"^^xsd:anyURI .
#
# SoloMusicArtist:Nicolette_Larson  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Nicolette Larson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nicolette_Larson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a45071c0-1805-4ec6-83c4-e3f62e2916b1"^^xsd:anyURI .
#
# SoloMusicArtist:Youssou_NDour  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Youssou N'Dour" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Youssou_N'Dour.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/af081ea2-7a2c-4fbd-8200-92d62056b5f5"^^xsd:anyURI .
#
# SoloMusicArtist:Kerri_Anderson  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Kerri Anderson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kerri_Anderson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1d607ccc-076a-457f-84f0-47e827a241ea"^^xsd:anyURI .
#
# SoloMusicArtist:Beth_Wood  a                          bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Beth Wood" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/53e234c4-9e59-463c-82ee-48ed7525aa90"^^xsd:anyURI .
#
# SoloMusicArtist:George_Harrison  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "George Harrison" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/George_Harrison.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/42a8f507-8412-4611-854f-926571049fa0"^^xsd:anyURI .
#
# SoloMusicArtist:Mutabaruka  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Mutabaruka" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mutabaruka.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a81dde75-8a81-40aa-ba73-cad6d3dd9ed9"^^xsd:anyURI .
#
# SoloMusicArtist:Queen_Latifah  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Queen Latifah" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Queen_Latifah.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7a305f29-539a-456e-93b7-61b0e2ba3ef2"^^xsd:anyURI .
#
# SoloMusicArtist:Wendy_Bucklew  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Wendy Bucklew" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wendy_Bucklew.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d8735a83-3fc2-43ad-b915-854b9969d28a"^^xsd:anyURI .
#
# SoloMusicArtist:Anita_O-Day  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Anita O'Day" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Anita_O'Day.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9516242e-ab62-4e6e-8404-c453668567c2"^^xsd:anyURI .
#
# SoloMusicArtist:Chet_Baker  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Chet Baker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chet_Baker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1ba1d493-7114-45e2-b163-a36d49a0c065"^^xsd:anyURI .
#
# SoloMusicArtist:Annie_Gallup  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Annie Gallup" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Annie_Gallup.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/86de1c4b-15e7-41e4-9e9a-06a5980ed0b9"^^xsd:anyURI .
#
# SoloMusicArtist:Hector_Zazou  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Hector Zazou" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hector_Zazou.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/00e9cc4c-e91c-4e2e-8e3b-bd7403139ac5"^^xsd:anyURI .
#
# SoloMusicArtist:Peter_Rowan  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Peter Rowan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peter_Rowan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1d1488a5-71c0-40ef-9b79-8451a18635ec"^^xsd:anyURI .
#
# SoloMusicArtist:Mary_Hopkin  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Mary Hopkin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mary_Hopkin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f6596571-9ce2-4d79-8e92-fa8cfc181b91"^^xsd:anyURI .
#
# SoloMusicArtist:Christine_Kane  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Christine Kane" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Christine_Kane.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/17c91d2f-df86-4355-b7c0-55d4046e0cb2"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_Dylan  a                          bibliographica:AlphaClassAD ;
#         rdfs:label                     "Bob Dylan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Dylan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/72c536dc-7137-4477-a521-567eeb840fa8"^^xsd:anyURI .
#
# SoloMusicArtist:Omara_Portuondo  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Omara Portuondo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Omara_Portuondo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d2e06763-1035-4b1a-82c7-b7c08e06ba48"^^xsd:anyURI .
#
# SoloMusicArtist:Jan_Peter_Schwalm  a                  bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "J. Peter Schwalm" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/J._Peter_Schwalm.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd42e630-8fb8-4df0-9f6b-751ce6bfc2f1"^^xsd:anyURI .
#
# SoloMusicArtist:Joan_Armatrading  a                   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Joan Armatrading" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joan_Armatrading.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fa598e78-5cc5-4a8b-a3b5-63934d4712c7"^^xsd:anyURI .
#
# SoloMusicArtist:Ben_Harper  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ben Harper" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ben_Harper.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1582a5b8-538e-45e7-9ae4-4099439a0e79"^^xsd:anyURI .
#
# SoloMusicArtist:Kitaro  a                             bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kitarō" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kitar%C5%8D.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f3d8c154-208d-4efa-b52d-7e9f16adcdae"^^xsd:anyURI .
#
# SoloMusicArtist:Rachel_Portman  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Rachel Portman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rachel_Portman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/550508e3-efae-47de-83cc-e50cc471d7e4"^^xsd:anyURI .
#
# SoloMusicArtist:Edie_Brickell  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Edie Brickell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Edie_Brickell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/070473e5-b214-4d6f-a7ca-bc7b84c94fca"^^xsd:anyURI .
#
# SoloMusicArtist:Sara_Hickman  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sara Hickman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sara_Hickman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5c9bd7ed-ede8-49e2-a693-2b6b59d06f65"^^xsd:anyURI .
#
# SoloMusicArtist:Jorma_Kaukonen  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Jorma Kaukonen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jorma_Kaukonen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9753dd7c-63d4-4022-a0ec-fee4966c8cdd"^^xsd:anyURI .
#
# SoloMusicArtist:Sonny_Sharrock  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sonny Sharrock" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sonny_Sharrock.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ebd39596-e2bb-4b3c-a661-412a4198a083"^^xsd:anyURI .
#
# SoloMusicArtist:Buddy_Miller  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Buddy Miller" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buddy_Miller.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ae9156f5-1ed4-4c42-828b-fe1f7b1876a7"^^xsd:anyURI .
#
# SoloMusicArtist:Rory_Block  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Rory Block" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rory_Block.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1e9aa4bd-9689-4535-9665-7f661d63d1c8"^^xsd:anyURI .
#
# SoloMusicArtist:Eliza_Carthy  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Eliza Carthy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eliza_Carthy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/19205396-3f90-4a8b-b085-a795df242a62"^^xsd:anyURI .
#
# SoloMusicArtist:Cesaria_Evora  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Cesária Évora" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ces%C3%A1ria_%C3%89vora.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ceafdf2f-bc18-4b99-8c71-d1834b0065c3"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Green  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Green" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Green_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/793ab510-07ea-488f-87c7-32698dedda33"^^xsd:anyURI .
#
# SoloMusicArtist:CJ_Chenier  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "C. J. Chenier" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/C._J._Chenier.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f5133038-c9d7-4fa2-8ec4-a44199571e25"^^xsd:anyURI .
#
# SoloMusicArtist:Diana_Krall  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Diana Krall" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Diana_Krall.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/67d2cb7a-9ddb-4a7f-82bf-5a2d1a038e98"^^xsd:anyURI .
#
# SoloMusicArtist:Al_Stewart  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Al Stewart" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Al_Stewart.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ab7d49fa-c383-4c41-b890-3fe68e559dc4"^^xsd:anyURI .
#
# SoloMusicArtist:Kristin_Hersh  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Kristin Hersh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kristin_Hersh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0b461f11-c7af-4ddb-a30e-5cb0aabb3e7f"^^xsd:anyURI .
#
# SoloMusicArtist:Patrice_Ratsimbazafy
#         a                              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Patrice Ratsimbazafy" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c5c8e757-0b3d-4ef3-9cd5-33975bdeb123"^^xsd:anyURI .
#
# SoloMusicArtist:Marvin_Gaye  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Marvin Gaye" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Marvin_Gaye.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/afdb7919-059d-43c1-b668-ba1d265e7e42"^^xsd:anyURI .
#
# SoloMusicArtist:Kaki_King  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kaki King" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kaki_King.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/451f8f16-990a-412c-ab3a-b61e5d265b55"^^xsd:anyURI .
#
# SoloMusicArtist:Tanya_Donelly  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Suzanne Ciani" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tanya_Donelly.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/478e2b34-bda3-48c8-81e4-77efac91f3ec"^^xsd:anyURI .
#
# SoloMusicArtist:Sam_Bush  a                           bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sam Bush" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sam_Bush.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c233d833-81d9-4feb-b70c-7ffe86200f7b"^^xsd:anyURI .
#
# SoloMusicArtist:Bruce_Springsteen  a                  bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Bruce Springsteen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bruce_Springsteen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/70248960-cb53-4ea4-943a-edb18f7d336f"^^xsd:anyURI .
#
# SoloMusicArtist:Hamilton_Cheifetz  a                  bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Hamilton Cheifetz" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5d220abd-578a-49b6-80da-d6d72af3b25a"^^xsd:anyURI .
#
# SoloMusicArtist:Dar_Williams  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Dar Williams" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dar_Williams.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f9908eb1-30ac-4fc9-929c-81fe2dcf2266"^^xsd:anyURI .
#
# SoloMusicArtist:Randy_Newman  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Randy Newman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Randy_Newman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/da7bb7d8-557d-4635-9ca1-e6e985525bd5"^^xsd:anyURI .
#
# SoloMusicArtist:Savourna_Stevenson  a                 bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Savourna Stevenson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Savourna_Stevenson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e6164917-b670-4ca8-9e75-b8ab655c81d9"^^xsd:anyURI .
#
# SoloMusicArtist:Jimmy_Witherspoon  a                  bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jimmy Witherspoon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jimmy_Witherspoon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1eaf1688-4f52-49e8-98bc-743828fe3e7e"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Hedges  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Hedges" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Hedges.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fbaba2b0-3a6f-41b1-9ecd-f89c1a666e99"^^xsd:anyURI .
#
# SoloMusicArtist:Steve_Vai  a                          bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Steve Vai" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steve_Vai.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5e7ccd92-6277-451a-aab9-1efd587c50f3"^^xsd:anyURI .
#
# SoloMusicArtist:Joshua_Redman  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Joshua Redman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joshua_Redman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b00a17c3-72b2-4e39-96f9-770ba6cf4573"^^xsd:anyURI .
#
# SoloMusicArtist:Paco_de_Lucia  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Paco de Lucía" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paco_de_Luc%C3%ADa.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7bc8dd01-35ea-4b18-a64d-3a364dc76a52"^^xsd:anyURI .
#
# SoloMusicArtist:Lisa_Lynne  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Lisa Lynne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lisa_Lynne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4bf9b00d-5f32-4b6f-badb-ad7bda086cb9"^^xsd:anyURI .
#
# SoloMusicArtist:Suzanne_Ciani  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Suzanne Ciani" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Suzanne_Ciani.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2ce96399-f6da-439f-af3a-f319ebe2074c"^^xsd:anyURI .
#
# SoloMusicArtist:Laura_Love  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Laura Love" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Laura_Love.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/53299fed-ec27-464f-94eb-5fda2db2902a"^^xsd:anyURI .
#
# SoloMusicArtist:Aretha_Franklin  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Aretha Franklin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Aretha_Franklin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2f9ecbed-27be-40e6-abca-6de49d50299e"^^xsd:anyURI .
#
# SoloMusicArtist:Natalie_Imbruglia  a                  bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Natalie Imbruglia" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Natalie_Imbruglia.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/60530915-9371-4b16-bc31-5c4456317ae0"^^xsd:anyURI .
#
# SoloMusicArtist:Enya   a                              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Enya" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Enya.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4967c0a1-b9f3-465e-8440-4598fd9fc33c"^^xsd:anyURI .
#
# SoloMusicArtist:Chantal_Kreviazuk  a                  bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Chantal Kreviazuk" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chantal_Kreviazuk.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd092d99-377f-414e-a63e-3dc849ad2cc9"^^xsd:anyURI .
#
# SoloMusicArtist:Bobby_Bland  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Bobby Bland" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bobby_Bland.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/66ebc271-6a26-4fe7-848b-f217da119d92"^^xsd:anyURI .
#
# SoloMusicArtist:Ken_Nordine  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Ken Nordine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ken_Nordine.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/02559a81-c2b5-46fd-a4d7-51d452fd3b3e"^^xsd:anyURI .
#
# SoloMusicArtist:Cal_Tjader  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Cal Tjader" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cal_Tjader.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1015b5e3-8e3d-4d78-806a-c530cf742e66"^^xsd:anyURI .
#
# SoloMusicArtist:Joe_Strummer  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Joe Strummer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joe_Strummer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/af4ea2a3-c54d-40b4-8120-a1f0b838ad54"^^xsd:anyURI .
#
# SoloMusicArtist:Leo_Kottke  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Leo Kottke" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Leo_Kottke.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1a21878d-05b1-4983-a059-7cf3abee04b7"^^xsd:anyURI .
#
# SoloMusicArtist:Hal_Willner  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Hal Willner" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hal_Willner.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2a791e7c-8012-4d5e-9581-b99a4c1abfed"^^xsd:anyURI .
#
# SoloMusicArtist:Compay_Segundo  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Compay Segundo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Compay_Segundo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8b8ab7a4-add8-4353-a586-e1086e521af8"^^xsd:anyURI .
#
# SoloMusicArtist:Megon_McDonough  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Megon McDonough" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Megon_McDonough.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/08aaad14-3e23-4eda-8bd4-66eade330178"^^xsd:anyURI .
#
# SoloMusicArtist:Paolo_Conte  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Paolo Conte" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paolo_Conte.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/777bfd31-0c54-49b9-b057-c1fa742cdcf1"^^xsd:anyURI .
#
# SoloMusicArtist:Stevie_Nicks  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Stevie Nicks" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stevie_Nicks.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b7f2cca2-72c6-41fb-ae33-53370fc62fe7"^^xsd:anyURI .
#
# SoloMusicArtist:Susan_Greenbaum  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Susan Greenbaum" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9a5a280-74d4-453f-a820-d507219651d9"^^xsd:anyURI .
#
# SoloMusicArtist:Steve_Hillage  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Steve Hillage" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steve_Hillage.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bb0ae0c0-16eb-43df-9f99-7f351c53354a"^^xsd:anyURI .
#
# SoloMusicArtist:Jen_Trynin  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Jen Trynin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jen_Trynin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/75d3704c-f5ab-4001-97de-740972461a7d"^^xsd:anyURI .
#
# SoloMusicArtist:Boo_Zoo_Chavis  a                 bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                 "Boozoo Chavis" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Boozoo_Chavis.ttl"^^xsd:anyURI .
#
# SoloMusicArtist:Bill_Frisell  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Bill Frisell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bill_Frisell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a21318db-f228-4a4d-8bce-6947a62985a5"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_Mould  a                          bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Bob Mould" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Mould.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d7f5305a-15fc-4af4-a61b-f6f45510cc8f"^^xsd:anyURI .
#
# SoloMusicArtist:Mike_Marshall  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Mike Marshall" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mike_Marshall_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/70e8f7ec-5321-4b2e-9a0a-9392d883e1ca"^^xsd:anyURI .
#
# SoloMusicArtist:Oumou_Sangare  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Oumou Sangaré" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Oumou_Sangar%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2013f3af-51a3-404d-9afc-91b3f277ea4e"^^xsd:anyURI .
#
# SoloMusicArtist:Baaba_Maal  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Baaba Maal" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Baaba_Maal.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cec7447d-a39c-41c5-ba74-5d7057e5c731"^^xsd:anyURI .
#
# SoloMusicArtist:Milt_Jackson  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Milt Jackson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Milt_Jackson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2e38e1de-2890-4620-8467-5b0bb4641cb9"^^xsd:anyURI .
#
# SoloMusicArtist:Gillian_Welch  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Gillian Welch" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gillian_Welch.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2ff49515-1701-4bac-a53a-04345893f3f3"^^xsd:anyURI .
#
# SoloMusicArtist:Tom_Russell  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Tom Russell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tom_Russell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/621e65bc-b5bc-471f-ba4d-184fc18c65e9"^^xsd:anyURI .
#
# SoloMusicArtist:Berta_Rojas  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Berta Rojas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Berta_Rojas.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7f41b109-4556-4c5f-b72e-39bc2e369cc4"^^xsd:anyURI .
#
# SoloMusicArtist:Curtis_Mayfield  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Curtis Mayfield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Curtis_Mayfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4dca4bb2-23ba-4103-97e6-5810311db33a"^^xsd:anyURI .
#
# SoloMusicArtist:John_Lennon  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "John Lennon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Lennon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4d5447d7-c61c-4120-ba1b-d7f471d385b9"^^xsd:anyURI .
#
# SoloMusicArtist:Kenny_Neal  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Kenny Neal" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kenny_Neal.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/adf3d1c6-6a7d-446c-b191-28bac7a2ee4a"^^xsd:anyURI .
#
# SoloMusicArtist:Pat_Metheny  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Pat Metheny" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pat_Metheny.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7daac7f9-8fcc-485f-a14f-f8091d98cf25"^^xsd:anyURI .
#
# SoloMusicArtist:Aimee_Mann  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Aimee Mann" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Aimee_Mann.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/db3c0a20-bf05-4b30-ac22-f294aea24172"^^xsd:anyURI .
#
# SoloMusicArtist:Mykel_Perkins  a   bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label  "Mykel Perkins" .
#
# SoloMusicArtist:Jello_Biafra  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jello Biafra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jello_Biafra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2280ca0e-6968-4349-8c36-cb0cbd6ee95f"^^xsd:anyURI .
#
# SoloMusicArtist:Orlando_Julius  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Orlando Julius" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Orlando_Julius.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d221571f-966a-41ac-83b2-261b6fda2253"^^xsd:anyURI .
#
# SoloMusicArtist:Junior_Wells  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Junior Wells" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Junior_Wells.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5f526374-0e88-4508-a8d6-7f25c16cb2d8"^^xsd:anyURI .
#
# SoloMusicArtist:Sandy_Denny  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sandy Denny" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sandy_Denny.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/08d86aab-8e58-4d9f-90e4-cfc3d2f0b867"^^xsd:anyURI .
#
# SoloMusicArtist:K_McCarty  a                          bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "K. McCarty" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kathy_McCarty.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5cdca417-1ded-41ad-b06b-fcc5410aa07f"^^xsd:anyURI .
#
# SoloMusicArtist:Ginger_Baker  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Ginger Baker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ginger_Baker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e01d1aff-9cc2-4606-83d7-56445515c6e6"^^xsd:anyURI .
#
# SoloMusicArtist:Jano   a                              bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Jano" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5dc6e316-eef1-4883-86cd-c2872e009706"^^xsd:anyURI .
#
# SoloMusicArtist:Al_DiMeola  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Al Di Meola" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Al_Di_Meola.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/09c0f334-f9de-4970-b9ee-ef799cd093be"^^xsd:anyURI .
#
# SoloMusicArtist:Hans_Zimmer  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Hans Zimmer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hans_Zimmer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e6de1f3b-6484-491c-88dd-6d619f142abc"^^xsd:anyURI .
#
# SoloMusicArtist:Oscar_Brand  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Oscar Brand" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Oscar_Brand.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c7418473-b85b-42a9-9512-1cddfb6eb3d8"^^xsd:anyURI .
#
# SoloMusicArtist:Ned_Lagin  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Ned Lagin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ned_Lagin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5f38caf8-7974-47a9-8635-ed3c7e543fbe"^^xsd:anyURI .
#
# SoloMusicArtist:Wilbur_Harden  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Wilbur Harden" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/Wilbur_Harden.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f3d8c65-7a72-414e-a83c-7aae9d129fbf"^^xsd:anyURI .
#
# SoloMusicArtist:Tom_Waits  a                          bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Tom Waits" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tom_Waits.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c3aeb863-7b26-4388-94e8-5a240f2be21b"^^xsd:anyURI .
#
# SoloMusicArtist:Iris_DeMent  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Iris DeMent" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Iris_DeMent.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e06aa44d-4c98-40c6-bf1d-d54637fa0bde"^^xsd:anyURI .
#
# SoloMusicArtist:Teddy_Thompson  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Teddy Thompson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Teddy_Thompson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1e816beb-dccc-445b-891f-f61d7d0e70d3"^^xsd:anyURI .
#
# SoloMusicArtist:Greg_Brown  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Greg Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Greg_Brown_(folk_musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8d5521d6-473d-4da0-b68d-553d4188619d"^^xsd:anyURI .
#
# SoloMusicArtist:Leonard_Cohen  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Leonard Cohen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Leonard_Cohen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/65314b12-0e08-43fa-ba33-baaa7b874c15"^^xsd:anyURI .
#
# SoloMusicArtist:Julie_Miller  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Julie Miller" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Julie_Miller.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd8fbe47-d815-474b-b0cf-b21c2f87c397"^^xsd:anyURI .
#
# SoloMusicArtist:Sonny_Landreth  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Sonny Landreth" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sonny_Landreth.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5ce64ed9-3015-4910-a2bb-1cd5c933de38"^^xsd:anyURI .
#
# SoloMusicArtist:Willie_Nelson  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Willie Nelson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Willie_Nelson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/668fd73c-bf54-4310-a139-305517f05311"^^xsd:anyURI .
#
# SoloMusicArtist:Pharoah_Sanders  a                    bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Pharoah Sanders" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pharoah_Sanders.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b3a0912a-a62a-4388-9368-7cb21ed5caf9"^^xsd:anyURI .
#
# SoloMusicArtist:Lester_Young  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Lester Young" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lester_Young.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d613e4ae-093a-49a1-b06a-579480f7f7e8"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Davies  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Davies" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Davies.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/65710ace-d0ea-45eb-afb7-291e6b13bee5"^^xsd:anyURI .
#
# SoloMusicArtist:Phil_Lesh  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Phil Lesh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Phil_Lesh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ea3d1341-bb3c-4784-bbf6-f71ebfd17e46"^^xsd:anyURI .
#
# SoloMusicArtist:Robert_Plant  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Robert Plant" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robert_Plant.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bd53f9a7-8be9-46b0-bf7d-1deea3cb57bc"^^xsd:anyURI .
#
# SoloMusicArtist:Peter_Tosh  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Peter Tosh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peter_Tosh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7db6aae5-6644-4513-9bfc-ca2e79d4469c"^^xsd:anyURI .
#
# SoloMusicArtist:Ben_Stevens  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Ben Stevens" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d09e23ce-af36-4a2f-9829-130bb7bb0ac8"^^xsd:anyURI .
#
# SoloMusicArtist:Jean_Luc_Ponty  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Jean-Luc Ponty" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jean-Luc_Ponty.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44cd4e2e-0a6a-4cd1-a2a7-e23d9f33df78"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Doucet  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Doucet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Doucet.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/53614b6c-a35d-4df7-9845-a7cc3d76b283"^^xsd:anyURI .
#
# SoloMusicArtist:Quincy_Jones  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Quincy Jones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Quincy_Jones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5803c81e-739a-4057-9a5c-cf84e55db630"^^xsd:anyURI .
#
# SoloMusicArtist:Linda_Thompson  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Linda Thompson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Linda_Thompson_(singer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/30792486-de7c-458a-873c-ca6931540a70"^^xsd:anyURI .
#
# SoloMusicArtist:Cyndi_Lauper  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Cyndi Lauper" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cyndi_Lauper.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7bd9e20e-74b9-446a-a2ed-a223f82a36e7"^^xsd:anyURI .
#
# SoloMusicArtist:James_Taylor  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "James Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/James_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/107d0c22-d051-4d98-8206-4e14de02132a"^^xsd:anyURI .
#
# SoloMusicArtist:Frank_Zappa  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Frank Zappa" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Frank_Zappa.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e20747e7-55a4-452e-8766-7b985585082d"^^xsd:anyURI .
#
# SoloMusicArtist:Todd_Snider  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Todd Snider" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Todd_Snider.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/25c13ec7-fad4-4da4-8d98-9607ff615d68"^^xsd:anyURI .
#
# SoloMusicArtist:Juliana_Hatfield  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Juliana Hatfield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Juliana_Hatfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f8bf63aa-9bc9-4c03-8673-396cfd5d3cab"^^xsd:anyURI .
#
# SoloMusicArtist:Ralph_McTell  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Ralph McTell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ralph_McTell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8bf5abde-89d0-4676-98ef-7e1a4eecd03d"^^xsd:anyURI .
#
# SoloMusicArtist:Dianne_Reeves  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Dianne Reeves" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dianne_Reeves.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/069c1f30-fd2a-4342-924a-cca7c605807f"^^xsd:anyURI .
#
# SoloMusicArtist:Alex_Chilton  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Alex Chilton" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Alex_Chilton.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/18b2f43a-fc98-4aab-b69c-eaaba41fecbc"^^xsd:anyURI .
#
# SoloMusicArtist:Donald_Fagen  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Donald Fagen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Donald_Fagen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/70047e57-0153-4117-b0fc-a1d2e322e5ef"^^xsd:anyURI .
#
# SoloMusicArtist:Nnenna_Freelon  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Nnenna Freelon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nnenna_Freelon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/389048c5-6cc4-4aa9-a7e3-df48ccb28c78"^^xsd:anyURI .
#
# SoloMusicArtist:Tim_Reynolds  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Tim Reynolds" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tim_Reynolds.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4ebefe60-3a9b-42a6-a5c5-27b85b76583f"^^xsd:anyURI .
#
# SoloMusicArtist:JJ_Cale  a                            bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "JJ Cale" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/J._J._Cale.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4b0be624-6b87-47e8-bbf0-588a2c6c0439"^^xsd:anyURI .
#
# SoloMusicArtist:John_Kirkpatrick  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "John Kirkpatrick" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Kirkpatrick_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cce8cdcc-294d-4f83-8f38-5e1b10573910"^^xsd:anyURI .
#
# SoloMusicArtist:William_Ackerman  a                   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "William Ackerman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/William_Ackerman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5155c952-8353-4e75-a56e-12e67aefdcb3"^^xsd:anyURI .
#
# SoloMusicArtist:Andre_Ceccarelli  a                   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "André Ceccarelli" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Andr%C3%A9_Ceccarelli.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/68a155b4-0345-44be-ab3f-dc88f68960ec"^^xsd:anyURI .
#
# SoloMusicArtist:Robert_Hunter  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Robert Hunter" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robert_Hunter_(lyricist).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9b419b5-ab8f-425c-8214-a7259e6efe10"^^xsd:anyURI .
#
# SoloMusicArtist:Screamin_Jay_Hawkins
#         a                              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Screamin' Jay Hawkins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Screamin'_Jay_Hawkins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/185af318-55c7-405f-8b00-0fa308e56da9"^^xsd:anyURI .
#
# SoloMusicArtist:Ibrahim_Ferrer  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ibrahim Ferrer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ibrahim_Ferrer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a61930ae-dfe3-4574-bc5b-b0fa8d8efb62"^^xsd:anyURI .
#
# SoloMusicArtist:Paul_Thorn  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Paul Thorn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paul_Thorn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f560cffe-c225-4b91-8511-403219819200"^^xsd:anyURI .
#
# SoloMusicArtist:Sass_Jordan  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Sass Jordan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sass_Jordan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3bbd6c44-385e-4e51-8250-fbb23435f165"^^xsd:anyURI .
#
# SoloMusicArtist:Jill_Cohn  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jill Cohn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/James_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f39fe911-99b2-4a27-898e-c2f0ff458eed"^^xsd:anyURI .
#
# SoloMusicArtist:Meshell_Ndegeocello  a                bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Me'Shell Ndegéocello" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Meshell_Ndegeocello.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/55a8b485-1cbf-47ee-ae15-d106200fafe8"^^xsd:anyURI .
#
# SoloMusicArtist:Laura_Nyro  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Laura Nyro" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Laura_Nyro.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bb0a1e95-9444-4a05-a1bb-22b8d7ed7844"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Williams  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Williams" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Williams_(drummer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b6a30b58-6b00-47c4-a031-c62a6981461f"^^xsd:anyURI .
#
# SoloMusicArtist:Serge_Gainsbourg  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Serge Gainsbourg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Serge_Gainsbourg.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b21ef19b-c6aa-4775-90d3-3cc3e067ce6d"^^xsd:anyURI .
#
# SoloMusicArtist:Georges_Kazazian  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Georges Kazazian" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Georges_Kazazian.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/febbd7db-56c2-42ed-b059-0b13a58db3ea"^^xsd:anyURI .
#
# SoloMusicArtist:Cat_Stevens  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Cat Stevens" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cat_Stevens.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e2345fdf-2be7-47c5-a6dd-be64353ad134"^^xsd:anyURI .
#
# SoloMusicArtist:Jose_Soto  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "José Soto \"Sorderita\"" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f4bf07da-92d9-449f-bbb9-ff104b7321db"^^xsd:anyURI .
#
# SoloMusicArtist:Herbie_Hancock  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Herbie Hancock" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Herbie_Hancock.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/27613b78-1b9d-4ec3-9db5-fa0743465fdd"^^xsd:anyURI .
#
# SoloMusicArtist:Mike_Scott  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Mike Scott" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mike_Scott_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/36deef3e-384d-4cdd-9a8e-f63aa3e16878"^^xsd:anyURI .
#
# SoloMusicArtist:Robin_Holcomb  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Robin Holcomb" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robin_Holcomb.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/99c41ed0-b681-4c1a-b232-d3819a28adb0"^^xsd:anyURI .
#
# SoloMusicArtist:KD_Lang  a                            bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "k.d. lang" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/K.d._lang.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/675c1c5e-5625-4a5e-97a2-b02aab5db2fc"^^xsd:anyURI .
#
# SoloMusicArtist:Jimi_Hendrix  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jimi Hendrix" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jimi_Hendrix.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/06fb1c8b-566e-4cb2-985b-b467c90781d4"^^xsd:anyURI .
#
# SoloMusicArtist:Richard_Thompson  a                   bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Richard Thompson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Richard_Thompson_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ecfeacaf-0399-470f-8207-d1c646569fd0"^^xsd:anyURI .
#
# SoloMusicArtist:John_Coltrane  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "John Coltrane" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Coltrane.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b625448e-bf4a-41c3-a421-72ad46cdb831"^^xsd:anyURI .
#
# SoloMusicArtist:Cassandra_Wilson  a                   bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Cassandra Wilson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cassandra_Wilson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/eb6595d3-e559-4bcc-a516-843bfdba82e9"^^xsd:anyURI .
#
# SoloMusicArtist:Lisa_Loeb  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Lisa Loeb" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lisa_Loeb.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/22c5cef9-80e8-48d2-acd3-6d16f6c8a16d"^^xsd:anyURI .
#
# SoloMusicArtist:Jim_White  a                          bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jim White" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jim_White_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e1f83b22-d40e-400a-8ebb-4e59b5b53d31"^^xsd:anyURI .
#
# SoloMusicArtist:Amanda_Marshall  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Amanda Marshall" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Amanda_Marshall.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6f1f4bb7-5253-4524-b4db-6a0a7f3cb4c5"^^xsd:anyURI .
#
# SoloMusicArtist:Walter_Becker  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Walter Becker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Walter_Becker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8cc72457-488e-44e6-a5b3-d2da843b7245"^^xsd:anyURI .
#
# SoloMusicArtist:Tommy_Peoples  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Tommy Peoples" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tommy_Peoples.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3d546ba7-aac8-474d-99ea-535a7ef7733e"^^xsd:anyURI .
#
# SoloMusicArtist:Professor_Longhair  a                 bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Professor Longhair" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Professor_Longhair.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c6177e77-151d-422d-bc87-57ae21d2780e"^^xsd:anyURI .
#
# SoloMusicArtist:Bryan_Ferry  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Bryan Ferry" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bryan_Ferry.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4ef7a9e2-2cf5-483a-8616-ef7791a98026"^^xsd:anyURI .
#
# SoloMusicArtist:Mary_Black  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Mary Black" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mary_Black.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dcc0e816-31d2-4501-93c6-b5b64fcda39f"^^xsd:anyURI .
#
# SoloMusicArtist:David_Wilcox  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "David Wilcox" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Wilcox_(American_musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/694b6a5a-e984-47f4-9a21-1a1ee76044df"^^xsd:anyURI .
#
# SoloMusicArtist:Jimmy_Cliff  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jimmy Cliff" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jimmy_Cliff.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2caa54a7-b08c-41da-b892-3a41abe778be"^^xsd:anyURI .
#
# SoloMusicArtist:Victoria_Williams  a                  bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Victoria Williams" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Victoria_Williams.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/161fe176-42d6-4a1a-8372-280164c7f15f"^^xsd:anyURI .
#
# SoloMusicArtist:Clarence_Gatemouth_Brown
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Clarence Gatemouth Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Clarence_\"Gatemouth\"_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/039e3952-2f73-49f4-86fe-7aaee4a89a17"^^xsd:anyURI .
#
# SoloMusicArtist:Mike_Bloomfield  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Bloomfield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mike_Bloomfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1be2e508-905c-4d90-9bf2-7ab55f78b3e6"^^xsd:anyURI .
#
# SoloMusicArtist:Dick_Dale  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dick Dale" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dick_Dale.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cc6115aa-379c-4133-9f46-5743a4a341d0"^^xsd:anyURI .
#
# SoloMusicArtist:Nina_Hagen  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Nina Hagen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nina_Hagen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e4d32f51-bc57-42a4-8165-b80f7a86496d"^^xsd:anyURI .
#
# SoloMusicArtist:Abbey_Lincoln  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Abbey Lincoln" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Abbey_Lincoln.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ce8cbced-8719-47b9-b728-6024e8b19b15"^^xsd:anyURI .
#
# SoloMusicArtist:Junis_Ponds  a     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label  "Junis Ponds" .
#
# SoloMusicArtist:Robbie_Laws  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Robbie Laws" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f07a0389-cc26-408b-864e-fc098d0e8b93"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Rich  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Rich" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Rich.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1e3bdbd0-f15b-4038-895f-d9a1f6571436"^^xsd:anyURI ;
#         skos:altLabel                  "The Tony Rich Project" .
#
# SoloMusicArtist:Marlee_MacLeod  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Marlee MacLeod" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44232ba9-34fd-450f-bc37-cdb1aaae05ce"^^xsd:anyURI .
#
# SoloMusicArtist:Brooks_Williams  a                    bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Brooks Williams" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Brooks_Williams.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1cc7480d-e28f-42e8-8aad-d7f34fa5676d"^^xsd:anyURI .
#
# SoloMusicArtist:Horace_Silver  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Horace Silver" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Horace_Silver.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d185d986-ee96-4fd3-bd61-8c848a4765b6"^^xsd:anyURI .
#
# SoloMusicArtist:Robby_Krieger  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Robby Krieger" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robby_Krieger.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b553f0ad-4543-46f2-88ea-1dc94a11c91a"^^xsd:anyURI .
#
# SoloMusicArtist:Willie_Dixon  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Willie Dixon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Willie_Dixon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ff4c8d42-4871-4778-885b-d41b01245133"^^xsd:anyURI .
#
# SoloMusicArtist:Annie_Lennox  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Annie Lennox" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Annie_Lennox.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3e30aebd-0557-4cfd-8fb9-3945afa5d72b"^^xsd:anyURI .
#
# SoloMusicArtist:Thelonious_Monk  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Thelonious Monk" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Thelonious_Monk.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8e8c7417-c905-46b1-b42a-5260b4274ed4"^^xsd:anyURI .
#
# SoloMusicArtist:Luka_Bloom  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Luka Bloom" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Luka_Bloom.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f70e325-8e95-406e-962c-e79190c7a5bf"^^xsd:anyURI .
#
# SoloMusicArtist:Nurudafina_Pili_Adena
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Nurudafina Pili Adena" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9e668c6-41a3-4c69-af91-df8bc7856950"^^xsd:anyURI .
#
# SoloMusicArtist:Rossy  a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Rossy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rossy_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c39462a1-2b7a-4333-b95f-d0620d974504"^^xsd:anyURI .
#
# SoloMusicArtist:Judy_Mowatt  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Judy Mowatt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Judy_Mowatt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/67919668-0060-4097-9687-8af0ed1df3da"^^xsd:anyURI .
#
# SoloMusicArtist:Patti_Rothberg  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Patti Rothberg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patti_Rothberg"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5d9a7f2a-c5e7-4589-bd84-56432ff6c44d"^^xsd:anyURI .
#
# SoloMusicArtist:Paula_Cole  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Paula Cole" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paula_Cole.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d3ba9251-215f-4ef3-a6de-8aa256b9c30c"^^xsd:anyURI .
#
# SoloMusicArtist:Sarah_McLachlan  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Sarah McLachlan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sarah_McLachlan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ce58d854-7430-4231-aa44-97f0144b3372"^^xsd:anyURI .
#
# SoloMusicArtist:Ali_Farka_Toure  a                    bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Ali Farka Touré" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ali_Farka_Tour%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9be2a5ac-8201-489b-b5f6-91f958bf9060"^^xsd:anyURI ;
#         skos:prefLabel                 "Ali Farka Touré" .
#
# SoloMusicArtist:Jackson_Browne  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jackson Browne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jackson_Browne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/88527d26-7496-47c5-8358-ebdb1868a90f"^^xsd:anyURI .
#
# SoloMusicArtist:Karl_Denson  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Karl Denson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Karl_Denson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e841dc87-7d2f-4ee2-ac70-e0941a7954c4"^^xsd:anyURI .
#
# SoloMusicArtist:Jessica_Ruby_Simpson
#         a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Jessica Ruby Simpson" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cace72a8-adc6-4bb2-bf1a-34d75770afc8"^^xsd:anyURI .
#
# SoloMusicArtist:Holger_Czukay  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Holger Czukay" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Holger_Czukay.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a48cce8c-8632-4e6f-b46f-40139be33ba0"^^xsd:anyURI .
#
# SoloMusicArtist:Thomas_Mapfumo  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Thomas Mapfumo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Thomas_Mapfumo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c17caac7-7667-4c8c-b54e-0aac360b37b6"^^xsd:anyURI .
#
# SoloMusicArtist:Sally_Fingerett  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sally Fingerett" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sally_Fingerett.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/40791151-f17a-42b2-bbb9-6d94e630df5e"^^xsd:anyURI .
#
# SoloMusicArtist:Airto_Moreira  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Airto Moreira" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Airto_Moreira.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dd2abaa1-0b73-4ded-82ed-c80cce8d6378"^^xsd:anyURI .
#
# SoloMusicArtist:Ian_Dury  a                           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Ian Dury & the Blockheads" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ian_Dury.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d4675794-9ad3-48eb-bcd4-b98be183b396"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Fracasso  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Fracasso" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Fracasso.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/17f8d423-6cf2-462e-afb7-1f76d5227cd4"^^xsd:anyURI .
#
# SoloMusicArtist:Tret_Fure  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Tret Fure" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tret_Fure.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b5d5b93d-1017-4b08-8878-5698db517acc"^^xsd:anyURI .
#
# SoloMusicArtist:Adrian_Belew  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Adrian Belew" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Adrian_Belew.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/73c3f499-60e2-44e1-81dd-7fe2191461fa"^^xsd:anyURI .
#
# SoloMusicArtist:Eddi_Reader  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Eddi Reader" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eddi_Reader.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ea2a48b2-0969-4496-9635-4ee206f3ffc5"^^xsd:anyURI .
#
# SoloMusicArtist:Eric_Andersen  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Eric Andersen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eric_Andersen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/69268541-0d69-4e0b-a121-2697bc8fff1b"^^xsd:anyURI .
#
# SoloMusicArtist:George_Winston  a                     bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "George Winston" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/George_Winston.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a6b93c3c-88bc-431c-a46c-155dee9371aa"^^xsd:anyURI .
#
# SoloMusicArtist:Sylvestre_Randafison
#         a                              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sylvestre Randafison" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2bb88094-0f77-47ca-9ff3-c04de2a8215a"^^xsd:anyURI .
#
# SoloMusicArtist:Rufus_Wainwright  a                   bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Rufus Wainwright" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rufus_Wainwright.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/78e46ae5-9bfd-433b-be3f-19e993d67ecc"^^xsd:anyURI .
#
# SoloMusicArtist:Sonia  a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sonia" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sonia_(singer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e7281e91-dfa9-4938-bdc2-979cb003ddd0"^^xsd:anyURI .
#
# SoloMusicArtist:Cannonball_Adderley  a                bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Cannonball Adderley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/Cannonball_Adderley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a4c73ebe-b2c7-4f13-b99d-2fe1f9f27da8"^^xsd:anyURI .
#
# SoloMusicArtist:Eleanor_McEvoy  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Eleanor McEvoy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eleanor_McEvoy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/464fe4a6-e4e1-4375-a73a-619e40995e31"^^xsd:anyURI .
#
# SoloMusicArtist:Danny_Thompson  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Danny Thompson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Danny_Thompson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0cd5e16e-a6ab-43af-8d75-158b3b561f6e"^^xsd:anyURI .
#
# SoloMusicArtist:William_S_Burroughs  a                bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "William S. Burroughs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/William_S._Burroughs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f150ed27-bee7-49d8-a226-31fef88c29b3"^^xsd:anyURI .
#
# SoloMusicArtist:Les_Brown  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Les Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Les_Brown_(bandleader).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3ffc8b31-cfe8-44c9-aa2e-e82d3355e9b3"^^xsd:anyURI .
#
# SoloMusicArtist:Gram_Parsons  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Gram Parsons" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gram_Parsons.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cbc83fb1-2c23-4ad1-9187-594b30da3f21"^^xsd:anyURI .
#
# SoloMusicArtist:Mick_Wolf  a       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label  "Mick Wolf" .
#
# SoloMusicArtist:Lauryn_Hill  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Lauryn Hill" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lauryn_Hill.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e8414012-4a1c-4ad4-be5e-fc55294e28cc"^^xsd:anyURI .
#
# SoloMusicArtist:Ahmad_Jamal  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Ahmad Jamal" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ahmad_Jamal.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf816800-4e0e-4d80-9cca-50a725e93787"^^xsd:anyURI .
#
# SoloMusicArtist:Isaac_Hayes  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Isaac Hayes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Isaac_Hayes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a2361c7d-ddb6-41c1-a9a0-be09fbbb8d21"^^xsd:anyURI .
#
# SoloMusicArtist:Sally_Taylor  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sally Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sally_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b7046af5-9a7b-4e88-ae76-dbaaea3f0d8f"^^xsd:anyURI .
#
# SoloMusicArtist:Howard_Shore  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Howard Shore" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Howard_Shore.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9b58672a-e68e-4972-956e-a8985a165a1f"^^xsd:anyURI .
#
# SoloMusicArtist:John_Scofield  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "John Scofield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Scofield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cbfd7f01-87c3-44bf-a3a2-fe4dbff20ad2"^^xsd:anyURI .
#
# SoloMusicArtist:Lucinda_Williams  a                   bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Lucinda Williams" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lucinda_Williams.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/21685b15-3074-446e-aa1d-ff7157014f53"^^xsd:anyURI .
#
# SoloMusicArtist:Paul_Kantner  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Paul Kantner" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paul_Kantner.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bfe46b8e-0c14-41c3-9ffe-c7ce3b53d226"^^xsd:anyURI .
#
# SoloMusicArtist:Wendy_Woo  a                          bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Wendy Woo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wendy_Woo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3f1a840b-74d5-4ce8-9b46-aa9915c00ca7"^^xsd:anyURI .
#
# SoloMusicArtist:Van_Morrison  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Van Morrison" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Van_Morrison.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a41ac10f-0a56-4672-9161-b83f9b223559"^^xsd:anyURI .
#
# SoloMusicArtist:David_Gray  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "David Gray" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Gray_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3e8bd859-7d82-49e0-b267-84fc46e2bf68"^^xsd:anyURI .
#
# SoloMusicArtist:Maura_OConnell  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Maura O'Connell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Maura_O'Connell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/522f9070-ab8a-42d0-8f0a-f2f35dcf40d4"^^xsd:anyURI .
#
# SoloMusicArtist:John_Fahey  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Fahey" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Fahey_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/95bb27d2-43c7-4a92-85ee-f95a245f0ee4"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_Marley  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Bob Marley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Marley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ed2ac1e9-d51d-4eff-a2c2-85e81abd6360"^^xsd:anyURI .
#
# SoloMusicArtist:DGary  a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "D'Gary" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/D%27Gary.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/612fcd72-c4a5-47df-bbdd-7e4b3292873a"^^xsd:anyURI .
#
# SoloMusicArtist:Buckwheat_Zydeco  a                   bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Buckwheat Zydeco" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buckwheat_Zydeco.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ca2b920b-702a-4c4a-9e22-a07e052b4fd8"^^xsd:anyURI .
#
# SoloMusicArtist:Joe_Zawinul  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Joe Zawinul" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joe_Zawinul.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dfe8c9e1-10c0-49ab-a07a-5b4c60179611"^^xsd:anyURI .
#
# SoloMusicArtist:Clifton_Chenier  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Clifton Chenier" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Clifton_Chenier.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/db1a3066-1586-495d-a09c-1312cabab5be"^^xsd:anyURI .
#
# SoloMusicArtist:Nan_Vernon  a                         bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Nan Vernon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nan_Vernon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/39efdfba-7082-47d4-9590-f50c8f671475"^^xsd:anyURI .
#
# SoloMusicArtist:Ben_Webster  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Ben Webster" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ben_Webster.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e28c0b26-3bdb-45dc-b4f5-f309c7c35ec4"^^xsd:anyURI .
#
# SoloMusicArtist:Audra_McDonald  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Audra McDonald" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Audra_McDonald.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/485ae838-05a9-49d0-9421-6ccfb203f17b"^^xsd:anyURI .
#
# SoloMusicArtist:Sigi_Schwab  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Siegfried Schwab" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sigi_Schwab.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/daa9e6b6-5454-4ad2-b099-bc0e5054ba3e"^^xsd:anyURI .
#
# SoloMusicArtist:Janis_Joplin  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Janis Joplin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Janis_Joplin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/76c9a186-75bd-436a-85c0-823e3efddb7f"^^xsd:anyURI .
#
# SoloMusicArtist:Joy_Askew  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Joy Askew" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d68ea536-ab61-4a2b-964a-07367a4835fb"^^xsd:anyURI .
#
# SoloMusicArtist:Daniel_Johnston  a                    bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Daniel Johnston" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Daniel_Johnston.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8a7ca8b0-d23c-4eff-8fe9-6220ba5c9c76"^^xsd:anyURI .
#
# SoloMusicArtist:Bill_Bruford  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Bill Bruford" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bill_Bruford.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0211756e-139e-4b4c-a721-9ee9db363f12"^^xsd:anyURI .
#
# SoloMusicArtist:King_Sunny_Ade  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "King Sunny Adé" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/King_Sunny_Ad%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3e110caa-e9e8-4c33-98dc-ebbf0c6d2494"^^xsd:anyURI .
#
# SoloMusicArtist:Darrell_Grant  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Darrell Grant" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/12d4b9e7-b05f-4a4d-88a3-edd4bc7f142b"^^xsd:anyURI .
#
# SoloMusicArtist:Wynton_Kelly  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Wynton Kelly" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wynton_Kelly.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d3f9352c-18e2-47a0-802c-13d821490e42"^^xsd:anyURI .
#
# SoloMusicArtist:Martin_Taylor  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Martin Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Martin_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/92ebb02d-2906-4a6d-9e43-21e16b877fa1"^^xsd:anyURI .
#
# SoloMusicArtist:Michelle_Shocked  a                   bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Michelle Shocked" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michelle_Shocked.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e2f41b6e-7045-44e8-86bf-deee758532e2"^^xsd:anyURI .
#
# SoloMusicArtist:Flora_Purim  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Flora Purim" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Flora_Purim.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b1091eee-4198-4e66-8b15-05ae12b03353"^^xsd:anyURI .
#
# SoloMusicArtist:John_Hartford  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Hartford" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Hartford.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3178cc4c-cd9f-4842-96fb-28bf9cfec591"^^xsd:anyURI .
#
# SoloMusicArtist:Erykah_Badu  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Erykah Badu" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Erykah_Badu.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/321531fc-db73-4ffa-a959-61a61a2908c1"^^xsd:anyURI .
#
# SoloMusicArtist:Ruben_Blades  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Rubén Blades" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rub%C3%A9n_Blades.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f050673a-dfb3-4200-b057-bf78213de36c"^^xsd:anyURI .
#
# SoloMusicArtist:Toni_Childs  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Toni Childs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Toni_Childs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dc4dd336-2299-4d7d-9514-b4f2cd8d0297"^^xsd:anyURI .
#
# SoloMusicArtist:Paul_Simon  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Paul Simon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paul_Simon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/05517043-ff78-4988-9c22-88c68588ebb9"^^xsd:anyURI .
#
# SoloMusicArtist:David_Bowie  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "David Bowie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Bowie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5441c29d-3602-4898-b1a1-b77fa23b8e50"^^xsd:anyURI .
#
# SoloMusicArtist:Lynn_Miles  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Lynn Miles" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lynn_Miles.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b12ba762-0dc2-465d-9c3a-7ba342498767"^^xsd:anyURI .
#
# SoloMusicArtist:Julia_Fordham  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Julia Fordham" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Julia_Fordham.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4cedbd59-60f8-4a0e-9b81-346220311123"^^xsd:anyURI .
#
# SoloMusicArtist:Rick_Danko  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Rick Danko" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rick_Danko.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/39d5615d-1418-4b80-85aa-214eaac7cfb2"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Matthews  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Matthews" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Matthews.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2fa95b32-3c11-42d7-b495-12fc6be0a024"^^xsd:anyURI .
#
# SoloMusicArtist:T_Bone_Burnett  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "T‐Bone Burnett" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/T_Bone_Burnett.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b821dd8c-4583-4385-9293-6f1015b74ef9"^^xsd:anyURI .
#
# SoloMusicArtist:Joy_Eden_Harrison  a              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                 "Joy Eden Harrison" ;
#         bibliographica:dbpediaURI  "http://dbpedia.org/data/Joy_Eden_Harrison.ttl"^^xsd:anyURI .
#
# SoloMusicArtist:Ashley_MacIsaac  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Ashley MacIsaac" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ashley_MacIsaac.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ec2764e4-8cc1-4c40-b7c0-466a3763cd37"^^xsd:anyURI .
#
# SoloMusicArtist:Mike_Auldridge  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Mike Auldridge" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mike_Auldridge.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a6604c40-3e7f-4090-ac6b-cbb8352df7f5"^^xsd:anyURI .
#
# SoloMusicArtist:Guty_Cardenas  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Guty Cárdenas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Guty_C%C3%A1rdenas.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c1b7081b-6425-463e-8c2c-649de5d1e220"^^xsd:anyURI .
#
# SoloMusicArtist:Lori_McKenna  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Lori McKenna" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lori_McKenna.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/886557b3-2fa6-494e-993d-b955e789dc57"^^xsd:anyURI .
#
# SoloMusicArtist:Beth_Hart  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Beth Hart" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Beth_Hart.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3fe817fc-966e-4ece-b00a-76be43e7e73c"^^xsd:anyURI .
#
# SoloMusicArtist:Bessie_Smith  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Bessie Smith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bessie_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ffa28768-ecda-42c6-ac49-6ce5c7d33043"^^xsd:anyURI .
#
# SoloMusicArtist:Grace_Jones  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Grace Jones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Grace_Jones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b1c124b3-cf60-41a6-8699-92728c8a3fe0"^^xsd:anyURI .
#
# SoloMusicArtist:Laurie_Anderson  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Laurie Anderson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Laurie_Anderson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/86809b51-cbe2-45f1-804a-e66eed635dea"^^xsd:anyURI .
#
# SoloMusicArtist:Janis_Ian  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Janis Ian" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Janis_Ian.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b72f115c-8afa-4dc5-bc6c-11225a53708a"^^xsd:anyURI .
#
# SoloMusicArtist:Dumisani_Maraire  a                   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dumisani Maraire" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dumisani_Maraire.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9a4d5b32-a34a-4aec-b781-865b4fb56026"^^xsd:anyURI .
#
# SoloMusicArtist:Sidney_Bechet  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sidney Bechet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sidney_Bechet.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bf1b23ea-9b76-42cf-a5f6-4a691e81af5e"^^xsd:anyURI .
#
# SoloMusicArtist:Bernie_Worrell  a                     bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Bernie Worrell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bernie_Worrell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e68abd50-e5ec-4b5c-87dd-0fd0437cafd1"^^xsd:anyURI .
#
# SoloMusicArtist:Elliott_Smith  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Elliott Smith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Elliott_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/03ad1736-b7c9-412a-b442-82536d63a5c4"^^xsd:anyURI .
#
# SoloMusicArtist:Marc_Johnson  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Marc Johnson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Marc_Johnson_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c0540872-ad50-4973-be47-f833940aa1b1"^^xsd:anyURI .
#
# SoloMusicArtist:Buddy_Guy  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Buddy Guy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buddy_Guy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4336a134-d091-4e54-9967-c7c433db6d4e"^^xsd:anyURI .
#
# SoloMusicArtist:Jennifer_Warnes  a                    bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jennifer Warnes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jennifer_Warnes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ee23fe81-e9e0-43cb-9794-6e91a97d7b3d"^^xsd:anyURI .
#
# SoloMusicArtist:Jonathan_Richmond  a                  bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Jonathan Richmond" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jonathan_Richman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bae34b81-9abd-416e-a720-fedc359df775"^^xsd:anyURI .
#
# SoloMusicArtist:Clive_Gregson  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Clive Gregson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Clive_Gregson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2311cb27-22f2-451e-8af3-f9ab594f15a9"^^xsd:anyURI .
#
# SoloMusicArtist:Jan_Hellriegel  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jan Hellriegel" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jan_Hellriegel.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5bcf2650-7dcd-4e8c-856d-f6073d2c8c2c"^^xsd:anyURI .
#
# SoloMusicArtist:Sheryl_Crow  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sheryl Crow" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sheryl_Crow.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/80ccfede-c258-4575-a7ad-c982e9932e0f"^^xsd:anyURI .
#
# SoloMusicArtist:Billy_Cobham  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Billy Cobham" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Billy_Cobham.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/255497f8-26fb-4044-b97e-d4787d5974f6"^^xsd:anyURI .
#
# SoloMusicArtist:Ira_Stein  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Ira Stein" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bf04ba36-394d-41cf-a94b-7cc9ffc02445"^^xsd:anyURI .
#
# SoloMusicArtist:Tommy_Bolin  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Tommy Bolin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tommy_Bolin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1edd8e9a-0deb-4548-a2a3-679af784f6c6"^^xsd:anyURI .
#
# SoloMusicArtist:Earl_Klugh  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Earl Klugh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Earl_Klugh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5c44b1b8-07ad-4aca-ac5d-ebdad8e62e12"^^xsd:anyURI .
#
# SoloMusicArtist:Lori_Carson  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Lori Carson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lori_Carson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/94028c33-8b11-496a-9491-8d6d676b88ab"^^xsd:anyURI .
#
# SoloMusicArtist:Tom_Wasinger  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Tom Wasinger" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tom_Wasinger.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9da1b9fe-1547-4c22-b3a6-e8da771fa452"^^xsd:anyURI .
#
# SoloMusicArtist:Regina_Carter  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Regina Carter" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Regina_Carter.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cdec40b9-84b4-4cd0-bab0-a77e1ad82a03"^^xsd:anyURI .
#
# SoloMusicArtist:Lindsay_Cooper  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Lindsay Cooper" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lindsay_Cooper.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4675dce4-32cd-4e5b-8270-676e2b9860c9"^^xsd:anyURI .
#
# SoloMusicArtist:Bill_Morrissey  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Bill Morrissey" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bill_Morrissey.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c274bda6-1230-49c6-b307-22146344d335"^^xsd:anyURI .
#
# SoloMusicArtist:Christine_Collister  a                bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Christine Collister" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Christine_Collister.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d46021e8-e269-40bd-a6d0-cf20da529b59"^^xsd:anyURI .
#
# SoloMusicArtist:Jah_Wobble  a                         bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jah Wobble" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jah_Wobble.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/904cc1c8-021e-45ac-bbe9-95c01a1f8099"^^xsd:anyURI .
#
# SoloMusicArtist:Katy_Moffatt  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Katy Moffatt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Katy_Moffatt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2d22e7de-81ab-42f3-a2e4-45dd395cf212"^^xsd:anyURI .
#
# SoloMusicArtist:George_Clinton  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "George Clinton" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/George_Clinton_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/84683370-5eae-418b-acd8-883ac028a8a0"^^xsd:anyURI .
#
# SoloMusicArtist:Rachelle_Ferrell  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Rachelle Ferrell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rachelle_Ferrell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/58ef4b35-02f7-4fae-994a-f6324211d2dc"^^xsd:anyURI .
#
# SoloMusicArtist:Edgar_Meyer  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Edgar Meyer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Edgar_Meyer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/901caa09-383e-4dbc-95f2-a75ec7863b6a"^^xsd:anyURI .
#
# SoloMusicArtist:Gordon_Lightfoot  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Gordon Lightfoot" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gordon_Lightfoot.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9d97b077-b28d-4ba8-a3d9-c71926e3b2b6"^^xsd:anyURI .
#
# SoloMusicArtist:Johnny_Cash  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Johnny Cash" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Johnny_Cash.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d43d12a1-2dc9-4257-a2fd-0a3bb1081b86"^^xsd:anyURI .
#
# SoloMusicArtist:Maire_Brennan  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Maire Brennan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/page/Moya_Brennan"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/51823891-6035-4d6c-a007-b70a86747023"^^xsd:anyURI .
#
# SoloMusicArtist:Roy_Buchanan  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Roy Buchanan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Roy_Buchanan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/82ad256f-8036-4318-98cb-e9b1e36c39e6"^^xsd:anyURI .
#
# SoloMusicArtist:Junko_Onishi  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Junko Onishi" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Junko_Onishi_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/57f23a73-0188-4d8e-81e3-66da6019a79e"^^xsd:anyURI .
#
# SoloMusicArtist:Steve_Earle  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Steve Earle" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steve_Earle.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ec863030-7c13-45a3-a025-a69195d3a020"^^xsd:anyURI .
#
# SoloMusicArtist:Robbie_Robertson  a                   bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Robbie Robertson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robbie_Robertson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a0920ae6-2968-4f92-ac14-67448452bd18"^^xsd:anyURI .
#
# SoloMusicArtist:Brian_Eno  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Brian Eno" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Brian_Eno.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ff95eb47-41c4-4f7f-a104-cdc30f02e872"^^xsd:anyURI .
#
# SoloMusicArtist:Jack_DeJohnette  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jack DeJohnette" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jack_DeJohnette.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f2d13d28-6f74-4dd5-b596-8bd0b6f67615"^^xsd:anyURI .
#
# SoloMusicArtist:Loey_Nelson  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Loey Nelson" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9bfd0a4c-b448-49e8-af60-afacadb070cb"^^xsd:anyURI .
#
# SoloMusicArtist:Billy_Bragg  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Billy Bragg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Billy_Bragg.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7cec4a03-0a83-4308-856a-afb8aa5db0fc"^^xsd:anyURI .
#
# SoloMusicArtist:Charles_Mingus  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Charles Mingus" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Charles_Mingus.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f3b8e107-abe8-4743-b6a3-4a4ee995e71f"^^xsd:anyURI .
#
# SoloMusicArtist:Sinead_OConnor  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Sinéad O’Connor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sin%C3%A9ad_O'Connor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c78a77fa-507c-4c07-947a-0355029453bd"^^xsd:anyURI .
#
# SoloMusicArtist:Joan_Baez  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Joan Baez" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joan_Baez.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/92d37892-6186-4459-9cc1-f0dde57652d0"^^xsd:anyURI .
#
# SoloMusicArtist:Charlie_Parker  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Charlie Parker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Charlie_Parker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c7356af9-9ea6-4a78-a55b-c73775716312"^^xsd:anyURI .
#
# SoloMusicArtist:Gil_Scott_Heron  a                    bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Gil Scott-Heron" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gil_Scott-Heron.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b5b89643-c488-4f39-a302-25cab31084a5"^^xsd:anyURI .
#
# SoloMusicArtist:Jerry_Lee_Lewis  a                    bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Jerry Lee Lewis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Lee_Lewis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b59ac58d-036e-4bba-8112-c32a34c4575b"^^xsd:anyURI .
#
# SoloMusicArtist:Bob_James  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Bob James" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_James_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f4d2fc5a-cacb-47c8-b096-ee73864b1aa8"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Bennett  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Bennett" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Bennett.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8be0594f-8c13-46bb-ab06-f93ffba5c776"^^xsd:anyURI .
#
# SoloMusicArtist:Pete_Zorn  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Pete Zorn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pete_Zorn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6fd4e675-1b3d-4265-ab6d-6f2863394010"^^xsd:anyURI .
#
# SoloMusicArtist:Wynton_Marsalis  a                    bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Wynton Marsalis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wynton_Marsalis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0d74dcc7-5684-4695-830f-a9846aad8ba9"^^xsd:anyURI .
#
# SoloMusicArtist:Lou_Reed  a                           bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Lou Reed" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lou_Reed.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9d1ebcfe-4c15-4d18-95d3-d919898638a1"^^xsd:anyURI .
#
# SoloMusicArtist:Chuck_E_Weiss  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Chuck E. Weiss" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chuck_E._Weiss.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/afd7c687-be28-44c2-a003-3fe698fa88eb"^^xsd:anyURI .
#
# SoloMusicArtist:Pete_Townshend  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Pete Townshend" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pete_Townshend.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fb147b8f-0144-4418-acaa-90b2d9779840"^^xsd:anyURI .
#
# SoloMusicArtist:Sting  a                              bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sting" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sting_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7944ed53-2a58-4035-9b93-140a71e41c34"^^xsd:anyURI .
#
# SoloMusicArtist:Archie_Shepp  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Archie Shepp" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Archie_Shepp.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5ceff60b-8183-49bf-a855-328d3c172106"^^xsd:anyURI .
#
# SoloMusicArtist:King_Tubby  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "King Tubby" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/King_Tubby.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/576134a6-9f1f-4bfa-af04-4848195849ca"^^xsd:anyURI .
#
# SoloMusicArtist:Arlo_Guthrie  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Arlo Guthrie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Arlo_Guthrie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b8efe8ac-45db-4a71-bb51-c1503986172f"^^xsd:anyURI .
#
# SoloMusicArtist:Miriam_Makeba  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Miriam Makeba" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Miriam_Makeba.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bc5c2918-4aba-4ef6-a245-100563a4487f"^^xsd:anyURI .
#
# SoloMusicArtist:Ernest_Ranglin  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Ernest Ranglin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ernest_Ranglin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/924203bb-da5f-4bd0-9630-c753c7cb9774"^^xsd:anyURI .
#
# SoloMusicArtist:Shona_Laing  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Shona Laing" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shona_Laing.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cbd6586b-fdd5-4939-a816-2c9cfff7e226"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Rice  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Rice" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Rice.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ca90a5b0-cb18-4f94-9c14-116826fcc422"^^xsd:anyURI .
#
# SoloMusicArtist:Stephen_Stills  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Stephen Stills" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stephen_Stills.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5642774a-72c0-4099-8da4-7c1ab36378a8"^^xsd:anyURI .
#
# SoloMusicArtist:Patti_Smith  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Patti Smith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patti_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d135874d-9cae-4fef-97e3-36acbd9f5a26"^^xsd:anyURI .
#
# SoloMusicArtist:Allen_Ginsberg  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Allen Ginsberg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Allen_Ginsberg.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8fc551bc-0c60-43fd-a234-2776561c2b18"^^xsd:anyURI .
#
# SoloMusicArtist:Bjork  a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Björk" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bj%C3%B6rk.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/87c5dedd-371d-4a53-9f7f-80522fb7f3cb"^^xsd:anyURI .
#
# SoloMusicArtist:Sherri_Jackson  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Sherri Jackson" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/82ae5d4c-79f4-414d-9980-f28b83c3daa0"^^xsd:anyURI .
#
# SoloMusicArtist:John_Hiatt  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Hiatt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Hiatt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e78202c9-7717-435c-9aac-dd5ebc4e64d5"^^xsd:anyURI .
#
# SoloMusicArtist:Seamus_Egan  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Séamus Egan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/S%C3%A9amus_Egan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c736201c-546d-469f-8475-4415db60aad0"^^xsd:anyURI .
#
# SoloMusicArtist:Jann_Arden  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jann Arden" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jann_Arden.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/31930c85-3e0e-488e-8407-46a0d73fa816"^^xsd:anyURI .
#
# SoloMusicArtist:Jim_McCaffrey  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Jim McCaffrey" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4b869707-6b46-4c93-b1b6-5dc22d0206ed"^^xsd:anyURI .
#
# SoloMusicArtist:Meredith_Brooks  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Meredith Brooks" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Meredith_Brooks.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6f033da5-396f-4381-a581-1f38c2d0a2d4"^^xsd:anyURI .
#
# SoloMusicArtist:David_Lindley  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "David Lindley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Lindley_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b3dcdff7-ddde-46bd-9527-684b8e8c0fc6"^^xsd:anyURI .
#
# SoloMusicArtist:Remmy_Ongala  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Remmy Ongala" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Remmy_Ongala.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f644d496-87f8-42d4-aeff-71c5708e8a01"^^xsd:anyURI .
#
# SoloMusicArtist:Judy_Henske  a                        bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Judy Henske" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Judy_Henske.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2cc6789c-48f2-4554-9b63-3112bfa5242c"^^xsd:anyURI .
#
# SoloMusicArtist:David_Sylvian  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "David Sylvian" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Sylvian.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/719db6b1-0d91-458c-8d18-875ec44105bf"^^xsd:anyURI .
#
# SoloMusicArtist:Richard_Cheese  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Richard Cheese & Lounge Against The Machine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Richard_Cheese.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/858db18f-1e09-4f0d-96d3-c15d28762c15"^^xsd:anyURI .
#
# SoloMusicArtist:Sally_Mack  a      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label  "Sally Mack" .
#
# SoloMusicArtist:Evan_Parker  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Evan Parker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Evan_Parker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8dba3cd5-5ed9-4472-8b38-c77ffc52b965"^^xsd:anyURI ;
#         skos:prefLabel                 "Evan Parker" .
#
# SoloMusicArtist:Muddy_Waters  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Muddy Waters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Muddy_Waters.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f86f1f07-d182-45ce-ae93-ef610880ca72"^^xsd:anyURI .
#
# SoloMusicArtist:Jerry_Garcia  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Jerry Garcia" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Garcia.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1ecff755-607d-4130-9a8a-8873f27e5de5"^^xsd:anyURI .
#
# SoloMusicArtist:Branford_Marsalis  a                  bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Branford Marsalis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Branford_Marsalis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd9cdeb8-5436-46a7-8e17-4ee900219246"^^xsd:anyURI .
#
# SoloMusicArtist:Rory_Gallagher  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Rory Gallagher" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rory_Gallagher.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/933fdeae-ec68-48e9-a752-8bcfd44bc429"^^xsd:anyURI .
#
# SoloMusicArtist:Emmylou_Harris  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Emmylou Harris" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Emmylou_Harris.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/35ef61ca-43db-4772-ba27-0489e9ebcb69"^^xsd:anyURI .
#
# SoloMusicArtist:Andrew_Bird  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Andrew Bird" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Andrew_Bird.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/081b133e-ce74-42ba-92c1-c18234acb532"^^xsd:anyURI .
#
# SoloMusicArtist:Abdullah_Ibrahim  a                   bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Abdullah Ibrahim" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Abdullah_Ibrahim.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd64e185-9973-44d5-ad09-5d5562804292"^^xsd:anyURI .
#
# SoloMusicArtist:John_Lee_Hooker  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Lee Hooker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Lee_Hooker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b0122194-c49a-46a1-ade7-84d1d76bd8e9"^^xsd:anyURI .
#
# SoloMusicArtist:Langston_Hughes  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Langston Hughes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Langston_Hughes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/43a86fa6-d6d4-4fa3-9b8e-575d10787b7a"^^xsd:anyURI .
#
# SoloMusicArtist:Vonda_Shepard  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Vonda Shepard" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Vonda_Shepard.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/31e82ae9-f414-4a68-a0bf-d2719368166d"^^xsd:anyURI .
#
# SoloMusicArtist:Lyle_Mays  a                          bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Lyle Mays" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lyle_Mays.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/210b51ef-bece-44c6-aa94-0ad7756dd538"^^xsd:anyURI .
#
# SoloMusicArtist:Exene_Cervenka  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Exene Cervenka" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Exene_Cervenka.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/33227388-b0fc-40d8-91d8-6140192c50fe"^^xsd:anyURI .
#
# SoloMusicArtist:Jonas_Fjeld  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jonas Fjeld" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jonas_Fjeld.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/412338c5-8096-45f1-8a99-a025d1a5e5c8"^^xsd:anyURI .
#
# SoloMusicArtist:Rosie_Ledet  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Rosie Ledet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rosie_Ledet.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4d83ff86-8bab-4bbf-a64f-45a7e63f4339"^^xsd:anyURI .
#
# SoloMusicArtist:Henry_Kaiser  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Henry Kaiser" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Henry_Kaiser_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3b4ce4be-55a1-44bb-abdc-bcc504f30ca1"^^xsd:anyURI .
#
# SoloMusicArtist:Hank_Jones  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Hank Jones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hank_Jones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/80d610fe-7771-4226-aa9b-950944791698"^^xsd:anyURI .
#
# SoloMusicArtist:Roy_Rogers  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Roy Rogers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Roy_Rogers_(guitarist).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/466d6ede-e12f-453e-ba84-3b850522f999"^^xsd:anyURI .
#
# SoloMusicArtist:Zakir_Hussain  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Zakir Hussain" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Zakir_Hussain_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a198b33b-a907-462d-a437-b6cc1b98b8f7"^^xsd:anyURI .
#
# SoloMusicArtist:Peter_Erskine  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Peter Erskine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peter_Erskine.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3086927c-e46f-4200-9c57-fb615ac8da2c"^^xsd:anyURI .
#
# SoloMusicArtist:Vance_Gilbert  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Vance Gilbert" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Vance_Gilbert.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6f320c25-5650-47dc-8d3c-7b8972f68ce2"^^xsd:anyURI .
#
# SoloMusicArtist:Harry_Chapin  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Harry Chapin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Harry_Chapin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ae4e3542-7838-4a6f-b753-08216be5a6bb"^^xsd:anyURI .
#
# SoloMusicArtist:Kerry_Getz  a                         bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Kerry Getz" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4bd03b73-63ae-472d-8aa0-047311e51630"^^xsd:anyURI .
#
# SoloMusicArtist:Merl_Saunders  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Merl Saunders" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Merl_Saunders.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7ae1ae9e-66f5-461f-8a16-1a394b400c14"^^xsd:anyURI .
#
# SoloMusicArtist:Joe_Jackson  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Joe Jackson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joe_Jackson_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/07f6d469-38f3-46da-9cfa-2f532422b84e"^^xsd:anyURI .
#
# SoloMusicArtist:Brent_Lewis  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Brent Lewis" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7183e4bd-1c95-4f0e-a479-51ae435f1aa7"^^xsd:anyURI .
#
# SoloMusicArtist:Kasey_Chambers  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Kasey Chambers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kasey_Chambers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7333182d-8933-4896-adaa-fe98e6b59bd7"^^xsd:anyURI .
#
# SoloMusicArtist:Ian_Anderson  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Ian Anderson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ian_Anderson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/12fffb1f-39af-4efe-9426-92e05bb651d1"^^xsd:anyURI .
#
# SoloMusicArtist:Mark_Whitfield  a                     bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Mark Whitfield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mark_Whitfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3911c174-873f-4b81-802a-d24df142a2bc"^^xsd:anyURI .
#
# SoloMusicArtist:Joe_Cocker  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Joe Cocker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joe_Cocker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/32f2d6bd-c22b-42cf-a7bc-0c4b48cd2bcb"^^xsd:anyURI .
#
# SoloMusicArtist:Geoff_Muldaur  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Geoff Muldaur" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Geoff_Muldaur.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3f49ffea-060c-419e-bc57-690cf23c2ac7"^^xsd:anyURI .
#
# SoloMusicArtist:Richard_Buckner  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Richard Buckner" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Richard_Buckner_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fec02932-60cd-46ee-a70c-05c07905ae77"^^xsd:anyURI .
#
# SoloMusicArtist:Dizzy_Gillespie  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Dizzy Gillespie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dizzy_Gillespie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9ba8ccb-505f-4e5c-b909-65998d0d35b5"^^xsd:anyURI .
#
# SoloMusicArtist:Sarah_Harmer  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sarah Harmer" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sarah_Harmer.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c1839df6-1f9d-4469-bbda-7779cc3da7de"^^xsd:anyURI .
#
# SoloMusicArtist:Linda_Ronstadt  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Linda Ronstadt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Linda_Ronstadt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/498f2581-be21-4eef-8756-fbb89d79b1c0"^^xsd:anyURI .
#
# SoloMusicArtist:Robert_Johnson  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Robert Johnson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robert_Johnson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8a8bbba6-72f7-4900-a306-c40b94f2631b"^^xsd:anyURI .
#
# SoloMusicArtist:Phoebe_Snow  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Phoebe Snow" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Phoebe_Snow.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d3986756-f1dd-4635-9510-2d116c0deddd"^^xsd:anyURI .
#
# SoloMusicArtist:Marc_Antoine  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Marc Antoine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Marc_Antoine_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e974b781-bfb9-43df-b1b6-565baf9768b0"^^xsd:anyURI .
#
# SoloMusicArtist:Dee_Dee_Bridgewater  a                bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dee Dee Bridgewater" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dee_Dee_Bridgewater.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/43826bcf-2c17-4bf5-92cf-671c184e215f"^^xsd:anyURI .
#
# SoloMusicArtist:Anna_Sofie_Van_Otter
#         a                              bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Anne Sofie von Otter" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Anna_Sofie_Van_Otter.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/da7c775b-ea4e-4e5f-a9a4-878574ca2c75"^^xsd:anyURI .
#
# SoloMusicArtist:Holladay_Cole  a   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label  "Holladay Cole" .
#
# SoloMusicArtist:Sainkho_Namtchylak  a                 bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Sainkho Namtchylak" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sainkho_Namtchylak.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b2b97779-e09d-4e76-a0c9-a4c80cf043fa"^^xsd:anyURI .
#
# SoloMusicArtist:Jack_Kerouac  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Jack Kerouac" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jack_Kerouac.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ccf81e74-b701-4277-a599-3e0942e70b53"^^xsd:anyURI .
#
# SoloMusicArtist:Beth_Nielsen_Chapman
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Beth Nielsen Chapman" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Beth_Nielsen_Chapman.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/10f55070-09fb-4ac8-b684-b70ca66b0055"^^xsd:anyURI .
#
# SoloMusicArtist:Eliza_Gilkyson  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Eliza Gilkyson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eliza_Gilkyson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c5a7534b-20a7-46cd-a0e2-dd16d41824da"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Brubeck  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Brubeck" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Brubeck.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/de0222a6-e1c4-403d-8b01-3f66d505061b"^^xsd:anyURI .
#
# SoloMusicArtist:Libby_Kirkpatrick  a                  bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Libby Kirkpatrick" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c93700af-95d7-4b5a-b751-3b0c1228b431"^^xsd:anyURI .
#
# SoloMusicArtist:Peter_Wolf  a                         bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Peter Wolf" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peter_Wolf.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/83701bad-b130-4c19-9783-59061ca79aa0"^^xsd:anyURI .
#
# SoloMusicArtist:Loreena_McKennitt  a                  bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Loreena McKennitt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Loreena_McKennitt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c1e5344e-1bff-4727-9417-a4f55e41b5ff"^^xsd:anyURI .
#
# SoloMusicArtist:June_Tabor  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "June Tabor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/June_Tabor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/55bd9053-241d-4ba5-b0b3-f9b792ab1c7d"^^xsd:anyURI .
#
# SoloMusicArtist:Bruce_Cockburn  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Bruce Cockburn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bruce_Cockburn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/254b70d3-4aec-4c64-ac95-b13a1dbb30cb"^^xsd:anyURI .
#
# SoloMusicArtist:Chante  a          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label  "Chanté" .
#
# SoloMusicArtist:Vernon_Reid  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Vernon Reid" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Vernon_Reid.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6b429638-0cb7-44b1-8b2c-691ee0e52ef7"^^xsd:anyURI .
#
# SoloMusicArtist:Linda_Perry  a                        bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Linda Perry" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Linda_Perry.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/26037b3e-064c-4e9d-9d88-ebcd35933272"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Occhipinti  a                 bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Occhipinti" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4a1fae59-f686-4fe0-b841-514f2661efba"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Alvin  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Alvin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Alvin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/306ebc54-d11c-4bf4-9f37-27adc37d00b4"^^xsd:anyURI .
#
# SoloMusicArtist:Charlie_Haden  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Charlie Haden" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Charlie_Haden.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1f0cdc02-c8d5-4228-8227-37ec0c289b48"^^xsd:anyURI .
#
# SoloMusicArtist:Mary_Karlzen  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Mary Karlzen" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fadcf674-09e0-44d7-b389-55cbcb7c074e"^^xsd:anyURI .
#
# SoloMusicArtist:Grover_Washington  a                  bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Grover Washington Jr." ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Grover_Washington_Jr..ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c60e178f-36f1-4169-9c03-84addbdbf104"^^xsd:anyURI .
#
# SoloMusicArtist:Django_Reinhardt  a                   bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Django Reinhardt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Django_Reinhardt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/650bf385-6f6d-4992-a3b9-779d144920a4"^^xsd:anyURI .
#
# SoloMusicArtist:Jess_Klein  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Jess Klein" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jess_Klein.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0e456258-692e-4515-86f1-d1cc3212223a"^^xsd:anyURI .
#
# SoloMusicArtist:Nusrat_Fateh_Ali_Khan
#         a                              bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Nusrat Fateh Ali Khan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nusrat_Fateh_Ali_Khan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5968383c-11c1-4c5b-ada0-504a38cec8e7"^^xsd:anyURI .
#
# SoloMusicArtist:Martin_Simpson  a                     bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Martin Simpson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Martin_Simpson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e229170f-0340-44a9-a39f-f319c64bde75"^^xsd:anyURI .
#
# SoloMusicArtist:Nico   a                              bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Nico" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nico.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/37c61bf2-5fb1-47ae-9605-80025d956958"^^xsd:anyURI .
#
# SoloMusicArtist:Susan_Werner  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Susan Werner" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Susan_Werner.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2be59423-9cf7-4a92-b967-97c1222dfe22"^^xsd:anyURI .
#
# SoloMusicArtist:BB_King  a                            bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "B.B. King" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/B.B._King.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dcb03ce3-67a5-4eb3-b2d1-2a12d93a38f3"^^xsd:anyURI .
#
# SoloMusicArtist:Seu_Jorge  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Seu Jorge" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Seu_Jorge.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c73d651d-87c9-4c5e-8abb-4ec9c4077241"^^xsd:anyURI .
#
# SoloMusicArtist:Cosy_Sheridan  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Cosy Sheridan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cosy_Sheridan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c509f5c2-d712-474c-833b-747ab77e65e6"^^xsd:anyURI .
#
# SoloMusicArtist:Tess_Bradley  a    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label  "Tess Bradley" .
#
# SoloMusicArtist:Woody_Guthrie  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Woody Guthrie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Woody_Guthrie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cbd827e1-4e38-427e-a436-642683433732"^^xsd:anyURI .
#
# SoloMusicArtist:Michael_Franti  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Michael Franti" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Michael_Franti.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/650012e9-f732-4295-936d-fdd99bbc6258"^^xsd:anyURI .
#
# SoloMusicArtist:Alpha_Blondy  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Alpha Blondy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Alpha_Blondy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/88502cc3-20e7-4c5d-b583-ea84ed263db4"^^xsd:anyURI .
#
# SoloMusicArtist:Guy_Clark  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Guy Clark" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Guy_Clark.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e885f72e-4617-46de-9454-5485061f29b3"^^xsd:anyURI .
#
# SoloMusicArtist:Andreas_Vollenweider
#         a                              bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Andreas Vollenweider" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Andreas_Vollenweider.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6438bd71-ddc1-4619-a383-20d28ee55b43"^^xsd:anyURI .
#
# SoloMusicArtist:Alex_de_Grassi  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Alex de Grassi" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Alex_De_Grassi.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f940c4dd-f687-4c6a-872b-1cce3f78dc0a"^^xsd:anyURI .
#
# SoloMusicArtist:Kathy_Mattea  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Kathy Mattea" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kathy_Mattea.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f29443f1-5712-4be7-a926-1bde47a1d71d"^^xsd:anyURI .
#
# SoloMusicArtist:Wayne_Shorter  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Wayne Shorter" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wayne_Shorter.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2379937f-6e0d-46a2-b8ff-633fafd72002"^^xsd:anyURI .
#
# SoloMusicArtist:Lucky_Dube  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Lucky Dube" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lucky_Dube.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/97aeedc1-f252-4cfa-a8d8-c895c490532f"^^xsd:anyURI .
#
# SoloMusicArtist:Monica_Augustine  a  bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label  "Monica Augustine" .
#
# SoloMusicArtist:Tish_Hinojosa  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Tish Hinojosa" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tish_Hinojosa.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/59d624fd-13c0-43b3-a36c-1f3e1b1b5775"^^xsd:anyURI .
#
# SoloMusicArtist:Neil_Young  a                         bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Neil Young" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Neil_Young.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/75167b8b-44e4-407b-9d35-effe87b223cf"^^xsd:anyURI .
#
# SoloMusicArtist:James_Brown  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "James Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/James_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/20ff3303-4fe2-4a47-a1b6-291e26aa3438"^^xsd:anyURI .
#
# SoloMusicArtist:Tim_OBrien  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Tim O'Brien" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tim_O'Brien_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3bece26d-86b1-4534-a205-6e6182264eb6"^^xsd:anyURI .
#
# SoloMusicArtist:Tony_Levin  a                         bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Tony Levin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tony_Levin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1fd8a385-ab08-418e-afc1-cb85f8e96b3f"^^xsd:anyURI .
#
# SoloMusicArtist:Shawn_Phillips  a                     bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Shawn Phillips" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shawn_Phillips.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a8e1ce2e-8b10-4bc3-b212-fa3f21a1f053"^^xsd:anyURI .
#
# SoloMusicArtist:Lucy_Kaplansky  a                     bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Lucy Kaplansky" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lucy_Kaplansky.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9781630c-797b-4164-a539-e1e9ac16eae8"^^xsd:anyURI .
#
# SoloMusicArtist:Susie_Suh  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Susie Suh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Susie_Suh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f7a15fef-db6f-437e-8bd0-b1829c18acfc"^^xsd:anyURI .
#
# SoloMusicArtist:Shuggie_Otis  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Shuggie Otis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shuggie_Otis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ff9542ca-7859-4db2-8796-c1e3c39b9c0a"^^xsd:anyURI .
#
# SoloMusicArtist:Judy_Collins  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Judy Collins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Judy_Collins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/06f9c474-0547-40fc-be3d-1ae6ce38abd7"^^xsd:anyURI .
#
# SoloMusicArtist:Pio_Leyva  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Pío Leyva" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/P%C3%ADo_Leyva.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/962dd3f3-97cc-4ce3-8ada-ae2163f2aa63"^^xsd:anyURI .
#
# SoloMusicArtist:Ani_DiFranco  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Ani DiFranco" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ani_DiFranco.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a7bdc71f-697a-45d9-92b2-a01fbbe50272"^^xsd:anyURI .
#
# SoloMusicArtist:Jennifer_Berezan  a                   bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jennifer Berezan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jennifer_Berezan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ee23fe81-e9e0-43cb-9794-6e91a97d7b3d"^^xsd:anyURI .
#
# SoloMusicArtist:Stan_Getz  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Stan Getz" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stan_Getz.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8f2422ab-0ec6-4c92-80c4-afe9622fab32"^^xsd:anyURI .
#
# SoloMusicArtist:Lady_Bianca  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Lady Bianca" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lady_Bianca.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f61a533f-4420-44ee-952a-12daad1cd6ef"^^xsd:anyURI .
#
# SoloMusicArtist:Johnny_Copeland  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Johnny Copeland" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Johnny_Copeland.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dda28e24-42e8-4ef9-9f06-c12541cacbad"^^xsd:anyURI .
#
# SoloMusicArtist:Joan_Osborne  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Joan Osborne" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joan_Osborne.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/746916c9-fd36-44e6-823d-03185e596f58"^^xsd:anyURI .
#
# SoloMusicArtist:Jeff_Beck  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Jeff Beck" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jeff_Beck.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/14a4bc78-1c2d-4ca7-8d1b-9b58076a2a17"^^xsd:anyURI .
#
# SoloMusicArtist:Ashley_Hutchings  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ashley Hutchings" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ashley_Hutchings.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/41b79e6f-9621-45c9-836c-9f08bedba4eb"^^xsd:anyURI .
#
# SoloMusicArtist:Manu_Dibango  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Manu Dibango" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Manu_Dibango.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/826b488f-5164-45ca-abc4-ab11b3c321eb"^^xsd:anyURI .
#
# SoloMusicArtist:Grace  a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Grace" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/eb3b86cc-3970-487d-9ec5-f0003f2c44ee"^^xsd:anyURI .
#
# SoloMusicArtist:Kate_Jacobs  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kate Jacobs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kate_Jacobs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c87a1313-d1d5-46c1-9a46-81098cbcc451"^^xsd:anyURI .
#
# SoloMusicArtist:Billy_Taylor  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Billy Taylor" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Billy_Taylor.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/80855d0f-b173-432a-8882-178cdec7fd71"^^xsd:anyURI .
#
# SoloMusicArtist:Edith_Piaf  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Édith Piaf" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/%C3%89dith_Piaf.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f8ef4a3-40fa-46b5-8773-97686a8424f4"^^xsd:anyURI .
#
# SoloMusicArtist:Marianne_Faithfull  a                 bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Marianne Faithfull" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Marianne_Faithfull.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/14ed9dea-1bb0-4743-ba32-39674a71da89"^^xsd:anyURI .
#
# SoloMusicArtist:Rosanne_Cash  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Rosanne Cash" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rosanne_Cash.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5ff6f6eb-31ad-4903-a3c3-4c9283fcde8b"^^xsd:anyURI .
#
# SoloMusicArtist:Barbara_Kessler  a                    bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Barbara Kessler" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Barbara_Kessler.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/626e6742-8e36-4f1e-aca7-88b64ea4dde6"^^xsd:anyURI .
#
# SoloMusicArtist:John_Prine  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "John Prine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_Prine.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e86492c1-0376-4df0-8042-8ba058c83960"^^xsd:anyURI .
#
# SoloMusicArtist:Neil_Finn  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Neil Finn" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Neil_Finn.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3b7c93ab-40a5-4745-ab6b-eaafed2308bb"^^xsd:anyURI .
#
# SoloMusicArtist:Dama   a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Dama" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/93a713e9-3a6d-4910-addf-04fc34da2395"^^xsd:anyURI .
#
# SoloMusicArtist:Sue_Foley  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sue Foley" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sue_Foley.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7699f64f-9a90-4291-902e-afeeed3e138f"^^xsd:anyURI .
#
# SoloMusicArtist:Al_Kooper  a                          bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Al Kooper" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Al_Kooper.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d6bee229-1957-4891-8d44-c56ac7ea259e"^^xsd:anyURI .
#
# SoloMusicArtist:Larry_Carlton  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Larry Carlton" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Larry_Carlton.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f1f81989-dfa9-4bd3-805e-dcf3900c43e3"^^xsd:anyURI .
#
# SoloMusicArtist:Stevie_Ray_Vaughan  a                 bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Stevie Ray Vaughan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stevie_Ray_Vaughan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f5426431-f490-4678-ad44-a75c71097bb4"^^xsd:anyURI .
#
# SoloMusicArtist:Joao_Gilberto  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "João Gilberto" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jo%C3%A3o_Gilberto.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/286ec4c2-b5ca-4f85-b331-280a6d73dd14"^^xsd:anyURI .
#
# SoloMusicArtist:Catie_Curtis  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Catie Curtis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Catie_Curtis.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/85028af2-b99b-3590-bd6b-499dec9ef8d0"^^xsd:anyURI .
#
# SoloMusicArtist:Eric_Clapton  a                       bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Eric Clapton" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eric_Clapton.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/618b6900-0618-4f1e-b835-bccb17f84294"^^xsd:anyURI .
#
# SoloMusicArtist:Dolly_Parton  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Dolly Parton" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dolly_Parton.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1d543e07-d0d2-4834-a8db-d65c50c2a856"^^xsd:anyURI .
#
# SoloMusicArtist:Sheila_Chandra  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Sheila Chandra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sheila_Chandra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/115bdd7a-8a62-4564-9368-251879248e47"^^xsd:anyURI .
#
# SoloMusicArtist:Lee_Scratch_Perry  a                  bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Lee “Scratch” Perry" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lee_%22Scratch%22_Perry.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/af75ebe4-3ab1-423d-a499-2a6f9d011ce2"^^xsd:anyURI .
#
# SoloMusicArtist:Dave_Mason  a                         bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Dave Mason" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dave_Mason.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d70c2ae1-911a-4bea-8ef4-63564a150ff2"^^xsd:anyURI .
#
# SoloMusicArtist:Daniel_Lanois  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Daniel Lanois" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Daniel_Lanois.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ca0489a4-3a7b-4def-b66e-e00b2f579ae0"^^xsd:anyURI .
#
# SoloMusicArtist:Bill_Laswell  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Bill Laswell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bill_Laswell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8b7a121c-5b50-4912-ab4c-e49a631a2db0"^^xsd:anyURI .
#
# SoloMusicArtist:Jesse_Colin_Young  a                  bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Jesse Colin Young" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jesse_Colin_Young.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d4519848-9e39-4544-b13c-10872fb974a0"^^xsd:anyURI .
#
# SoloMusicArtist:Claire_Martin  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Claire Martin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Claire_Martin_(singer).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/196f31fc-95a7-4fb3-8a00-33c0eae1f73d"^^xsd:anyURI .
#
# SoloMusicArtist:John_Hammond  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "John Hammond" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/John_P._Hammond.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d83e599c-2d5a-44ec-b727-587e1455b1b5"^^xsd:anyURI .
#
# SoloMusicArtist:Norah_Jones  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Norah Jones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Norah_Jones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/985c709c-7771-4de3-9024-7bda29ebe3f9"^^xsd:anyURI .
#
# SoloMusicArtist:Badi_Assad  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Badi Assad" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Badi_Assad.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/572813ae-736f-47c9-9755-0ec0a550ddd5"^^xsd:anyURI .
#
# SoloMusicArtist:Roger_Waters  a                       bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Roger Waters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Roger_Waters.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0f50beab-d77d-4f0f-ac26-0b87d3e9b11b"^^xsd:anyURI .
#
# SoloMusicArtist:Nina_Simone  a                        bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Nina Simone" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nina_Simone.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2944824d-4c26-476f-a981-be849081942f"^^xsd:anyURI .
#
# SoloMusicArtist:Colin_Hay  a                          bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Colin Hay" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Colin_Hay.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/864d7069-57dc-45f6-b408-875b35106dd3"^^xsd:anyURI .
#
# SoloMusicArtist:Ruben_Gonzalez  a                     bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Rubén González" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rub%C3%A9n_Gonz%C3%A1lez.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6aa6ed34-4d69-49a4-9ba2-d3bc45b80b8a"^^xsd:anyURI .
#
# SoloMusicArtist:Martha_Schyuler_Thompson
#         a           bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label  "Martha Schyuler Thompson" .
#
# SoloMusicArtist:Ry_Cooder  a                          bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Ry Cooder" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ry_Cooder.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a4e2650b-938b-4b72-95bc-6e229cd34601"^^xsd:anyURI .
#
# SoloMusicArtist:Kelly_Joe_Phelps  a                   bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Kelly Joe Phelps" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kelly_Joe_Phelps.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fb1a017d-697d-48e6-8884-3ab3b41709ab"^^xsd:anyURI .
#
# SoloMusicArtist:Charles_Brown  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Charles Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Charles_Brown_(musician).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dbc9229a-6fb7-43b1-9763-df1e87112a93f"^^xsd:anyURI .
#
# SoloMusicArtist:Beth_Quist  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Beth Quist" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Beth_Quist.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f30dd6d9-b615-4073-9bc1-43fce8bd1624"^^xsd:anyURI .
#
# SoloMusicArtist:Peter_Gabriel  a                      bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Peter Gabriel" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peter_Gabriel.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8e66ea2b-b57b-47d9-8df0-df4630aeb8e5"^^xsd:anyURI .
#
# SoloMusicArtist:Suzanne_Vega  a                       bibliographica:AlphaClassUV , mo:SoloMusicArtist ;
#         rdfs:label                     "Suzanne Vega" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Suzanne_Vega.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf119120-7df5-47d7-9dec-49f8837a4e40"^^xsd:anyURI .
#
# SoloMusicArtist:Freddie_Hubbard  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Freddie Hubbard" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Freddie_Hubbard.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/59ae7a1a-f454-435b-8a5a-e327e692bb5a"^^xsd:anyURI .
#
# SoloMusicArtist:Randy_Crawford  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Randy Crawford" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Randy_Crawford.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/614e392a-0d63-48a2-bbd5-03265c407bd1"^^xsd:anyURI .
#
# SoloMusicArtist:Kevyn_Lettau  a                       bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Kevyn Lettau" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kevyn_Lettau.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/68057aab-5f54-4a2f-ab9a-af0cbcbb09b9"^^xsd:anyURI .
#
# SoloMusicArtist:Toumani_Diabate  a                    bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Toumani Diabaté" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Toumani_Diabat%C3%A9.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b96ba7e7-d882-409a-9825-ed3d6dbb437d"^^xsd:anyURI .
#
# SoloMusicArtist:Kate_Rusby  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Kate Rusby" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kate_Rusby.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62b86b55-e0aa-446f-b326-054576968310"^^xsd:anyURI .
#
# SoloMusicArtist:Sophie_B_Hawkins  a                   bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Sophie B. Hawkins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sophie_B._Hawkins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fd7a8bc1-1b25-4b4c-b899-8f7b3343a229"^^xsd:anyURI .
#
# SoloMusicArtist:Otis_Rush  a                          bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Otis Rush" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Otis_Rush.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/40ee7c92-f44a-4d14-9aee-f87244465ee4"^^xsd:anyURI .
#
# SoloMusicArtist:Joni_Mitchell  a                      bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Joni Mitchell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Joni_Mitchell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a6de8ef9-b1a1-4756-97aa-481bbb8a4069"^^xsd:anyURI .
#
# SoloMusicArtist:Angelique_Kidjo  a                    bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Angélique Kidjo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Angélique_Kidjo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/80fe34d0-6b4f-4ccd-81c3-281ab37f0451"^^xsd:anyURI .
#
# SoloMusicArtist:Desree  a                             bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Des'ree" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Des%27ree.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/250504d4-eca1-4b23-bea6-db1dc7d2eaf9"^^xsd:anyURI .
#
# SoloMusicArtist:Maceo_Parker  a                       bibliographica:AlphaClassMP , mo:SoloMusicArtist ;
#         rdfs:label                     "Maceo Parker" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Maceo_Parker.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7ec0b91d-c6ad-417e-934c-decfdc45bada"^^xsd:anyURI .
#
# SoloMusicArtist:Marc_Ribot  a                         bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Marc Ribot" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Marc_Ribot.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e6071b18-261e-46a1-8ee6-4dbd7f5f99f3"^^xsd:anyURI .
#
# SoloMusicArtist:Howard_Wales  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Howard Wales" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Howard_Wales.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3638179c-efe8-449e-858a-e1e6f394b9fe"^^xsd:anyURI .
#
# SoloMusicArtist:Barry_White  a                        bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Barry White" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Barry_White.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b904d624-9e05-4398-8f4f-88fbcf022f79"^^xsd:anyURI .
#
# SoloMusicArtist:Nick_Drake  a                         bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Nick Drake" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nick_Drake.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/99ea432a-e3d8-42cb-9d5e-db316a6a8458"^^xsd:anyURI .
#
# SoloMusicArtist:Coleman_Hawkins  a                    bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Coleman Hawkins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Coleman_Hawkins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5c8cb181-38fe-4300-8153-650b2ed0258f"^^xsd:anyURI .
#
# SoloMusicArtist:Stevie_Wonder  a                      bibliographica:AlphaClassWZ , mo:SoloMusicArtist ;
#         rdfs:label                     "Stevie Wonder" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Stevie_Wonder.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1ee18fb3-18a6-4c7f-8ba0-bc41cdd0462e"^^xsd:anyURI .
#
# SoloMusicArtist:Kate_Campbell  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Kate Campbell" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kate_Campbell.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ab923aac-b7e3-4eaa-a970-dcf898c95db2"^^xsd:anyURI .
#
# SoloMusicArtist:Clifford_Brown  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Clifford Brown" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Clifford_Brown.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2a291f34-73cb-40c5-b721-eab1269c7ba8"^^xsd:anyURI .
#
# SoloMusicArtist:Robert_Cray  a                        bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Robert Cray" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robert_Cray.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7112c4bc-5b15-4180-bfd5-2ca76745e87c"^^xsd:anyURI .
#
# SoloMusicArtist:David_Bromberg  a                     bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "David Bromberg" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Bromberg.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/00daff08-6cd1-4f91-b1ec-2f8ce8603442"^^xsd:anyURI .
#
# SoloMusicArtist:Lisa_Germano  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Lisa Germano" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lisa_Germano.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b4cadc83-7307-4196-9f2f-29ebf1650045"^^xsd:anyURI .
#
# SoloMusicArtist:Lyle_Lovett  a                        bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Lyle Lovett" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lyle_Lovett.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7241e3ed-5ad4-4849-94df-6858ea833472"^^xsd:anyURI .
#
# SoloMusicArtist:Sona_Jobarteh  a                      bibliographica:AlphaClassIL , mo:SoloMusicArtist ;
#         rdfs:label                     "Sona Jobarteh" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sona_Jobarteh.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7778142f-c11a-44a1-8917-7e8a5d2d72df"^^xsd:anyURI .
#
# SoloMusicArtist:Robert_Fripp  a                       bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Robert Fripp" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Robert_Fripp.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/898b645e-eed2-490a-8ce2-0e7a4d2d5bc8"^^xsd:anyURI .
#
# SoloMusicArtist:Solomon_Burke  a                      bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Solomon Burke" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Solomon_Burke.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d5c79890-36c5-4f1b-bed3-4468eee093f3"^^xsd:anyURI .
#
# SoloMusicArtist:Wes_Montgomery  a                     bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Wes Montgomery" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Wynton_Kelly.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/663f8232-8c46-4851-803f-a91d31593b14"^^xsd:anyURI .
#
# SoloMusicArtist:Ramblin_Jack_Elliott
#         a                              bibliographica:AlphaClassEH , mo:SoloMusicArtist ;
#         rdfs:label                     "Ramblin’ Jack Elliott" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ramblin'_Jack_Elliott.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/41ed6db5-7a87-4535-b9f1-67ce54598662"^^xsd:anyURI .
#
# SoloMusicArtist:Andy_Summers  a                       bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Andy Summers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Andy_Summers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7d81816f-200c-47d3-a71d-4421b3185d45"^^xsd:anyURI .
#
# SoloMusicArtist:Sonny_Rollins  a                      bibliographica:AlphaClassQT , mo:SoloMusicArtist ;
#         rdfs:label                     "Sonny Rollins" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sonny_Rollins.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3b47247e-5b57-49b6-a0ed-bad80243802a"^^xsd:anyURI .
#
# }

# %% [markdown]
# #### Music Groups

# %%
# %%sparql
#
# PREFIX authors: <http://www.connaissance.io/onto/biblio/authors#>
# PREFIX MusicGroup: <http://www.connaissance.io/onto/biblio/MusicGroup#>
# PREFIX SoloMusicArtist: <http://www.connaissance.io/onto/biblio/SoloMusicArtist#>
# PREFIX bibliographica: <http://www.connaissance.io/onto/biblio/bibliographica#>
# PREFIX books: <http://www.connaissance.io/onto/biblio/books#>
# PREFIX boots: <http://www.connaissance.io/onto/biblio/boots#>
# PREFIX ebooks: <http://www.connaissance.io/onto/biblio/ebooks#>
# PREFIX video: <http://www.connaissance.io/onto/biblio/video#>
# PREFIX CDs: <http://www.connaissance.io/onto/biblio/CDs#>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX dctype: <http://purl.org/dc/dcmitype/>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
# PREFIX schema: <http://schema.org/>
# PREFIX dcterms: <http://purl.org/dc/terms/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX mo: <http://purl.org/ontology/mo/>
# PREFIX owl: <http://www.w3.org/2002/07/owl#>
#
# INSERT DATA {
#
# <http://www.connaissance.io/onto/biblio/MusicGroup>
#   rdf:type dctype:Dataset ;
#   dcterms:modified "2022-10-20" ;
#   dcterms:description "Music groups, cataloged and serialized in RDF. Links to DBpedia and Musibrainz." ;
#   owl:imports <http://www.connaissance.io/onto/biblio/SoloMusicArtist> ;
#   owl:imports <http://www.connaissance.io/onto/biblio/bibliographica> ;
#   owl:versionInfo "Developed by M Lane" .
#
#
# MusicGroup:Tuck_Patti  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tuck & Patti" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tuck_&_Patti.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7ed8ab11-74e7-4ecc-beaf-73feb3ab6c44"^^xsd:anyURI .
#
# MusicGroup:Left_Wing_Fascists  a                 bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Left Wing Fascists" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1fc55b7b-dec1-480f-8599-5c1ac8313c06"^^xsd:anyURI .
#
# MusicGroup:Massacre  a                           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Massacre" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Massacre_(experimental_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4b71450d-9889-4175-a391-16b9b2f63408"^^xsd:anyURI .
#
# MusicGroup:Tom_Tom_Club  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tom Tom Club" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tom_Tom_Club.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3dc66525-d359-406d-9cdf-cdd3a7de289c"^^xsd:anyURI .
#
# MusicGroup:Sly_and_Robbie  a                     bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sly & Robbie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sly_and_Robbie.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6e14dc18-9313-4afa-9344-4b6c2bf80fca"^^xsd:anyURI .
#
# MusicGroup:Heart  a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Heart" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Heart_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bdbd48f5-abf3-4a4f-9a21-4551dbc3fde9"^^xsd:anyURI .
#
# MusicGroup:Jefferson_Airplane  a                 bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Jefferson Airplane" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jefferson_Airplane.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/39c2a93d-9afa-4a22-9bba-c087ab056e1c"^^xsd:anyURI .
#
# MusicGroup:Zephyr  a                             bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Zephyr" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Zephyr_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ad360657-17ec-4ab1-a144-3d19101e404c"^^xsd:anyURI .
#
# MusicGroup:The_Chieftains  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Chieftains" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Chieftains.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fce5eb9a-95a7-4a54-b9e4-fe1b036fbe57"^^xsd:anyURI .
#
# MusicGroup:Allman_Brothers  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Allman Brothers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Allman_Brothers_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/72359492-22be-4ed9-aaa0-efa434fb2b01"^^xsd:anyURI .
#
# MusicGroup:League_Crafty_Guitarists
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "League of Crafty Guitarists" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Guitar_Craft.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6ee2f839-a523-41b4-aa5a-a6dafcf4a9b9"^^xsd:anyURI .
#
# MusicGroup:Police  a                             bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Police" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Police.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9e0e2b01-41db-4008-bd8b-988977d6019a"^^xsd:anyURI .
#
# MusicGroup:Energisers  a                         bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Energisers" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf5bb96f-019d-41e1-bb1d-14525c744cf1"^^xsd:anyURI .
#
# MusicGroup:Master_Drummers_Dagbon
#         a           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "Master Drummers Of Dagbon" .
#
# MusicGroup:Altan  a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Altan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Altan_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e6211cf7-272f-4431-bbd3-40c081b992d4"^^xsd:anyURI .
#
# MusicGroup:Skanic  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Skavoovie & The Epitones" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/56cb417b-31c4-40ce-aa78-00b159c3c164"^^xsd:anyURI .
#
# MusicGroup:Vika_Linda  a                         bibliographica:AlphaClassUV , mo:MusicGroup ;
#         rdfs:label                     "Vika and Linda" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Vika_and_Linda.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fe70ae16-d1a9-4250-8dff-5cbda7274ac8"^^xsd:anyURI .
#
# MusicGroup:Never_the_Bride  a                    bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Never the Bride" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Never_the_Bride.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6ff4d2a6-7731-4265-ae97-9ed72cdc07c0"^^xsd:anyURI .
#
# MusicGroup:Lounge_Lizards  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Lounge Lizards" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Lounge_Lizards.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3ccbb0c7-6c37-4bc0-8dd7-c970f8d462be"^^xsd:anyURI .
#
# MusicGroup:Zuba   a                              bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Zuba" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/aac42e0e-028d-4865-beea-b751a105e459"^^xsd:anyURI .
#
# MusicGroup:Nirvana  a                            bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Nirvana" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nirvana_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5b11f4ce-a62d-471e-81fc-a69a8278c7da"^^xsd:anyURI .
#
# MusicGroup:Hot_Rize  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hot Rize" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hot_Rize.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ce76c736-07db-4503-b771-0ee2c981a144"^^xsd:anyURI .
#
# MusicGroup:Rusted_Root  a                        bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rusted Root" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rusted_Root.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/eec37ec3-79f5-4158-bed8-370ccb4aa295"^^xsd:anyURI .
#
# MusicGroup:The_Who  a                            bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "The Who" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Who.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9fdaa16b-a6c4-4831-b87c-bc9ca8ce7eaa"^^xsd:anyURI .
#
# MusicGroup:Elvis_Costello_Attractions
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Elvis Costello & the Attractions" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Elvis_Costello.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0ffb6573-a98e-412e-aa01-0a580e9d8b06"^^xsd:anyURI .
#
# MusicGroup:Leftover_Salmon  a                    bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Leftover Salmon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Leftover_Salmon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3020be1d-3c41-4e42-911b-ca5e96489300"^^xsd:anyURI .
#
# MusicGroup:Pickin_on_Project  a                  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Pickin' on Project" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a2e48b1e-62a3-470e-bddc-2fe167148e0b"^^xsd:anyURI .
#
# MusicGroup:Bela_Fleck_and_the_Flecktones
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Béla Fleck and the Flecktones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Béla_Fleck_and_the_Flecktones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/830dce6f-c9ff-4ebe-944b-2ea2ab22fcdf"^^xsd:anyURI .
#
# MusicGroup:Blind_Boys_of_Alabama
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Blind Boys of Alabama" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Blind_Boys_of_Alabama.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2f76bd85-ba19-4d80-9bb7-4555abe463c5"^^xsd:anyURI .
#
# MusicGroup:Phil_Woods_Quintet  a                 bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Phil Woods Quintet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Phil_Woods.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/70c897ed-1c74-4ad1-a61c-f127d3a6d8df"^^xsd:anyURI .
#
# MusicGroup:Black_Sabbath  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Black Sabbath" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Black_Sabbath.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5182c1d9-c7d2-4dad-afa0-ccfeada921a8"^^xsd:anyURI .
#
# MusicGroup:Bug_Toast  a       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Bug Toast" .
#
# MusicGroup:Zulu_Jive_Umbaqanga  a  bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label  "Zulu Jive Umbaqanga" .
#
# MusicGroup:Jerry_Garcia_Band  a                  bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Jerry Garcia Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jerry_Garcia_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3f7a73e5-cb7f-4488-bd7e-f5e26c87fe1b"^^xsd:anyURI .
#
# MusicGroup:Pentangle  a                          bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Pentangle" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pentangle_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a4e31e59-e662-4cf4-bd4f-d7bf712bc21f"^^xsd:anyURI .
#
# MusicGroup:Genesis  a                            bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Genesis" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Genesis_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8e3fcd7d-bda1-4ca0-b987-b8528d2ee74e"^^xsd:anyURI .
#
# MusicGroup:Fleetwood_Mac  a                      bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Fleetwood Mac" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Fleetwood_Mac.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bd13909f-1c29-4c27-a874-d4aaf27c5b1a"^^xsd:anyURI .
#
# MusicGroup:Jam    a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Jam" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Jam.'s.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/23228f18-01d5-493e-94ce-cfcde82a8db2"^^xsd:anyURI .
#
# MusicGroup:Turtles_in_the_Wave  a  bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Turtles in the Wave" .
#
# MusicGroup:Dire_Straits  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dire Straits" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dire_Straits.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/614e3804-7d34-41ba-857f-811bad7c2b7a"^^xsd:anyURI .
#
# MusicGroup:Silos  a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Silos" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Silos.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cb987607-f778-4bed-9a11-f68b19773b07"^^xsd:anyURI .
#
# MusicGroup:Modern_Lovers  a                      bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Modern Lovers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Modern_Lovers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/535f06f0-7ea2-41a4-a967-743b25558805"^^xsd:anyURI .
#
# MusicGroup:U2     a                              bibliographica:AlphaClassUV , mo:MusicGroup ;
#         rdfs:label                     "U2" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/U2.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a3cb23fc-acd3-4ce0-8f36-1e5aa6a18432"^^xsd:anyURI .
#
# MusicGroup:Lincoln_Center_Jazz_Orchestra
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Lincoln Center Jazz Orchestra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jazz_at_Lincoln_Center_Orchestra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6e420511-4beb-4205-8b66-74a29ed87e4a"^^xsd:anyURI .
#
# MusicGroup:Austin_Lounge_Lizards
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Austin Lounge Lizards" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Austin_Lounge_Lizards.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1ddec30d-dba7-4421-a8b0-14ea8f09d050"^^xsd:anyURI .
#
# MusicGroup:Swamp_Mama_Johnson  a                 bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Swamp Mama Johnson" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5f77b66a-8b38-4409-8057-b9281c9c0e45"^^xsd:anyURI .
#
# MusicGroup:Eurythmics  a                         bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Eurythmics" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eurythmics.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b4d32cff-f19e-455f-86c4-f347d824ca61"^^xsd:anyURI .
#
# MusicGroup:Four_Non_Blondes  a                   bibliographica:AlphaClassNUM , bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "4 Non Blondes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/4_Non_Blondes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/efef848b-63e4-4323-8ef7-69a48fbdd51d"^^xsd:anyURI .
#
# MusicGroup:Adventures_in_Afropea
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Adventures in Afropea 3 (various artists)" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release-group/30c783af-55d2-34e4-bed2-636583990975"^^xsd:anyURI .
#
# MusicGroup:Gaelic_Storm  a                       bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Gaelic Storm" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gaelic_Storm.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/abcd1648-fb93-4d4b-a073-dd61e4006b8b"^^xsd:anyURI .
#
# MusicGroup:Shakti  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Shakti" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shakti_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1eb30e7e-e374-4de7-8d13-ae5855ae6df8"^^xsd:anyURI .
#
# MusicGroup:DGary_Jihe  a                         bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "D'Gary & Jihé" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/466cb25b-af31-4abd-a61a-a2a8db7cb252"^^xsd:anyURI .
#
# MusicGroup:Sixteen_Horsepower  a                 bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sixteen Horsepower" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/16_Horsepower.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9a22fc7b-ad7f-4c70-9e0f-4d40cd7562cd"^^xsd:anyURI .
#
# MusicGroup:King_Crimson  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "King Crimson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/King_Crimson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b38225b8-8e5f-42aa-bcdc-7bae5b5bdab3"^^xsd:anyURI .
#
# MusicGroup:Ten_Thousand_Maniacs
#         a                              bibliographica:AlphaClassQT , bibliographica:AlphaClassNUM , mo:MusicGroup ;
#         rdfs:label                     "10,000 Maniacs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/10,000_Maniacs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b9a06530-1241-4162-836f-7b8e79deaa58"^^xsd:anyURI .
#
# MusicGroup:Third_World  a                        bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Third World" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Third_World_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a9355030-319f-4d1b-8798-adaf43f85112"^^xsd:anyURI .
#
# MusicGroup:Flying_Burrito_Brothers
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Flying Burrito Brothers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Flying_Burrito_Brothers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b4375768-3c8b-46e7-b578-c920ccfe725f"^^xsd:anyURI .
#
# MusicGroup:Silly_Sisters  a                      bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Silly Sisters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Silly_Sisters_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ba256d10-3ef9-4393-a9b3-6ac14e4342eb"^^xsd:anyURI .
#
# MusicGroup:UB40   a                              bibliographica:AlphaClassUV , mo:MusicGroup ;
#         rdfs:label                     "UB40" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/UB40.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7113aab7-628f-4050-ae49-dbecac110ca8"^^xsd:anyURI .
#
# MusicGroup:Strength_in_Numbers  a                bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Strength in Numbers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Strength_in_Numbers_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5517ae1b-4a80-4f2b-804f-fd0e8a720ffc"^^xsd:anyURI .
#
# MusicGroup:Disappear_Fear  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Disappear Fear" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Disappear_Fear.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/be8d6886-0a2d-4312-a174-de192ee77eb2"^^xsd:anyURI .
#
# MusicGroup:Crusaders  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Crusaders" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Crusaders.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fcb79f1a-d3a9-41fe-9cd7-d16537907337"^^xsd:anyURI .
#
# MusicGroup:Paul_Butterfield_Blues_Band
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Paul Butterfield Blues Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paul_Butterfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/20dcf3aa-c313-4f24-acd4-461327a76a73"^^xsd:anyURI .
#
# MusicGroup:Quadrophonnes  a   bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Quadrophonnes" .
#
# MusicGroup:Waterson_Carthy  a                    bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Waterson:Carthy" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Waterson–Carthy.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5e4be767-e691-415a-8f99-17d2fcbc4ce3"^^xsd:anyURI .
#
# MusicGroup:Fishbone  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Fishbone" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Fishbone.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9f3764c0-c9f4-4e20-b7a8-9993124fb1b2"^^xsd:anyURI .
#
# MusicGroup:Rodrigo_y_Gabriela  a                 bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rodrigo y Gabriela" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rodrigo_y_Gabriela.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a8ed28e3-5c08-4448-b889-867483e251f5"^^xsd:anyURI .
#
# MusicGroup:Story  a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Story" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Story_(American_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ab923307-cd7e-4681-a80b-3054ae8a25ae"^^xsd:anyURI .
#
# MusicGroup:Dead_Kennedys  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dead Kennedys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dead_Kennedys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/37c78aeb-d196-42b5-b991-6afb4fc9bc2e"^^xsd:anyURI .
#
# MusicGroup:Specials  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Specials" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Specials.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/07eb40a2-2914-439c-a01d-15a685b84ddf"^^xsd:anyURI .
#
# MusicGroup:Montreux  a                           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Montreux" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Montreux_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1ecf6231-4914-4d71-8ed0-954122c55f60"^^xsd:anyURI .
#
# MusicGroup:Bombay_Black  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Bombay Black" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/33ca9026-808c-4c33-be66-fe30add254f1"^^xsd:anyURI .
#
# MusicGroup:Barrel_of_Blues  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Barrel of Blues" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8da727cf-737b-4ce1-b29d-7f68225a4d10"^^xsd:anyURI .
#
# MusicGroup:Subdudes  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Subdudes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Subdudes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f3cded29-c81d-4d17-8d19-fcfa4058fc28"^^xsd:anyURI .
#
# MusicGroup:Windham_Hill  a                       bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Windham Hill" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Windham_Hill.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/94d3d1b5-1249-4673-ac64-f6d13ebffc2f"^^xsd:anyURI .
#
# MusicGroup:The_Assassins  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Assassins" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b23d849c-c10f-4570-afcf-c17b0fc17531"^^xsd:anyURI .
#
# MusicGroup:Chris_Maggie  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Chris & Maggie" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/091d7dec-1496-402c-8a6b-8058fd0afe3e"^^xsd:anyURI .
#
# MusicGroup:Crazy_Horse  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Crazy Horse" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Crazy_Horse_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/71f754c0-f2d1-4a54-8d70-cc0ee409ca00"^^xsd:anyURI .
#
# MusicGroup:Red_Knuckles  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:comment                   "Pseudonym/side project for the group Hot Rize." ;
#         rdfs:label                     "Red Knuckles and the Trailblazers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hot_Rize.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/97240950-0968-4d30-8358-8d233be84d5d"^^xsd:anyURI ;
#         owl:sameAs                     :Hot_Rize .
#
# MusicGroup:Oysterband  a                         bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Oysterband" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Oysterband.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c4be8a78-d4a8-4515-9759-5aa61162b197"^^xsd:anyURI .
#
# MusicGroup:Lowen_Navarro  a                      bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Lowen & Navarro" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lowen_%26_Navarro.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ac05b35d-2cae-4765-832f-77cd52e8c17c"^^xsd:anyURI .
#
# MusicGroup:The_Books  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Books" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Books.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1270af14-9c17-4400-8ebb-3f0ac40dcfb0"^^xsd:anyURI .
#
# MusicGroup:Turtle_Island_Quartet
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Turtle Island String Quartet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Turtle_Island_Quartet.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7a8844e0-df25-4dd1-a74f-b96775d8523b"^^xsd:anyURI .
#
# MusicGroup:Zap_Mama  a                           bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Zap Mama" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Zap_Mama.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/50c0ec9a-a2a3-4888-a8b0-a0cf565e5ac7"^^xsd:anyURI .
#
# MusicGroup:Jesse_Sykes_Sweet_Hereafter
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Jesse Sykes & The Sweet Hereafter" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jesse_Sykes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/254b5419-1819-49c9-abcf-6e9b8210ebf4"^^xsd:anyURI .
#
# MusicGroup:Four_Bitchin_Babes  a                 bibliographica:AlphaClassNUM , bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Four Bitchin' Babes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Four_Bitchin'_Babes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c4990d62-84f0-468b-9283-e248de37ced7"^^xsd:anyURI .
#
# MusicGroup:Easy_Star_All_Stars  a                bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Easy Star All‐Stars" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Easy_Star_All-Stars.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0cee95e3-a61d-4cd1-a39c-75464a05b606"^^xsd:anyURI .
#
# MusicGroup:Ketama  a                             bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Ketama" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ketama.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7fe8e911-d706-44d9-b633-702065f8fd6c"^^xsd:anyURI .
#
# MusicGroup:Patrick_Street  a                     bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Patrick Street" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Patrick_Street.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/622b1e36-4d4e-4744-80b3-056d4484a1ae"^^xsd:anyURI .
#
# MusicGroup:Alison_Krauss_Union_Station
#         a                              bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Alison Krauss & Union Station" ;
#         mo:supporting_musician         bibliographica:Alison_Krauss ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Union_Station_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b91c664b-5eee-4536-8b70-b1f2be519ac0"^^xsd:anyURI .
#
# MusicGroup:Incredible_String_Band
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Incredible String Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Incredible_String_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/04da193a-a956-4940-a6ca-e6021c7861c2"^^xsd:anyURI .
#
# MusicGroup:Velvet_Underground  a                 bibliographica:AlphaClassUV , mo:MusicGroup ;
#         rdfs:label                     "Velvet Underground" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Velvet_Underground.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/54aa91b4-7099-4461-8873-e6768226e61f"^^xsd:anyURI .
#
# MusicGroup:Art_Zoyd  a                           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Art Zoyd" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Art_Zoyd.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/aba325af-9e75-4db8-967f-eab02b1116d2"^^xsd:anyURI .
#
# MusicGroup:Mahavishnu_Orchestra
#         a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Mahavishnu Orchestra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mahavishnu_Orchestra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a2be74f5-0735-46f7-a295-7e41aab30029"^^xsd:anyURI .
#
# MusicGroup:Juluka  a                             bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Juluka" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Juluka.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/46868313-f4bd-40fd-81f6-b5d09b10c3fc"^^xsd:anyURI .
#
# MusicGroup:Diga_Rhythm_Band  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Diga Rhythm Band" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/74775f30-1183-4abf-939c-faee95f80490"^^xsd:anyURI .
#
# MusicGroup:League_of_Gentlemen  a                bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "League of Gentlemen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_League_of_Gentlemen_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e2cd9278-7bd1-4fbf-b507-e8c68c5fb21a"^^xsd:anyURI .
#
# MusicGroup:Laurel_Canyon_Ramblers
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Laurel Canyon Ramblers" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/844c9b91-dee4-4d83-bb68-fe488a745b23"^^xsd:anyURI .
#
# MusicGroup:Iron_Butterfly  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Iron Butterfly" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Iron_Butterfly.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3da3e7e1-e817-47e8-8624-635df4aedbe6"^^xsd:anyURI .
#
# MusicGroup:Son_Volt  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Son Volt" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Son_Volt.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ecbd1331-95b6-4a77-b739-b4bd8ef222a7"^^xsd:anyURI .
#
# MusicGroup:Second_Hand_Smokers  a  bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Second Hand Smokers" .
#
# MusicGroup:String_Cheese_Incident
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "String Cheese Incident" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_String_Cheese_Incident.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cff95140-6d57-498a-8834-10eb72865b29"^^xsd:anyURI .
#
# MusicGroup:Sun_Kil_Moon  a                       bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Sun Kil Moon" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sun_Kil_Moon.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ef2c6449-d02b-415b-ad8c-c14c08266552"^^xsd:anyURI .
#
# MusicGroup:Break_The_Chains  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Break The Chains" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ab512eb7-e39e-4a19-b7e6-a9e2b292867f"^^xsd:anyURI .
#
# MusicGroup:Wailers  a                            bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "The Wailers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Marley_and_the_Wailers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c9e99d40-4a2c-4ca7-ac5b-e842264ee271"^^xsd:anyURI .
#
# MusicGroup:Brian_Setzer_Orchestra
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Brian Setzer Orchestra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Brian_Setzer_Orchestra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3c98e32e-5bf5-4484-bdab-bd8d1736112a"^^xsd:anyURI .
#
# MusicGroup:Endangered_Species  a  bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label  "Endangered Species" .
#
# MusicGroup:Texas  a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Texas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Texas_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7289d10d-d8d2-41ff-8308-c56ec9346e07"^^xsd:anyURI .
#
# MusicGroup:Sly_Family_Stone  a                   bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sly & the Family Stone" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sly_and_the_Family_Stone.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b7ec4c54-1f93-4bf2-957f-7b9921ab84ea"^^xsd:anyURI .
#
# MusicGroup:Neville_Brothers  a                   bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Neville Brothers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Neville_Brothers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5464e20c-7dcb-4a3e-9b25-13bb959fadc9"^^xsd:anyURI .
#
# MusicGroup:Word   a           bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label  "Word" .
#
# MusicGroup:Moon_Seven_Times  a                   bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Moon Seven Times" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b42712b3-bdf5-4c6a-b082-87eb92ba82dd"^^xsd:anyURI .
#
# MusicGroup:New_Shining_Soul_Band
#         a           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "New Shining Soul Band" .
#
# MusicGroup:Janes_Addiction  a                    bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Jane's Addiction" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jane's_Addiction.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e3434cc7-d348-491a-9dc8-325af3d9086d"^^xsd:anyURI .
#
# MusicGroup:Salamander_Crossing  a                bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Salamander Crossing" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Salamander_Crossing.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/637a3c83-9b1c-44a1-b0af-85c2125d680f"^^xsd:anyURI .
#
# MusicGroup:Violent_Femmes  a                     bibliographica:AlphaClassUV , mo:MusicGroup ;
#         rdfs:label                     "Violent Femmes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Violent_Femmes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2aab61bc-67f4-4722-8c6e-e1821b2e32a6"^^xsd:anyURI .
#
# MusicGroup:Cradle_of_Thorns  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Concrete Blonde" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cradle_of_Thorns.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4c5a41a9-da4c-4710-927d-8f7a2fad1b67"^^xsd:anyURI .
#
# MusicGroup:Concrete_Blonde  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Concrete Blonde" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Concrete_Blonde.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/701fc524-b5f2-42f2-9db7-8198cdd6839c"^^xsd:anyURI .
#
# MusicGroup:Residents  a                          bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Residents" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Residents.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8c9b336e-acc8-4e20-9195-6ed0634da9fc"^^xsd:anyURI .
#
# MusicGroup:The_Doors  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Doors" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Doors.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9efff43b-3b29-4082-824e-bc82f646f93d"^^xsd:anyURI .
#
# MusicGroup:B_Fifty_Twos  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "B-52s" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_B-52's.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/127f591a-7e27-4435-92db-0780f219f3a1"^^xsd:anyURI .
#
# MusicGroup:Skavoovie  a                          bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Skavoovie & The Epitones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Skavoovie_and_the_Epitones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d0176597-caee-4e66-80a9-fc054ad4698c"^^xsd:anyURI .
#
# MusicGroup:The_Be_Good_Tanyas  a                 bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Be Good Tanyas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Be_Good_Tanyas.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bf52f343-a752-4633-8521-9e99eaad8f9f"^^xsd:anyURI .
#
# MusicGroup:Big_Audio_Dynamite  a                 bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Big Audio Dynamite" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Big_Audio_Dynamite.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/694b1fd8-0ba6-45bb-a359-d8a8fecaee46"^^xsd:anyURI .
#
# MusicGroup:Southern_Culture_Skids
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Southern Culture on the Skids" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Southern_Culture_on_the_Skids.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/90c88f94-8b70-49fd-9726-cadf4306ef42"^^xsd:anyURI .
#
# MusicGroup:Sex_Pistols  a                        bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sex Pistols" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sex_Pistols.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e5db18cb-4b1f-496d-a308-548b611090d3"^^xsd:anyURI .
#
# MusicGroup:Sonia_Dada  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sonia Dada" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sonia_Dada.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44f04c5e-63e1-4729-ba40-a471b7252259"^^xsd:anyURI .
#
# MusicGroup:Timbuk_3  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Timbuk 3" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Timbuk_3.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6de4e992-3f69-4616-8c08-74cff57b39b3"^^xsd:anyURI .
#
# MusicGroup:Spyro_Gyra  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Spyro Gyra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Spyro_Gyra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9a7c8025-1af8-42cd-8df8-857220610bc5"^^xsd:anyURI .
#
# MusicGroup:Camper_Van_Beethoven
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Camper Van Beethoven" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Camper_Van_Beethoven.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0ee7e64d-90ca-406b-b59a-3e551c556dbe"^^xsd:anyURI .
#
# MusicGroup:Dread_Zeppelin  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dread Zeppelin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dread_Zeppelin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/74e2c381-7a79-4c21-8738-20da383e14d2"^^xsd:anyURI .
#
# MusicGroup:Roches  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Roches" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Roches.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4ee9f5ed-5f20-41a7-b467-72c79549a67d"^^xsd:anyURI .
#
# MusicGroup:Buena_Vista_Social_Club
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Buena Vista Social Club" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buena_Vista_Social_Club.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2a85ecff-41e9-4be1-aca6-c87054a4c334"^^xsd:anyURI .
#
# MusicGroup:Stomu_Yamashta_Go  a                  bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Stomu Yamashta's Go" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/31559424-7e17-4670-bef2-5198148a4438"^^xsd:anyURI .
#
# MusicGroup:Grateful_Dead  a                      bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Grateful Dead" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Grateful_Dead.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6faa7ca7-0d99-4a5e-bfa6-1fd5037520c6"^^xsd:anyURI .
#
# MusicGroup:Radiators  a                          bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Radiators" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Radiators_(American_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4bd3fb40-1c6f-4056-a0ee-8427685586fc"^^xsd:anyURI .
#
# MusicGroup:Soul_Jazz  a                          bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Soul Jazz" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Soul_jazz.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44f04c5e-63e1-4729-ba40-a471b7252259"^^xsd:anyURI .
#
# MusicGroup:Steely_Dan  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Steely Dan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Steely_Dan.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e01c3376-15fa-40d7-b747-5f219bdefdd7"^^xsd:anyURI .
#
# MusicGroup:YoMiles  a                            bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Yo Miles!" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/013cabd3-3949-47ef-be6b-2491a61902fb"^^xsd:anyURI .
#
# MusicGroup:New_Grass_Revival  a                  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "New Grass Revival" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/New_Grass_Revival.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9b6f3084-7bd7-444a-b0a5-d2dc78c19284"^^xsd:anyURI .
#
# MusicGroup:Widespread_Panic  a                   bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Widespread Panic" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Widespread_Panic.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3797a6d0-7700-44bf-96fb-f44386bc9ab2"^^xsd:anyURI .
#
# MusicGroup:Blues_Traveler  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Blues Traveler" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Blues_Traveler.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6b28ecf0-94e6-48bb-aa2a-5ede325b675b"^^xsd:anyURI .
#
# MusicGroup:Brave_Combo  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Brave Combo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Brave_Combo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fdefbd57-abcd-435a-8b6c-d03cc4990efd"^^xsd:anyURI .
#
# MusicGroup:GrooveGrass_Boyz  a                   bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Groovegrass Boyz" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_GrooveGrass_Boyz.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/36c2f168-2ddd-487d-b51a-6e86ee92dfb8"^^xsd:anyURI .
#
# MusicGroup:The_Bears  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Bears" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Bears_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b5ebf9fb-43f5-407f-a49b-8355e5c5667b"^^xsd:anyURI .
#
# MusicGroup:Eyuphuro  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Eyuphuro" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eyuphuro.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6e2df5d6-6481-4e20-b89c-5eef9d3ad7f3"^^xsd:anyURI .
#
# MusicGroup:Lynyrd_Skynyrd  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Lynyrd Skynyrd" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lynyrd_Skynyrd.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c544ed4d-2390-4442-a83e-1ea2883b09c8"^^xsd:anyURI .
#
# MusicGroup:Traveling_Wilburys  a                 bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Traveling Wilburys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Traveling_Wilburys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4387b544-e4d0-4f18-b74e-d4a5ba1582ab"^^xsd:anyURI .
#
# MusicGroup:Strunz_Farah  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Strunz & Farah" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Strunz_%26_Farah.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/22c2636a-df4c-4b30-b2f4-3bc40ca47d8b"^^xsd:anyURI .
#
# MusicGroup:Captain_Beefheart_Magic_Band
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Captain Beefheart & His Magic Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/Captain_Beefheart.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8dcd04e4-7695-4d80-bae9-1d7d680a38ef"^^xsd:anyURI .
#
# MusicGroup:Murmurs  a                            bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Murmurs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Murmurs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c5db90c4-580d-4f33-b364-fbaa5a3a58b5"^^xsd:anyURI .
#
# MusicGroup:Weather_Report  a                     bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Weather Report" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Weather_Report.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0f9997bd-e079-429e-8ccd-9378c9b0c746"^^xsd:anyURI .
#
# MusicGroup:Wynton_Kelly_Trio  a                  bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "The Wynton Kelly Trio" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8218b061-2d51-4375-affd-2e272083d12a"^^xsd:anyURI .
#
# MusicGroup:White_Stripes  a                      bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "White Stripes" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_White_Stripes.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/11ae9fbb-f3d7-4a47-936f-4c0a04d3b3b5"^^xsd:anyURI .
#
# MusicGroup:Barenberg_Bush_Douglas_Meyer
#         a           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Barenberg Bush Douglas Meyer" .
#
# MusicGroup:Johnny_Clegg_Savuka  a                bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Johnny Clegg and Savuka" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Savuka.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/08e3c40b-dbec-49aa-96ff-e1ab37ae6aca"^^xsd:anyURI .
#
# MusicGroup:Assassins  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Assassins" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b23d849c-c10f-4570-afcf-c17b0fc17531"^^xsd:anyURI .
#
# MusicGroup:Arrested_Development
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Arrested Development" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Arrested_Development_(group).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d8b15d32-609e-44a6-bff1-65c4df53a9f1"^^xsd:anyURI .
#
# MusicGroup:Psychefunkapus  a                     bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Psychefunkapus" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Psychefunkapus.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b8edbfe9-9ab0-400f-b544-81ba7d57d2f1"^^xsd:anyURI .
#
# MusicGroup:The_Beach_Boys  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Beach Boys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Beach_Boys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ebfc1398-8d96-47e3-82c3-f782abcdb13d"^^xsd:anyURI .
#
# MusicGroup:The_Bothy_Band  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Bothy Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Bothy_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e286a02a-eeb2-4dce-b7bf-f05feebd52ae"^^xsd:anyURI .
#
# MusicGroup:Devo   a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Devo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Devo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d2db1078-c170-4e22-b261-14f3ad60a690"^^xsd:anyURI .
#
# MusicGroup:Buffalo_Springfield  a                bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Buffalo Springfield" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buffalo_Springfield.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/22dc19af-d085-4c9b-adfb-22ec256251f1"^^xsd:anyURI .
#
# MusicGroup:Acoustic_Allstars  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Acoustic Allstars" .
#
# MusicGroup:Clash  a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Clash" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Clash.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8f92558c-2baa-4758-8c38-615519e9deda"^^xsd:anyURI .
#
# MusicGroup:David_Johansen_Group
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The David Johansen Group" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Johansen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0568deac-6de9-41d3-9f7a-ad59bbcab9ce"^^xsd:anyURI .
#
# MusicGroup:Ike_Tina_Turner  a                    bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Ike & Tina Turner" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ike_&_Tina_Turner.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1c7b3786-b99a-40ab-81e4-f3056da19e13"^^xsd:anyURI .
#
# MusicGroup:Chick_Corea_Akoustic
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Chick Corea Akoustic Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Chick_Corea_Akoustic_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/81fe165e-2cfe-4c52-9bf0-1853647bf489"^^xsd:anyURI .
#
# MusicGroup:BeauSoleil  a                         bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "BeauSoleil" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/BeauSoleil.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/143d190c-11e8-4ecd-adf7-a68a3ccdaab1"^^xsd:anyURI .
#
# MusicGroup:The_Corrs  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Corrs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Corrs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/acf6c776-d0f6-4239-b5a2-a45a613ffa52"^^xsd:anyURI .
#
# MusicGroup:Elvis_Costello_Imposters
#         a                              bibliographica:AlphaClassAD , mo:SoloMusicArtist ;
#         rdfs:label                     "Elvis Costello & the Imposters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Elvis_Costello.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a3e6fa6e-32de-4152-ae38-81291597a10c"^^xsd:anyURI .
#
# MusicGroup:Little_Beirut  a   bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label  "Little Beirut" .
#
# MusicGroup:BeauJocque_ZydecoHiRollers
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Beau Jocque and the Zydeco Hi-Rollers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Beau_Jocque.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/56ae315b-787f-472c-ba15-56e9a8a8028c"^^xsd:anyURI .
#
# MusicGroup:Calexico  a                           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Calexico" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Calexico_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5e372a49-5672-4fb8-ba14-18c90780c4f9"^^xsd:anyURI .
#
# MusicGroup:Blind_Faith  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Blind Faith" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Blind_Faith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/53fa91ca-a2b9-463d-b78e-daca9894082a"^^xsd:anyURI .
#
# MusicGroup:Crossing_Jordan  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Crossing Jordan" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/11f99686-1096-4981-bbe3-2a2a5ee26827"^^xsd:anyURI .
#
# MusicGroup:X      a                              bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "X" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/X_(American_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ddd553d4-977e-416c-8f57-e4b72c0fc746"^^xsd:anyURI .
#
# MusicGroup:Three_Dog_Night  a                    bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Three Dog Night" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Three_Dog_Night.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1a48176d-1414-4a18-9792-50ba585d4d59"^^xsd:anyURI .
#
# MusicGroup:Poi_Dog_Pondering  a                  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Pogues" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Poi_Dog_Pondering.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b0b95c2e-a361-4a36-bd77-9dfb6ce41014"^^xsd:anyURI .
#
# MusicGroup:Mescaleros  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Mescaleros" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Mescaleros.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/39c1e474-647e-42ef-a157-fcfb30c2c2ff"^^xsd:anyURI .
#
# MusicGroup:The_Paul_deLay_Band  a                bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Paul deLay Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Paul_deLay.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fa0e3ef0-d0bd-4906-9ec2-e3b87e99c9c1"^^xsd:anyURI .
#
# MusicGroup:English_Beat  a                       bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The English Beat" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Beat_(British_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9727e632-c228-47f8-a7ae-398df94f00c7"^^xsd:anyURI .
#
# MusicGroup:Shivas  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Shivas" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/50bb2d85-7a6b-4457-b995-9c1074c17d52"^^xsd:anyURI .
#
# MusicGroup:Lone_Justice  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Lone Justice" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lone_Justice.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/778b34b7-736f-45d1-9486-2c9545ea6daa"^^xsd:anyURI .
#
# MusicGroup:War    a                              bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "War" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/War_(American_band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3e6bbdb8-66c8-439c-a3d9-87391ce88740"^^xsd:anyURI .
#
# MusicGroup:Ziggy_Marley_Melody_Makers
#         a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Ziggy Marley & The Melody Makers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ziggy_Marley_and_the_Melody_Makers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7b5239b1-07ff-41ce-834b-29fe98de9970"^^xsd:anyURI .
#
# MusicGroup:Ladysmith_Black_Mambazo
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Ladysmith Black Mambazo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ladysmith_Black_Mambazo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c1982570-8efb-4cf7-bb5b-c9c026c0e8f4"^^xsd:anyURI .
#
# MusicGroup:Mannheim_Steamroller
#         a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Mannheim Steamroller" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mannheim_Steamroller.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/922a18b1-0aba-4868-8f38-2aa4f324fe16"^^xsd:anyURI .
#
# MusicGroup:Signals  a         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Signals" .
#
# MusicGroup:Heath_Brothers  a                     bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Heath Brothers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Heath_Brothers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://beta.musicbrainz.org/artist/0357c427-d302-4d55-b726-6519505d4d10"^^xsd:anyURI .
#
# MusicGroup:Spinal_Tap  a                         bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Spinal Tap" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Spinal_Tap_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d0a0b3a2-ea58-4a7a-b18c-849d589bfac7"^^xsd:anyURI .
#
# MusicGroup:Gary_Burton_Quartet  a                bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Gary Burton Quartet" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/be7ffcaa-0185-456b-9aa8-1bfd52b57676"^^xsd:anyURI .
#
# MusicGroup:Crosby_Stills_Nash_Young
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Crosby, Stills, Nash & Young" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Crosby,_Stills,_Nash_&_Young.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/46a782ea-4308-476b-abd1-a91b197f3037"^^xsd:anyURI .
#
# MusicGroup:Ramones  a                            bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Ramones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ramones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d6ed7887-a401-47a8-893c-34b967444d26"^^xsd:anyURI .
#
# MusicGroup:Tarika  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tarika" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Tarika_(musical_group).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/26f6d5b4-137f-451d-aadc-74ae204dc5b3"^^xsd:anyURI .
#
# MusicGroup:Radiohead  a                          bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Radiohead" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Radiohead.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a74b1b7f-71a5-4011-9441-d0b5e4122711"^^xsd:anyURI .
#
# MusicGroup:Meters  a                             bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Meters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Meters.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/851827d6-ae31-4093-a166-1420cac610a4"^^xsd:anyURI ;
#         skos:altLabel                  "The Funky Meters" .
#
# MusicGroup:Bossa_Samba  a     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Bossa Samba" .
#
# MusicGroup:My_Sister_Kate  a  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "My Sister Kate" .
#
# MusicGroup:Seven_Year_Bitch  a                   bibliographica:AlphaClassQT , bibliographica:AlphaClassNUM , mo:MusicGroup ;
#         rdfs:label                     "7 Year Bitch" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/7_Year_Bitch.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/91d06612-5c1e-4278-b40b-b6ce22dc9bb4"^^xsd:anyURI .
#
# MusicGroup:Seldom_Scene  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Seldom Scene" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Seldom_Scene.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62014a59-8f3f-4f8a-80ed-5c2b794bde0d"^^xsd:anyURI .
#
# MusicGroup:Halibuts  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Halibuts" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8ab6877a-6783-4d71-b9dd-be630ef0ca8a"^^xsd:anyURI .
#
# MusicGroup:Cabaret_Diosa  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Cabaret Diosa" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6606cb77-02a6-4385-a38c-7d4944e1150c"^^xsd:anyURI .
#
# MusicGroup:Everything_but_the_Girl
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Everything but the Girl" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Everything_but_the_Girl.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/959cf5bf-ee29-4af6-a85a-0b480181d988"^^xsd:anyURI .
#
# MusicGroup:Heads  a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Heads" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/840645fa-d7ce-4ccb-8581-311efe6c2383"^^xsd:anyURI .
#
# MusicGroup:Artistas_Cubanos  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Artistas Cubanos" .
#
# MusicGroup:Bad_Livers  a                         bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Bad Livers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bad_Livers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/52136679-5be1-403a-ab23-a3a934646daa"^^xsd:anyURI .
#
# MusicGroup:Lavay_Smith_Skillet_Lickers
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Lavay Smith & Her Red Hot Skillet Lickers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Lavay_Smith.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cb8d5012-d384-4574-a0b4-59a3aedddf52"^^xsd:anyURI .
#
# MusicGroup:Crowded_House  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Crowded House" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Crowded_House.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9854d99f-d954-4c0f-9ae5-58a0cdd885f5"^^xsd:anyURI .
#
# MusicGroup:Mary_Lees_Corvette  a                 bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Mary Lee's Corvette" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mary_Lee's_Corvette.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c0ef3bec-1e2e-46b3-a826-7887349739f9"^^xsd:anyURI .
#
# MusicGroup:Rising_Sons  a                        bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rising Sons" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rising_Sons.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9005740-188b-4f57-bb02-a5cdafeb6a6f"^^xsd:anyURI .
#
# MusicGroup:Monkey_Siren  a                       bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Monkey Siren" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d1e6b55d-7660-4009-a7ca-5d69b7c772a1"^^xsd:anyURI .
#
# MusicGroup:Black_Flag  a                         bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Black Flag" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Black_Flag_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9941a936-196a-4a62-ae53-a69cbc33f20e"^^xsd:anyURI .
#
# MusicGroup:King_Missile  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "King Missile" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/King_Missile.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62881dc4-2776-4743-a938-79a7d865ea53"^^xsd:anyURI .
#
# MusicGroup:Creedence_Clearwater_Revival
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Creedence Clearwater Revival" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Creedence_Clearwater_Revival.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/109958eb-a335-4c5e-907e-597ff4c6af46"^^xsd:anyURI .
#
# MusicGroup:Amadou_and_Mariam  a                  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Amadou & Mariam" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Amadou_&_Mariam.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1fb60b6c-0f4d-42b4-8a5e-de705ec76660"^^xsd:anyURI .
#
# MusicGroup:Old_In_the_Way  a                     bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Old & In the Way" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Old_%26_In_the_Way.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e3a2d328-2dbb-45d7-b9b5-548c7804f04f"^^xsd:anyURI .
#
# MusicGroup:Tom_Scott_LA_Express
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tom Scott & the LA Express" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/62c1ad74-bb34-4651-a77e-a6607962ead3"^^xsd:anyURI .
#
# MusicGroup:Traffic  a                            bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Traffic" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Traffic_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9fadfba9-ecae-4383-a4d8-47b043cea19a"^^xsd:anyURI .
#
# MusicGroup:Sleater_Kinney  a                     bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sleater Kinney" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sleater-Kinney.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e36e78eb-3ace-4acd-882c-16789e700ab7"^^xsd:anyURI .
#
# MusicGroup:Dead_Ringer_Band  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dead Ringer Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dead_Ringer_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b3c45251-adb7-40bb-946f-b238703147bb"^^xsd:anyURI .
#
# MusicGroup:Latin_Playboys  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Latin Playboys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Latin_Playboys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f052725a-f7aa-4764-b5ec-0ff39619fa78"^^xsd:anyURI .
#
# MusicGroup:Skin   a           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Skin" .
#
# MusicGroup:The_Beat_Farmers  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Beat Farmers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Beat_Farmers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fa5d4d6f-bfca-4412-869e-def05b4974bb"^^xsd:anyURI .
#
# MusicGroup:Dr_Hook  a                            bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dr. Hook & the Medicine Show" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dr._Hook_&_the_Medicine_Show.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1c893468-37a9-4fb7-909f-929751a8ebed"^^xsd:anyURI .
#
# MusicGroup:Eagles  a                             bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Eagles" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Eagles_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f46bd570-5768-462e-b84c-c7c993bbf47e"^^xsd:anyURI .
#
# MusicGroup:Hem    a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hem" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hem_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/232bb885-d7c6-4463-a694-0830ae3300bc"^^xsd:anyURI .
#
# MusicGroup:Lo_Cura  a         bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label  "Lo Cura" .
#
# MusicGroup:ZappaPlaysZappa  a                    bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Zappa Plays Zappa" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Zappa_Plays_Zappa.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fcebdabe-319f-4690-8827-c8fac63b1b80"^^xsd:anyURI .
#
# MusicGroup:Yardbirds  a                          bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Yardbirds" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Yardbirds.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/191de76f-a224-445d-b041-54df16d65bf7"^^xsd:anyURI .
#
# MusicGroup:Trout_Fishing_in_America
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Trout Fishing in America" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Trout_Fishing_in_America_(duo).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/514afd98-fc4e-45d1-83a2-f0efcd784466"^^xsd:anyURI .
#
# MusicGroup:Cream  a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Cream" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cream_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/04cd0cfd-bfd1-4c36-bc38-95c35e2c045f"^^xsd:anyURI .
#
# MusicGroup:Black_Uhuru  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Black Uhuru" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Black_Uhuru.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8ee00333-ec2c-439b-a619-ae160aca2a15"^^xsd:anyURI .
#
# MusicGroup:Cherry_Poppin_Daddies
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Carolina Chocolate Drops" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cherry_Poppin'_Daddies.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e23612fb-6dd6-4d5c-b638-2611bfc8c48a"^^xsd:anyURI .
#
# MusicGroup:Flatlanders  a                        bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Flatlanders" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Flatlanders.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f68b47aa-a7e0-4e2e-bf6a-f6e23e88fec8"^^xsd:anyURI .
#
# MusicGroup:Bleecker_Street  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Bleecker Street" .
#
# MusicGroup:Jethro_Tull  a                        bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Jethro Tull" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jethro_Tull_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ece57992-dc2e-4f67-a269-fa43626c1a3d"^^xsd:anyURI .
#
# MusicGroup:JBs    a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The J.B.'s" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_J.B.'s.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cb6a2948-7b9b-4a15-8c71-2b79cc76408e"^^xsd:anyURI .
#
# MusicGroup:Hank_Dogs  a                          bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hank Dogs" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hank_Dogs.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/12d6382f-23ac-4afa-a442-01a6de786ef4"^^xsd:anyURI .
#
# MusicGroup:Cheifetz_Johansen  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Cheifetz & Johansen" .
#
# MusicGroup:Tina_B_Side_Movement
#         a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tina and The B-Side Movement" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0705810f-2332-44c5-9cce-3c9a3be62d82"^^xsd:anyURI .
#
# MusicGroup:Mahotella_Queens  a                   bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Mahotella Queens" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mahotella_Queens.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf54350f-92c4-495e-9a72-8691b0657aaf"^^xsd:anyURI .
#
# MusicGroup:Dave_Alvin_Guilty_Men
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Dave Alvin and The Guilty Men" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/01585ac5-601a-4c83-842a-877b92d62a0b"^^xsd:anyURI .
#
# MusicGroup:Adalberto_Alvarez_Y_Su_Son
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Adalberto Alvarez Y Su Son" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Adalberto_%C3%81lvarez_y_su_Son.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/be05b7a6-1d86-407d-80f6-0cdfbafc709f"^^xsd:anyURI .
#
# MusicGroup:Renaissance  a                        bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Renaissance" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Renaissance_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/874aec28-dfa7-4a73-a3fa-8212f769754d"^^xsd:anyURI .
#
# MusicGroup:Medeski_Martin_Wood  a                bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Medeski Martin & Wood" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Medeski_Martin_%26_Wood.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/6eed1ed9-ab02-45cd-a306-828bc1b98671"^^xsd:anyURI .
#
# MusicGroup:Amaduduzo  a                          bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Amaduduzo" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a41fb0cf-dc92-495a-8375-7d536ba3a016"^^xsd:anyURI .
#
# MusicGroup:Finn_Bros  a                          bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Finn Brothers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Finn_Brothers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/83af9c0f-aa96-4249-a485-4026d341fb30"^^xsd:anyURI .
#
# MusicGroup:Santana  a                            bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Santana" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Santana_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9a3bf45c-347d-4630-894d-7cf3e8e0b632"^^xsd:anyURI .
#
# MusicGroup:Yothu_Yindi  a                        bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Yothu Yindi" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Yothu_Yindi.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/af5958c6-59b0-4335-a245-ddd46c4a4d9e"^^xsd:anyURI .
#
# MusicGroup:Levellers  a                          bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Levellers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Levellers_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7c8c72f5-01ed-4a55-89d1-ced1a6b3fb0d"^^xsd:anyURI .
#
# MusicGroup:Jazz_Is_Dead  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Jazz Is Dead" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Jazz_Is_Dead.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/df3226af-d263-4cf0-9ce8-fb3182eddba8"^^xsd:anyURI .
#
# MusicGroup:Catherine_Wheel  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Catherine Wheel" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Catherine_Wheel_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/37e3dd97-73f9-4c69-b50d-0c0e3c47c40c"^^xsd:anyURI .
#
# MusicGroup:MC5    a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "MC5" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/MC5.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/08b736bb-1c82-40b4-8b0b-49e2182a067a"^^xsd:anyURI .
#
# MusicGroup:Capercaillie  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Capercaillie" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Capercaillie_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/3020fb04-9795-412f-8474-bf6d2ac6d29c"^^xsd:anyURI .
#
# MusicGroup:Little_Feat  a                        bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Little Feat" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Little_Feat.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9b106beb-12b5-4525-8025-42e295a2b90a"^^xsd:anyURI .
#
# MusicGroup:Old_In_the_Gray  a                    bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Old & In the Gray" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Old_%26_In_the_Gray.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2feac672-164e-4375-baeb-54178e3bfccf"^^xsd:anyURI .
#
# MusicGroup:Kingfish  a                           bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Kingfish" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Kingfish_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b6196f87-0c76-483a-b694-1243362e130e"^^xsd:anyURI .
#
# MusicGroup:Talking_Heads  a                      bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Talking Heads" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Talking_Heads.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a94a7155-c79d-4409-9fcf-220cb0e4dc3a"^^xsd:anyURI .
#
# MusicGroup:Material  a                           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Material" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Material_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ceaf841a-60e9-4391-9e26-88b853cd4658"^^xsd:anyURI .
#
# MusicGroup:Albion_Country_Band  a                bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Albion Country Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Albion_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a63b0be7-151d-497c-b564-dd6a3d8c6dc0"^^xsd:anyURI .
#
# MusicGroup:Nick_Cave_Bad_Seeds  a                bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Nick Cave & the Bad Seeds" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Nick_Cave_and_the_Bad_Seeds.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/172e1f1a-504d-4488-b053-6344ba63e6d0"^^xsd:anyURI .
#
# MusicGroup:Mahavishnu_Project  a                 bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Mahavishnu Project" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/accc8399-1bdf-491e-a3a7-cf99302c65c4"^^xsd:anyURI .
#
# MusicGroup:Hardware  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hardware" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hardware_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/fb619345-f0ba-4d4b-bb7b-83ff173c9d73"^^xsd:anyURI .
#
# MusicGroup:Waterboys  a                          bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "The Waterboys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Waterboys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/21666405-49f8-44f6-94bb-e064f202f7ba"^^xsd:anyURI .
#
# MusicGroup:Sounds_of_Blackness  a                bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sounds of Blackness" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sounds_of_Blackness.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f9d560b-f378-4bdb-9676-8b7aa7744821"^^xsd:anyURI .
#
# MusicGroup:Baka_Beyond  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Baka Beyond" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Baka_Beyond.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/bc30924c-1900-41c3-9a97-41a93433836f"^^xsd:anyURI .
#
# MusicGroup:Freetown  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Freetown" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c5fb83d7-5fe6-4224-aedb-a42432fe8cba"^^xsd:anyURI .
#
# MusicGroup:Nine_Stories  a                       bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Nine Stories" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/94204786-d86d-40ab-ba91-ef8e6c640e07"^^xsd:anyURI .
#
# MusicGroup:Amazulu  a                            bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Amazulu" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Amazulu_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44c0262f-97b2-4227-b5eb-fac46f1e8880"^^xsd:anyURI .
#
# MusicGroup:James_Gang  a                         bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "James Gang" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/James_Gang.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4167b497-1ae5-4502-a8e6-e1546ffbe514"^^xsd:anyURI .
#
# MusicGroup:Illinois_Jacquet_Ben_Webster
#         a                              bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Illinois Jacquet & Ben Webster Sextet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Illinois_Jacquet.ttl"^^xsd:anyURI , "http://dbpedia.org/data/Ben_Webster.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/45288d5c-6d6c-41fb-acf9-e83b23ee01cb"^^xsd:anyURI .
#
# MusicGroup:Rolling_Stones  a                     bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Rolling Stones" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Rolling_Stones.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b071f9fa-14b0-4217-8e97-eb41da73f598"^^xsd:anyURI .
#
# MusicGroup:Oregon_Composers  a  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "Oregon Composers" .
#
# MusicGroup:The_Band  a                           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8c90ad8c-9150-4c51-a1eb-342232e99d06"^^xsd:anyURI .
#
# MusicGroup:Clifton_Chenier_Red_Hot
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Clifton Chenier and his Red Hot Louisiana Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Clifton_Chenier.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0fa64acf-5007-4cbd-9cf7-d039fcb503be"^^xsd:anyURI .
#
# MusicGroup:Bass_Desires  a      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:comment  "For live gigs. Studio releases are under solo artist name (i.e., Marc Johnson)." ;
#         rdfs:label    "Bass Desires" .
#
# MusicGroup:Pogues  a                             bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Pogues" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Pogues.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d41a6875-b626-4c0f-89a1-aecb643d29ff"^^xsd:anyURI .
#
# MusicGroup:Rockpile  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rockpile" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rockpile.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e0bcd6af-e702-4e3c-964d-355801ce2c65"^^xsd:anyURI .
#
# MusicGroup:Solas  a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Solas" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Solas_(group).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ae389557-f85b-4954-88f2-7b542db07ff8"^^xsd:anyURI .
#
# MusicGroup:Rara_Machine  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rara Machine" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e3ef17ef-2b6c-459a-bfb9-e482d4a4798e"^^xsd:anyURI .
#
# MusicGroup:Crosby_Nash  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Crosby & Nash" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Crosby_%26_Nash.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ed944321-63d7-4275-a272-3e856d42a7bf"^^xsd:anyURI .
#
# MusicGroup:David_Grisman_Quintet
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The David Grisman Quintet" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/David_Grisman_Quintet.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/408c9ce8-f9c4-4151-b1b7-39ddd2391982"^^xsd:anyURI .
#
# MusicGroup:Golden_Palominos  a                   bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Golden Palominos" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Golden_Palominos.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/907981c8-f6be-4d8d-9210-01a0c4843b59"^^xsd:anyURI .
#
# MusicGroup:Flowmotion  a                         bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Flowmotion" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c6694bea-a716-48da-8e2d-b745d592aaea"^^xsd:anyURI .
#
# MusicGroup:Guadalcanal_Diary  a                  bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Guadalcanal Diary" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Guadalcanal_Diary_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e9b2f192-d21e-471b-8842-71373cb20080"^^xsd:anyURI .
#
# MusicGroup:The_Dead_Milkmen  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Dead Milkmen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Dead_Milkmen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cdd2e0f0-703d-454d-b5c7-cc3bb6dd5552"^^xsd:anyURI .
#
# MusicGroup:Rat_Pack  a                           bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Rat Pack" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Rat_Pack.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/35e227e5-f724-4699-91b2-d5184cdc7411"^^xsd:anyURI .
#
# MusicGroup:Nomad  a           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "Nomad" .
#
# MusicGroup:Husker_Du  a                          bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hüsker Dü" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/H%C3%BCsker_D%C3%BC.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5c4c90a4-539f-4101-83cf-301bc6a94e06"^^xsd:anyURI .
#
# MusicGroup:Colores_del_Alma  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Colores del Alma" .
#
# MusicGroup:BluegrassReunion  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Bluegrass Reunion" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bluegrass_Reunion.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/release/ebd26d0e-217d-450a-94cb-e55c2758107b"^^xsd:anyURI .
#
# MusicGroup:Pat_Metheny_Group  a                  bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Pat Metheny Group" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pat_Metheny_Group.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://beta.musicbrainz.org/artist/66a7f1f8-0ad6-4e3a-9346-a643e2739a8c"^^xsd:anyURI .
#
# MusicGroup:Two_Nice_Girls  a                     bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Two Nice Girls" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Two_Nice_Girls.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/40ca4c75-bac3-4d30-ac01-e0aea128c1e9"^^xsd:anyURI .
#
# MusicGroup:Legion_of_Mary  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Legion of Mary" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Legion_of_Mary_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cf5fa30a-fbf2-4a9b-a32d-86282752c58e"^^xsd:anyURI .
#
# MusicGroup:America  a                            bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "America" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/America_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/34cf95c7-4be9-4efd-a48a-c2ea4a0bb114"^^xsd:anyURI .
#
# MusicGroup:The_Beatles  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Beatles" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Beatles.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d"^^xsd:anyURI .
#
# MusicGroup:Indigo_Girls  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Indigo Girls" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Indigo_Girls.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/00c49f40-d715-4b79-b223-432048602cce"^^xsd:anyURI .
#
# MusicGroup:Sacrificial_Lamb  a  bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Sacrificial Lamb" .
#
# MusicGroup:Tannahill_Weavers  a                  bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Tannahill Weavers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Tannahill_Weavers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2684a10b-dcf0-46f4-966d-5f26440952a1"^^xsd:anyURI .
#
# MusicGroup:Crash_of_Rhinos  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Crash of Rhinos" .
#
# MusicGroup:Deep_Forest  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Deep Forest" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Deep_Forest.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/67468e38-0c90-4318-b2d2-0c18b7b1e144"^^xsd:anyURI .
#
# MusicGroup:Sweet_Honey_Rock  a                   bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Sweet Honey in the Rock" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Sweet_Honey_in_the_Rock.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/28b6ce62-5e14-443c-80b4-ebb8e04936e1"^^xsd:anyURI .
#
# MusicGroup:VariousBluegrass  a  bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label  "Various Bluegrass" .
#
# MusicGroup:Beatles  a                            bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Beatles" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Beatles.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b10bbbfc-cf9e-42e0-be17-e2c3e1d2600d"^^xsd:anyURI .
#
# MusicGroup:Boukan_Ginen  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Boukan Ginen" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Boukan_Ginen.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a40c79f8-afb6-48fa-a6a5-92b4ea68c7a8"^^xsd:anyURI .
#
# MusicGroup:Born_To_Choose  a  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Born To Choose" .
#
# MusicGroup:Them   a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Them" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Them_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/dbd8e1e8-b3d5-4c5f-9343-bbe5e86380a6"^^xsd:anyURI .
#
# MusicGroup:French_Frith_Kaiser_Thompson
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "French Frith Kaiser Thompson" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/French_Frith_Kaiser_Thompson.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b2f78b55-f7c4-41c1-980c-9d5b6173320f"^^xsd:anyURI .
#
# MusicGroup:Bad_Company  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Bad Company" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bad_Company.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0053dbd9-bfbc-4e38-9f08-66a27d914c38"^^xsd:anyURI .
#
# MusicGroup:Buchanan  a                           bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Buchanan" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Buchanan_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/f6de0675-c521-4193-a0a9-36ce110a967b"^^xsd:anyURI .
#
# MusicGroup:Peace_Orchestra  a                    bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Peace Orchestra" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Peace_Orchestra.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/334cd452-8833-4da4-8f14-90136cb0492f"^^xsd:anyURI .
#
# MusicGroup:Ed_Palermo_Big_Band  a                bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Ed Palermo Big Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Ed_Palermo_Big_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9ec14940-69f1-4537-afe3-c2b94e96b028"^^xsd:anyURI .
#
# MusicGroup:Drive_By_Truckers  a                  bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Drive-By Truckers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Drive-By_Truckers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/8eae1e0a-1696-4532-9e3c-0a072217ef4c"^^xsd:anyURI .
#
# MusicGroup:Swamp_Zombies  a                      bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Swamp Zombies" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Swamp_Zombies.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/1dd108bc-eeb9-4efd-952b-ea233bd5fbf0"^^xsd:anyURI .
#
# MusicGroup:Laughing_Hands  a                     bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Laughing Hands" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/43956e04-70b3-4f24-824d-fcb70ca615c6"^^xsd:anyURI .
#
# MusicGroup:Hot_Tuna  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hot Tuna" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hot_Tuna.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/d13d9feb-b7c7-49f4-9b72-65e29a16aa24"^^xsd:anyURI .
#
# MusicGroup:Los_Lobos  a                          bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Los Lobos" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Los_Lobos.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2b9967c7-3246-4658-a561-ded5408dd9af"^^xsd:anyURI .
#
# MusicGroup:Gipsy_Kings  a                        bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Gipsy Kings" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Gipsy_Kings.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/44a7f7d5-79df-4f44-8f5e-02dfc0626904"^^xsd:anyURI .
#
# MusicGroup:Jody_Grind  a                         bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Jody Grind" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Jody_Grind_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4434d1fa-8f7c-46cb-af0b-738c72314242"^^xsd:anyURI .
#
# MusicGroup:Carlpole  a        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Carlpole & Buddy Mudbomb" .
#
# MusicGroup:Soft_Machine  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Soft Machine" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Soft_Machine.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5193ce6b-a315-4c50-ae49-54e69ffbc988"^^xsd:anyURI .
#
# MusicGroup:Funk_Inc  a                           bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Funk Inc." ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Funk,_Inc..ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ba4b6cca-e93f-451e-bf40-23e5af36f1fb"^^xsd:anyURI .
#
# MusicGroup:Phish  a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Phish" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Phish.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e01646f2-2a04-450d-8bf2-0d993082e058"^^xsd:anyURI .
#
# MusicGroup:Moody_Blues  a                        bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "The Moody Blues" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Moody_Blues.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/774666d2-2064-4d6c-856c-f8cda0aaf9f0"^^xsd:anyURI .
#
# MusicGroup:Willie_Nelson_Friends
#         a                              bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label                     "Willie Nelson & Friends" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/668fd73c-bf54-4310-a139-305517f05311"^^xsd:anyURI .
#
# MusicGroup:Los_Lonely_Boys  a                    bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Los Lonely Boys" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Los_Lonely_Boys.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/98fe243c-3685-4491-8135-edc713963be4"^^xsd:anyURI .
#
# MusicGroup:Tin_Silver  a      bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label  "Tin Silver" .
#
# MusicGroup:Tarika_Sammy  a                       bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tarika Sammy" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e01363bc-0fd5-4f4b-9051-683c54c299ac"^^xsd:anyURI ;
#         owl:sameAs                     :Tarika .
#
# MusicGroup:Faith_No_More  a                      bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Faith No More" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Faith_No_More.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b15ebd71-a252-417d-9e1c-3e6863da68f8"^^xsd:anyURI .
#
# MusicGroup:Danu   a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Danú" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Dan%C3%BA.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/0614c68a-89ee-40bb-a1be-0d588f7987cd"^^xsd:anyURI .
#
# MusicGroup:Butthole_Surfers  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Butthole Surfers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Butthole_Surfers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/2339bc21-aa92-4850-86f0-4bb9433910c8"^^xsd:anyURI .
#
# MusicGroup:Grant_Lee_Buffalo  a                  bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Grant Lee Buffalo" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Grant_Lee_Buffalo.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b2ccf20a-0569-4375-a486-7ca9c5e65afc"^^xsd:anyURI .
#
# MusicGroup:Shakespears_Sister  a                 bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Shakespears Sister" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Shakespears_Sister.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4f20b3e2-adda-4063-a43b-2432ddf9ba8d"^^xsd:anyURI .
#
# MusicGroup:Indigenous  a                         bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Indigenous" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Indigenous_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4cd0fc03-a6a4-4bf5-b09b-5fdc6e510e42"^^xsd:anyURI .
#
# MusicGroup:Fairport_Convention  a                bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Fairport Convention" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Fairport_Convention.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/cc60d937-e80b-4c66-8aa2-e89cb57c8b08"^^xsd:anyURI .
#
# MusicGroup:VariousDylan  a    bibliographica:AlphaClassWZ , mo:MusicGroup ;
#         rdfs:label  "Various Dylan Contributors" .
#
# MusicGroup:Old_School_String_Band
#         a           bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label  "Old School String Band" .
#
# MusicGroup:Mahlathini_Mahotella_Queens
#         a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Mahlathini and the Mahotella Queens" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Mahlathini_and_the_Mahotella_Queens.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7a63191f-6d03-4b91-ae21-86dac044bec8"^^xsd:anyURI .
#
# MusicGroup:Simon_Garfunkel  a                    bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Simon & Garfunkel" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Simon_&_Garfunkel.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/5d02f264-e225-41ff-83f7-d9b1f0b1874a"^^xsd:anyURI .
#
# MusicGroup:Tama   a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Tama" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c9fe3f5f-c7d3-4c86-92da-082867e6eb2d"^^xsd:anyURI .
#
# MusicGroup:NRBQ   a                              bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "NRBQ" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/NRBQ.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/4777dc1b-2533-4189-9062-c1b2b477d5c5"^^xsd:anyURI .
#
# MusicGroup:Hart_Rouge  a                         bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Hart-Rouge" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Hart-Rouge.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b746c051-3a42-4cf6-871a-bdcb39e78686"^^xsd:anyURI .
#
# MusicGroup:Po_Girl  a                            bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Po' Girl" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Po'_Girl.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/74c94b37-d05b-4d7e-910b-2afbffef342f"^^xsd:anyURI .
#
# MusicGroup:Bob_Marley_Wailers  a                 bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Bob Marley & The Wailers" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Bob_Marley_and_the_Wailers.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c296e10c-110a-4103-9e77-47bfebb7fb2e"^^xsd:anyURI .
#
# MusicGroup:The_Blasters  a                       bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Blasters" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Blasters.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ce0a5b20-7485-4074-85c8-bdb6a3668d12"^^xsd:anyURI .
#
# MusicGroup:Ravi_Harris_Prophets
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Ravi Harris & The Prophets" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/baabbfb9-43cd-4507-bbdb-5345606d0156"^^xsd:anyURI .
#
# MusicGroup:Morcheeba  a                          bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Morcheeba" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Morcheeba.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/067102ea-9519-4622-9077-57ca4164cfbb"^^xsd:anyURI .
#
# MusicGroup:Kinsey_Report  a                      bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "The Kinsey Report" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Kinsey_Report.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/56936a3b-1b5f-4495-88b1-93a76a1c5bec"^^xsd:anyURI .
#
# MusicGroup:Alfred_Hause_Tango_Orchestra
#         a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Alfred Hause Tango Orchestra" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/ed99baec-5186-4d44-a5cd-89b8398ebd91"^^xsd:anyURI .
#
# MusicGroup:Band_Du_Jour  a    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label  "Band Du Jour" .
#
# MusicGroup:Carolina_Chocolate_Drops
#         a                              bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Carolina Chocolate Drops" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/The_Carolina_Chocolate_Drops.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/9278d5f4-993d-403a-8dd8-eb61139274cf"^^xsd:anyURI .
#
# MusicGroup:Burning_Spear  a                      bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Burning Spear" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Burning_Spear.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/16dad944-c492-43dd-88ed-e0b7ac520c40"^^xsd:anyURI .
#
# MusicGroup:Glass_Eye  a                          bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "Glass Eye" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Glass_Eye_(band).ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e3b71c72-775b-4e76-b7e2-d778bea16958"^^xsd:anyURI .
#
# MusicGroup:Pink_Floyd  a                         bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Pink Floyd" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pink_Floyd.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/83d91898-7763-47d7-b03b-b92132375c47"^^xsd:anyURI .
#
# MusicGroup:Devonsquare  a                        bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Devonsquare" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Devonsquare.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/455482cd-37db-412c-a7e7-13a81a510879"^^xsd:anyURI .
#
# MusicGroup:Herbs  a                              bibliographica:AlphaClassEH , mo:MusicGroup ;
#         rdfs:label                     "The Herbs" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/76f369d0-c0dd-4664-9075-a94b99b8ca5c"^^xsd:anyURI .
#
# MusicGroup:Serah  a                              bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "Serah" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/e2c79dde-12eb-4588-bc15-09706ba09d44"^^xsd:anyURI .
#
# MusicGroup:Jeff_Beck_Group  a                    bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Jeff Beck Group" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/a6339659-c879-4f88-9908-206d47963e29"^^xsd:anyURI .
#
# MusicGroup:Pink_Martini  a                       bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Pink Martini" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Pink_Martini.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/113e0972-077f-423b-9b5f-3cc8a5bafa0f"^^xsd:anyURI .
#
# MusicGroup:Orchestra_Baobab  a                   bibliographica:AlphaClassMP , mo:MusicGroup ;
#         rdfs:label                     "Orchestra Baobab" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Orchestra_Baobab.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/30331c85-26d4-4daa-9f66-3075cac4c20b"^^xsd:anyURI .
#
# MusicGroup:Cowboy_Junkies  a                     bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Concrete Blonde" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Cowboy_Junkies.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/b52211f1-49a2-4cd2-8535-dd1ba37ea90b"^^xsd:anyURI .
#
# MusicGroup:Led_Zeppelin  a                       bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Led Zeppelin" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Led_Zeppelin.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/678d88b2-87b0-403b-b63d-5da7465aecc3"^^xsd:anyURI .
#
# MusicGroup:Del_McCoury_Band  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "The Del McCoury Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Del_McCoury_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/7e5a0c3f-339a-4e5d-aed0-1946112b4a66"^^xsd:anyURI .
#
# MusicGroup:Battlefield_Band  a                   bibliographica:AlphaClassAD , mo:MusicGroup ;
#         rdfs:label                     "Battlefield Band" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Battlefield_Band.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/48db5a2c-ae66-4e7d-8986-b277a7b867e4"^^xsd:anyURI .
#
# MusicGroup:Los_Van_Van  a                        bibliographica:AlphaClassIL , mo:MusicGroup ;
#         rdfs:label                     "Los Van Van" ;
#         bibliographica:dbpediaURI      "http://dbpedia.org/data/Los_Van_Van.ttl"^^xsd:anyURI ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/452d9da4-21a7-44b0-8299-1ec4a8f031ef"^^xsd:anyURI .
#
# MusicGroup:Syrens  a                             bibliographica:AlphaClassQT , mo:MusicGroup ;
#         rdfs:label                     "The Syrens" ;
#         bibliographica:musicbrainzURI  "https://musicbrainz.org/artist/c3e63c6f-1f5d-40ea-86a2-34c6939a766b"^^xsd:anyURI .
#
# }
